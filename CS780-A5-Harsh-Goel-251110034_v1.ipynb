# %% [markdown]
# # ASSIGNMENT 5 (Policy Gradient and Actor Critic Methods)
# # Submission Deadline: 30-03-2026, 11:59 PM
# # Submission Link: [https://forms.gle/UYb1Lu6jiSiCiWVs8](https://forms.gle/UYb1Lu6jiSiCiWVs8)

# %% [markdown]
# # Table of Contents
#
# 1. [Provide Information](#Provide-Information)
# 2. [Instructions](#Instructions)
# 3. [Environment](#Environment)
# 4. [Hyperparameters](#Hyperparameters)
# 5. [Helper Functions](#helper)
# 6. [DDPG](#ddpg)
# 7. [TD3](#td3)
# 8. [SAC](#SAC)
# 9. [PPO](#ppo)
# 10. [Experiments to Run](#experiments)

# %% [markdown]
# # Provide Information
# <a id="Provide-Information"></a>

# %% [markdown]
# Name: **HARSH GOEL**
#
# Roll No.: **251110034**
#
# IITK EMail: **harshgoel25@iitk.ac.in**

# %% [markdown]
# # Instructions
# <a id="Instructions"></a>

# %% [markdown]
# **Read all the instructions below carefully before you start working on the assignment.**
# - The purpose of this course is that you learn RL and the best way to do that is by implementation and experimentation.
# - The assignment requires your to implement some algorithms and you are required report your findings after experimenting with those algorithms.
# - **You are required to submit a Jupyter notebook (.ipynb). The notebook would include the code, graphs/plots of the experiments you run and your findings/observations.**
# - In case you use any maths in your explanations, render it using latex in the Jupyter notebook.
# - You are expected to implement algorithms on your own and not copy it from other sources/class mates. Of course, you can refer to lecture slides.
# - If you use any reference or material (including code), please cite the source, else it will be considered plagiarism. But referring to other sources that directly solve the problems given in the assignment is not allowed. There is a limit to which you can refer to outside material.
# - This is an individual assignment.
# - In case your solution is found to have an overlap with solution by someone else (including external sources), all the parties involved will get zero in this and all future assignments plus further more penalties in the overall grade. We will check not just for lexical but also semantic overlap. Same applies for the code as well. Even an iota of cheating would NOT be tolerated. If you cheat one line or cheat one page the penalty would be same.
# - Be a smart agent, think long term, if you cheat we will discover it somehow, the price you would be paying is not worth it.
# - In case you are struggling with the assignment, seek help from TAs. Cheating is not an option! I respect honesty and would be lenient if you are not able to solve some questions due to difficulty in understanding. Remember we are there to help you out, seek help if something is difficult to understand.
# - The deadline for the submission is given above. Submit at least 30 minutes before the deadline, lot can happen at the last moment, your internet can fail, there can be a power failure, you can be abducted by aliens, etc.
# - You have to submit your assignment via the Google Form (link above)
# - The form would close after the deadline and we will not accept any solution. No reason what-so-ever would be accepted for not being able to submit before the deadline.
# - Since the assignment involves experimentation, reporting your results and observations, there is a lot of scope for creativity and innovation and presenting new perspectives. Such efforts would be highly appreciated and accordingly well rewarded. Be an exploratory agent!
# - Your code should be very well documented, there are marks for that.
# - In your plots, have a clear legend and clear lines, etc. Of course you would generating the plots in your code but you must also put these plots in your notebook. Generate high resolution pdf/svg version of the plots so that it doesn't pixilate on zooming.
# - For all experiments, report about the seed used in the code documentation, write about the seed used.
# - In your notebook write about all things that are not obvious from the code e.g., if you have made any assumptions, references/sources, running time, etc.
# -  **DO NOT Forget to write name, roll no and email details above**
# - **In addition to checking your code, we will be conducting one-on-one viva for the evaluation. So please make sure that you do not cheat!**
# - For each of the sub-part in the question create a new cell below the question and put your answer in there. This includes the plots as well

# %% [markdown]
# # LLM Usage Policy
#
# It is **OK** to use LLM or other sources (websites, blogs, books, etc) for:
# * Coding ancillary parts of the algorithm such as plotting graphs, etc.
# * To develop understanding of the algorithm in the case it is not clear to you
#
# It is **NOT OK** to use LLM or other sources (websites, blogs, books, etc) for:
# * Writing the code for the main parts of the algorithm especially given that I have already provided pseudo-code in the lectures. (You can use pseudo code as it is from the lecture slides)
# * For doing hyper-parameter tuning of the algorithm.
# * For doing analysis of the results and drawing conclusions about it
#
# Since RL is specialized domain, it is very straight forward to detect when someone (especially a newbie) is taking code from LLM or other sources. In case you are found to do so (even for a small part of assignment), there will be no questions asked direct zero will be awarded to you along with further penalties which will affect your final grade.
#
# Be a smart agent (remember Honesty is the best Policy), it is ok to loose a few marks than getting a zero + penalties. It is OK if you don't do all questions in the assignment which will cost you a few marks vs getting 0.
#
# **Remember that grading is relative and you are not the only one who is finding it tough!**

# %% [markdown]
# # LLM Usage Declaration
#
# It is permitted to use Large Language Models (LLMs) **only for understanding concepts, ideation, and creating initial code stubs**.
# Using an LLM to **completely solve the assignment is not allowed**.
#
# Even if an LLM is used for the permitted purposes, you **must be able to clearly explain the solution without any LLM assistance during the viva**, if called.
#
# ---
#
# ### Q1. **Which Large Language Model (LLM) did you use to complete this assignment?**
#
# > ChatGPT
#
# ---
#
# ### Q2. **In which questions did you use the LLM, and how did it help you?**
# (You may extend this table by adding more rows if needed.)
#
# | Question Number / Sub-part | Used LLM? (Yes/No) | Purpose of Using LLM (e.g., ideation, explanation, code stub, grammar) | Brief Description of LLM Contribution |
# |----------------------------|--------------------|------------------------------------------------------------------------|-------------------------------------|
# | HelperFunctions/PlotResults                         |          Yes          |                            Code Stub                                            |               Used LLM for plotting the graphs and dealing with multiple input types                      |
# |        A3C                  |         Yes           |                                   explanation, code stub                                  |                Got stuck in dealing with multi-processing stuff so used it for unserstanding and efficiently passing data in shared queue                     |
# |       A2C                        |           Yes         |                                  Code Stub, Explanation                                      |                     Got Stuck in handling logic for single env, although "train_a2c" function should work for 1 env as well but because of timing difference, main process was readig from the shared queue before even pushing the data on to the queu by worker which causes trouble so took help of LLM for dealing witht this.                 |
# | PPO / train_ppo                         |          Yes          |                             COde Stub, Explanation                                           |                   Used LLM for understanding and fixing few multiprocessing and gradients accumaulation related bugs                 |
#
# ---
#
# ### Q3. **Did you refer to any other sources or websites apart from the LLM and lecture slides?**
#
# If yes, please mention the source(s) clearly:
# > _Example: Research papers, blogs, documentation, textbooks, etc._
#
# No
#
# ---
#
# ### Q4. **Apart from using any LLM, what was your own contribution while solving this assignment?**
#
# Briefly describe:
# - Your understanding of the concepts
# - The reasoning you applied
# - Any implementation or analysis done independently
#
# > I have used LLM only for understanding multi-processing stuff properly and took its help for little fixes there. Apart from that, Everything written and coded except the plottting codes where I took GPT help, is done by me.
#
# > First i write the code folllowing the lecture notes but exact implementation is quite off from what was mentionedd there, then i just tried normalization and action squeeshing and then rescaling which helped me producing better results.
#
# ---

# %% [markdown]
# Adding Github Link for reference if any plots found missing (In last assignment faced this issue so attaching it.)
#
# https://github.com/Harshgoel22/DRL_Assignment5.git

# %% [markdown]
# # OpenAI Gym Environments [10 marks]
# <a id="Environment"></a>

# %%
# all imports go in here
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import time
import random
from itertools import count, cycle
from collections import deque, namedtuple

from matplotlib import animation
from IPython.display import HTML

from scipy import stats
import os
import matplotlib.pyplot as plt
import torch.multiprocessing as mp
from collections import defaultdict

# %% [markdown]
# In this assignment we will be exploring Deep RL algorithms and for this we will be using environmentd provided by OpenAI Gym. In particular we will be exploring "Pendulum-v1" , "Hopper-v4", and "Half-Cheetah" environments (https://gymnasium.farama.org/environments/classic_control/ ). The code to instantiate the environments are given in the cells below. Run these cells and play with the environments to learn more details about the environments.
#
# **We are restricting 1 env per algorithm, so total 9 environments.**
#
# **It will be like this:**
# **REINFORCE, VPG: Pendulum**
#
# **A2C, A3C, GAE: Hopper**
#
# **DDPG, TD3, SAC, PPO: Half Cheetah**

# %%
# Create Inverted Pendulum environment

env = gym.make('Pendulum-v1', render_mode="rgb_array")
s = env.reset(seed = 34)
print("Observation Space = ")
print(env.observation_space)
print("Action Space = ")
print(env.action_space)
done = False
for episode in range(20):
    print("In episode {}".format(episode))
    for i in range(100):
        env.render()
        print(s)
        a = env.action_space.sample()
        s, r, done, truncated, _ = env.step(a)
        if done:
            print("Finished after {} timestep".format(i+1))
env.close()
# Out:
# Observation Space =
# Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# Action Space =
# Box(-2.0, 2.0, (1,), float32)
# In episode 0
# (array([-0.9996797 , -0.0253075 ,  0.74435383], dtype=float32), {})
# [-0.9981843  -0.06023294  0.6991844 ]
# [-0.9966914  -0.08127849  0.42197648]
# [-0.9945479  -0.10428095  0.46205267]
# [-0.99065125 -0.13641876  0.64749193]
# [-0.9854232  -0.17012076  0.68213487]
# [-0.9797439  -0.20025447  0.6133084 ]
# [-0.97351706 -0.22861432  0.58072853]
# [-0.97011334 -0.24265222  0.2888958 ]
# [-0.97112954 -0.23855276 -0.08447085]
# [-0.9744231  -0.22472125 -0.28436705]
# [-0.9782185  -0.207578   -0.35117164]
# [-0.9830286  -0.18345255 -0.4920184 ]
# [-0.98976827 -0.14268398 -0.82649666]
# [-0.9943704  -0.10595997 -0.7402672 ]
# [-0.99866647 -0.05162701 -1.0901858 ]
# [-0.9998458   0.01755929 -1.3842034 ]
# [-0.9950978   0.09889539 -1.6299423 ]
# [-0.9867585  0.1621964 -1.2771764]
# [-0.978707    0.20526214 -0.8763083 ]
# [-0.97167295  0.2363297  -0.6371055 ]
# [-0.9670854   0.254452   -0.37388384]
# [-0.96366346  0.26711932 -0.26242983]
# [-0.964921    0.26254037  0.09497   ]
# [-0.96662337  0.2562016   0.13126811]
# [-0.971914    0.23533626  0.43052137]
# [-0.9800552   0.19872537  0.7501469 ]
# [-0.9893652   0.14545263  1.0817344 ]
# [-0.9948931   0.10093454  0.89727485]
# [-0.99916947  0.04074717  1.2069653 ]
# [-0.99996644 -0.00819537  0.9790783 ]
# [-0.99894834 -0.04585041  0.7534204 ]
# [-0.996478   -0.08385468  0.76173556]
# [-0.9935344  -0.11353153  0.5964717 ]
# [-0.98838896 -0.15194494  0.77517825]
# [-0.9804138  -0.19694862  0.9141769 ]
# [-0.97101384 -0.23902331  0.86230546]
# [-0.95830584 -0.28574455  0.96846783]
# [-0.95034456 -0.31119958  0.5334349 ]
# [-0.9407018  -0.33923462  0.59296244]
# [-0.93911994 -0.3435895   0.09266625]
# [-0.9445924  -0.32824552 -0.3258177 ]
# [-0.95375174 -0.30059543 -0.5825736 ]
# [-0.9646828  -0.26341426 -0.77514243]
# [-0.9740551  -0.22631086 -0.76542306]
# [-0.9825209  -0.1861524  -0.82087946]
# [-0.98849344 -0.1512636  -0.70796365]
# [-0.99271536 -0.12048334 -0.6213941 ]
# [-0.9974445  -0.07144515 -0.98541355]
# [-0.9996064  -0.02805548 -0.8689384 ]
# [-0.99977237  0.02133568 -0.9879292 ]
# [-0.99822205  0.05960466 -0.76605415]
# [-0.9964719   0.08392695 -0.4877157 ]
# [-0.9930102   0.11802822 -0.6855638 ]
# [-0.9904275   0.138034   -0.40344304]
# [-0.9868272  0.1617778 -0.4803155]
# [-0.98103255  0.19384304 -0.6517214 ]
# [-0.9729233   0.23112823 -0.7631833 ]
# [-0.9676973   0.25211477 -0.43255734]
# [-0.96400714  0.26587632 -0.28495657]
# [-0.9608559   0.2770487  -0.23216769]
# [-0.96419984  0.26517665  0.24668214]
# [-0.9697152   0.24423851  0.4330557 ]
# [-0.9771656   0.21247916  0.6524597 ]
# [-0.98300385  0.18358484  0.5895861 ]
# [-0.9885256   0.15105341  0.6599644 ]
# [-0.9939753   0.10960422  0.83617926]
# [-0.9979847   0.06345492  0.9265457 ]
# [-0.9999883  0.0048375  1.1732012]
# [-0.99870265 -0.05092216  1.1156342 ]
# [-0.99407    -0.10874207  1.1602669 ]
# [-0.98818016 -0.15329704  0.89892715]
# [-0.9793486  -0.20217887  0.9935668 ]
# [-0.9696347  -0.24455774  0.86962634]
# [-0.96342766 -0.26796857  0.4844063 ]
# [-0.9589211  -0.28367302  0.32676908]
# [-0.9593501  -0.28221858 -0.03032842]
# [-0.96630305 -0.2574072  -0.51535773]
# [-0.9732536  -0.22973324 -0.5706884 ]
# [-0.98326224 -0.18219608 -0.9716826 ]
# [-0.9924915  -0.12231379 -1.2119722 ]
# [-0.998897   -0.04695494 -1.5129727 ]
# [-0.99958336  0.02886435 -1.5168113 ]
# [-0.99541736  0.09562605 -1.3380808 ]
# [-0.98496175  0.1727726  -1.5574301 ]
# [-0.9731392   0.23021735 -1.1731424 ]
# [-0.96000606  0.27997917 -1.0294278 ]
# [-0.94500846  0.32704595 -0.9880702 ]
# [-0.92851275  0.37130052 -0.944667  ]
# [-0.91233194  0.40945134 -0.8288662 ]
# [-0.9059011   0.4234894  -0.30882293]
# [-0.90168315  0.43239734 -0.1971221 ]
# [-0.89850575  0.43896174 -0.14585933]
# [-0.89610964  0.4438327  -0.10856824]
# [-0.9054692   0.42441207  0.43117464]
# [-0.92333966  0.38398418  0.8841013 ]
# [-0.9462906   0.32331732  1.2974881 ]
# [-0.9652524  0.2613194  1.2968835]
# [-0.9843331   0.17631887  1.7428675 ]
# [-0.997524    0.07032667  2.1372137 ]
# In episode 1
# [-0.9988712  -0.04750066  2.358066  ]
# [-0.98801553 -0.15435438  2.1491086 ]
# [-0.9639177  -0.26620042  2.2895021 ]
# [-0.9265494  -0.37617323  2.3242722 ]
# [-0.8867476  -0.46225396  1.8974532 ]
# [-0.8525259 -0.522685   1.3892406]
# [-0.8213214 -0.5704657  1.1415074]
# [-0.8034735 -0.5953406  0.6123348]
# [-0.80008185 -0.5998909   0.11350435]
# [-0.8163526  -0.5775538  -0.55271333]
# [-0.83963525 -0.54315066 -0.83088106]
# [-0.86707217 -0.49818254 -1.053671  ]
# [-0.8963885  -0.44326928 -1.2451769 ]
# [-0.93223417 -0.36185563 -1.7796986 ]
# [-0.96457076 -0.26382422 -2.0654576 ]
# [-0.98653364 -0.16355833 -2.0537655 ]
# [-0.99840224 -0.05650612 -2.1552052 ]
# [-0.9990005   0.04469926 -2.0250077 ]
# [-0.9900681   0.14058863 -1.9268351 ]
# [-0.9722367   0.23399955 -1.9026701 ]
# [-0.95033306  0.3112347  -1.6060516 ]
# [-0.92935216  0.3691944  -1.2330005 ]
# [-0.9149449   0.4035788  -0.74565864]
# [-0.90315217  0.4293206  -0.56630874]
# [-0.9040383   0.4274515   0.04137083]
# [-0.9111602   0.41205236  0.33932915]
# [-0.91823125  0.39604467  0.35000244]
# [-0.93245375  0.36128935  0.7510999 ]
# [-0.94906193  0.31508952  0.9819862 ]
# [-0.964745   0.2631865  1.0845457]
# [-0.97937244  0.20206344  1.2571864 ]
# [-0.99241024  0.12297104  1.6036254 ]
# [-0.9991654   0.04084708  1.6484929 ]
# [-0.9988714  -0.04749673  1.7674611 ]
# [-0.9922212  -0.12448759  1.5459356 ]
# [-0.97959095 -0.20100147  1.551375  ]
# [-0.9669718  -0.25488338  1.1069393 ]
# [-0.95536005 -0.29544404  0.8438635 ]
# [-0.94789165 -0.3185929   0.48648772]
# [-0.94297945 -0.33285093  0.30161238]
# [-0.9457214  -0.32497856 -0.1667244 ]
# [-0.9523445  -0.30502456 -0.42049718]
# [-0.9656237  -0.25994396 -0.9400006 ]
# [-0.9805894  -0.19607268 -1.3122585 ]
# [-0.99369055 -0.11215657 -1.6991642 ]
# [-0.99993527 -0.01137724 -2.0203114 ]
# [-0.9956949   0.09269158 -2.0840461 ]
# [-0.9836113   0.18030198 -1.7693727 ]
# [-0.96630186  0.2574117  -1.580984  ]
# [-0.94215196  0.33518606 -1.6292013 ]
# [-0.9143621   0.40489757 -1.5012815 ]
# [-0.88763285  0.4605517  -1.2349973 ]
# [-0.8655955   0.50074387 -0.91682553]
# [-0.8545076   0.51943886 -0.4347241 ]
# [-0.8607484   0.50903064  0.24271877]
# [-0.8711114   0.49108547  0.41445652]
# [-0.8915267   0.4529682   0.86486995]
# [-0.9120893   0.40999168  0.9529389 ]
# [-0.9399637   0.34127447  1.4834498 ]
# [-0.9669153  0.2550975  1.8064784]
# [-0.9891858   0.14666769  2.2149968 ]
# [-0.9990908  0.0426329  2.0910573]
# [-0.99840957 -0.05637651  1.9810449 ]
# [-0.98930365 -0.14587079  1.7997341 ]
# [-0.97431433 -0.22519237  1.6149468 ]
# [-0.9585428  -0.28494856  1.236246  ]
# [-0.9462775 -0.3233557  0.8064163]
# [-0.93277866 -0.36044973  0.78952855]
# [-0.9199962  -0.39192733  0.679512  ]
# [-0.9062481 -0.4227463  0.6749599]
# [-0.8978989  -0.4402017   0.38699427]
# [-0.8977694  -0.4404658   0.00588275]
# [-0.9079855  -0.41900152 -0.47544172]
# [-0.921441   -0.38851827 -0.66644716]
# [-0.9411473  -0.33799654 -1.0847135 ]
# [-0.96256846 -0.27103862 -1.4063092 ]
# [-0.9808638  -0.19469497 -1.5705082 ]
# [-0.9937477  -0.11164879 -1.681288  ]
# [-0.99985445 -0.01706262 -1.8963722 ]
# [-0.9960396   0.08891062 -2.1218326 ]
# [-0.98242736  0.1866454  -1.9743649 ]
# [-0.9613419  0.2753574 -1.8243006]
# [-0.932009    0.36243525 -1.8383603 ]
# [-0.90063244  0.43458164 -1.5738846 ]
# [-0.8714707   0.49044758 -1.2605915 ]
# [-0.8423527   0.53892666 -1.1311814 ]
# [-0.82128054  0.5705246  -0.75964123]
# [-0.8037099  0.5950213 -0.6029551]
# [-0.79081583  0.61205417 -0.42726743]
# [-0.7948263   0.606837    0.13161138]
# [-0.8123148   0.58321923  0.58777785]
# [-0.8341279  0.551571   0.7687916]
# [-0.8607597  0.5090116  1.0042075]
# [-0.8895567   0.45682475  1.192274  ]
# [-0.9267197  0.3757533  1.784258 ]
# [-0.9627384  0.2704345  2.2273042]
# [-0.9870985   0.16011411  2.2607613 ]
# [-0.99873257  0.05033102  2.2090793 ]
# [-0.99726224 -0.07394586  2.487314  ]
# [-0.9810701  -0.19365297  2.4174166 ]
# In episode 2
# [-0.9519219 -0.3063409  2.3292496]
# [-0.9149484 -0.4035708  2.0813904]
# [-0.8801004  -0.47478762  1.5861288 ]
# [-0.85593593 -0.5170819   0.9743094 ]
# [-0.8412146  -0.54070145  0.55665123]
# [-0.83188075 -0.5549544   0.3407483 ]
# [-0.8408535  -0.5412628  -0.32739928]
# [-0.8548862  -0.51881564 -0.52946454]
# [-0.8821242  -0.47101685 -1.1004359 ]
# [-0.9086108  -0.41764385 -1.1918504 ]
# [-0.93781984 -0.34712234 -1.5269951 ]
# [-0.96107996 -0.27627033 -1.4917934 ]
# [-0.97931916 -0.20232145 -1.5236679 ]
# [-0.9944846 -0.1048829 -1.9730332]
# [-0.9999791  -0.00646911 -1.97214   ]
# [-0.99466324  0.10317487 -2.1965592 ]
# [-0.97771835  0.20992103 -2.1627076 ]
# [-0.95074916  0.3099614  -2.0731654 ]
# [-0.9231375   0.38447005 -1.5896243 ]
# [-0.8993219  0.4372872 -1.1589261]
# [-0.87549436  0.48322836 -1.0351695 ]
# [-0.86013615  0.5100645  -0.618426  ]
# [-0.85770273  0.514146   -0.09503733]
# [-0.8576064   0.51430655 -0.00374504]
# [-0.866234   0.4996385  0.3403493]
# [-0.8849127   0.46575686  0.77383417]
# [-0.90595615  0.42337152  0.9465216 ]
# [-0.93127763  0.3643103   1.2854304 ]
# [-0.95488244  0.296984    1.4271905 ]
# [-0.97716296  0.21249138  1.7481742 ]
# [-0.9936365   0.11263459  2.0249949 ]
# [-0.9999067   0.01365836  1.9843066 ]
# [-0.99704933 -0.07676315  1.8099506 ]
# [-0.9862014  -0.16555002  1.7895392 ]
# [-0.9660526  -0.25834545  1.8998682 ]
# [-0.94242203 -0.33442593  1.5937382 ]
# [-0.91775537 -0.3971461   1.3481817 ]
# [-0.896972   -0.44208732  0.99038607]
# [-0.88426566 -0.4669842   0.5590553 ]
# [-0.8780411  -0.4785853   0.26331234]
# [-0.88448286 -0.46657267 -0.27261907]
# [-0.8997835  -0.43633667 -0.6777713 ]
# [-0.9225849  -0.38579416 -1.1090966 ]
# [-0.9498891 -0.3125871 -1.5630612]
# [-0.9743621  -0.22498564 -1.819742  ]
# [-0.9918491  -0.12741803 -1.983259  ]
# [-0.99982333 -0.01879551 -2.1793747 ]
# [-0.99625605  0.08645171 -2.1071277 ]
# [-0.98364     0.18014535 -1.8914891 ]
# [-0.9617931  0.2737772 -1.9236768]
# [-0.9370529   0.34918734 -1.587713  ]
# [-0.9084108  0.4180788 -1.4925133]
# [-0.8872486   0.46129158 -0.9624199 ]
# [-0.8706245   0.49194816 -0.69751215]
# [-0.8600431   0.51022136 -0.42232358]
# [-0.85675985  0.5157156  -0.12801018]
# [-0.86507785  0.50163764  0.32703707]
# [-0.8777671   0.47908756  0.51751786]
# [-0.9019274  0.4318876  1.0606071]
# [-0.92511576  0.37968516  1.1425724 ]
# [-0.9525966   0.30423626  1.606387  ]
# [-0.97716093  0.21250065  1.9000652 ]
# [-0.9942546  0.1070411  2.1377356]
# [-0.99984777 -0.01744854  2.4939198 ]
# [-0.98968315 -0.1432733   2.5263722 ]
# [-0.962152   -0.27251324  2.6447227 ]
# [-0.92336774 -0.38391665  2.3606021 ]
# [-0.8808105 -0.473469   1.9838151]
# [-0.8429266 -0.5380286  1.4974308]
# [-0.8106434 -0.5855402  1.1489941]
# [-0.78357184 -0.6213012   0.8971183 ]
# [-0.76957273 -0.63855916  0.44444665]
# [-0.7616189  -0.6480252   0.24728271]
# [-0.7730252 -0.6343753 -0.3557711]
# [-0.7970651 -0.6038934 -0.7764665]
# [-0.83058923 -0.55688554 -1.154909  ]
# [-0.86770725 -0.49707556 -1.408123  ]
# [-0.9095842  -0.41551962 -1.8342234 ]
# [-0.9486378  -0.31636426 -2.1323917 ]
# [-0.9796172  -0.20087343 -2.3928995 ]
# [-0.9966379  -0.08193234 -2.404503  ]
# [-0.9990287  0.0440647 -2.5220654]
# [-0.9849297   0.17295532 -2.595009  ]
# [-0.96027887  0.279042   -2.1793387 ]
# [-0.9276918  0.3733469 -1.9963565]
# [-0.8899256   0.45610574 -1.8200033 ]
# [-0.8538117   0.52058196 -1.478362  ]
# [-0.82276976  0.5683748  -1.1399355 ]
# [-0.79307294  0.6091266  -1.0085937 ]
# [-0.7795369   0.62635624 -0.4382252 ]
# [-0.7859545   0.61828434  0.20624448]
# [-0.8019515   0.59738916  0.5263283 ]
# [-0.8223635   0.56896245  0.6999581 ]
# [-0.85684943  0.5155667   1.2714947 ]
# [-0.8916044   0.45281515  1.4349737 ]
# [-0.92260987  0.38573444  1.4783293 ]
# [-0.95533866  0.2955131   1.9202234 ]
# [-0.9832972   0.18200709  2.3393064 ]
# [-0.99787664  0.06513181  2.356986  ]
# [-0.99836904 -0.05708968  2.4459736 ]
# In episode 3
# [-0.98401076 -0.17810895  2.4388719 ]
# [-0.9584112  -0.28539088  2.2069983 ]
# [-0.9226166  -0.38571832  2.1314404 ]
# [-0.8809248  -0.47325626  1.9399455 ]
# [-0.8351302 -0.5500523  1.7888653]
# [-0.78828174 -0.6153145   1.6071612 ]
# [-0.749897  -0.6615546  1.2021016]
# [-0.71852344 -0.69550276  0.9245888 ]
# [-0.6965876  -0.7174717   0.62093186]
# [-0.6920792  -0.72182155  0.12529533]
# [-0.7142789  -0.69986117 -0.62455237]
# [-0.75507545 -0.6556379  -1.2035191 ]
# [-0.8098481 -0.5866396 -1.7624805]
# [-0.866434  -0.4992917 -2.082441 ]
# [-0.9243433  -0.38156188 -2.6259134 ]
# [-0.97041714 -0.24143441 -2.952834  ]
# [-0.9966981  -0.08119706 -3.2511435 ]
# [-0.99591094  0.09034058 -3.4350092 ]
# [-0.9634417   0.26791787 -3.6153464 ]
# [-0.9041107  0.4272982 -3.405421 ]
# [-0.8283464   0.56021625 -3.0628915 ]
# [-0.742531   0.6698117 -2.786166 ]
# [-0.65600485  0.7547566  -2.4265585 ]
# [-0.58005106  0.81458014 -1.9344378 ]
# [-0.52811414  0.8491734  -1.248263  ]
# [-0.50100875  0.8654422  -0.6322842 ]
# [-0.502712    0.864454    0.03938399]
# [-0.52561456  0.85072285  0.5340829 ]
# [-0.5787961  0.8154723  1.2762843]
# [-0.6553871  0.7552932  1.9488693]
# [-0.74872774  0.6628776   2.6289144 ]
# [-0.8413182  0.5405402  3.0715299]
# [-0.9238597   0.38273123  3.5665658 ]
# [-0.97981554  0.19990362  3.8298254 ]
# [-9.9999654e-01  2.6401544e-03  3.9723880e+00]
# [-0.9779182  -0.20898803  4.2636037 ]
# [-0.91483676 -0.4038239   4.1030574 ]
# [-0.8169664 -0.5766852  3.9794507]
# [-0.7080258  -0.70618653  3.3886442 ]
# [-0.60382587 -0.7971162   2.7681327 ]
# [-0.52319896 -0.8522105   1.9538336 ]
# [-0.47725904 -0.87876266  1.0613489 ]
# [-0.46091434 -0.8874446   0.37015447]
# [-0.46584788 -0.8848648  -0.11134689]
# [-0.48891336 -0.87233233 -0.52502143]
# [-0.54011816 -0.84158915 -1.1946777 ]
# [-0.62006485 -0.78455055 -1.9649563 ]
# [-0.70655406 -0.70765907 -2.3158288 ]
# [-0.8070921  -0.59042555 -3.0918705 ]
# [-0.89288294 -0.4502889  -3.289943  ]
# [-0.9627764 -0.270299  -3.8677058]
# [-0.9984438  -0.05576797 -4.358133  ]
# [-0.98689985  0.16133423 -4.3567877 ]
# [-0.92572504  0.37819728 -4.5161138 ]
# [-0.8309869   0.55629194 -4.041374  ]
# [-0.7170979  0.6969725 -3.625    ]
# [-0.6062459   0.79527724 -2.9659584 ]
# [-0.5075647   0.86161363 -2.3795109 ]
# [-0.42967469  0.9029838  -1.7644707 ]
# [-0.39205855  0.9199403  -0.8252847 ]
# [-0.3900644   0.9207876  -0.04333422]
# [-0.41602987  0.90935093  0.5674705 ]
# [-0.48353747  0.87532365  1.51233   ]
# [-0.5788397  0.8154413  2.2522714]
# [-0.6889407  0.7248177  2.854429 ]
# [-0.7950453  0.60655    3.1811152]
# [-0.8970459   0.44193742  3.8791337 ]
# [-0.9726884  0.232115   4.470116 ]
# [-1.0000000e+00 -6.2645595e-05  4.6862831e+00]
# [-0.974038   -0.22638443  4.5660295 ]
# [-0.9022672  -0.43117726  4.3486605 ]
# [-0.79988724 -0.60015035  3.9578378 ]
# [-0.68682843 -0.7268196   3.3998184 ]
# [-0.5866235 -0.8098598  2.6046624]
# [-0.51146644 -0.85930324  1.7998556 ]
# [-0.4563963 -0.8897766  1.2589918]
# [-0.42192194 -0.9066322   0.76753443]
# [-0.42769197 -0.9039245  -0.12747477]
# [-0.45301688 -0.89150196 -0.564172  ]
# [-0.4994792  -0.86632586 -1.0570203 ]
# [-0.5656085 -0.8246739 -1.5634685]
# [-0.65729773 -0.753631   -2.3211305 ]
# [-0.7604557  -0.64938974 -2.9357436 ]
# [-0.86128706 -0.5081187  -3.4756517 ]
# [-0.94535977 -0.32602897 -4.0179825 ]
# [-0.99157006 -0.12957163 -4.0432606 ]
# [-0.99677926  0.08019416 -4.2043467 ]
# [-0.9629628   0.26963434 -3.8546584 ]
# [-0.8930426   0.44997206 -3.8744156 ]
# [-0.80827725  0.58880204 -3.2568374 ]
# [-0.7085146   0.70569617 -3.076587  ]
# [-0.6027326   0.79794323 -2.8093953 ]
# [-0.5199922   0.85417104 -2.0015893 ]
# [-0.4607265  0.8875422 -1.3605648]
# [-0.43669283  0.8996107  -0.5378884 ]
# [-0.45410612  0.8909476   0.38898996]
# [-0.49603632  0.86830175  0.9531856 ]
# [-0.55230147  0.83364445  1.3218898 ]
# [-0.6335151  0.7737303  2.01931  ]
# [-0.7378764  0.6749358  2.8766136]
# In episode 4
# [-0.84678227  0.5319397   3.5997632 ]
# [-0.9339842   0.35731417  3.9099786 ]
# [-0.98902476  0.1477497   4.3419604 ]
# [-0.99671406 -0.08100029  4.587635  ]
# [-0.95343655 -0.30159366  4.5054917 ]
# [-0.8613973 -0.5079317  4.528366 ]
# [-0.7354633  -0.67756456  4.2332816 ]
# [-0.5998786 -0.800091   3.660017 ]
# [-0.48307836 -0.87557715  2.7836454 ]
# [-0.38773996 -0.9217688   2.1197727 ]
# [-0.31474692 -0.94917566  1.5597694 ]
# [-0.27319488 -0.9619587   0.8695464 ]
# [-0.28017986 -0.9599475  -0.14537546]
# [-0.31610888 -0.9487229  -0.7528754 ]
# [-0.37348148 -0.92763764 -1.2226809 ]
# [-0.47102723 -0.8821187  -2.1539128 ]
# [-0.5974932 -0.801874  -2.9983273]
# [-0.73372024 -0.6794517  -3.6681995 ]
# [-0.853516  -0.5210667 -3.9782968]
# [-0.94238234 -0.3345378  -4.13971   ]
# [-0.9930144  -0.11799331 -4.4569182 ]
# [-0.9923246   0.12366068 -4.8449373 ]
# [-0.9357861   0.35256812 -4.72672   ]
# [-0.8350827   0.55012447 -4.4439845 ]
# [-0.70366675  0.71053016 -4.1547613 ]
# [-0.56735915  0.8234705  -3.5449936 ]
# [-0.4299825  0.9028372 -3.176438 ]
# [-0.32009047  0.947387   -2.3729684 ]
# [-0.22689627  0.9739189  -1.938707  ]
# [-0.15719132  0.98756814 -1.4208736 ]
# [-0.13811818  0.99041575 -0.38569677]
# [-0.16925463  0.98557234  0.6302443 ]
# [-0.24634252  0.96918285  1.5766263 ]
# [-0.36087066  0.9326159   2.4059327 ]
# [-0.5131473   0.85830057  3.3929276 ]
# [-0.67992866  0.7332783   4.176353  ]
# [-0.8407268  0.5414595  5.019177 ]
# [-0.957175    0.28950992  5.569147  ]
# [-9.9999011e-01  4.4512744e-03  5.7852702e+00]
# [-0.9563188  -0.29232585  6.0221863 ]
# [-0.83199877 -0.5547775   5.8287497 ]
# [-0.65448374 -0.7560761   5.384025  ]
# [-0.45106116 -0.892493    4.910912  ]
# [-0.24401288 -0.969772    4.4290457 ]
# [-0.07525513 -0.9971643   3.4235067 ]
# [ 0.04894625 -0.9988014   2.4858432 ]
# [ 0.13886838 -0.99031085  1.8070563 ]
# [ 0.17900069 -0.9838489   0.8130403 ]
# [ 0.18795839 -0.982177    0.18224868]
# [ 0.14928246 -0.98879457 -0.78481036]
# [ 0.08402792 -0.9964634  -1.3143088 ]
# [-0.02363714 -0.99972063 -2.1553292 ]
# [-0.1634518  -0.98655134 -2.8109832 ]
# [-0.33664268 -0.94163245 -3.5832138 ]
# [-0.51988757 -0.8542347  -4.067402  ]
# [-0.71105236 -0.70313907 -4.885488  ]
# [-0.87971926 -0.47549352 -5.6855536 ]
# [-0.97905624 -0.20358996 -5.810033  ]
# [-0.9962249   0.08681004 -5.838855  ]
# [-0.93526626  0.35394502 -5.4973273 ]
# [-0.80842286  0.5886021  -5.3508563 ]
# [-0.64745575  0.7621031  -4.7445297 ]
# [-0.4769221  0.8789456 -4.141833 ]
# [-0.3164609   0.94860554 -3.5030646 ]
# [-0.1671965  0.9859236 -3.0802174]
# [-0.04858977  0.9988188  -2.3875308 ]
# [ 0.04720121  0.9988854  -1.9165531 ]
# [ 0.11010422  0.99392    -1.2621831 ]
# [ 0.15034541  0.9886335  -0.811795  ]
# [ 0.16201009  0.9867891  -0.2361931 ]
# [0.12716345 0.9918818  0.70437235]
# [0.0592988 0.9982403 1.3635017]
# [-0.04870683  0.9988131   2.161194  ]
# [-0.2063597  0.9784762  3.18254  ]
# [-0.3935821   0.91928947  3.9334369 ]
# [-0.5934683  0.8048573  4.6167264]
# [-0.78769064  0.616071    5.4338036 ]
# [-0.9326158   0.36087078  5.890869  ]
# [-0.99825007  0.05913348  6.200668  ]
# [-0.9643516  -0.26462427  6.5396457 ]
# [-0.8341239 -0.5515771  6.32879  ]
# [-0.6449911 -0.7641901  5.710618 ]
# [-0.43022132 -0.90272343  5.125474  ]
# [-0.21428575 -0.976771    4.575548  ]
# [-0.01665214 -0.99986136  3.9861522 ]
# [ 0.14732093 -0.9890888   3.29024   ]
# [ 0.2822196 -0.9593498  2.7649577]
# [ 0.3918089 -0.9200466  2.329798 ]
# [ 0.47464833 -0.88017553  1.8393515 ]
# [ 0.53349936 -0.84580046  1.3633614 ]
# [ 0.5524156  -0.8335688   0.45053777]
# [ 0.55093706 -0.8345468  -0.0354552 ]
# [ 0.5198608  -0.85425097 -0.73597306]
# [ 0.45188054 -0.89207846 -1.5563148 ]
# [ 0.3613288 -0.9324385 -1.9835932]
# [ 0.22403276 -0.9745816  -2.8748424 ]
# [ 0.04628452 -0.9989283  -3.592988  ]
# [-0.18448696 -0.98283494 -4.6370177 ]
# [-0.45054856 -0.89275193 -5.6365976 ]
# [-0.7033402  -0.71085346 -6.2541146 ]
# In episode 5
# [-0.89639497 -0.44325623 -6.6296573 ]
# [-0.99473196 -0.10251009 -7.13075   ]
# [-0.9701451   0.24252516 -6.9531674 ]
# [-0.8395109   0.54334277 -6.5889187 ]
# [-0.64029396  0.76812994 -6.030032  ]
# [-0.42338127  0.9059516  -5.154131  ]
# [-0.21253838  0.9771527  -4.4600477 ]
# [-0.03302621  0.9994545  -3.6227949 ]
# [ 0.09836394  0.9951505  -2.6311095 ]
# [ 0.17943151  0.9837705  -1.6377059 ]
# [ 0.21717961  0.9761317  -0.77031267]
# [ 0.2178985   0.97597146 -0.01473061]
# [0.18121801 0.98344296 0.74871784]
# [0.09371516 0.99559903 1.7674389 ]
# [-0.02931641  0.9995702   2.4634697 ]
# [-0.18993606  0.98179644  3.235528  ]
# [-0.36820573  0.92974436  3.7196283 ]
# [-0.56364375  0.826018    4.43424   ]
# [-0.7440815   0.66808885  4.807371  ]
# [-0.8947443  0.4465789  5.3739843]
# [-0.98556185  0.1693159   5.8560524 ]
# [-0.9926208  -0.12125964  5.833886  ]
# [-0.91360855 -0.40659487  5.9433007 ]
# [-0.7563067  -0.65421724  5.8884664 ]
# [-0.546486   -0.83746827  5.5897336 ]
# [-0.33188152 -0.9433211   4.797301  ]
# [-0.13134046 -0.9913373   4.1315284 ]
# [ 0.02457429 -0.999698    3.1259558 ]
# [ 0.14208986 -0.98985374  2.3599122 ]
# [ 0.22968654 -0.97326463  1.7836647 ]
# [ 0.2938145  -0.95586246  1.3291886 ]
# [ 0.32053304 -0.9472373   0.56154233]
# [ 0.3098503  -0.95078534 -0.22513172]
# [ 0.27345055 -0.96188605 -0.7611419 ]
# [ 0.20384748 -0.97900265 -1.433843  ]
# [ 0.09419349 -0.9955539  -2.21906   ]
# [-0.04973286 -0.99876255 -2.8817344 ]
# [-0.24272366 -0.97009546 -3.908382  ]
# [-0.46343073 -0.88613313 -4.733808  ]
# [-0.69322115 -0.72072494 -5.681719  ]
# [-0.88059443 -0.47387075 -6.2233257 ]
# [-0.9881529  -0.15347235 -6.7919984 ]
# [-0.9818387   0.18971772 -6.899119  ]
# [-0.8658053   0.50038093 -6.6632814 ]
# [-0.6738878  0.7388337 -6.1459856]
# [-0.45578942  0.89008766 -5.323988  ]
# [-0.2416896  0.9703536 -4.5830445]
# [-0.04946754  0.9987757  -3.892379  ]
# [ 0.10744457  0.9942111  -3.1428025 ]
# [ 0.21181583  0.9773096  -2.115604  ]
# [ 0.28489584  0.9585585  -1.5093038 ]
# [ 0.3153739  0.9489675 -0.6390572]
# [ 0.32186404  0.94678587 -0.13694042]
# [0.28473476 0.95860636 0.7793589 ]
# [0.21381412 0.97687435 1.4650396 ]
# [0.10885946 0.9940572  2.1280422 ]
# [-0.03706477  0.9993129   2.9229774 ]
# [-0.20551196  0.9786546   3.3982708 ]
# [-0.40667167  0.9135744   4.236422  ]
# [-0.61316454  0.7899552   4.825049  ]
# [-0.7959203  0.6054014  5.209317 ]
# [-0.93754154  0.34787327  5.8993673 ]
# [-0.9993704   0.03548027  6.3962803 ]
# [-0.9633163 -0.2683686  6.143737 ]
# [-0.84666353 -0.5321286   5.7882714 ]
# [-0.6774441 -0.7355743  5.3080263]
# [-0.48367125 -0.87524974  4.7887588 ]
# [-0.29500785 -0.9554948   4.1076136 ]
# [-0.12039889 -0.9927256   3.5754406 ]
# [ 0.01501744 -0.9998872   2.7141938 ]
# [ 0.10135572 -0.9948503   1.7302412 ]
# [ 0.15405144 -0.98806286  1.0627459 ]
# [ 0.17099719 -0.9852715   0.3434863 ]
# [ 0.14284217 -0.9897455  -0.5701844 ]
# [ 0.06465217 -0.9979079  -1.5727032 ]
# [-0.04663034 -0.9989122  -2.2268908 ]
# [-0.18575056 -0.98259693 -2.8037682 ]
# [-0.34253418 -0.9395054  -3.2555451 ]
# [-0.51406956 -0.8577485  -3.8061929 ]
# [-0.6939244  -0.72004783 -4.54005   ]
# [-0.84667665 -0.5321078  -4.8556633 ]
# [-0.95794564 -0.28694978 -5.400938  ]
# [-0.999854   -0.01708742 -5.4790587 ]
# [-0.9691419   0.24650346 -5.3231792 ]
# [-0.8698232   0.49336353 -5.3376346 ]
# [-0.72758085  0.686022   -4.8010993 ]
# [-0.5659177   0.82446176 -4.2648606 ]
# [-0.39974964  0.91662437 -3.806044  ]
# [-0.24304612  0.97001475 -3.314776  ]
# [-0.10741645  0.9942141  -2.7576163 ]
# [-0.00838024  0.9999649  -1.9848751 ]
# [ 0.04703222  0.9988934  -1.1085982 ]
# [ 0.07640482  0.99707687 -0.58859557]
# [0.06082926 0.9981482  0.31225038]
# [-0.00543475  0.9999852   1.3260323 ]
# [-0.09912728  0.99507475  1.8771112 ]
# [-0.23793824  0.9712803   2.8190446 ]
# [-0.41097042  0.9116487   3.6655142 ]
# [-0.5953338  0.8034785  4.2832556]
# [-0.78045946  0.6252064   5.1543865 ]
# In episode 6
# [-0.9179418   0.39671504  5.3492103 ]
# [-0.9927144   0.12049125  5.7430143 ]
# [-0.98332524 -0.18185571  6.0731606 ]
# [-0.8873048  -0.46118352  5.9291058 ]
# [-0.7328328 -0.6804088  5.3798337]
# [-0.55062217 -0.8347546   4.787333  ]
# [-0.38010994 -0.9249413   3.8638852 ]
# [-0.2414668 -0.9704091  2.9207609]
# [-0.12224719 -0.9924997   2.4264672 ]
# [-0.03874949 -0.999249    1.675891  ]
# [ 0.00429196 -0.99999076  0.8610232 ]
# [ 0.02062627 -0.9997873   0.32671532]
# [-0.00838686 -0.99996483 -0.5802939 ]
# [-0.07210966 -0.9973967  -1.2757068 ]
# [-0.16928291 -0.9855675  -1.9585947 ]
# [-0.28737387 -0.9578185  -2.4276376 ]
# [-0.42409965 -0.9056155  -2.9296715 ]
# [-0.5724969 -0.8199069 -3.4316099]
# [-0.7289431  -0.68457425 -4.1445775 ]
# [-0.86640227 -0.49934673 -4.6234975 ]
# [-0.96121615 -0.27579618 -4.8685336 ]
# [-0.99949336 -0.03182861 -4.9516783 ]
# [-0.9740113   0.22649951 -5.2063255 ]
# [-0.8813458  0.4724717 -5.2722173]
# [-0.74358267  0.668644   -4.8058114 ]
# [-0.5810356  0.8138781 -4.3682413]
# [-0.42454755  0.90540564 -3.6307685 ]
# [-0.28445914  0.95868814 -3.0003977 ]
# [-0.16476524  0.98633283 -2.4584446 ]
# [-0.07028797  0.99752676 -1.9034805 ]
# [-0.02309957  0.99973315 -0.94488686]
# [-0.01400713  0.9999019  -0.1818809 ]
# [-0.05622663  0.99841803  0.84497434]
# [-0.12815915  0.99175364  1.4451259 ]
# [-0.24303271  0.9700181   2.3395696 ]
# [-0.3851958  0.9228349  2.998578 ]
# [-0.54439706  0.83882767  3.6050036 ]
# [-0.70991886  0.7042835   4.2742567 ]
# [-0.8612358   0.50820553  4.966268  ]
# [-0.96489596  0.26263246  5.34701   ]
# [-9.9999857e-01  1.6817452e-03  5.2813535e+00]
# [-0.9686349  -0.24848828  5.0560203 ]
# [-0.8784404  -0.47785202  4.941772  ]
# [-0.75531965 -0.6553566   4.3289347 ]
# [-0.61276805 -0.7902628   3.9316635 ]
# [-0.47461128 -0.8801955   3.300724  ]
# [-0.34788784 -0.9375362   2.7841015 ]
# [-0.2521296  -0.96769345  2.0087392 ]
# [-0.17952073 -0.9837542   1.4876215 ]
# [-0.13490409 -0.9908587   0.9036516 ]
# [-0.11986709 -0.9927899   0.30321327]
# [-0.1468153  -0.98916394 -0.5438381 ]
# [-0.21482398 -0.9766528  -1.3832737 ]
# [-0.32858235 -0.94447535 -2.3658118 ]
# [-0.4616591 -0.8870574 -2.9012492]
# [-0.6174936  -0.78657585 -3.7137527 ]
# [-0.777983  -0.6282853 -4.5179367]
# [-0.90641195 -0.42239484 -4.865228  ]
# [-0.98290634 -0.18410636 -5.0184646 ]
# [-0.99694926  0.0780526  -5.2658935 ]
# [-0.93989307  0.34146884 -5.4069433 ]
# [-0.8147693  0.5797852 -5.399717 ]
# [-0.64618397  0.7631817  -4.995152  ]
# [-0.4503615  0.8928463 -4.7080693]
# [-0.26879638  0.96319705 -3.9005394 ]
# [-0.10879439  0.9940643  -3.2626607 ]
# [ 0.01938647  0.99981207 -2.567957  ]
# [ 0.10930412  0.99400836 -1.802705  ]
# [ 0.15750647  0.98751795 -0.97284305]
# [ 0.16537909  0.9862301  -0.15954578]
# [0.1419986  0.98986685 0.4732439 ]
# [0.0755963 0.9971385 1.3362341]
# [-0.01479884  0.9998905   1.8093573 ]
# [-0.14492667  0.9894424   2.6127894 ]
# [-0.31482178  0.9491508   3.4966006 ]
# [-0.5097852   0.86030173  4.293324  ]
# [-0.71162885  0.7025556   5.1375775 ]
# [-0.88630164  0.46310845  5.949663  ]
# [-0.9851306   0.17180707  6.17671   ]
# [-0.98882324 -0.14909276  6.4462886 ]
# [-0.8912029  -0.45360488  6.4231086 ]
# [-0.7049519  -0.70925516  6.3526974 ]
# [-0.46957317 -0.88289356  5.87096   ]
# [-0.22254296 -0.9749229   5.2877045 ]
# [ 0.01817456 -0.99983484  4.8519526 ]
# [ 0.22247364 -0.9749387   4.123508  ]
# [ 0.37003404 -0.9290182   3.093894  ]
# [ 0.4680704 -0.8836912  2.1612058]
# [ 0.54532766 -0.838223    1.7934809 ]
# [ 0.60162526 -0.7987785   1.3750852 ]
# [ 0.6301332  -0.77648705  0.72381073]
# [ 0.6377487 -0.7702445  0.1969418]
# [ 0.61188793 -0.79094446 -0.6625306 ]
# [ 0.5636744 -0.8259971 -1.1923572]
# [ 0.47909886 -0.87776095 -1.9839939 ]
# [ 0.362463  -0.9319982 -2.5743713]
# [ 0.20175396 -0.9794362  -3.3552172 ]
# [-3.1244312e-03 -9.9999511e-01 -4.1254563e+00]
# [-0.25032595 -0.96816164 -4.99785   ]
# [-0.50931776 -0.86057854 -5.627498  ]
# In episode 7
# [-0.7489796 -0.662593  -6.242579 ]
# [-0.9254092  -0.37896943 -6.711863  ]
# [-0.9990266  -0.04411164 -6.891129  ]
# [-0.9533012  0.3020213 -7.018764 ]
# [-0.8056685  0.5923667 -6.543619 ]
# [-0.60076696  0.79942423 -5.846859  ]
# [-0.3779391  0.9258304 -5.1378174]
# [-0.1770712   0.98419803 -4.1911893 ]
# [-2.0598448e-03  9.9999785e-01 -3.5189996e+00]
# [ 0.1243617  0.992237  -2.5348873]
# [ 0.20717432  0.978304   -1.6800241 ]
# [ 0.254967    0.96694976 -0.98255736]
# [ 0.27314252  0.96197355 -0.37689355]
# [0.25115475 0.96794695 0.45570397]
# [0.18762614 0.9822405  1.3025652 ]
# [0.09585971 0.9953948  1.8547536 ]
# [-0.02134277  0.9997722   2.3470304 ]
# [-0.16286659  0.9866481   2.845019  ]
# [-0.33368704  0.94268394  3.532335  ]
# [-0.52725565  0.8497067   4.303109  ]
# [-0.71446353  0.6996727   4.80979   ]
# [-0.87144446  0.4904942   5.24565   ]
# [-0.97551423  0.21993642  5.8181496 ]
# [-0.9972391  -0.07425735  5.921501  ]
# [-0.930226   -0.36698717  6.028847  ]
# [-0.78327936 -0.6216699   5.902094  ]
# [-0.58828896 -0.8086508   5.4196444 ]
# [-0.36648628 -0.93042344  5.074231  ]
# [-0.14836916 -0.9889321   4.5262146 ]
# [ 0.04475937 -0.9989978   3.873866  ]
# [ 0.18670087 -0.9824168   2.8605711 ]
# [ 0.28172028 -0.95949656  1.9556735 ]
# [ 0.34180024 -0.9397726   1.2649062 ]
# [ 0.3552739  -0.93476224  0.28750393]
# [ 0.33233544 -0.94316125 -0.48856777]
# [ 0.28084418 -0.9597534  -1.0821016 ]
# [ 0.18184243 -0.9833277  -2.0362759 ]
# [ 0.04012543 -0.9991946  -2.8544717 ]
# [-0.14173035 -0.9899053  -3.646908  ]
# [-0.3615201 -0.9323643 -4.5537715]
# [-0.58390963 -0.81181866 -5.072771  ]
# [-0.7904642 -0.6125082 -5.7606053]
# [-0.9381374 -0.3462631 -6.1128983]
# [-0.99892426 -0.04637223 -6.14392   ]
# [-0.96679467  0.25555447 -6.096201  ]
# [-0.8429074  0.5380586 -6.1942196]
# [-0.66370183  0.7479972  -5.538144  ]
# [-0.46079588  0.8875061  -4.937304  ]
# [-0.25837913  0.9660436  -4.350955  ]
# [-0.07874902  0.9968945  -3.650267  ]
# [ 0.05885784  0.9982664  -2.7544506 ]
# [ 0.15851636  0.98735636 -2.0059192 ]
# [ 0.20918797  0.9778755  -1.0311329 ]
# [ 0.21132348  0.97741616 -0.04368667]
# [0.18065491 0.98354656 0.6255309 ]
# [0.12017721 0.99275243 1.2236779 ]
# [0.03411523 0.9994179  1.7269307 ]
# [-0.08410918  0.99645656  2.3666103 ]
# [-0.23124088  0.9728965   2.9828856 ]
# [-0.41987452  0.90758216  3.999082  ]
# [-0.61557657  0.78807706  4.596207  ]
# [-0.788608   0.6148963  4.90849  ]
# [-0.918058   0.3964462  5.0922365]
# [-0.99114496  0.13278444  5.489297  ]
# [-0.98716193 -0.15972263  5.8717484 ]
# [-0.8949034  -0.44625992  6.0434394 ]
# [-0.7253157  -0.68841636  5.934436  ]
# [-0.507994  -0.8613606  5.572771 ]
# [-0.27841905 -0.9604597   5.0141335 ]
# [-0.06896418 -0.99761915  4.262574  ]
# [ 0.09286133 -0.9956791   3.2402854 ]
# [ 0.21501707 -0.9766103   2.4742799 ]
# [ 0.30202338 -0.95330054  1.802103  ]
# [ 0.3571458  -0.93404865  1.167918  ]
# [ 0.37083042 -0.9287006   0.29385325]
# [ 0.35109785 -0.9363388  -0.42319357]
# [ 0.30898973 -0.95106536 -0.8922545 ]
# [ 0.23744199 -0.9714017  -1.4879788 ]
# [ 0.1266425 -0.9919484 -2.2549636]
# [-0.02224765 -0.99975246 -2.9846594 ]
# [-0.1989859  -0.98000234 -3.5614707 ]
# [-0.4133264  -0.91058296 -4.5156217 ]
# [-0.63976574 -0.76856995 -5.361787  ]
# [-0.83901733 -0.5441047  -6.025624  ]
# [-0.9657076  -0.25963223 -6.253607  ]
# [-0.99825275  0.05908851 -6.435286  ]
# [-0.9323863   0.36146346 -6.214281  ]
# [-0.790112   0.6129625 -5.799352 ]
# [-0.59109986  0.8065984  -5.5713997 ]
# [-0.3846914  0.9230453 -4.750965 ]
# [-0.1931695  0.9811654 -4.0096397]
# [-0.02933108  0.9995698  -3.3011236 ]
# [ 0.11299254  0.99359584 -2.851393  ]
# [ 0.2296343  0.973277  -2.3693511]
# [ 0.3081916  0.9513243 -1.631792 ]
# [ 0.34522334  0.93852055 -0.78370476]
# [ 0.35997987  0.9329601  -0.31539112]
# [0.33620378 0.94178927 0.50726366]
# [0.29080248 0.9567831  0.95635355]
# [0.22052181 0.97538203 1.4543208 ]
# In episode 8
# [0.11486927 0.9933806  2.1445203 ]
# [-0.02243983  0.9997482   2.7513022 ]
# [-0.19472453  0.98085797  3.4706976 ]
# [-0.3894246   0.92105836  4.0806036 ]
# [-0.59222203  0.8057748   4.6761384 ]
# [-0.7848742   0.61965513  5.373587  ]
# [-0.92801327  0.37254718  5.7310195 ]
# [-0.99734443  0.07282916  6.177172  ]
# [-0.9736388  -0.22809544  6.060296  ]
# [-0.8685223  -0.49565014  5.769243  ]
# [-0.7144505  -0.69968605  5.127494  ]
# [-0.5349095  -0.84490937  4.628755  ]
# [-0.356471  -0.9343064  3.998252 ]
# [-0.19177607 -0.9814387   3.430331  ]
# [-0.05450854 -0.9985133   2.7687182 ]
# [ 0.04579464 -0.9989509   2.0069246 ]
# [ 0.10326747 -0.99465364  1.1528248 ]
# [ 0.12703237 -0.9918986   0.4784925 ]
# [ 0.12345154 -0.9923506  -0.07218485]
# [ 0.06877597 -0.99763215 -1.0987395 ]
# [-0.02611021 -0.99965906 -1.8988698 ]
# [-0.16717441 -0.98592734 -2.8369975 ]
# [-0.34542412 -0.9384467  -3.694553  ]
# [-0.5377576 -0.8430995 -4.3016887]
# [-0.71748173 -0.6965773  -4.6481047 ]
# [-0.8721981  -0.48915282 -5.1899557 ]
# [-0.9714476  -0.23725423 -5.4315953 ]
# [-0.99949515  0.03177202 -5.4263153 ]
# [-0.95768964  0.287803   -5.203092  ]
# [-0.85024554  0.5263863  -5.248256  ]
# [-0.70520943  0.70899904 -4.674661  ]
# [-0.54786193  0.8365688  -4.0582438 ]
# [-0.383965    0.92334765 -3.714394  ]
# [-0.22910677  0.9734013  -3.2585332 ]
# [-0.09796555  0.9951898  -2.6607404 ]
# [ 0.01141351  0.99993485 -2.1907337 ]
# [ 0.07603058  0.9971055  -1.2938054 ]
# [ 0.09931229  0.99505633 -0.46744493]
# [0.08340029 0.9965161  0.31957987]
# [0.04233583 0.9991034  0.8229758 ]
# [-0.04678314  0.99890506  1.7829741 ]
# [-0.18301791  0.9831096   2.7451022 ]
# [-0.34855422  0.93728864  3.4394565 ]
# [-0.54621476  0.8376452   4.4362087 ]
# [-0.73197454  0.681332    4.8675385 ]
# [-0.88623023  0.4632451   5.3585486 ]
# [-0.9834471   0.18119565  5.989026  ]
# [-0.99174196 -0.1282493   6.2161117 ]
# [-0.90787476 -0.41924146  6.080123  ]
# [-0.7435348  -0.66869724  5.996913  ]
# [-0.53621525 -0.8440813   5.447885  ]
# [-0.31943595 -0.9476079   4.8162518 ]
# [-0.1126929 -0.9936299  4.244028 ]
# [ 0.06534722 -0.9978626   3.5665324 ]
# [ 0.19260041 -0.9812773   2.5683534 ]
# [ 0.27145028 -0.9624525   1.6217616 ]
# [ 0.30850434 -0.95122296  0.7744145 ]
# [ 0.2986426  -0.954365   -0.20700485]
# [ 0.24812868 -0.96872705 -1.05044   ]
# [ 0.16081384 -0.9869847  -1.7846575 ]
# [ 0.02076501 -0.9997844  -2.8149734 ]
# [-0.16449459 -0.986378   -3.720242  ]
# [-0.3833929  -0.92358536 -4.56443   ]
# [-0.61343753 -0.78974324 -5.338777  ]
# [-0.809743   -0.58678466 -5.666161  ]
# [-0.95093995 -0.30937555 -6.2509203 ]
# [-0.9998896   0.01485776 -6.587892  ]
# [-0.93952227  0.3424878  -6.694105  ]
# [-0.7739128   0.63329214 -6.724724  ]
# [-0.5384964  0.8426278 -6.3268986]
# [-0.2836627  0.9589241 -5.6208014]
# [-0.02760111  0.999619   -5.200139  ]
# [ 0.18325964  0.98306453 -4.2381167 ]
# [ 0.34180602  0.9397705  -3.2907352 ]
# [ 0.45414424  0.89092815 -2.4514692 ]
# [ 0.53775287  0.8431025  -1.9271622 ]
# [ 0.589334    0.80788946 -1.2492939 ]
# [ 0.6080214   0.79392064 -0.4666349 ]
# [0.5922884  0.80572605 0.39339912]
# [0.5615834  0.8274202  0.75195706]
# [0.501576  0.8651136 1.4175731]
# [0.42296496 0.90614605 1.7740932 ]
# [0.3059679 0.9520418 2.5151992]
# [0.15155731 0.9884485  3.1762264 ]
# [-0.05064411  0.9987168   4.0561876 ]
# [-0.2938282   0.95585823  4.951272  ]
# [-0.55655557  0.83081037  5.8400955 ]
# [-0.79178405  0.61080116  6.469803  ]
# [-0.9553143   0.29559195  7.1399384 ]
# [-0.9966463  -0.08183018  7.639938  ]
# [-0.8941544  -0.44775873  7.6467085 ]
# [-0.68121964 -0.7320791   7.1422358 ]
# [-0.39755172 -0.91757977  6.8116045 ]
# [-0.08869769 -0.9960586   6.400654  ]
# [ 0.19825494 -0.98015046  5.7678323 ]
# [ 0.44446605 -0.8957957   5.2200184 ]
# [ 0.62724215 -0.77882427  4.34858   ]
# [ 0.754466  -0.6563391  3.536661 ]
# [ 0.8457994  -0.53350115  3.0644312 ]
# [ 0.90312546 -0.42937675  2.3786411 ]
# In episode 9
# [ 0.93790036 -0.3469047   1.7906746 ]
# [ 0.96560645 -0.26000804  1.8247662 ]
# [ 0.98384756 -0.17900835  1.6610417 ]
# [ 0.9938728  -0.11052991  1.3844441 ]
# [ 0.99919385 -0.04014534  1.4120017 ]
# [0.99947476 0.03240729 1.4513819 ]
# [0.99516517 0.09821523 1.3192171 ]
# [0.9843634  0.17614979 1.5739975 ]
# [0.9689991  0.24706435 1.4515163 ]
# [0.9491102 0.3149442 1.4149674]
# [0.92180663 0.38765007 1.5536612 ]
# [0.87905836 0.47671422 1.9766424 ]
# [0.8091089 0.5876587 2.6249804]
# [0.7203479 0.693613  2.7666104]
# [0.60020363 0.79984725 3.210961  ]
# [0.43376258 0.9010272  3.901824  ]
# [0.2268636  0.97392654 4.3961678 ]
# [-0.04122696  0.9991498   5.401895  ]
# [-0.35094672  0.9363954   6.346866  ]
# [-0.6629514  0.7486624  7.3234444]
# [-0.8951769   0.44571105  7.681475  ]
# [-0.9979445   0.06408412  7.956807  ]
# [-0.9457309  -0.32495084  7.9017563 ]
# [-0.7533582 -0.6576104  7.7336545]
# [-0.46887422 -0.88326496  7.302762  ]
# [-0.16791892 -0.9858008   6.3859506 ]
# [ 0.11159606 -0.9937537   5.6109443 ]
# [ 0.34741905 -0.93771     4.859766  ]
# [ 0.5313346  -0.84716207  4.107157  ]
# [ 0.65873915 -0.7523714   3.1793308 ]
# [ 0.7425655  -0.66977346  2.3550198 ]
# [ 0.79421735 -0.60763377  1.6165154 ]
# [ 0.82851714 -0.55996376  1.1747164 ]
# [ 0.84911233 -0.5282123   0.756964  ]
# [ 0.85380495 -0.52059305  0.17896818]
# [ 0.8459931 -0.5331938 -0.2965187]
# [ 0.8288621 -0.559453  -0.6270867]
# [ 0.7900759  -0.61300904 -1.322757  ]
# [ 0.7300267  -0.68341863 -1.8514351 ]
# [ 0.63365555 -0.7736153  -2.6418328 ]
# [ 0.51366115 -0.8579931  -2.9364586 ]
# [ 0.35895374 -0.93335533 -3.4459956 ]
# [ 0.1537415 -0.9881111 -4.2558603]
# [-0.09556172 -0.9954235  -5.001229  ]
# [-0.3876364  -0.92181236 -6.0471673 ]
# [-0.6657285 -0.746194  -6.608072 ]
# [-0.89072895 -0.45453483 -7.4095345 ]
# [-0.9953964  -0.09584419 -7.517167  ]
# [-0.96305084  0.26931974 -7.373563  ]
# [-0.8146361   0.57997245 -6.920165  ]
# [-0.5983329   0.80124766 -6.2136526 ]
# [-0.36403465  0.9313854  -5.3764544 ]
# [-0.14106636  0.9900001  -4.6211534 ]
# [ 0.04368355  0.99904543 -3.7047184 ]
# [ 0.19164868  0.9814636  -2.982885  ]
# [ 0.286364   0.9581209 -1.951761 ]
# [ 0.34857103  0.9372824  -1.312327  ]
# [ 0.37299272  0.9278343  -0.5237268 ]
# [0.36364406 0.931538   0.20111293]
# [0.33386335 0.94262147 0.6355534 ]
# [0.27169287 0.962384   1.3049494 ]
# [0.15868291 0.9873296  2.3159025 ]
# [-1.1643758e-03  9.9999934e-01  3.2104180e+00]
# [-0.20867604  0.97798485  4.181133  ]
# [-0.43307516  0.9013578   4.753614  ]
# [-0.6646627   0.74714357  5.5828114 ]
# [-0.8664743   0.49922174  6.4210744 ]
# [-0.983274    0.18213257  6.7909093 ]
# [-0.98724794 -0.15919009  6.860502  ]
# [-0.8810993  -0.47293136  6.6548905 ]
# [-0.68385315 -0.7296197   6.5030184 ]
# [-0.44907212 -0.8934955   5.7460814 ]
# [-0.22254455 -0.97492254  4.826058  ]
# [-0.00765694 -0.9999707   4.335334  ]
# [ 0.15985003 -0.9871413   3.363915  ]
# [ 0.29513633 -0.9554551   2.7811897 ]
# [ 0.39822012 -0.91728985  2.1995492 ]
# [ 0.46364424 -0.88602144  1.4505633 ]
# [ 0.49766022 -0.8673721   0.77590597]
# [ 0.4998684  -0.8661014   0.05095334]
# [ 0.47282395 -0.8811569  -0.6190788 ]
# [ 0.41959882 -0.90770966 -1.189791  ]
# [ 0.34529114 -0.93849564 -1.6090869 ]
# [ 0.22960587 -0.9732837  -2.417525  ]
# [ 0.06290431 -0.9980196  -3.3745368 ]
# [-0.14405963 -0.989569   -4.15017   ]
# [-0.37717426 -0.92614233 -4.8436136 ]
# [-0.62691087 -0.779091   -5.8167696 ]
# [-0.8415128 -0.5402371 -6.449913 ]
# [-0.97709936 -0.21278362 -7.1259193 ]
# [-0.98695403  0.1610022  -7.522579  ]
# [-0.8584289   0.51293254 -7.537829  ]
# [-0.6360616  0.7716383 -6.856306 ]
# [-0.37665373  0.9263541  -6.064044  ]
# [-0.1209097  0.9926635 -5.299502 ]
# [ 0.11343525  0.9935454  -4.697724  ]
# [ 0.31345487  0.9496031  -4.1029825 ]
# [ 0.45647684  0.8897353  -3.1040459 ]
# [ 0.5593511   0.82893085 -2.3914273 ]
# [ 0.6363908  0.7713668 -1.9241503]
# In episode 10
# [ 0.69489545  0.7191108  -1.5692841 ]
# [ 0.73598135  0.67700183 -1.1768125 ]
# [ 0.7620279   0.6475442  -0.78647953]
# [ 0.76557004  0.64335257 -0.1097566 ]
# [0.75597286 0.65460294 0.2957568 ]
# [0.733294   0.67991173 0.679699  ]
# [0.68622786 0.72738665 1.3372741 ]
# [0.6170656  0.78691167 1.8256427 ]
# [0.51466674 0.8573903  2.4877868 ]
# [0.37261584 0.92798567 3.1758533 ]
# [0.19290765 0.9812169  3.7540333 ]
# [-0.02662202  0.9996456   4.414995  ]
# [-0.27771896  0.96066236  5.095874  ]
# [-0.5336354  0.8457146  5.6294904]
# [-0.7745976  0.6324544  6.4637046]
# [-0.9384723  0.3453546  6.6420226]
# [-0.9997752  0.0212037  6.628226 ]
# [-0.9537242  -0.30068275  6.5322747 ]
# [-0.8216191  -0.57003695  6.022847  ]
# [-0.64356804 -0.7653889   5.3018913 ]
# [-0.43977544 -0.89810777  4.8760467 ]
# [-0.23683666 -0.9715495   4.324801  ]
# [-0.07419795 -0.9972435   3.2968473 ]
# [ 0.06544661 -0.9978561   2.7951925 ]
# [ 0.17787467 -0.98405313  2.2666566 ]
# [ 0.25162825 -0.967824    1.5107205 ]
# [ 0.28466293 -0.9586277   0.6858502 ]
# [ 0.27698407 -0.9608745  -0.16001712]
# [ 0.2219245  -0.97506386 -1.1373239 ]
# [ 0.11714652 -0.99311465 -2.127432  ]
# [-0.01996335 -0.99980074 -2.747616  ]
# [-0.18995406 -0.981793   -3.4230134 ]
# [-0.38890365 -0.9212784  -4.166518  ]
# [-0.6044977  -0.79660696 -4.9938765 ]
# [-0.80313706 -0.5957943  -5.668139  ]
# [-0.9424197  -0.33443245 -5.945027  ]
# [-0.99949056 -0.03191558 -6.1816387 ]
# [-0.9599089  0.2803121 -6.3208046]
# [-0.83869886  0.5445954  -5.835749  ]
# [-0.67035156  0.7420436  -5.204143  ]
# [-0.48415703  0.8749811  -4.5856595 ]
# [-0.30917692  0.95100456 -3.8214417 ]
# [-0.14513972  0.9894112  -3.3734648 ]
# [-0.01842344  0.99983025 -2.544594  ]
# [ 0.05984859  0.99820745 -1.5661772 ]
# [ 0.09563787  0.99541616 -0.7179978 ]
# [0.08746574 0.99616754 0.16413242]
# [0.04918334 0.9987898  0.7674892 ]
# [-0.03874351  0.99924916  1.7591279 ]
# [-0.15858461  0.9873454   2.410075  ]
# [-0.30905214  0.9510451   3.0987852 ]
# [-0.4883841   0.87262875  3.9208162 ]
# [-0.665424   0.7464656  4.356492 ]
# [-0.8345721   0.55089873  5.1858788 ]
# [-0.94999325  0.31227037  5.3171754 ]
# [-0.99850464  0.0546675   5.2577443 ]
# [-0.98075145 -0.1952603   5.024352  ]
# [-0.9088122 -0.4172054  4.6769056]
# [-0.78912944 -0.61422694  4.620756  ]
# [-0.64330316 -0.7656115   4.21171   ]
# [-0.50527936 -0.8629558   3.3819845 ]
# [-0.3898755  -0.92086756  2.5841856 ]
# [-0.28713086 -0.95789135  2.185323  ]
# [-0.21239693 -0.97718346  1.5440602 ]
# [-0.18115382 -0.98345476  0.6373532 ]
# [-0.19547854 -0.980708   -0.29171664]
# [-0.25786215 -0.9661817  -1.2812697 ]
# [-0.35501534 -0.93486047 -2.042432  ]
# [-0.47996166 -0.8772895  -2.7536108 ]
# [-0.61830384 -0.78593916 -3.3194346 ]
# [-0.7592123 -0.650843  -3.9103858]
# [-0.8888285  -0.45823994 -4.6536055 ]
# [-0.9761435 -0.2171266 -5.142883 ]
# [-0.99949634  0.03173513 -5.0122066 ]
# [-0.9591954   0.28274417 -5.098267  ]
# [-0.86073744  0.5090492  -4.948519  ]
# [-0.7331478  0.6800693 -4.2755485]
# [-0.5938956  0.8045421 -3.7409382]
# [-0.47097942  0.8821442  -2.90983   ]
# [-0.36149836  0.93237275 -2.4105258 ]
# [-0.27325043  0.9619429  -1.86208   ]
# [-0.23098502  0.9729573  -0.87360984]
# [-0.21336702  0.9769721  -0.3613982 ]
# [-0.2176036   0.9760372   0.08677025]
# [-0.25307637  0.9674463   0.7300056 ]
# [-0.33198217  0.94328564  1.6509058 ]
# [-0.4404016   0.89780086  2.3528361 ]
# [-0.5793931  0.8150482  3.238759 ]
# [-0.7190925  0.6949144  3.6902323]
# [-0.8552002   0.51829785  4.4688277 ]
# [-0.95465016  0.29772982  4.8509135 ]
# [-0.9981748   0.06039092  4.8377213 ]
# [-0.98123336 -0.19282414  5.0893435 ]
# [-0.90176487 -0.43222696  5.0584273 ]
# [-0.78113616 -0.6243607   4.5470395 ]
# [-0.6454269 -0.763822   3.8980277]
# [-0.51463616 -0.85740864  3.2199771 ]
# [-0.40850082 -0.91275793  2.3954453 ]
# [-0.33527723 -0.94211954  1.5782299 ]
# [-0.30567214 -0.9521368   0.62510425]
# In episode 11
# [-0.3228094  -0.946464   -0.36104065]
# [-0.3612201 -0.9324806 -0.8175939]
# [-0.42494592 -0.9052187  -1.386523  ]
# [-0.5184537 -0.8551057 -2.1227906]
# [-0.6405977 -0.7678767 -3.004694 ]
# [-0.7744069  -0.63268787 -3.8100157 ]
# [-0.893511  -0.4490413 -4.3865414]
# [-0.97068673 -0.24034813 -4.459352  ]
# [-0.99998057 -0.00623495 -4.7297897 ]
# [-0.97199255  0.23501158 -4.8693094 ]
# [-0.88946146  0.45701018 -4.7480087 ]
# [-0.7737087  0.6335415 -4.229822 ]
# [-0.6326471  0.7744402 -3.994155 ]
# [-0.4959714  0.8683388 -3.3202674]
# [-0.3811842  0.9244991 -2.5575268]
# [-0.29825702  0.9544856  -1.7642161 ]
# [-0.25946996  0.9657512  -0.80785453]
# [-0.24322423  0.9699701  -0.33569577]
# [-0.26802307  0.9634125   0.513038  ]
# [-0.33991703  0.94045544  1.5097651 ]
# [-0.44561493  0.89522475  2.300647  ]
# [-0.57610387  0.8173765   3.0418591 ]
# [-0.7242143   0.68957496  3.9188063 ]
# [-0.8619917   0.50692236  4.5858274 ]
# [-0.963983   0.2659638  5.2481413]
# [-0.9999802  -0.00628674  5.509807  ]
# [-0.95788133 -0.2871644   5.699569  ]
# [-0.8385556 -0.5448161  5.69809  ]
# [-0.6702632  -0.74212354  5.2012653 ]
# [-0.47444102 -0.8802873   4.8046875 ]
# [-0.27610928 -0.96112627  4.2917056 ]
# [-0.09607954 -0.99537367  3.6703136 ]
# [ 0.0451312  -0.99898106  2.82749   ]
# [ 0.14276129 -0.9897571   1.9620837 ]
# [ 0.21348086 -0.97694725  1.4377172 ]
# [ 0.24868882 -0.96858346  0.72379446]
# [ 0.24213329 -0.970243   -0.13524678]
# [ 0.18963829 -0.981854   -1.0754045 ]
# [ 0.11028193 -0.99390036 -1.6057407 ]
# [-0.0081334 -0.9999669 -2.372804 ]
# [-0.14979523 -0.988717   -2.8445535 ]
# [-0.33193907 -0.94330084 -3.759946  ]
# [-0.540879  -0.8411004 -4.662467 ]
# [-0.73695433 -0.67594254 -5.141432  ]
# [-0.89077693 -0.45444077 -5.409972  ]
# [-0.9838808 -0.1788254 -5.8390374]
# [-0.99157405  0.12954108 -6.193972  ]
# [-0.9091082   0.41655996 -5.9950385 ]
# [-0.76215327  0.6473966  -5.4901123 ]
# [-0.5793573   0.81507367 -4.973853  ]
# [-0.3802003   0.92490417 -4.5585427 ]
# [-0.185111    0.98271763 -4.076561  ]
# [-0.02946789  0.9995657  -3.1342533 ]
# [ 0.09384816  0.9955865  -2.4691725 ]
# [ 0.17940581  0.98377514 -1.727919  ]
# [ 0.21907607  0.97570777 -0.80970013]
# [0.21563044 0.97647506 0.07060034]
# [0.18225838 0.9832507  0.6810918 ]
# [0.11237702 0.99366564 1.4133584 ]
# [0.00284148 0.99999595 2.1954684 ]
# [-0.1298691   0.99153113  2.6615689 ]
# [-0.30565524  0.95214224  3.6077914 ]
# [-0.50130826  0.86526877  4.2896714 ]
# [-0.6985729  0.7155389  4.9658194]
# [-0.86693716  0.4984175   5.5124574 ]
# [-0.9737046   0.22781444  5.8387985 ]
# [-0.9965013  -0.08357663  6.270135  ]
# [-0.9190429 -0.3941576  6.4295363]
# [-0.75666976 -0.65379727  6.1488204 ]
# [-0.53222865 -0.84660065  5.939469  ]
# [-0.3028498 -0.9530383  5.0709877]
# [-0.08050843 -0.99675393  4.541716  ]
# [ 0.09406278 -0.99556625  3.4959538 ]
# [ 0.22619188 -0.97408277  2.6792881 ]
# [ 0.314571   -0.94923395  1.8367646 ]
# [ 0.37042964 -0.92886055  1.1893367 ]
# [ 0.39259854 -0.9197099   0.47967547]
# [ 0.37344837 -0.927651   -0.41463414]
# [ 0.30889672 -0.9510956  -1.3738154 ]
# [ 0.20557937 -0.97864044 -2.1395426 ]
# [ 0.06573898 -0.9978368  -2.8253853 ]
# [-0.10801261 -0.9941495  -3.4802032 ]
# [-0.31688195 -0.948465   -4.2843294 ]
# [-0.54786843 -0.8365645  -5.1474776 ]
# [-0.76611596 -0.6427024  -5.8592353 ]
# [-0.93038    -0.36659658 -6.453444  ]
# [-0.99943924 -0.03348479 -6.837144  ]
# [-0.95478547  0.29729575 -6.707003  ]
# [-0.8043445   0.59416324 -6.687317  ]
# [-0.58648664  0.80995893 -6.157143  ]
# [-0.32879215  0.94440234 -5.8337984 ]
# [-0.06795365  0.9976885  -5.340366  ]
# [ 0.15721989  0.9875636  -4.517619  ]
# [ 0.32956892  0.9441315  -3.559441  ]
# [ 0.46239308  0.88667506 -2.8969061 ]
# [ 0.56376845  0.82593286 -2.3649833 ]
# [ 0.6404356  0.7680119 -1.9224768]
# [ 0.68021107  0.7330163  -1.0597062 ]
# [ 0.7004624   0.7136893  -0.55989254]
# [ 0.70453894  0.70966536 -0.11456109]
# In episode 12
# [0.69136566 0.72250503 0.36791423]
# [0.6662489 0.7457294 0.6842039]
# [0.6302397  0.77640057 0.9461076 ]
# [0.57742894 0.81644094 1.3257182 ]
# [0.49048808 0.8714479  2.0585263 ]
# [0.37313822 0.92777574 2.6052098 ]
# [0.203837   0.97900486 3.5422726 ]
# [-0.01857175  0.9998275   4.476969  ]
# [-0.28815043  0.95758516  5.474439  ]
# [-0.56658584  0.82400274  6.2012353 ]
# [-0.8156946   0.57848287  7.0314455 ]
# [-0.97041106  0.24145888  7.4599714 ]
# [-0.9921592 -0.1249808  7.3835483]
# [-0.8855481  -0.46454763  7.1563044 ]
# [-0.67613983 -0.7367733   6.903239  ]
# [-0.41585982 -0.9094287   6.272453  ]
# [-0.15189548 -0.9883966   5.528046  ]
# [ 0.08782144 -0.99613625  4.808409  ]
# [ 0.28457665 -0.9586533   4.0126014 ]
# [ 0.42535445 -0.90502685  3.0157738 ]
# [ 0.52645946 -0.85020024  2.301546  ]
# [ 0.59174603 -0.80612445  1.5758456 ]
# [ 0.62634647 -0.7795448   0.87269074]
# [ 0.62717414 -0.77887905  0.02124408]
# [ 0.6136817 -0.7895536 -0.3440934]
# [ 0.5642633 -0.8255949 -1.2234894]
# [ 0.48640284 -0.87373465 -1.8314527 ]
# [ 0.36277768 -0.9318757  -2.7344222 ]
# [ 0.20083317 -0.97962546 -3.3807714 ]
# [-0.01090769 -0.9999405  -4.2623253 ]
# [-0.25356415 -0.9673186  -4.909103  ]
# [-0.50862265 -0.8609896  -5.5444255 ]
# [-0.7394023  -0.67326385 -5.971957  ]
# [-0.9144657  -0.40466338 -6.440069  ]
# [-0.9973175  -0.07319725 -6.8669586 ]
# [-0.9592497  0.2825599 -7.1944895]
# [-0.80938524  0.58727807 -6.8246007 ]
# [-0.5778416   0.81614894 -6.5404606 ]
# [-0.31082037  0.95046866 -6.00051   ]
# [-0.05158111  0.9986688  -5.2890406 ]
# [ 0.1848268  0.9827711 -4.749993 ]
# [ 0.36664048  0.9303627  -3.7899969 ]
# [ 0.5110132  0.8595729 -3.2193525]
# [ 0.60927284  0.79296064 -2.3756034 ]
# [ 0.68304753  0.7303739  -1.9356763 ]
# [ 0.72581065  0.6878946  -1.2057    ]
# [ 0.74026984  0.6723099  -0.42519054]
# [0.72797394 0.6856048  0.36218894]
# [0.6942975 0.7196881 0.9583778]
# [0.63688934 0.7709552  1.5397315 ]
# [0.55576897 0.8313368  2.0233803 ]
# [0.4511678 0.8924391 2.4242852]
# [0.31423205 0.9493462  2.9685163 ]
# [0.13401785 0.9909789  3.7045062 ]
# [-0.10277278  0.99470484  4.747537  ]
# [-0.35887963  0.9333838   5.282254  ]
# [-0.61643517  0.78740567  5.9428    ]
# [-0.8316758   0.55526143  6.3582344 ]
# [-0.97237116  0.2334401   7.0612655 ]
# [-0.99154365 -0.12977365  7.3150945 ]
# [-0.87584376 -0.4825948   7.4694843 ]
# [-0.6472214 -0.7623021  7.264953 ]
# [-0.37366048 -0.9275656   6.4196305 ]
# [-0.09778874 -0.9952072   5.700139  ]
# [ 0.13475059 -0.99087954  4.6621404 ]
# [ 0.32445323 -0.94590175  3.9054375 ]
# [ 0.45905027 -0.8884103   2.929845  ]
# [ 0.566684  -0.8239352  2.5109966]
# [ 0.63177544 -0.7751515   1.6273156 ]
# [ 0.6805418 -0.7327092  1.2932068]
# [ 0.7135769  -0.7005769   0.92177665]
# [ 0.7201731 -0.6937944  0.1892223]
# [ 0.70671093 -0.70750237 -0.38426486]
# ...
# [ 0.0031953  -0.9999949  -0.39811638]
# [-0.06067395 -0.9981576  -1.2781309 ]
# [-0.1565737  -0.98766625 -1.9301873 ]
# [-0.30033028 -0.95383525 -2.956366  ]
# [-0.47570693 -0.87960386 -3.814573  ]
# [-0.65292084 -0.75742614 -4.313336  ]
# [-0.81102514 -0.5850113  -4.6893587 ]
# [-0.9332016 -0.3593532 -5.146386 ]
# [-0.9965235  -0.08331194 -5.683322  ]
# [-0.9821117   0.18829915 -5.456773  ]
# [-0.89194536  0.45214322 -5.594734  ]
# [-0.75145966  0.6597791  -5.027159  ]
# [-0.5932212  0.8050395 -4.304347 ]
# [-0.42994773  0.9028538  -3.812387  ]
# [-0.26956466  0.9629823  -3.4298792 ]
# [-0.13029662  0.99147505 -2.845456  ]
# [-0.01386097  0.9999039  -2.3361347 ]
# [ 0.07335615  0.9973058  -1.7456703 ]
# [ 0.13759352  0.99048877 -1.2921864 ]
# [ 0.15147799  0.9884606  -0.28063866]
# [0.12800755 0.9917732  0.47407243]
# [0.07887756 0.9968843  0.988003  ]
# [-0.00557046  0.9999845   1.6906015 ]
# [-0.12938285  0.99159473  2.4835215 ]
# [-0.29120243  0.95666146  3.3147385 ]
# [-0.4785969  0.8780348  4.07145  ]
# [-0.6683579   0.74383986  4.6588597 ]
# In episode 16
# [-0.83605814  0.54864085  5.161192  ]
# [-0.95669794  0.2910826   5.70759   ]
# [-9.9999732e-01 -2.3082278e-03  5.9533291e+00]
# [-0.9563428 -0.2922471  5.885349 ]
# [-0.835889  -0.5488985  5.689405 ]
# [-0.6636076  -0.74808085  5.282389  ]
# [-0.47485757 -0.88006264  4.6165752 ]
# [-0.29989374 -0.95397264  3.8044183 ]
# [-0.14019467 -0.990124    3.278465  ]
# [-0.00673328 -0.99997735  2.6784937 ]
# [ 0.08804168 -0.9961168   1.897783  ]
# [ 0.13593788 -0.99071735  0.9640851 ]
# [ 0.14999539 -0.9886867   0.28407073]
# [ 0.11507839 -0.9933564  -0.7045939 ]
# [ 0.04564298 -0.9989578  -1.3935014 ]
# [-0.06089774 -0.99814403 -2.1318858 ]
# [-0.19985086 -0.97982633 -2.8054054 ]
# [-0.35775167 -0.93381673 -3.293068  ]
# [-0.5429995 -0.839733  -4.1629176]
# [-0.71874714 -0.6952716  -4.5598726 ]
# [-0.8764424 -0.4815068 -5.3284917]
# [-0.9749991  -0.22220868 -5.565878  ]
# [-0.99885076  0.04792806 -5.4405127 ]
# [-0.95004606  0.31210968 -5.3893285 ]
# [-0.83462733  0.55081505 -5.3185525 ]
# [-0.67057747  0.7418395  -5.049379  ]
# [-0.48083797  0.8768095  -4.667535  ]
# [-0.29348692  0.9559631  -4.074756  ]
# [-0.13124576  0.9913499  -3.324937  ]
# [ 0.01007302  0.9999493  -2.833974  ]
# [ 0.12507339  0.9921475  -2.3065722 ]
# [ 0.19501953  0.9807994  -1.4175111 ]
# [ 0.22868694  0.9735     -0.6890263 ]
# [0.21514727 0.97658163 0.2777209 ]
# [0.17790708 0.9840473  0.75966877]
# [0.0951381 0.9954641 1.6715394]
# [-0.02592491  0.9996639   2.4242005 ]
# [-0.18484539  0.98276764  3.1997342 ]
# [-0.38450027  0.9231249   4.1750374 ]
# [-0.5924359  0.8056176  4.7882547]
# [-0.7779998  0.6282645  5.147935 ]
# [-0.92390424  0.3826237   5.73372   ]
# [-0.99624485  0.08658062  6.1189055 ]
# [-0.9783093  -0.20714961  5.9069924 ]
# [-0.8721868  -0.48917294  6.0496154 ]
# [-0.7076287  -0.70658445  5.4703693 ]
# [-0.5196043 -0.854407   4.794976 ]
# [-0.3290381 -0.9443166  4.2220607]
# [-0.15997219 -0.9871215   3.4924457 ]
# [-0.00936037 -0.9999562   3.0260396 ]
# [ 0.11169917 -0.99374205  2.4258652 ]
# [ 0.18135858 -0.98341703  1.4087002 ]
# [ 0.21275134 -0.9771064   0.6404428 ]
# [ 0.2005847  -0.97967637 -0.24870382]
# [ 0.14453667 -0.98949945 -1.1381998 ]
# [ 0.05437742 -0.99852043 -1.8128093 ]
# [-0.06082963 -0.99814814 -2.3054292 ]
# [-0.20650572 -0.9784454  -2.9427028 ]
# [-0.3900633  -0.92078805 -3.8539596 ]
# [-0.5961017  -0.80290896 -4.7587347 ]
# [-0.790274   -0.61275357 -5.452381  ]
# [-0.9335482  -0.35845184 -5.858624  ]
# [-0.99832416 -0.05786918 -6.17415   ]
# [-0.9672602   0.25378677 -6.2898946 ]
# [-0.8450745  0.5346486 -6.149974 ]
# [-0.65747297  0.75347817 -5.7848897 ]
# [-0.43816468  0.8988947  -5.2780814 ]
# [-0.23255442  0.9725834  -4.3770523 ]
# [-0.06271663  0.9980314  -3.4389093 ]
# [ 0.05804749  0.99831384 -2.4167593 ]
# [ 0.1321714   0.99122685 -1.4895829 ]
# [ 0.18182966  0.9833301  -1.0057504 ]
# [ 0.19957937  0.97988164 -0.36163673]
# [0.19467555 0.9808677  0.10003968]
# [0.14993624 0.9886957  0.9084575 ]
# [0.0710017 0.9974762 1.5888458]
# [-0.05797632  0.99831796  2.5814068 ]
# [-0.21678054  0.97622037  3.2101307 ]
# [-0.39497867  0.9186903   3.7505848 ]
# [-0.5771254  0.8166556  4.1831937]
# [-0.74963975  0.66184604  4.646267  ]
# [-0.89437276  0.4473224   5.1901884 ]
# [-0.9798503   0.19973332  5.25367   ]
# [-0.9980038  -0.06315399  5.285636  ]
# [-0.9468551 -0.3216603  5.2857285]
# [-0.8382583 -0.5452733  4.9846535]
# [-0.6829893  -0.73042834  4.8446755 ]
# [-0.49908626 -0.8665523   4.5860686 ]
# [-0.30932665 -0.95095587  4.1611824 ]
# [-0.12977768 -0.9915431   3.6868021 ]
# [ 2.1104426e-03 -9.9999779e-01  2.6451042e+00]
# [ 0.08697502 -0.9962105   1.6994922 ]
# [ 0.12470726 -0.9921936   0.7589544 ]
# [ 0.11871246 -0.9929287  -0.12079412]
# [ 0.09054628 -0.9958922  -0.5664521 ]
# [ 0.02702272 -0.9996348  -1.2728891 ]
# [-0.07980584 -0.99681044 -2.1383362 ]
# [-0.23601098 -0.9717504  -3.1673603 ]
# [-0.42051628 -0.907285   -3.9151094 ]
# [-0.61180896 -0.79100555 -4.4866242 ]
# In episode 17
# [-0.7954636 -0.6060014 -5.228534 ]
# [-0.934665   -0.35552967 -5.7508683 ]
# [-0.99867576 -0.05144661 -6.240227  ]
# [-0.9664049  0.2570245 -6.228226 ]
# [-0.8404387  0.5419066 -6.2552414]
# [-0.65433764  0.7562025  -5.695718  ]
# [-0.4500351   0.89301085 -4.9300346 ]
# [-0.24442773  0.9696675  -4.3975034 ]
# [-0.05730817  0.9983565  -3.7917976 ]
# [ 0.09607097  0.9953745  -3.071179  ]
# [ 0.22181621  0.9750885  -2.5491467 ]
# [ 0.31738126  0.94829804 -1.9857999 ]
# [ 0.3636916  0.9315194 -0.9852229]
# [ 0.36802152  0.92981726 -0.09304965]
# [0.35217342 0.9359348  0.33976063]
# [0.30657846 0.9518454  0.96591985]
# [0.22362085 0.9746762  1.7213696 ]
# [0.09802638 0.9951838  2.5468752 ]
# [-0.08020389  0.9967785   3.5694838 ]
# [-0.2969843  0.9548824  4.424855 ]
# [-0.5220419  0.8529198  4.9542065]
# [-0.7336933   0.67948073  5.4899683 ]
# [-0.89975584  0.43639362  5.909362  ]
# [-0.98925537  0.1461977   6.0972605 ]
# [-0.9861962  -0.16558099  6.2614136 ]
# [-0.89599365 -0.44406682  5.8757076 ]
# [-0.7406311 -0.6719119  5.533094 ]
# [-0.5412134 -0.8408853  5.2425947]
# [-0.34850878 -0.9373055   4.317995  ]
# [-0.17342657 -0.98484683  3.6334352 ]
# [-0.0270115 -0.9996351  2.9458623]
# [ 0.07364065 -0.9972848   2.0144432 ]
# [ 0.14874184 -0.98887604  1.5117693 ]
# [ 0.19943681 -0.9799107   1.0297463 ]
# [ 0.22838208 -0.9735716   0.5926473 ]
# [ 0.2212549  -0.97521603 -0.1462889 ]
# [ 0.17010714 -0.9854256  -1.0432535 ]
# [ 0.08365075 -0.9964951  -1.7437955 ]
# [-0.05041458 -0.9987284  -2.6836917 ]
# [-0.21871772 -0.9757882  -3.4012845 ]
# [-0.4259246  -0.90475863 -4.3896675 ]
# [-0.6315837 -0.7753077 -4.8722115]
# [-0.8105766 -0.5856326 -5.2308383]
# [-0.93718916 -0.3488215  -5.386939  ]
# [-0.99611115 -0.08810534 -5.3618717 ]
# [-0.98434395  0.17625839 -5.308075  ]
# [-0.9094389  0.4158376 -5.0335917]
# [-0.79442185  0.60736644 -4.477554  ]
# [-0.6663446  0.745644  -3.7751892]
# [-0.53908664  0.8422503  -3.198865  ]
# [-0.4251439  0.9051258 -2.6046295]
# [-0.34010386  0.94038785 -1.84187   ]
# [-0.29944143  0.9541147  -0.85840404]
# [-0.28414118  0.95878243 -0.3199319 ]
# [-0.31405059  0.94940627  0.6269181 ]
# [-0.36361885  0.9315478   1.0538652 ]
# [-0.43707293  0.8994261   1.6038396 ]
# [-0.53301173  0.84610784  2.1962876 ]
# [-0.6564265  0.75439    3.0783184]
# [-0.7890401   0.61434174  3.8634574 ]
# [-0.90876454  0.4173092   4.6213818 ]
# [-0.9820043   0.18885857  4.8096538 ]
# [-0.9987963  -0.04905049  4.781397  ]
# [-0.9584908  -0.28512347  4.801301  ]
# [-0.8733123 -0.4871608  4.39401  ]
# [-0.76569587 -0.64320284  3.7967618 ]
# [-0.6465147 -0.7629015  3.3823078]
# [-0.5437739 -0.8392318  2.561594 ]
# [-0.4561764  -0.88988936  2.0246735 ]
# [-0.40365618 -0.91491073  1.1636834 ]
# [-0.3732007  -0.92775065  0.66105884]
# [-0.38478377 -0.9230067  -0.2503386 ]
# [-0.4186464  -0.9081493  -0.73961484]
# [-0.4927413  -0.87017584 -1.6656588 ]
# [-0.5865684 -0.8098997 -2.2315598]
# [-0.68809074 -0.7256246  -2.6407876 ]
# [-0.79961646 -0.600511   -3.3560336 ]
# [-0.89355    -0.44896376 -3.5706947 ]
# [-0.9604162 -0.2785691 -3.6660283]
# [-0.9952378  -0.09747655 -3.6934466 ]
# [-0.9963934   0.08485405 -3.6517558 ]
# [-0.9634277   0.26796842 -3.7265499 ]
# [-0.90519994  0.42498595 -3.353253  ]
# [-0.82803875  0.56067085 -3.1249878 ]
# [-0.74110156  0.6713929  -2.8178198 ]
# [-0.6527063  0.757611  -2.4711683]
# [-0.5843454  0.8115051 -1.7415606]
# [-0.5498898  0.8352372 -0.8368176]
# [-0.5287593  0.8487718 -0.5018821]
# [-0.5310705   0.84732765  0.05450545]
# [-0.56710345  0.82364655  0.8624281 ]
# [-0.62828404  0.777984    1.5272154 ]
# [-0.71398455  0.70016146  2.3165421 ]
# [-0.80599636  0.5919205   2.8436818 ]
# [-0.8912724  0.4534682  3.255734 ]
# [-0.9572127   0.28938526  3.5413651 ]
# [-0.9935681   0.11323616  3.6021    ]
# [-0.9974985  -0.07068739  3.684519  ]
# [-0.97138125 -0.2375257   3.3814294 ]
# [-0.9220481  -0.38707533  3.152794  ]
# In episode 18
# [-0.8610248 -0.508563   2.7211483]
# [-0.80045134 -0.5993977   2.1846695 ]
# [-0.7361945  -0.67677003  2.0123584 ]
# [-0.6782616  -0.73482054  1.6407138 ]
# [-0.64395666 -0.765062    0.91471016]
# [-0.6201067  -0.78451747  0.6156014 ]
# [-0.61448693 -0.78892696  0.14286375]
# [-0.6397071  -0.76861876 -0.64763254]
# [-0.67653036 -0.73641473 -0.97847426]
# [-0.72616714 -0.6875182  -1.3937932 ]
# [-0.78373176 -0.6210994  -1.758422  ]
# [-0.8476861 -0.5304981 -2.219134 ]
# [-0.90871817 -0.41741017 -2.571891  ]
# [-0.9607932 -0.2772661 -2.9929202]
# [-0.9910629  -0.13339567 -2.9430597 ]
# [-0.99982154  0.01889273 -3.0537667 ]
# [-0.98407763  0.17773904 -3.1958916 ]
# [-0.94914657  0.3148346  -2.8318791 ]
# [-0.89882725  0.43830302 -2.6685483 ]
# [-0.8419351  0.5395788 -2.3245385]
# [-0.79286075  0.60940284 -1.7074099 ]
# [-0.76000315  0.6499194  -1.0434222 ]
# [-0.74466705  0.66743606 -0.4656417 ]
# [-0.75257564  0.65850586  0.23857592]
# [-0.77830344  0.6278883   0.7998919 ]
# [-0.81041396  0.5858576   1.0579817 ]
# [-0.8573941  0.5146604  1.706528 ]
# [-0.9008818   0.43406448  1.8322395 ]
# [-0.93955696  0.34239268  1.9907453 ]
# [-0.9730643   0.23053396  2.3367186 ]
# [-0.9940159   0.10923581  2.4634433 ]
# [-0.99999416 -0.00341466  2.2573779 ]
# [-0.9932555 -0.1159461  2.255856 ]
# [-0.9730961  -0.23039964  2.3256178 ]
# [-0.9381115 -0.3463335  2.4234304]
# [-0.89992553 -0.43604362  1.9507549 ]
# [-0.86865544 -0.49541676  1.3423381 ]
# [-0.8424039 -0.5388466  1.015056 ]
# [-0.82491064 -0.5652632   0.6336988 ]
# [-0.8183301  -0.5747485   0.23089056]
# [-0.823281   -0.567634   -0.17335302]
# [-0.84398186 -0.5363717  -0.7499388 ]
# [-0.8677767  -0.49695435 -0.9209337 ]
# [-0.89934224 -0.43724546 -1.3510396 ]
# [-0.9332408  -0.35925147 -1.701357  ]
# [-0.9660426  -0.25838292 -2.1223555 ]
# [-0.9904777  -0.13767359 -2.464713  ]
# [-0.9998667  -0.01632554 -2.4357197 ]
# [-0.9931694   0.11668118 -2.665477  ]
# [-0.9733641  0.2292647 -2.2874925]
# [-0.9480444   0.31813806 -1.8488531 ]
# [-0.9211082  0.3893067 -1.5222788]
# [-0.8911805   0.45364892 -1.4195353 ]
# [-0.8602443   0.50988215 -1.2838448 ]
# [-0.83966786  0.54310024 -0.78154284]
# [-0.8303912   0.5571808  -0.33723906]
# [-0.8366861   0.54768276  0.22789411]
# [-0.85315174  0.52166283  0.61586756]
# [-0.8827294   0.46988165  1.1928424 ]
# [-0.91543823  0.40245855  1.4991157 ]
# [-0.9502784   0.31140167  1.9506645 ]
# [-0.9763015   0.21641488  1.9705373 ]
# [-0.9949735   0.10013894  2.3566754 ]
# [-0.99978244 -0.02085902  2.4233518 ]
# [-0.99056417 -0.1370497   2.3324373 ]
# [-0.9675855  -0.25254363  2.3565164 ]
# [-0.9303815  -0.36659288  2.400722  ]
# [-0.88933563 -0.45725498  1.9912363 ]
# [-0.8504903 -0.5259908  1.5794704]
# [-0.82244277 -0.5688479   1.0244933 ]
# [-0.8043752  -0.59412163  0.6213788 ]
# [-0.79596853 -0.60533804  0.2803442 ]
# [-0.8017296  -0.5976869  -0.19155273]
# [-0.82770556 -0.56116265 -0.8964601 ]
# [-0.8594416 -0.511234  -1.1833963]
# [-0.8948483  -0.44637042 -1.4782975 ]
# [-0.9325628  -0.36100766 -1.8671385 ]
# [-0.9666695  -0.25602743 -2.2087555 ]
# [-0.98999166 -0.14112575 -2.3462393 ]
# [-0.9999654  -0.00831281 -2.665711  ]
# [-0.9914843   0.13022655 -2.7782078 ]
# [-0.96461606  0.26365852 -2.7243097 ]
# [-0.9201821  0.3914906 -2.7087593]
# [-0.858885   0.5121685 -2.7091355]
# [-0.79436034  0.60744685 -2.3026965 ]
# [-0.7257855   0.68792105 -2.1155646 ]
# [-0.6628085   0.74878895 -1.7522458 ]
# [-0.62632126  0.77956504 -0.95476055]
# [-0.6210369   0.7837813  -0.13520552]
# [-0.63387525  0.7734353   0.3297689 ]
# [-0.6761452  0.7367684  1.1192906]
# [-0.72606164  0.6876296   1.4011827 ]
# [-0.79141986  0.61127293  2.0110247 ]
# [-0.8571611  0.5150483  2.3320792]
# [-0.92049235  0.39076063  2.7921252 ]
# [-0.9700648   0.24284616  3.1231802 ]
# [-0.99743134  0.07162893  3.472169  ]
# [-0.99368894 -0.11217087  3.6819553 ]
# [-0.9584418 -0.2852881  3.537991 ]
# [-0.89178187 -0.4524656   3.6044242 ]
# In episode 19
# [-0.8101457 -0.5862286  3.1373508]
# [-0.7256356 -0.6880792  2.6488583]
# [-0.64116496 -0.76740307  2.3188455 ]
# [-0.57678574 -0.8168955   1.6245388 ]
# [-0.52855104 -0.8489015   1.157913  ]
# [-0.4959468  -0.8683529   0.75935924]
# [-0.49496913 -0.86891055  0.02251083]
# [-0.53069216 -0.84756464 -0.8323538 ]
# [-0.579939  -0.8146599 -1.1847371]
# [-0.65300846 -0.7573506  -1.8579232 ]
# [-0.7429203 -0.6693799 -2.5174503]
# [-0.83856386 -0.5448033  -3.1443849 ]
# [-0.9192324  -0.39371523 -3.4296956 ]
# [-0.97421247 -0.22563271 -3.5415468 ]
# [-0.9988612  -0.04771091 -3.5972683 ]
# [-0.98935074  0.14555097 -3.8759775 ]
# [-0.9473318   0.32025382 -3.5985513 ]
# [-0.8797435   0.47544855 -3.3895283 ]
# [-0.80096984  0.5987047  -2.9281828 ]
# [-0.72552437  0.6881965  -2.3423464 ]
# [-0.6673427   0.74475074 -1.6232191 ]
# [-0.62637997  0.7795179  -1.0746899 ]
# [-0.6055337   0.79581964 -0.5292853 ]
# [-0.61598855  0.7877551   0.26407894]
# [-0.6601715  0.7511149  1.1481365]
# [-0.7159966  0.6981037  1.5400721]
# [-0.7771499  0.6293155  1.8414702]
# [-0.8473795   0.53098774  2.4181268 ]
# [-0.9100468   0.41450548  2.6473289 ]
# [-0.9586183   0.28469452  2.7742314 ]
# [-0.992056    0.12579699  3.251132  ]
# [-0.999546  -0.0301291  3.1252964]
# [-0.9830328  -0.18342975  3.0868123 ]
# [-0.94325656 -0.33206478  3.080349  ]
# [-0.8816894 -0.4718302  3.057474 ]
# [-0.8124201  -0.58307254  2.6228023 ]
# [-0.73393565 -0.67921895  2.4838483 ]
# [-0.6606956 -0.7506539  2.0470672]
# [-0.6086686  -0.79342455  1.3472705 ]
# [-0.5890066  -0.80812824  0.49104935]
# [-0.5975561  -0.8018271  -0.21241412]
# [-0.6216417 -0.7833017 -0.6077416]
# [-0.66085386 -0.7505146  -1.0223808 ]
# [-0.709162  -0.7050456 -1.3270615]
# [-0.7768952 -0.6296299 -2.0282128]
# [-0.8529593 -0.5219775 -2.6381817]
# [-0.91791534 -0.39677626 -2.8233106 ]
# [-0.97042143 -0.24141718 -3.2835233 ]
# [-0.9982852  -0.05853811 -3.7050877 ]
# [-0.99344164  0.11434041 -3.4632525 ]
# [-0.9641743   0.26526955 -3.077849  ]
# [-0.9201022  0.3916784 -2.6794312]
# [-0.86488014  0.50197846 -2.4685957 ]
# [-0.7996891  0.6004143 -2.3626842]
# [-0.7358889   0.67710227 -1.9959742 ]
# [-0.6840914  0.7293963 -1.4724262]
# [-0.659216    0.75195366 -0.6716324 ]
# [-0.6473932   0.7621562  -0.31232977]
# [-0.65836126  0.7527021   0.2896081 ]
# [-0.6878472  0.7258555  0.797588 ]
# [-0.7323061   0.68097556  1.2636672 ]
# [-0.7965173   0.60461575  1.9962133 ]
# [-0.8588276  0.5122648  2.2292714]
# [-0.92202526  0.38712972  2.8060644 ]
# [-0.9692805   0.24595812  2.98017   ]
# [-0.9957625   0.09196163  3.1283262 ]
# [-0.9970736  -0.07644781  3.3722844 ]
# [-0.97291434 -0.23116598  3.1350696 ]
# [-0.92271864 -0.38547412  3.2489128 ]
# [-0.86001325 -0.51027167  2.7955813 ]
# [-0.7935144 -0.6085515  2.3746648]
# [-0.7308284 -0.6825613  1.9405522]
# [-0.6781666  -0.73490816  1.4853951 ]
# [-0.6328578  -0.77426803  1.2005278 ]
# [-0.61357397 -0.7896372   0.49319747]
# [-0.61607647 -0.78768635 -0.06346144]
# [-0.6362434  -0.77148837 -0.5173465 ]
# [-0.67116815 -0.7413051  -0.9232861 ]
# [-0.7195417 -0.6944492 -1.347174 ]
# [-0.7856015 -0.6187328 -2.0105095]
# [-0.85365105 -0.5208453  -2.3857553 ]
# [-0.91596    -0.40126958 -2.698768  ]
# [-0.96565115 -0.2598419  -3.0008807 ]
# [-0.9953727  -0.09608942 -3.332411  ]
# [-0.9964931   0.08367492 -3.6002154 ]
# [-0.96875215  0.24803083 -3.3374834 ]
# [-0.9186617  0.3950452 -3.1094   ]
# [-0.8592616  0.5115365 -2.617099 ]
# [-0.79922    0.6010386 -2.1565597]
# [-0.75064844  0.6607018  -1.5390673 ]
# [-0.71902317  0.6949861  -0.9329454 ]
# [-0.7110398  0.7031518 -0.2283983]
# [-0.71395016  0.70019656  0.08295518]
# [-0.7347164   0.67837435  0.60249996]
# [-0.7748193  0.6321828  1.2236128]
# [-0.8181576  0.574994   1.4354056]
# [-0.8751961  0.4837683  2.1528308]
# [-0.92460793  0.38092017  2.2832797 ]
# [-0.9679957  0.2509668  2.7422483]
# [-0.9952767   0.09707914  3.1289322 ]

# %%
# %pip install gymnasium
# %pip install swig
# %pip install gymnasium[box2d]
# %pip install gymnasium[mujoco]

# Create Hopper environment
# https://gymnasium.farama.org/environments/mujoco/hopper/


import gymnasium as gym
env = gym.make("Hopper-v4", render_mode = "rgb_array")
s = env.reset(seed = 34)
print("Observation Space = ")
print(env.observation_space)
print("Action Space = ")
print(env.action_space)
done = False
for episode in range(1):
    print("In episode {}".format(episode))
    for i in range(100):

        print(s)
        a = env.action_space.sample()
        s, r, done, truncated, _ = env.step(a)
        if done:
            print("Finished after {} timestep".format(i+1))
env.close()
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: swig in /usr/local/lib/python3.12/dist-packages (4.4.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d==2.3.10 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.1)
# Requirement already satisfied: gymnasium[mujoco] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (0.0.4)
# Requirement already satisfied: mujoco>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (3.6.0)
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (2.37.3)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (26.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio>=2.14.1->gymnasium[mujoco]) (11.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.14.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (2.10.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (2025.3.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.23.0)
# Observation Space =
# Box(-inf, inf, (11,), float64)
# Action Space =
# Box(-1.0, 1.0, (3,), float32)
# In episode 0
# (array([ 1.25372177e+00, -2.57257612e-03,  1.51061298e-03, -1.59076170e-04,
#         2.88533494e-03,  3.80722565e-03,  3.99721996e-03,  2.09928936e-04,
#         4.64165624e-03,  4.11351193e-03,  1.77765794e-03]), {})
# [ 1.25349518e+00 -6.16210826e-03 -2.90035925e-03  4.23144035e-04
#   6.15524434e-04 -6.24008690e-02 -6.02284562e-02 -9.24526947e-01
#  -1.09953473e+00  6.90532038e-02 -5.64604193e-01]
# [ 1.25262847e+00 -1.19843320e-02 -9.88677487e-03  8.43619143e-04
#  -8.32759353e-04 -2.43043478e-02 -1.56247587e-01 -5.31136646e-01
#  -6.47674176e-01  3.69290457e-02  2.01600091e-01]
# [ 1.25115748e+00 -2.07487702e-02 -2.01606214e-02  1.01293437e-03
#  -3.40953400e-03 -1.18542943e-01 -2.12371559e-01 -1.65753178e+00
#  -1.91955699e+00  8.53066968e-03 -8.44831468e-01]
# [ 1.24921813e+00 -3.57328975e-02 -3.74035444e-02  1.13146569e-03
#  -1.45177225e-02 -1.66599790e-01 -2.73002668e-01 -2.08902126e+00
#  -2.39043114e+00  1.92812835e-02 -1.93091703e+00]
# [ 1.24669973e+00 -4.87667029e-02 -5.22393879e-02  1.34750076e-03
#  -2.93909278e-02 -1.04335866e-01 -3.55593102e-01 -1.17137794e+00
#  -1.31962733e+00  3.22922608e-02 -1.78730877e+00]
# [ 1.24364329e+00 -5.69012280e-02 -6.04246617e-02  2.77407828e-04
#  -4.79531697e-02 -1.26580448e-01 -4.08386016e-01 -8.63085396e-01
#  -7.27404163e-01 -2.99293836e-01 -2.85205613e+00]
# [ 1.23998294 -0.06238155 -0.06235158 -0.00656675 -0.06478044 -0.14452448
#  -0.50699286 -0.50708728  0.24433276 -1.41043731 -1.35659914]
# [ 1.23548674 -0.06922857 -0.06605965 -0.01377713 -0.07249991 -0.10953446
#  -0.61691916 -1.20349474 -1.16953464 -0.3934163  -0.57405571]
# [ 1.23051821 -0.07916305 -0.07644063 -0.01540466 -0.07529935 -0.13908115
#  -0.59469473 -1.26905128 -1.41938844  0.02409112 -0.02733437]
# [ 1.22588389 -0.08656976 -0.085182   -0.01423115 -0.07194982 -0.11367701
#  -0.56952708 -0.58240458 -0.76898018  0.25886893  0.84207545]
# [ 1.22118589 -0.08932738 -0.08745036 -0.01567474 -0.05897029 -0.13064796
#  -0.61203711 -0.11051358  0.19941206 -0.62708815  2.37807184]
# [ 1.21631612 -0.08866726 -0.08191584 -0.02422397 -0.03804942 -0.19803318
#  -0.60749044  0.27354075  1.18295903 -1.51039106  2.84712774]
# [ 1.21120449 -0.08965171 -0.07480606 -0.03872412 -0.01146115 -0.29316625
#  -0.67465251 -0.52157562  0.59490136 -2.11746968  3.78719231]
# [ 1.20593688 -0.08871261 -0.06629365 -0.05198358  0.01704975 -0.13207068
#  -0.57600997  0.72775455  1.51680594 -1.26898453  3.18100257]
# [ 1.20219638 -0.08476484 -0.05774486 -0.05947404  0.037396   -0.10378295
#  -0.3656768   0.26263465  0.62366536 -0.59575095  1.92787565]
# [ 1.19985503 -0.08856721 -0.05719304 -0.06785323  0.05130743 -0.26336215
#  -0.22763059 -1.20905401 -0.48223395 -1.48817595  1.5734069 ]
# [ 1.1984989  -0.10069356 -0.06390492 -0.07935176  0.06171608 -0.30286673
#  -0.11793147 -1.81868008 -1.19389059 -1.38110347  1.04447837]
# [ 1.19798194 -0.11575893 -0.07442721 -0.08892168  0.06594099 -0.34838879
#  -0.0164525  -1.94174901 -1.4345396  -1.00078752  0.04280199]
# [ 1.19817674 -0.13024281 -0.0818131  -0.10071236  0.06376196 -0.49427372
#   0.06772113 -1.67822232 -0.41254956 -1.94053509 -0.5705682 ]
# [ 1.19904073 -0.14226984 -0.08365183 -0.11503568  0.05672159 -0.54371372
#   0.15013187 -1.32772484 -0.04787987 -1.64082977 -1.18482488]
# [ 1.20001237 -0.15720207 -0.08971741 -0.1271254   0.0507996  -0.60634124
#   0.0872269  -2.40536583 -1.46783707 -1.38858909 -0.31514299]
# [ 1.2006641  -0.17554338 -0.09739602 -0.1430599   0.04959218 -0.71399915
#   0.07407819 -2.18149339 -0.45307112 -2.59376339  0.01132031]
# [ 1.20081355 -0.1951771  -0.10359625 -0.16415219  0.05384637 -0.73289173
#  -0.0384891  -2.7288974  -1.09761819 -2.68738743  1.02929546]
# Finished after 24 timestep
# [ 1.2002284  -0.21884    -0.11596618 -0.18388254  0.06654192 -0.68365702
#  -0.10107962 -3.18938798 -1.99550247 -2.25340265  2.13033505]
# Finished after 25 timestep
# [ 1.19946525 -0.2399739  -0.12760505 -0.20002638  0.07831323 -0.63140108
#  -0.08163555 -2.09457558 -0.91492859 -1.77727266  0.83550678]
# Finished after 26 timestep
# [ 1.19860127 -0.25602693 -0.1308727  -0.21936581  0.08435206 -0.74016933
#  -0.1324237  -1.9202059   0.09764219 -3.05139384  0.68666755]
# Finished after 27 timestep
# [ 1.19757163 -0.26645091 -0.1261413  -0.24067756  0.08869754 -0.63105336
#  -0.12257266 -0.68578169  1.08351356 -2.27859027  0.40147929]
# Finished after 28 timestep
# [ 1.19667423 -0.2712654  -0.11916219 -0.25436818  0.08940887 -0.58881428
#  -0.09849827 -0.51741599  0.661859   -1.14449727 -0.21589403]
# Finished after 29 timestep
# [ 1.19542787 -0.28016373 -0.11913594 -0.26414559  0.09019652 -0.67004392
#  -0.21552089 -1.70759943 -0.65336149 -1.29991718  0.40709627]
# Finished after 30 timestep
# [ 1.19357388 -0.29234296 -0.12502933 -0.27061065  0.09433013 -0.58234682
#  -0.24762787 -1.33735828 -0.81987396 -0.31815812  0.62466602]
# Finished after 31 timestep
# [ 1.19195609 -0.30279888 -0.13433663 -0.26794851  0.0956684  -0.51366184
#  -0.15268241 -1.27888494 -1.50611052  0.98228964 -0.2853955 ]
# Finished after 32 timestep
# [ 1.19047903 -0.31768306 -0.14956802 -0.26353384  0.09372207 -0.6644257
#  -0.21940518 -2.44119846 -2.29917106  0.12926032 -0.18901891]
# Finished after 33 timestep
# [ 1.18867828 -0.33668399 -0.16445634 -0.26670701  0.09125047 -0.78801187
#  -0.22854499 -2.3093478  -1.42366671 -0.91767088 -0.41677831]
# Finished after 34 timestep
# [ 1.1867497  -0.35764314 -0.17985411 -0.27215372  0.08909563 -0.79576666
#  -0.25456651 -2.93137669 -2.42548401 -0.4499155  -0.13551812]
# Finished after 35 timestep
# [ 1.18425314 -0.38731388 -0.20447306 -0.27850225  0.08848506 -0.97523575
#  -0.3719923  -4.48569249 -3.72716112 -1.13455065 -0.01260739]
# Finished after 36 timestep
# [ 1.18079133 -0.4277489  -0.23739408 -0.29065396  0.08933939 -1.12581389
#  -0.49697103 -5.62260527 -4.50189937 -1.90218996  0.226108  ]
# Finished after 37 timestep
# [ 1.17667344 -0.47609154 -0.27785161 -0.30384894  0.08863279 -1.20951648
#  -0.53250678 -6.46243461 -5.61162825 -1.39726122 -0.39566467]
# Finished after 38 timestep
# [ 1.1721134  -0.52798227 -0.3202247  -0.31907438  0.08610764 -1.3149237
#  -0.60913584 -6.51133927 -4.9825245  -2.40819421 -0.23764753]
# Finished after 39 timestep
# [ 1.16751769 -0.57664438 -0.35737791 -0.33552915  0.08223569 -1.28023433
#  -0.53614549 -5.65461671 -4.3080926  -1.70876063 -0.72975319]
# Finished after 40 timestep
# [ 1.16295131 -0.61852732 -0.38761056 -0.35041998  0.08139651 -1.21993381
#  -0.60621766 -4.81958799 -3.25039668 -2.01217452  0.51272331]
# Finished after 41 timestep
# [ 1.15734932 -0.66152359 -0.41878015 -0.3664697   0.08639754 -1.25346653
#  -0.79794478 -5.93031932 -4.53918369 -1.99920929  0.73497114]
# Finished after 42 timestep
# [ 1.15021668 -0.70925684 -0.45286081 -0.38717368  0.09528847 -1.28933862
#  -0.98660503 -6.00259561 -3.981119   -3.17430002  1.48675857]
# Finished after 43 timestep
# [ 1.14178921 -0.75719491 -0.48417644 -0.41327162  0.10793524 -1.2722979
#  -1.12028322 -5.98155772 -3.84786968 -3.35000466  1.67427704]
# Finished after 44 timestep
# [ 1.1325986  -0.80303901 -0.51377012 -0.4380354   0.12336879 -1.19661325
#  -1.17518329 -5.48016511 -3.55131347 -2.84193843  2.18401759]
# Finished after 45 timestep
# [ 1.1217722  -0.85331852 -0.54714899 -0.46547724  0.14376816 -1.25787325
#  -1.53681083 -7.08753464 -4.79007909 -4.01542243  2.91361858]
# Finished after 46 timestep
# [ 1.10905066 -0.91118155 -0.58848824 -0.49404657  0.16440638 -1.19633958
#  -1.64268672 -7.37947181 -5.54386825 -3.12880875  2.24705936]
# Finished after 47 timestep
# [ 1.09563406 -0.96687847 -0.62794747 -0.52085612  0.18382084 -1.16298746
#  -1.70965358 -6.54478287 -4.32285729 -3.57279885  2.60632337]
# Finished after 48 timestep
# [ 1.08116011 -1.02136816 -0.66365684 -0.551317    0.20075415 -1.17926266
#  -1.91051334 -7.07730463 -4.60345629 -4.04134594  1.62770734]
# Finished after 49 timestep
# [ 1.06583354 -1.07439442 -0.69597726 -0.5838462   0.21097542 -1.15681389
#  -1.91926747 -6.17983503 -3.47870109 -4.0911904   0.92880447]
# Finished after 50 timestep
# [ 1.05075452 -1.12285811 -0.72486645 -0.61231798  0.21629853 -1.07991085
#  -1.81925935 -5.96642026 -3.7585598  -3.05914117  0.42691824]
# Finished after 51 timestep
# [ 1.03630144 -1.1713763  -0.75415471 -0.63767259  0.21652943 -1.208997
#  -1.79415244 -6.16322063 -3.56422872 -3.2769766  -0.35486031]
# Finished after 52 timestep
# [ 1.02162251 -1.2232784  -0.78469686 -0.66422551  0.21386482 -1.2660309
#  -1.87887304 -6.8100916  -4.06969736 -3.36171208 -0.31797547]
# Finished after 53 timestep
# [ 1.00630425 -1.28098103 -0.82182731 -0.6887213   0.21189411 -1.24480058
#  -1.95336625 -7.61336059 -5.21049614 -2.76531141 -0.18640017]
# Finished after 54 timestep
# [ 0.99013268 -1.34448781 -0.86664407 -0.71039793  0.21311486 -1.17301422
#  -2.09250603 -8.26334305 -5.9910326  -2.6595637   0.46439372]
# Finished after 55 timestep
# [ 0.97316211 -1.41032495 -0.91378109 -0.73225912  0.21790748 -1.13097276
#  -2.1512066  -8.19672921 -5.79262535 -2.80762964  0.72069264]
# Finished after 56 timestep
# [ 0.95527232 -1.47829975 -0.96228835 -0.75522693  0.22473516 -1.04548295
#  -2.32231473 -8.79692101 -6.33226076 -2.93641019  0.97504141]
# Finished after 57 timestep
# [ 0.93756398 -1.54572322 -1.01150418 -0.77475107  0.2290657  -1.03106275
#  -2.10018321 -8.06445798 -5.97494737 -1.94864389  0.11836727]
# Finished after 58 timestep
# [ 0.92115673 -1.60689193 -1.05538714 -0.79140991  0.23444215 -0.97346757
#  -1.99704806 -7.23483568 -4.99952593 -2.22550205  1.21376553]
# Finished after 59 timestep
# [ 0.90570711 -1.66181387 -1.09209332 -0.80999658  0.24816778 -0.91734604
#  -1.86168822 -6.50124701 -4.18000097 -2.42943999  2.20739777]
# Finished after 60 timestep
# [ 0.89100045 -1.7126967  -1.12354065 -0.83130519  0.26972157 -0.8553371
#  -1.81354252 -6.22215042 -3.68289476 -2.90096628  3.1753992 ]
# Finished after 61 timestep
# [ 0.87563295 -1.76465727 -1.15247981 -0.85898806  0.29546695 -0.81023263
#  -2.03305614 -6.7623323  -3.5487383  -4.00700403  3.27036421]
# Finished after 62 timestep
# [ 0.85973239 -1.81895593 -1.18222936 -0.88919997  0.32287118 -0.70752585
#  -1.93909257 -6.81425565 -3.88928289 -3.55300494  3.57606107]
# Finished after 63 timestep
# [ 0.84455532 -1.87383177 -1.21476544 -0.91512615  0.34731736 -0.64834258
#  -1.8556269  -6.9024972  -4.24358561 -2.92643228  2.54161035]
# Finished after 64 timestep
# [ 0.82996275 -1.92890081 -1.2490752  -0.9369968   0.36434057 -0.60723201
#  -1.79322197 -6.86282267 -4.33303176 -2.53859984  1.71928721]
# Finished after 65 timestep
# [ 0.81498571 -1.98887988 -1.28923044 -0.9562056   0.37557713 -0.45666295
#  -1.95125532 -8.13056014 -5.70241875 -2.25969475  1.09645448]
# Finished after 66 timestep
# [ 0.8004554  -2.05122941 -1.33415209 -0.97120847  0.38669735 -0.39950339
#  -1.67622454 -7.46166913 -5.53018951 -1.50484507  1.67101364]
# Finished after 67 timestep
# [ 0.78820323 -2.10732095 -1.37608715 -0.98145693  0.40212787 -0.38589043
#  -1.3839887  -6.56413613 -4.9553279  -1.06578501  2.17778342]
# Finished after 68 timestep
# [ 0.77620753 -2.16490021 -1.41885595 -0.99373986  0.42311354 -0.20114919
#  -1.61539574 -7.8310216  -5.73401998 -1.99861471  3.07311783]
# Finished after 69 timestep
# [ 0.76248836 -2.23141838 -1.46661134 -1.01248317  0.44698837 -0.07093953
#  -1.81628329 -8.79584943 -6.20231392 -2.67718457  2.90551685]
# Finished after 70 timestep
# [ 0.74940145 -2.29616319 -1.51214809 -1.0317947   0.47311042 -0.11564358
#  -1.45218637 -7.39119101 -5.18445709 -2.16298944  3.61245557]
# Finished after 71 timestep
# [ 0.73892138 -2.352828   -1.55287299 -1.0460828   0.50004693 -0.12604204
#  -1.16719748 -6.77341055 -4.9967876  -1.41187384  3.12089357]
# Finished after 72 timestep
# [ 0.7300385  -2.40413821 -1.5892575  -1.05845395  0.52441241 -0.17912372
#  -1.05632389 -6.05095191 -4.09967778 -1.67502292  2.97510197]
# Finished after 73 timestep
# [ 0.72235374 -2.45025739 -1.6206016  -1.07063875  0.54805772 -0.19973915
#  -0.8649566  -5.4769202  -3.73654714 -1.37212172  2.93576845]
# Finished after 74 timestep
# [ 0.71633772 -2.49498379 -1.65377124 -1.07837382  0.57288728 -0.09312904
#  -0.63553169 -5.70517515 -4.55466117 -0.56925126  3.26600486]
# Finished after 75 timestep
# [ 0.71078587 -2.53938141 -1.68592817 -1.0878737   0.59974584 -0.1268003
#  -0.75798917 -5.39030868 -3.4848778  -1.79107704  3.45987197]
# Finished after 76 timestep
# [ 0.70486326 -2.58443945 -1.71615855 -1.1011113   0.62579456 -0.0461339
#  -0.72260751 -5.87176597 -4.07157321 -1.5161325   3.05652059]
# Finished after 77 timestep
# [ 0.70028564 -2.62672977 -1.74617754 -1.1104871   0.65103636 -0.14103184
#  -0.42047732 -4.69906023 -3.43391065 -0.83484863  3.24729147]
# Finished after 78 timestep
# [ 0.69660971 -2.66431439 -1.77204405 -1.11916625  0.67464647 -0.1580725
#  -0.50307367 -4.69403851 -3.03256013 -1.32280061  2.66655608]
# Finished after 79 timestep
# [ 0.69265771 -2.70036068 -1.79453917 -1.1294263   0.69256543 -0.22745746
#  -0.48787856 -4.31423926 -2.59147724 -1.23601384  1.81984889]
# Finished after 80 timestep
# [ 0.68955689 -2.733911   -1.81670322 -1.13617499  0.70867573 -0.20561006
#  -0.28350803 -4.07365101 -2.94911842 -0.46141694  2.19903388]
# Finished after 81 timestep
# [ 0.68778187 -2.77015575 -1.84590594 -1.13715644  0.72732404 -0.0343169
#  -0.15636171 -4.98929393 -4.34933487  0.20953363  2.45862284]
# Finished after 82 timestep
# [ 0.68723966 -2.81045712 -1.88282622 -1.13307762  0.74687161  0.01259766
#   0.02233885 -5.08618037 -4.8792708   0.80722278  2.42609659]
# Finished after 83 timestep
# [ 0.68669244 -2.85041501 -1.91800605 -1.1311224   0.76512634 -0.0387466
#  -0.16369439 -4.90074136 -3.91731757 -0.30689286  2.1475116 ]
# Finished after 84 timestep
# [ 0.68440269 -2.89546692 -1.95245222 -1.1381189   0.7870247   0.19162978
#  -0.40720818 -6.37690275 -4.69525378 -1.43537126  3.16894113]
# Finished after 85 timestep
# [ 0.6806839  -2.9456511  -1.98665201 -1.1519552   0.80383976  0.08488482
#  -0.52461283 -6.15166146 -3.85376932 -2.02410267  1.23567153]
# Finished after 86 timestep
# [ 0.67562003 -2.99623513 -2.01542623 -1.17240646  0.80927436  0.08853685
#  -0.74182547 -6.48336762 -3.339304   -3.08839683  0.23737825]
# Finished after 87 timestep
# [ 0.66981369 -3.04437658 -2.03906958 -1.19541827  0.80909302 -0.05322792
#  -0.71175789 -5.53947674 -2.57224367 -2.66599581 -0.22133174]
# Finished after 88 timestep
# [ 0.66408388 -3.08694827 -2.0584247  -1.21556218  0.80662181 -0.11419457
#  -0.72162039 -5.0997252  -2.26669424 -2.37038708 -0.36874814]
# Finished after 89 timestep
# [ 0.65815861 -3.12866595 -2.07770662 -1.23377536  0.80328472 -0.08049308
#  -0.7590577  -5.32955461 -2.55337813 -2.18365102 -0.4585943 ]
# Finished after 90 timestep
# [ 0.65192955 -3.17332958 -2.10032036 -1.25058362  0.79989903 -0.00597385
#  -0.7967732  -5.83700413 -3.09940465 -2.01956937 -0.38622874]
# Finished after 91 timestep
# [ 0.64501061 -3.22373265 -2.12729886 -1.26892596  0.79710968  0.13232762
#  -0.93055751 -6.76626742 -3.64459074 -2.56653029 -0.3117679 ]
# Finished after 92 timestep
# [ 0.63703573 -3.27931504 -2.15608713 -1.29193822  0.79146966  0.167903
#  -1.062621   -7.13085472 -3.5524666  -3.18566549 -1.09754018]
# Finished after 93 timestep
# [ 0.62913085 -3.33733681 -2.18805317 -1.31254293  0.78439586  0.18671034
#  -0.91189153 -7.37323913 -4.43795502 -1.96885465 -0.6708564 ]
# Finished after 94 timestep
# [ 0.62134854 -3.398261   -2.22371961 -1.33082876  0.77837829  0.24819109
#  -1.03246133 -7.85978797 -4.47869257 -2.60233191 -0.8334714 ]
# Finished after 95 timestep
# [ 0.61274659 -3.45906368 -2.25693258 -1.35256089  0.77318582  0.18550363
#  -1.12007352 -7.33966808 -3.82541353 -2.82889795 -0.46524985]
# Finished after 96 timestep
# [ 0.60387077 -3.51531975 -2.28599839 -1.37313714  0.76578731  0.05687029
#  -1.10084375 -6.72218056 -3.44132621 -2.31485396 -1.38325416]
# Finished after 97 timestep
# [ 0.59459942 -3.57569312 -2.31719373 -1.39531641  0.75077205  0.24613222
#  -1.2122642  -8.37626903 -4.35628354 -3.23138549 -2.36946607]
# Finished after 98 timestep
# [ 0.58410311 -3.63908403 -2.34702975 -1.42398538  0.73627055  0.18096426
#  -1.41548308 -7.47036355 -3.10453785 -3.93172135 -1.25773851]
# Finished after 99 timestep
# [ 0.57268037 -3.69935811 -2.37220877 -1.45511624  0.72482277  0.17401349
#  -1.43996846 -7.59824307 -3.19002503 -3.85137633 -1.60375625]
# Finished after 100 timestep
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment Hopper-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(

# %%
# !pip install gymnasium
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install gymnasium[mujoco]

# Create Half-Cheetah environment
# https://gymnasium.farama.org/environments/mujoco/hopper/


import gymnasium as gym
env = gym.make("HalfCheetah-v4", render_mode = "rgb_array")
s = env.reset(seed = 34)
print("Observation Space = ")
print(env.observation_space)
print("Action Space = ")
print(env.action_space)
done = False
for episode in range(1):
    print("In episode {}".format(episode))
    for i in range(100):
        print(s)
        a = env.action_space.sample()
        s, r, done, truncated, _ = env.step(a)
        if done:
            print("Finished after {} timestep".format(i+1))
env.close()
# Out:
# Observation Space =
# Box(-inf, inf, (17,), float64)
# Action Space =
# Box(-1.0, 1.0, (6,), float32)
# In episode 0
# (array([ 0.07443538, -0.05145152,  0.03021226, -0.00318152,  0.0577067 ,
#         0.07614451,  0.0799444 ,  0.00419858, -0.06093145,  0.06146804,
#         0.04904031, -0.01182644, -0.07192433, -0.08793664, -0.10080283,
#         0.02766291, -0.03509065]), {})
# [ 0.0637717  -0.04411648 -0.0306666  -0.0976586  -0.04591319  0.20679539
#   0.19557165  0.13062492  0.09018974 -0.4464108   0.20357914 -2.03847252
#  -2.57348873 -2.53518357  3.97487028  3.51762668  3.7207169 ]
# [ 0.03315586 -0.01573648  0.13807129 -0.53624415  0.08021053  0.4629033
#   0.41206715 -0.1053689   0.59418345 -0.90404937  0.45781857  4.63273722
#  -8.50776116  4.30579034  5.289863    4.25077962 -8.27873801]
# [-0.01116328  0.01438904 -0.1053495  -0.26620909  0.18728931  0.29363131
#   0.51462347  0.04663516 -0.78054498 -0.92256251  0.67875594 -7.47121942
#   8.35012585  2.16205974 -7.38596074 -0.27288548  8.58485941]
# [-0.02406933  0.05203731 -0.24180237 -0.2938181   0.40728026 -0.03327741
#   0.39078861  0.32824696 -0.71481872  0.59595756 -0.33650719  0.86115524
#  -4.01775021  4.12566107 -1.58439336 -3.16388337  5.5247297 ]
# [-2.62218767e-02 -2.58574683e-02 -7.75357301e-02  4.48123387e-04
#   3.53207098e-01 -1.06076070e-02  1.48907028e-01  1.91701265e-01
#  -5.03296726e-02 -3.90729412e-01 -2.14448175e+00  5.56342288e+00
#   9.36035269e+00 -2.61004857e+00  7.23005357e-01 -4.54618771e+00
#  -6.90685213e+00]
# [-0.05322596 -0.0900014   0.12381104  0.27150011 -0.07119988 -0.34307488
#   0.23087805 -0.11302125 -1.04560432 -0.67038692 -0.42562457  1.83990279
#   2.27892641 -8.76015185 -9.59194216  3.32385249 -4.75609263]
# [-0.11109662 -0.08157198 -0.17242361  0.4387216  -0.22257424 -0.78910505
#   0.40761082 -0.38101586 -1.33960582 -1.40427106  0.25579075 -8.36799341
#   2.25021203  0.0910481  -6.39006444  2.00548047 -4.83406686]
# [-0.15873581 -0.11673237 -0.20577424  0.5657174  -0.26709971 -0.45861329
#   0.14809772 -0.31036232  0.60418646 -0.45180525 -0.45186441  2.31251385
#   3.25980132 -3.55572325 11.62138323 -6.11025101  4.60465071]
# [ -0.14892451  -0.02282135   0.15710293   0.16298877  -0.46556629
#   -0.05042038  -0.10900898   0.07838935   0.83823433   0.57071485
#    2.51077916   6.19574182 -10.71497459   0.71596476   4.08372849
#   -7.52671434   4.83697404]
# [-0.11478717  0.12055656  0.34415884 -0.33823005  0.09677372  0.1238409
#  -0.3332602  -0.04544393  0.85545722  0.53135233  2.51764245  2.05448632
#  -7.39901169 15.56641115  2.69426659 -1.8004983  -6.0537856 ]
# [-0.10454111  0.20075078  0.26650495 -0.21615144  0.39754453  0.01041617
#  -0.46662352  0.02343084 -0.16208219  0.06876863  1.15641748 -2.38731548
#   6.05608436 -0.23031255 -4.65634273 -2.88759789  5.10396011]
# [-0.10589541  0.29282901  0.05901255 -0.05991008  0.11442932 -0.23727741
#  -0.53021287 -0.08259529 -0.29233606 -0.11410791  2.19122042 -4.37061242
#   0.25138441 -6.77935912 -4.16588743 -0.30935433 -5.76383982]
# [ -0.12260572   0.27545526   0.02928484   0.26147905  -0.08984624
#   -0.2913274   -0.26270505  -0.57635854   0.0841218   -0.38089902
#   -1.62492997   2.42001798   7.78075747  -1.35381608   0.70835517
#    6.63002636 -10.65428568]
# [-0.1244593   0.2135544   0.01739704  0.1777477   0.14760416 -0.02529497
#  -0.39842141 -0.32489483  0.20063917  0.09106477 -1.07647082 -2.03259261
#  -5.91259888  6.0519919   7.12389892 -4.62000502  8.23279621]
# [-0.12099034  0.11946195  0.19290542 -0.27665658  0.29206963  0.26890481
#  -0.28797014 -0.2528601   0.50151295 -0.07965876 -2.58075586  4.85628142
#  -7.62497599  0.64115386  4.37767251  6.07504366 -1.83889699]
# [-0.0909259   0.09709457  0.29418138 -0.34152238  0.39341079  0.41173292
#  -0.04482209 -0.07107199  0.72443631  0.48388252 -0.16379056  0.75634075
#  -2.49596537  4.60073045  2.16670994  4.61968872  7.06442728]
# [-0.08004501  0.0485697   0.34860942 -0.2196179   0.20700232  0.2280925
#   0.51746072  0.34662175  0.42145493 -0.02766028 -1.08183114  1.26332294
#   3.98601803 -6.34296404 -5.23455261 11.44277696  7.84272555]
# [-0.10934743 -0.02329143  0.28943905  0.36908766 -0.03326603  0.22534621
#   0.51304637  0.40316895  0.13499086 -0.64833595 -1.49123143 -0.68389696
#  11.78569081 -2.40034077  3.64900679 -4.20001372 -0.71211142]
# [-1.24874231e-01  1.30853099e-03  1.42810103e-01  3.18603194e-01
#  -1.18613235e-01  4.19293709e-01  2.58620359e-01  1.63448286e-01
#   8.13583576e-02 -1.60050229e-01  1.37796263e+00 -3.93893225e+00
#  -7.33708110e+00 -1.26050365e+00  3.25945798e+00 -3.90498103e+00
#  -6.29160600e+00]
# [-1.23612704e-01  4.11575190e-02 -1.24261072e-01  1.41010342e-01
#   2.30421841e-01  4.79774466e-01  5.94951092e-02 -3.91815396e-03
#  -4.61865797e-01  2.76129788e-01  6.23964377e-01 -4.90966710e+00
#   1.21227210e+00  8.03625390e+00 -4.11788952e-01 -3.19556569e+00
#  -1.51481662e+00]
# [-8.71488419e-02  3.33832251e-02 -2.60276848e-01  2.49275298e-01
#   1.83070156e-01  2.67022781e-01  5.69788966e-02  6.41959955e-03
#  -9.40969053e-01  9.43370498e-01 -3.63289346e-01 -1.14381874e+00
#   1.90707742e+00 -4.89540208e+00 -6.64306473e+00  8.18777716e-01
#   6.03541940e-01]
# [ -0.05566872   0.01838094  -0.30146927   0.31965127  -0.40874763
#   -0.07119551   0.15455419   0.27897071  -0.93524321   0.38613907
#   -0.22130337  -0.78287899   0.54589113 -11.70052714  -5.65610118
#    1.5537294    7.07073667]
# [-0.0489141  -0.01381199 -0.08817208  0.31011174 -0.39133201 -0.0301168
#   0.21908328  0.5041272   0.29593548 -0.10705326 -1.00502815  6.41548674
#   0.06790285  3.56138985  4.2962411   1.26589556  2.48308399]
# [ -0.07004691  -0.04483197   0.17003953   0.31150844   0.32255431
#   -0.09524913   0.16127143   0.12058377  -0.58144166  -0.70623243
#   -0.40394605   3.95541267   0.33806011  15.3910621   -4.80465132
#   -2.72412565 -12.17591687]
# [-1.07282900e-01 -1.24892148e-02  4.69475042e-01 -3.24158698e-02
#   8.50850228e-02 -5.05817525e-01  2.46043954e-01 -4.17914993e-01
#  -6.59031701e-01 -9.50975704e-01  1.02285502e+00  5.06041539e+00
#  -8.39610931e+00 -1.27231364e+01 -8.66578044e+00  2.50634063e+00
#  -8.21771365e+00]
# [-1.62264648e-01  9.32038885e-02  2.25491837e-01 -4.32518384e-02
#  -9.01935073e-03 -6.29607950e-01 -1.87713959e-01 -2.05652988e-01
#  -8.51718982e-01 -1.04997805e+00  2.57961701e+00 -8.15948041e+00
#   3.79523371e+00  3.54023701e+00  1.07571215e+00 -1.17845687e+01
#   9.98144627e+00]
# [-0.20098338  0.19884055  0.27103997 -0.21525377 -0.07724415 -0.46396556
#  -0.45988279  0.04278364  0.07773404 -0.59343458  1.43384221  4.26193235
#  -5.62570105 -3.41084574  1.19293866 -7.8069951  -3.89325306]
# [-0.24182239  0.20654883  0.33826872 -0.17136252  0.12762832  0.08833371
#  -0.77426952 -0.38461494  0.46891142 -0.9469043  -0.30865291 -0.4722109
#   3.17519524  7.1466385  14.02894036 -3.71250101 -9.9557128 ]
# [-2.56797053e-01  2.08702775e-01  4.23475919e-02  1.11439280e-01
#   1.69374622e-01  3.48179823e-03 -7.39782735e-01 -4.65121717e-01
#  -1.26975110e+00  1.96983318e-01  6.20347022e-02 -6.82430913e+00
#   4.86507249e+00 -2.21057067e+00 -7.74046796e+00  1.36761252e+00
#   4.04248767e+00]
# [-0.24220881  0.12793452  0.09981385  0.24230391  0.25900384 -0.35386849
#  -0.4742944  -0.07941773 -0.72882323  0.220266   -2.3914277   5.65443069
#   1.48499756  3.42879798 -6.15276888  6.91036408  8.08967537]
# [-0.22898848 -0.03333415  0.29413199  0.3700243   0.04138498 -0.31578521
#  -0.05394332 -0.20966117 -0.4282393   0.38125796 -3.17244181  2.90062613
#   5.16555865 -5.37546374  4.11085444  8.14618365 -7.15199534]
# [-0.18579178 -0.03882914  0.12973195  0.39935467 -0.22103554 -0.30385045
#   0.15316087 -0.3696976  -1.13764538  1.13428268  1.61010759 -6.36551392
#  -3.05407475 -4.78561306 -1.37518321  0.78502551 -0.7249887 ]
# [-1.44386347e-01 -4.36930496e-03 -3.55105984e-03  2.91038544e-01
#  -1.45041036e-01 -1.70603303e-01  7.56726018e-02 -2.89649395e-01
#  -4.48183889e-01  6.28393774e-01  6.99449267e-02 -5.83537201e-01
#  -1.27149102e+00  3.82723332e+00  4.26949155e+00 -2.05317033e+00
#   2.40697078e+00]
# [-1.30925711e-01 -2.12335835e-02  2.22569591e-01  2.70572215e-01
#  -3.54256767e-01 -3.80986636e-02 -9.61723935e-03 -1.03041471e-01
#  -2.68897480e-01  4.11567333e-03 -5.84858753e-01  6.13366951e+00
#   6.00514791e-01 -6.32847559e+00  1.08829758e+00 -8.63479368e-01
#   4.01378940e+00]
# [-1.37789267e-01 -8.39356856e-04  3.43253683e-01  6.91090777e-02
#  -1.36955419e-01  6.44681789e-02 -2.69637445e-01  2.32396910e-01
#  -5.33848185e-01 -2.64731283e-01  8.34454794e-01 -1.27269611e-01
#  -5.03099706e+00  8.05972396e+00  1.88907647e+00 -5.82239474e+00
#   6.92204421e+00]
# [-0.14132193  0.00817805  0.01748152  0.22322226  0.0333315  -0.01298718
#  -0.21071643  0.17298899 -1.42953264  0.09546118 -0.27754664 -8.03796849
#   5.41650737  0.0200297  -2.64083003  4.06733522 -5.61946784]
# [ -0.09202072   0.04135234   0.0902952   -0.06934795   0.13019715
#   -0.01220929   0.1362067   -0.3725885    0.20349056   1.33421625
#    1.19171862   5.13945628 -10.00710382   2.05186656   1.65668191
#    7.82664134 -11.01809414]
# [-0.04559261  0.14614448  0.03174775 -0.41050646 -0.17862088 -0.24846179
#   0.19629044 -0.49780595 -1.34236329  0.59829471  2.42656012 -4.68417065
#  -4.01664754 -8.55002019 -7.45024983 -3.00513638  2.46490132]
# [-0.04186779  0.2029795  -0.04325349 -0.33883835  0.13929492 -0.287779
#  -0.05159215 -0.07391212  0.03956104 -0.20215561  0.31685928  1.09906478
#   3.62378321 11.59422395  2.83700632 -4.40933686 10.17093057]
# [-6.97176064e-02  1.90279598e-01  3.11243665e-02 -3.74971701e-02
#  -1.70825782e-03 -2.49763192e-01 -2.36978863e-01  6.72923238e-02
#  -2.82694571e-01 -7.27983425e-01 -2.58031813e-01  1.98369555e+00
#   5.53289961e+00 -8.54360173e+00 -5.07724570e-01 -1.24070899e+00
#  -5.38652782e-01]
# [-0.11454865  0.23260415 -0.1763365   0.15439927 -0.1370269  -0.52135282
#  -0.36010068  0.2405802  -1.20192916 -1.0121338   1.45656094 -6.43400623
#   1.33250917  0.42154159 -7.16362052 -2.89051872  4.82626064]
# [-0.15891701  0.20584242 -0.19842173  0.14016982 -0.35277516 -0.54030891
#  -0.34697374  0.14440891 -0.36905663 -0.80302369 -1.82170227  2.45034931
#  -0.72918841 -5.18717527  2.80500851  1.62405613 -5.77343818]
# [ -0.18054869   0.13677952   0.30663572  -0.36731018  -0.51556772
#   -0.34362221  -0.28053549  -0.18400356   0.66287969   0.16362351
#   -0.09770037   9.5744696   -8.06504945 -12.29229802   2.92165374
#    1.04919332  -5.67041373]
# [-0.16815191  0.12256861  0.2414428  -0.08344133 -0.4111356  -0.14196141
#  -0.25388692 -0.40615621  0.0895143   0.10930891 -0.75695546 -4.47715577
#   9.36951023  3.0297728   4.51116118  0.54298576 -2.87099784]
# [-0.17911864  0.06952512 -0.1254022   0.4005335   0.36091507  0.09770503
#  -0.3688922  -0.24600763 -0.02627833 -0.35292443 -1.23812894 -6.62508502
#   6.33597734 16.67682613  4.24678216 -2.90617972  5.84816184]
# [-0.17039077  0.07224854 -0.27670295  0.18358303  0.81156023  0.16326371
#  -0.5456808   0.20929487  0.29340432  0.66971826  1.21311056 -0.31439665
#  -2.41301061  5.52434228 -0.49969884 -3.09444249  9.33102175]
# [ -0.07908341   0.11182486   0.18297899  -0.31221685   0.33994975
#   -0.05776062  -0.23207097   0.29467426   0.62988935   1.99811509
#   -0.19776959  11.21872783 -11.48177691 -13.77466628  -4.98412918
#   10.92293004  -1.50330381]
# [-0.0228559   0.08119609  0.14779153 -0.25804836 -0.13088651 -0.03304391
#   0.05173129  0.2470694  -0.17806689  0.728467   -0.48860786 -6.53012919
#   5.70815275 -4.90838595  3.58132437  2.01108885 -0.25433159]
# [ 5.84147207e-03  8.10956664e-02  3.54560130e-02 -3.04841543e-01
#  -4.04412859e-01  3.10570895e-02  7.17041822e-02 -7.66046610e-02
#  -5.46473404e-02  4.67846578e-01  2.30651480e-01  1.36656887e-02
#  -3.64596123e+00 -4.19083909e+00 -3.36960399e-01 -6.45581009e-01
#  -8.83716699e+00]
# [-2.26876155e-04  4.98103498e-02 -1.51222687e-01 -1.30760453e-02
#  -1.64280429e-01  4.58475546e-02  2.58199574e-04 -3.36658982e-02
#  -7.31924099e-02 -3.96500595e-01 -9.84506215e-01 -4.00740559e+00
#   7.70047171e+00  7.56766567e+00  5.84639357e-01 -1.36221577e+00
#   6.00996269e+00]
# [-2.31363957e-02  8.70811965e-04  1.34320931e-01  6.33227924e-02
#   5.81645139e-02  1.25188373e-01 -3.73964871e-02 -1.02494908e-01
#   8.96480403e-01 -6.33518250e-01 -1.16091304e+00  9.88420630e+00
#  -6.03292499e-01  2.23072526e+00  1.69055360e+00 -2.66069928e-01
#  -5.17800913e+00]
# [-0.06947086 -0.02697608  0.26580186  0.13669253  0.28458164 -0.16484343
#  -0.03910573 -0.13558678 -0.59507995 -1.12696649  0.10956738 -1.49534149
#   2.17126981  4.13774239 -9.20589327 -0.63210269  1.75467766]
# [-0.13624757 -0.0257495   0.10148964  0.18306854  0.26446318 -0.26354855
#   0.0658012  -0.30803865  0.01188277 -1.43916496 -0.18114558 -3.70317571
#  -0.30140212 -2.5722755   2.80882731  3.0492621  -5.58044612]
# [-0.15461741  0.02860956 -0.03117335  0.2214788   0.2618156  -0.33020031
#   0.09745894 -0.31657037 -0.74548032  0.27227967  1.30704253 -2.2090038
#  -2.14715261 -0.03917455 -3.3668007  -1.12200818  2.36659929]
# [ -0.16443464   0.08296782   0.13830814   0.14551643  -0.21269372
#   -0.33975245  -0.32325063   0.06327753  -0.07793576  -0.53309358
#    0.7579865    5.24228254  -0.52058549 -10.85837085   0.6521576
#   -9.84976922   8.90322925]
# [-0.19568598  0.03432517  0.43539151  0.19078675 -0.43296701 -0.13287277
#  -0.43052547  0.28409185  0.10577396 -0.56939006 -1.98444788  4.99136602
#   1.7813285   1.21218295  3.95665233 -0.48425764 -0.9729928 ]
# [ -0.17379197   0.02756469   0.35546691   0.02689902  -0.17413104
#   -0.23908309  -0.04196934  -0.3008791   -0.55847392   1.14611059
#    1.44459979  -3.97560433  -2.27284117   3.92539757  -4.39200476
#    9.98070772 -15.46616425]
# [-0.15521856  0.0768887   0.19385802  0.12243515 -0.06156964  0.02537421
#  -0.23848983 -0.50292248  0.14738551 -0.03871408  0.81121643 -2.34259277
#   3.15778128  0.72511375  9.27979728 -9.01422064  3.07621267]
# [-0.13872399  0.08549645 -0.08140722  0.19448955  0.35453774  0.04816173
#  -0.20712251 -0.30392941 -0.70953085  0.59324925 -0.61792406 -5.56517466
#  -0.18789049  9.24859126 -3.78047592  3.75461369  2.80845309]
# [-0.12719474  0.06621714 -0.20904348  0.10034251  0.56434054  0.18080305
#  -0.20436349 -0.3428832   0.17594884  0.17078508  0.1499592  -0.6058657
#   0.95428589  1.6497546   5.57807847 -1.37922016 -2.55540049]
# [-1.27162681e-01  2.41890505e-02 -1.41966685e-02  3.27292514e-01
#   1.35695274e-01  2.42906281e-01 -1.36450817e-01 -1.16830661e-01
#   1.45351194e-01 -8.13398980e-03 -1.52604330e+00  6.14269633e+00
#   5.52538704e+00 -1.02460198e+01 -9.47397681e-01  7.26330969e-01
#   6.56181214e+00]
# [-1.35210601e-01 -1.69919722e-03 -9.91500456e-02  5.15147950e-01
#  -3.84657872e-01  9.02205086e-02 -2.42034374e-01  1.75574814e-01
#  -9.32279547e-01 -2.71764463e-01  1.53531795e-01 -5.96190245e+00
#   1.21485048e+00 -7.94550892e+00 -4.12442422e+00 -2.97318088e+00
#   4.35969265e+00]
# [-0.15026762 -0.01683257 -0.43494651  0.3310071  -0.04683958  0.05174791
#  -0.17297293  0.05408    -0.52501818 -0.34994416 -0.95836663 -5.36728277
#  -5.35188499 11.51342626  1.39461406  2.47111949 -6.36186673]
# [-0.11851468  0.03148156 -0.14736682  0.13993151 -0.03400025  0.09028581
#  -0.09846511 -0.1337794   0.6772211   0.54407095  0.75232938 10.27734141
#  -4.9392963  -1.21070452  0.96477258  1.12652866 -1.42194745]
# [-0.09722938  0.0409045   0.24367414 -0.13241652  0.23786679  0.26905091
#   0.15230418 -0.41832309  0.91782003  0.18981937 -0.01399079  5.08604732
#  -4.09906149  8.05611987  4.6225303   7.26892305 -5.87708016]
# [-8.40052383e-02 -1.33613893e-02 -7.43906640e-02  3.05675978e-01
#   9.91203549e-03  1.24992780e-01  5.09543385e-01 -5.17624217e-01
#  -1.09112482e+00  4.23365083e-01 -1.62555199e+00 -1.04898245e+01
#   1.07019358e+01 -9.32986054e+00 -4.95843144e+00  5.88552776e+00
#   1.22712668e+00]
# [-6.12445694e-02 -3.19485452e-02  2.95943899e-03  1.57506055e-01
#  -4.55983384e-01  9.54080931e-02  9.09215004e-02 -3.79245512e-01
#   1.08079719e-01  4.04567292e-01  1.32185605e-01  6.36223715e+00
#  -7.82284954e+00 -7.34108292e-01  3.16729359e-01 -1.31491627e+01
#   2.80580555e+00]
# [-0.04774298 -0.00789615  0.033711   -0.15083247  0.04049624 -0.06207105
#  -0.20294819 -0.33171273 -0.28808309  0.57328932  1.4588317  -3.53932882
#  -0.63552571  6.40937964 -4.70371181 -1.55646556 -0.42342073]
# [-4.77531546e-02  4.97028098e-03 -1.46425031e-01  1.95548748e-01
#   1.04640825e-01 -2.73726923e-01 -8.71939003e-02 -3.22810689e-01
#   7.84396832e-03 -2.55948076e-01 -1.73119610e-01 -1.98456624e+00
#   8.15807239e+00 -1.42643221e+00 -3.02176744e+00  3.40108402e+00
#   5.27802021e-01]
# [-0.05954791  0.0144925   0.20765912  0.10398065  0.25058817 -0.02651731
#  -0.29254098 -0.0577788   1.36391509 -0.45106314  0.12333057  9.75762499
#  -5.22072949  4.56891759  7.93923173 -5.96648941  6.97280745]
# [-0.10158705  0.02884825  0.28254575  0.13320905  0.40265553  0.02301132
#  -0.37971632  0.34291452 -0.12868858 -0.97671708  0.56127112 -2.75917295
#   3.12789509  1.31296866 -2.8712611   0.48222812  7.19693472]
# [ -0.14942559   0.10739838   0.34073611  -0.17667686  -0.11088938
#   -0.07813798  -0.42279477   0.12230137   0.09187315  -0.99274014
#    1.65348383   2.03714256  -9.30078363 -12.75990951  -0.84804952
#   -3.23937299 -10.61794391]
# [-0.20049232  0.18692218  0.26758535 -0.18083239 -0.09159376 -0.10196754
#  -0.49443077 -0.42003406 -0.08768996 -0.98665784  1.45958487 -2.99679753
#   2.8375982   6.17943987 -0.11460075 -1.22628188 -9.85850651]
# [ -0.25248073   0.14699723  -0.25380309   0.46004215   0.27087476
#   -0.07161417  -0.54865448  -0.49231359  -0.73161632  -0.98451051
#   -2.27322904 -11.31449766  12.39185279   5.48644375   1.67783326
#    0.51264669   3.92218262]
# [ -0.23298166   0.02787896   0.07534096   0.43019018  -0.10827964
#   -0.12087355  -0.25454786  -0.41570349   0.55649992   1.0901346
#   -2.41152039  13.81382683  -5.12459347 -11.11507465  -1.87688047
#    8.8759028    1.45148586]
# [ -0.13421551   0.02063442   0.40166207  -0.10271941  -0.06649704
#   -0.53433921   0.2623295   -0.10028809  -0.08830377   2.23605157
#    1.20701935   1.72939612 -11.62982412   6.91817395 -10.09886522
#    9.73378054   9.29872629]
# [ -0.05617429   0.06600984   0.14825201  -0.24439953   0.4336646
#   -0.23506598  -0.17417657   0.07310708   0.3101043    1.11488661
#    0.61132095  -7.91454267   1.39486443   8.10802085  13.20080961
#  -14.0802008   -0.53883633]
# [-0.02275302  0.07784865 -0.19748293 -0.12833501  0.45985171  0.24620587
#  -0.43026586  0.27376532  0.12407138  0.53107635  0.01675468 -5.08304208
#   1.30380803 -3.33638595  6.04009829  1.0216474   6.02994543]
# [-3.84949194e-03  6.28876619e-02 -9.87011067e-02 -1.46083651e-01
#  -1.72065333e-01  4.53419655e-01 -1.65401545e-01  2.71431020e-01
#   7.43212202e-01  2.22257732e-01 -4.92160854e-01  4.87144614e+00
#  -6.09851569e-01 -1.30112557e+01  2.63662766e+00  6.40307390e+00
#  -3.12469116e+00]
# [-1.10322785e-02 -8.34931183e-03  6.70841502e-02  1.65617342e-01
#  -4.40222027e-01  3.43927835e-01  4.16895673e-01 -5.05011042e-02
#   3.99918200e-01 -3.61474181e-01 -1.46864080e+00  2.73879230e+00
#   7.79049864e+00  1.34416946e+00 -3.72335897e+00  1.09356056e+01
#  -6.99440999e+00]
# [ -0.01579534   0.03701093   0.02197804  -0.14052425  -0.16958798
#    0.07953273   0.57997688   0.07188654  -0.4313051   -0.13797537
#    1.89438717  -2.91271415 -10.96299005   5.66726794  -5.21249928
#   -1.74698256   7.08994611]
# [-0.02089438  0.05878242 -0.11276163 -0.33897871  0.35365832 -0.03841241
#   0.28009709  0.32269783 -0.67932433 -0.0216659  -0.56921896 -2.24314866
#   0.25854466  9.43932576 -1.1276361  -6.51892121  2.76009494]
# [-5.89249985e-02 -1.15157463e-02 -3.29802629e-01  6.75618304e-02
#  -6.18370549e-02 -8.45053252e-03  6.06651513e-03  2.31945143e-01
#  -5.79933019e-01 -1.03928825e+00 -1.64562105e+00 -3.96282805e+00
#   8.44179504e+00 -1.40702955e+01  1.05276575e+00 -3.62496012e+00
#  -4.10968338e+00]
# [ -0.07405866  -0.02227805   0.02953406  -0.39383119  -0.36116113
#   -0.24099099   0.13588007   0.22097946  -0.07726332  -0.32320099
#   -0.0796393   10.16619775 -13.3993668   -0.07611139  -6.2867363
#    4.62105042   1.97121319]
# [-0.07800458  0.02212625  0.11805689 -0.48190021 -0.44679296 -0.31327322
#   0.03582146  0.00929718  0.45354937 -0.19364988  0.75475267 -0.46268204
#   4.42575991  1.27479352  1.6661276  -4.63536433 -6.99524021]
# [-0.10157231  0.04426955 -0.1474116   0.0175865  -0.05290318 -0.02674164
#  -0.14722321 -0.20598521  0.61948239 -0.62853744  0.3277287  -5.65735302
#   8.58385866 10.55263819  7.23198124 -1.56448932 -1.98863444]
# [-1.19730964e-01  1.01492308e-01 -3.99435182e-01  4.53952116e-02
#   3.57954363e-02 -2.50605841e-02 -2.21670289e-01 -1.63092373e-01
#  -5.32779910e-01 -3.02383142e-03  1.11736458e+00 -3.87741089e+00
#  -3.64786666e+00 -3.07101137e+00 -2.48472765e+00 -3.56508337e+00
#   8.73709738e-01]
# [-0.13341896  0.17195446 -0.36736065 -0.41139235 -0.39198544  0.17346451
#  -0.56275346 -0.26011717  0.19215686 -0.58033481  1.12998023  1.4477964
#  -9.09606127 -8.64490191  6.81826408 -6.17484203 -3.2331711 ]
# [-0.15525829  0.18506449 -0.16148999 -0.58740305 -0.22130966  0.53190604
#  -0.47777618 -0.3692375   0.79067415  0.47274355  0.60059682  1.97746772
#  -0.75096738 -5.77864152  4.32511886  0.07932048 -5.38192942]
# [-0.11208636  0.09129665 -0.31401676  0.09978381 -0.0222324   0.35739621
#   0.05048542 -0.5365199   0.52372758  1.11438053 -3.15374181 -2.02160053
#  15.65424604 10.01548203 -5.25247886 12.49171053  0.99028576]
# [-7.85357497e-02 -6.49390084e-03 -2.68767029e-01  5.37148844e-01
#   3.03971366e-01  3.93011715e-01 -4.90279508e-02 -6.75547788e-02
#   6.24406799e-01  5.32014771e-01 -1.08301506e+00  2.48844082e+00
#   3.83040694e+00  3.16813846e+00  3.09989298e+00 -8.49324026e+00
#   1.21106161e+01]
# [-4.71927132e-02 -1.50577168e-02  2.07413795e-03  4.03480892e-01
#   2.66546316e-01  3.83435487e-01 -4.13000069e-01  1.62328027e-01
#   5.10101677e-01  5.50392338e-01  6.23608310e-02  5.21653419e+00
#  -4.60405102e+00 -2.20856137e+00 -2.38672752e+00 -5.34006860e+00
#  -5.24455250e-01]
# [ -0.0237568   -0.02897717  -0.11109835   0.32271554  -0.15406053
#   -0.15150713   0.11750994  -0.03511067  -0.61438575   0.1756613
#   -0.21947203  -5.92580337  -0.60675682  -9.16865939 -12.16847008
#   15.7829541   -4.91396362]
# [-4.06811238e-02  7.85878318e-04 -2.10532212e-01  9.71385251e-02
#  -1.71879203e-01 -3.48408959e-01  7.58212028e-04  8.51504004e-02
#   3.61544483e-01 -6.31205549e-01  7.02307421e-01  2.89656036e-01
#  -4.72662179e+00  3.79935344e+00  3.57685066e-01 -1.08378039e+01
#   5.68646954e+00]
# [-0.08567793 -0.0330418   0.11873584  0.04567122 -0.05517645 -0.34826285
#  -0.12819566  0.36358544  1.14991391 -1.19308956 -1.63588542  8.96513125
#   1.87985177  1.51380188 -0.08946248  2.12539655  4.65160994]
# [-0.15486031 -0.07424298  0.29973144  0.35455776 -0.16438873 -0.49894955
#   0.02414302  0.40847171  0.47172671 -1.58581163 -0.33633527  1.27490462
#   5.63733958 -0.65247496 -3.97422417  2.41277491 -1.36744037]
# [-2.23721199e-01 -2.96031658e-03  3.10295998e-01  2.77221405e-01
#   1.65808079e-01 -6.30796046e-01 -1.91399125e-01  3.19983329e-01
#   1.05316589e+00 -1.14116628e+00  2.55142504e+00 -3.57468144e-01
#  -2.57548050e+00  7.17584962e+00 -1.97471221e+00 -6.88414150e+00
#  -1.94564409e+00]
# [ -0.25538685   0.11977166   0.18695761   0.22211664   0.0351349
#   -0.43391092  -0.35284763  -0.25477176   0.95436676  -0.22957347
#    2.35258593  -2.71526009   1.31419902  -5.39465531   5.58496712
#   -3.91299075 -17.14363347]
# [-0.22600019  0.2546529   0.10390743 -0.07019541 -0.30817131 -0.19580596
#  -0.6750847  -0.47885199  1.06283473  1.00975283  2.78693869 -1.53333668
#  -8.52163975 -6.08316095  4.77847529 -4.15444387  3.79694004]
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(

# %% [markdown]
# # Hyperparameters [10 marks]
# <a id="Hyperparameters"></a>
#
# All your hyperparameters should be stated here. We will change their value here and your code should work  accordingly.

# %%
# mention the values of all the hyperparameters (you can add more hyper-paramters as well) to be used in the entire notebook, put the values that gave the best
# performance and were finally used for the agent

gamma = 0.99                         # FOR REINFORCE, VPG, DDPG, TD3, SAC

# tried other values for beta but on increasing it, rewards dropped to around -1600 then tried decreasing it, but still
# wont help.
beta = 0.08                          # FOR VPG
optimizerFn = torch.optim.Adam       # FOR REINFORCE, VPG
optimizerLR = 0.0003                 # FOR REINFORCE, VPG
MAX_GRAD_NORM_POLICY = 1.0           # FOR REINFORCE, VPG, DDPG, TD3, SAC
MAX_GRAD_NORM_VALUE = 1.0            # FOR REINFORCE, VPG, DDPG, TD3, SAC

# for reinforce and vpg, i trained it for even around 1000 episodes as well but these algos still
# remained stuck in between -1500 to -1200 train or eval reward
MAX_TRAIN_EPISODES = 150             # FOR REINFORCE, VPG, DDPG, TD3, SAC
MAX_EVAL_EPISODES = 1                # FOR REINFORCE, VPG, DDPG, TD3, SAC

updateFrequency = 1                       # FOR DDPG, SAC
policyOptimizerFn = torch.optim.Adam      # FOR DDPG, TD3
valueOptimizerFn = torch.optim.Adam       # FOR DDPG, TD3
policyOptimizerLR = 2e-4                  # FOR DDPG, TD3
valueOptimizerLR = 3e-4                   # FOR DDPG, TD3

# I used these minSamples to deicde when to start training the neural network
# means when replay_buffer contains atleast these many expereinces only then start learning
# so these many steps will be like a warmup for collecting some experiences.
minSamples = 10000                        # FOR DDPG, TD3, SAC

# this is most important for better exploration, i tried increaing it but because of higher exploration, final
# rewards got hurt and making it smaller makes the agent to exploit some sub-optimal action leading to lower rewards.
# I am decaying it within my algorithm linearly based on global steps taken out of total steps possible.
noiseScaleRatio = 0.1                     # FOR DDPG, TD3

# I tried initially 0.1, 0.2, 0.02 but all are changing the target network too drastically making trinaing unstable.
tau = 5e-3                                # FOR DDPG, TD3, SAC
bufferSize = 1_000_000                    # FOR DDPG, TD3, SAC
batchSize = 256                           # FOR DDPG, TD3, SAC

# I kept valye frequency value smller since want my critic to get trianed more for better learning
# because if critic will be weak then policy network will get noisy signals since policyloss in itself relies on
# value estimated using critic network.
updateFrequencyValue = 1                  # FOR TD3
updateFrequencyPolicy = 2                 # FOR TD3
trainPolicyFrequency = 2                  # FOR TD3

# i tried higher values of entrpoLR like 1e-3, 3e-3, 5e-3 but SAC was getting stuck and converges prematurely.
entropyLR = 2e-4                          # FOR SAC
logSTD_min = -10.0                        # FOR SAC
logSTD_max = 2.0                          # FOR SAC
epsilon = 1e-6                            # FOR SAC
squasherMin = -1                          # FOR SAC
squasherMax = 1                           # FOR SAC
ep_max_steps = 1000
base_seed = 21

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Helper Functions [20 marks]
#
# <a id="helper"></a>
#
# Write all the helper functions that will be used for value-based and policy based algorithms below. In case you want to add more helper functions, please feel free to add.

# %%
#Value Network

def createValueNetwork(inDim, outDim, action_size=0, hDim = [32,32], activation = F.relu):
    #this creates a Feed Forward Neural Network class and instantiates it and returns the class
    #the class should be derived from torch nn.Module and it should have init and forward method at the very least
    #the forward function should return q-value for each possible action

    #Your code goes in here
    class ValueNetwork(nn.Module):
        def __init__(self):
            super(ValueNetwork, self).__init__()
            self.activation = activation

            layers = []
            prev_dim = inDim + action_size

            for h in hDim:
                layers.append(nn.Linear(prev_dim, h))
                prev_dim = h

            layers.append(nn.Linear(prev_dim, outDim))
            self.layers = nn.ModuleList(layers)

            # initializinig the weights using orthogonal initialization for a good start and avoiading policy collapse
            self._init_weights()

        def _init_weights(self):
            for m in self.modules():
                if isinstance(m, nn.Linear):
                    nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                    nn.init.constant_(m.bias, 0)


        def forward(self, x, action=None):
            if action is not None:
                x = torch.cat([x, action], dim=-1)

            for layer in self.layers[:-1]:
                x = self.activation(layer(x))

            x = self.layers[-1](x)
            return x

    valueNetwork = ValueNetwork()
    return valueNetwork

# %%
#Policy Network

"""
added use_tanh boolean in the funciton arguments for reusing the same method for TD3 and DDPG since tanh 
activation is used at the output layer of policy network for these two. Then rescaling stuff is being handled in the

"""

def createPolicyNetwork(inDim, outDim, hDim = [32,32], activation = F.relu, use_tanh=False):
    #this creates a Feed Forward Neural Network class and instantiates it and returns the class
    #the class should be derived from torch nn.Module and it should have init and forward method at the very least
    #the forward function should return action logit vector
    #Your code goes in here
    class PolicyNetwork(nn.Module):
        def __init__(self):
            super(PolicyNetwork, self).__init__()
            self.activation = activation
            layers = []
            prev_dim = inDim

            # Hidden layers
            for h in hDim:
                layers.append(nn.Linear(prev_dim, h))
                prev_dim = h

            layers.append(nn.Linear(prev_dim, outDim))
            self.layers = nn.ModuleList(layers)

            # initializinig the weights using orthogonal initialization for a good start and avoiading policy collapse
            self._init_weights()

        def _init_weights(self):
            for m in self.modules():
                if isinstance(m, nn.Linear):
                    nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                    nn.init.constant_(m.bias, 0)

        def forward(self, x):
            for layer in self.layers[:-1]:
                x = self.activation(layer(x))
            x = self.layers[-1](x)
            
            # squeeshing the action-values in the range [-1,+1]
            if use_tanh:
                x = F.tanh(x)
            return x

    policyNetwork = PolicyNetwork()
    return policyNetwork

# %%
# These action selction methods will be used for REINFORCE and VPG  

def selectGreedyAction(policy_network, s, env):
    state = torch.FloatTensor(s).unsqueeze(0)
    action_low = env.action_space.low
    action_high = env.action_space.high

    action_scale = torch.tensor((action_high - action_low) / 2.0, dtype=torch.float32)
    action_bias = torch.tensor((action_high + action_low) / 2.0, dtype=torch.float32)

    with torch.no_grad():
        # here i am squashing the output from policy network (not using tanh but eventually i am using it while action selction)
        # and then reacling and shifting it to the actual values.
        mean = torch.tanh(policy_network(state)) * action_scale + action_bias

    return mean.detach().cpu().numpy().flatten()


def selectAction(policy_network, s, env, std_scale=0.5):
    state = torch.FloatTensor(s).unsqueeze(0)
    action_low = env.action_space.low
    action_high = env.action_space.high

    action_scale = torch.tensor((action_high - action_low) / 2.0, dtype=torch.float32)
    action_bias = torch.tensor((action_high + action_low) / 2.0, dtype=torch.float32)

    mean = torch.tanh(policy_network(state)) * action_scale + action_bias
    
    std = torch.ones_like(mean) * std_scale * action_scale
    dist = torch.distributions.Normal(mean, std)
    action = dist.sample()

    action = torch.clamp(action, action_low[0], action_high[0])

    logp_a = dist.log_prob(action).sum(dim=-1)
    entropy_pa = dist.entropy().sum(dim=-1)

    return action.detach().numpy().flatten(), logp_a.squeeze(), entropy_pa.squeeze()

# %%
def getStepWiseReturnsAndDiscounts(gamma, reward, next_value=0.0):
    """
        input: gamma (Int)
               reward (python list)
               next_values (if episode got terminated else 0)

        output: returns (tensor)
                gammas (tensor)
    """
    rewards = torch.tensor(reward, dtype=torch.float32)
    size = rewards.shape[-1]
    returns = torch.zeros(size, dtype=torch.float32)
    gammas = gamma ** torch.arange(size, dtype=torch.float32)

    G = next_value if isinstance(next_value, float) else next_value.item()
    for t in range(size-1, -1, -1):
        G = rewards[t] + gamma * G
        returns[t] = G

    return returns, gammas

# %%
def moving_average(x, window=50):
    if len(x) < window:
        return np.array(x)
    return np.convolve(x, np.ones(window) / window, mode='valid')


def plotResults(
    quantityDict,
    env_names,
    window=50,
    use_moving_avg=True,
    save_pdf=False,
    save_dir='./plots',
    plot_over_steps=False, # if enables then dont print train and eval rewards over episodes
    x_reduced_percent=None
):
    """
    input format:
    - [y1, y2, y3]
    - (x_list, y_list)
    - [(x, y), (x, y)]
    """

    if save_pdf:
        os.makedirs(save_dir, exist_ok=True)

    for env in env_names:
        for quantityName in quantityDict[env].keys():
            if plot_over_steps == True and quantityName in ["Train Rewards", "Eval Rewards", "Total Steps"]:
                continue

            plt.figure(figsize=(8, 5))

            for agent, quantityOverSeeds in quantityDict[env][quantityName].items():

                processed_seeds = []
                x_reference = None

                for quantityList in quantityOverSeeds:
                    # UNWRAP nested structures like [[[(x,y)]]]
                    while isinstance(quantityList, (list, tuple)) and len(quantityList) == 1:
                        quantityList = quantityList[0]
                        
                    # CASE 1: (x_list, y_list)
                    if isinstance(quantityList, tuple) and len(quantityList) == 2:
                        x_vals, y_vals = quantityList
                        x_vals = np.array(x_vals).reshape(-1)
                        y_vals = np.array(y_vals).reshape(-1)

                    # CASE 2: [(x,y), (x,y)]
                    elif (
                        isinstance(quantityList, (list, tuple)) and
                        len(quantityList) > 0 and
                        isinstance(quantityList[0], (list, tuple))
                    ):
                        x_vals = np.array([item[0] for item in quantityList if len(item) >= 2])
                        y_vals = np.array([item[1] for item in quantityList if len(item) >= 2])

                    # CASE 3: [y1, y2, y3]
                    else:
                        y_vals = np.array(quantityList)
                        x_vals = np.arange(len(y_vals))

                    if y_vals.ndim == 0 or len(y_vals) == 0:
                        continue

                    if y_vals.ndim > 1:
                        y_vals = y_vals.reshape(-1)
                        x_vals = x_vals[:len(y_vals)]

                    # Moving Average
                    if use_moving_avg:
                        adaptive_window = min(window, max(3, len(y_vals)//5))
                        y_vals = moving_average(y_vals, adaptive_window)
                        x_vals = x_vals[-len(y_vals):]

                    processed_seeds.append(y_vals)

                    if x_reference is None:
                        x_reference = x_vals

                if len(processed_seeds) == 0:
                    print(f"No valid data for {agent} in {quantityName}")
                    continue

                # Align lengths
                min_len = min(len(s) for s in processed_seeds)
                if x_reduced_percent is not None:
                    min_len = int(min_len * x_reduced_percent)
                if min_len == 0:
                    continue

                processed_seeds = np.array([s[:min_len] for s in processed_seeds])

                mean = processed_seeds.mean(axis=0)
                if processed_seeds.shape[0] > 1:
                    std = processed_seeds.std(axis=0)
                    sem = stats.sem(processed_seeds, axis=0)
                else:
                    std = np.zeros_like(mean)
                    sem = np.zeros_like(mean)

                # X-axis
                if x_reference is not None:
                    x = x_reference[:min_len]
                else:
                    x = np.arange(min_len)

                # Plot
                plt.plot(x, mean, label=agent, linewidth=2)

                if processed_seeds.shape[0] > 1:
                    if use_moving_avg:
                        plt.fill_between(x, mean - std, mean + std, alpha=0.2)
                    else:
                        plt.fill_between(x, mean - sem, mean + sem, alpha=0.3)

            # Labels
            title_suffix = "Moving Avg" if use_moving_avg else "Raw"
            title = f"{quantityName} vs Episodes"
            y_label = quantityName
            x_label = "Episodes"

            if "(over global steps)" in quantityName:
                x_label = "Global Steps"
                y_label = quantityName[:-20]
                title = f"{y_label} vs {x_label}"


            plt.title(f"[{env}] {title_suffix} {title}")
            plt.xlabel(x_label)
            plt.ylabel(y_label)

            plt.legend()
            plt.grid(True, alpha=0.3)
            plt.tight_layout()

            # Save / Show
            if save_pdf:
                safe_env = env.replace('-', '_').replace(' ', '_')
                safe_quantity = quantityName.replace(' ', '_').replace('/', '_')
                suffix = "MA" if use_moving_avg else "Raw"

                filename = f"{safe_env}_{safe_quantity}_{suffix}.pdf"
                filepath = os.path.join(save_dir, filename)

                plt.savefig(filepath, format='pdf', dpi=300, bbox_inches='tight')
                print(f"Saved: {filepath}")
                plt.close()
            else:
                plt.show()

# %% [markdown]
# ## ReplayBuffer [40 marks]

# %% [markdown]
# In next few cells, you will implement replaybuffer class.
#
# This class creates a buffer for storing and retrieving experiences. This is a generic class and can be used
# for different agents like NFQ, DQN, DDQN, PER_DDQN, etc.
# Following are the methods for this class which are implemented in subsequent cells
#
# ```
# class ReplayBuffer():
#     def __init__(self, bufferSize, batch_size, seed)
#     def store(self, state, action, reward, next_state, done)
#     def sample(self, batchSize)
#     def length(self)
# ```

# %%
class ReplayBuffer():
    def __init__(self, buffer_size, batch_size=32, seed=33):
        # this function creates the relevant data-structures, and intializes all relevant variables
        #Your code goes in here
        self.buffer_size = buffer_size
        self.batch_size = batch_size
        self.seed = seed
        random.seed(self.seed)

        self.buffer = deque(maxlen=self.buffer_size)

# %%
class ReplayBuffer(ReplayBuffer):
    def store(self, state, action, reward, next_state, done):
        #stores the experiences, based on parameters in init
        #
        #this function does not return anything
        #
        #Your code goes in here
        self.buffer.append((state, action, reward, next_state, done))

# %%
class ReplayBuffer(ReplayBuffer):
    def sample(self, batchSize):
        # this method returns batchSize number of experiences
        # this function returns experiences samples
        #
        #Your code goes in here
        experiencesList = random.sample(self.buffer, batchSize)
        return experiencesList

# %%
# added one of the method within replayBuffer ie splitExpereinces for splitting the list of tuple into 
# separate lists for each entity.

class ReplayBuffer(ReplayBuffer):
    def splitExperiences(self, experiences):
        #it takes in experiences and gives the following:
        #states, actions, rewards, nextStates, dones
        #
        #Your code goes in here

        states, actions, rewards, sNexts, dones = zip(*experiences)

        states = torch.FloatTensor(np.array(states))
        actions = torch.FloatTensor(np.array(actions))
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        sNexts = torch.FloatTensor(np.array(sNexts))
        dones = torch.FloatTensor(dones).unsqueeze(1)

        # finally returning all the separated torch tensors
        return states, actions, rewards, sNexts, dones

# %%
class ReplayBuffer(ReplayBuffer):
    def length(self):
        #tells the number of experiences stored in the internal buffer
        #
        #Your code goes in here
        #
        bufferSize = len(self.buffer)
        return bufferSize

# %% [markdown]
# # Deep Policy Based RL agents.
# <a id="deep-policy-based"></a>

# %% [markdown]
# **The purpose of this part is to learn about different Deep Policy Based RL agents.**
#
# In this part of the assignment you will be implementing Deep Policy based RL algorithms we learnt in Lectures. Namely, we will be implementing REINFORCE and VPG.
#
# For all the algorithms below, this time we will not be specifying the hyper-parameters, please play with the hyper-params to come up with the best values. This way you will learn to tune the model. Some of the values were specified in the lecture, that would be a good starting point.

# %% [markdown]
# #REINFORCE [40 marks]

# %% [markdown]
# Implement the REINFORCE algorithm. We have studied about REINFORCE algorithm in the Lecture. Use the function definitions (given below).
#
# This class implements the REINFORCE Agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# ```
# class REINFORCE():
#     def __init__(env, seed, gamma,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runREINFORCE(self)
#     def trainAgent(self)
#     def trainPolicyNetwork(self, experiences)
#     def evaluateAgent(self)
# ```

# %% [markdown]
# ### Implement the methods for the REINFORCE class below

# %%
# def __init__
class Reinforce():
    def __init__(self, env, seed, gamma, optimizerFn, optimizerLR,
                MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                explorationStrategyTrainFn, explorationStrategyEvalFn):

        self.env = env
        self.seed = seed

        self.env.reset(seed=self.seed)
        self.env.action_space.seed(self.seed)
        self.env.observation_space.seed(self.seed)
        np.random.seed(seed=self.seed)
        random.seed(self.seed)
        torch.manual_seed(self.seed)

        self.gamma = gamma
        self.optimizerFn = optimizerFn
        self.optimizerLR = optimizerLR
        self.epsilon = epsilon
        self.render = False

        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES

        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn

        inDim = self.env.observation_space.shape[0]
        outDim = self.env.action_space.shape[0]
        self.policy_network = createPolicyNetwork(inDim, outDim, hDim=[512, 324, 256])

        self.optimizer = self.optimizerFn(self.policy_network.parameters(), lr=self.optimizerLR)
        self.initBookKeeping()

# %%
# def initBookKeeping
class Reinforce(Reinforce):
    def initBookKeeping(self):

        self.trainRewardsList = []
        self.evalRewardsList = []
        self.trainTimeList = []
        self.wallClockTimeList = []
        self.totalStepsList = []

        self.startTime = time.time()

# %%
# def performBookKeeping
class Reinforce(Reinforce):
    def performBookKeeping(self, train = True):

       currentTime = time.time()
       if train:
           trainTime = currentTime - self.startTime
           self.trainTimeList.append(trainTime)
       else :
           wallClock = currentTime - self.startTime
           self.wallClockTimeList.append(wallClock)

# %%
# def runREINFORCE
class Reinforce(Reinforce):
    def runREINFORCE(self):
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
        finalEvalReward = self.evaluateAgent()
        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward

# %%
# def trainAgent
class Reinforce(Reinforce):
    def trainAgent(self):
        for e in range(self.MAX_TRAIN_EPISODES):
            s, done = self.env.reset()
            rewards, logProbs = [], []
            train_steps = 0
            while not done:
                a, logp_a, _ = self.explorationStrategyTrainFn(self.policy_network, s, self.env)
                s, r, done, truncated, _ = self.env.step(a)
                done = done or truncated

                rewards.append(r)
                logProbs.append(logp_a)
                train_steps += 1

            self.totalStepsList.append(train_steps)
            self.trainRewardsList.append(np.sum(rewards))
            self.trainPolicyNetwork(rewards, logProbs)
            self.performBookKeeping(train = True)

            evalRmean, _ = self.evaluateAgent()
            self.evalRewardsList.append(evalRmean)
            self.performBookKeeping(train = False)
            if (e+1) % 10 == 0:
                print(f"[Episode {e+1}] Mean Train Reward = {np.sum(rewards):.2f} | Mean Eval Reward = {evalRmean:.2f}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList, self.wallClockTimeList, self.totalStepsList

# %%
# def trainPolicyNetwork
class Reinforce(Reinforce):
    def trainPolicyNetwork(self, rewards, logProbs):
        returns, gammas = getStepWiseReturnsAndDiscounts(self.gamma, rewards)
        baseline = returns.mean()
        advantages = returns - baseline
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        logProbs = torch.stack(logProbs).squeeze()

        # Although while calculating gammas should not be multiplies since advantage esimtationo itself uses retutns which involves
        # discounted summation of the rewards. But used this, since mentioned in lecture notes.
        policyLoss = -1.0 * (gammas * advantages * logProbs).mean()

        self.optimizer.zero_grad()
        policyLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_network.parameters(), MAX_GRAD_NORM_POLICY)
        self.optimizer.step()

# %%
# def evaluateAgent
class Reinforce(Reinforce):
    def evaluateAgent(self, greedy = True):
        rewards = []
        for _ in range(self.MAX_EVAL_EPISODES):
            rs, done = 0, 0
            s, _ = self.env.reset()
            for _ in count():
                if greedy:
                    a = self.explorationStrategyEvalFn(self.policy_network, s, self.env)
                else:
                    a, _, _ = self.explorationStrategyTrainFn(self.policy_network, s, self.env)

                s, r, done, truncated, _ = self.env.step(a)
                rs += r
                if done or truncated:
                    rewards.append(rs)
                    break

        rewards = np.array(rewards)
        return rewards.mean(), rewards.std()

# %%
# evaluating the REINFORCE agent on multiple continuous-control

# Environments used in this experiment
rein_env_name = "Pendulum-v1"
reinforceQuantityDict = {}

# Number of independent training runs per environment
num_runs = 5

# For each environment:
print(f"\n===== Environment: {rein_env_name} =====")

all_train_rewards = []
all_eval_rewards = []
all_train_times = []
all_total_steps = []
all_wall_times = []

for run in range(num_runs):
    print(f"Executing Run {run+1}  ")

    # Create environment
    env = gym.make(rein_env_name)

    # Initialize Reinforce agent
    agent = Reinforce(
        env=env, seed=base_seed+run, gamma=gamma,
        optimizerFn=optimizerFn, optimizerLR=optimizerLR,
        MAX_TRAIN_EPISODES=MAX_TRAIN_EPISODES,
        MAX_EVAL_EPISODES=MAX_EVAL_EPISODES,
        explorationStrategyTrainFn=selectAction,
        explorationStrategyEvalFn=selectGreedyAction
    )

    # Run training
    train_rewards, train_times, eval_rewards, wall_clock_times, total_steps, final_eval_reward = agent.runREINFORCE()

    print(f"Finished Run {run+1}  ")

    all_train_rewards.append(train_rewards)
    all_eval_rewards.append(eval_rewards)
    all_train_times.append(train_times)
    all_wall_times.append(wall_clock_times)
    all_total_steps.append(total_steps)


reinforceQuantityDict[rein_env_name] = {
    "Mean Train Rewards": {
        "REINFORCE": all_train_rewards
    },
    "Mean Eval Rewards": {
        "REINFORCE": all_eval_rewards
    },
    "Train Time (in sec)": {
        "REINFORCE": all_train_times
    },
    "Wall Clock Time (in sec)": {
        "REINFORCE": all_wall_times
    },
    "Total Steps": {
        "REINFORCE": all_total_steps
    }
}

# Compute Statistics
train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"\n(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
print(f"Finished {rein_env_name}")
# Out:
# ===== Environment: Pendulum-v1 =====
# Executing Run 1
# [Episode 10] Mean Train Reward = -1807.43 | Mean Eval Reward = -1651.46
# [Episode 20] Mean Train Reward = -1868.24 | Mean Eval Reward = -1771.26
# [Episode 30] Mean Train Reward = -1814.31 | Mean Eval Reward = -1731.12
# [Episode 40] Mean Train Reward = -1780.00 | Mean Eval Reward = -1686.03
# [Episode 50] Mean Train Reward = -1813.54 | Mean Eval Reward = -1704.69
# [Episode 60] Mean Train Reward = -1550.06 | Mean Eval Reward = -1728.12
# [Episode 70] Mean Train Reward = -1784.01 | Mean Eval Reward = -1535.00
# [Episode 80] Mean Train Reward = -1742.29 | Mean Eval Reward = -1585.07
# [Episode 90] Mean Train Reward = -1647.77 | Mean Eval Reward = -1677.09
# [Episode 100] Mean Train Reward = -1535.89 | Mean Eval Reward = -1639.28
# [Episode 110] Mean Train Reward = -1645.62 | Mean Eval Reward = -1609.41
# [Episode 120] Mean Train Reward = -1660.31 | Mean Eval Reward = -1579.34
# [Episode 130] Mean Train Reward = -1398.39 | Mean Eval Reward = -1601.72
# [Episode 140] Mean Train Reward = -1630.05 | Mean Eval Reward = -1576.63
# [Episode 150] Mean Train Reward = -1647.28 | Mean Eval Reward = -1586.92
# Finished Run 1
# Executing Run 2
# [Episode 10] Mean Train Reward = -1433.10 | Mean Eval Reward = -1665.01
# [Episode 20] Mean Train Reward = -1332.83 | Mean Eval Reward = -1662.72
# [Episode 30] Mean Train Reward = -1560.77 | Mean Eval Reward = -1658.92
# [Episode 40] Mean Train Reward = -1182.32 | Mean Eval Reward = -1183.05
# [Episode 50] Mean Train Reward = -1507.97 | Mean Eval Reward = -1628.75
# [Episode 60] Mean Train Reward = -1442.60 | Mean Eval Reward = -1551.69
# [Episode 70] Mean Train Reward = -1565.72 | Mean Eval Reward = -1339.11
# [Episode 80] Mean Train Reward = -1588.74 | Mean Eval Reward = -1358.96
# [Episode 90] Mean Train Reward = -1428.29 | Mean Eval Reward = -1559.36
# [Episode 100] Mean Train Reward = -1206.12 | Mean Eval Reward = -1353.62
# [Episode 110] Mean Train Reward = -1609.39 | Mean Eval Reward = -1525.03
# [Episode 120] Mean Train Reward = -1389.85 | Mean Eval Reward = -1215.16
# [Episode 130] Mean Train Reward = -1383.37 | Mean Eval Reward = -1607.03
# [Episode 140] Mean Train Reward = -1444.32 | Mean Eval Reward = -1503.99
# [Episode 150] Mean Train Reward = -1154.71 | Mean Eval Reward = -1289.42
# Finished Run 2
# Executing Run 3
# [Episode 10] Mean Train Reward = -1488.35 | Mean Eval Reward = -1540.85
# [Episode 20] Mean Train Reward = -1566.49 | Mean Eval Reward = -1594.80
# [Episode 30] Mean Train Reward = -1385.69 | Mean Eval Reward = -1591.41
# [Episode 40] Mean Train Reward = -1561.95 | Mean Eval Reward = -1594.53
# [Episode 50] Mean Train Reward = -1541.74 | Mean Eval Reward = -1595.10
# [Episode 60] Mean Train Reward = -1552.12 | Mean Eval Reward = -1683.20
# [Episode 70] Mean Train Reward = -1510.84 | Mean Eval Reward = -1613.40
# [Episode 80] Mean Train Reward = -1479.41 | Mean Eval Reward = -1572.52
# [Episode 90] Mean Train Reward = -1551.97 | Mean Eval Reward = -1592.66
# [Episode 100] Mean Train Reward = -1504.56 | Mean Eval Reward = -1665.07
# [Episode 110] Mean Train Reward = -1535.24 | Mean Eval Reward = -1562.93
# [Episode 120] Mean Train Reward = -1528.59 | Mean Eval Reward = -1604.55
# [Episode 130] Mean Train Reward = -1554.92 | Mean Eval Reward = -1565.31
# [Episode 140] Mean Train Reward = -1499.13 | Mean Eval Reward = -1627.89
# [Episode 150] Mean Train Reward = -1546.82 | Mean Eval Reward = -1585.76
# Finished Run 3
# Executing Run 4
# [Episode 10] Mean Train Reward = -1360.63 | Mean Eval Reward = -1619.12
# [Episode 20] Mean Train Reward = -1056.37 | Mean Eval Reward = -1275.11
# [Episode 30] Mean Train Reward = -1380.34 | Mean Eval Reward = -1679.06
# [Episode 40] Mean Train Reward = -1389.21 | Mean Eval Reward = -1442.25
# [Episode 50] Mean Train Reward = -1175.11 | Mean Eval Reward = -1381.79
# [Episode 60] Mean Train Reward = -1281.72 | Mean Eval Reward = -1551.90
# [Episode 70] Mean Train Reward = -1612.39 | Mean Eval Reward = -1482.80
# [Episode 80] Mean Train Reward = -1551.07 | Mean Eval Reward = -1512.96
# [Episode 90] Mean Train Reward = -1186.21 | Mean Eval Reward = -1514.23
# [Episode 100] Mean Train Reward = -1357.29 | Mean Eval Reward = -1673.69
# [Episode 110] Mean Train Reward = -1186.54 | Mean Eval Reward = -1606.31
# [Episode 120] Mean Train Reward = -1170.13 | Mean Eval Reward = -1010.78
# [Episode 130] Mean Train Reward = -1358.74 | Mean Eval Reward = -1015.29
# [Episode 140] Mean Train Reward = -1406.41 | Mean Eval Reward = -1605.70
# [Episode 150] Mean Train Reward = -1542.43 | Mean Eval Reward = -1642.01
# Finished Run 4
# Executing Run 5
# [Episode 10] Mean Train Reward = -1333.04 | Mean Eval Reward = -1410.21
# [Episode 20] Mean Train Reward = -1281.89 | Mean Eval Reward = -1771.60
# [Episode 30] Mean Train Reward = -1066.31 | Mean Eval Reward = -1517.03
# [Episode 40] Mean Train Reward = -1548.61 | Mean Eval Reward = -1601.82
# [Episode 50] Mean Train Reward = -1429.63 | Mean Eval Reward = -1667.01
# [Episode 60] Mean Train Reward = -1584.39 | Mean Eval Reward = -1660.61
# [Episode 70] Mean Train Reward = -1660.65 | Mean Eval Reward = -1668.42
# [Episode 80] Mean Train Reward = -1608.08 | Mean Eval Reward = -1623.80
# [Episode 90] Mean Train Reward = -1655.61 | Mean Eval Reward = -1615.78
# [Episode 100] Mean Train Reward = -1563.16 | Mean Eval Reward = -1550.99
# [Episode 110] Mean Train Reward = -1518.10 | Mean Eval Reward = -1531.91
# [Episode 120] Mean Train Reward = -1600.23 | Mean Eval Reward = -1416.86
# [Episode 130] Mean Train Reward = -1534.28 | Mean Eval Reward = -1498.41
# [Episode 140] Mean Train Reward = -1481.26 | Mean Eval Reward = -1392.54
# [Episode 150] Mean Train Reward = -1387.93 | Mean Eval Reward = -1498.80
# Finished Run 5
#
# (Mean over last 50 epiosdes) Mean train rewards: -1495.07 | Mean Eval Score: -1507.52
# Finished Pendulum-v1

# %% [markdown]
# For REINFORCE, seeds used are 21, 22, 23, 24, 25.
#
# From the training logs, it is observed that reinforce is not quite powerfull (although i am using baseline as returns mean but not helping much in learning) and getting stuck in local optima.

# %% [markdown]
# # Vanilla Policy Gradient (VPG) [40 marks]

# %% [markdown]
# Implement the VPG algorithm. We have studied about VPG algorithm in the Lecture. Use the function definitions (given below).
#
# This class implements the VPG Agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment.
# Run one environment: 'Pendulum-v1'
#
#
# ```
# class VPG():
#     def __init__(env, seed, gamma, beta,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runVPG(self)
#     def trainAgent(self)
#     def trainPolicyNetwork(self, experiences)
#     def evaluateAgent(self)
# ```

# %%
# def __init__
class VPG():
    def __init__(self, env, seed, gamma, beta, optimizerFn, optimizerLR,
                MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                explorationStrategyTrainFn, explorationStrategyEvalFn):

        self.env = env
        self.seed = seed

        self.env.reset(seed=self.seed)
        self.env.action_space.seed(self.seed)
        self.env.observation_space.seed(self.seed)
        np.random.seed(seed=self.seed)
        random.seed(self.seed)
        torch.manual_seed(self.seed)

        self.gamma = gamma
        self.beta = beta
        self.optimizerFn = optimizerFn
        self.optimizerLR = optimizerLR
        self.epsilon = epsilon
        self.render = False

        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES

        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn

        inDim = self.env.observation_space.shape[0]
        outDim = self.env.action_space.shape[0]

        self.policy_network = createPolicyNetwork(inDim, outDim, hDim=[512, 324, 256])
        self.value_network = createValueNetwork(inDim, 1, hDim=[512, 324, 256])
        self.policyOptimizer = self.optimizerFn(self.policy_network.parameters(), lr=self.optimizerLR)
        self.valueOptimizer = self.optimizerFn(self.value_network.parameters(), lr=self.optimizerLR)

        self.initBookKeeping()

# %%
# def initBookKeeping
class VPG(VPG):
    def initBookKeeping(self):

        self.trainRewardsList = []
        self.evalRewardsList = []
        self.trainTimeList = []
        self.wallClockTimeList = []
        self.totalStepsList = []

        self.startTime = time.time()

# %%
# def performBookKeeping
class VPG(VPG):
    def performBookKeeping(self, train = True):

       currentTime = time.time()
       if train:
           trainTime = currentTime - self.startTime
           self.trainTimeList.append(trainTime)
       else :
           wallClock = currentTime - self.startTime
           self.wallClockTimeList.append(wallClock)

# %%
# def runVPG
class VPG(VPG):
    def runVPG(self):
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
        finalEvalReward = self.evaluateAgent()

        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward

# %%
# def trainAgent
class VPG(VPG):
    def trainAgent(self):
        for e in range(self.MAX_TRAIN_EPISODES):
            s, done = self.env.reset()
            rewards, logProbs = [], []
            entropies, values = [], []
            train_steps = 0
            while not done:
                a, logp_a, entropy_pa = self.explorationStrategyTrainFn(self.policy_network, s, self.env)
                state = torch.FloatTensor(s).unsqueeze(0)
                value = self.value_network(state)
                s, r, done, truncated, _ = self.env.step(a)
                done = done or truncated

                rewards.append(r)
                logProbs.append(logp_a)
                entropies.append(entropy_pa)
                values.append(value.squeeze())
                train_steps += 1

            self.totalStepsList.append(train_steps)
            self.trainRewardsList.append(np.sum(rewards))
            self.trainPolicyAndValueNetwork(rewards, logProbs, entropies, values)
            self.performBookKeeping(train = True)

            evalRmean, _ = self.evaluateAgent()
            self.evalRewardsList.append(evalRmean)
            self.performBookKeeping(train = False)
            if (e+1) % 10 == 0:
                print(f"[Episode {e+1}] Mean Train Reward = {np.sum(rewards):.2f} | Mean Eval Reward = {evalRmean:.2f}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList, self.wallClockTimeList, self.totalStepsList

# %%
# def trainPolicyNetwork
class VPG(VPG):
    def trainPolicyAndValueNetwork(self, rewards, logProbs, entropies, values):
        returns, gammas = getStepWiseReturnsAndDiscounts(self.gamma, rewards)
        logProbs = torch.stack(logProbs).squeeze()
        entropies = torch.stack(entropies).squeeze()
        values = torch.stack(values).squeeze()

        deltas = returns - values
        deltas = (deltas - deltas.mean()) / (deltas.std() + 1e-6)

        # same for here gammas shouldn't get multiplied explicitly but mentioend oion lecture notes
        baselineLoss = -1.0 * (gammas * deltas.detach() * logProbs).mean()
        entropyLoss = -1.0 * entropies.mean()
        policyLoss = baselineLoss + self.beta * entropyLoss

        self.policyOptimizer.zero_grad()
        policyLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_network.parameters(), MAX_GRAD_NORM_POLICY)
        self.policyOptimizer.step()

        valueLoss = 0.5 * (deltas ** 2)
        valueLoss = valueLoss.mean()
        self.valueOptimizer.zero_grad()
        valueLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.value_network.parameters(), MAX_GRAD_NORM_VALUE)
        self.valueOptimizer.step()

# %%
# def evaluateAgent
class VPG(VPG):
    def evaluateAgent(self, greedy = True):
        rewards = []
        for _ in range(self.MAX_EVAL_EPISODES):
            rs, done = 0, 0
            s, _ = self.env.reset()
            for _ in count():
                if greedy:
                    a = self.explorationStrategyEvalFn(self.policy_network, s, self.env)
                else:
                    a, _ = self.explorationStrategyTrainFn(self.policy_network, s, self.env)

                s, r, done, truncated, _ = self.env.step(a)
                rs += r
                if done or truncated:
                    rewards.append(rs)
                    break

        rewards = np.array(rewards)
        return rewards.mean(), rewards.std()

# %%
# evaluating the VPG agent on multiple continuous-control

# Environments used in this experiment
vpg_env_name = "Pendulum-v1"

quantityDictVPG = {}

# Number of independent training runs per environment
num_runs = 5

all_train_rewards = []
all_eval_rewards = []
all_train_times = []
all_total_steps = []
all_wall_times = []

# For each environment:
print(f"\n===== Environment: {vpg_env_name} =====")

for run in range(num_runs):
    print(f"Executing Run {run+1}  ")

    # Create environment
    env = gym.make(vpg_env_name)

    # Initialize SAC agent
    agent = VPG(
        env=env, seed=base_seed+run, gamma=gamma, beta=beta,
        optimizerFn=optimizerFn, optimizerLR=optimizerLR,
        MAX_TRAIN_EPISODES=MAX_TRAIN_EPISODES,
        MAX_EVAL_EPISODES=MAX_EVAL_EPISODES,
        explorationStrategyTrainFn=selectAction,
        explorationStrategyEvalFn=selectGreedyAction
    )

    # Run training
    train_rewards, train_times, eval_rewards, wall_clock_times, total_steps, final_eval_reward = agent.runVPG()
    print(f"Finished Run {run+1}")

    all_train_rewards.append(train_rewards)
    all_eval_rewards.append(eval_rewards)
    all_train_times.append(train_times)
    all_wall_times.append(wall_clock_times)
    all_total_steps.append(total_steps)

quantityDictVPG[vpg_env_name] = {
    "Mean Train Rewards": {
        "VPG": all_train_rewards
    },
    "Mean Eval Rewards": {
        "VPG": all_eval_rewards
    },
    "Train Time (in sec)": {
        "VPG": all_train_times
    },
    "Wall Clock Time (in sec)": {
        "VPG": all_wall_times
    },
    "Total Steps": {
        "VPG": all_total_steps
    }
}

# Compute Statistics
train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"\n(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
print(f"Finished {vpg_env_name}")
# Out:
# ===== Environment: Pendulum-v1 =====
# Executing Run 1
# [Episode 10] Mean Train Reward = -1305.58 | Mean Eval Reward = -1417.43
# [Episode 20] Mean Train Reward = -1389.19 | Mean Eval Reward = -1598.64
# [Episode 30] Mean Train Reward = -1390.42 | Mean Eval Reward = -1669.32
# [Episode 40] Mean Train Reward = -1482.30 | Mean Eval Reward = -1658.46
# [Episode 50] Mean Train Reward = -1405.28 | Mean Eval Reward = -1685.33
# [Episode 60] Mean Train Reward = -1257.88 | Mean Eval Reward = -1577.96
# [Episode 70] Mean Train Reward = -1565.42 | Mean Eval Reward = -1578.36
# [Episode 80] Mean Train Reward = -1402.11 | Mean Eval Reward = -1611.57
# [Episode 90] Mean Train Reward = -1549.56 | Mean Eval Reward = -1530.88
# [Episode 100] Mean Train Reward = -1564.92 | Mean Eval Reward = -1596.32
# [Episode 110] Mean Train Reward = -1551.34 | Mean Eval Reward = -1662.36
# [Episode 120] Mean Train Reward = -1561.79 | Mean Eval Reward = -1659.23
# [Episode 130] Mean Train Reward = -1537.19 | Mean Eval Reward = -1674.77
# [Episode 140] Mean Train Reward = -1569.54 | Mean Eval Reward = -1677.05
# [Episode 150] Mean Train Reward = -1421.13 | Mean Eval Reward = -1584.25
# Finished Run 1
# Executing Run 2
# [Episode 10] Mean Train Reward = -1036.92 | Mean Eval Reward = -1393.33
# [Episode 20] Mean Train Reward = -1295.55 | Mean Eval Reward = -1540.84
# [Episode 30] Mean Train Reward = -1537.22 | Mean Eval Reward = -1589.76
# [Episode 40] Mean Train Reward = -1363.43 | Mean Eval Reward = -1541.14
# [Episode 50] Mean Train Reward = -1477.92 | Mean Eval Reward = -1618.41
# [Episode 60] Mean Train Reward = -1283.04 | Mean Eval Reward = -1413.91
# [Episode 70] Mean Train Reward = -1324.53 | Mean Eval Reward = -1538.27
# [Episode 80] Mean Train Reward = -1420.61 | Mean Eval Reward = -1464.18
# [Episode 90] Mean Train Reward = -1422.74 | Mean Eval Reward = -1549.33
# [Episode 100] Mean Train Reward = -1168.54 | Mean Eval Reward = -1286.60
# [Episode 110] Mean Train Reward = -1504.31 | Mean Eval Reward = -1451.33
# [Episode 120] Mean Train Reward = -1411.88 | Mean Eval Reward = -1209.22
# [Episode 130] Mean Train Reward = -1149.22 | Mean Eval Reward = -1606.02
# [Episode 140] Mean Train Reward = -1446.90 | Mean Eval Reward = -1521.43
# [Episode 150] Mean Train Reward = -1170.18 | Mean Eval Reward = -1288.37
# Finished Run 2
# Executing Run 3
# [Episode 10] Mean Train Reward = -1322.83 | Mean Eval Reward = -1365.39
# [Episode 20] Mean Train Reward = -1561.85 | Mean Eval Reward = -1732.72
# [Episode 30] Mean Train Reward = -1555.91 | Mean Eval Reward = -1622.46
# [Episode 40] Mean Train Reward = -1567.23 | Mean Eval Reward = -1230.33
# [Episode 50] Mean Train Reward = -1224.12 | Mean Eval Reward = -1224.00
# [Episode 60] Mean Train Reward = -1557.72 | Mean Eval Reward = -1685.07
# [Episode 70] Mean Train Reward = -1171.74 | Mean Eval Reward = -1331.49
# [Episode 80] Mean Train Reward = -1230.29 | Mean Eval Reward = -1580.01
# [Episode 90] Mean Train Reward = -915.06 | Mean Eval Reward = -1118.11
# [Episode 100] Mean Train Reward = -1543.49 | Mean Eval Reward = -1671.60
# [Episode 110] Mean Train Reward = -1563.90 | Mean Eval Reward = -1493.23
# [Episode 120] Mean Train Reward = -1443.61 | Mean Eval Reward = -1175.86
# [Episode 130] Mean Train Reward = -1157.40 | Mean Eval Reward = -1571.47
# [Episode 140] Mean Train Reward = -1359.79 | Mean Eval Reward = -1642.44
# [Episode 150] Mean Train Reward = -1262.71 | Mean Eval Reward = -1430.45
# Finished Run 3
# Executing Run 4
# [Episode 10] Mean Train Reward = -1624.68 | Mean Eval Reward = -1814.53
# [Episode 20] Mean Train Reward = -1779.29 | Mean Eval Reward = -1879.07
# [Episode 30] Mean Train Reward = -1521.61 | Mean Eval Reward = -1874.60
# [Episode 40] Mean Train Reward = -1445.87 | Mean Eval Reward = -1843.33
# [Episode 50] Mean Train Reward = -1563.52 | Mean Eval Reward = -1669.50
# [Episode 60] Mean Train Reward = -1727.21 | Mean Eval Reward = -1690.18
# [Episode 70] Mean Train Reward = -1705.95 | Mean Eval Reward = -1690.76
# [Episode 80] Mean Train Reward = -1593.39 | Mean Eval Reward = -1646.50
# [Episode 90] Mean Train Reward = -1319.94 | Mean Eval Reward = -1596.75
# [Episode 100] Mean Train Reward = -1330.04 | Mean Eval Reward = -1412.82
# [Episode 110] Mean Train Reward = -1546.21 | Mean Eval Reward = -1587.09
# [Episode 120] Mean Train Reward = -1548.99 | Mean Eval Reward = -1653.74
# [Episode 130] Mean Train Reward = -1534.48 | Mean Eval Reward = -1527.29
# [Episode 140] Mean Train Reward = -1084.12 | Mean Eval Reward = -1604.23
# [Episode 150] Mean Train Reward = -1311.65 | Mean Eval Reward = -842.39
# Finished Run 4
# Executing Run 5
# [Episode 10] Mean Train Reward = -1389.10 | Mean Eval Reward = -1515.35
# [Episode 20] Mean Train Reward = -1435.82 | Mean Eval Reward = -1345.83
# [Episode 30] Mean Train Reward = -1362.17 | Mean Eval Reward = -1655.73
# [Episode 40] Mean Train Reward = -1562.20 | Mean Eval Reward = -1193.02
# [Episode 50] Mean Train Reward = -1379.21 | Mean Eval Reward = -1321.42
# [Episode 60] Mean Train Reward = -1555.89 | Mean Eval Reward = -1639.62
# [Episode 70] Mean Train Reward = -1330.29 | Mean Eval Reward = -1452.24
# [Episode 80] Mean Train Reward = -1558.51 | Mean Eval Reward = -1673.79
# [Episode 90] Mean Train Reward = -1248.72 | Mean Eval Reward = -1172.25
# [Episode 100] Mean Train Reward = -1186.65 | Mean Eval Reward = -1649.83
# [Episode 110] Mean Train Reward = -1539.65 | Mean Eval Reward = -1639.47
# [Episode 120] Mean Train Reward = -1299.37 | Mean Eval Reward = -1558.33
# [Episode 130] Mean Train Reward = -1564.10 | Mean Eval Reward = -1374.33
# [Episode 140] Mean Train Reward = -1057.83 | Mean Eval Reward = -1640.37
# [Episode 150] Mean Train Reward = -1192.18 | Mean Eval Reward = -1329.62
# Finished Run 5
#
# (Mean over last 50 epiosdes) Mean train rewards: -1433.48 | Mean Eval Score: -1477.24
# Finished Pendulum-v1

# %% [markdown]
# For VPG, seeds used are 21, 22, 23, 24, 25.
#
# VPG also couldn't ble to learn well on this pendulum environment, I tried even for 1000 episdoes but nothing changes. it still suffers from premature convergence. But as can be observed from trainign logs, VPG is able to make slighylt better reward than reinforce because of introcing entropy loss in the total loss estimation, which avoids making the peaky distrubtion too early which leads to better exploration.

# %% [markdown]
# # Asynchronous Advantange Actor-Critic (A3C) [50 marks]
# <a id="a3c"></a>
#
# A3C (Mnih et al., 2016) was one of the first successful deep RL algorithms to train on CPU using parallel workers. Each worker maintains its own copy of the environment and policy, collects experience independently, and asynchronously pushes gradient updates to a shared global network.
#
# **Key ideas:**
# - Multiple worker processes each interact with their own environment copy.
# - Each worker computes gradients locally and applies them to a **shared global network** asynchronously (no waiting for other workers).
# - The asynchronous updates provide natural exploration diversity (different workers explore different parts of the state space).
# - Uses n-step returns and advantage estimation similar to A2C.
#
# **Update rule per worker:**
# $$\theta \leftarrow \theta + \alpha \nabla_\theta \log \pi_\theta(a_t|s_t) \cdot A(s_t, a_t)$$
#
# where the gradient is computed by the worker and applied to the shared $\theta$.
#
# **Note:** True A3C requires `multiprocessing` with shared memory. Below we implement it using `torch.multiprocessing` with shared parameters.
#
# ```
# class SharedAdam(optim.Adam)   # Adam optimizer with shared state
# class A3CAgent(nn.Module)      # Same architecture as A2C
# def a3c_worker(...)            # Worker process
# def train_a3c(...)             # Main launcher
# ```

# %%
# ======================================================================
# A3C Implementation
# ======================================================================

import torch.multiprocessing as mp
from queue import Empty

# A3C Hyperparameters
a3c_gym_id = 'Hopper-v4'
a3c_learning_rate = 5e-5
a3c_gamma = 0.99
a3c_num_workers = 8                          # Number of asynchronous worker processes
a3c_num_steps = 20                           # n-step return length per worker
a3c_max_episodes_per_worker = 2000
a3c_ent_coef = 1e-5
a3c_vf_coef = 0.48
a3c_max_grad_norm = 0.5

# %%
# i created this method for checcking the evaluation reward trend in A3C and A2C
# although not mentioned to plot it but for but understanding purpose doing it

def evaluate_policy(agent, env_id, episodes=1):
    env = gym.make(env_id)
    rewards = []

    for _ in range(episodes):
        s, _ = env.reset()
        done = False
        total_reward = 0

        while not done:
            with torch.no_grad():
                s_tensor = torch.FloatTensor(s).unsqueeze(0)
                action, _, _, _ = agent.get_action_and_value(s_tensor)

            if agent.is_discrete:
                action = action.item()
            else:
                action_np = action.squeeze(0).detach().cpu().numpy()
                action_np = np.tanh(action_np)
                action_np = np.clip(action_np, env.action_space.low, env.action_space.high)

            s, r, done, truncated, _ = env.step(action_np)
            done = done or truncated
            total_reward += r

        rewards.append(total_reward)

    return np.mean(rewards)

# %%
# ======================================================================
# SharedAdam: Adam optimizer with shared state across processes
# ======================================================================
# Standard Adam stores its internal state (moment estimates) per-process.
# For A3C, we need the optimizer state to be in shared memory so that
# all worker processes update the same momentum buffers.

class SharedAdam(torch.optim.Adam):
    def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8):
        super().__init__(params, lr=lr, betas=betas, eps=eps)

        for group in self.param_groups:
            for p in group['params']:
                state = self.state[p]
                state['step'] = torch.zeros(1).share_memory_()
                state['exp_avg'] = torch.zeros_like(p.data).share_memory_()
                state['exp_avg_sq'] = torch.zeros_like(p.data).share_memory_()

# %%
# ==============================================================
# A3C Agent
# ==============================================================

class A3CAgent(nn.Module):
    """
    A3C agent with separate actor and critic networks.
    Supports both discrete and continuous action spaces.
    """

    def __init__(self, obs_dim, act_dim, is_discrete=False):
        """
        Initialize actor and critic networks.
        obs_dim     : Dimension of observation space
        act_dim     : Dimension of action space
        is_discrete : Whether the action space is discrete
        """

        # Your code goes here
        super(A3CAgent, self).__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.is_discrete = is_discrete

        self.hDim = [512, 324, 256]
        self.actor_network = createPolicyNetwork(obs_dim, act_dim, hDim=self.hDim)
        self.critic_network = createValueNetwork(obs_dim, 1, hDim=self.hDim)

        if not self.is_discrete:
            self.actor_log_std = nn.Parameter(torch.zeros(act_dim))


    def get_value(self, x):
        """
        Return the value estimate for a given state using the critic.
        """
        return self.critic_network(x)


    def get_action_and_value(self, x, action=None):
        """
        Compute action, log probability, entropy, and value.

        For discrete actions:
            create a categorical distribution from actor logits.

        For continuous actions:
            create a normal distribution using mean and std.

        If action is None, sample from the distribution.
        Return action, log probability, entropy, and value.
        """
        value = self.get_value(x)

        if self.is_discrete:
            logits = self.actor_network(x)
            dist = torch.distributions.Categorical(logits=logits)
            if action is None:
                action = dist.sample()
            else:
                action = action.long().squeeze()
            log_prob = dist.log_prob(action)
            entropy = dist.entropy()

        else:
            mu = self.actor_network(x)

            log_std = torch.clamp(self.actor_log_std, -20, 2)
            std = torch.exp(log_std).unsqueeze(0).expand_as(mu)
            dist = torch.distributions.Normal(mu, std)

            if action is None:
                action = dist.sample()
            else:
                action = action.float()
            log_prob = dist.log_prob(action).sum(dim=-1)
            entropy = dist.entropy().sum(dim=-1)

        return action, log_prob, entropy, value

# %%
# A3C Worker (truly parallel via torch.multiprocessing)

def a3c_worker(worker_id, global_agent, global_optimizer, grad_lock,
               env_id, seed, num_episodes,
               gamma, num_steps, ent_coef, vf_coef, max_grad_norm,
               result_queue):
    """
    A3C worker — runs as a separate OS process.

    Each worker independently:
      1. Syncs local weights from the shared global network.
      2. Collects a rollout of num_steps transitions.
      3. Computes n-step returns and advantage.
      4. Computes gradients on its LOCAL network copy.
      5. Pushes those gradients to the GLOBAL network (under lock).
      6. Sends episode reward to main process via result_queue.

    The grad_lock serialises gradient push + optimizer.step() to prevent
    two workers from corrupting each other's gradients.
    """
    env = gym.make(env_id)
    env.reset(seed=seed*10 + worker_id)
    torch.manual_seed(seed*10 + worker_id)
    np.random.seed(seed*10 + worker_id)
    env.action_space.seed(seed*10 + worker_id)
    env.observation_space.seed(seed*10 + worker_id)
    random.seed(seed*10 + worker_id)

    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
    action_high = env.action_space.high if not is_discrete else None
    action_low = env.action_space.low if not is_discrete else None

    local_agent = A3CAgent(obs_dim, act_dim, is_discrete)

    for episode in range(num_episodes):
        state, _ = env.reset()
        train_er = 0
        step_count = 0

        log_probs = []
        values = []
        rewards = []
        entropies = []

        done = False
        truncated = False

        local_agent.load_state_dict(global_agent.state_dict())
        while not (done or truncated):
            for step in range(num_steps):
                state_tensor = torch.FloatTensor(state).unsqueeze(0)
                action, log_prob, entropy, value = local_agent.get_action_and_value(state_tensor)

                if is_discrete:
                    action_np = action.item()
                else:
                    action_np = action.squeeze(0).detach().cpu().numpy()
                    action_np = np.clip(action_np, env.action_space.low, env.action_space.high)

                next_state, reward, done, truncated, _ = env.step(action_np)

                log_probs.append(log_prob)
                values.append(value)
                rewards.append(reward)
                entropies.append(entropy)

                train_er += reward
                step_count += 1
                state = next_state

                if done or truncated:
                    break

            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            with torch.no_grad():
                next_value = local_agent.get_value(state_tensor)
                if done or truncated:
                    next_value = torch.tensor([[0.0]])

            returns, gammas = getStepWiseReturnsAndDiscounts(gamma, rewards, next_value)
            returns = returns.view(-1, 1)
            gammas = gammas.view(-1, 1)

            values_tensor = torch.cat(values)
            log_probs_tensor = torch.cat(log_probs)
            entropies_tensor = torch.stack(entropies)

            advantages = returns - values_tensor

            policy_loss = -(gammas * log_probs_tensor * advantages.detach()).mean()
            value_loss = 0.5 * advantages.pow(2).mean()
            entropy_loss = entropies_tensor.mean()

            total_loss = policy_loss - ent_coef * entropy_loss + vf_coef * value_loss

            local_agent.zero_grad()
            total_loss.backward()
            nn.utils.clip_grad_norm_(local_agent.parameters(), max_grad_norm)

            with grad_lock:
                global_optimizer.zero_grad()
                for local_p, global_p in zip(local_agent.parameters(), global_agent.parameters()):
                    if global_p.grad is None:
                        global_p.grad = local_p.grad.clone()
                    else:
                        global_p.grad += local_p.grad
                global_optimizer.step()

            log_probs = []
            values = []
            rewards = []
            entropies = []

        result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))

    env.close()

# %%
# A3C Launcher — spawns truly parallel worker processes

def train_a3c(env_id=a3c_gym_id, seed=base_seed, num_workers=a3c_num_workers,
              episodes_per_worker=a3c_max_episodes_per_worker,
              gamma=a3c_gamma, num_steps=a3c_num_steps, lr=a3c_learning_rate,
              ent_coef=a3c_ent_coef, vf_coef=a3c_vf_coef,
              max_grad_norm=a3c_max_grad_norm):
    """
    Launches A3C training with truly parallel worker processes.

    1. Creates global_agent in shared memory.
    2. Creates SharedAdam (optimizer state also in shared memory).
    3. Creates mp.Lock for gradient push serialisation.
    4. Spawns num_workers mp.Process instances (all start simultaneously).
    5. Main process collects rewards from Queue while workers train.
    6. p.join() waits for all workers to finish.
    """

    # Your code goes here
    env = gym.make(env_id)
    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
    env.close()

    global_agent = A3CAgent(obs_dim, act_dim, is_discrete=is_discrete)
    global_agent.share_memory()
    global_optimizer = SharedAdam(global_agent.parameters(), lr=lr)
    eval_agent = A3CAgent(obs_dim, act_dim, is_discrete=is_discrete)

    grad_lock = mp.Lock()
    result_queue = mp.Queue()

    print(f"Training A3C on {env_id}")
    print(f"Workers: {num_workers} | Episodes Per Worker: {episodes_per_worker}")

    processes = []
    for worker_id in range(num_workers):
        p = mp.Process(
            target=a3c_worker,
            args=(
                worker_id, global_agent, global_optimizer,
                grad_lock, env_id, seed, episodes_per_worker,
                gamma, num_steps, ent_coef, vf_coef,
                max_grad_norm, result_queue
            )
        )
        p.start()
        processes.append(p)

    total_episodes = num_workers * episodes_per_worker
    episodes = 0
    global_steps = 0

    train_rewards = []
    global_steps_list = []
    total_steps_list = []
    eval_rewards = []

    trg = []
    erg = []

    while episodes < total_episodes:
        while True:
            try:
                worker_id, train_er, e_step, e_loss = result_queue.get_nowait()
                global_steps += e_step
                episodes += 1
                train_rewards.append((episodes, train_er))
                global_steps_list.append((episodes, global_steps))
                total_steps_list.append((episodes, e_step))
                trg.append((int(global_steps), float(train_er)))

                if episodes % 20 == 0:
                    eval_agent.load_state_dict(global_agent.state_dict())
                    eval_r = evaluate_policy(eval_agent, env_id)
                    eval_rewards.append((episodes, eval_r))
                    erg.append((int(global_steps), float(eval_r)))

                    print(f"Worker {worker_id} | Episode {episodes} | Step Counts: {e_step:.0f} | Train Reward: {train_er:.2f} | "
                          f"Global Steps: {global_steps} | Loss: {e_loss:.2f}")
            except Empty:
                break

    for p in processes:
        p.join()

    while not result_queue.empty():
        worker_id, train_er, e_step, e_loss = result_queue.get_nowait()
        global_steps += e_step
        episodes += 1
        train_rewards.append((episodes, train_er))
        global_steps_list.append((episodes, global_steps))
        total_steps_list.append((episodes, e_step))
        trg.append((int(global_steps), float(train_er)))

        if episodes % 20 == 0:
            eval_agent.load_state_dict(global_agent.state_dict())
            eval_r = evaluate_policy(eval_agent, env_id)
            eval_rewards.append((episodes, eval_r))
            erg.append((int(global_steps), float(eval_r)))

            print(f"Worker {worker_id} | Episode {episodes} | Step Counts: {e_step:.0f} | Train Reward: {train_er:.2f} | "
                          f"Global Steps: {global_steps} | Loss: {e_loss:.2f}")


    _, train_rw = zip(*train_rewards)
    _, eval_rw = zip(*eval_rewards)
    print(f"\nTraining Done!\nMean Train Reward (last 40 episodes): {np.mean(train_rw[-40:]):.2f} | Mean Eval Reward (last 40 episodes): {np.mean(eval_rw[-40:]):.2f}")

    return train_rewards, total_steps_list, eval_rewards, global_steps_list, trg, erg

# %%
# Run A3C on all 3 environments
a3c_all_results = {}

# Plot all the graphs
# Your code goes here

rewards, episode_steps, eval_rewards, global_steps, trg, erg = train_a3c()
a3c_all_results[a3c_gym_id] = {
    "Train Rewards": {"A3C": [rewards]},
    "Total Steps": {"A3C": [episode_steps]},
    "Eval Rewards": {"A3C": [eval_rewards]},
    "Global Steps": {"A3C": [global_steps]},
    "Train Rewards (over global steps)": {"A3C": [trg]},
    "Eval Rewards (over global steps)": {"A3C": [erg]}
}

# Seeds used for this experiment are [210, 211, 212, 213, 214, 215, 216, 217]
# Out:
# Training A3C on Hopper-v4
# Workers: 8 | Episodes Per Worker: 2000
# /tmp/ipykernel_10238/1344311515.py:116: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))
# /tmp/ipykernel_10238/1344311515.py:116: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))
# /tmp/ipykernel_10238/1344311515.py:116: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))
# /tmp/ipykernel_10238/1344311515.py:116: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))
# /tmp/ipykernel_10238/1344311515.py:116: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))
# /tmp/ipykernel_10238/1344311515.py:116: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))
# /tmp/ipykernel_10238/1344311515.py:116: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))
# /tmp/ipykernel_10238/1344311515.py:116: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))
# Worker 4 | Episode 20 | Step Counts: 11 | Train Reward: 9.08 | Global Steps: 205 | Loss: 21.42
# Worker 7 | Episode 40 | Step Counts: 8 | Train Reward: 6.20 | Global Steps: 400 | Loss: 10.29
# Worker 7 | Episode 60 | Step Counts: 8 | Train Reward: 5.22 | Global Steps: 588 | Loss: 6.96
# Worker 6 | Episode 80 | Step Counts: 12 | Train Reward: 10.98 | Global Steps: 794 | Loss: 27.19
# Worker 3 | Episode 100 | Step Counts: 8 | Train Reward: 5.96 | Global Steps: 1002 | Loss: 7.71
# Worker 6 | Episode 120 | Step Counts: 7 | Train Reward: 5.23 | Global Steps: 1198 | Loss: 4.70
# Worker 7 | Episode 140 | Step Counts: 10 | Train Reward: 8.24 | Global Steps: 1380 | Loss: 12.29
# Worker 2 | Episode 160 | Step Counts: 10 | Train Reward: 7.94 | Global Steps: 1567 | Loss: 8.54
# Worker 1 | Episode 180 | Step Counts: 7 | Train Reward: 5.36 | Global Steps: 1758 | Loss: 3.87
# Worker 2 | Episode 200 | Step Counts: 13 | Train Reward: 8.27 | Global Steps: 1949 | Loss: 1.24
# Worker 1 | Episode 220 | Step Counts: 8 | Train Reward: 6.47 | Global Steps: 2147 | Loss: 1.57
# Worker 5 | Episode 240 | Step Counts: 12 | Train Reward: 9.25 | Global Steps: 2372 | Loss: 1.46
# Worker 1 | Episode 260 | Step Counts: 24 | Train Reward: 14.36 | Global Steps: 2629 | Loss: -6.46
# Worker 4 | Episode 280 | Step Counts: 16 | Train Reward: 13.19 | Global Steps: 2888 | Loss: 6.24
# Worker 6 | Episode 300 | Step Counts: 16 | Train Reward: 13.04 | Global Steps: 3194 | Loss: 2.00
# Worker 1 | Episode 320 | Step Counts: 10 | Train Reward: 8.59 | Global Steps: 3519 | Loss: -1.59
# Worker 6 | Episode 340 | Step Counts: 11 | Train Reward: 9.40 | Global Steps: 3852 | Loss: -1.06
# Worker 3 | Episode 360 | Step Counts: 12 | Train Reward: 10.93 | Global Steps: 4209 | Loss: -1.85
# Worker 5 | Episode 380 | Step Counts: 10 | Train Reward: 9.05 | Global Steps: 4644 | Loss: -8.27
# Worker 1 | Episode 400 | Step Counts: 31 | Train Reward: 48.14 | Global Steps: 5070 | Loss: -7.21
# Worker 3 | Episode 420 | Step Counts: 44 | Train Reward: 67.22 | Global Steps: 5975 | Loss: -16.51
# Worker 0 | Episode 440 | Step Counts: 37 | Train Reward: 53.59 | Global Steps: 7059 | Loss: 5.12
# Worker 7 | Episode 460 | Step Counts: 33 | Train Reward: 37.03 | Global Steps: 8317 | Loss: 53.22
# Worker 2 | Episode 480 | Step Counts: 39 | Train Reward: 55.83 | Global Steps: 9553 | Loss: 50.53
# Worker 7 | Episode 500 | Step Counts: 104 | Train Reward: 213.99 | Global Steps: 10880 | Loss: 294.07
# Worker 6 | Episode 520 | Step Counts: 95 | Train Reward: 173.44 | Global Steps: 12443 | Loss: 396.89
# Worker 3 | Episode 540 | Step Counts: 57 | Train Reward: 99.95 | Global Steps: 13999 | Loss: 783.52
# Worker 6 | Episode 560 | Step Counts: 97 | Train Reward: 215.56 | Global Steps: 15752 | Loss: 1329.56
# Worker 6 | Episode 580 | Step Counts: 92 | Train Reward: 207.48 | Global Steps: 17513 | Loss: 3068.99
# Worker 5 | Episode 600 | Step Counts: 91 | Train Reward: 207.04 | Global Steps: 18949 | Loss: 4148.01
# Worker 2 | Episode 620 | Step Counts: 37 | Train Reward: 61.74 | Global Steps: 20538 | Loss: 5001.71
# Worker 1 | Episode 640 | Step Counts: 89 | Train Reward: 203.88 | Global Steps: 22240 | Loss: 7218.13
# Worker 7 | Episode 660 | Step Counts: 105 | Train Reward: 218.25 | Global Steps: 24092 | Loss: 7948.82
# Worker 5 | Episode 680 | Step Counts: 100 | Train Reward: 215.53 | Global Steps: 25772 | Loss: 9575.01
# Worker 0 | Episode 700 | Step Counts: 86 | Train Reward: 188.21 | Global Steps: 27330 | Loss: 10938.23
# Worker 5 | Episode 720 | Step Counts: 62 | Train Reward: 115.39 | Global Steps: 28922 | Loss: 13932.65
# Worker 0 | Episode 740 | Step Counts: 106 | Train Reward: 192.05 | Global Steps: 30571 | Loss: 9751.83
# Worker 7 | Episode 760 | Step Counts: 64 | Train Reward: 122.17 | Global Steps: 32278 | Loss: 12112.11
# Worker 5 | Episode 780 | Step Counts: 91 | Train Reward: 201.52 | Global Steps: 33968 | Loss: 8540.15
# Worker 4 | Episode 800 | Step Counts: 34 | Train Reward: 55.37 | Global Steps: 35476 | Loss: 9789.10
# Worker 5 | Episode 820 | Step Counts: 90 | Train Reward: 203.58 | Global Steps: 37220 | Loss: 4073.02
# Worker 6 | Episode 840 | Step Counts: 66 | Train Reward: 134.09 | Global Steps: 38795 | Loss: 4439.17
# Worker 3 | Episode 860 | Step Counts: 91 | Train Reward: 201.99 | Global Steps: 40184 | Loss: 308.77
# Worker 6 | Episode 880 | Step Counts: 89 | Train Reward: 201.51 | Global Steps: 41763 | Loss: 62.62
# Worker 0 | Episode 900 | Step Counts: 90 | Train Reward: 183.60 | Global Steps: 43413 | Loss: 46.23
# Worker 4 | Episode 920 | Step Counts: 71 | Train Reward: 136.74 | Global Steps: 44874 | Loss: 81.53
# Worker 4 | Episode 940 | Step Counts: 88 | Train Reward: 196.33 | Global Steps: 46409 | Loss: 75.01
# Worker 5 | Episode 960 | Step Counts: 65 | Train Reward: 119.48 | Global Steps: 47904 | Loss: 53.94
# Worker 3 | Episode 980 | Step Counts: 83 | Train Reward: 159.73 | Global Steps: 49389 | Loss: -10.92
# Worker 2 | Episode 1000 | Step Counts: 86 | Train Reward: 172.03 | Global Steps: 51021 | Loss: -9.61
# Worker 1 | Episode 1020 | Step Counts: 50 | Train Reward: 85.93 | Global Steps: 52625 | Loss: 487.61
# Worker 7 | Episode 1040 | Step Counts: 90 | Train Reward: 174.96 | Global Steps: 54272 | Loss: -7.87
# Worker 5 | Episode 1060 | Step Counts: 83 | Train Reward: 160.94 | Global Steps: 55798 | Loss: -18.35
# Worker 4 | Episode 1080 | Step Counts: 88 | Train Reward: 182.96 | Global Steps: 57436 | Loss: -17.31
# Worker 7 | Episode 1100 | Step Counts: 93 | Train Reward: 196.82 | Global Steps: 59055 | Loss: -1.76
# Worker 2 | Episode 1120 | Step Counts: 95 | Train Reward: 161.14 | Global Steps: 60440 | Loss: 468.76
# Worker 0 | Episode 1140 | Step Counts: 68 | Train Reward: 129.93 | Global Steps: 62106 | Loss: 451.64
# Worker 5 | Episode 1160 | Step Counts: 102 | Train Reward: 193.27 | Global Steps: 63413 | Loss: 2.38
# Worker 2 | Episode 1180 | Step Counts: 95 | Train Reward: 212.71 | Global Steps: 65117 | Loss: -3.42
# Worker 3 | Episode 1200 | Step Counts: 86 | Train Reward: 178.33 | Global Steps: 67008 | Loss: 19.12
# Worker 5 | Episode 1220 | Step Counts: 86 | Train Reward: 155.46 | Global Steps: 68692 | Loss: 203.46
# Worker 3 | Episode 1240 | Step Counts: 28 | Train Reward: 47.58 | Global Steps: 70001 | Loss: 1534.08
# Worker 0 | Episode 1260 | Step Counts: 52 | Train Reward: 88.71 | Global Steps: 71279 | Loss: 505.13
# Worker 4 | Episode 1280 | Step Counts: 96 | Train Reward: 201.69 | Global Steps: 72621 | Loss: 23.55
# Worker 1 | Episode 1300 | Step Counts: 99 | Train Reward: 212.06 | Global Steps: 74177 | Loss: -0.68
# Worker 7 | Episode 1320 | Step Counts: 76 | Train Reward: 148.10 | Global Steps: 75667 | Loss: 67.48
# Worker 0 | Episode 1340 | Step Counts: 104 | Train Reward: 204.36 | Global Steps: 77529 | Loss: -11.47
# Worker 6 | Episode 1360 | Step Counts: 88 | Train Reward: 183.10 | Global Steps: 79241 | Loss: 49.61
# Worker 6 | Episode 1380 | Step Counts: 40 | Train Reward: 68.04 | Global Steps: 80933 | Loss: 1410.15
# Worker 5 | Episode 1400 | Step Counts: 95 | Train Reward: 194.04 | Global Steps: 82792 | Loss: 23.46
# Worker 3 | Episode 1420 | Step Counts: 101 | Train Reward: 222.59 | Global Steps: 84517 | Loss: -6.30
# Worker 1 | Episode 1440 | Step Counts: 37 | Train Reward: 62.34 | Global Steps: 86396 | Loss: 1991.20
# Worker 7 | Episode 1460 | Step Counts: 96 | Train Reward: 218.01 | Global Steps: 87910 | Loss: 97.80
# Worker 7 | Episode 1480 | Step Counts: 99 | Train Reward: 222.89 | Global Steps: 89363 | Loss: 104.81
# Worker 3 | Episode 1500 | Step Counts: 37 | Train Reward: 61.67 | Global Steps: 91117 | Loss: 2955.56
# Worker 5 | Episode 1520 | Step Counts: 106 | Train Reward: 210.62 | Global Steps: 92764 | Loss: 671.79
# Worker 2 | Episode 1540 | Step Counts: 91 | Train Reward: 154.37 | Global Steps: 94719 | Loss: 105.67
# Worker 3 | Episode 1560 | Step Counts: 101 | Train Reward: 207.54 | Global Steps: 96474 | Loss: 31.99
# Worker 3 | Episode 1580 | Step Counts: 103 | Train Reward: 211.22 | Global Steps: 98480 | Loss: -16.64
# Worker 2 | Episode 1600 | Step Counts: 98 | Train Reward: 197.18 | Global Steps: 100308 | Loss: -14.92
# Worker 3 | Episode 1620 | Step Counts: 72 | Train Reward: 123.47 | Global Steps: 102128 | Loss: 647.20
# Worker 6 | Episode 1640 | Step Counts: 67 | Train Reward: 126.88 | Global Steps: 104250 | Loss: 534.45
# Worker 7 | Episode 1660 | Step Counts: 104 | Train Reward: 205.24 | Global Steps: 106216 | Loss: 30.95
# Worker 4 | Episode 1680 | Step Counts: 102 | Train Reward: 216.78 | Global Steps: 108133 | Loss: -15.32
# Worker 1 | Episode 1700 | Step Counts: 90 | Train Reward: 190.28 | Global Steps: 109719 | Loss: 204.05
# Worker 5 | Episode 1720 | Step Counts: 85 | Train Reward: 183.37 | Global Steps: 111568 | Loss: -9.48
# Worker 1 | Episode 1740 | Step Counts: 88 | Train Reward: 195.58 | Global Steps: 113430 | Loss: -2.16
# Worker 3 | Episode 1760 | Step Counts: 91 | Train Reward: 209.19 | Global Steps: 115243 | Loss: 83.96
# Worker 6 | Episode 1780 | Step Counts: 94 | Train Reward: 209.82 | Global Steps: 117084 | Loss: -12.66
# Worker 7 | Episode 1800 | Step Counts: 98 | Train Reward: 213.87 | Global Steps: 119044 | Loss: 29.39
# Worker 4 | Episode 1820 | Step Counts: 80 | Train Reward: 156.36 | Global Steps: 121030 | Loss: 328.65
# Worker 0 | Episode 1840 | Step Counts: 98 | Train Reward: 206.54 | Global Steps: 122884 | Loss: -12.00
# Worker 7 | Episode 1860 | Step Counts: 110 | Train Reward: 209.17 | Global Steps: 124836 | Loss: -10.34
# Worker 6 | Episode 1880 | Step Counts: 99 | Train Reward: 206.59 | Global Steps: 126587 | Loss: -12.00
# Worker 0 | Episode 1900 | Step Counts: 103 | Train Reward: 227.52 | Global Steps: 128617 | Loss: 67.32
# Worker 4 | Episode 1920 | Step Counts: 107 | Train Reward: 213.88 | Global Steps: 130375 | Loss: 2.22
# Worker 2 | Episode 1940 | Step Counts: 50 | Train Reward: 86.62 | Global Steps: 132286 | Loss: 1566.08
# Worker 4 | Episode 1960 | Step Counts: 101 | Train Reward: 189.30 | Global Steps: 134149 | Loss: 117.75
# Worker 6 | Episode 1980 | Step Counts: 98 | Train Reward: 195.20 | Global Steps: 136124 | Loss: 104.09
# Worker 4 | Episode 2000 | Step Counts: 99 | Train Reward: 215.77 | Global Steps: 138096 | Loss: 7.70
# Worker 5 | Episode 2020 | Step Counts: 98 | Train Reward: 212.46 | Global Steps: 140038 | Loss: 25.08
# Worker 3 | Episode 2040 | Step Counts: 92 | Train Reward: 208.78 | Global Steps: 141997 | Loss: -17.88
# Worker 0 | Episode 2060 | Step Counts: 96 | Train Reward: 216.59 | Global Steps: 143911 | Loss: -12.90
# Worker 1 | Episode 2080 | Step Counts: 98 | Train Reward: 220.02 | Global Steps: 145861 | Loss: 49.73
# Worker 0 | Episode 2100 | Step Counts: 101 | Train Reward: 214.93 | Global Steps: 147852 | Loss: -25.53
# Worker 6 | Episode 2120 | Step Counts: 104 | Train Reward: 214.96 | Global Steps: 149849 | Loss: 138.69
# Worker 7 | Episode 2140 | Step Counts: 102 | Train Reward: 224.31 | Global Steps: 151748 | Loss: 51.35
# Worker 3 | Episode 2160 | Step Counts: 80 | Train Reward: 171.00 | Global Steps: 153600 | Loss: 770.99
# Worker 0 | Episode 2180 | Step Counts: 91 | Train Reward: 198.63 | Global Steps: 155554 | Loss: -6.67
# Worker 3 | Episode 2200 | Step Counts: 99 | Train Reward: 211.14 | Global Steps: 157533 | Loss: 31.69
# Worker 5 | Episode 2220 | Step Counts: 65 | Train Reward: 112.92 | Global Steps: 159440 | Loss: 1803.12
# Worker 2 | Episode 2240 | Step Counts: 100 | Train Reward: 218.07 | Global Steps: 161377 | Loss: 10.16
# Worker 7 | Episode 2260 | Step Counts: 103 | Train Reward: 223.13 | Global Steps: 163434 | Loss: -4.26
# Worker 5 | Episode 2280 | Step Counts: 103 | Train Reward: 215.40 | Global Steps: 165131 | Loss: -15.22
# Worker 5 | Episode 2300 | Step Counts: 100 | Train Reward: 222.76 | Global Steps: 166929 | Loss: 28.68
# Worker 2 | Episode 2320 | Step Counts: 102 | Train Reward: 218.16 | Global Steps: 169003 | Loss: 7.05
# Worker 7 | Episode 2340 | Step Counts: 100 | Train Reward: 206.59 | Global Steps: 170496 | Loss: -13.28
# Worker 3 | Episode 2360 | Step Counts: 98 | Train Reward: 176.13 | Global Steps: 172375 | Loss: -8.73
# Worker 2 | Episode 2380 | Step Counts: 104 | Train Reward: 213.88 | Global Steps: 174424 | Loss: 1.59
# Worker 3 | Episode 2400 | Step Counts: 103 | Train Reward: 223.43 | Global Steps: 176478 | Loss: 32.59
# Worker 2 | Episode 2420 | Step Counts: 106 | Train Reward: 213.77 | Global Steps: 178527 | Loss: 35.26
# Worker 1 | Episode 2440 | Step Counts: 104 | Train Reward: 194.94 | Global Steps: 180525 | Loss: -9.39
# Worker 1 | Episode 2460 | Step Counts: 87 | Train Reward: 183.14 | Global Steps: 182299 | Loss: 129.93
# Worker 3 | Episode 2480 | Step Counts: 102 | Train Reward: 177.95 | Global Steps: 184313 | Loss: 21.41
# Worker 2 | Episode 2500 | Step Counts: 102 | Train Reward: 201.32 | Global Steps: 186331 | Loss: -18.60
# Worker 3 | Episode 2520 | Step Counts: 102 | Train Reward: 212.62 | Global Steps: 188413 | Loss: -23.65
# Worker 7 | Episode 2540 | Step Counts: 104 | Train Reward: 217.15 | Global Steps: 190465 | Loss: -1.77
# Worker 1 | Episode 2560 | Step Counts: 99 | Train Reward: 220.23 | Global Steps: 192470 | Loss: 44.33
# Worker 4 | Episode 2580 | Step Counts: 100 | Train Reward: 221.25 | Global Steps: 194441 | Loss: 46.54
# Worker 0 | Episode 2600 | Step Counts: 100 | Train Reward: 225.09 | Global Steps: 196367 | Loss: 85.40
# Worker 7 | Episode 2620 | Step Counts: 94 | Train Reward: 210.27 | Global Steps: 198272 | Loss: 29.36
# Worker 1 | Episode 2640 | Step Counts: 98 | Train Reward: 222.71 | Global Steps: 200193 | Loss: 29.92
# Worker 4 | Episode 2660 | Step Counts: 88 | Train Reward: 196.26 | Global Steps: 202081 | Loss: 15.59
# Worker 6 | Episode 2680 | Step Counts: 96 | Train Reward: 218.47 | Global Steps: 203943 | Loss: 8.12
# Worker 7 | Episode 2700 | Step Counts: 93 | Train Reward: 211.89 | Global Steps: 205857 | Loss: 13.01
# Worker 6 | Episode 2720 | Step Counts: 92 | Train Reward: 209.28 | Global Steps: 207722 | Loss: -16.51
# Worker 2 | Episode 2740 | Step Counts: 96 | Train Reward: 216.44 | Global Steps: 209633 | Loss: 12.43
# Worker 6 | Episode 2760 | Step Counts: 95 | Train Reward: 218.03 | Global Steps: 211585 | Loss: -12.46
# Worker 1 | Episode 2780 | Step Counts: 96 | Train Reward: 220.25 | Global Steps: 213495 | Loss: 104.01
# Worker 1 | Episode 2800 | Step Counts: 91 | Train Reward: 204.46 | Global Steps: 215377 | Loss: 4.74
# Worker 4 | Episode 2820 | Step Counts: 102 | Train Reward: 227.55 | Global Steps: 217347 | Loss: -14.91
# Worker 3 | Episode 2840 | Step Counts: 107 | Train Reward: 227.93 | Global Steps: 219218 | Loss: 32.73
# Worker 6 | Episode 2860 | Step Counts: 97 | Train Reward: 210.78 | Global Steps: 221264 | Loss: -14.45
# Worker 2 | Episode 2880 | Step Counts: 101 | Train Reward: 196.88 | Global Steps: 223261 | Loss: 16.34
# Worker 6 | Episode 2900 | Step Counts: 101 | Train Reward: 199.95 | Global Steps: 225012 | Loss: -13.58
# Worker 1 | Episode 2920 | Step Counts: 101 | Train Reward: 201.75 | Global Steps: 227017 | Loss: -8.98
# Worker 1 | Episode 2940 | Step Counts: 99 | Train Reward: 217.55 | Global Steps: 229058 | Loss: -16.06
# Worker 6 | Episode 2960 | Step Counts: 96 | Train Reward: 217.71 | Global Steps: 230940 | Loss: 57.23
# Worker 3 | Episode 2980 | Step Counts: 51 | Train Reward: 92.30 | Global Steps: 232494 | Loss: 2196.05
# Worker 3 | Episode 3000 | Step Counts: 58 | Train Reward: 110.03 | Global Steps: 234368 | Loss: 947.68
# Worker 1 | Episode 3020 | Step Counts: 102 | Train Reward: 225.50 | Global Steps: 236196 | Loss: -13.40
# Worker 5 | Episode 3040 | Step Counts: 101 | Train Reward: 220.08 | Global Steps: 238152 | Loss: -1.98
# Worker 6 | Episode 3060 | Step Counts: 99 | Train Reward: 223.63 | Global Steps: 240131 | Loss: -9.59
# Worker 5 | Episode 3080 | Step Counts: 98 | Train Reward: 223.90 | Global Steps: 242115 | Loss: 19.84
# Worker 1 | Episode 3100 | Step Counts: 69 | Train Reward: 140.00 | Global Steps: 243999 | Loss: 1335.25
# Worker 4 | Episode 3120 | Step Counts: 96 | Train Reward: 217.93 | Global Steps: 245948 | Loss: 95.97
# Worker 5 | Episode 3140 | Step Counts: 103 | Train Reward: 224.72 | Global Steps: 247894 | Loss: 7.05
# Worker 4 | Episode 3160 | Step Counts: 102 | Train Reward: 219.29 | Global Steps: 249912 | Loss: 6.52
# Worker 0 | Episode 3180 | Step Counts: 87 | Train Reward: 169.46 | Global Steps: 251808 | Loss: 158.89
# Worker 1 | Episode 3200 | Step Counts: 101 | Train Reward: 214.90 | Global Steps: 253760 | Loss: -27.25
# Worker 0 | Episode 3220 | Step Counts: 53 | Train Reward: 95.40 | Global Steps: 255561 | Loss: 1642.35
# Worker 1 | Episode 3240 | Step Counts: 100 | Train Reward: 225.75 | Global Steps: 256566 | Loss: 149.53
# Worker 3 | Episode 3260 | Step Counts: 99 | Train Reward: 221.89 | Global Steps: 258199 | Loss: 88.20
# Worker 5 | Episode 3280 | Step Counts: 96 | Train Reward: 219.55 | Global Steps: 260107 | Loss: 4.18
# Worker 2 | Episode 3300 | Step Counts: 97 | Train Reward: 221.94 | Global Steps: 261937 | Loss: 145.58
# Worker 3 | Episode 3320 | Step Counts: 97 | Train Reward: 222.64 | Global Steps: 263809 | Loss: -6.89
# Worker 2 | Episode 3340 | Step Counts: 98 | Train Reward: 220.79 | Global Steps: 265705 | Loss: -13.77
# Worker 3 | Episode 3360 | Step Counts: 98 | Train Reward: 224.73 | Global Steps: 267549 | Loss: 46.64
# Worker 6 | Episode 3380 | Step Counts: 97 | Train Reward: 220.31 | Global Steps: 269443 | Loss: -10.99
# Worker 3 | Episode 3400 | Step Counts: 100 | Train Reward: 224.74 | Global Steps: 271413 | Loss: -15.65
# Worker 1 | Episode 3420 | Step Counts: 54 | Train Reward: 98.47 | Global Steps: 273102 | Loss: 2021.13
# Worker 5 | Episode 3440 | Step Counts: 62 | Train Reward: 118.29 | Global Steps: 274444 | Loss: 1081.37
# Worker 4 | Episode 3460 | Step Counts: 52 | Train Reward: 94.57 | Global Steps: 275910 | Loss: 1633.08
# Worker 2 | Episode 3480 | Step Counts: 95 | Train Reward: 217.04 | Global Steps: 277770 | Loss: 105.48
# Worker 7 | Episode 3500 | Step Counts: 85 | Train Reward: 183.37 | Global Steps: 279682 | Loss: 462.29
# Worker 2 | Episode 3520 | Step Counts: 101 | Train Reward: 228.04 | Global Steps: 281622 | Loss: -10.60
# Worker 7 | Episode 3540 | Step Counts: 93 | Train Reward: 214.74 | Global Steps: 283563 | Loss: -6.38
# Worker 2 | Episode 3560 | Step Counts: 99 | Train Reward: 225.54 | Global Steps: 285502 | Loss: -4.21
# Worker 4 | Episode 3580 | Step Counts: 99 | Train Reward: 221.47 | Global Steps: 287422 | Loss: -5.13
# Worker 3 | Episode 3600 | Step Counts: 65 | Train Reward: 128.01 | Global Steps: 289355 | Loss: 1033.21
# Worker 3 | Episode 3620 | Step Counts: 45 | Train Reward: 76.41 | Global Steps: 291137 | Loss: 2663.26
# Worker 3 | Episode 3640 | Step Counts: 96 | Train Reward: 215.52 | Global Steps: 292902 | Loss: 5.68
# Worker 1 | Episode 3660 | Step Counts: 98 | Train Reward: 223.84 | Global Steps: 294487 | Loss: 29.81
# Worker 0 | Episode 3680 | Step Counts: 107 | Train Reward: 210.67 | Global Steps: 296560 | Loss: -15.30
# Worker 2 | Episode 3700 | Step Counts: 102 | Train Reward: 204.20 | Global Steps: 298610 | Loss: 24.69
# Worker 1 | Episode 3720 | Step Counts: 72 | Train Reward: 129.09 | Global Steps: 300061 | Loss: 1445.48
# Worker 0 | Episode 3740 | Step Counts: 85 | Train Reward: 182.54 | Global Steps: 301437 | Loss: 50.80
# Worker 4 | Episode 3760 | Step Counts: 107 | Train Reward: 206.03 | Global Steps: 303041 | Loss: 120.16
# Worker 4 | Episode 3780 | Step Counts: 131 | Train Reward: 246.14 | Global Steps: 305254 | Loss: 48.73
# Worker 5 | Episode 3800 | Step Counts: 101 | Train Reward: 160.67 | Global Steps: 307568 | Loss: 1347.13
# Worker 6 | Episode 3820 | Step Counts: 197 | Train Reward: 302.25 | Global Steps: 310467 | Loss: 269.25
# Worker 5 | Episode 3840 | Step Counts: 220 | Train Reward: 346.55 | Global Steps: 313982 | Loss: 39.85
# Worker 1 | Episode 3860 | Step Counts: 147 | Train Reward: 270.65 | Global Steps: 317774 | Loss: -11.55
# Worker 2 | Episode 3880 | Step Counts: 181 | Train Reward: 302.49 | Global Steps: 321442 | Loss: -7.88
# Worker 7 | Episode 3900 | Step Counts: 238 | Train Reward: 376.05 | Global Steps: 325756 | Loss: -10.17
# Worker 7 | Episode 3920 | Step Counts: 412 | Train Reward: 555.37 | Global Steps: 330929 | Loss: -15.02
# Worker 3 | Episode 3940 | Step Counts: 219 | Train Reward: 354.21 | Global Steps: 335914 | Loss: 6.35
# Worker 6 | Episode 3960 | Step Counts: 80 | Train Reward: 136.59 | Global Steps: 339217 | Loss: 2290.25
# Worker 3 | Episode 3980 | Step Counts: 179 | Train Reward: 306.90 | Global Steps: 341918 | Loss: -5.51
# Worker 5 | Episode 4000 | Step Counts: 142 | Train Reward: 271.61 | Global Steps: 345105 | Loss: -5.75
# Worker 7 | Episode 4020 | Step Counts: 223 | Train Reward: 358.33 | Global Steps: 348884 | Loss: -2.98
# Worker 1 | Episode 4040 | Step Counts: 168 | Train Reward: 285.77 | Global Steps: 352662 | Loss: 158.88
# Worker 3 | Episode 4060 | Step Counts: 164 | Train Reward: 251.90 | Global Steps: 355730 | Loss: 1119.56
# Worker 0 | Episode 4080 | Step Counts: 108 | Train Reward: 206.32 | Global Steps: 359449 | Loss: 702.10
# Worker 3 | Episode 4100 | Step Counts: 200 | Train Reward: 327.69 | Global Steps: 362737 | Loss: -8.31
# Worker 6 | Episode 4120 | Step Counts: 212 | Train Reward: 366.17 | Global Steps: 367605 | Loss: 27.35
# Worker 4 | Episode 4140 | Step Counts: 216 | Train Reward: 368.08 | Global Steps: 372145 | Loss: -12.65
# Worker 6 | Episode 4160 | Step Counts: 182 | Train Reward: 262.53 | Global Steps: 376706 | Loss: 1909.15
# Worker 2 | Episode 4180 | Step Counts: 302 | Train Reward: 490.67 | Global Steps: 381867 | Loss: -16.42
# Worker 4 | Episode 4200 | Step Counts: 197 | Train Reward: 321.68 | Global Steps: 386912 | Loss: 1778.61
# Worker 2 | Episode 4220 | Step Counts: 184 | Train Reward: 282.84 | Global Steps: 391005 | Loss: 1994.83
# Worker 6 | Episode 4240 | Step Counts: 206 | Train Reward: 369.38 | Global Steps: 394760 | Loss: -11.46
# Worker 4 | Episode 4260 | Step Counts: 309 | Train Reward: 499.51 | Global Steps: 399704 | Loss: 14.00
# Worker 5 | Episode 4280 | Step Counts: 168 | Train Reward: 346.31 | Global Steps: 404212 | Loss: -13.13
# Worker 3 | Episode 4300 | Step Counts: 84 | Train Reward: 154.07 | Global Steps: 407602 | Loss: 3151.97
# Worker 6 | Episode 4320 | Step Counts: 85 | Train Reward: 148.34 | Global Steps: 409754 | Loss: 3177.45
# Worker 6 | Episode 4340 | Step Counts: 161 | Train Reward: 351.50 | Global Steps: 412371 | Loss: 0.94
# Worker 3 | Episode 4360 | Step Counts: 144 | Train Reward: 315.11 | Global Steps: 415168 | Loss: 39.49
# Worker 5 | Episode 4380 | Step Counts: 61 | Train Reward: 90.54 | Global Steps: 417160 | Loss: 4907.48
# Worker 0 | Episode 4400 | Step Counts: 51 | Train Reward: 75.86 | Global Steps: 418854 | Loss: 3200.91
# Worker 6 | Episode 4420 | Step Counts: 42 | Train Reward: 58.26 | Global Steps: 419685 | Loss: 1698.01
# Worker 6 | Episode 4440 | Step Counts: 60 | Train Reward: 89.37 | Global Steps: 420505 | Loss: 1437.34
# Worker 6 | Episode 4460 | Step Counts: 47 | Train Reward: 71.08 | Global Steps: 421242 | Loss: 81.31
# Worker 1 | Episode 4480 | Step Counts: 36 | Train Reward: 49.11 | Global Steps: 422009 | Loss: 814.49
# Worker 5 | Episode 4500 | Step Counts: 42 | Train Reward: 68.30 | Global Steps: 422693 | Loss: 62.87
# Worker 7 | Episode 4520 | Step Counts: 47 | Train Reward: 68.24 | Global Steps: 423497 | Loss: 48.25
# Worker 4 | Episode 4540 | Step Counts: 39 | Train Reward: 53.65 | Global Steps: 424220 | Loss: 83.40
# Worker 2 | Episode 4560 | Step Counts: 55 | Train Reward: 85.50 | Global Steps: 425044 | Loss: 33.48
# Worker 0 | Episode 4580 | Step Counts: 59 | Train Reward: 103.54 | Global Steps: 426330 | Loss: 38.16
# Worker 2 | Episode 4600 | Step Counts: 56 | Train Reward: 76.71 | Global Steps: 427530 | Loss: 0.91
# Worker 0 | Episode 4620 | Step Counts: 97 | Train Reward: 126.03 | Global Steps: 429087 | Loss: 1099.07
# Worker 4 | Episode 4640 | Step Counts: 82 | Train Reward: 132.56 | Global Steps: 431135 | Loss: 180.07
# Worker 5 | Episode 4660 | Step Counts: 132 | Train Reward: 173.93 | Global Steps: 433588 | Loss: 1250.45
# Worker 4 | Episode 4680 | Step Counts: 133 | Train Reward: 176.54 | Global Steps: 436431 | Loss: 1904.51
# Worker 7 | Episode 4700 | Step Counts: 141 | Train Reward: 188.71 | Global Steps: 439095 | Loss: 2358.24
# Worker 4 | Episode 4720 | Step Counts: 255 | Train Reward: 452.09 | Global Steps: 441999 | Loss: -7.83
# Worker 2 | Episode 4740 | Step Counts: 219 | Train Reward: 432.52 | Global Steps: 446394 | Loss: -2.53
# Worker 5 | Episode 4760 | Step Counts: 151 | Train Reward: 222.57 | Global Steps: 450262 | Loss: 6182.66
# Worker 1 | Episode 4780 | Step Counts: 176 | Train Reward: 271.73 | Global Steps: 453376 | Loss: 3468.19
# Worker 3 | Episode 4800 | Step Counts: 358 | Train Reward: 477.75 | Global Steps: 456867 | Loss: 5442.19
# Worker 4 | Episode 4820 | Step Counts: 85 | Train Reward: 88.17 | Global Steps: 460104 | Loss: 3394.05
# Worker 5 | Episode 4840 | Step Counts: 160 | Train Reward: 323.13 | Global Steps: 463208 | Loss: 1579.03
# Worker 0 | Episode 4860 | Step Counts: 215 | Train Reward: 415.53 | Global Steps: 467006 | Loss: -18.88
# Worker 0 | Episode 4880 | Step Counts: 181 | Train Reward: 358.79 | Global Steps: 469886 | Loss: -9.64
# Worker 7 | Episode 4900 | Step Counts: 187 | Train Reward: 340.28 | Global Steps: 472955 | Loss: 5190.79
# Worker 4 | Episode 4920 | Step Counts: 189 | Train Reward: 378.02 | Global Steps: 477204 | Loss: 19.29
# Worker 2 | Episode 4940 | Step Counts: 115 | Train Reward: 147.13 | Global Steps: 480143 | Loss: 4768.99
# Worker 4 | Episode 4960 | Step Counts: 154 | Train Reward: 319.22 | Global Steps: 482901 | Loss: 16.63
# Worker 5 | Episode 4980 | Step Counts: 186 | Train Reward: 310.92 | Global Steps: 485466 | Loss: 1121.08
# Worker 4 | Episode 5000 | Step Counts: 165 | Train Reward: 347.32 | Global Steps: 488510 | Loss: -5.77
# Worker 5 | Episode 5020 | Step Counts: 171 | Train Reward: 388.93 | Global Steps: 491788 | Loss: 1234.82
# Worker 5 | Episode 5040 | Step Counts: 57 | Train Reward: 102.48 | Global Steps: 494462 | Loss: 4047.31
# Worker 6 | Episode 5060 | Step Counts: 362 | Train Reward: 420.29 | Global Steps: 497954 | Loss: 6764.58
# Worker 3 | Episode 5080 | Step Counts: 196 | Train Reward: 403.37 | Global Steps: 501620 | Loss: -7.46
# Worker 7 | Episode 5100 | Step Counts: 133 | Train Reward: 347.37 | Global Steps: 504692 | Loss: 4.13
# Worker 0 | Episode 5120 | Step Counts: 142 | Train Reward: 335.07 | Global Steps: 507205 | Loss: -3.50
# Worker 0 | Episode 5140 | Step Counts: 59 | Train Reward: 108.47 | Global Steps: 508751 | Loss: 1901.38
# Worker 0 | Episode 5160 | Step Counts: 53 | Train Reward: 95.05 | Global Steps: 509957 | Loss: 948.32
# Worker 6 | Episode 5180 | Step Counts: 86 | Train Reward: 190.63 | Global Steps: 511563 | Loss: 101.93
# Worker 2 | Episode 5200 | Step Counts: 50 | Train Reward: 88.99 | Global Steps: 512791 | Loss: 894.61
# Worker 7 | Episode 5220 | Step Counts: 44 | Train Reward: 79.40 | Global Steps: 513591 | Loss: 876.28
# Worker 6 | Episode 5240 | Step Counts: 58 | Train Reward: 106.60 | Global Steps: 514566 | Loss: 300.66
# Worker 1 | Episode 5260 | Step Counts: 61 | Train Reward: 111.87 | Global Steps: 515671 | Loss: 319.21
# Worker 7 | Episode 5280 | Step Counts: 61 | Train Reward: 113.60 | Global Steps: 516824 | Loss: 4.98
# Worker 2 | Episode 5300 | Step Counts: 49 | Train Reward: 88.01 | Global Steps: 518008 | Loss: 109.17
# Worker 5 | Episode 5320 | Step Counts: 43 | Train Reward: 76.44 | Global Steps: 519061 | Loss: 147.11
# Worker 7 | Episode 5340 | Step Counts: 33 | Train Reward: 57.53 | Global Steps: 519784 | Loss: 232.08
# Worker 0 | Episode 5360 | Step Counts: 39 | Train Reward: 66.96 | Global Steps: 520507 | Loss: 20.94
# Worker 4 | Episode 5380 | Step Counts: 41 | Train Reward: 67.48 | Global Steps: 521339 | Loss: -17.09
# Worker 7 | Episode 5400 | Step Counts: 99 | Train Reward: 126.40 | Global Steps: 522432 | Loss: 1332.05
# Worker 6 | Episode 5420 | Step Counts: 60 | Train Reward: 53.12 | Global Steps: 523639 | Loss: 846.65
# Worker 2 | Episode 5440 | Step Counts: 59 | Train Reward: 53.53 | Global Steps: 524728 | Loss: 770.74
# Worker 3 | Episode 5460 | Step Counts: 102 | Train Reward: 128.16 | Global Steps: 526309 | Loss: 1215.52
# Worker 2 | Episode 5480 | Step Counts: 36 | Train Reward: 60.57 | Global Steps: 527188 | Loss: 584.56
# Worker 5 | Episode 5500 | Step Counts: 47 | Train Reward: 76.93 | Global Steps: 528073 | Loss: 550.12
# Worker 7 | Episode 5520 | Step Counts: 49 | Train Reward: 80.62 | Global Steps: 529002 | Loss: 632.81
# Worker 3 | Episode 5540 | Step Counts: 113 | Train Reward: 146.76 | Global Steps: 530250 | Loss: 810.57
# Worker 5 | Episode 5560 | Step Counts: 43 | Train Reward: 29.16 | Global Steps: 532190 | Loss: 1722.31
# Worker 5 | Episode 5580 | Step Counts: 86 | Train Reward: 92.88 | Global Steps: 533751 | Loss: 3517.14
# Worker 0 | Episode 5600 | Step Counts: 135 | Train Reward: 168.83 | Global Steps: 535671 | Loss: 2551.39
# Worker 0 | Episode 5620 | Step Counts: 20 | Train Reward: 0.41 | Global Steps: 537134 | Loss: 2058.53
# Worker 7 | Episode 5640 | Step Counts: 51 | Train Reward: 93.05 | Global Steps: 538630 | Loss: 346.30
# Worker 3 | Episode 5660 | Step Counts: 54 | Train Reward: 85.93 | Global Steps: 539963 | Loss: 1946.21
# Worker 2 | Episode 5680 | Step Counts: 50 | Train Reward: 84.82 | Global Steps: 541058 | Loss: 410.19
# Worker 1 | Episode 5700 | Step Counts: 119 | Train Reward: 146.04 | Global Steps: 542153 | Loss: 1375.53
# Worker 2 | Episode 5720 | Step Counts: 48 | Train Reward: 76.60 | Global Steps: 544401 | Loss: 2098.02
# Worker 0 | Episode 5740 | Step Counts: 19 | Train Reward: -1.40 | Global Steps: 545984 | Loss: 2507.49
# Worker 2 | Episode 5760 | Step Counts: 215 | Train Reward: 238.89 | Global Steps: 548109 | Loss: 4558.71
# Worker 1 | Episode 5780 | Step Counts: 142 | Train Reward: 185.30 | Global Steps: 550415 | Loss: 3187.72
# Worker 1 | Episode 5800 | Step Counts: 49 | Train Reward: 37.58 | Global Steps: 552175 | Loss: 2304.04
# Worker 1 | Episode 5820 | Step Counts: 128 | Train Reward: 163.34 | Global Steps: 553924 | Loss: 3710.12
# Worker 4 | Episode 5840 | Step Counts: 145 | Train Reward: 240.61 | Global Steps: 555644 | Loss: 1884.70
# Worker 3 | Episode 5860 | Step Counts: 60 | Train Reward: 100.65 | Global Steps: 556825 | Loss: 1010.85
# Worker 3 | Episode 5880 | Step Counts: 50 | Train Reward: 79.10 | Global Steps: 558260 | Loss: 823.75
# Worker 3 | Episode 5900 | Step Counts: 49 | Train Reward: 77.82 | Global Steps: 559528 | Loss: 461.89
# Worker 2 | Episode 5920 | Step Counts: 46 | Train Reward: 75.66 | Global Steps: 560612 | Loss: 143.50
# Worker 1 | Episode 5940 | Step Counts: 42 | Train Reward: 69.36 | Global Steps: 561504 | Loss: 322.33
# Worker 4 | Episode 5960 | Step Counts: 32 | Train Reward: 56.07 | Global Steps: 562255 | Loss: 279.22
# Worker 6 | Episode 5980 | Step Counts: 41 | Train Reward: 72.15 | Global Steps: 562946 | Loss: -38.25
# Worker 2 | Episode 6000 | Step Counts: 47 | Train Reward: 83.36 | Global Steps: 563839 | Loss: 55.99
# Worker 6 | Episode 6020 | Step Counts: 43 | Train Reward: 75.39 | Global Steps: 564772 | Loss: -28.41
# Worker 5 | Episode 6040 | Step Counts: 46 | Train Reward: 81.98 | Global Steps: 565658 | Loss: 2.40
# Worker 6 | Episode 6060 | Step Counts: 66 | Train Reward: 124.79 | Global Steps: 566952 | Loss: -0.75
# Worker 4 | Episode 6080 | Step Counts: 109 | Train Reward: 252.19 | Global Steps: 568880 | Loss: -15.68
# Worker 7 | Episode 6100 | Step Counts: 115 | Train Reward: 258.90 | Global Steps: 570749 | Loss: -7.74
# Worker 1 | Episode 6120 | Step Counts: 76 | Train Reward: 138.73 | Global Steps: 572790 | Loss: 167.57
# Worker 2 | Episode 6140 | Step Counts: 93 | Train Reward: 177.66 | Global Steps: 574606 | Loss: 127.13
# Worker 1 | Episode 6160 | Step Counts: 97 | Train Reward: 186.26 | Global Steps: 576508 | Loss: 0.92
# Worker 2 | Episode 6180 | Step Counts: 93 | Train Reward: 178.30 | Global Steps: 578426 | Loss: -7.83
# Worker 0 | Episode 6200 | Step Counts: 95 | Train Reward: 180.76 | Global Steps: 580271 | Loss: 10.24
# Worker 2 | Episode 6220 | Step Counts: 100 | Train Reward: 189.13 | Global Steps: 582175 | Loss: -10.57
# Worker 1 | Episode 6240 | Step Counts: 100 | Train Reward: 204.13 | Global Steps: 584058 | Loss: 129.41
# Worker 3 | Episode 6260 | Step Counts: 102 | Train Reward: 199.13 | Global Steps: 585982 | Loss: -10.96
# Worker 5 | Episode 6280 | Step Counts: 79 | Train Reward: 140.96 | Global Steps: 587667 | Loss: -6.89
# Worker 6 | Episode 6300 | Step Counts: 78 | Train Reward: 145.20 | Global Steps: 589224 | Loss: 25.00
# Worker 0 | Episode 6320 | Step Counts: 75 | Train Reward: 131.80 | Global Steps: 590607 | Loss: 24.60
# Worker 2 | Episode 6340 | Step Counts: 71 | Train Reward: 122.39 | Global Steps: 592039 | Loss: -8.18
# Worker 5 | Episode 6360 | Step Counts: 88 | Train Reward: 167.51 | Global Steps: 593493 | Loss: 24.21
# Worker 3 | Episode 6380 | Step Counts: 93 | Train Reward: 178.39 | Global Steps: 595386 | Loss: 27.23
# Worker 4 | Episode 6400 | Step Counts: 100 | Train Reward: 193.67 | Global Steps: 597280 | Loss: -5.36
# Worker 7 | Episode 6420 | Step Counts: 103 | Train Reward: 204.64 | Global Steps: 599160 | Loss: -12.81
# Worker 5 | Episode 6440 | Step Counts: 97 | Train Reward: 191.61 | Global Steps: 601075 | Loss: -8.26
# Worker 0 | Episode 6460 | Step Counts: 93 | Train Reward: 181.43 | Global Steps: 602938 | Loss: -11.46
# Worker 1 | Episode 6480 | Step Counts: 90 | Train Reward: 172.03 | Global Steps: 604427 | Loss: -3.33
# Worker 7 | Episode 6500 | Step Counts: 94 | Train Reward: 179.16 | Global Steps: 606081 | Loss: 21.89
# Worker 6 | Episode 6520 | Step Counts: 95 | Train Reward: 181.16 | Global Steps: 607954 | Loss: -14.24
# Worker 1 | Episode 6540 | Step Counts: 86 | Train Reward: 158.73 | Global Steps: 609746 | Loss: 60.42
# Worker 0 | Episode 6560 | Step Counts: 97 | Train Reward: 185.76 | Global Steps: 611596 | Loss: -10.67
# Worker 1 | Episode 6580 | Step Counts: 97 | Train Reward: 191.09 | Global Steps: 613533 | Loss: -4.63
# Worker 7 | Episode 6600 | Step Counts: 94 | Train Reward: 184.35 | Global Steps: 615455 | Loss: -3.73
# Worker 6 | Episode 6620 | Step Counts: 97 | Train Reward: 190.70 | Global Steps: 617400 | Loss: -19.27
# Worker 4 | Episode 6640 | Step Counts: 95 | Train Reward: 186.09 | Global Steps: 619342 | Loss: -13.23
# Worker 0 | Episode 6660 | Step Counts: 94 | Train Reward: 190.76 | Global Steps: 621247 | Loss: -4.18
# Worker 5 | Episode 6680 | Step Counts: 97 | Train Reward: 188.76 | Global Steps: 623159 | Loss: -8.15
# Worker 2 | Episode 6700 | Step Counts: 96 | Train Reward: 188.64 | Global Steps: 625097 | Loss: -11.60
# Worker 6 | Episode 6720 | Step Counts: 98 | Train Reward: 189.09 | Global Steps: 627026 | Loss: -14.10
# Worker 2 | Episode 6740 | Step Counts: 102 | Train Reward: 204.24 | Global Steps: 628970 | Loss: -12.05
# Worker 5 | Episode 6760 | Step Counts: 101 | Train Reward: 197.19 | Global Steps: 631004 | Loss: -3.08
# Worker 3 | Episode 6780 | Step Counts: 97 | Train Reward: 190.09 | Global Steps: 632971 | Loss: -8.29
# Worker 2 | Episode 6800 | Step Counts: 105 | Train Reward: 205.25 | Global Steps: 634992 | Loss: -11.44
# Worker 3 | Episode 6820 | Step Counts: 80 | Train Reward: 152.47 | Global Steps: 636980 | Loss: 150.90
# Worker 3 | Episode 6840 | Step Counts: 55 | Train Reward: 100.52 | Global Steps: 638469 | Loss: 808.29
# Worker 3 | Episode 6860 | Step Counts: 77 | Train Reward: 143.81 | Global Steps: 639619 | Loss: 131.91
# Worker 1 | Episode 6880 | Step Counts: 54 | Train Reward: 97.02 | Global Steps: 640875 | Loss: 279.35
# Worker 1 | Episode 6900 | Step Counts: 77 | Train Reward: 144.22 | Global Steps: 642239 | Loss: -5.01
# Worker 6 | Episode 6920 | Step Counts: 97 | Train Reward: 193.45 | Global Steps: 644021 | Loss: 51.48
# Worker 1 | Episode 6940 | Step Counts: 95 | Train Reward: 194.48 | Global Steps: 645832 | Loss: 5.96
# Worker 5 | Episode 6960 | Step Counts: 96 | Train Reward: 206.69 | Global Steps: 647729 | Loss: 30.10
# Worker 1 | Episode 6980 | Step Counts: 99 | Train Reward: 197.82 | Global Steps: 649687 | Loss: -15.94
# Worker 3 | Episode 7000 | Step Counts: 101 | Train Reward: 201.29 | Global Steps: 651656 | Loss: 16.00
# Worker 1 | Episode 7020 | Step Counts: 95 | Train Reward: 185.10 | Global Steps: 653639 | Loss: -5.10
# Worker 3 | Episode 7040 | Step Counts: 71 | Train Reward: 132.26 | Global Steps: 655485 | Loss: 359.49
# Worker 1 | Episode 7060 | Step Counts: 87 | Train Reward: 172.98 | Global Steps: 657343 | Loss: 11.41
# Worker 7 | Episode 7080 | Step Counts: 92 | Train Reward: 187.87 | Global Steps: 659220 | Loss: -11.20
# Worker 2 | Episode 7100 | Step Counts: 88 | Train Reward: 179.42 | Global Steps: 660918 | Loss: -17.16
# Worker 1 | Episode 7120 | Step Counts: 88 | Train Reward: 174.91 | Global Steps: 662619 | Loss: -15.45
# Worker 6 | Episode 7140 | Step Counts: 84 | Train Reward: 172.89 | Global Steps: 664354 | Loss: 3.10
# Worker 3 | Episode 7160 | Step Counts: 89 | Train Reward: 177.87 | Global Steps: 666097 | Loss: -18.82
# Worker 0 | Episode 7180 | Step Counts: 90 | Train Reward: 184.73 | Global Steps: 667906 | Loss: 10.73
# Worker 5 | Episode 7200 | Step Counts: 93 | Train Reward: 192.33 | Global Steps: 669745 | Loss: -4.22
# Worker 6 | Episode 7220 | Step Counts: 88 | Train Reward: 174.53 | Global Steps: 671571 | Loss: -5.92
# Worker 5 | Episode 7240 | Step Counts: 97 | Train Reward: 206.24 | Global Steps: 673417 | Loss: 64.41
# Worker 6 | Episode 7260 | Step Counts: 96 | Train Reward: 183.42 | Global Steps: 675384 | Loss: 0.71
# Worker 3 | Episode 7280 | Step Counts: 108 | Train Reward: 226.36 | Global Steps: 677369 | Loss: 39.00
# Worker 2 | Episode 7300 | Step Counts: 93 | Train Reward: 189.22 | Global Steps: 679345 | Loss: 101.13
# Worker 4 | Episode 7320 | Step Counts: 97 | Train Reward: 187.99 | Global Steps: 681333 | Loss: 40.14
# Worker 0 | Episode 7340 | Step Counts: 99 | Train Reward: 201.39 | Global Steps: 683278 | Loss: -5.70
# Worker 1 | Episode 7360 | Step Counts: 93 | Train Reward: 198.91 | Global Steps: 685167 | Loss: -6.92
# Worker 2 | Episode 7380 | Step Counts: 98 | Train Reward: 204.01 | Global Steps: 687041 | Loss: -11.56
# Worker 7 | Episode 7400 | Step Counts: 93 | Train Reward: 190.19 | Global Steps: 689025 | Loss: 33.34
# Worker 3 | Episode 7420 | Step Counts: 94 | Train Reward: 192.32 | Global Steps: 690932 | Loss: -13.03
# Worker 6 | Episode 7440 | Step Counts: 96 | Train Reward: 205.37 | Global Steps: 692957 | Loss: 8.28
# Worker 3 | Episode 7460 | Step Counts: 108 | Train Reward: 239.79 | Global Steps: 695060 | Loss: 45.28
# Worker 6 | Episode 7480 | Step Counts: 109 | Train Reward: 229.28 | Global Steps: 697234 | Loss: -3.73
# Worker 4 | Episode 7500 | Step Counts: 101 | Train Reward: 222.37 | Global Steps: 699293 | Loss: -5.26
# Worker 0 | Episode 7520 | Step Counts: 92 | Train Reward: 193.58 | Global Steps: 701260 | Loss: -18.51
# Worker 4 | Episode 7540 | Step Counts: 110 | Train Reward: 251.55 | Global Steps: 703396 | Loss: 19.72
# Worker 6 | Episode 7560 | Step Counts: 115 | Train Reward: 276.63 | Global Steps: 705565 | Loss: 4.02
# Worker 4 | Episode 7580 | Step Counts: 104 | Train Reward: 240.56 | Global Steps: 707751 | Loss: 425.11
# Worker 0 | Episode 7600 | Step Counts: 78 | Train Reward: 141.10 | Global Steps: 709980 | Loss: 1206.49
# Worker 5 | Episode 7620 | Step Counts: 104 | Train Reward: 227.36 | Global Steps: 712314 | Loss: 201.83
# Worker 3 | Episode 7640 | Step Counts: 40 | Train Reward: 67.90 | Global Steps: 713930 | Loss: 2489.67
# Worker 2 | Episode 7660 | Step Counts: 47 | Train Reward: 81.13 | Global Steps: 714761 | Loss: 2494.30
# Worker 7 | Episode 7680 | Step Counts: 14 | Train Reward: 19.37 | Global Steps: 715085 | Loss: 1766.05
# Worker 7 | Episode 7700 | Step Counts: 47 | Train Reward: 80.24 | Global Steps: 715563 | Loss: 943.12
# Worker 2 | Episode 7720 | Step Counts: 116 | Train Reward: 258.19 | Global Steps: 717300 | Loss: 14.22
# Worker 4 | Episode 7740 | Step Counts: 114 | Train Reward: 242.46 | Global Steps: 719038 | Loss: 70.61
# Worker 1 | Episode 7760 | Step Counts: 51 | Train Reward: 87.14 | Global Steps: 720755 | Loss: 2765.57
# Worker 2 | Episode 7780 | Step Counts: 124 | Train Reward: 298.62 | Global Steps: 722727 | Loss: -20.33
# Worker 0 | Episode 7800 | Step Counts: 53 | Train Reward: 92.38 | Global Steps: 724169 | Loss: 2103.31
# Worker 4 | Episode 7820 | Step Counts: 17 | Train Reward: 24.49 | Global Steps: 725132 | Loss: 2009.25
# Worker 2 | Episode 7840 | Step Counts: 123 | Train Reward: 270.29 | Global Steps: 726492 | Loss: 0.61
# Worker 2 | Episode 7860 | Step Counts: 105 | Train Reward: 248.76 | Global Steps: 728799 | Loss: 69.65
# Worker 2 | Episode 7880 | Step Counts: 107 | Train Reward: 230.73 | Global Steps: 731066 | Loss: -5.32
# Worker 2 | Episode 7900 | Step Counts: 105 | Train Reward: 247.68 | Global Steps: 733260 | Loss: -2.14
# Worker 0 | Episode 7920 | Step Counts: 97 | Train Reward: 201.74 | Global Steps: 735303 | Loss: 53.59
# Worker 6 | Episode 7940 | Step Counts: 101 | Train Reward: 213.66 | Global Steps: 737231 | Loss: -12.82
# Worker 0 | Episode 7960 | Step Counts: 97 | Train Reward: 205.66 | Global Steps: 739214 | Loss: -20.71
# Worker 1 | Episode 7980 | Step Counts: 98 | Train Reward: 205.86 | Global Steps: 741189 | Loss: -2.44
# Worker 7 | Episode 8000 | Step Counts: 110 | Train Reward: 231.73 | Global Steps: 743314 | Loss: 2.51
# Worker 1 | Episode 8020 | Step Counts: 114 | Train Reward: 272.58 | Global Steps: 745459 | Loss: 126.45
# Worker 0 | Episode 8040 | Step Counts: 50 | Train Reward: 85.35 | Global Steps: 747286 | Loss: 2079.27
# Worker 0 | Episode 8060 | Step Counts: 114 | Train Reward: 259.36 | Global Steps: 748341 | Loss: -6.51
# Worker 5 | Episode 8080 | Step Counts: 24 | Train Reward: 38.15 | Global Steps: 749112 | Loss: 2355.33
# Worker 1 | Episode 8100 | Step Counts: 16 | Train Reward: 23.32 | Global Steps: 749738 | Loss: 1619.69
# Worker 4 | Episode 8120 | Step Counts: 18 | Train Reward: 27.26 | Global Steps: 750125 | Loss: 954.24
# Worker 0 | Episode 8140 | Step Counts: 109 | Train Reward: 236.31 | Global Steps: 751859 | Loss: 34.20
# Worker 5 | Episode 8160 | Step Counts: 103 | Train Reward: 220.71 | Global Steps: 753711 | Loss: 199.47
# Worker 7 | Episode 8180 | Step Counts: 100 | Train Reward: 214.70 | Global Steps: 755578 | Loss: -15.47
# Worker 6 | Episode 8200 | Step Counts: 45 | Train Reward: 78.77 | Global Steps: 757280 | Loss: 1725.82
# Worker 4 | Episode 8220 | Step Counts: 57 | Train Reward: 100.37 | Global Steps: 759059 | Loss: 904.75
# Worker 0 | Episode 8240 | Step Counts: 106 | Train Reward: 209.59 | Global Steps: 761033 | Loss: 7.78
# Worker 2 | Episode 8260 | Step Counts: 112 | Train Reward: 228.07 | Global Steps: 763028 | Loss: -14.28
# Worker 0 | Episode 8280 | Step Counts: 71 | Train Reward: 127.57 | Global Steps: 765075 | Loss: 417.08
# Worker 1 | Episode 8300 | Step Counts: 110 | Train Reward: 248.98 | Global Steps: 767121 | Loss: 21.27
# Worker 2 | Episode 8320 | Step Counts: 120 | Train Reward: 279.65 | Global Steps: 769084 | Loss: 117.57
# Worker 7 | Episode 8340 | Step Counts: 48 | Train Reward: 83.09 | Global Steps: 771191 | Loss: 2639.15
# Worker 1 | Episode 8360 | Step Counts: 96 | Train Reward: 202.10 | Global Steps: 773273 | Loss: 755.43
# Worker 5 | Episode 8380 | Step Counts: 96 | Train Reward: 205.47 | Global Steps: 775186 | Loss: 549.44
# Worker 6 | Episode 8400 | Step Counts: 122 | Train Reward: 253.47 | Global Steps: 777209 | Loss: -14.18
# Worker 3 | Episode 8420 | Step Counts: 113 | Train Reward: 267.90 | Global Steps: 779352 | Loss: 36.67
# Worker 1 | Episode 8440 | Step Counts: 121 | Train Reward: 327.00 | Global Steps: 781596 | Loss: -17.02
# Worker 6 | Episode 8460 | Step Counts: 59 | Train Reward: 103.24 | Global Steps: 783094 | Loss: 2021.04
# Worker 3 | Episode 8480 | Step Counts: 128 | Train Reward: 321.50 | Global Steps: 784087 | Loss: 9.65
# Worker 4 | Episode 8500 | Step Counts: 89 | Train Reward: 186.50 | Global Steps: 786276 | Loss: 1901.33
# Worker 6 | Episode 8520 | Step Counts: 80 | Train Reward: 164.30 | Global Steps: 787985 | Loss: 1305.34
# Worker 5 | Episode 8540 | Step Counts: 107 | Train Reward: 235.58 | Global Steps: 789952 | Loss: 3.27
# Worker 2 | Episode 8560 | Step Counts: 116 | Train Reward: 246.88 | Global Steps: 792261 | Loss: 126.91
# Worker 4 | Episode 8580 | Step Counts: 81 | Train Reward: 163.76 | Global Steps: 794192 | Loss: 1448.60
# Worker 3 | Episode 8600 | Step Counts: 63 | Train Reward: 114.96 | Global Steps: 795774 | Loss: 2553.50
# Worker 0 | Episode 8620 | Step Counts: 111 | Train Reward: 244.89 | Global Steps: 797942 | Loss: -3.87
# Worker 1 | Episode 8640 | Step Counts: 119 | Train Reward: 286.16 | Global Steps: 800300 | Loss: 8.71
# Worker 1 | Episode 8660 | Step Counts: 115 | Train Reward: 301.11 | Global Steps: 802622 | Loss: 64.31
# Worker 5 | Episode 8680 | Step Counts: 121 | Train Reward: 284.73 | Global Steps: 805049 | Loss: 166.05
# Worker 0 | Episode 8700 | Step Counts: 122 | Train Reward: 311.41 | Global Steps: 807390 | Loss: 102.47
# Worker 2 | Episode 8720 | Step Counts: 126 | Train Reward: 309.46 | Global Steps: 809528 | Loss: 212.71
# Worker 4 | Episode 8740 | Step Counts: 134 | Train Reward: 332.63 | Global Steps: 811267 | Loss: 834.07
# Worker 6 | Episode 8760 | Step Counts: 118 | Train Reward: 273.10 | Global Steps: 813424 | Loss: -9.21
# Worker 1 | Episode 8780 | Step Counts: 110 | Train Reward: 255.98 | Global Steps: 815707 | Loss: 46.37
# ...
# Worker 1 | Episode 13000 | Step Counts: 100 | Train Reward: 228.80 | Global Steps: 1199583 | Loss: 374.85
# Worker 3 | Episode 13020 | Step Counts: 98 | Train Reward: 224.31 | Global Steps: 1201472 | Loss: 128.15
# Worker 6 | Episode 13040 | Step Counts: 92 | Train Reward: 206.53 | Global Steps: 1203254 | Loss: 44.53
# Worker 4 | Episode 13060 | Step Counts: 90 | Train Reward: 205.70 | Global Steps: 1205100 | Loss: -1.78
# Worker 1 | Episode 13080 | Step Counts: 120 | Train Reward: 326.98 | Global Steps: 1206892 | Loss: 455.16
# Worker 5 | Episode 13100 | Step Counts: 120 | Train Reward: 324.82 | Global Steps: 1208810 | Loss: 343.48
# Worker 1 | Episode 13120 | Step Counts: 110 | Train Reward: 280.16 | Global Steps: 1210218 | Loss: -8.50
# Worker 4 | Episode 13140 | Step Counts: 94 | Train Reward: 212.70 | Global Steps: 1212308 | Loss: 933.40
# Worker 2 | Episode 13160 | Step Counts: 95 | Train Reward: 216.74 | Global Steps: 1214295 | Loss: 812.57
# Worker 3 | Episode 13180 | Step Counts: 95 | Train Reward: 211.51 | Global Steps: 1216315 | Loss: 647.58
# Worker 3 | Episode 13200 | Step Counts: 94 | Train Reward: 210.87 | Global Steps: 1218433 | Loss: 1387.19
# Worker 7 | Episode 13220 | Step Counts: 138 | Train Reward: 374.06 | Global Steps: 1220631 | Loss: 422.26
# Worker 1 | Episode 13240 | Step Counts: 114 | Train Reward: 296.60 | Global Steps: 1222771 | Loss: 16.30
# Worker 5 | Episode 13260 | Step Counts: 119 | Train Reward: 318.45 | Global Steps: 1225043 | Loss: 111.45
# Worker 2 | Episode 13280 | Step Counts: 111 | Train Reward: 285.47 | Global Steps: 1226999 | Loss: 34.37
# Worker 5 | Episode 13300 | Step Counts: 16 | Train Reward: 23.45 | Global Steps: 1228699 | Loss: 3950.68
# Worker 4 | Episode 13320 | Step Counts: 114 | Train Reward: 284.44 | Global Steps: 1230916 | Loss: -10.24
# Worker 7 | Episode 13340 | Step Counts: 88 | Train Reward: 196.04 | Global Steps: 1233241 | Loss: 2866.21
# Worker 1 | Episode 13360 | Step Counts: 124 | Train Reward: 340.21 | Global Steps: 1235528 | Loss: 48.76
# Worker 4 | Episode 13380 | Step Counts: 123 | Train Reward: 316.69 | Global Steps: 1237950 | Loss: 985.46
# Worker 2 | Episode 13400 | Step Counts: 125 | Train Reward: 345.69 | Global Steps: 1240212 | Loss: 1978.27
# Worker 1 | Episode 13420 | Step Counts: 84 | Train Reward: 183.84 | Global Steps: 1242032 | Loss: 1933.93
# Worker 4 | Episode 13440 | Step Counts: 88 | Train Reward: 191.16 | Global Steps: 1243754 | Loss: 589.45
# Worker 7 | Episode 13460 | Step Counts: 141 | Train Reward: 409.45 | Global Steps: 1245616 | Loss: -6.69
# Worker 7 | Episode 13480 | Step Counts: 133 | Train Reward: 308.90 | Global Steps: 1247387 | Loss: 165.80
# Worker 1 | Episode 13500 | Step Counts: 96 | Train Reward: 193.89 | Global Steps: 1249303 | Loss: 47.28
# Worker 2 | Episode 13520 | Step Counts: 98 | Train Reward: 201.88 | Global Steps: 1251223 | Loss: 568.23
# Worker 1 | Episode 13540 | Step Counts: 100 | Train Reward: 212.70 | Global Steps: 1253076 | Loss: 239.44
# Worker 1 | Episode 13560 | Step Counts: 119 | Train Reward: 267.30 | Global Steps: 1254674 | Loss: 15.16
# Worker 2 | Episode 13580 | Step Counts: 111 | Train Reward: 243.18 | Global Steps: 1256388 | Loss: -13.54
# Worker 0 | Episode 13600 | Step Counts: 97 | Train Reward: 208.80 | Global Steps: 1258308 | Loss: 26.17
# Worker 3 | Episode 13620 | Step Counts: 128 | Train Reward: 291.21 | Global Steps: 1260282 | Loss: 100.20
# Worker 6 | Episode 13640 | Step Counts: 37 | Train Reward: 63.98 | Global Steps: 1262222 | Loss: 1956.42
# Worker 7 | Episode 13660 | Step Counts: 88 | Train Reward: 167.82 | Global Steps: 1264598 | Loss: 345.13
# Worker 1 | Episode 13680 | Step Counts: 153 | Train Reward: 431.33 | Global Steps: 1267193 | Loss: 150.19
# Worker 1 | Episode 13700 | Step Counts: 188 | Train Reward: 504.47 | Global Steps: 1269863 | Loss: 0.45
# Worker 1 | Episode 13720 | Step Counts: 57 | Train Reward: 97.78 | Global Steps: 1272377 | Loss: 2231.46
# Worker 3 | Episode 13740 | Step Counts: 107 | Train Reward: 234.51 | Global Steps: 1274462 | Loss: 2053.29
# Worker 1 | Episode 13760 | Step Counts: 56 | Train Reward: 97.58 | Global Steps: 1276588 | Loss: 2575.30
# Worker 3 | Episode 13780 | Step Counts: 117 | Train Reward: 262.50 | Global Steps: 1278827 | Loss: 691.01
# Worker 0 | Episode 13800 | Step Counts: 118 | Train Reward: 313.32 | Global Steps: 1281159 | Loss: 27.21
# Worker 3 | Episode 13820 | Step Counts: 122 | Train Reward: 335.08 | Global Steps: 1283484 | Loss: 753.16
# Worker 5 | Episode 13840 | Step Counts: 65 | Train Reward: 120.70 | Global Steps: 1285656 | Loss: 4683.16
# Worker 2 | Episode 13860 | Step Counts: 129 | Train Reward: 325.05 | Global Steps: 1288134 | Loss: 1167.66
# Worker 7 | Episode 13880 | Step Counts: 125 | Train Reward: 311.71 | Global Steps: 1290602 | Loss: -11.90
# Worker 7 | Episode 13900 | Step Counts: 53 | Train Reward: 96.30 | Global Steps: 1292610 | Loss: 3482.43
# Worker 2 | Episode 13920 | Step Counts: 129 | Train Reward: 353.39 | Global Steps: 1295066 | Loss: 1260.20
# Worker 4 | Episode 13940 | Step Counts: 55 | Train Reward: 100.06 | Global Steps: 1297320 | Loss: 4695.92
# Worker 0 | Episode 13960 | Step Counts: 128 | Train Reward: 308.86 | Global Steps: 1299560 | Loss: 187.44
# Worker 1 | Episode 13980 | Step Counts: 122 | Train Reward: 335.25 | Global Steps: 1301204 | Loss: 753.14
# Worker 4 | Episode 14000 | Step Counts: 68 | Train Reward: 124.86 | Global Steps: 1303264 | Loss: 3691.63
# Worker 4 | Episode 14020 | Step Counts: 126 | Train Reward: 332.79 | Global Steps: 1305461 | Loss: 224.32
# Worker 3 | Episode 14040 | Step Counts: 44 | Train Reward: 79.91 | Global Steps: 1306540 | Loss: 4154.24
# Worker 4 | Episode 14060 | Step Counts: 46 | Train Reward: 82.37 | Global Steps: 1307453 | Loss: 2663.47
# Worker 3 | Episode 14080 | Step Counts: 47 | Train Reward: 83.26 | Global Steps: 1308460 | Loss: 2813.90
# Worker 0 | Episode 14100 | Step Counts: 35 | Train Reward: 61.96 | Global Steps: 1309209 | Loss: 2012.76
# Worker 3 | Episode 14120 | Step Counts: 48 | Train Reward: 85.03 | Global Steps: 1310047 | Loss: 1054.32
# Worker 0 | Episode 14140 | Step Counts: 118 | Train Reward: 296.93 | Global Steps: 1311471 | Loss: 120.90
# Worker 2 | Episode 14160 | Step Counts: 74 | Train Reward: 138.70 | Global Steps: 1313176 | Loss: 511.37
# Worker 6 | Episode 14180 | Step Counts: 74 | Train Reward: 143.09 | Global Steps: 1314689 | Loss: 46.27
# Worker 5 | Episode 14200 | Step Counts: 75 | Train Reward: 137.48 | Global Steps: 1316209 | Loss: 309.75
# Worker 0 | Episode 14220 | Step Counts: 66 | Train Reward: 111.03 | Global Steps: 1317283 | Loss: 197.57
# Worker 3 | Episode 14240 | Step Counts: 48 | Train Reward: 86.02 | Global Steps: 1318471 | Loss: 405.47
# Worker 7 | Episode 14260 | Step Counts: 45 | Train Reward: 80.07 | Global Steps: 1319447 | Loss: 429.28
# Worker 3 | Episode 14280 | Step Counts: 44 | Train Reward: 79.55 | Global Steps: 1320353 | Loss: 210.20
# Worker 0 | Episode 14300 | Step Counts: 50 | Train Reward: 90.96 | Global Steps: 1321303 | Loss: -2.88
# Worker 5 | Episode 14320 | Step Counts: 47 | Train Reward: 83.52 | Global Steps: 1322255 | Loss: -5.26
# Worker 6 | Episode 14340 | Step Counts: 45 | Train Reward: 79.69 | Global Steps: 1323159 | Loss: -6.86
# Worker 0 | Episode 14360 | Step Counts: 43 | Train Reward: 76.79 | Global Steps: 1324002 | Loss: -13.53
# Worker 3 | Episode 14380 | Step Counts: 44 | Train Reward: 78.93 | Global Steps: 1324804 | Loss: 30.42
# Worker 7 | Episode 14400 | Step Counts: 50 | Train Reward: 91.14 | Global Steps: 1325765 | Loss: 79.14
# Worker 6 | Episode 14420 | Step Counts: 38 | Train Reward: 65.75 | Global Steps: 1326659 | Loss: -15.43
# Worker 4 | Episode 14440 | Step Counts: 48 | Train Reward: 87.23 | Global Steps: 1327547 | Loss: 32.90
# Worker 5 | Episode 14460 | Step Counts: 48 | Train Reward: 87.49 | Global Steps: 1328513 | Loss: 14.13
# Worker 7 | Episode 14480 | Step Counts: 47 | Train Reward: 87.11 | Global Steps: 1329491 | Loss: -6.70
# Worker 6 | Episode 14500 | Step Counts: 49 | Train Reward: 88.54 | Global Steps: 1330501 | Loss: -4.29
# Worker 5 | Episode 14520 | Step Counts: 56 | Train Reward: 104.90 | Global Steps: 1331862 | Loss: 26.57
# Worker 7 | Episode 14540 | Step Counts: 54 | Train Reward: 100.52 | Global Steps: 1333182 | Loss: -14.19
# Worker 3 | Episode 14560 | Step Counts: 53 | Train Reward: 98.27 | Global Steps: 1334261 | Loss: -5.42
# Worker 6 | Episode 14580 | Step Counts: 97 | Train Reward: 230.67 | Global Steps: 1335879 | Loss: 197.21
# Worker 0 | Episode 14600 | Step Counts: 58 | Train Reward: 106.06 | Global Steps: 1337645 | Loss: 79.05
# Worker 1 | Episode 14620 | Step Counts: 107 | Train Reward: 258.80 | Global Steps: 1339622 | Loss: 2.76
# Worker 0 | Episode 14640 | Step Counts: 117 | Train Reward: 281.54 | Global Steps: 1341621 | Loss: 416.73
# Worker 7 | Episode 14660 | Step Counts: 100 | Train Reward: 241.62 | Global Steps: 1343273 | Loss: -7.88
# Worker 1 | Episode 14680 | Step Counts: 59 | Train Reward: 110.00 | Global Steps: 1344702 | Loss: 417.10
# Worker 2 | Episode 14700 | Step Counts: 55 | Train Reward: 103.14 | Global Steps: 1345820 | Loss: 46.13
# Worker 0 | Episode 14720 | Step Counts: 124 | Train Reward: 329.25 | Global Steps: 1347189 | Loss: 975.97
# Worker 3 | Episode 14740 | Step Counts: 39 | Train Reward: 66.93 | Global Steps: 1348240 | Loss: 270.34
# Worker 3 | Episode 14760 | Step Counts: 41 | Train Reward: 72.26 | Global Steps: 1349010 | Loss: 20.09
# Worker 2 | Episode 14780 | Step Counts: 36 | Train Reward: 61.90 | Global Steps: 1349818 | Loss: 85.30
# Worker 6 | Episode 14800 | Step Counts: 28 | Train Reward: 49.14 | Global Steps: 1350478 | Loss: 116.21
# Worker 0 | Episode 14820 | Step Counts: 38 | Train Reward: 65.17 | Global Steps: 1351165 | Loss: -7.08
# Worker 3 | Episode 14840 | Step Counts: 26 | Train Reward: 45.57 | Global Steps: 1351823 | Loss: -27.04
# Worker 4 | Episode 14860 | Step Counts: 47 | Train Reward: 84.13 | Global Steps: 1352579 | Loss: -2.61
# Worker 5 | Episode 14880 | Step Counts: 59 | Train Reward: 109.09 | Global Steps: 1353595 | Loss: 90.73
# Worker 1 | Episode 14900 | Step Counts: 80 | Train Reward: 153.51 | Global Steps: 1355704 | Loss: 122.63
# Worker 0 | Episode 14920 | Step Counts: 136 | Train Reward: 329.51 | Global Steps: 1357773 | Loss: -3.22
# Worker 7 | Episode 14940 | Step Counts: 138 | Train Reward: 371.01 | Global Steps: 1360282 | Loss: 157.93
# Worker 6 | Episode 14960 | Step Counts: 131 | Train Reward: 356.26 | Global Steps: 1362806 | Loss: 2639.47
# Worker 4 | Episode 14980 | Step Counts: 113 | Train Reward: 287.27 | Global Steps: 1365413 | Loss: 2595.31
# Worker 3 | Episode 15000 | Step Counts: 51 | Train Reward: 89.85 | Global Steps: 1368187 | Loss: 4971.13
# Worker 5 | Episode 15020 | Step Counts: 75 | Train Reward: 137.79 | Global Steps: 1370304 | Loss: 4912.92
# Worker 7 | Episode 15040 | Step Counts: 86 | Train Reward: 178.13 | Global Steps: 1372698 | Loss: 11068.52
# Worker 6 | Episode 15060 | Step Counts: 166 | Train Reward: 552.20 | Global Steps: 1374661 | Loss: 4724.18
# Worker 7 | Episode 15080 | Step Counts: 155 | Train Reward: 495.01 | Global Steps: 1376653 | Loss: 4818.31
# Worker 5 | Episode 15100 | Step Counts: 62 | Train Reward: 115.31 | Global Steps: 1378956 | Loss: 6021.64
# Worker 6 | Episode 15120 | Step Counts: 149 | Train Reward: 384.31 | Global Steps: 1382075 | Loss: 1411.16
# Worker 1 | Episode 15140 | Step Counts: 46 | Train Reward: 81.60 | Global Steps: 1383954 | Loss: 6370.12
# Worker 4 | Episode 15160 | Step Counts: 53 | Train Reward: 96.45 | Global Steps: 1384910 | Loss: 3983.81
# Worker 7 | Episode 15180 | Step Counts: 40 | Train Reward: 71.26 | Global Steps: 1385846 | Loss: 2828.92
# Worker 4 | Episode 15200 | Step Counts: 49 | Train Reward: 88.69 | Global Steps: 1386804 | Loss: 1378.47
# Worker 6 | Episode 15220 | Step Counts: 53 | Train Reward: 97.85 | Global Steps: 1387786 | Loss: 465.78
# Worker 7 | Episode 15240 | Step Counts: 49 | Train Reward: 89.17 | Global Steps: 1388726 | Loss: 108.07
# Worker 0 | Episode 15260 | Step Counts: 52 | Train Reward: 93.17 | Global Steps: 1389755 | Loss: 52.85
# Worker 6 | Episode 15280 | Step Counts: 48 | Train Reward: 87.89 | Global Steps: 1390919 | Loss: -15.06
# Worker 2 | Episode 15300 | Step Counts: 111 | Train Reward: 267.60 | Global Steps: 1393017 | Loss: 406.39
# Worker 1 | Episode 15320 | Step Counts: 111 | Train Reward: 276.09 | Global Steps: 1394996 | Loss: 150.68
# Worker 2 | Episode 15340 | Step Counts: 117 | Train Reward: 299.55 | Global Steps: 1396966 | Loss: 587.06
# Worker 4 | Episode 15360 | Step Counts: 110 | Train Reward: 280.81 | Global Steps: 1399082 | Loss: 144.26
# Worker 0 | Episode 15380 | Step Counts: 133 | Train Reward: 274.71 | Global Steps: 1401541 | Loss: 720.81
# Worker 0 | Episode 15400 | Step Counts: 56 | Train Reward: 100.94 | Global Steps: 1403780 | Loss: 3965.73
# Worker 7 | Episode 15420 | Step Counts: 54 | Train Reward: 98.64 | Global Steps: 1405546 | Loss: 4886.10
# Worker 1 | Episode 15440 | Step Counts: 171 | Train Reward: 499.17 | Global Steps: 1407615 | Loss: 3154.26
# Worker 1 | Episode 15460 | Step Counts: 110 | Train Reward: 269.88 | Global Steps: 1410161 | Loss: 6584.60
# Worker 6 | Episode 15480 | Step Counts: 128 | Train Reward: 311.63 | Global Steps: 1412697 | Loss: 1454.93
# Worker 2 | Episode 15500 | Step Counts: 117 | Train Reward: 292.26 | Global Steps: 1415203 | Loss: 2645.02
# Worker 6 | Episode 15520 | Step Counts: 105 | Train Reward: 257.33 | Global Steps: 1417264 | Loss: 2661.66
# Worker 7 | Episode 15540 | Step Counts: 102 | Train Reward: 237.06 | Global Steps: 1419299 | Loss: 837.18
# Worker 1 | Episode 15560 | Step Counts: 108 | Train Reward: 257.97 | Global Steps: 1421287 | Loss: 6112.97
# Worker 5 | Episode 15580 | Step Counts: 91 | Train Reward: 185.26 | Global Steps: 1423323 | Loss: 124.61
# Worker 3 | Episode 15600 | Step Counts: 84 | Train Reward: 151.66 | Global Steps: 1425406 | Loss: -5.67
# Worker 1 | Episode 15620 | Step Counts: 93 | Train Reward: 193.04 | Global Steps: 1427459 | Loss: 9.58
# Worker 3 | Episode 15640 | Step Counts: 81 | Train Reward: 139.47 | Global Steps: 1429422 | Loss: -3.18
# Worker 2 | Episode 15660 | Step Counts: 119 | Train Reward: 276.31 | Global Steps: 1431530 | Loss: 1432.71
# Worker 0 | Episode 15680 | Step Counts: 130 | Train Reward: 324.34 | Global Steps: 1434007 | Loss: 66.31
# Worker 6 | Episode 15700 | Step Counts: 49 | Train Reward: 89.58 | Global Steps: 1436094 | Loss: 1391.99
# Worker 3 | Episode 15720 | Step Counts: 72 | Train Reward: 138.69 | Global Steps: 1437364 | Loss: 20.36
# Worker 1 | Episode 15740 | Step Counts: 77 | Train Reward: 151.51 | Global Steps: 1438763 | Loss: 84.89
# Worker 2 | Episode 15760 | Step Counts: 163 | Train Reward: 522.14 | Global Steps: 1440322 | Loss: -5.56
# Worker 3 | Episode 15780 | Step Counts: 122 | Train Reward: 337.10 | Global Steps: 1442109 | Loss: -6.00
# Worker 7 | Episode 15800 | Step Counts: 58 | Train Reward: 105.59 | Global Steps: 1443826 | Loss: 95.35
# Worker 2 | Episode 15820 | Step Counts: 98 | Train Reward: 199.62 | Global Steps: 1445755 | Loss: 2.40
# Worker 6 | Episode 15840 | Step Counts: 124 | Train Reward: 308.25 | Global Steps: 1447879 | Loss: 6.92
# Worker 7 | Episode 15860 | Step Counts: 69 | Train Reward: 130.47 | Global Steps: 1450083 | Loss: 396.53
# Worker 2 | Episode 15880 | Step Counts: 91 | Train Reward: 198.57 | Global Steps: 1451681 | Loss: 1290.80
# Worker 0 | Episode 15900 | Step Counts: 126 | Train Reward: 346.46 | Global Steps: 1453326 | Loss: 15.61
# Worker 3 | Episode 15920 | Step Counts: 49 | Train Reward: 90.01 | Global Steps: 1454805 | Loss: 348.04
# Worker 5 | Episode 15940 | Step Counts: 57 | Train Reward: 103.46 | Global Steps: 1455904 | Loss: 74.49
# Worker 0 | Episode 15960 | Step Counts: 135 | Train Reward: 350.83 | Global Steps: 1457350 | Loss: 100.91
# Worker 2 | Episode 15980 | Step Counts: 136 | Train Reward: 359.69 | Global Steps: 1460356 | Loss: 33.56
# Worker 0 | Episode 16000 | Step Counts: 38 | Train Reward: 69.37 | Global Steps: 1462212 | Loss: 1095.49
#
# Training Done!
# Mean Train Reward (last 40 episodes): 325.48 | Mean Eval Reward (last 40 episodes): 186.35

# %%
plotResults(a3c_all_results, env_names=[a3c_gym_id], use_moving_avg=False)
plotResults(a3c_all_results, env_names=[a3c_gym_id])

# %% [markdown]
# ## A3C Questions [$10 \times 3 = 30$ marks]
#
# ### Q1. Why does A3C use asynchronous updates, and what benefit does this provide over synchronous (A2C) updates?
#
# 1. A3C uses asynchronous updates in order to solve the problem of seqeuntial correlation among the observed states. Since we are training the actor and critic network and these neural networks works only by assuming that data is IID. So to make them work well, it uses asynchronous updates by multiple works which adds the grdients after their own updates without waiting for anyone. This will help in breaking this correlation issue since updates are random and can be overriden by another.
#
# 2. One major advantage of asynchronuos over synchrounous ones is high speed. Async updates took less time compared to updates in sync since workers have to wait for others to complete to some endpoint before contiuing ahead.
#
# ### Q2. What is the "stale gradient" problem in A3C and how does it affect learning?
#
# 1. In A3C, multiple workers did updates asynchrounously. They first make local copies of the global network then after observing the environment,collects the states and then computes the n-step returns for policyloss calculation so in this mean time, other workers might update the global network parameters so when this worker updates the global network then its network over which it has computed the gradients became stale since global network is quite ahead now. So then it updates the global network parameters with its stale parameters and this is known as 'stale gradeints' problem.
#
# 2. This makes the global network parameters quite unstable, making the convregence slower and due to this, global network might got stuck in some local optima.
#
# ### Q3. Compare A3C with DQN in terms of memory requirements and training paradigm.
#
# 1. Based on memory requirements:
#
#     DQN requires lot of memory for storing past experiences into the replay buffer, since the way it deals with one of the important issues in RL (ie. non IID data) is different from A3C. DQN smaples past experiences from the replay buffer randonly while A3C simply handles these issues by asynchronous updates to the global network breaking the high sequential data correlation between the continous expereinces observed. So in short, A3C memory requirements is too low compared to that of DQN.
#
# 2. Based on training paradigm:
#
#     a. DQN is an off-policy value based learning which trains the value network using the past stored expereinces by sampling some random samples from the replay buffer over each step. On the other hand, A3C is an on-policy actor-critic based learning which trains its policy network using multiple asynchronous workers updating its parameters out of sync for breaking high corelation amoing experiences.
#
#     b. For DQN-PER, we uses prioritized expereince replay buffer where the idea is to sample epereinces with higher priority (computed using TD error) so higher the td error, more chances of getting selected. While A3C is not that sample efficeint since samples collected randomly by multiple workers and dont utilize the past collected experiences to explore newer ones.

# %% [markdown]
# # Advantange Actor-Critic (A2C) [50 marks]
# <a id="a2c"></a>
#
# A2C is the synchronous, deterministic variant of A3C. Instead of using asynchronous workers, A2C waits for all parallel workers to finish their rollouts before performing a single gradient update. This makes it simpler to implement and often equally effective.
#
# **Key ideas:**
# - Uses an Actor-Critic architecture: the actor outputs a policy $\pi(a|s)$ and the critic estimates $V(s)$.
# - The advantage $A(s,a) = R_t - V(s_t)$ (or using GAE) is used to reduce variance in the policy gradient.
# - Multiple environments run in parallel (vectorized) and all updates are synchronous.
# - The loss combines: policy gradient loss, value loss, and an entropy bonus for exploration.
#
# **Policy Gradient with Advantage:**
# $$\nabla_\theta J(\theta) = \mathbb{E}\left[\nabla_\theta \log \pi_\theta(a_t|s_t) \cdot A(s_t, a_t)\right]$$
#
# Implement the A2C agent using the class structure below.
#
# ```
# class A2CAgent(nn.Module):
#     def __init__(self, envs)
#     def get_value(self, x)
#     def get_action_and_value(self, x, action=None)
#
# def train_a2c(env_id, seed, ...)
# ```

# %%
# Import all the required libraries
from torch.distributions import Categorical, Normal
import torch.nn.functional as F
from multiprocessing import Process, Queue, Barrier
import time
import copy

# %%
# ======================================================================
# A2C Hyperparameters
# ======================================================================

a2c_gym_id = "Hopper-v4"     # Environment name
a2c_learning_rate = 3e-4
a2c_seed = 21

a2c_total_timesteps = 1_464_000
a2c_num_envs = 6
a2c_num_steps = 2048

a2c_gamma = 0.99
a2c_gae_lambda = 0.95
a2c_use_gae = True

a2c_ent_coef = 1e-3
a2c_vf_coef = 0.5
a2c_max_grad_norm = 0.5
a2c_norm_adv = True

# Derived parameter
a2c_batch_size = a2c_num_envs * a2c_num_steps

print(
    f"A2C: {a2c_total_timesteps // a2c_batch_size} gradient updates on {a2c_total_timesteps}"
)
# Out:
# A2C: 119 gradient updates on 1464000

# %%
# ======================================================================
# A2C Agent Network
# ======================================================================
# This class defines the architecture for an Advantage Actor-Critic (A2C) agent.
# A2C has two parts:
# 1. A critic that estimates the value of a state (V(s)).
# 2. An actor that outputs a probability distribution over actions.
# You will create separate networks for the actor and the critic.

class A2CAgent(nn.Module):
    def __init__(self, env):
        # Initialize the A2C agent.
        # Tasks:
        # - Determine the dimensions of the observation space.
        # - Determine the number of possible actions.
        # - Create the critic network (takes state, outputs V(s)).
        # - Create the actor network (takes state, outputs action logits).

        # Your code goes here
        super(A2CAgent, self).__init__()
        self.obs_dim = env.observation_space.shape[0]
        self.is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
        self.act_dim = env.action_space.n if self.is_discrete else env.action_space.shape[0]

        self.hDim = [512, 256, 256]
        self.actor_network = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=self.hDim)
        self.critic_network = createValueNetwork(self.obs_dim, 1, hDim=self.hDim)

        if not self.is_discrete:
            self.actor_log_std = nn.Parameter(torch.full((self.act_dim,), -0.5))
            self.register_buffer('action_low', torch.FloatTensor(env.action_space.low))
            self.register_buffer('action_high', torch.FloatTensor(env.action_space.high))


    def get_value(self, x):
        """Return the value of a state from the critic network."""
        # Your code goes here
        return self.critic_network(x)

    def get_action_and_value(self, x, action=None):
        """
        Get an action from the actor and value from the critic.
        Tasks:
        - Use the actor network to produce logits over actions.
        - Convert logits into a probability distribution.
        - Sample an action from the distribution (if action is not provided).
        - Compute the log probability of the chosen action.
        - Compute the entropy of the distribution (helps with exploration).
        - Get the value of the state from the critic.

        Returns: action, log_prob, entropy, value
        """
        # Your code goes here
        value = self.get_value(x)

        if self.is_discrete:
            logits = self.actor_network(x)
            dist = torch.distributions.Categorical(logits=logits)
            if action is None:
                action = dist.sample()
            else:
                action = action.long().view(-1)
            log_prob = dist.log_prob(action)
            entropy = dist.entropy()

        else:
            mu = self.actor_network(x)
            log_std = torch.clamp(self.actor_log_std, -20, 2)
            std = torch.exp(log_std).expand_as(mu)
            dist = torch.distributions.Normal(mu, std)

            if action is None:
                action = dist.rsample()
                action = torch.max(torch.min(action, self.action_high), self.action_low)
            else:
                action = action.float()

            log_prob = dist.log_prob(action).sum(dim=-1)
            entropy = dist.entropy().sum(dim=-1)

        return action, log_prob, entropy, value

# %%
def train_a2c_single_worker(env_id=a2c_gym_id, seed=a2c_seed, total_timesteps=a2c_total_timesteps,
                          num_steps=a2c_num_steps, lr=a2c_learning_rate,
                          gamma=a2c_gamma, gae_lambda=a2c_gae_lambda, use_gae=a2c_use_gae,
                          ent_coef=a2c_ent_coef, vf_coef=a2c_vf_coef,
                          max_grad_norm=a2c_max_grad_norm, norm_adv=a2c_norm_adv):

    env = gym.make(env_id)
    env.reset(seed=seed*10)
    torch.manual_seed(seed*10)
    np.random.seed(seed*10)
    env.action_space.seed(seed*10)
    env.observation_space.seed(seed*10)
    random.seed(seed*10)
    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = 1 if is_discrete else env.action_space.shape[0]

    agent = A2CAgent(env)
    eval_agent = A2CAgent(env)
    optimizer = torch.optim.Adam(agent.parameters(), lr=lr)

    num_updates = total_timesteps // num_steps

    train_rewards = []
    total_steps_list = []
    global_steps_list = []
    trg = []
    eval_rewards = []
    erg = []
    global_steps = 0
    ep_steps, ep_reward = 0, 0.0
    completed_episodes = 0

    s, _ = env.reset()

    for update in range(num_updates):
        obs_buffer, action_buffer = [], []
        reward_buffer, done_buffer, value_buffer = [], [], []

        for step in range(num_steps):
            s_tensor = torch.tensor(s, dtype=torch.float32).unsqueeze(0)

            with torch.no_grad():
                action, logprob, _, value = agent.get_action_and_value(s_tensor)

            if is_discrete:
                action_np = action.item()
            else:
                action_np = action.squeeze(0).cpu().numpy()
                action_np = np.clip(action_np, env.action_space.low, env.action_space.high)

            s_next, reward, terminated, truncated, _ = env.step(action_np)
            done = terminated or truncated

            obs_buffer.append(s_tensor.squeeze(0))
            action_buffer.append(action if not is_discrete else action.float())
            reward_buffer.append(reward)
            done_buffer.append(float(done))
            value_buffer.append(value.squeeze())

            s = s_next
            ep_reward += reward
            ep_steps += 1
            global_steps += 1

            if done:
                train_rewards.append((completed_episodes, ep_reward))
                total_steps_list.append((completed_episodes, ep_steps))
                global_steps_list.append((completed_episodes, global_steps))
                trg.append((global_steps, ep_reward))
                completed_episodes += 1
                
                if completed_episodes % 100 == 0:
                    eval_agent.load_state_dict(agent.state_dict())
                    eval_r = evaluate_policy(eval_agent, env_id)
                    eval_rewards.append((completed_episodes, eval_r))
                    erg.append((global_steps, eval_r))

                    print(f"Global Steps: {global_steps} | Completed Episodes: {completed_episodes} | Train Reward: {ep_reward:.2f} | Eval Reward: {eval_r:.2f}")

                ep_reward, ep_steps = 0, 0
                s, _ = env.reset()

        obs_tensor = torch.stack(obs_buffer)
        actions_tensor = torch.stack(action_buffer)
        rewards_tensor = torch.tensor(reward_buffer, dtype=torch.float32)
        dones_tensor = torch.tensor(done_buffer, dtype=torch.float32)
        values_tensor = torch.stack(value_buffer).detach()

        with torch.no_grad():
            next_value = agent.get_value(torch.tensor(s, dtype=torch.float32).unsqueeze(0)).squeeze(0)

        advantages = torch.zeros_like(rewards_tensor)
        lastgaelam = 0
        for t in reversed(range(num_steps)):
            if t == num_steps - 1:
                nextnonterminal = 1.0 - dones_tensor[t]
                nextvalues = next_value
            else:
                nextnonterminal = 1.0 - dones_tensor[t+1]
                nextvalues = values_tensor[t+1]
            delta = rewards_tensor[t] + gamma * nextvalues * nextnonterminal - values_tensor[t]
            if use_gae:
                advantages[t] = lastgaelam = delta + gamma * gae_lambda * nextnonterminal * lastgaelam
            else:
                advantages[t] = delta
        
        returns = advantages + values_tensor

        if norm_adv:
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        _, new_logprob, entropy, value = agent.get_action_and_value(
            obs_tensor, actions_tensor if not is_discrete else actions_tensor.long()
        )
        value = value.view(-1)

        policy_loss = -(advantages.detach() * new_logprob).mean()
        value_loss = ((returns.detach() - value) ** 2).mean()
        entropy_loss = entropy.mean()
        
        loss = policy_loss + vf_coef * value_loss - ent_coef * entropy_loss

        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(agent.parameters(), max_grad_norm)
        optimizer.step()

    env.close()

    _, train_r = zip(*train_rewards)
    _, eval_r  = zip(*eval_rewards)

    print(f"\nTraining Done!\nMean Train Reward (last 40): {np.mean(train_r[-40:]):.2f} | Mean Eval Reward (last 40): {np.mean(eval_r[-40:]):.2f}")

    return train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg

# %%
# ======================================================================
# A2C Worker + Training Loop (multiprocessing version)
# ======================================================================
# A2C is the SYNCHRONOUS counterpart to A3C:
#   - Worker processes each run their own environment and collect rollouts.
#   - After each rollout, workers WAIT at a barrier (synchronous).
#   - The main process computes GAE and does a SINGLE gradient update.
#   - A second barrier signals workers that weights have been updated.
# This barrier-based synchronisation is the key difference from A3C.
# ======================================================================

def a2c_worker(worker_id, global_agent,
               env_id, seed, num_steps, num_updates,
               shared_obs, shared_actions, shared_logprobs,
               shared_rewards, shared_dones, shared_values,
               shared_next_obs, shared_next_done,
               collect_barrier, update_barrier, ep_queue):
    """
    A2C worker process.  Collects rollouts into shared memory buffers,
    then waits at a barrier for the main process to do a centralised update.

    Unlike A3C, this worker NEVER computes gradients or calls optimizer.step().
    The main process owns the gradient update exclusively.
    """

    #Your code goes here
    env = gym.make(env_id)
    env.reset(seed=seed*10 + worker_id)
    torch.manual_seed(seed*10 + worker_id)
    np.random.seed(seed*10 + worker_id)
    env.action_space.seed(seed*10 + worker_id)
    env.observation_space.seed(seed*10 + worker_id)
    random.seed(seed*10 + worker_id)

    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)

    s, _ = env.reset()
    ep_steps = 0

    for _ in range(num_updates):
        total_reward = 0.0

        for step in range(num_steps):
            ep_steps += 1
            s_tensor = torch.tensor(s, dtype=torch.float32).unsqueeze(0)

            with torch.no_grad():
                action, logprob, _, value = global_agent.get_action_and_value(s_tensor)

            if is_discrete:
                action_np = action.item()
                action_store = action.float()
            else:
                action_np = action.squeeze(0).cpu().numpy()
                action_np = np.clip(action_np, env.action_space.low, env.action_space.high)
                action_store = action.squeeze(0)

            s_next, reward, terminated, truncated, _ = env.step(action_np)
            done = terminated or truncated
            total_reward += reward

            shared_obs[worker_id, step] = s_tensor.squeeze(0)
            shared_actions[worker_id, step] = action_store
            shared_logprobs[worker_id, step] = logprob.item()
            shared_rewards[worker_id, step] = reward
            shared_dones[worker_id, step] = float(done)
            shared_values[worker_id, step] = value.squeeze().detach()

            s = s_next
            if done:
                ep_queue.put((worker_id, total_reward, ep_steps))
                total_reward = 0.0
                ep_steps = 0
                s, _ = env.reset()

        s_tensor = torch.tensor(s, dtype=torch.float32).unsqueeze(0)
        shared_next_obs [worker_id] = s_tensor.squeeze(0)
        shared_next_done[worker_id] = float(done)

        collect_barrier.wait()
        update_barrier.wait()

    env.close()

def train_a2c(env_id=a2c_gym_id, seed=a2c_seed, total_timesteps=a2c_total_timesteps,
              num_envs=a2c_num_envs, num_steps=a2c_num_steps, lr=a2c_learning_rate,
              gamma=a2c_gamma, gae_lambda=a2c_gae_lambda, use_gae=a2c_use_gae,
              ent_coef=a2c_ent_coef, vf_coef=a2c_vf_coef,
              max_grad_norm=a2c_max_grad_norm, norm_adv=a2c_norm_adv):
    """
    A2C training with torch.multiprocessing.

    - num_envs worker processes each run their own environment.
    - Workers collect num_steps of experience into shared memory buffers.
    - A barrier synchronises: all workers must finish before the update.
    - The main process computes GAE advantages and does ONE gradient step.
    - A second barrier signals workers that weights have been updated.
    """

    #Your code goes here
    if num_envs == 1:
        return train_a2c_single_worker(
            env_id, seed, total_timesteps, num_steps, lr,
            gamma, gae_lambda, use_gae, ent_coef, vf_coef,
            max_grad_norm, norm_adv
        )

    env = gym.make(env_id)
    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = 1 if is_discrete else env.action_space.shape[0]
    env.close()

    global_agent = A2CAgent(gym.make(env_id))
    global_agent.share_memory()

    eval_agent = A2CAgent(gym.make(env_id))

    optimizer = torch.optim.Adam(global_agent.parameters(), lr=lr)
    num_updates = total_timesteps // (num_envs * num_steps)

    shared_obs = torch.zeros(num_envs, num_steps, obs_dim).share_memory_()
    shared_actions = torch.zeros(num_envs, num_steps, act_dim).share_memory_()
    shared_logprobs = torch.zeros(num_envs, num_steps).share_memory_()
    shared_rewards = torch.zeros(num_envs, num_steps).share_memory_()
    shared_dones = torch.zeros(num_envs, num_steps).share_memory_()
    shared_values = torch.zeros(num_envs, num_steps).share_memory_()
    shared_next_obs = torch.zeros(num_envs, obs_dim).share_memory_()
    shared_next_done = torch.zeros(num_envs).share_memory_()

    collect_barrier = mp.Barrier(num_envs + 1)
    update_barrier = mp.Barrier(num_envs + 1)
    ep_queue = mp.Queue()

    train_rewards = []
    global_steps_list = []
    eval_rewards = []
    total_steps_list = []
    trg = []
    erg = []

    completed_episodes = 0
    global_steps = 0

    processes = []
    for i in range(num_envs):
        p = mp.Process(target=a2c_worker, args=(
            i, global_agent,
            env_id, seed, num_steps, num_updates,
            shared_obs, shared_actions, shared_logprobs,
            shared_rewards, shared_dones, shared_values,
            shared_next_obs, shared_next_done,
            collect_barrier, update_barrier, ep_queue
        ))
        p.start()
        processes.append(p)

    for update in range(num_updates):
        collect_barrier.wait()

        with torch.no_grad():
            next_value = global_agent.get_value(shared_next_obs).squeeze(-1)

        advantages = torch.zeros_like(shared_rewards)
        lastgaelam = torch.zeros(num_envs)

        for t in reversed(range(num_steps)):
            if t == num_steps - 1:
                nextnonterminal = 1.0 - shared_next_done
                nextvalues = next_value
            else:
                nextnonterminal = 1.0 - shared_dones[:, t + 1]
                nextvalues = shared_values[:, t + 1]

            delta = shared_rewards[:, t] + gamma * nextvalues * nextnonterminal - shared_values[:, t]

            if use_gae:
                advantages[:, t] = lastgaelam = delta + gamma * gae_lambda * nextnonterminal * lastgaelam
            else:
                advantages[:, t] = delta

        returns = advantages + shared_values

        b_obs = shared_obs.reshape(-1, obs_dim)
        b_actions = shared_actions.reshape(-1, act_dim)
        b_advantages = advantages.reshape(-1)
        b_returns = returns.reshape(-1)

        if norm_adv:
            b_advantages = (b_advantages - b_advantages.mean()) / (b_advantages.std() + 1e-8)

        _, new_logprob, entropy, value = global_agent.get_action_and_value(
            b_obs,
            b_actions.long().view(-1) if is_discrete else b_actions
        )
        value = value.view(-1)

        policy_loss = -(b_advantages * new_logprob).mean()
        value_loss = ((b_returns - value) ** 2).mean()
        entropy_loss = entropy.mean()
        loss = policy_loss + vf_coef * value_loss - ent_coef * entropy_loss

        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(global_agent.parameters(), max_grad_norm)
        optimizer.step()

        update_barrier.wait()

        while not ep_queue.empty():
            try:
                worker_id, train_r, ep_steps = ep_queue.get_nowait()
                completed_episodes += 1
                global_steps += ep_steps
                train_rewards.append((completed_episodes, train_r))
                global_steps_list.append((completed_episodes, global_steps))
                total_steps_list.append((completed_episodes, ep_steps))
                trg.append((global_steps, train_r))

                if completed_episodes % 20 == 0:
                    eval_agent.load_state_dict(global_agent.state_dict())
                    eval_r = evaluate_policy(eval_agent, env_id)
                    eval_rewards.append((completed_episodes, eval_r))
                    erg.append((global_steps, eval_r))

                if completed_episodes % 100 == 0:
                    print(f"[worker_id: {worker_id}] Global Steps: {global_steps:.0f} | Completed Episodes: {completed_episodes:.0f} | Train Rewards: {train_r:.2f} | "
                          f"Eval Rewards: {eval_r:.2f} | Steps (this episode): {ep_steps:.0f}")
            except:
                break

    for p in processes:
        p.join()

    if not train_rewards or not eval_rewards:
        print("No episodes or evals recorded.")
        return train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg

    _, train_r = zip(*train_rewards)
    _, eval_r  = zip(*eval_rewards)

    print(f"\nTraining Done!\nMean Train Reward (last 40): {np.mean(train_r[-40:]):.2f} | Mean Eval Reward (last 40): {np.mean(eval_r[-40:]):.2f}")

    return train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg

# %%
# Run the A2C training on multiple environments and store the results.
# Iterate through the environments: 'Pendulum-v1', 'Hopper-v4', and 'HalfCheetah-v4'.

# For each environment, print a header so that the training progress is clear.

# Call the function train_a2c() with the environment name and a total training
# Store the returned training results in a dictionary.


# Plot the learning curve:
#   - First plot the raw returns with a light transparency.
#   - Then compute a moving-average smoothing using numpy convolution
#     to show a cleaner trend of the learning progress.


# Display the plot for each environment.

a2c_plot_config = {}

print(f"Running {a2c_gym_id}")
train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg = train_a2c()

a2c_plot_config[a2c_gym_id] = {
    "Train Rewards": {"A2C": [train_rewards]},
    "Eval Rewards": {"A2C": [eval_rewards]},
    "Total Steps": {"A2C": [total_steps_list]},
    "Global Steps": {"A2C": [global_steps_list]},
    "Train Rewards (over global steps)": {"A2C": [trg]},
    "Eval Rewards (over global steps)": {"A2C": [erg]}
}

# Seed used for this experimnet are [210, 211, 212, 213, 214, 215]
# Out:
# Running Hopper-v4
# [worker_id: 1] Global Steps: 1943 | Completed Episodes: 100 | Train Rewards: 74.69 | Eval Rewards: 15.38 | Steps (this episode): 47
# [worker_id: 5] Global Steps: 3865 | Completed Episodes: 200 | Train Rewards: 12.30 | Eval Rewards: 11.90 | Steps (this episode): 17
# [worker_id: 0] Global Steps: 5748 | Completed Episodes: 300 | Train Rewards: 16.88 | Eval Rewards: 18.80 | Steps (this episode): 17
# [worker_id: 1] Global Steps: 7791 | Completed Episodes: 400 | Train Rewards: 33.40 | Eval Rewards: 74.33 | Steps (this episode): 25
# [worker_id: 5] Global Steps: 10077 | Completed Episodes: 500 | Train Rewards: 14.62 | Eval Rewards: 22.88 | Steps (this episode): 14
# [worker_id: 4] Global Steps: 12360 | Completed Episodes: 600 | Train Rewards: 9.37 | Eval Rewards: 15.20 | Steps (this episode): 19
# [worker_id: 4] Global Steps: 15606 | Completed Episodes: 700 | Train Rewards: 24.90 | Eval Rewards: 25.33 | Steps (this episode): 24
# [worker_id: 3] Global Steps: 18605 | Completed Episodes: 800 | Train Rewards: 45.60 | Eval Rewards: 99.61 | Steps (this episode): 27
# [worker_id: 5] Global Steps: 21761 | Completed Episodes: 900 | Train Rewards: 113.43 | Eval Rewards: 54.91 | Steps (this episode): 73
# [worker_id: 5] Global Steps: 25380 | Completed Episodes: 1000 | Train Rewards: 70.82 | Eval Rewards: 54.78 | Steps (this episode): 53
# [worker_id: 2] Global Steps: 30186 | Completed Episodes: 1100 | Train Rewards: 53.94 | Eval Rewards: 198.84 | Steps (this episode): 41
# [worker_id: 4] Global Steps: 35283 | Completed Episodes: 1200 | Train Rewards: 189.96 | Eval Rewards: 92.37 | Steps (this episode): 102
# [worker_id: 4] Global Steps: 39760 | Completed Episodes: 1300 | Train Rewards: 55.59 | Eval Rewards: 93.63 | Steps (this episode): 33
# [worker_id: 4] Global Steps: 44601 | Completed Episodes: 1400 | Train Rewards: 59.03 | Eval Rewards: 80.04 | Steps (this episode): 36
# [worker_id: 3] Global Steps: 48992 | Completed Episodes: 1500 | Train Rewards: 59.39 | Eval Rewards: 81.25 | Steps (this episode): 35
# [worker_id: 2] Global Steps: 53806 | Completed Episodes: 1600 | Train Rewards: 119.69 | Eval Rewards: 46.39 | Steps (this episode): 85
# [worker_id: 2] Global Steps: 58418 | Completed Episodes: 1700 | Train Rewards: 69.26 | Eval Rewards: 57.89 | Steps (this episode): 41
# [worker_id: 1] Global Steps: 63221 | Completed Episodes: 1800 | Train Rewards: 70.19 | Eval Rewards: 67.32 | Steps (this episode): 43
# [worker_id: 5] Global Steps: 67513 | Completed Episodes: 1900 | Train Rewards: 73.03 | Eval Rewards: 153.03 | Steps (this episode): 43
# [worker_id: 1] Global Steps: 71968 | Completed Episodes: 2000 | Train Rewards: 48.91 | Eval Rewards: 155.75 | Steps (this episode): 29
# [worker_id: 1] Global Steps: 76573 | Completed Episodes: 2100 | Train Rewards: 110.77 | Eval Rewards: 140.81 | Steps (this episode): 64
# [worker_id: 1] Global Steps: 81361 | Completed Episodes: 2200 | Train Rewards: 140.82 | Eval Rewards: 59.55 | Steps (this episode): 71
# [worker_id: 4] Global Steps: 86674 | Completed Episodes: 2300 | Train Rewards: 253.04 | Eval Rewards: 103.01 | Steps (this episode): 133
# [worker_id: 3] Global Steps: 92102 | Completed Episodes: 2400 | Train Rewards: 68.10 | Eval Rewards: 209.96 | Steps (this episode): 40
# [worker_id: 2] Global Steps: 97501 | Completed Episodes: 2500 | Train Rewards: 69.45 | Eval Rewards: 116.06 | Steps (this episode): 43
# [worker_id: 4] Global Steps: 104522 | Completed Episodes: 2600 | Train Rewards: 185.44 | Eval Rewards: 181.59 | Steps (this episode): 89
# [worker_id: 1] Global Steps: 111068 | Completed Episodes: 2700 | Train Rewards: 191.39 | Eval Rewards: 239.07 | Steps (this episode): 97
# [worker_id: 0] Global Steps: 119789 | Completed Episodes: 2800 | Train Rewards: 211.52 | Eval Rewards: 220.10 | Steps (this episode): 102
# [worker_id: 2] Global Steps: 128875 | Completed Episodes: 2900 | Train Rewards: 114.01 | Eval Rewards: 106.04 | Steps (this episode): 68
# [worker_id: 1] Global Steps: 138416 | Completed Episodes: 3000 | Train Rewards: 206.39 | Eval Rewards: 214.12 | Steps (this episode): 107
# [worker_id: 5] Global Steps: 147515 | Completed Episodes: 3100 | Train Rewards: 136.14 | Eval Rewards: 240.58 | Steps (this episode): 108
# [worker_id: 3] Global Steps: 156300 | Completed Episodes: 3200 | Train Rewards: 224.14 | Eval Rewards: 70.57 | Steps (this episode): 104
# [worker_id: 4] Global Steps: 165087 | Completed Episodes: 3300 | Train Rewards: 103.36 | Eval Rewards: 103.46 | Steps (this episode): 62
# [worker_id: 4] Global Steps: 173855 | Completed Episodes: 3400 | Train Rewards: 227.01 | Eval Rewards: 170.84 | Steps (this episode): 111
# [worker_id: 2] Global Steps: 182352 | Completed Episodes: 3500 | Train Rewards: 126.27 | Eval Rewards: 225.89 | Steps (this episode): 70
# [worker_id: 5] Global Steps: 191394 | Completed Episodes: 3600 | Train Rewards: 204.22 | Eval Rewards: 212.49 | Steps (this episode): 101
# [worker_id: 2] Global Steps: 200320 | Completed Episodes: 3700 | Train Rewards: 210.33 | Eval Rewards: 145.52 | Steps (this episode): 106
# [worker_id: 0] Global Steps: 209329 | Completed Episodes: 3800 | Train Rewards: 192.91 | Eval Rewards: 91.17 | Steps (this episode): 104
# [worker_id: 4] Global Steps: 218836 | Completed Episodes: 3900 | Train Rewards: 192.81 | Eval Rewards: 139.03 | Steps (this episode): 108
# [worker_id: 1] Global Steps: 228794 | Completed Episodes: 4000 | Train Rewards: 198.51 | Eval Rewards: 100.34 | Steps (this episode): 104
# [worker_id: 4] Global Steps: 238842 | Completed Episodes: 4100 | Train Rewards: 211.85 | Eval Rewards: 207.37 | Steps (this episode): 108
# [worker_id: 0] Global Steps: 249071 | Completed Episodes: 4200 | Train Rewards: 123.77 | Eval Rewards: 229.46 | Steps (this episode): 72
# [worker_id: 0] Global Steps: 259046 | Completed Episodes: 4300 | Train Rewards: 207.16 | Eval Rewards: 222.69 | Steps (this episode): 108
# [worker_id: 1] Global Steps: 269092 | Completed Episodes: 4400 | Train Rewards: 171.50 | Eval Rewards: 138.97 | Steps (this episode): 94
# [worker_id: 2] Global Steps: 278399 | Completed Episodes: 4500 | Train Rewards: 213.31 | Eval Rewards: 213.79 | Steps (this episode): 110
# [worker_id: 4] Global Steps: 287315 | Completed Episodes: 4600 | Train Rewards: 184.51 | Eval Rewards: 124.79 | Steps (this episode): 100
# [worker_id: 4] Global Steps: 296253 | Completed Episodes: 4700 | Train Rewards: 200.77 | Eval Rewards: 220.58 | Steps (this episode): 101
# [worker_id: 1] Global Steps: 305423 | Completed Episodes: 4800 | Train Rewards: 62.90 | Eval Rewards: 176.90 | Steps (this episode): 36
# [worker_id: 1] Global Steps: 313981 | Completed Episodes: 4900 | Train Rewards: 198.35 | Eval Rewards: 194.47 | Steps (this episode): 101
# [worker_id: 4] Global Steps: 322800 | Completed Episodes: 5000 | Train Rewards: 150.51 | Eval Rewards: 133.37 | Steps (this episode): 82
# [worker_id: 3] Global Steps: 331426 | Completed Episodes: 5100 | Train Rewards: 183.45 | Eval Rewards: 176.08 | Steps (this episode): 104
# [worker_id: 3] Global Steps: 340569 | Completed Episodes: 5200 | Train Rewards: 200.08 | Eval Rewards: 144.40 | Steps (this episode): 112
# [worker_id: 0] Global Steps: 350073 | Completed Episodes: 5300 | Train Rewards: 209.09 | Eval Rewards: 211.42 | Steps (this episode): 114
# [worker_id: 0] Global Steps: 359735 | Completed Episodes: 5400 | Train Rewards: 153.77 | Eval Rewards: 208.00 | Steps (this episode): 86
# [worker_id: 1] Global Steps: 369917 | Completed Episodes: 5500 | Train Rewards: 186.19 | Eval Rewards: 163.62 | Steps (this episode): 98
# [worker_id: 2] Global Steps: 380592 | Completed Episodes: 5600 | Train Rewards: 152.71 | Eval Rewards: 179.91 | Steps (this episode): 80
# [worker_id: 5] Global Steps: 391443 | Completed Episodes: 5700 | Train Rewards: 167.97 | Eval Rewards: 217.76 | Steps (this episode): 95
# [worker_id: 3] Global Steps: 402278 | Completed Episodes: 5800 | Train Rewards: 182.66 | Eval Rewards: 159.43 | Steps (this episode): 112
# [worker_id: 1] Global Steps: 413294 | Completed Episodes: 5900 | Train Rewards: 171.29 | Eval Rewards: 98.53 | Steps (this episode): 102
# [worker_id: 4] Global Steps: 424362 | Completed Episodes: 6000 | Train Rewards: 240.23 | Eval Rewards: 207.71 | Steps (this episode): 152
# [worker_id: 2] Global Steps: 435910 | Completed Episodes: 6100 | Train Rewards: 188.63 | Eval Rewards: 207.46 | Steps (this episode): 117
# [worker_id: 4] Global Steps: 447147 | Completed Episodes: 6200 | Train Rewards: 111.37 | Eval Rewards: 207.04 | Steps (this episode): 78
# [worker_id: 4] Global Steps: 458828 | Completed Episodes: 6300 | Train Rewards: 206.56 | Eval Rewards: 141.71 | Steps (this episode): 120
# [worker_id: 5] Global Steps: 470388 | Completed Episodes: 6400 | Train Rewards: 214.32 | Eval Rewards: 240.41 | Steps (this episode): 128
# [worker_id: 2] Global Steps: 481858 | Completed Episodes: 6500 | Train Rewards: 212.47 | Eval Rewards: 195.01 | Steps (this episode): 126
# [worker_id: 3] Global Steps: 493081 | Completed Episodes: 6600 | Train Rewards: 191.68 | Eval Rewards: 158.94 | Steps (this episode): 111
# [worker_id: 1] Global Steps: 504082 | Completed Episodes: 6700 | Train Rewards: 149.27 | Eval Rewards: 198.34 | Steps (this episode): 125
# [worker_id: 1] Global Steps: 515217 | Completed Episodes: 6800 | Train Rewards: 168.15 | Eval Rewards: 204.76 | Steps (this episode): 97
# [worker_id: 4] Global Steps: 526061 | Completed Episodes: 6900 | Train Rewards: 185.01 | Eval Rewards: 179.42 | Steps (this episode): 109
# [worker_id: 5] Global Steps: 536755 | Completed Episodes: 7000 | Train Rewards: 134.69 | Eval Rewards: 176.19 | Steps (this episode): 78
# [worker_id: 3] Global Steps: 547449 | Completed Episodes: 7100 | Train Rewards: 128.15 | Eval Rewards: 193.54 | Steps (this episode): 74
# [worker_id: 5] Global Steps: 558460 | Completed Episodes: 7200 | Train Rewards: 168.35 | Eval Rewards: 199.29 | Steps (this episode): 104
# [worker_id: 3] Global Steps: 569232 | Completed Episodes: 7300 | Train Rewards: 183.95 | Eval Rewards: 206.75 | Steps (this episode): 110
# [worker_id: 5] Global Steps: 580514 | Completed Episodes: 7400 | Train Rewards: 186.89 | Eval Rewards: 195.37 | Steps (this episode): 115
# [worker_id: 4] Global Steps: 591901 | Completed Episodes: 7500 | Train Rewards: 197.41 | Eval Rewards: 189.57 | Steps (this episode): 120
# [worker_id: 3] Global Steps: 602958 | Completed Episodes: 7600 | Train Rewards: 162.46 | Eval Rewards: 203.91 | Steps (this episode): 101
# [worker_id: 1] Global Steps: 613986 | Completed Episodes: 7700 | Train Rewards: 166.64 | Eval Rewards: 201.31 | Steps (this episode): 101
# [worker_id: 3] Global Steps: 624403 | Completed Episodes: 7800 | Train Rewards: 167.71 | Eval Rewards: 166.70 | Steps (this episode): 96
# [worker_id: 2] Global Steps: 634125 | Completed Episodes: 7900 | Train Rewards: 165.16 | Eval Rewards: 154.29 | Steps (this episode): 100
# [worker_id: 2] Global Steps: 642588 | Completed Episodes: 8000 | Train Rewards: 199.80 | Eval Rewards: 77.10 | Steps (this episode): 132
# [worker_id: 1] Global Steps: 650456 | Completed Episodes: 8100 | Train Rewards: 137.18 | Eval Rewards: 74.15 | Steps (this episode): 88
# [worker_id: 4] Global Steps: 657977 | Completed Episodes: 8200 | Train Rewards: 157.34 | Eval Rewards: 90.10 | Steps (this episode): 98
# [worker_id: 2] Global Steps: 665420 | Completed Episodes: 8300 | Train Rewards: 183.48 | Eval Rewards: 54.98 | Steps (this episode): 124
# [worker_id: 1] Global Steps: 672032 | Completed Episodes: 8400 | Train Rewards: 105.37 | Eval Rewards: 176.26 | Steps (this episode): 71
# [worker_id: 1] Global Steps: 679082 | Completed Episodes: 8500 | Train Rewards: 83.77 | Eval Rewards: 161.38 | Steps (this episode): 57
# [worker_id: 0] Global Steps: 686048 | Completed Episodes: 8600 | Train Rewards: 83.50 | Eval Rewards: 91.71 | Steps (this episode): 57
# [worker_id: 1] Global Steps: 693200 | Completed Episodes: 8700 | Train Rewards: 164.31 | Eval Rewards: 118.23 | Steps (this episode): 104
# [worker_id: 0] Global Steps: 700740 | Completed Episodes: 8800 | Train Rewards: 151.33 | Eval Rewards: 74.78 | Steps (this episode): 95
# [worker_id: 0] Global Steps: 708530 | Completed Episodes: 8900 | Train Rewards: 78.28 | Eval Rewards: 164.88 | Steps (this episode): 53
# [worker_id: 3] Global Steps: 716663 | Completed Episodes: 9000 | Train Rewards: 135.24 | Eval Rewards: 161.86 | Steps (this episode): 85
# [worker_id: 4] Global Steps: 724891 | Completed Episodes: 9100 | Train Rewards: 37.02 | Eval Rewards: 154.98 | Steps (this episode): 97
# [worker_id: 2] Global Steps: 734032 | Completed Episodes: 9200 | Train Rewards: 134.62 | Eval Rewards: 159.30 | Steps (this episode): 85
# [worker_id: 2] Global Steps: 743367 | Completed Episodes: 9300 | Train Rewards: 173.04 | Eval Rewards: 166.32 | Steps (this episode): 106
# [worker_id: 0] Global Steps: 753039 | Completed Episodes: 9400 | Train Rewards: 168.76 | Eval Rewards: 171.84 | Steps (this episode): 104
# [worker_id: 0] Global Steps: 762693 | Completed Episodes: 9500 | Train Rewards: 157.34 | Eval Rewards: 187.30 | Steps (this episode): 90
# [worker_id: 5] Global Steps: 772645 | Completed Episodes: 9600 | Train Rewards: 158.13 | Eval Rewards: 159.63 | Steps (this episode): 92
# [worker_id: 1] Global Steps: 782546 | Completed Episodes: 9700 | Train Rewards: 170.74 | Eval Rewards: 174.24 | Steps (this episode): 97
# [worker_id: 2] Global Steps: 792270 | Completed Episodes: 9800 | Train Rewards: 170.80 | Eval Rewards: 180.06 | Steps (this episode): 98
# [worker_id: 2] Global Steps: 802002 | Completed Episodes: 9900 | Train Rewards: 145.59 | Eval Rewards: 140.10 | Steps (this episode): 83
# [worker_id: 4] Global Steps: 811611 | Completed Episodes: 10000 | Train Rewards: 152.29 | Eval Rewards: 142.73 | Steps (this episode): 86
# [worker_id: 4] Global Steps: 820411 | Completed Episodes: 10100 | Train Rewards: 154.08 | Eval Rewards: 169.66 | Steps (this episode): 88
# [worker_id: 0] Global Steps: 829202 | Completed Episodes: 10200 | Train Rewards: 164.99 | Eval Rewards: 127.82 | Steps (this episode): 94
# [worker_id: 2] Global Steps: 837846 | Completed Episodes: 10300 | Train Rewards: 162.70 | Eval Rewards: 165.07 | Steps (this episode): 92
# [worker_id: 5] Global Steps: 846444 | Completed Episodes: 10400 | Train Rewards: 89.03 | Eval Rewards: 159.47 | Steps (this episode): 52
# [worker_id: 3] Global Steps: 855155 | Completed Episodes: 10500 | Train Rewards: 170.94 | Eval Rewards: 189.51 | Steps (this episode): 98
# [worker_id: 1] Global Steps: 864424 | Completed Episodes: 10600 | Train Rewards: 175.34 | Eval Rewards: 122.31 | Steps (this episode): 100
# [worker_id: 0] Global Steps: 873548 | Completed Episodes: 10700 | Train Rewards: 195.72 | Eval Rewards: 188.27 | Steps (this episode): 114
# [worker_id: 4] Global Steps: 883409 | Completed Episodes: 10800 | Train Rewards: 145.46 | Eval Rewards: 177.13 | Steps (this episode): 83
# [worker_id: 1] Global Steps: 893464 | Completed Episodes: 10900 | Train Rewards: 169.39 | Eval Rewards: 171.13 | Steps (this episode): 96
# [worker_id: 4] Global Steps: 903403 | Completed Episodes: 11000 | Train Rewards: 180.20 | Eval Rewards: 153.45 | Steps (this episode): 106
# [worker_id: 0] Global Steps: 912948 | Completed Episodes: 11100 | Train Rewards: 156.64 | Eval Rewards: 164.28 | Steps (this episode): 97
# [worker_id: 4] Global Steps: 922004 | Completed Episodes: 11200 | Train Rewards: 82.06 | Eval Rewards: 78.13 | Steps (this episode): 56
# [worker_id: 5] Global Steps: 929514 | Completed Episodes: 11300 | Train Rewards: 156.86 | Eval Rewards: 74.76 | Steps (this episode): 94
# [worker_id: 1] Global Steps: 935955 | Completed Episodes: 11400 | Train Rewards: 89.97 | Eval Rewards: 51.41 | Steps (this episode): 62
# [worker_id: 5] Global Steps: 941210 | Completed Episodes: 11500 | Train Rewards: 60.66 | Eval Rewards: 41.55 | Steps (this episode): 43
# [worker_id: 0] Global Steps: 946320 | Completed Episodes: 11600 | Train Rewards: 49.92 | Eval Rewards: 71.21 | Steps (this episode): 46
# [worker_id: 2] Global Steps: 950601 | Completed Episodes: 11700 | Train Rewards: 95.36 | Eval Rewards: 59.36 | Steps (this episode): 65
# [worker_id: 3] Global Steps: 955190 | Completed Episodes: 11800 | Train Rewards: 21.74 | Eval Rewards: 85.29 | Steps (this episode): 19
# [worker_id: 0] Global Steps: 959660 | Completed Episodes: 11900 | Train Rewards: 49.82 | Eval Rewards: 66.16 | Steps (this episode): 36
# [worker_id: 3] Global Steps: 963817 | Completed Episodes: 12000 | Train Rewards: 68.41 | Eval Rewards: 40.89 | Steps (this episode): 48
# [worker_id: 4] Global Steps: 967900 | Completed Episodes: 12100 | Train Rewards: 21.81 | Eval Rewards: 49.40 | Steps (this episode): 19
# [worker_id: 5] Global Steps: 972050 | Completed Episodes: 12200 | Train Rewards: 50.96 | Eval Rewards: 155.74 | Steps (this episode): 37
# [worker_id: 0] Global Steps: 976589 | Completed Episodes: 12300 | Train Rewards: 32.95 | Eval Rewards: 60.79 | Steps (this episode): 26
# [worker_id: 1] Global Steps: 980775 | Completed Episodes: 12400 | Train Rewards: 44.16 | Eval Rewards: 82.55 | Steps (this episode): 33
# [worker_id: 2] Global Steps: 985063 | Completed Episodes: 12500 | Train Rewards: 52.42 | Eval Rewards: 77.20 | Steps (this episode): 38
# [worker_id: 4] Global Steps: 989240 | Completed Episodes: 12600 | Train Rewards: 54.39 | Eval Rewards: 78.87 | Steps (this episode): 39
# [worker_id: 2] Global Steps: 993536 | Completed Episodes: 12700 | Train Rewards: 33.06 | Eval Rewards: 92.82 | Steps (this episode): 26
# [worker_id: 3] Global Steps: 998093 | Completed Episodes: 12800 | Train Rewards: 28.22 | Eval Rewards: 96.43 | Steps (this episode): 23
# [worker_id: 4] Global Steps: 1002726 | Completed Episodes: 12900 | Train Rewards: 70.74 | Eval Rewards: 74.85 | Steps (this episode): 49
# [worker_id: 5] Global Steps: 1007531 | Completed Episodes: 13000 | Train Rewards: 19.00 | Eval Rewards: 62.18 | Steps (this episode): 40
# [worker_id: 4] Global Steps: 1012869 | Completed Episodes: 13100 | Train Rewards: 88.42 | Eval Rewards: 94.68 | Steps (this episode): 60
# [worker_id: 4] Global Steps: 1018644 | Completed Episodes: 13200 | Train Rewards: 64.49 | Eval Rewards: 84.58 | Steps (this episode): 45
# [worker_id: 1] Global Steps: 1024985 | Completed Episodes: 13300 | Train Rewards: 84.86 | Eval Rewards: 167.65 | Steps (this episode): 58
# [worker_id: 3] Global Steps: 1032491 | Completed Episodes: 13400 | Train Rewards: 102.33 | Eval Rewards: 168.39 | Steps (this episode): 69
# [worker_id: 2] Global Steps: 1041468 | Completed Episodes: 13500 | Train Rewards: 150.23 | Eval Rewards: 194.42 | Steps (this episode): 92
# [worker_id: 1] Global Steps: 1051091 | Completed Episodes: 13600 | Train Rewards: 177.37 | Eval Rewards: 157.52 | Steps (this episode): 107
# [worker_id: 3] Global Steps: 1060943 | Completed Episodes: 13700 | Train Rewards: 171.73 | Eval Rewards: 152.24 | Steps (this episode): 106
# [worker_id: 3] Global Steps: 1070932 | Completed Episodes: 13800 | Train Rewards: 159.88 | Eval Rewards: 155.62 | Steps (this episode): 93
# [worker_id: 2] Global Steps: 1080912 | Completed Episodes: 13900 | Train Rewards: 169.88 | Eval Rewards: 176.61 | Steps (this episode): 102
# [worker_id: 2] Global Steps: 1091011 | Completed Episodes: 14000 | Train Rewards: 174.28 | Eval Rewards: 170.55 | Steps (this episode): 101
# [worker_id: 2] Global Steps: 1101118 | Completed Episodes: 14100 | Train Rewards: 176.08 | Eval Rewards: 184.09 | Steps (this episode): 101
# [worker_id: 3] Global Steps: 1111177 | Completed Episodes: 14200 | Train Rewards: 168.82 | Eval Rewards: 177.43 | Steps (this episode): 94
# [worker_id: 2] Global Steps: 1121028 | Completed Episodes: 14300 | Train Rewards: 170.60 | Eval Rewards: 158.11 | Steps (this episode): 96
# [worker_id: 0] Global Steps: 1130579 | Completed Episodes: 14400 | Train Rewards: 118.56 | Eval Rewards: 171.39 | Steps (this episode): 107
# [worker_id: 4] Global Steps: 1140106 | Completed Episodes: 14500 | Train Rewards: 204.91 | Eval Rewards: 169.53 | Steps (this episode): 125
# [worker_id: 1] Global Steps: 1149791 | Completed Episodes: 14600 | Train Rewards: 174.68 | Eval Rewards: 174.06 | Steps (this episode): 100
# [worker_id: 3] Global Steps: 1159587 | Completed Episodes: 14700 | Train Rewards: 171.65 | Eval Rewards: 172.23 | Steps (this episode): 97
# [worker_id: 5] Global Steps: 1169666 | Completed Episodes: 14800 | Train Rewards: 179.31 | Eval Rewards: 196.17 | Steps (this episode): 106
# [worker_id: 2] Global Steps: 1179897 | Completed Episodes: 14900 | Train Rewards: 168.23 | Eval Rewards: 180.90 | Steps (this episode): 96
# [worker_id: 3] Global Steps: 1190413 | Completed Episodes: 15000 | Train Rewards: 182.09 | Eval Rewards: 173.10 | Steps (this episode): 107
# [worker_id: 3] Global Steps: 1200923 | Completed Episodes: 15100 | Train Rewards: 186.35 | Eval Rewards: 185.52 | Steps (this episode): 109
# [worker_id: 2] Global Steps: 1210728 | Completed Episodes: 15200 | Train Rewards: 172.72 | Eval Rewards: 178.19 | Steps (this episode): 101
# [worker_id: 4] Global Steps: 1219467 | Completed Episodes: 15300 | Train Rewards: 95.94 | Eval Rewards: 173.00 | Steps (this episode): 65
# [worker_id: 5] Global Steps: 1226314 | Completed Episodes: 15400 | Train Rewards: 89.28 | Eval Rewards: 102.53 | Steps (this episode): 61
# [worker_id: 5] Global Steps: 1232529 | Completed Episodes: 15500 | Train Rewards: 75.00 | Eval Rewards: 31.31 | Steps (this episode): 52
# [worker_id: 0] Global Steps: 1237647 | Completed Episodes: 15600 | Train Rewards: 80.10 | Eval Rewards: 33.04 | Steps (this episode): 55
# [worker_id: 1] Global Steps: 1242802 | Completed Episodes: 15700 | Train Rewards: 58.74 | Eval Rewards: 54.48 | Steps (this episode): 41
# [worker_id: 3] Global Steps: 1246912 | Completed Episodes: 15800 | Train Rewards: 46.30 | Eval Rewards: 56.50 | Steps (this episode): 34
# [worker_id: 1] Global Steps: 1251178 | Completed Episodes: 15900 | Train Rewards: 86.52 | Eval Rewards: 105.90 | Steps (this episode): 59
# [worker_id: 4] Global Steps: 1255414 | Completed Episodes: 16000 | Train Rewards: 36.82 | Eval Rewards: 47.66 | Steps (this episode): 28
# [worker_id: 2] Global Steps: 1259149 | Completed Episodes: 16100 | Train Rewards: 59.35 | Eval Rewards: 50.41 | Steps (this episode): 42
# [worker_id: 4] Global Steps: 1262901 | Completed Episodes: 16200 | Train Rewards: 70.82 | Eval Rewards: 54.86 | Steps (this episode): 49
# [worker_id: 4] Global Steps: 1266858 | Completed Episodes: 16300 | Train Rewards: 32.85 | Eval Rewards: 31.46 | Steps (this episode): 26
# [worker_id: 4] Global Steps: 1270693 | Completed Episodes: 16400 | Train Rewards: 63.91 | Eval Rewards: 60.79 | Steps (this episode): 45
# [worker_id: 1] Global Steps: 1274929 | Completed Episodes: 16500 | Train Rewards: 49.60 | Eval Rewards: 68.08 | Steps (this episode): 36
# [worker_id: 2] Global Steps: 1279514 | Completed Episodes: 16600 | Train Rewards: 70.99 | Eval Rewards: 63.99 | Steps (this episode): 49
# [worker_id: 1] Global Steps: 1284043 | Completed Episodes: 16700 | Train Rewards: 48.88 | Eval Rewards: 76.08 | Steps (this episode): 35
# [worker_id: 0] Global Steps: 1288792 | Completed Episodes: 16800 | Train Rewards: 70.07 | Eval Rewards: 157.50 | Steps (this episode): 49
# [worker_id: 5] Global Steps: 1294951 | Completed Episodes: 16900 | Train Rewards: 81.89 | Eval Rewards: 41.00 | Steps (this episode): 56
# [worker_id: 0] Global Steps: 1301542 | Completed Episodes: 17000 | Train Rewards: 66.33 | Eval Rewards: 161.35 | Steps (this episode): 46
# [worker_id: 3] Global Steps: 1310131 | Completed Episodes: 17100 | Train Rewards: 167.43 | Eval Rewards: 102.24 | Steps (this episode): 102
# [worker_id: 4] Global Steps: 1319794 | Completed Episodes: 17200 | Train Rewards: 180.69 | Eval Rewards: 195.57 | Steps (this episode): 109
# [worker_id: 5] Global Steps: 1330312 | Completed Episodes: 17300 | Train Rewards: 168.49 | Eval Rewards: 185.77 | Steps (this episode): 100
# [worker_id: 4] Global Steps: 1341178 | Completed Episodes: 17400 | Train Rewards: 185.79 | Eval Rewards: 189.57 | Steps (this episode): 109
# [worker_id: 1] Global Steps: 1352049 | Completed Episodes: 17500 | Train Rewards: 182.77 | Eval Rewards: 196.47 | Steps (this episode): 106
# [worker_id: 3] Global Steps: 1362877 | Completed Episodes: 17600 | Train Rewards: 185.45 | Eval Rewards: 194.19 | Steps (this episode): 111
# [worker_id: 0] Global Steps: 1373598 | Completed Episodes: 17700 | Train Rewards: 187.98 | Eval Rewards: 192.32 | Steps (this episode): 109
# [worker_id: 3] Global Steps: 1384476 | Completed Episodes: 17800 | Train Rewards: 190.42 | Eval Rewards: 201.21 | Steps (this episode): 114
# [worker_id: 2] Global Steps: 1395230 | Completed Episodes: 17900 | Train Rewards: 183.63 | Eval Rewards: 166.21 | Steps (this episode): 107
# [worker_id: 0] Global Steps: 1405844 | Completed Episodes: 18000 | Train Rewards: 182.57 | Eval Rewards: 180.69 | Steps (this episode): 109
# [worker_id: 1] Global Steps: 1416450 | Completed Episodes: 18100 | Train Rewards: 175.98 | Eval Rewards: 170.21 | Steps (this episode): 106
# [worker_id: 2] Global Steps: 1426861 | Completed Episodes: 18200 | Train Rewards: 191.74 | Eval Rewards: 181.48 | Steps (this episode): 125
# [worker_id: 2] Global Steps: 1436959 | Completed Episodes: 18300 | Train Rewards: 196.39 | Eval Rewards: 181.70 | Steps (this episode): 123
# [worker_id: 5] Global Steps: 1445483 | Completed Episodes: 18400 | Train Rewards: 63.36 | Eval Rewards: 88.51 | Steps (this episode): 44
# [worker_id: 0] Global Steps: 1453956 | Completed Episodes: 18500 | Train Rewards: 156.19 | Eval Rewards: 97.32 | Steps (this episode): 100
# [worker_id: 5] Global Steps: 1461154 | Completed Episodes: 18600 | Train Rewards: 43.16 | Eval Rewards: 153.77 | Steps (this episode): 32
#
# Training Done!
# Mean Train Reward (last 40): 112.79 | Mean Eval Reward (last 40): 158.36

# %%
plotResults(a2c_plot_config, env_names=[a2c_gym_id], use_moving_avg=False)
plotResults(a2c_plot_config, env_names=[a2c_gym_id])

# %% [markdown]
# ## A2C Questions [$10 \times 4 = 40$ marks ]
#
# ### Q1. What is the advantage function in A2C and why is it used instead of raw returns?
#
# [Took reference from lecture notes]
# 1. In A2C, Advantage function used is shown below:
#
#     * This is the advantage function used in standard A2C implementation.
#
#         $A(S_t,A_t;\phi) = R_t + \gamma * V(S_{t+1};\phi) - V(s_{t};\phi)$
#
#     * Currently, we use GAE for better bias-varaince trade-off.  Since 1 step advantage function is quite biased.
#
#         $A^{1}(S_t,A_t;\phi) = \delta_t^{V} = R_t + \gamma V(S_{t+1};\phi) - V(s_{t};\phi)$
#
#         $A^{2}(S_t,A_t;\phi) = \delta_t^{V} + \gamma \delta_{t+1}^{V} = R_t + \gamma R_{t+1} + \gamma^{2} V(S_{t+2};\phi) - V(s_{t};\phi)$
#
#         ...
#
#         $A^{\inf}(S_t,A_t;\phi) = \sum_{n=0}^{\inf} \gamma^{n} \delta_{t+n}^{V} = \sum_{n=0}^{\inf} \gamma^{n} R_{t+n} - V(S_t;\phi)$
#
#         Therefore:
#
#         $A^{GAE(\gamma,\lambda)}(S_t,A_t;\phi) = (1-\lambda) A^{1}(S_t,A_t;\phi) + \lambda A^{2}(S_t,A_t;\phi) + ..$
#
#         $A^{GAE(\gamma,\lambda)}(S_t,A_t;\phi) = \sum_{n=0}^{\inf} (\gamma \lambda)^{n} \delta_{t+n}^{V}$
#
#
# 2. Major reason for not using raw returns is because of its high variance which makes the training unstable and make the model to get trapped in local optima. So, we use advantage function here which first used in VPG, although reinforce also tries to reduce this variance by subtracting the baseline from full returns. While A3C instead of using full retusns uses n-step returns computed using crtic. But A2C, instead of using n-step returns uses GAE (Genralizd Advantage function). The idea is that findinig the best n is in itself quite challenging so we take the weighted sum of all n step returns for better bias-variance trade-off.
#
#
# ### Q2. How does A2C differ from REINFORCE?
#
# * A2C differs from REINFORCE in many ways:
#
#     1. REINFORCE uses full trajectroy returns for loss estimation while A2C uses TD error type advantage function for loss estimation.
#
#     2. REINFORCE does not explicitly handle high sequential correlation problem While A2C uses multiple workers in sync for dealing with this problem, and this idea works since each worker runs independently and after each episode ends, waits for other to update the global network by taking average of all the gradients accumulated for smoother transitions.
#
#     3. REINFROCE does not uses entropy based regularization while A2C does which helps it in better exploration as it avoids the steep probability distribution and tries to spread it for fair exploratin.
#
#     4. REINFORCE has high variance because of full returns while A2C dont but A2C is biased since it uses bootstrapping for retuns estimation.
#
#     5. REINFORCE is less sample efficient only because of waiting for whoile episode to end before updation while A2C is compartively more sample efficient because of updates to global network at every step.
#
# ### Q3. Why does A2C use RMSprop instead of Adam, and does the choice matter?
#
# * In A2C, polict network distribution changes contiously on every update and using past (stale) gradients for updating the recent network might collapse the policy because in rl, target is not stationary and policy distribution sometimes changes drastically. So, using RMSprop can be better, but still it's a design choice since Adam also can work better if hyperparametters like entropy_coef, lr, etc tuned correctly.
#
# * Choice of using RMSProp is not strict since algorithm design pattern, and hyper-parameters chioce matters much. Adam can also work better, if tuned properly.
#
#
#
# ### Q4. Experiment: Compare A2C with different numbers of parallel environments (num_envs = 1, 4, 8, 16). What do you observe?
#
# * I observed few things listed below:
#     1. With increase in number of parallel environemnts, both training and evaluation rewards has increased. This might be because synchrounous averaging of gradietns from multiple environments reduces the noise if introduced. Hence, makes more stable policy tranistions ehich eventually helkps in making higher rewards.
#
#     2. Although with large number of environments, updates are fewer but quite stable since diversed experiences collected by multiple envs, helps in stabilizing the policy network better.
#
#     3. By observing "Moving Avg Global Steps vs Episodes" plot, it is clear that with more number of envs, number of episodes will be lesser since episode length will vary a lot on varying number of envs. With more envs, gradients are stable and dont end up with premature convergence. Hence, number of steps will be higher and vice versa.
#
# Plots are shown below.

# %%
### A2C Question 4 solution

num_envs = [1, 4, 8, 16]

print(f"A2C Comparison Logs over different number of num_envs")
a2c_comparison_over_envs = {
    f"{a2c_gym_id}": {
        "Train Rewards": {}, "Eval Rewards": {}, "Total Steps": {},
        "Global Steps": {}, "Train Rewards (over global steps)": {},
        "Eval Rewards (over global steps)": {}
    }
}

for num_env in num_envs:
    print(f"\nTrain with num_env={num_env}")

    train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg = train_a2c(env_id=a2c_gym_id, num_envs=num_env, total_timesteps=80_000)

    agent_name = f"num_env={num_env}"
    a2c_comparison_over_envs[a2c_gym_id]["Train Rewards"][agent_name] = [train_rewards]
    a2c_comparison_over_envs[a2c_gym_id]["Eval Rewards"][agent_name] = [eval_rewards]
    a2c_comparison_over_envs[a2c_gym_id]["Train Rewards (over global steps)"][agent_name] = [trg]
    a2c_comparison_over_envs[a2c_gym_id]["Eval Rewards (over global steps)"][agent_name] = [erg]
    a2c_comparison_over_envs[a2c_gym_id]["Total Steps"][agent_name] = [total_steps_list]
    a2c_comparison_over_envs[a2c_gym_id]["Global Steps"][agent_name] = [global_steps_list]

"""
Here for each num_env, seeds used are different.
for num_env=1: seeds used are [210]
for num_env=4: seeds used are [210, 211, 212, 213]
for num_env=8: seeds used are [210, 211, 212, 213, 214, 215, 216, 217] 
for num_env=16: seeds used are [210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225]
"""
# Out:
#  A2C Comparison Logs over different number of num_envs
#
# Train with num_env=1
# Global Steps: 1841 | Completed Episodes: 100 | Train Reward: 10.55 | Eval Reward: 7.38
# Global Steps: 3377 | Completed Episodes: 200 | Train Reward: 6.59 | Eval Reward: 13.37
# Global Steps: 4755 | Completed Episodes: 300 | Train Reward: 6.19 | Eval Reward: 9.32
# Global Steps: 5961 | Completed Episodes: 400 | Train Reward: 11.29 | Eval Reward: 9.02
# Global Steps: 7080 | Completed Episodes: 500 | Train Reward: 6.67 | Eval Reward: 5.61
# Global Steps: 8207 | Completed Episodes: 600 | Train Reward: 5.76 | Eval Reward: 6.45
# Global Steps: 9222 | Completed Episodes: 700 | Train Reward: 10.03 | Eval Reward: 5.26
# Global Steps: 10219 | Completed Episodes: 800 | Train Reward: 4.39 | Eval Reward: 9.26
# Global Steps: 11143 | Completed Episodes: 900 | Train Reward: 4.97 | Eval Reward: 7.20
# Global Steps: 12066 | Completed Episodes: 1000 | Train Reward: 6.35 | Eval Reward: 9.76
# Global Steps: 12950 | Completed Episodes: 1100 | Train Reward: 5.00 | Eval Reward: 5.15
# Global Steps: 13838 | Completed Episodes: 1200 | Train Reward: 4.51 | Eval Reward: 6.06
# Global Steps: 14722 | Completed Episodes: 1300 | Train Reward: 4.94 | Eval Reward: 5.10
# Global Steps: 15551 | Completed Episodes: 1400 | Train Reward: 4.99 | Eval Reward: 5.61
# Global Steps: 16369 | Completed Episodes: 1500 | Train Reward: 4.35 | Eval Reward: 4.95
# Global Steps: 17178 | Completed Episodes: 1600 | Train Reward: 4.42 | Eval Reward: 6.92
# Global Steps: 17999 | Completed Episodes: 1700 | Train Reward: 4.58 | Eval Reward: 4.84
# Global Steps: 18809 | Completed Episodes: 1800 | Train Reward: 4.57 | Eval Reward: 5.80
# Global Steps: 19589 | Completed Episodes: 1900 | Train Reward: 5.26 | Eval Reward: 6.79
# Global Steps: 20373 | Completed Episodes: 2000 | Train Reward: 4.71 | Eval Reward: 5.46
# Global Steps: 21144 | Completed Episodes: 2100 | Train Reward: 3.57 | Eval Reward: 4.94
# Global Steps: 21904 | Completed Episodes: 2200 | Train Reward: 4.22 | Eval Reward: 5.15
# Global Steps: 22675 | Completed Episodes: 2300 | Train Reward: 4.66 | Eval Reward: 5.75
# Global Steps: 23439 | Completed Episodes: 2400 | Train Reward: 4.50 | Eval Reward: 7.50
# Global Steps: 24194 | Completed Episodes: 2500 | Train Reward: 4.86 | Eval Reward: 5.20
# Global Steps: 24952 | Completed Episodes: 2600 | Train Reward: 4.93 | Eval Reward: 6.38
# Global Steps: 25697 | Completed Episodes: 2700 | Train Reward: 3.98 | Eval Reward: 4.34
# Global Steps: 26434 | Completed Episodes: 2800 | Train Reward: 3.96 | Eval Reward: 4.49
# Global Steps: 27165 | Completed Episodes: 2900 | Train Reward: 3.84 | Eval Reward: 4.25
# Global Steps: 27909 | Completed Episodes: 3000 | Train Reward: 5.66 | Eval Reward: 5.06
# Global Steps: 28656 | Completed Episodes: 3100 | Train Reward: 4.75 | Eval Reward: 4.40
# Global Steps: 29385 | Completed Episodes: 3200 | Train Reward: 3.76 | Eval Reward: 4.49
# Global Steps: 30109 | Completed Episodes: 3300 | Train Reward: 4.13 | Eval Reward: 5.11
# Global Steps: 30834 | Completed Episodes: 3400 | Train Reward: 4.55 | Eval Reward: 4.36
# Global Steps: 31555 | Completed Episodes: 3500 | Train Reward: 3.46 | Eval Reward: 4.53
# Global Steps: 32276 | Completed Episodes: 3600 | Train Reward: 3.99 | Eval Reward: 4.76
# Global Steps: 32992 | Completed Episodes: 3700 | Train Reward: 3.66 | Eval Reward: 4.81
# Global Steps: 33710 | Completed Episodes: 3800 | Train Reward: 3.47 | Eval Reward: 4.96
# Global Steps: 34424 | Completed Episodes: 3900 | Train Reward: 4.24 | Eval Reward: 4.40
# Global Steps: 35147 | Completed Episodes: 4000 | Train Reward: 3.58 | Eval Reward: 4.58
# Global Steps: 35858 | Completed Episodes: 4100 | Train Reward: 3.60 | Eval Reward: 4.70
# Global Steps: 36564 | Completed Episodes: 4200 | Train Reward: 4.19 | Eval Reward: 4.55
# Global Steps: 37278 | Completed Episodes: 4300 | Train Reward: 4.36 | Eval Reward: 4.72
# Global Steps: 37985 | Completed Episodes: 4400 | Train Reward: 3.76 | Eval Reward: 4.43
# Global Steps: 38695 | Completed Episodes: 4500 | Train Reward: 3.76 | Eval Reward: 5.36
# Global Steps: 39405 | Completed Episodes: 4600 | Train Reward: 4.36 | Eval Reward: 4.86
# Global Steps: 40115 | Completed Episodes: 4700 | Train Reward: 3.76 | Eval Reward: 4.72
# Global Steps: 40822 | Completed Episodes: 4800 | Train Reward: 3.44 | Eval Reward: 4.73
# Global Steps: 41531 | Completed Episodes: 4900 | Train Reward: 3.61 | Eval Reward: 4.52
# Global Steps: 42238 | Completed Episodes: 5000 | Train Reward: 3.62 | Eval Reward: 4.47
# Global Steps: 42943 | Completed Episodes: 5100 | Train Reward: 3.69 | Eval Reward: 4.88
# Global Steps: 43651 | Completed Episodes: 5200 | Train Reward: 3.85 | Eval Reward: 4.53
# Global Steps: 44357 | Completed Episodes: 5300 | Train Reward: 4.02 | Eval Reward: 4.53
# Global Steps: 45061 | Completed Episodes: 5400 | Train Reward: 3.70 | Eval Reward: 4.64
# Global Steps: 45765 | Completed Episodes: 5500 | Train Reward: 3.54 | Eval Reward: 4.54
# Global Steps: 46469 | Completed Episodes: 5600 | Train Reward: 3.59 | Eval Reward: 4.52
# Global Steps: 47170 | Completed Episodes: 5700 | Train Reward: 3.65 | Eval Reward: 4.51
# Global Steps: 47876 | Completed Episodes: 5800 | Train Reward: 3.78 | Eval Reward: 4.55
# Global Steps: 48580 | Completed Episodes: 5900 | Train Reward: 3.94 | Eval Reward: 4.34
# Global Steps: 49280 | Completed Episodes: 6000 | Train Reward: 3.42 | Eval Reward: 4.42
# Global Steps: 49983 | Completed Episodes: 6100 | Train Reward: 4.31 | Eval Reward: 4.53
# Global Steps: 50684 | Completed Episodes: 6200 | Train Reward: 3.44 | Eval Reward: 4.34
# Global Steps: 51386 | Completed Episodes: 6300 | Train Reward: 3.54 | Eval Reward: 4.28
# Global Steps: 52087 | Completed Episodes: 6400 | Train Reward: 3.62 | Eval Reward: 4.40
# Global Steps: 52789 | Completed Episodes: 6500 | Train Reward: 3.47 | Eval Reward: 4.47
# Global Steps: 53492 | Completed Episodes: 6600 | Train Reward: 3.70 | Eval Reward: 4.22
# Global Steps: 54195 | Completed Episodes: 6700 | Train Reward: 3.61 | Eval Reward: 4.76
# Global Steps: 54898 | Completed Episodes: 6800 | Train Reward: 3.45 | Eval Reward: 4.45
# Global Steps: 55598 | Completed Episodes: 6900 | Train Reward: 3.78 | Eval Reward: 4.31
# Global Steps: 56298 | Completed Episodes: 7000 | Train Reward: 3.86 | Eval Reward: 4.45
# Global Steps: 56998 | Completed Episodes: 7100 | Train Reward: 3.45 | Eval Reward: 4.63
# Global Steps: 57698 | Completed Episodes: 7200 | Train Reward: 3.65 | Eval Reward: 4.58
# Global Steps: 58398 | Completed Episodes: 7300 | Train Reward: 3.64 | Eval Reward: 4.40
# Global Steps: 59098 | Completed Episodes: 7400 | Train Reward: 3.57 | Eval Reward: 4.27
# Global Steps: 59799 | Completed Episodes: 7500 | Train Reward: 3.56 | Eval Reward: 4.36
# Global Steps: 60500 | Completed Episodes: 7600 | Train Reward: 3.59 | Eval Reward: 4.40
# Global Steps: 61200 | Completed Episodes: 7700 | Train Reward: 3.54 | Eval Reward: 4.67
# Global Steps: 61900 | Completed Episodes: 7800 | Train Reward: 3.61 | Eval Reward: 4.28
# Global Steps: 62600 | Completed Episodes: 7900 | Train Reward: 3.54 | Eval Reward: 4.52
# Global Steps: 63300 | Completed Episodes: 8000 | Train Reward: 3.60 | Eval Reward: 4.60
# Global Steps: 64000 | Completed Episodes: 8100 | Train Reward: 3.46 | Eval Reward: 4.42
# Global Steps: 64700 | Completed Episodes: 8200 | Train Reward: 3.68 | Eval Reward: 4.61
# Global Steps: 65401 | Completed Episodes: 8300 | Train Reward: 3.48 | Eval Reward: 4.52
# Global Steps: 66101 | Completed Episodes: 8400 | Train Reward: 3.56 | Eval Reward: 4.63
# Global Steps: 66801 | Completed Episodes: 8500 | Train Reward: 3.52 | Eval Reward: 4.58
# Global Steps: 67501 | Completed Episodes: 8600 | Train Reward: 3.57 | Eval Reward: 4.59
# Global Steps: 68201 | Completed Episodes: 8700 | Train Reward: 3.59 | Eval Reward: 4.54
# Global Steps: 68901 | Completed Episodes: 8800 | Train Reward: 3.72 | Eval Reward: 4.41
# Global Steps: 69602 | Completed Episodes: 8900 | Train Reward: 3.61 | Eval Reward: 4.58
# Global Steps: 70302 | Completed Episodes: 9000 | Train Reward: 3.65 | Eval Reward: 4.37
# Global Steps: 71002 | Completed Episodes: 9100 | Train Reward: 3.44 | Eval Reward: 4.37
# Global Steps: 71702 | Completed Episodes: 9200 | Train Reward: 3.57 | Eval Reward: 4.30
# Global Steps: 72402 | Completed Episodes: 9300 | Train Reward: 3.48 | Eval Reward: 4.28
# Global Steps: 73102 | Completed Episodes: 9400 | Train Reward: 3.71 | Eval Reward: 4.40
# Global Steps: 73802 | Completed Episodes: 9500 | Train Reward: 3.50 | Eval Reward: 4.48
# Global Steps: 74502 | Completed Episodes: 9600 | Train Reward: 3.52 | Eval Reward: 4.37
# Global Steps: 75202 | Completed Episodes: 9700 | Train Reward: 3.51 | Eval Reward: 4.47
# Global Steps: 75902 | Completed Episodes: 9800 | Train Reward: 3.70 | Eval Reward: 4.46
# Global Steps: 76602 | Completed Episodes: 9900 | Train Reward: 3.50 | Eval Reward: 4.52
# Global Steps: 77302 | Completed Episodes: 10000 | Train Reward: 3.46 | Eval Reward: 4.44
# Global Steps: 78002 | Completed Episodes: 10100 | Train Reward: 3.57 | Eval Reward: 4.43
# Global Steps: 78702 | Completed Episodes: 10200 | Train Reward: 3.51 | Eval Reward: 4.50
# Global Steps: 79402 | Completed Episodes: 10300 | Train Reward: 3.62 | Eval Reward: 4.34
#
# Training Done!
# Mean Train Reward (last 40): 3.57 | Mean Eval Reward (last 40): 4.46
#
# Train with num_env=4
# [worker_id: 1] Global Steps: 1846 | Completed Episodes: 100 | Train Rewards: 7.40 | Eval Rewards: 18.92 | Steps (this episode): 21
# [worker_id: 0] Global Steps: 3596 | Completed Episodes: 200 | Train Rewards: 8.81 | Eval Rewards: 42.36 | Steps (this episode): 12
# [worker_id: 3] Global Steps: 5316 | Completed Episodes: 300 | Train Rewards: 9.46 | Eval Rewards: 17.41 | Steps (this episode): 15
# [worker_id: 2] Global Steps: 7159 | Completed Episodes: 400 | Train Rewards: 18.64 | Eval Rewards: 14.65 | Steps (this episode): 20
# [worker_id: 2] Global Steps: 9019 | Completed Episodes: 500 | Train Rewards: 39.33 | Eval Rewards: 11.63 | Steps (this episode): 32
# [worker_id: 1] Global Steps: 10931 | Completed Episodes: 600 | Train Rewards: 27.38 | Eval Rewards: 11.82 | Steps (this episode): 24
# [worker_id: 1] Global Steps: 12885 | Completed Episodes: 700 | Train Rewards: 28.76 | Eval Rewards: 23.44 | Steps (this episode): 25
# [worker_id: 2] Global Steps: 14802 | Completed Episodes: 800 | Train Rewards: 21.76 | Eval Rewards: 18.75 | Steps (this episode): 20
# [worker_id: 3] Global Steps: 16694 | Completed Episodes: 900 | Train Rewards: 11.10 | Eval Rewards: 26.10 | Steps (this episode): 15
# [worker_id: 1] Global Steps: 18704 | Completed Episodes: 1000 | Train Rewards: 18.89 | Eval Rewards: 14.94 | Steps (this episode): 19
# [worker_id: 1] Global Steps: 20832 | Completed Episodes: 1100 | Train Rewards: 17.18 | Eval Rewards: 27.55 | Steps (this episode): 17
# [worker_id: 2] Global Steps: 22719 | Completed Episodes: 1200 | Train Rewards: 12.59 | Eval Rewards: 15.93 | Steps (this episode): 15
# [worker_id: 2] Global Steps: 24591 | Completed Episodes: 1300 | Train Rewards: 11.97 | Eval Rewards: 34.05 | Steps (this episode): 21
# [worker_id: 3] Global Steps: 26591 | Completed Episodes: 1400 | Train Rewards: 19.60 | Eval Rewards: 21.21 | Steps (this episode): 19
# [worker_id: 3] Global Steps: 28465 | Completed Episodes: 1500 | Train Rewards: 10.98 | Eval Rewards: 15.33 | Steps (this episode): 14
# [worker_id: 0] Global Steps: 30280 | Completed Episodes: 1600 | Train Rewards: 16.19 | Eval Rewards: 13.49 | Steps (this episode): 18
# [worker_id: 1] Global Steps: 32202 | Completed Episodes: 1700 | Train Rewards: 18.02 | Eval Rewards: 24.02 | Steps (this episode): 18
# [worker_id: 2] Global Steps: 34025 | Completed Episodes: 1800 | Train Rewards: 17.28 | Eval Rewards: 7.51 | Steps (this episode): 17
# [worker_id: 0] Global Steps: 35807 | Completed Episodes: 1900 | Train Rewards: 8.41 | Eval Rewards: 14.86 | Steps (this episode): 12
# [worker_id: 0] Global Steps: 37601 | Completed Episodes: 2000 | Train Rewards: 11.38 | Eval Rewards: 23.15 | Steps (this episode): 14
# [worker_id: 2] Global Steps: 39398 | Completed Episodes: 2100 | Train Rewards: 23.26 | Eval Rewards: 19.57 | Steps (this episode): 27
# [worker_id: 2] Global Steps: 41259 | Completed Episodes: 2200 | Train Rewards: 8.51 | Eval Rewards: 20.00 | Steps (this episode): 13
# [worker_id: 1] Global Steps: 43075 | Completed Episodes: 2300 | Train Rewards: 16.71 | Eval Rewards: 10.21 | Steps (this episode): 17
# [worker_id: 2] Global Steps: 44825 | Completed Episodes: 2400 | Train Rewards: 10.25 | Eval Rewards: 40.45 | Steps (this episode): 14
# [worker_id: 2] Global Steps: 46592 | Completed Episodes: 2500 | Train Rewards: 12.12 | Eval Rewards: 28.83 | Steps (this episode): 14
# [worker_id: 0] Global Steps: 48306 | Completed Episodes: 2600 | Train Rewards: 11.74 | Eval Rewards: 12.98 | Steps (this episode): 14
# [worker_id: 2] Global Steps: 50060 | Completed Episodes: 2700 | Train Rewards: 10.69 | Eval Rewards: 16.96 | Steps (this episode): 14
# [worker_id: 0] Global Steps: 51792 | Completed Episodes: 2800 | Train Rewards: 15.61 | Eval Rewards: 20.62 | Steps (this episode): 16
# [worker_id: 3] Global Steps: 53468 | Completed Episodes: 2900 | Train Rewards: 15.02 | Eval Rewards: 39.78 | Steps (this episode): 16
# [worker_id: 3] Global Steps: 55134 | Completed Episodes: 3000 | Train Rewards: 33.82 | Eval Rewards: 19.97 | Steps (this episode): 26
# [worker_id: 1] Global Steps: 56799 | Completed Episodes: 3100 | Train Rewards: 10.75 | Eval Rewards: 10.35 | Steps (this episode): 14
# [worker_id: 3] Global Steps: 58610 | Completed Episodes: 3200 | Train Rewards: 17.06 | Eval Rewards: 20.35 | Steps (this episode): 19
# [worker_id: 0] Global Steps: 60262 | Completed Episodes: 3300 | Train Rewards: 11.33 | Eval Rewards: 13.77 | Steps (this episode): 14
# [worker_id: 3] Global Steps: 61908 | Completed Episodes: 3400 | Train Rewards: 21.91 | Eval Rewards: 18.19 | Steps (this episode): 20
# [worker_id: 1] Global Steps: 63485 | Completed Episodes: 3500 | Train Rewards: 23.77 | Eval Rewards: 8.77 | Steps (this episode): 21
# [worker_id: 3] Global Steps: 65134 | Completed Episodes: 3600 | Train Rewards: 18.42 | Eval Rewards: 9.92 | Steps (this episode): 20
# [worker_id: 1] Global Steps: 66730 | Completed Episodes: 3700 | Train Rewards: 9.05 | Eval Rewards: 10.56 | Steps (this episode): 12
# [worker_id: 1] Global Steps: 68296 | Completed Episodes: 3800 | Train Rewards: 21.50 | Eval Rewards: 17.65 | Steps (this episode): 21
# [worker_id: 0] Global Steps: 69871 | Completed Episodes: 3900 | Train Rewards: 12.26 | Eval Rewards: 15.71 | Steps (this episode): 14
# [worker_id: 0] Global Steps: 71444 | Completed Episodes: 4000 | Train Rewards: 13.50 | Eval Rewards: 10.66 | Steps (this episode): 16
# [worker_id: 2] Global Steps: 73010 | Completed Episodes: 4100 | Train Rewards: 16.87 | Eval Rewards: 16.77 | Steps (this episode): 16
#
# Training Done!
# Mean Train Reward (last 40): 15.53 | Mean Eval Reward (last 40): 16.00
#
# Train with num_env=8
# [worker_id: 4] Global Steps: 4049 | Completed Episodes: 100 | Train Rewards: 8.52 | Eval Rewards: 22.91 | Steps (this episode): 12
# [worker_id: 7] Global Steps: 8765 | Completed Episodes: 200 | Train Rewards: 6.08 | Eval Rewards: 21.91 | Steps (this episode): 26
# [worker_id: 1] Global Steps: 13631 | Completed Episodes: 300 | Train Rewards: 7.28 | Eval Rewards: 24.31 | Steps (this episode): 37
# [worker_id: 6] Global Steps: 18828 | Completed Episodes: 400 | Train Rewards: 125.81 | Eval Rewards: 82.94 | Steps (this episode): 82
# [worker_id: 7] Global Steps: 25187 | Completed Episodes: 500 | Train Rewards: 29.17 | Eval Rewards: 102.88 | Steps (this episode): 42
# [worker_id: 3] Global Steps: 31762 | Completed Episodes: 600 | Train Rewards: 72.45 | Eval Rewards: 145.12 | Steps (this episode): 88
# [worker_id: 3] Global Steps: 38727 | Completed Episodes: 700 | Train Rewards: 26.58 | Eval Rewards: 80.92 | Steps (this episode): 28
# [worker_id: 0] Global Steps: 45479 | Completed Episodes: 800 | Train Rewards: 29.90 | Eval Rewards: 67.62 | Steps (this episode): 61
# [worker_id: 1] Global Steps: 51528 | Completed Episodes: 900 | Train Rewards: 66.68 | Eval Rewards: 102.42 | Steps (this episode): 41
# [worker_id: 4] Global Steps: 56650 | Completed Episodes: 1000 | Train Rewards: 76.52 | Eval Rewards: 67.00 | Steps (this episode): 46
# [worker_id: 0] Global Steps: 61389 | Completed Episodes: 1100 | Train Rewards: 57.64 | Eval Rewards: 58.86 | Steps (this episode): 35
#
# Training Done!
# Mean Train Reward (last 40): 83.86 | Mean Eval Reward (last 40): 85.68
#
# Train with num_env=16
# [worker_id: 4] Global Steps: 5679 | Completed Episodes: 100 | Train Rewards: 39.56 | Eval Rewards: 14.81 | Steps (this episode): 59
# [worker_id: 13] Global Steps: 11232 | Completed Episodes: 200 | Train Rewards: 10.91 | Eval Rewards: 77.39 | Steps (this episode): 15
# [worker_id: 1] Global Steps: 17032 | Completed Episodes: 300 | Train Rewards: 27.40 | Eval Rewards: 104.29 | Steps (this episode): 48
# [worker_id: 5] Global Steps: 22469 | Completed Episodes: 400 | Train Rewards: 36.29 | Eval Rewards: 143.52 | Steps (this episode): 49
# [worker_id: 6] Global Steps: 28029 | Completed Episodes: 500 | Train Rewards: 41.09 | Eval Rewards: 147.58 | Steps (this episode): 65
# [worker_id: 8] Global Steps: 33790 | Completed Episodes: 600 | Train Rewards: 99.10 | Eval Rewards: 150.56 | Steps (this episode): 66
# [worker_id: 1] Global Steps: 39778 | Completed Episodes: 700 | Train Rewards: 129.81 | Eval Rewards: 86.91 | Steps (this episode): 84
# [worker_id: 10] Global Steps: 46023 | Completed Episodes: 800 | Train Rewards: 115.14 | Eval Rewards: 161.71 | Steps (this episode): 60
# [worker_id: 6] Global Steps: 52308 | Completed Episodes: 900 | Train Rewards: 117.93 | Eval Rewards: 152.24 | Steps (this episode): 80
# [worker_id: 14] Global Steps: 58457 | Completed Episodes: 1000 | Train Rewards: 10.12 | Eval Rewards: 89.05 | Steps (this episode): 39
# [worker_id: 11] Global Steps: 64458 | Completed Episodes: 1100 | Train Rewards: 73.53 | Eval Rewards: 87.40 | Steps (this episode): 56
#
# Training Done!
# Mean Train Reward (last 40): 95.37 | Mean Eval Reward (last 40): 107.27

# %%
plotResults(a2c_comparison_over_envs, [a2c_gym_id], plot_over_steps=True)

# %% [markdown]
# # Generalized Advantage Estimation (GAE) [50 marks]
# <a id="gae"></a>
#
# GAE (Schulman et al., 2016) provides a principled way to balance bias and variance in advantage estimation through a single parameter $\lambda \in [0, 1]$.
#
# **The core idea:**
#
# The 1-step advantage (TD error) is: $\delta_t^V = r_t + \gamma V(s_{t+1}) - V(s_t)$
#
# The GAE advantage is an exponentially-weighted average of multi-step advantages:
# $$\hat{A}_t^{\text{GAE}(\gamma, \lambda)} = \sum_{l=0}^{\infty} (\gamma \lambda)^l \delta_{t+l}^V$$
#
# This can be computed recursively:
# $$\hat{A}_t = \delta_t + \gamma \lambda \hat{A}_{t+1}$$
#
# **Special cases:**
# - $\lambda = 0$: GAE reduces to the 1-step TD advantage $\delta_t^V$ → **low variance, high bias**
# - $\lambda = 1$: GAE reduces to the full Monte Carlo advantage → **high variance, low bias**
# - $0 < \lambda < 1$: Smooth interpolation between the two extremes
#
# Below we implement a standalone GAE module and demonstrate how different values of $\lambda$ affect learning performance.

# %%
# ======================================================================
# GAE Implementation (standalone module)
# ======================================================================

def compute_gae(rewards, values, dones, next_value, gamma, gae_lambda):
    """
    Computes Generalized Advantage Estimation.

    Args:
        rewards    : tensor of shape (T, num_envs) - rewards at each timestep
        values     : tensor of shape (T, num_envs) - V(s_t) predictions
        dones      : tensor of shape (T, num_envs) - done flags
        next_value : tensor of shape (1, num_envs) - V(s_{T}) bootstrap value
        gamma      : discount factor
        gae_lambda : GAE lambda parameter (0=TD, 1=MC)

    Returns:
        advantages : tensor of shape (T, num_envs)
        returns    : tensor of shape (T, num_envs)
    """

    #Your code goes here
    T, N = rewards.shape
    advantages = torch.zeros_like(rewards)
    returns = torch.zeros_like(rewards)

    advantage_next = torch.zeros(N)
    for t in reversed(range(T)):
        if t == T - 1:
            done = 1.0 - dones[t]
            next_values = next_value
        else:
            done = 1.0 - dones[t+1]
            next_values = values[t+1]

        delta = rewards[t] + gamma * next_values * done - values[t]

        advantages[t] = advantage_next = delta + gamma * gae_lambda * done * advantage_next
        returns[t] = advantages[t] + values[t]

    return advantages, returns

# %%
# ==============================================================
# GAE Visualization (Synthetic Example)
# ==============================================================

# Demonstrate how GAE behaves for different λ values using
# a small synthetic reward and value sequence.

# Generate synthetic rewards, values, and a done signal.
# Assume the episode terminates at a specific timestep.

# For multiple λ values (e.g., 0 → 1), compute the advantages
# using the compute_gae() function.

# Plot 1:
# Visualize the advantage estimates across timesteps for
# different λ values to observe how smoothing changes.

# Plot 2:
# Evaluate the bias–variance trade-off:
#   • Compute the variance of advantages for λ ∈ [0,1]
#   • Also compute the mean absolute advantage
# Plot both curves against λ.

# Add labels, legend, grid, and export the figure as
# 'gae_lambda_analysis.pdf'.

def create_synthetic_data(T=50, seed=42):
    np.random.seed(seed)

    rewards = np.zeros(T)
    rewards[10:15] = 1.0
    rewards[25:30] = 1.5
    rewards[40:45] = 2.0
    rewards += np.random.randn(T) * 0.01

    gamma = 0.99
    returns = np.zeros(T)
    G = 0
    for t in reversed(range(T)):
        G = rewards[t] + gamma * G
        returns[t] = G

    values = returns * 0.9 + np.random.randn(T) * 0.02
    dones = np.zeros(T)
    dones[39] = 1.0

    return (
        torch.tensor(rewards, dtype=torch.float32),
        torch.tensor(values, dtype=torch.float32),
        torch.tensor(dones, dtype=torch.float32),
    )

def visualize_gae_bias_variance_and_adv_mean(T=100, num_envs=8):
    gamma = 0.99
    reward, value, done = create_synthetic_data(T=T)

    rewards = reward.unsqueeze(1).repeat(1, num_envs)
    values = value.unsqueeze(1).repeat(1, num_envs)
    dones = done.unsqueeze(1).repeat(1, num_envs)

    next_value = torch.zeros(num_envs)
    lambda_range1 = np.linspace(0, 1, 50)
    lambda_range2 = [0.0, 0.25, 0.5, 0.75, 0.9, 1.0]

    variances = []
    mean_abs_adv = []
    biases = []

    true_returns = torch.zeros_like(rewards)
    G = torch.zeros(num_envs)
    for t in reversed(range(T)):
        G = rewards[t] + gamma * G * (1.0 - dones[t])
        true_returns[t] = G

    for lam in lambda_range1:
        advantages, returns = compute_gae(rewards, values, dones, next_value, gamma, lam)

        adv_flat = advantages.reshape(-1)
        ret_flat = returns.reshape(-1)
        true_flat = true_returns.reshape(-1)

        variances.append(adv_flat.var().item())
        mean_abs_adv.append(adv_flat.abs().mean().item())
        biases.append((ret_flat - true_flat).abs().mean().item())

    fig = plt.figure(figsize=(16, 10))

    ax_main = plt.subplot(2, 1, 1)

    for lam in lambda_range2:
        advantages, _ = compute_gae(rewards, values, dones, next_value, gamma, lam)

        adv_mean = advantages.mean(dim=1).numpy()
        adv_std = advantages.std(dim=1).numpy()

        timesteps = np.arange(T)

        ax_main.plot(timesteps, adv_mean, label=f"lamda={lam}")
        ax_main.fill_between(timesteps, adv_mean - adv_std, adv_mean + adv_std, alpha=0.15)

    ax_main.set_title("GAE Advantage Estimates over Time", fontsize=14, fontweight='semibold')
    ax_main.set_xlabel("Timestep")
    ax_main.set_ylabel("Advantage")
    ax_main.legend()
    ax_main.grid(True)

    ax1 = plt.subplot(2, 3, 4)
    ax2 = plt.subplot(2, 3, 5)
    ax3 = plt.subplot(2, 3, 6)

    ax1.plot(lambda_range1, variances)
    ax1.set_title("Variance vs lamda", fontweight='semibold')
    ax1.set_xlabel("lamda")
    ax1.set_ylabel("Variance")
    ax1.grid(True)

    ax2.plot(lambda_range1, mean_abs_adv)
    ax2.set_title("Mean Absolute Advantage vs lamda", fontweight='semibold')
    ax2.set_xlabel("lamda")
    ax2.set_ylabel("Magnitude")
    ax2.grid(True)

    ax3.plot(lambda_range1, biases)
    ax3.set_title("Bias vs lamda", fontweight='semibold')
    ax3.set_xlabel("lamda")
    ax3.set_ylabel("Bias")
    ax3.grid(True)

    plt.tight_layout()
    plt.savefig("gae_full_analysis.png", dpi=300)
    plt.show()

visualize_gae_bias_variance_and_adv_mean()

# %% [markdown]
# ### Demonstration of GAE behaviour over differnet $\lambda$ values
#
# 1. As observed from the above **GAE Advantage Estimates over Time** plot:
#
#     * When $\lambda=0$, advantage estimates are around constant till timestep 38 then suddenly drops down to around -8 to -9. This happens when episode got completed since in **synthetic data generation** episode completion happens at timestep 39.
#
#     * When $\lambda=0.25$, advantage estimates are around constant till timestep 36 then starts decreasing and ends up making around -8 to -9 to the same point as above.
#
#     * When $\lambda=0.5$, advantage estimates are around constant till timestep 30 then starts decreasing and ends up making around -8 to -9 to the same point as above.
#
#     * When $\lambda=0.9$, advantage estimates are around constant till timestep 10 then starts decreasing gradually and ends up making around -8 to -9 to the same point as above.
#
#     * When $\lambda=1.0$, advantage estimates starts decreasing from the very begining and eventually lands upto the same value of arounf -8 to -9.
#
#
# 2. So, It is very clear that using GAE, with smaller values of $\lambda$ advantage signals are highly biased (can be observed from the **bias vs lambda** plot below) but has little variance since advantage is estimated with smaller ratio of later return signals, which makes the advantage biased for long time depending on value of lambda. As value of lambda increases, advantage estimation considers significant weightage of later return signals which makes it less biased but at the cost of higher varaince (can be observed from **variance vs lambda** plots below).

# %%
# GAE Lambda Sweep on all 3 environments
''' - Run A2C with different GAE λ values on multiple environments.
- For each environment (Pendulum, Hopper, HalfCheetah), train the agent
- using several λ values and store the training results for comparison.'''

# Your code goes here
def run_gae_sweep(env_names, lambda_values=[0.0, 0.5, 0.95, 0.99, 1.0]):

    results = {
        env: {
          "Train Rewards": {}, "Eval Rewards": {}, "Total Steps": {},
          "Global Steps": {}, "Train Rewards (over global steps)": {},
          "Eval Rewards (over global steps)": {}
        } for env in env_names
    }

    for env_name in env_names:
        print(f"GAE on {env_name}")

        for lam in lambda_values:
            print(f"\nTrain over lamda={lam}")

            train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg = train_a2c(
                env_id=env_name, gae_lambda=lam, total_timesteps=80_000,
                num_envs=16, lr=1e-3, ent_coef=0.002
            )

            agent_name = f"lamda={lam}"
            results[env_name]["Train Rewards"][agent_name] = [[train_rewards]]
            results[env_name]["Eval Rewards"][agent_name] = [[eval_rewards]]
            results[env_name]["Train Rewards (over global steps)"][agent_name] = [[trg]]
            results[env_name]["Eval Rewards (over global steps)"][agent_name] = [[erg]]
            results[env_name]["Total Steps"][agent_name] = [[total_steps_list]]
            results[env_name]["Global Steps"][agent_name] = [[global_steps_list]]

    return results

# %%
# GAE sweep plots for all environments

# Your code goes here

"""I am using slight different hyper-parameters for sweep plot curves since i run it for only 80_000 timesteps, so accordingly i requirede to change
its leaerning rate and entropy_coef."""

gae_env_names = ["Hopper-v4"]
print("\nGAE sweep plots over Hopper-v4 Environment")
sweep_data = run_gae_sweep(gae_env_names)
# Out:
# GAE sweep plots over Hopper-v4 Environment
# GAE on Hopper-v4
#
# Train over lamda=0.0
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment Hopper-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# [worker_id: 9] Global Steps: 1408 | Completed Episodes: 100 | Train Rewards: 8.51 | Eval Rewards: 5.30 | Steps (this episode): 14
# [worker_id: 13] Global Steps: 2763 | Completed Episodes: 200 | Train Rewards: 7.57 | Eval Rewards: 15.33 | Steps (this episode): 14
# [worker_id: 10] Global Steps: 4132 | Completed Episodes: 300 | Train Rewards: 7.52 | Eval Rewards: 9.80 | Steps (this episode): 12
# [worker_id: 4] Global Steps: 5552 | Completed Episodes: 400 | Train Rewards: 6.07 | Eval Rewards: 12.07 | Steps (this episode): 9
# [worker_id: 7] Global Steps: 6996 | Completed Episodes: 500 | Train Rewards: 11.96 | Eval Rewards: 7.84 | Steps (this episode): 26
# [worker_id: 11] Global Steps: 8329 | Completed Episodes: 600 | Train Rewards: 7.51 | Eval Rewards: 10.47 | Steps (this episode): 12
# [worker_id: 1] Global Steps: 9796 | Completed Episodes: 700 | Train Rewards: 5.19 | Eval Rewards: 6.19 | Steps (this episode): 12
# [worker_id: 8] Global Steps: 11134 | Completed Episodes: 800 | Train Rewards: 4.51 | Eval Rewards: 8.44 | Steps (this episode): 11
# [worker_id: 1] Global Steps: 12424 | Completed Episodes: 900 | Train Rewards: 10.66 | Eval Rewards: 8.30 | Steps (this episode): 15
# [worker_id: 3] Global Steps: 13749 | Completed Episodes: 1000 | Train Rewards: 5.26 | Eval Rewards: 4.82 | Steps (this episode): 12
# [worker_id: 15] Global Steps: 15097 | Completed Episodes: 1100 | Train Rewards: 7.48 | Eval Rewards: 7.22 | Steps (this episode): 13
# [worker_id: 5] Global Steps: 16337 | Completed Episodes: 1200 | Train Rewards: 5.52 | Eval Rewards: 9.11 | Steps (this episode): 12
# [worker_id: 7] Global Steps: 17602 | Completed Episodes: 1300 | Train Rewards: 4.83 | Eval Rewards: 7.84 | Steps (this episode): 11
# [worker_id: 2] Global Steps: 18873 | Completed Episodes: 1400 | Train Rewards: 9.23 | Eval Rewards: 9.21 | Steps (this episode): 14
# [worker_id: 14] Global Steps: 20120 | Completed Episodes: 1500 | Train Rewards: 6.54 | Eval Rewards: 4.87 | Steps (this episode): 12
# [worker_id: 8] Global Steps: 21334 | Completed Episodes: 1600 | Train Rewards: 3.56 | Eval Rewards: 6.40 | Steps (this episode): 10
# [worker_id: 14] Global Steps: 22514 | Completed Episodes: 1700 | Train Rewards: 11.29 | Eval Rewards: 10.23 | Steps (this episode): 21
# [worker_id: 9] Global Steps: 23677 | Completed Episodes: 1800 | Train Rewards: 7.78 | Eval Rewards: 7.23 | Steps (this episode): 12
# [worker_id: 4] Global Steps: 24863 | Completed Episodes: 1900 | Train Rewards: 9.66 | Eval Rewards: 8.41 | Steps (this episode): 15
# [worker_id: 5] Global Steps: 26033 | Completed Episodes: 2000 | Train Rewards: 7.54 | Eval Rewards: 8.07 | Steps (this episode): 13
# [worker_id: 9] Global Steps: 27253 | Completed Episodes: 2100 | Train Rewards: 5.44 | Eval Rewards: 5.60 | Steps (this episode): 10
# [worker_id: 0] Global Steps: 28479 | Completed Episodes: 2200 | Train Rewards: 6.32 | Eval Rewards: 7.62 | Steps (this episode): 11
# [worker_id: 13] Global Steps: 29649 | Completed Episodes: 2300 | Train Rewards: 4.79 | Eval Rewards: 6.94 | Steps (this episode): 8
# [worker_id: 14] Global Steps: 30850 | Completed Episodes: 2400 | Train Rewards: 5.91 | Eval Rewards: 7.70 | Steps (this episode): 12
# [worker_id: 7] Global Steps: 32028 | Completed Episodes: 2500 | Train Rewards: 3.03 | Eval Rewards: 3.96 | Steps (this episode): 12
# [worker_id: 1] Global Steps: 33152 | Completed Episodes: 2600 | Train Rewards: 5.24 | Eval Rewards: 6.83 | Steps (this episode): 10
# [worker_id: 0] Global Steps: 34296 | Completed Episodes: 2700 | Train Rewards: 4.78 | Eval Rewards: 7.03 | Steps (this episode): 10
# [worker_id: 15] Global Steps: 35433 | Completed Episodes: 2800 | Train Rewards: 4.09 | Eval Rewards: 5.18 | Steps (this episode): 11
# [worker_id: 14] Global Steps: 36531 | Completed Episodes: 2900 | Train Rewards: 4.28 | Eval Rewards: 6.15 | Steps (this episode): 8
# [worker_id: 1] Global Steps: 37640 | Completed Episodes: 3000 | Train Rewards: 5.82 | Eval Rewards: 9.03 | Steps (this episode): 11
# [worker_id: 6] Global Steps: 38750 | Completed Episodes: 3100 | Train Rewards: 3.68 | Eval Rewards: 7.30 | Steps (this episode): 9
# [worker_id: 13] Global Steps: 39854 | Completed Episodes: 3200 | Train Rewards: 5.14 | Eval Rewards: 7.76 | Steps (this episode): 12
# [worker_id: 3] Global Steps: 40950 | Completed Episodes: 3300 | Train Rewards: 7.60 | Eval Rewards: 8.42 | Steps (this episode): 12
# [worker_id: 12] Global Steps: 42076 | Completed Episodes: 3400 | Train Rewards: 4.20 | Eval Rewards: 6.04 | Steps (this episode): 10
# [worker_id: 12] Global Steps: 43165 | Completed Episodes: 3500 | Train Rewards: 4.27 | Eval Rewards: 6.81 | Steps (this episode): 9
# [worker_id: 1] Global Steps: 44282 | Completed Episodes: 3600 | Train Rewards: 5.28 | Eval Rewards: 6.27 | Steps (this episode): 10
# [worker_id: 12] Global Steps: 45381 | Completed Episodes: 3700 | Train Rewards: 3.55 | Eval Rewards: 7.03 | Steps (this episode): 10
# [worker_id: 9] Global Steps: 46448 | Completed Episodes: 3800 | Train Rewards: 4.83 | Eval Rewards: 7.03 | Steps (this episode): 9
# [worker_id: 11] Global Steps: 47527 | Completed Episodes: 3900 | Train Rewards: 6.46 | Eval Rewards: 7.19 | Steps (this episode): 11
# [worker_id: 13] Global Steps: 48610 | Completed Episodes: 4000 | Train Rewards: 4.90 | Eval Rewards: 6.08 | Steps (this episode): 10
# [worker_id: 4] Global Steps: 49698 | Completed Episodes: 4100 | Train Rewards: 6.96 | Eval Rewards: 10.26 | Steps (this episode): 12
# [worker_id: 15] Global Steps: 50783 | Completed Episodes: 4200 | Train Rewards: 4.78 | Eval Rewards: 6.76 | Steps (this episode): 10
# [worker_id: 10] Global Steps: 51837 | Completed Episodes: 4300 | Train Rewards: 5.43 | Eval Rewards: 6.45 | Steps (this episode): 11
# [worker_id: 13] Global Steps: 52938 | Completed Episodes: 4400 | Train Rewards: 4.65 | Eval Rewards: 5.90 | Steps (this episode): 11
# [worker_id: 1] Global Steps: 54016 | Completed Episodes: 4500 | Train Rewards: 8.52 | Eval Rewards: 6.35 | Steps (this episode): 15
# [worker_id: 1] Global Steps: 55092 | Completed Episodes: 4600 | Train Rewards: 4.45 | Eval Rewards: 6.97 | Steps (this episode): 10
# [worker_id: 6] Global Steps: 56129 | Completed Episodes: 4700 | Train Rewards: 5.80 | Eval Rewards: 6.66 | Steps (this episode): 11
# [worker_id: 15] Global Steps: 57182 | Completed Episodes: 4800 | Train Rewards: 4.20 | Eval Rewards: 5.16 | Steps (this episode): 10
# [worker_id: 8] Global Steps: 58274 | Completed Episodes: 4900 | Train Rewards: 4.39 | Eval Rewards: 5.68 | Steps (this episode): 8
# [worker_id: 2] Global Steps: 59350 | Completed Episodes: 5000 | Train Rewards: 5.16 | Eval Rewards: 7.07 | Steps (this episode): 10
# [worker_id: 9] Global Steps: 60429 | Completed Episodes: 5100 | Train Rewards: 6.02 | Eval Rewards: 6.68 | Steps (this episode): 11
# [worker_id: 3] Global Steps: 61472 | Completed Episodes: 5200 | Train Rewards: 6.62 | Eval Rewards: 8.97 | Steps (this episode): 12
# [worker_id: 13] Global Steps: 62543 | Completed Episodes: 5300 | Train Rewards: 4.40 | Eval Rewards: 5.65 | Steps (this episode): 10
# [worker_id: 10] Global Steps: 63589 | Completed Episodes: 5400 | Train Rewards: 4.70 | Eval Rewards: 8.11 | Steps (this episode): 10
# [worker_id: 13] Global Steps: 64658 | Completed Episodes: 5500 | Train Rewards: 4.29 | Eval Rewards: 5.86 | Steps (this episode): 9
# [worker_id: 0] Global Steps: 65708 | Completed Episodes: 5600 | Train Rewards: 3.94 | Eval Rewards: 6.53 | Steps (this episode): 11
# [worker_id: 3] Global Steps: 66740 | Completed Episodes: 5700 | Train Rewards: 4.87 | Eval Rewards: 6.36 | Steps (this episode): 10
# [worker_id: 3] Global Steps: 67763 | Completed Episodes: 5800 | Train Rewards: 5.48 | Eval Rewards: 6.15 | Steps (this episode): 10
# [worker_id: 13] Global Steps: 68800 | Completed Episodes: 5900 | Train Rewards: 5.77 | Eval Rewards: 7.16 | Steps (this episode): 11
# [worker_id: 7] Global Steps: 69840 | Completed Episodes: 6000 | Train Rewards: 6.72 | Eval Rewards: 5.98 | Steps (this episode): 12
# [worker_id: 2] Global Steps: 70870 | Completed Episodes: 6100 | Train Rewards: 4.79 | Eval Rewards: 5.90 | Steps (this episode): 10
# [worker_id: 10] Global Steps: 71899 | Completed Episodes: 6200 | Train Rewards: 5.43 | Eval Rewards: 5.64 | Steps (this episode): 11
# [worker_id: 0] Global Steps: 72938 | Completed Episodes: 6300 | Train Rewards: 5.23 | Eval Rewards: 5.69 | Steps (this episode): 11
# [worker_id: 8] Global Steps: 73977 | Completed Episodes: 6400 | Train Rewards: 4.51 | Eval Rewards: 4.49 | Steps (this episode): 10
# [worker_id: 15] Global Steps: 75034 | Completed Episodes: 6500 | Train Rewards: 4.64 | Eval Rewards: 6.46 | Steps (this episode): 10
# [worker_id: 14] Global Steps: 76078 | Completed Episodes: 6600 | Train Rewards: 5.00 | Eval Rewards: 7.32 | Steps (this episode): 9
# [worker_id: 3] Global Steps: 77125 | Completed Episodes: 6700 | Train Rewards: 5.81 | Eval Rewards: 7.16 | Steps (this episode): 11
# [worker_id: 4] Global Steps: 78170 | Completed Episodes: 6800 | Train Rewards: 5.06 | Eval Rewards: 6.17 | Steps (this episode): 10
# [worker_id: 6] Global Steps: 79222 | Completed Episodes: 6900 | Train Rewards: 5.44 | Eval Rewards: 6.18 | Steps (this episode): 11
#
# Training Done!
# Mean Train Reward (last 40): 5.23 | Mean Eval Reward (last 40): 6.17
#
# Train over lamda=0.5
# [worker_id: 4] Global Steps: 1818 | Completed Episodes: 100 | Train Rewards: 11.07 | Eval Rewards: 134.11 | Steps (this episode): 14
# [worker_id: 11] Global Steps: 3741 | Completed Episodes: 200 | Train Rewards: 64.83 | Eval Rewards: 65.14 | Steps (this episode): 44
# [worker_id: 5] Global Steps: 5873 | Completed Episodes: 300 | Train Rewards: 7.08 | Eval Rewards: 54.72 | Steps (this episode): 11
# [worker_id: 13] Global Steps: 7969 | Completed Episodes: 400 | Train Rewards: 9.32 | Eval Rewards: 67.84 | Steps (this episode): 13
# [worker_id: 11] Global Steps: 10202 | Completed Episodes: 500 | Train Rewards: 19.04 | Eval Rewards: 75.36 | Steps (this episode): 23
# [worker_id: 0] Global Steps: 12439 | Completed Episodes: 600 | Train Rewards: 9.32 | Eval Rewards: 99.08 | Steps (this episode): 15
# [worker_id: 12] Global Steps: 15307 | Completed Episodes: 700 | Train Rewards: 69.98 | Eval Rewards: 85.10 | Steps (this episode): 42
# [worker_id: 10] Global Steps: 18862 | Completed Episodes: 800 | Train Rewards: 8.50 | Eval Rewards: 78.63 | Steps (this episode): 14
# [worker_id: 4] Global Steps: 22788 | Completed Episodes: 900 | Train Rewards: 108.07 | Eval Rewards: 59.33 | Steps (this episode): 59
# [worker_id: 1] Global Steps: 27140 | Completed Episodes: 1000 | Train Rewards: 76.16 | Eval Rewards: 95.68 | Steps (this episode): 49
# [worker_id: 5] Global Steps: 31547 | Completed Episodes: 1100 | Train Rewards: 63.34 | Eval Rewards: 107.39 | Steps (this episode): 39
# [worker_id: 12] Global Steps: 34628 | Completed Episodes: 1200 | Train Rewards: 42.65 | Eval Rewards: 47.95 | Steps (this episode): 25
# [worker_id: 3] Global Steps: 37388 | Completed Episodes: 1300 | Train Rewards: 45.52 | Eval Rewards: 46.64 | Steps (this episode): 27
# [worker_id: 3] Global Steps: 40100 | Completed Episodes: 1400 | Train Rewards: 48.66 | Eval Rewards: 58.01 | Steps (this episode): 28
# [worker_id: 12] Global Steps: 42864 | Completed Episodes: 1500 | Train Rewards: 47.45 | Eval Rewards: 46.91 | Steps (this episode): 28
# [worker_id: 3] Global Steps: 45664 | Completed Episodes: 1600 | Train Rewards: 51.44 | Eval Rewards: 100.28 | Steps (this episode): 31
# [worker_id: 11] Global Steps: 48424 | Completed Episodes: 1700 | Train Rewards: 56.69 | Eval Rewards: 54.22 | Steps (this episode): 35
# [worker_id: 9] Global Steps: 51277 | Completed Episodes: 1800 | Train Rewards: 50.10 | Eval Rewards: 52.91 | Steps (this episode): 30
# [worker_id: 15] Global Steps: 54199 | Completed Episodes: 1900 | Train Rewards: 44.64 | Eval Rewards: 47.70 | Steps (this episode): 26
# [worker_id: 7] Global Steps: 57021 | Completed Episodes: 2000 | Train Rewards: 42.83 | Eval Rewards: 48.04 | Steps (this episode): 25
# [worker_id: 9] Global Steps: 59873 | Completed Episodes: 2100 | Train Rewards: 51.33 | Eval Rewards: 46.93 | Steps (this episode): 31
# [worker_id: 1] Global Steps: 62749 | Completed Episodes: 2200 | Train Rewards: 40.17 | Eval Rewards: 53.94 | Steps (this episode): 23
# [worker_id: 4] Global Steps: 65857 | Completed Episodes: 2300 | Train Rewards: 57.82 | Eval Rewards: 129.02 | Steps (this episode): 32
# [worker_id: 3] Global Steps: 69311 | Completed Episodes: 2400 | Train Rewards: 46.64 | Eval Rewards: 127.56 | Steps (this episode): 27
# [worker_id: 3] Global Steps: 72718 | Completed Episodes: 2500 | Train Rewards: 54.48 | Eval Rewards: 129.32 | Steps (this episode): 31
# [worker_id: 7] Global Steps: 76304 | Completed Episodes: 2600 | Train Rewards: 65.69 | Eval Rewards: 142.08 | Steps (this episode): 36
# [worker_id: 1] Global Steps: 79667 | Completed Episodes: 2700 | Train Rewards: 61.04 | Eval Rewards: 85.16 | Steps (this episode): 36
#
# Training Done!
# Mean Train Reward (last 40): 58.72 | Mean Eval Reward (last 40): 83.71
#
# Train over lamda=0.95
# [worker_id: 2] Global Steps: 4821 | Completed Episodes: 100 | Train Rewards: 82.57 | Eval Rewards: 88.01 | Steps (this episode): 45
# [worker_id: 11] Global Steps: 10266 | Completed Episodes: 200 | Train Rewards: 68.65 | Eval Rewards: 145.10 | Steps (this episode): 43
# [worker_id: 15] Global Steps: 15632 | Completed Episodes: 300 | Train Rewards: 76.25 | Eval Rewards: 122.47 | Steps (this episode): 65
# [worker_id: 6] Global Steps: 20322 | Completed Episodes: 400 | Train Rewards: 96.31 | Eval Rewards: 53.10 | Steps (this episode): 56
# [worker_id: 3] Global Steps: 24585 | Completed Episodes: 500 | Train Rewards: 49.45 | Eval Rewards: 59.02 | Steps (this episode): 30
# [worker_id: 9] Global Steps: 29091 | Completed Episodes: 600 | Train Rewards: 32.82 | Eval Rewards: 96.24 | Steps (this episode): 25
# [worker_id: 9] Global Steps: 33030 | Completed Episodes: 700 | Train Rewards: 26.09 | Eval Rewards: 99.62 | Steps (this episode): 19
# [worker_id: 1] Global Steps: 35548 | Completed Episodes: 800 | Train Rewards: 29.43 | Eval Rewards: 74.94 | Steps (this episode): 23
# [worker_id: 6] Global Steps: 37996 | Completed Episodes: 900 | Train Rewards: 33.39 | Eval Rewards: 85.32 | Steps (this episode): 24
# [worker_id: 5] Global Steps: 40392 | Completed Episodes: 1000 | Train Rewards: 47.78 | Eval Rewards: 92.02 | Steps (this episode): 31
# [worker_id: 6] Global Steps: 42986 | Completed Episodes: 1100 | Train Rewards: 60.96 | Eval Rewards: 66.57 | Steps (this episode): 37
# [worker_id: 14] Global Steps: 45459 | Completed Episodes: 1200 | Train Rewards: 96.56 | Eval Rewards: 90.63 | Steps (this episode): 53
# [worker_id: 13] Global Steps: 48770 | Completed Episodes: 1300 | Train Rewards: 26.45 | Eval Rewards: 88.87 | Steps (this episode): 19
# [worker_id: 11] Global Steps: 52647 | Completed Episodes: 1400 | Train Rewards: 75.65 | Eval Rewards: 86.79 | Steps (this episode): 42
# [worker_id: 2] Global Steps: 56929 | Completed Episodes: 1500 | Train Rewards: 30.87 | Eval Rewards: 81.70 | Steps (this episode): 22
# [worker_id: 0] Global Steps: 61157 | Completed Episodes: 1600 | Train Rewards: 30.75 | Eval Rewards: 73.77 | Steps (this episode): 22
# [worker_id: 3] Global Steps: 65547 | Completed Episodes: 1700 | Train Rewards: 67.39 | Eval Rewards: 147.08 | Steps (this episode): 37
# [worker_id: 13] Global Steps: 69975 | Completed Episodes: 1800 | Train Rewards: 90.02 | Eval Rewards: 86.63 | Steps (this episode): 52
# [worker_id: 12] Global Steps: 74301 | Completed Episodes: 1900 | Train Rewards: 71.31 | Eval Rewards: 71.80 | Steps (this episode): 41
# [worker_id: 13] Global Steps: 78733 | Completed Episodes: 2000 | Train Rewards: 77.19 | Eval Rewards: 74.86 | Steps (this episode): 44
#
# Training Done!
# Mean Train Reward (last 40): 76.26 | Mean Eval Reward (last 40): 94.34
#
# Train over lamda=0.99
# [worker_id: 9] Global Steps: 1365 | Completed Episodes: 100 | Train Rewards: 11.06 | Eval Rewards: 75.51 | Steps (this episode): 14
# [worker_id: 1] Global Steps: 2728 | Completed Episodes: 200 | Train Rewards: 6.58 | Eval Rewards: 84.61 | Steps (this episode): 9
# [worker_id: 15] Global Steps: 4071 | Completed Episodes: 300 | Train Rewards: 7.21 | Eval Rewards: 27.10 | Steps (this episode): 10
# [worker_id: 3] Global Steps: 5527 | Completed Episodes: 400 | Train Rewards: 10.74 | Eval Rewards: 86.57 | Steps (this episode): 14
# [worker_id: 3] Global Steps: 6937 | Completed Episodes: 500 | Train Rewards: 5.54 | Eval Rewards: 69.65 | Steps (this episode): 8
# [worker_id: 8] Global Steps: 8331 | Completed Episodes: 600 | Train Rewards: 11.34 | Eval Rewards: 90.65 | Steps (this episode): 14
# [worker_id: 15] Global Steps: 10115 | Completed Episodes: 700 | Train Rewards: 15.36 | Eval Rewards: 68.80 | Steps (this episode): 18
# [worker_id: 3] Global Steps: 12161 | Completed Episodes: 800 | Train Rewards: 13.87 | Eval Rewards: 93.09 | Steps (this episode): 18
# [worker_id: 11] Global Steps: 14079 | Completed Episodes: 900 | Train Rewards: 9.67 | Eval Rewards: 56.52 | Steps (this episode): 12
# [worker_id: 5] Global Steps: 16632 | Completed Episodes: 1000 | Train Rewards: 9.01 | Eval Rewards: 81.82 | Steps (this episode): 12
# [worker_id: 1] Global Steps: 18869 | Completed Episodes: 1100 | Train Rewards: 7.53 | Eval Rewards: 90.27 | Steps (this episode): 11
# [worker_id: 9] Global Steps: 20975 | Completed Episodes: 1200 | Train Rewards: 8.78 | Eval Rewards: 71.91 | Steps (this episode): 13
# [worker_id: 14] Global Steps: 24199 | Completed Episodes: 1300 | Train Rewards: 1.10 | Eval Rewards: 72.37 | Steps (this episode): 19
# [worker_id: 12] Global Steps: 28552 | Completed Episodes: 1400 | Train Rewards: 77.11 | Eval Rewards: 123.80 | Steps (this episode): 50
# [worker_id: 7] Global Steps: 33543 | Completed Episodes: 1500 | Train Rewards: 53.58 | Eval Rewards: 65.46 | Steps (this episode): 32
# [worker_id: 10] Global Steps: 37801 | Completed Episodes: 1600 | Train Rewards: 65.40 | Eval Rewards: 69.87 | Steps (this episode): 40
# [worker_id: 5] Global Steps: 41954 | Completed Episodes: 1700 | Train Rewards: 77.16 | Eval Rewards: 74.41 | Steps (this episode): 49
# [worker_id: 5] Global Steps: 46179 | Completed Episodes: 1800 | Train Rewards: 101.34 | Eval Rewards: 77.49 | Steps (this episode): 70
# [worker_id: 9] Global Steps: 50214 | Completed Episodes: 1900 | Train Rewards: 55.82 | Eval Rewards: 87.50 | Steps (this episode): 34
# [worker_id: 15] Global Steps: 53995 | Completed Episodes: 2000 | Train Rewards: 51.75 | Eval Rewards: 75.97 | Steps (this episode): 31
# [worker_id: 2] Global Steps: 57711 | Completed Episodes: 2100 | Train Rewards: 57.15 | Eval Rewards: 60.90 | Steps (this episode): 35
# [worker_id: 5] Global Steps: 61482 | Completed Episodes: 2200 | Train Rewards: 56.36 | Eval Rewards: 60.73 | Steps (this episode): 37
# [worker_id: 1] Global Steps: 65161 | Completed Episodes: 2300 | Train Rewards: 53.45 | Eval Rewards: 45.79 | Steps (this episode): 35
# [worker_id: 11] Global Steps: 68656 | Completed Episodes: 2400 | Train Rewards: 69.99 | Eval Rewards: 51.46 | Steps (this episode): 42
# [worker_id: 12] Global Steps: 72086 | Completed Episodes: 2500 | Train Rewards: 48.67 | Eval Rewards: 61.91 | Steps (this episode): 33
# [worker_id: 2] Global Steps: 75607 | Completed Episodes: 2600 | Train Rewards: 48.98 | Eval Rewards: 67.29 | Steps (this episode): 29
# [worker_id: 15] Global Steps: 78961 | Completed Episodes: 2700 | Train Rewards: 52.97 | Eval Rewards: 45.52 | Steps (this episode): 32
#
# Training Done!
# Mean Train Reward (last 40): 54.42 | Mean Eval Reward (last 40): 63.73
#
# Train over lamda=1.0
# [worker_id: 7] Global Steps: 3516 | Completed Episodes: 100 | Train Rewards: 13.83 | Eval Rewards: 79.71 | Steps (this episode): 22
# [worker_id: 14] Global Steps: 6694 | Completed Episodes: 200 | Train Rewards: 7.46 | Eval Rewards: 44.19 | Steps (this episode): 10
# [worker_id: 8] Global Steps: 10146 | Completed Episodes: 300 | Train Rewards: 15.07 | Eval Rewards: 51.11 | Steps (this episode): 17
# [worker_id: 0] Global Steps: 13585 | Completed Episodes: 400 | Train Rewards: 30.22 | Eval Rewards: 71.06 | Steps (this episode): 32
# [worker_id: 2] Global Steps: 17209 | Completed Episodes: 500 | Train Rewards: 88.48 | Eval Rewards: 71.87 | Steps (this episode): 53
# [worker_id: 3] Global Steps: 20998 | Completed Episodes: 600 | Train Rewards: 64.62 | Eval Rewards: 65.26 | Steps (this episode): 40
# [worker_id: 6] Global Steps: 24658 | Completed Episodes: 700 | Train Rewards: 41.87 | Eval Rewards: 52.91 | Steps (this episode): 25
# [worker_id: 4] Global Steps: 28503 | Completed Episodes: 800 | Train Rewards: 69.80 | Eval Rewards: 62.94 | Steps (this episode): 42
# [worker_id: 1] Global Steps: 32647 | Completed Episodes: 900 | Train Rewards: 62.16 | Eval Rewards: 97.80 | Steps (this episode): 38
# [worker_id: 11] Global Steps: 36191 | Completed Episodes: 1000 | Train Rewards: 63.62 | Eval Rewards: 70.10 | Steps (this episode): 41
# [worker_id: 1] Global Steps: 39686 | Completed Episodes: 1100 | Train Rewards: 47.32 | Eval Rewards: 55.44 | Steps (this episode): 28
# [worker_id: 7] Global Steps: 42977 | Completed Episodes: 1200 | Train Rewards: 42.39 | Eval Rewards: 46.72 | Steps (this episode): 25
# [worker_id: 11] Global Steps: 46664 | Completed Episodes: 1300 | Train Rewards: 66.57 | Eval Rewards: 58.91 | Steps (this episode): 47
# [worker_id: 4] Global Steps: 49947 | Completed Episodes: 1400 | Train Rewards: 48.73 | Eval Rewards: 72.50 | Steps (this episode): 29
# [worker_id: 15] Global Steps: 53335 | Completed Episodes: 1500 | Train Rewards: 51.64 | Eval Rewards: 52.75 | Steps (this episode): 31
# [worker_id: 13] Global Steps: 56634 | Completed Episodes: 1600 | Train Rewards: 57.66 | Eval Rewards: 58.12 | Steps (this episode): 35
# [worker_id: 2] Global Steps: 59940 | Completed Episodes: 1700 | Train Rewards: 47.09 | Eval Rewards: 50.14 | Steps (this episode): 28
# [worker_id: 11] Global Steps: 63175 | Completed Episodes: 1800 | Train Rewards: 57.24 | Eval Rewards: 60.47 | Steps (this episode): 35
# [worker_id: 5] Global Steps: 66274 | Completed Episodes: 1900 | Train Rewards: 45.81 | Eval Rewards: 55.14 | Steps (this episode): 27
# [worker_id: 6] Global Steps: 69345 | Completed Episodes: 2000 | Train Rewards: 50.58 | Eval Rewards: 41.03 | Steps (this episode): 30
# [worker_id: 10] Global Steps: 72402 | Completed Episodes: 2100 | Train Rewards: 44.12 | Eval Rewards: 50.10 | Steps (this episode): 26
# [worker_id: 0] Global Steps: 75400 | Completed Episodes: 2200 | Train Rewards: 42.85 | Eval Rewards: 48.84 | Steps (this episode): 25
# [worker_id: 1] Global Steps: 78455 | Completed Episodes: 2300 | Train Rewards: 60.82 | Eval Rewards: 58.56 | Steps (this episode): 37
#
# Training Done!
# Mean Train Reward (last 40): 48.61 | Mean Eval Reward (last 40): 53.51

# %%
plotResults(sweep_data, [a2c_gym_id], window=40, plot_over_steps=True)

# %%
# A2C vs A3C comparison on all 3 environments

# Your code goes here

def compare_a2c_a3c(env_name, a2c_plot_config, a3c_all_results):
    
    combined_results = {
        env_name: {
            "Train Rewards": {},
            "Eval Rewards": {},
            "Total Steps": {},
            "Global Steps": {},
            "Train Rewards (over global steps)": {},
            "Eval Rewards (over global steps)": {}
        }
    }

    # A2C data
    a2c_data = a2c_plot_config[env_name]
    for key in combined_results[env_name]:
        if key in a2c_data:
            combined_results[env_name][key]["A2C"] = a2c_data[key]["A2C"]

    # A3C data
    a3c_data = a3c_all_results[env_name]
    for key in combined_results[env_name]:
        if key in a3c_data:
            combined_results[env_name][key]["A3C"] = a3c_data[key]["A3C"]

    return combined_results

a2c_a3c_result = compare_a2c_a3c(
    env_name=a2c_gym_id,
    a2c_plot_config=a2c_plot_config,
    a3c_all_results=a3c_all_results
)

plotResults(a2c_a3c_result, [a2c_gym_id])

# %% [markdown]
# ### Comparison of A2C and A3C
#
# 1. From the **Moving average train rewards vs global steps** plot, it can be observed that A3C train rewards have high variance compared to A2C train rewards, which is quite obvious because of asynchronous updates (most of the time "stale update") to the global network makes the global network highly unstable. Wherass, in A2C gradients from all the workers got averaged and then global parameters are updated for smoother trainisiton and to makw the trianing stable.
#
# 2. A3C, despite being unstable able to make higher rewards than A2C (although it is not strict) but here A2C seems to get stuck but it might take longer time for learning and exploraing significantly since on avergaing the gradient updates from multiple workers limits the exploration. Whereas in A3C, although it is not very robust to noisy updates. Everything depends on asynhronous behaviour, if noisy updates happened first which later followed by deceny updates then overall global network will shift towards to the decent policy distribution which actually exposed to more diverse experriences and can sometimes seem doing better over A2C.

# %% [markdown]
# ## GAE Questions [$10 \times 4 = 40$ marks]
#
# ### Q1. Derive the GAE formula starting from multi-step advantage estimates.
#
# [took reference from notes]
# * GAE formula derivatoin:
#
#     $A^{1}(S_t,A_t;\phi) = \delta_t^{V} = R_t + \gamma V(S_{t+1};\phi) - V(s_{t};\phi)$
#
#     $A^{2}(S_t,A_t;\phi) = \delta_t^{V} + \gamma \delta_{t+1}^{V} = R_t + \gamma R_{t+1} + \gamma^{2} V(S_{t+2};\phi) - V(s_{t};\phi)$
#
#     ...
#
#     $A^{\inf}(S_t,A_t;\phi) = \sum_{n=0}^{\inf} \gamma^{n} \delta_{t+n}^{V} = \sum_{n=0}^{\inf} \gamma^{n} R_{t+n} - V(S_t;\phi)$
#
#     Therefore:
#
#     $A^{GAE(\gamma,\lambda)}(S_t,A_t;\phi) = (1-\lambda) A^{1}(S_t,A_t;\phi) + \lambda A^{2}(S_t,A_t;\phi) + ..$
#
#     $A^{GAE(\gamma,\lambda)}(S_t,A_t;\phi) = (1-\lambda)(\delta_t^{V} + \lambda (\delta_t^{V} + \gamma \delta_{t+1}^{V}) + \lambda^{2} (\delta_t{V} + \gamma \delta_{t+1}^{V} + \gamma^{2} \delta_{t+2}^{V}) + ...)$
#
#     $A^{GAE(\gamma,\lambda)}(S_t,A_t;\phi) = (1-\lambda) (\delta_t^{V} (\frac{1}{1-\lambda}) + \gamma \delta_{t+1}^{V} (\frac{\lambda}{1-\lambda}) + \gamma^{2} \delta_{t+2}^{V} (\frac{\lambda^{2}}{1-\lambda}) + ...)$
#
#     $A^{GAE(\gamma,\lambda)}(S_t,A_t;\phi) = \sum_{n=0}^{\inf} (\gamma \lambda)^{n} \delta_{t+n}^{V}$
#
# ### Q2. What happens at the extreme values of λ, and what is a good practical default?
#
# * For $\lambda = 0$:
#
#     $A^{GAE(\gamma,0)}(S_t,A_t;\phi) = R_t + \gamma V(S_{t+1};\phi) - V(s_{t};\phi)$
#
#     GAE acts like 1 step TD advantage with less variance but high bias.
#
# * For $\lambda = 1$:
#
#     $A^{GAE(\gamma,1)}(S_t,A_t;\phi) = \sum_{n=0}^{\inf} \gamma^{n} \delta_{t+n}^{V}$
#
#     GAE acts like full Monte Carlo advantage with low bias but high variance.
#
# * Good practical default is 0.95 which will reduce variance at the cost of little bias.
#
# ### Q3. From the GAE lambda sweep experiment, which lambda values perform best and why?
#
# * From the GAE lamda sweep experiment, lambda value of 0.95 observed performing the best among others.
#
#     1. lambda with value 1 has Monte Carlo returns having high variance, which eventually hurts the reward and ends up making the second lowest reward.
#
#     2. lamda with value 0 uses bootstrapping (or 1 step returns) for advantage estimation but it is observed to get stuck leading to premature convergence.
#
#     3. lamda with value 0.99 works better then lambda = 1 sinice it tries to reduce variance at the cost of little bias which it helps it in making higher rewards.
#
#     4. lambda with 0.5 is observed to be working better than lambda with 0.99 (but it is not must) implies that using half of the trajectory returns is helping the agent in making good rewards.
#
#     5. lambda with 0.95 is seen to be worked best among others. Although policy is collapsing in the middle of the steps but then recovering but lambda has nothing to do with this, since it only deals with bias-variance trade-off. And here despite having little bias and variance, it performs better and stable.
#
# ### Q4. How does GAE relate to TD(λ) from tabular RL?
#
# * GAE and $TD(\lambda)$ both uses mathematically similar concept but use cases and manneer in which it is used, is different.
#
#     1. $TD(\lambda)$:
#
#         $G_{t:T}^{\lambda} = (1-\lambda) * \sum_{n=1}^{T-t-1} \lambda^{n-1} G_{t:t+n} + \lambda^{T-t-1} G_{t:T}$
#
#         * $TD(\lambda)$ is used for value estimation in tabular RL. It uses eligibility traces for keep tracking of past visited states and based on their visited frequency make changes in the value estimates.
#
#         * But the main reason of using this $\lambda$ is for better trade-off between bias and variance. Since, with $\lambda=0$, it reduces to TD learnring and with $\lambda=1$, returns reduces to Monte Carlo style learning considering full trajectoey returns which introcues variance.
#
#
#     2. GAE:
#
#         $A^{GAE(\gamma,\lambda)}(S_t,A_t;\phi) = \sum_{n=0}^{\inf} (\gamma \lambda)^{n} \delta_{t+n}^{V}$
#
#         GAE is used in advantage estimation in policy based methods, since estimating advantage using either 1-step or full trajectory returns either introduces bias or variance repectively. So, again for stable and smoother curves, did weighted sum of all TD errors for advantage estimation as mentioned above.

# %% [markdown]
# # Deep Deterministic Policy Gradient (DDPG) [50 marks]
# <a id="ddpg"></a>

# %% [markdown]
# Implement the Deep Deterministic Policy Gradient (DDPG) agent. We have studied about DDPG agent in the Lecture. Use the function definitions (given below).
#
# This class implements the DDPG agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# ```
# class DDPG():
#     def init(self, env, seed, gamma, tau, bufferSize, batch_size, updateFrequency,
#              policyOptimizerFn, valueOptimizerFn,
#              policyOptimizerLR,valueOptimizerLR,
#              MAX_TRAIN_EPISODES,MAX_EVAL_EPISODE,
#              optimizerFn)
#
#     def runDDPG(self)
#     def trainAgent(self)
#     def gaussianStrategy(self, net , s , envActionRange , noiseScaleRatio,
#         explorationMax = True)
#     def greedyStrategy(self, net , s , envActionRange)
#     def trainNetworks(self, experiences)
#     def updateNetworks(self, onlineNet, targetNet, tau)
#     def evaluateAgent(self)
#
#
#
#
# ```

# %%
class DDPG():
    def __init__(self, env, seed, gamma, tau, bufferSize, batch_size, updateFrequency,
             policyOptimizerFn, valueOptimizerFn,
             policyOptimizerLR,valueOptimizerLR,
             MAX_TRAIN_EPISODES,MAX_EVAL_EPISODE,
             optimizerFn):
        #this DDPG method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates targetValueNetwork , targetPolicyNetwork
        # 4. creates and initializes (with network params) the optimizer function
        # 5. creates onlineValueNetwork, onlinePolicyNetwork
        # 6. Creates the replayBuffer

        #Your code goes in here
        self.env = env
        self.seed = seed
        self.env.reset(seed=seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        self.env.action_space.seed(seed)
        self.env.observation_space.seed(seed)

        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODE = MAX_EVAL_EPISODE
        self.MAX_VALUE_GRAD_NORM = MAX_GRAD_NORM_VALUE
        self.MAX_POLICY_GRAD_NORM = MAX_GRAD_NORM_POLICY

        self.gamma = gamma
        self.tau = tau
        self.bufferSize = bufferSize
        self.batch_size = batch_size
        self.updateFrequency = updateFrequency
        self.minSamples = minSamples
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.obs_dim = self.env.observation_space.shape[0]
        self.act_dim = self.env.action_space.shape[0]
        self.max_steps = ep_max_steps
        self.noiseScaleRatio = noiseScaleRatio

        self.targetValueNetwork = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.onlineValueNetwork = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.targetPolicyNetwork = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=[324, 256, 256], use_tanh=True).to(self.device)
        self.onlinePolicyNetwork = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=[324, 256, 256], use_tanh=True).to(self.device)

        self.updateNetworks(self.onlineValueNetwork, self.targetValueNetwork, 1.0)
        self.updateNetworks(self.onlinePolicyNetwork, self.targetPolicyNetwork, 1.0)

        self.policyOptimizer = policyOptimizerFn(self.onlinePolicyNetwork.parameters(), lr=policyOptimizerLR)
        self.valueOptimizer = valueOptimizerFn(self.onlineValueNetwork.parameters(), lr=valueOptimizerLR)

        self.actionLowVal = torch.tensor(self.env.action_space.low, dtype=torch.float32).to(self.device)
        self.actionHighVal = torch.tensor(self.env.action_space.high, dtype=torch.float32).to(self.device)
        self.envActionRange = (self.actionLowVal, self.actionHighVal)

        self.initBookKeeping()
        self.rBuffer = ReplayBuffer(self.bufferSize, self.batch_size, self.seed)

# %%
class DDPG(DDPG):
    def initBookKeeping(self):

      self.trainRewardsList = []
      self.evalRewardsList = []
      self.trainTimeList = []
      self.wallClockTimeList = []
      self.totalStepsList = []

      self.startTime = time.time()

    def performBookKeeping(self, train=True):
        if train:
            self.trainTimeList.append(time.time() - self.startTime)
        else:
            self.wallClockTimeList.append(time.time() - self.startTime)

# %%
class DDPG(DDPG):
    def updateNetworks(self, onlineNet, targetNet, tau):
        #this function updates the onlineNetwork with the target network
        #
        # Your code goes in here
        #
        for targetParam, onlineParam in zip(targetNet.parameters(), onlineNet.parameters()):
            mixedWeights = onlineParam.data * tau + targetParam.data * (1 - tau)
            targetParam.data.copy_(mixedWeights)

# %%
class DDPG(DDPG):
    def gaussianStrategy (self, net , s , envActionRange , noiseScaleRatio , explorationMax = True):
        #this function sets the scale of exploration then add the noise of this scale to the greedy action
        #and clips it within the range

        #Your code here
        if explorationMax:
            return self.env.action_space.sample()

        with torch.no_grad():
            state = torch.FloatTensor(s).unsqueeze(0).to(self.device)
            actionLowVec, actionHighVec = envActionRange
            action = net(state).cpu().numpy()[0]

            if noiseScaleRatio > 0:
                noise = np.random.normal(0, noiseScaleRatio, size=action.shape)
                action = action + noise

            action = np.clip(action, actionLowVec.cpu().numpy(), actionHighVec.cpu().numpy())

            return action

# %%
class DDPG(DDPG):
    def greedyStrategy (self, net , s , envActionRange):
        #this function selects the greedy action
        #and clips it within the range

        #Your code here
        with torch.no_grad():
            state = torch.FloatTensor(s).unsqueeze(0).to(self.device)
            actionLowVec, actionHighVec = envActionRange
            action = net(state).cpu().numpy()[0]

            action = np.clip(action, actionLowVec.cpu().numpy(), actionHighVec.cpu().numpy())

            return action

# %%
class DDPG(DDPG):
    def runDDPG (self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.
        #
        #Your code goes in here
        #
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
        finalEvalReward = self.evaluateAgent()
        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward

# %%
class DDPG(DDPG):
    def trainAgent(self):
        #this method collects experiences and trains the agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES
        #
        #Your code goes in here
        #
        global_steps = 0
        global_max_steps = self.MAX_TRAIN_EPISODES * self.max_steps

        for e in range(self.MAX_TRAIN_EPISODES):
            s, _ = self.env.reset()
            train_r = 0.0
            steps = 0
            done = False

            while steps < self.max_steps and not done:
                # i am decaying noiseScaleRatio linearly wrt the global number of steps taken overs episodes
                current_noise = max(0.01, self.noiseScaleRatio * (1 - global_steps / global_max_steps))
                action = self.gaussianStrategy(
                    self.onlinePolicyNetwork, s, self.envActionRange, current_noise,
                    self.rBuffer.length() < self.minSamples
                )

                sNext, rs, done, truncated, _ = self.env.step(action)
                done = done or truncated
                train_r += rs

                self.rBuffer.store(s, action, rs, sNext, done)

                if self.rBuffer.length() >= self.minSamples:
                    experiences = self.rBuffer.sample(self.batch_size)
                    self.trainNetwork(experiences)

                    if steps % self.updateFrequency == 0:
                        self.updateNetworks(self.onlineValueNetwork, self.targetValueNetwork, self.tau)
                        self.updateNetworks(self.onlinePolicyNetwork, self.targetPolicyNetwork, self.tau)

                steps += 1
                global_steps += 1
                s = sNext
            # for reporting episodewise train time, I am bookkeeping traain time after episode ends not after each step
            self.performBookKeeping(train=True)

            # evaluating after every episode
            eval_r = self.evaluateAgent()
            self.performBookKeeping(train=False)

            self.trainRewardsList.append(train_r)
            self.evalRewardsList.append(eval_r)
            self.totalStepsList.append(steps)

            if (e+1) % 5 == 0:
                print(f"[Episode {e+1}/{self.MAX_TRAIN_EPISODES}] Train Reward: {train_r:.3f} | Eval Reward: {eval_r:.3f} | Steps: {steps}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList, self.wallClockTimeList, self.totalStepsList

# %%
class DDPG(DDPG):
    def trainNetwork(self, experiences):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.
        #
        #Your code goes in here

        ss, actions, rs, sNexts, dones = self.rBuffer.splitExperiences(experiences)

        ss = ss.to(self.device)
        actions = actions.to(self.device)
        rs = rs.to(self.device)
        sNexts = sNexts.to(self.device)
        dones = dones.to(self.device)

        with torch.no_grad():
            next_actions = self.targetPolicyNetwork(sNexts)
            next_q = self.targetValueNetwork(sNexts, next_actions)
            targets = rs + self.gamma * (1 - dones) * next_q

        current_q = self.onlineValueNetwork(ss, actions)
        valueLoss = F.mse_loss(current_q, targets)

        self.valueOptimizer.zero_grad()
        valueLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizer.step()

        pred_actions = self.onlinePolicyNetwork(ss)
        actor_loss = -self.onlineValueNetwork(ss, pred_actions).mean()
        self.policyOptimizer.zero_grad()
        actor_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.onlinePolicyNetwork.parameters(), self.MAX_POLICY_GRAD_NORM)
        self.policyOptimizer.step()

# %%
class DDPG(DDPG):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1
        #
        #Your code goes in here

        final_eval_r = 0.0
        for e in range(self.MAX_EVAL_EPISODE):
            s, _ = self.env.reset()
            done = False
            for c in count():
                envActionRange = (self.actionLowVal, self.actionHighVal)
                a = self.greedyStrategy(self.onlinePolicyNetwork, s, envActionRange)
                s_next, r, done, truncated, _ = self.env.step(a)
                final_eval_r += r
                s = s_next
                if done or truncated:
                    break
        final_eval_r /= self.MAX_EVAL_EPISODE
        return final_eval_r

# %%
# evaluating the DDPG agent on multiple continuous-control

# Environments used in this experiment
ddpg_env_name = "HalfCheetah-v4"

quantityDictDDPG = {}

# Number of independent training runs per environment
num_runs = 5

all_train_rewards = []
all_eval_rewards = []
all_total_steps = []
all_train_times = []
all_wall_times = []

# For each environment:
print(f"\n===== Environment: {ddpg_env_name} =====")
for run in range(num_runs):
    print(f"Executing Run {run+1}  ")

    # Create environment
    env = gym.make(ddpg_env_name)

    agent = DDPG(
        env, base_seed + run, gamma, tau, bufferSize, batchSize, updateFrequency,
        policyOptimizerFn, valueOptimizerFn,
        policyOptimizerLR, valueOptimizerLR,
        MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
        optimizerFn
    )

    # Run training
    train_rewards, train_times, eval_rewards, wallclock_times, total_steps, final_eval_reward = agent.runDDPG()

    print(f"Finished Run {run+1}  ")

    all_train_rewards.append(train_rewards)
    all_eval_rewards.append(eval_rewards)
    all_train_times.append(train_times)
    all_wall_times.append(wallclock_times)
    all_total_steps.append(total_steps)

quantityDictDDPG[ddpg_env_name] = {
    "Mean Train Rewards": {
        "DDPG": all_train_rewards
    },
    "Mean Eval Rewards": {
        "DDPG": all_eval_rewards
    },
    "Train Time (in sec)": {
        "DDPG": all_train_times
    },
    "Wall Clock Time (in sec)": {
        "DDPG": all_wall_times
    },
    "Total Steps": {
        "DDPG": all_total_steps
    }
}

train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
print(f"Finished {ddpg_env_name}")
# Out:
# ===== Environment: HalfCheetah-v4 =====
# Executing Run 1
# [Episode 5/150] Train Reward: -227.522 | Eval Reward: -145.501 | Steps: 1000
# [Episode 10/150] Train Reward: -383.397 | Eval Reward: -104.322 | Steps: 1000
# [Episode 15/150] Train Reward: -394.992 | Eval Reward: -350.118 | Steps: 1000
# [Episode 20/150] Train Reward: -124.626 | Eval Reward: -137.519 | Steps: 1000
# [Episode 25/150] Train Reward: 114.568 | Eval Reward: -298.274 | Steps: 1000
# [Episode 30/150] Train Reward: 138.172 | Eval Reward: 254.087 | Steps: 1000
# [Episode 35/150] Train Reward: 136.137 | Eval Reward: 140.005 | Steps: 1000
# [Episode 40/150] Train Reward: 307.940 | Eval Reward: 376.075 | Steps: 1000
# [Episode 45/150] Train Reward: -81.746 | Eval Reward: 243.663 | Steps: 1000
# [Episode 50/150] Train Reward: 25.917 | Eval Reward: -190.113 | Steps: 1000
# [Episode 55/150] Train Reward: -20.437 | Eval Reward: 584.509 | Steps: 1000
# [Episode 60/150] Train Reward: 445.406 | Eval Reward: 542.491 | Steps: 1000
# [Episode 65/150] Train Reward: 421.804 | Eval Reward: 4.524 | Steps: 1000
# [Episode 70/150] Train Reward: 691.046 | Eval Reward: 668.249 | Steps: 1000
# [Episode 75/150] Train Reward: 740.190 | Eval Reward: 145.552 | Steps: 1000
# [Episode 80/150] Train Reward: 1172.190 | Eval Reward: 699.736 | Steps: 1000
# [Episode 85/150] Train Reward: 1390.724 | Eval Reward: 1051.116 | Steps: 1000
# [Episode 90/150] Train Reward: 1074.555 | Eval Reward: 1574.092 | Steps: 1000
# [Episode 95/150] Train Reward: 1853.789 | Eval Reward: 1776.223 | Steps: 1000
# [Episode 100/150] Train Reward: 1712.243 | Eval Reward: 2199.126 | Steps: 1000
# [Episode 105/150] Train Reward: 1864.631 | Eval Reward: 1699.934 | Steps: 1000
# [Episode 110/150] Train Reward: 1954.558 | Eval Reward: 1719.247 | Steps: 1000
# [Episode 115/150] Train Reward: 2728.230 | Eval Reward: 2308.916 | Steps: 1000
# [Episode 120/150] Train Reward: 2494.428 | Eval Reward: 2728.153 | Steps: 1000
# [Episode 125/150] Train Reward: 2744.001 | Eval Reward: 2475.153 | Steps: 1000
# [Episode 130/150] Train Reward: 3161.929 | Eval Reward: 1760.439 | Steps: 1000
# [Episode 135/150] Train Reward: 3360.134 | Eval Reward: 2635.467 | Steps: 1000
# [Episode 140/150] Train Reward: 2704.850 | Eval Reward: 2303.924 | Steps: 1000
# [Episode 145/150] Train Reward: 3192.354 | Eval Reward: 3341.956 | Steps: 1000
# [Episode 150/150] Train Reward: 3161.736 | Eval Reward: 3231.211 | Steps: 1000
# Finished Run 1
# Executing Run 2
# [Episode 5/150] Train Reward: -358.640 | Eval Reward: -1102.361 | Steps: 1000
# [Episode 10/150] Train Reward: -402.689 | Eval Reward: -1237.794 | Steps: 1000
# [Episode 15/150] Train Reward: -392.387 | Eval Reward: -607.760 | Steps: 1000
# [Episode 20/150] Train Reward: -80.412 | Eval Reward: -549.861 | Steps: 1000
# [Episode 25/150] Train Reward: -28.777 | Eval Reward: -325.330 | Steps: 1000
# [Episode 30/150] Train Reward: 121.576 | Eval Reward: 40.678 | Steps: 1000
# [Episode 35/150] Train Reward: 73.860 | Eval Reward: 254.627 | Steps: 1000
# [Episode 40/150] Train Reward: 119.708 | Eval Reward: 386.948 | Steps: 1000
# [Episode 45/150] Train Reward: -286.195 | Eval Reward: 84.434 | Steps: 1000
# [Episode 50/150] Train Reward: 117.696 | Eval Reward: 294.607 | Steps: 1000
# [Episode 55/150] Train Reward: -112.923 | Eval Reward: 321.971 | Steps: 1000
# [Episode 60/150] Train Reward: 64.163 | Eval Reward: 218.511 | Steps: 1000
# [Episode 65/150] Train Reward: 114.308 | Eval Reward: 554.556 | Steps: 1000
# [Episode 70/150] Train Reward: 750.133 | Eval Reward: -38.858 | Steps: 1000
# [Episode 75/150] Train Reward: 763.384 | Eval Reward: 604.006 | Steps: 1000
# [Episode 80/150] Train Reward: 36.165 | Eval Reward: 958.768 | Steps: 1000
# [Episode 85/150] Train Reward: 614.839 | Eval Reward: 1212.652 | Steps: 1000
# [Episode 90/150] Train Reward: 1425.324 | Eval Reward: 1165.093 | Steps: 1000
# [Episode 95/150] Train Reward: 1504.673 | Eval Reward: 956.337 | Steps: 1000
# [Episode 100/150] Train Reward: 1348.880 | Eval Reward: 1824.730 | Steps: 1000
# [Episode 105/150] Train Reward: 1993.965 | Eval Reward: 1896.564 | Steps: 1000
# [Episode 110/150] Train Reward: 2117.123 | Eval Reward: 2214.193 | Steps: 1000
# [Episode 115/150] Train Reward: 2465.142 | Eval Reward: 2227.536 | Steps: 1000
# [Episode 120/150] Train Reward: 2037.356 | Eval Reward: 2745.484 | Steps: 1000
# [Episode 125/150] Train Reward: 2966.493 | Eval Reward: 2795.227 | Steps: 1000
# [Episode 130/150] Train Reward: 2681.392 | Eval Reward: 2667.105 | Steps: 1000
# [Episode 135/150] Train Reward: 2873.161 | Eval Reward: 2855.858 | Steps: 1000
# [Episode 140/150] Train Reward: 2827.637 | Eval Reward: 2695.409 | Steps: 1000
# [Episode 145/150] Train Reward: 3022.810 | Eval Reward: 3380.921 | Steps: 1000
# [Episode 150/150] Train Reward: 3182.385 | Eval Reward: 3061.332 | Steps: 1000
# Finished Run 2
# Executing Run 3
# [Episode 5/150] Train Reward: -202.823 | Eval Reward: -41.513 | Steps: 1000
# [Episode 10/150] Train Reward: -401.966 | Eval Reward: -76.587 | Steps: 1000
# [Episode 15/150] Train Reward: -360.965 | Eval Reward: -456.668 | Steps: 1000
# [Episode 20/150] Train Reward: -52.683 | Eval Reward: 47.591 | Steps: 1000
# [Episode 25/150] Train Reward: 161.981 | Eval Reward: 177.172 | Steps: 1000
# [Episode 30/150] Train Reward: 196.637 | Eval Reward: 76.652 | Steps: 1000
# [Episode 35/150] Train Reward: 245.897 | Eval Reward: -102.694 | Steps: 1000
# [Episode 40/150] Train Reward: 223.519 | Eval Reward: 170.608 | Steps: 1000
# [Episode 45/150] Train Reward: 313.724 | Eval Reward: 223.921 | Steps: 1000
# [Episode 50/150] Train Reward: -160.848 | Eval Reward: 235.717 | Steps: 1000
# [Episode 55/150] Train Reward: 376.441 | Eval Reward: 462.786 | Steps: 1000
# [Episode 60/150] Train Reward: 210.817 | Eval Reward: 327.877 | Steps: 1000
# [Episode 65/150] Train Reward: 319.029 | Eval Reward: -264.970 | Steps: 1000
# [Episode 70/150] Train Reward: 554.161 | Eval Reward: 266.172 | Steps: 1000
# [Episode 75/150] Train Reward: 736.997 | Eval Reward: 14.313 | Steps: 1000
# [Episode 80/150] Train Reward: 735.506 | Eval Reward: 329.457 | Steps: 1000
# [Episode 85/150] Train Reward: -105.219 | Eval Reward: 279.362 | Steps: 1000
# [Episode 90/150] Train Reward: -310.371 | Eval Reward: 4.615 | Steps: 1000
# [Episode 95/150] Train Reward: 495.787 | Eval Reward: -82.249 | Steps: 1000
# [Episode 100/150] Train Reward: 1414.433 | Eval Reward: 1385.822 | Steps: 1000
# [Episode 105/150] Train Reward: 1327.917 | Eval Reward: 1296.082 | Steps: 1000
# [Episode 110/150] Train Reward: 1834.586 | Eval Reward: 1728.401 | Steps: 1000
# [Episode 115/150] Train Reward: 1946.308 | Eval Reward: 1685.327 | Steps: 1000
# [Episode 120/150] Train Reward: 1560.297 | Eval Reward: 1823.514 | Steps: 1000
# [Episode 125/150] Train Reward: -197.639 | Eval Reward: 2176.265 | Steps: 1000
# [Episode 130/150] Train Reward: 2313.320 | Eval Reward: 1956.226 | Steps: 1000
# [Episode 135/150] Train Reward: 2631.910 | Eval Reward: 2359.674 | Steps: 1000
# [Episode 140/150] Train Reward: 2621.550 | Eval Reward: 2382.587 | Steps: 1000
# [Episode 145/150] Train Reward: 2479.805 | Eval Reward: 2795.797 | Steps: 1000
# [Episode 150/150] Train Reward: 3015.780 | Eval Reward: 2920.021 | Steps: 1000
# Finished Run 3
# Executing Run 4
# [Episode 5/150] Train Reward: -367.730 | Eval Reward: -68.664 | Steps: 1000
# [Episode 10/150] Train Reward: -290.757 | Eval Reward: -81.946 | Steps: 1000
# [Episode 15/150] Train Reward: -486.100 | Eval Reward: -525.682 | Steps: 1000
# [Episode 20/150] Train Reward: 8.070 | Eval Reward: -55.395 | Steps: 1000
# [Episode 25/150] Train Reward: 282.215 | Eval Reward: 186.129 | Steps: 1000
# [Episode 30/150] Train Reward: 119.350 | Eval Reward: -11.554 | Steps: 1000
# [Episode 35/150] Train Reward: 372.840 | Eval Reward: 21.696 | Steps: 1000
# [Episode 40/150] Train Reward: -7.513 | Eval Reward: 473.171 | Steps: 1000
# [Episode 45/150] Train Reward: 402.428 | Eval Reward: 213.527 | Steps: 1000
# [Episode 50/150] Train Reward: 329.992 | Eval Reward: 476.447 | Steps: 1000
# [Episode 55/150] Train Reward: -151.697 | Eval Reward: 531.303 | Steps: 1000
# [Episode 60/150] Train Reward: 452.901 | Eval Reward: 502.435 | Steps: 1000
# [Episode 65/150] Train Reward: -118.562 | Eval Reward: 193.684 | Steps: 1000
# [Episode 70/150] Train Reward: -210.146 | Eval Reward: 796.990 | Steps: 1000
# [Episode 75/150] Train Reward: 971.763 | Eval Reward: 863.472 | Steps: 1000
# [Episode 80/150] Train Reward: 860.566 | Eval Reward: 331.521 | Steps: 1000
# [Episode 85/150] Train Reward: 1384.313 | Eval Reward: 1461.594 | Steps: 1000
# [Episode 90/150] Train Reward: 1470.079 | Eval Reward: 1694.119 | Steps: 1000
# [Episode 95/150] Train Reward: 1882.166 | Eval Reward: 1654.530 | Steps: 1000
# [Episode 100/150] Train Reward: 2219.256 | Eval Reward: 2277.522 | Steps: 1000
# [Episode 105/150] Train Reward: 2273.892 | Eval Reward: 2796.659 | Steps: 1000
# [Episode 110/150] Train Reward: 2660.652 | Eval Reward: 3051.137 | Steps: 1000
# [Episode 115/150] Train Reward: 2536.029 | Eval Reward: 2845.429 | Steps: 1000
# [Episode 120/150] Train Reward: 2981.496 | Eval Reward: 2910.843 | Steps: 1000
# [Episode 125/150] Train Reward: 3115.290 | Eval Reward: 3113.396 | Steps: 1000
# [Episode 130/150] Train Reward: 2932.479 | Eval Reward: 3132.748 | Steps: 1000
# [Episode 135/150] Train Reward: 3350.098 | Eval Reward: 3490.810 | Steps: 1000
# [Episode 140/150] Train Reward: 3454.172 | Eval Reward: 3650.538 | Steps: 1000
# [Episode 145/150] Train Reward: 3312.568 | Eval Reward: 1931.726 | Steps: 1000
# [Episode 150/150] Train Reward: 3305.366 | Eval Reward: 3523.151 | Steps: 1000
# Finished Run 4
# Executing Run 5
# [Episode 5/150] Train Reward: -346.956 | Eval Reward: -154.265 | Steps: 1000
# [Episode 10/150] Train Reward: -208.350 | Eval Reward: -198.660 | Steps: 1000
# [Episode 15/150] Train Reward: -233.496 | Eval Reward: -548.665 | Steps: 1000
# [Episode 20/150] Train Reward: -356.252 | Eval Reward: -372.839 | Steps: 1000
# [Episode 25/150] Train Reward: 98.047 | Eval Reward: 6.239 | Steps: 1000
# [Episode 30/150] Train Reward: -21.807 | Eval Reward: -210.689 | Steps: 1000
# [Episode 35/150] Train Reward: -192.907 | Eval Reward: 96.207 | Steps: 1000
# [Episode 40/150] Train Reward: -257.510 | Eval Reward: 227.477 | Steps: 1000
# [Episode 45/150] Train Reward: -36.750 | Eval Reward: -136.692 | Steps: 1000
# [Episode 50/150] Train Reward: -349.151 | Eval Reward: -180.852 | Steps: 1000
# [Episode 55/150] Train Reward: -1.644 | Eval Reward: -52.225 | Steps: 1000
# [Episode 60/150] Train Reward: -48.910 | Eval Reward: 179.024 | Steps: 1000
# [Episode 65/150] Train Reward: 748.158 | Eval Reward: 281.407 | Steps: 1000
# [Episode 70/150] Train Reward: 424.016 | Eval Reward: -105.965 | Steps: 1000
# [Episode 75/150] Train Reward: 690.835 | Eval Reward: 563.852 | Steps: 1000
# [Episode 80/150] Train Reward: 565.948 | Eval Reward: 882.636 | Steps: 1000
# [Episode 85/150] Train Reward: 104.363 | Eval Reward: 671.097 | Steps: 1000
# [Episode 90/150] Train Reward: 765.843 | Eval Reward: 938.147 | Steps: 1000
# [Episode 95/150] Train Reward: 545.096 | Eval Reward: 696.587 | Steps: 1000
# [Episode 100/150] Train Reward: 723.752 | Eval Reward: 1284.236 | Steps: 1000
# [Episode 105/150] Train Reward: 1353.450 | Eval Reward: 1676.501 | Steps: 1000
# [Episode 110/150] Train Reward: 1739.309 | Eval Reward: 1541.572 | Steps: 1000
# [Episode 115/150] Train Reward: 1103.690 | Eval Reward: 1815.448 | Steps: 1000
# [Episode 120/150] Train Reward: 1766.384 | Eval Reward: 2059.190 | Steps: 1000
# [Episode 125/150] Train Reward: -360.951 | Eval Reward: 2247.872 | Steps: 1000
# [Episode 130/150] Train Reward: 2361.811 | Eval Reward: 2061.916 | Steps: 1000
# [Episode 135/150] Train Reward: 2312.748 | Eval Reward: 2806.155 | Steps: 1000
# [Episode 140/150] Train Reward: 2493.101 | Eval Reward: 2431.526 | Steps: 1000
# [Episode 145/150] Train Reward: 2103.114 | Eval Reward: 2554.943 | Steps: 1000
# [Episode 150/150] Train Reward: 2749.048 | Eval Reward: 2883.168 | Steps: 1000
# Finished Run 5
# (Mean over last 50 epiosdes) Mean train rewards: 2316.21 | Mean Eval Score: 2319.91
# Finished HalfCheetah-v4

# %% [markdown]
# For DDPG, seeds used are [21, 22, 23, 24, 25]

# %% [markdown]
# # Twin-Delayed Deep Deterministic Policy Gradient (TD3) [50 marks]
# <a id="td3"></a>

# %% [markdown]
# Implement the Twin-delayed deep deterministic policy gradient (TD3) agent. We have studied about TD3 agent in the Lecture. Use the function definitions (given below).
#
# This class implements the TD3 agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# ```
# class DDPG():
#     def init(env, gamma, tau,
#     bufferSize ,
#     updateFrequencyPolicy ,
#     updateFrequencyValue ,
#     trainPolicyFrequency ,
#     policyOptimizerFn ,
#     valueOptimizerFn ,
#     policyOptimizerLR ,
#     valueOptimizerLR ,
#     MAX TRAIN EPISODES,
#     MAX EVAL EPISODE,
#     optimizerFn )
#
#     def runTD3 (self)
#     def trainAgent (self)
#     def gaussianStrategy (self, net , s , envActionRange , noiseScaleRatio ,
#         explorationMax = True)
#     def greedyStrategy (self, net , s , envActionRange)
#     def trainNetworks (self,experiences , envActionRange)
#     def updateValueNetwork(self, onlineNet, targetNet, tau)
#     def updatePolicyNetwork(self, onlineNet, targetNet, tau)
#     def evaluateAgent (self)
#
#
#
# ```

# %%
class TD3():
    def __init__(self, seed, env, gamma, tau,
    bufferSize ,
    updateFrequencyPolicy ,
    updateFrequencyValue ,
    trainPolicyFrequency ,
    policyOptimizerFn ,
    valueOptimizerFn ,
    policyOptimizerLR ,
    valueOptimizerLR ,
    MAX_TRAIN_EPISODES,
    MAX_EVAL_EPISODE,
    optimizerFn):
        #this TD3 method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates targetValueNetwork , targetPolicyNetwork
        # 4. creates and initializes (with network params) the optimizer function
        # 5. creates onlineValueNetwork, onlinePolicyNetwork
        # 6. Creates the replayBuffer

        #Your code goes in here
        self.env = env
        self.seed = seed
        self.env.reset(seed=seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        self.env.action_space.seed(seed)
        self.env.observation_space.seed(seed)

        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODE = MAX_EVAL_EPISODE
        self.MAX_VALUE_GRAD_NORM = MAX_GRAD_NORM_VALUE
        self.MAX_POLICY_GRAD_NORM = MAX_GRAD_NORM_POLICY

        self.gamma = gamma
        self.tau = tau
        self.bufferSize = bufferSize
        self.batch_size = batchSize
        self.updateFrequencyValue = updateFrequencyValue
        self.updateFrequencyPolicy = updateFrequencyPolicy
        self.trainPolicyFrequency = trainPolicyFrequency
        self.minSamples = minSamples
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.obs_dim = self.env.observation_space.shape[0]
        self.act_dim = self.env.action_space.shape[0]
        self.max_steps = ep_max_steps
        self.noiseScaleRatio = noiseScaleRatio

        self.targetValueNetwork1 = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.onlineValueNetwork1 = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.targetValueNetwork2 = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.onlineValueNetwork2 = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.targetPolicyNetwork = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=[324, 256, 256], use_tanh=True).to(self.device)
        self.onlinePolicyNetwork = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=[324, 256, 256], use_tanh=True).to(self.device)

        self.updateValueNetwork(self.onlineValueNetwork1, self.targetValueNetwork1, 1.0)
        self.updateValueNetwork(self.onlineValueNetwork2, self.targetValueNetwork2, 1.0)
        self.updatePolicyNetwork(self.onlinePolicyNetwork, self.targetPolicyNetwork, 1.0)

        self.policyOptimizer = policyOptimizerFn(self.onlinePolicyNetwork.parameters(), lr=policyOptimizerLR)
        self.valueOptimizer1 = valueOptimizerFn(self.onlineValueNetwork1.parameters(), lr=valueOptimizerLR)
        self.valueOptimizer2 = valueOptimizerFn(self.onlineValueNetwork2.parameters(), lr=valueOptimizerLR)

        self.actionLowVal = torch.tensor(self.env.action_space.low, dtype=torch.float32).to(self.device)
        self.actionHighVal = torch.tensor(self.env.action_space.high, dtype=torch.float32).to(self.device)
        self.envActionRange = (self.actionLowVal, self.actionHighVal)
        self.action_scale = torch.tensor((self.env.action_space.high - self.env.action_space.low) / 2.0, dtype=torch.float32).to(self.device)

        self.initBookKeeping()
        self.rBuffer = ReplayBuffer(self.bufferSize, self.batch_size, self.seed)

# %%
class TD3(TD3):
    def initBookKeeping(self):
      self.trainRewardsList = []
      self.evalRewardsList = []
      self.trainTimeList = []
      self.wallClockTimeList = []
      self.totalStepsList = []

      self.startTime = time.time()

    def performBookKeeping(self, train=True):
        if train:
            self.trainTimeList.append(time.time() - self.startTime)
        else:
            self.wallClockTimeList.append(time.time() - self.startTime)

# %%
class TD3(TD3):
    def updateValueNetwork(self, onlineNet, targetNet, tau):
        #this function updates the onlineValueNetwork with the targetValuenetwork
        #
        # Your code goes in here
        #
        for targetParam, onlineParam in zip(targetNet.parameters(), onlineNet.parameters()):
            mixedWeights = onlineParam.data * tau + targetParam.data * (1 - tau)
            targetParam.data.copy_(mixedWeights)

# %%
class TD3(TD3):
    def updatePolicyNetwork(self, onlineNet, targetNet, tau):
        #this function updates the onlinePolicuNetwork with the targetPolicynetwork
        #
        # Your code goes in here
        #
        for targetParam, onlineParam in zip(targetNet.parameters(), onlineNet.parameters()):
            mixedWeights = onlineParam.data * tau + targetParam.data * (1 - tau)
            targetParam.data.copy_(mixedWeights)

# %%
class TD3(TD3):
    def gaussianStrategy (self, net , s , envActionRange , noiseScaleRatio ,
        explorationMax = True ):
        #this function sets the scale of exploration then add the noise of this scale to the greedy action
        #and clips it within the range

        #Your code here
        if explorationMax:
            return self.env.action_space.sample()

        with torch.no_grad():
            state = torch.FloatTensor(s).unsqueeze(0).to(self.device)
            actionLowVec, actionHighVec = envActionRange
            action = net(state).cpu().numpy()[0]

            if noiseScaleRatio > 0:
                noise = np.random.normal(0, noiseScaleRatio, size=action.shape)
                action = action + noise

            action = np.clip(action, actionLowVec.cpu().numpy(), actionHighVec.cpu().numpy())

            return action

# %%
class TD3(TD3):
    def greedyStrategy (self, net , s , envActionRange ):
        #this function selects the greedy action
        #and clips it within the range

        #Your code here
        with torch.no_grad():
            state = torch.FloatTensor(s).unsqueeze(0).to(self.device)
            actionLowVec, actionHighVec = envActionRange
            action = net(state).cpu().numpy()[0]

            action = np.clip(action, actionLowVec.cpu().numpy(), actionHighVec.cpu().numpy())

            return action

# %%
class TD3(TD3):
    def runTD3 (self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.
        #
        #Your code goes in here
        #
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
        finalEvalReward = self.evaluateAgent()
        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward

# %%
class TD3(TD3):
    def trainAgent(self):
        #this method collects experiences and trains the agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES
        #
        #Your code goes in here
        #
        self.global_steps = 0
        global_max_steps = self.MAX_TRAIN_EPISODES * self.max_steps

        for e in range(self.MAX_TRAIN_EPISODES):
            s, _ = self.env.reset()
            train_r = 0.0
            steps = 0
            done = False

            while steps < self.max_steps and not done:
                # i am decaying noiseScaleRatio linearly wrt the global number of steps taken across episodes
                current_noise = max(0.01, self.noiseScaleRatio * (1 - self.global_steps / global_max_steps))
                action = self.gaussianStrategy(
                    self.onlinePolicyNetwork, s, self.envActionRange, current_noise,
                    self.rBuffer.length() < self.minSamples
                )

                sNext, rs, done, truncated, _ = self.env.step(action)
                done = done or truncated
                train_r += rs

                self.rBuffer.store(s, action, rs, sNext, done)

                if self.rBuffer.length() >= self.minSamples:
                    experiences = self.rBuffer.sample(self.batch_size)
                    self.trainNetwork(experiences, self.envActionRange)

                    if steps % self.updateFrequencyValue == 0:
                        self.updateValueNetwork(self.onlineValueNetwork1, self.targetValueNetwork1, self.tau)
                        self.updateValueNetwork(self.onlineValueNetwork2, self.targetValueNetwork2, self.tau)

                    if steps % self.updateFrequencyPolicy == 0:
                        self.updatePolicyNetwork(self.onlinePolicyNetwork, self.targetPolicyNetwork, self.tau)

                steps += 1
                self.global_steps += 1
                s = sNext
            
            self.performBookKeeping(train=True)
            
            # evaluating after every episode
            eval_r = self.evaluateAgent()
            self.performBookKeeping(train=False)

            self.trainRewardsList.append(train_r)
            self.evalRewardsList.append(eval_r)
            self.totalStepsList.append(steps)

            if (e+1) % 5 == 0:
                print(f"[Episode {e+1}/{self.MAX_TRAIN_EPISODES}] Train Reward: {train_r:.3f} | Eval Reward: {eval_r:.3f} | Steps: {steps}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList, self.wallClockTimeList, self.totalStepsList

# %%
class TD3(TD3):
    def trainNetwork(self, experiences , envActionRange):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.
        #
        #Your code goes in here
        #

        ss, actions, rs, sNexts, dones = self.rBuffer.splitExperiences(experiences)

        ss = ss.to(self.device)
        actions = actions.to(self.device)
        rs = rs.to(self.device)
        sNexts = sNexts.to(self.device)
        dones = dones.to(self.device)

        policy_noise = 0.2 * self.action_scale
        noise_clip = 0.5 * self.action_scale
        as_noise = torch.randn_like(actions) * policy_noise
        as_noise = torch.clamp(as_noise, -noise_clip, noise_clip)

        argmax_a_qs_v = self.targetPolicyNetwork(sNexts)
        noisy_argmax_a_qs_v = argmax_a_qs_v + as_noise
        noisy_argmax_a_qs_v = torch.max(torch.min(noisy_argmax_a_qs_v, self.actionHighVal), self.actionLowVal)

        max_1_a_qs_v = self.targetValueNetwork1(sNexts, noisy_argmax_a_qs_v)
        max_2_a_qs_v = self.targetValueNetwork2(sNexts, noisy_argmax_a_qs_v)
        max_a_qs_v = torch.min(max_1_a_qs_v, max_2_a_qs_v)
        target_qs = rs + self.gamma * (1 - dones) * max_a_qs_v

        qs_1 = self.onlineValueNetwork1(ss, actions)
        qs_2 = self.onlineValueNetwork2(ss, actions)
        tdErrors_1 = target_qs.detach() - qs_1
        tdErrors_2 = target_qs.detach() - qs_2

        valueLoss1 = torch.mean(0.5 * (tdErrors_1 ** 2))
        valueLoss2 = torch.mean(0.5 * (tdErrors_2 ** 2))

        self.valueOptimizer1.zero_grad()
        valueLoss1.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork1.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizer1.step()

        self.valueOptimizer2.zero_grad()
        valueLoss2.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork2.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizer2.step()

        if self.global_steps % self.trainPolicyFrequency == 0:
            argmax_a_qs_p = self.onlinePolicyNetwork(ss)
            max_a_qs_p1 = self.onlineValueNetwork1(ss, argmax_a_qs_p)
            max_a_qs_p2 = self.onlineValueNetwork2(ss, argmax_a_qs_p)
            min_max_a_qs_p = torch.min(max_a_qs_p1, max_a_qs_p2)
            policyLoss = -min_max_a_qs_p.mean()
            self.policyOptimizer.zero_grad()
            policyLoss.backward()
            torch.nn.utils.clip_grad_norm_(self.onlinePolicyNetwork.parameters(), self.MAX_POLICY_GRAD_NORM)
            self.policyOptimizer.step()

# %%
class TD3(TD3):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1
        #
        #Your code goes in here
        #
        final_eval_r = 0.0
        for e in range(self.MAX_EVAL_EPISODE):
            s, _ = self.env.reset()
            done = False
            for c in count():
                envActionRange = (self.actionLowVal, self.actionHighVal)
                a = self.greedyStrategy(self.onlinePolicyNetwork, s, envActionRange)
                s_next, r, done, truncated, _ = self.env.step(a)
                final_eval_r += r
                s = s_next
                if done or truncated:
                    break
        final_eval_r /= self.MAX_EVAL_EPISODE
        return final_eval_r

# %%
# evaluating the TD3 agent on multiple continuous-control

# Environments used in this experiment
td3_env_name = "HalfCheetah-v4"

quantityDictTD3 = {}

# Number of independent training runs per environment
num_runs = 5

all_train_rewards = []
all_eval_rewards = []
all_train_times = []
all_wall_clock_times = []
all_total_steps = []

# For each environment:
print(f"\n===== Environment: {td3_env_name} =====")
for run in range(num_runs):
    print(f"Executing Run {run+1}   ")

    # Create environment
    env = gym.make(td3_env_name)

    agent = TD3(
        base_seed + run, env, gamma, tau, bufferSize, updateFrequencyPolicy,
        updateFrequencyValue, trainPolicyFrequency,
        policyOptimizerFn, valueOptimizerFn,
        policyOptimizerLR, valueOptimizerLR,
        MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
        optimizerFn
    )

    # Run training
    train_rewards, train_times, eval_rewards, wall_clock_times, total_steps, final_eval_reward = agent.runTD3()

    all_train_rewards.append(train_rewards)
    all_eval_rewards.append(eval_rewards)
    all_train_times.append(train_times)
    all_wall_clock_times.append(wall_clock_times)
    all_total_steps.append(total_steps)

    print(f"Finished Run {run+1}  ")


print(f'Mean train rewards: {np.mean(all_train_rewards):.2f} | Train std: {np.std(all_train_rewards):.2f}')
print(f'Mean eval rewards: {np.mean(all_eval_rewards):.2f} | Eval std: {np.std(all_eval_rewards):.2f}')
print(f"Finished {td3_env_name}")

quantityDictTD3[td3_env_name] = {
    "Mean Train Rewards": {
        "TD3": all_train_rewards
    },
    "Mean Eval Rewards": {
        "TD3": all_eval_rewards
    },
    "Train Time (in sec)": {
        "TD3": all_train_times
    },
    "Wall Clock Time (in sec)": {
        "TD3": all_wall_clock_times
    },
    "Total Steps": {
        "TD3": all_total_steps
    }
}

train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"\n(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
# Out:
# ===== Environment: HalfCheetah-v4 =====
# Executing Run 1
# [Episode 5/150] Train Reward: -227.522 | Eval Reward: -372.793 | Steps: 1000
# [Episode 10/150] Train Reward: -383.397 | Eval Reward: -341.703 | Steps: 1000
# [Episode 15/150] Train Reward: -247.558 | Eval Reward: -289.993 | Steps: 1000
# [Episode 20/150] Train Reward: -110.395 | Eval Reward: -152.192 | Steps: 1000
# [Episode 25/150] Train Reward: 460.415 | Eval Reward: 504.046 | Steps: 1000
# [Episode 30/150] Train Reward: 1541.081 | Eval Reward: 2147.932 | Steps: 1000
# [Episode 35/150] Train Reward: 1018.178 | Eval Reward: 2675.089 | Steps: 1000
# [Episode 40/150] Train Reward: 3670.294 | Eval Reward: 3703.122 | Steps: 1000
# [Episode 45/150] Train Reward: 3744.355 | Eval Reward: 3629.985 | Steps: 1000
# [Episode 50/150] Train Reward: 3703.951 | Eval Reward: 3794.685 | Steps: 1000
# [Episode 55/150] Train Reward: 3547.048 | Eval Reward: 4188.649 | Steps: 1000
# [Episode 60/150] Train Reward: 4080.962 | Eval Reward: 4030.075 | Steps: 1000
# [Episode 65/150] Train Reward: 4150.875 | Eval Reward: 4110.555 | Steps: 1000
# [Episode 70/150] Train Reward: 4247.486 | Eval Reward: 4292.432 | Steps: 1000
# [Episode 75/150] Train Reward: 3842.638 | Eval Reward: 4153.529 | Steps: 1000
# [Episode 80/150] Train Reward: 4168.419 | Eval Reward: 4204.352 | Steps: 1000
# [Episode 85/150] Train Reward: 4195.971 | Eval Reward: 4458.696 | Steps: 1000
# [Episode 90/150] Train Reward: 4229.015 | Eval Reward: 4262.362 | Steps: 1000
# [Episode 95/150] Train Reward: 4257.532 | Eval Reward: 4206.603 | Steps: 1000
# [Episode 100/150] Train Reward: 4272.264 | Eval Reward: 4229.213 | Steps: 1000
# [Episode 105/150] Train Reward: 4231.034 | Eval Reward: 4305.419 | Steps: 1000
# [Episode 110/150] Train Reward: 4422.290 | Eval Reward: 4192.910 | Steps: 1000
# [Episode 115/150] Train Reward: 4209.339 | Eval Reward: 4317.108 | Steps: 1000
# [Episode 120/150] Train Reward: 4182.505 | Eval Reward: 4478.361 | Steps: 1000
# [Episode 125/150] Train Reward: 4338.982 | Eval Reward: 4135.879 | Steps: 1000
# [Episode 130/150] Train Reward: 4451.337 | Eval Reward: 4479.868 | Steps: 1000
# [Episode 135/150] Train Reward: 4360.354 | Eval Reward: 4253.137 | Steps: 1000
# [Episode 140/150] Train Reward: 4384.224 | Eval Reward: 4574.758 | Steps: 1000
# [Episode 145/150] Train Reward: 5032.700 | Eval Reward: 5385.778 | Steps: 1000
# [Episode 150/150] Train Reward: 5120.031 | Eval Reward: 5358.606 | Steps: 1000
# Finished Run 1
# Executing Run 2
# [Episode 5/150] Train Reward: -358.640 | Eval Reward: -198.090 | Steps: 1000
# [Episode 10/150] Train Reward: -402.689 | Eval Reward: -195.027 | Steps: 1000
# [Episode 15/150] Train Reward: -370.686 | Eval Reward: -397.092 | Steps: 1000
# [Episode 20/150] Train Reward: 735.141 | Eval Reward: 598.216 | Steps: 1000
# [Episode 25/150] Train Reward: 812.033 | Eval Reward: 754.134 | Steps: 1000
# [Episode 30/150] Train Reward: 1181.724 | Eval Reward: 1262.694 | Steps: 1000
# [Episode 35/150] Train Reward: 1839.026 | Eval Reward: 1931.731 | Steps: 1000
# [Episode 40/150] Train Reward: 2024.751 | Eval Reward: 2466.872 | Steps: 1000
# [Episode 45/150] Train Reward: 1143.484 | Eval Reward: 3114.446 | Steps: 1000
# [Episode 50/150] Train Reward: 1169.402 | Eval Reward: 2501.781 | Steps: 1000
# [Episode 55/150] Train Reward: 2622.035 | Eval Reward: 3432.576 | Steps: 1000
# [Episode 60/150] Train Reward: 3632.333 | Eval Reward: 3547.707 | Steps: 1000
# [Episode 65/150] Train Reward: 3404.024 | Eval Reward: 3899.192 | Steps: 1000
# [Episode 70/150] Train Reward: 3909.374 | Eval Reward: 3834.193 | Steps: 1000
# [Episode 75/150] Train Reward: 3106.433 | Eval Reward: 3953.926 | Steps: 1000
# [Episode 80/150] Train Reward: 2855.782 | Eval Reward: 4303.178 | Steps: 1000
# [Episode 85/150] Train Reward: 3904.537 | Eval Reward: 3961.771 | Steps: 1000
# [Episode 90/150] Train Reward: 4368.559 | Eval Reward: 3611.976 | Steps: 1000
# [Episode 95/150] Train Reward: 4176.555 | Eval Reward: 4438.838 | Steps: 1000
# [Episode 100/150] Train Reward: 4240.311 | Eval Reward: 4255.218 | Steps: 1000
# [Episode 105/150] Train Reward: 4484.725 | Eval Reward: 4780.931 | Steps: 1000
# [Episode 110/150] Train Reward: 4535.232 | Eval Reward: 4801.217 | Steps: 1000
# [Episode 115/150] Train Reward: 4630.551 | Eval Reward: 4590.091 | Steps: 1000
# [Episode 120/150] Train Reward: 4736.746 | Eval Reward: 4926.177 | Steps: 1000
# [Episode 125/150] Train Reward: 4743.417 | Eval Reward: 4514.319 | Steps: 1000
# [Episode 130/150] Train Reward: 4532.218 | Eval Reward: 4967.050 | Steps: 1000
# [Episode 135/150] Train Reward: 5111.332 | Eval Reward: 4898.671 | Steps: 1000
# [Episode 140/150] Train Reward: 4794.292 | Eval Reward: 4914.920 | Steps: 1000
# [Episode 145/150] Train Reward: 5061.993 | Eval Reward: 5207.441 | Steps: 1000
# [Episode 150/150] Train Reward: 5020.262 | Eval Reward: 5394.071 | Steps: 1000
# Finished Run 2
# Executing Run 3
# [Episode 5/150] Train Reward: -202.823 | Eval Reward: -68.480 | Steps: 1000
# [Episode 10/150] Train Reward: -401.966 | Eval Reward: -73.026 | Steps: 1000
# [Episode 15/150] Train Reward: -413.671 | Eval Reward: -407.572 | Steps: 1000
# [Episode 20/150] Train Reward: -178.737 | Eval Reward: -135.094 | Steps: 1000
# [Episode 25/150] Train Reward: 452.411 | Eval Reward: 446.386 | Steps: 1000
# [Episode 30/150] Train Reward: 557.407 | Eval Reward: 701.707 | Steps: 1000
# [Episode 35/150] Train Reward: 614.380 | Eval Reward: 1034.688 | Steps: 1000
# [Episode 40/150] Train Reward: 1244.918 | Eval Reward: 1171.679 | Steps: 1000
# [Episode 45/150] Train Reward: 1565.288 | Eval Reward: 1555.931 | Steps: 1000
# [Episode 50/150] Train Reward: 691.221 | Eval Reward: 1948.045 | Steps: 1000
# [Episode 55/150] Train Reward: 1910.048 | Eval Reward: 1835.559 | Steps: 1000
# [Episode 60/150] Train Reward: 2169.305 | Eval Reward: 2208.806 | Steps: 1000
# [Episode 65/150] Train Reward: 2160.820 | Eval Reward: 1895.994 | Steps: 1000
# [Episode 70/150] Train Reward: 2356.614 | Eval Reward: 2434.353 | Steps: 1000
# [Episode 75/150] Train Reward: -333.493 | Eval Reward: 395.328 | Steps: 1000
# [Episode 80/150] Train Reward: 2490.110 | Eval Reward: 2378.368 | Steps: 1000
# [Episode 85/150] Train Reward: 2547.648 | Eval Reward: 2422.485 | Steps: 1000
# [Episode 90/150] Train Reward: 2549.766 | Eval Reward: 2783.208 | Steps: 1000
# [Episode 95/150] Train Reward: 2713.332 | Eval Reward: 2806.671 | Steps: 1000
# [Episode 100/150] Train Reward: 2867.249 | Eval Reward: 2834.421 | Steps: 1000
# [Episode 105/150] Train Reward: 2977.978 | Eval Reward: 2962.979 | Steps: 1000
# [Episode 110/150] Train Reward: 2917.656 | Eval Reward: 3188.257 | Steps: 1000
# [Episode 115/150] Train Reward: 3028.938 | Eval Reward: 605.719 | Steps: 1000
# [Episode 120/150] Train Reward: 2862.186 | Eval Reward: 3269.034 | Steps: 1000
# [Episode 125/150] Train Reward: 3155.331 | Eval Reward: 3252.784 | Steps: 1000
# [Episode 130/150] Train Reward: 3323.663 | Eval Reward: 3613.703 | Steps: 1000
# [Episode 135/150] Train Reward: 3511.128 | Eval Reward: 3528.452 | Steps: 1000
# [Episode 140/150] Train Reward: 2298.366 | Eval Reward: 3483.447 | Steps: 1000
# [Episode 145/150] Train Reward: 3670.751 | Eval Reward: 3826.681 | Steps: 1000
# [Episode 150/150] Train Reward: 3542.487 | Eval Reward: 3819.481 | Steps: 1000
# Finished Run 3
# Executing Run 4
# [Episode 5/150] Train Reward: -367.730 | Eval Reward: -101.029 | Steps: 1000
# [Episode 10/150] Train Reward: -290.757 | Eval Reward: -129.216 | Steps: 1000
# [Episode 15/150] Train Reward: -325.354 | Eval Reward: -333.268 | Steps: 1000
# [Episode 20/150] Train Reward: -19.383 | Eval Reward: -87.986 | Steps: 1000
# [Episode 25/150] Train Reward: 809.598 | Eval Reward: 941.639 | Steps: 1000
# [Episode 30/150] Train Reward: -50.727 | Eval Reward: 951.130 | Steps: 1000
# [Episode 35/150] Train Reward: 1110.269 | Eval Reward: 1206.336 | Steps: 1000
# [Episode 40/150] Train Reward: 1491.870 | Eval Reward: 1371.603 | Steps: 1000
# [Episode 45/150] Train Reward: 1533.026 | Eval Reward: 1447.895 | Steps: 1000
# [Episode 50/150] Train Reward: 1827.602 | Eval Reward: 1905.365 | Steps: 1000
# [Episode 55/150] Train Reward: 1895.346 | Eval Reward: 1991.431 | Steps: 1000
# [Episode 60/150] Train Reward: 2264.146 | Eval Reward: 2023.890 | Steps: 1000
# [Episode 65/150] Train Reward: 2383.282 | Eval Reward: 2324.932 | Steps: 1000
# [Episode 70/150] Train Reward: 2395.846 | Eval Reward: 2659.214 | Steps: 1000
# [Episode 75/150] Train Reward: 2832.957 | Eval Reward: 3069.916 | Steps: 1000
# [Episode 80/150] Train Reward: 2899.872 | Eval Reward: 3006.676 | Steps: 1000
# [Episode 85/150] Train Reward: 2750.345 | Eval Reward: 3434.728 | Steps: 1000
# [Episode 90/150] Train Reward: 3142.162 | Eval Reward: 3060.916 | Steps: 1000
# [Episode 95/150] Train Reward: 3540.726 | Eval Reward: 3418.965 | Steps: 1000
# [Episode 100/150] Train Reward: 2501.381 | Eval Reward: 3509.782 | Steps: 1000
# [Episode 105/150] Train Reward: 3745.258 | Eval Reward: 3767.993 | Steps: 1000
# [Episode 110/150] Train Reward: 3896.450 | Eval Reward: 3406.555 | Steps: 1000
# [Episode 115/150] Train Reward: 3868.029 | Eval Reward: 3879.609 | Steps: 1000
# [Episode 120/150] Train Reward: 3956.240 | Eval Reward: 3974.827 | Steps: 1000
# [Episode 125/150] Train Reward: 4066.077 | Eval Reward: 4102.088 | Steps: 1000
# [Episode 130/150] Train Reward: 4071.927 | Eval Reward: 4170.253 | Steps: 1000
# [Episode 135/150] Train Reward: 4238.143 | Eval Reward: 3999.483 | Steps: 1000
# [Episode 140/150] Train Reward: 4229.727 | Eval Reward: 4083.385 | Steps: 1000
# [Episode 145/150] Train Reward: 4302.439 | Eval Reward: 4162.902 | Steps: 1000
# [Episode 150/150] Train Reward: 4304.469 | Eval Reward: 4138.607 | Steps: 1000
# Finished Run 4
# Executing Run 5
# [Episode 5/150] Train Reward: -346.956 | Eval Reward: -294.348 | Steps: 1000
# [Episode 10/150] Train Reward: -208.350 | Eval Reward: -317.767 | Steps: 1000
# [Episode 15/150] Train Reward: -361.591 | Eval Reward: -278.896 | Steps: 1000
# [Episode 20/150] Train Reward: 55.187 | Eval Reward: 40.117 | Steps: 1000
# [Episode 25/150] Train Reward: 721.061 | Eval Reward: 417.908 | Steps: 1000
# [Episode 30/150] Train Reward: 1148.122 | Eval Reward: 1218.536 | Steps: 1000
# [Episode 35/150] Train Reward: 239.313 | Eval Reward: 1450.107 | Steps: 1000
# [Episode 40/150] Train Reward: 151.102 | Eval Reward: 670.175 | Steps: 1000
# [Episode 45/150] Train Reward: 1844.501 | Eval Reward: 1406.585 | Steps: 1000
# [Episode 50/150] Train Reward: 2006.807 | Eval Reward: 1938.580 | Steps: 1000
# [Episode 55/150] Train Reward: 996.478 | Eval Reward: 1968.171 | Steps: 1000
# [Episode 60/150] Train Reward: 2143.131 | Eval Reward: 2169.561 | Steps: 1000
# [Episode 65/150] Train Reward: 2682.043 | Eval Reward: 2694.115 | Steps: 1000
# [Episode 70/150] Train Reward: 2455.604 | Eval Reward: 2720.637 | Steps: 1000
# [Episode 75/150] Train Reward: 2744.660 | Eval Reward: 2896.798 | Steps: 1000
# [Episode 80/150] Train Reward: 2838.524 | Eval Reward: 2865.438 | Steps: 1000
# [Episode 85/150] Train Reward: 2721.523 | Eval Reward: 2887.441 | Steps: 1000
# [Episode 90/150] Train Reward: 3253.317 | Eval Reward: 3501.356 | Steps: 1000
# [Episode 95/150] Train Reward: 3354.541 | Eval Reward: 3433.525 | Steps: 1000
# [Episode 100/150] Train Reward: 3340.509 | Eval Reward: 3175.863 | Steps: 1000
# [Episode 105/150] Train Reward: 3530.236 | Eval Reward: 3845.040 | Steps: 1000
# [Episode 110/150] Train Reward: 3415.738 | Eval Reward: 3859.212 | Steps: 1000
# [Episode 115/150] Train Reward: 3935.055 | Eval Reward: 4119.897 | Steps: 1000
# [Episode 120/150] Train Reward: 3895.197 | Eval Reward: 4305.803 | Steps: 1000
# [Episode 125/150] Train Reward: 3832.877 | Eval Reward: 4344.498 | Steps: 1000
# [Episode 130/150] Train Reward: 4069.879 | Eval Reward: 4373.696 | Steps: 1000
# [Episode 135/150] Train Reward: 4414.676 | Eval Reward: 4272.378 | Steps: 1000
# [Episode 140/150] Train Reward: 4524.801 | Eval Reward: 4430.022 | Steps: 1000
# [Episode 145/150] Train Reward: 4972.927 | Eval Reward: 4733.030 | Steps: 1000
# [Episode 150/150] Train Reward: 4938.448 | Eval Reward: 4755.551 | Steps: 1000
# Finished Run 5
# Mean train rewards: 2560.00 | Train std: 1696.12
# Mean eval rewards: 2647.75 | Eval std: 1714.08
# Finished HalfCheetah-v4
#
# (Mean over last 50 epiosdes) Mean train rewards: 4042.33 | Mean Eval Score: 4120.24

# %% [markdown]
# For TD3, sseds used are [21, 22, 23, 24, 25]

# %% [markdown]
# # Soft Actor-Critic (SAC) [ 50 marks ]
#
# SAC is an off-policy maximum entropy deep RL algorithm for continuous action spaces. It maintains two online Q-networks and two target Q-networks to mitigate overestimation bias, and uses a squashed Gaussian policy with automatic entropy tuning.
#
# ### Key Ideas
#
# **1. Stochastic Policy (Squashed Gaussian)**
# The network learns $\mu$ and $\sigma$; samples $u \sim \mathcal{N}(\mu, \sigma)$, applies $a = \tanh(u)$, then rescales to the environment action range.
#
# **2. Log-probability correction for tanh squashing:**
#
# $$\log \pi(a \mid s) = \log p(u \mid s) - \sum_{i=0}^{D} \log(1 - \tanh^2(u_i))$$
#
# **3. Policy Loss (maximize Q, maximize entropy):**
#
# $$J_\pi(\phi) = -\, \mathbb{E}_{s \sim \mathcal{U}(D),\, \hat{a} \sim \pi} \left[ \min_k Q(s, \hat{a};\, \theta^k) - \alpha \log \pi(\hat{a} \mid s;\, \phi) \right]$$
#
# **4. Automatic Entropy Tuning (learn $\alpha$):**
#
# $$J(\alpha) = -\, \mathbb{E}_{s \sim \mathcal{U}(D),\, \hat{a} \sim \pi} \left[ \alpha \left( \mathcal{H} + \log \pi(\hat{a} \mid s;\, \phi) \right) \right]$$
#
# where $\mathcal{H} = -|\mathcal{A}| = -\prod \text{shape}(a_\text{env})$
#
# **5. Soft Bellman Backup (critic target):**
#
# $$\text{target\_q} = r + \gamma \cdot \left( \min_k Q_{\text{target},k}(s', a') - \alpha \log \pi(a' \mid s') \right) \cdot (1 - \text{done})$$
#
# **6. Soft (Polyak) Target Update:**
#
# $$\theta_{\text{target}} \leftarrow (1 - \tau)\, \theta_{\text{target}} + \tau\, \theta_{\text{online}}$$
#
#
#
# ### Task
#
# Implement the SAC agent using the class structure below.

# %%
class ValueNetwork(nn.Module):

    def __init__(self, stateDim, actionDim, hiddenDims):
        """
        Args:
            stateDim (int): dimension of state space
            actionDim (int): dimension of action space
            hiddenDims (list): hidden layer sizes

        Output:
            Initializes Q-network Q(s,a)
        """
        super(ValueNetwork, self).__init__()
        prevdim = stateDim + actionDim
        self.layers = nn.ModuleList()
        for dim in hiddenDims:
            self.layers.append(nn.Linear(prevdim, dim))
            prevdim = dim
        self.layers.append(nn.Linear(prevdim, 1))
        self.activation = nn.ReLU()

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                nn.init.constant_(m.bias, 0)

    def forward(self, state, action):
        """
        Args:
            state (tensor): shape (batch_size, stateDim)
            action (tensor): shape (batch_size, actionDim)

        Returns:
            q_value (tensor): predicted Q(s,a), shape (batch_size,1)
        """
        x = torch.cat([state, action], dim=-1)
        for layer in self.layers[:-1]:
            x = self.activation(layer(x))
        x = self.layers[-1](x)
        return x

# %%
class PolicyNetwork(nn.Module):

    def __init__(self, stateDim, actionRange, hiddenDims):
        """
        Args:
            stateDim (int): state dimension
            actionRange (tuple): (action_low, action_high)
            hiddenDims (list): hidden layer sizes

        Output:
            Initializes stochastic policy network
        """
        super(PolicyNetwork, self).__init__()

        self.logSTD_min = logSTD_min
        self.logSTD_max = logSTD_max
        self.epsilon = epsilon

        self.actionRange = actionRange
        self.actDim = len(self.actionRange[0])
        self.register_buffer('actionLowVal', torch.as_tensor(actionRange[0], dtype=torch.float32))
        self.register_buffer('actionHighVal', torch.as_tensor(actionRange[1], dtype=torch.float32))

        hLayers = []
        prevDim = stateDim
        for nextDim in hiddenDims:
            hLayers.append(nn.Linear(prevDim, nextDim))
            hLayers.append(nn.ReLU())
            prevDim = nextDim
        self.features = nn.Sequential(*hLayers)
        self.mean = nn.Linear(prevDim, self.actDim)
        self.logStd = nn.Linear(prevDim, self.actDim)

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                nn.init.constant_(m.bias, 0)

    def forward(self, state):
        """
        Args:
            state (tensor): input states

        Returns:
            action_env (tensor): sampled action in env range
            action_greedy (tensor): deterministic action
            log_prob (tensor): log probability of action
        """
        l = self.features(state)
        mean, logSTD = self.mean(l), self.logStd(l)
        logSTD = torch.clamp(logSTD, self.logSTD_min, self.logSTD_max)
        std = torch.exp(logSTD)

        pi_s = torch.distributions.Normal(mean, std)
        u = pi_s.rsample()
        a = torch.tanh(u)
        a_env = self.rescale(a)
        a_greedy = self.rescale(torch.tanh(mean))
        log_prob = pi_s.log_prob(u) - torch.log(1 - a**2 + self.epsilon)
        log_prob = log_prob.sum(dim=1, keepdim=True)
        return a_env, a_greedy, log_prob

    def rescale(self, action):
        """
        Args:
            action (tensor): tanh output in [-1,1]

        Returns:
            scaled_action (tensor): action in environment range
        """
        action_scale = (self.actionHighVal - self.actionLowVal) / (squasherMax - squasherMin)
        action_bias = (self.actionHighVal + self.actionLowVal) / (squasherMax - squasherMin)
        action_r = action * action_scale + action_bias
        return action_r

# %%
class ReplayBuffer:

    def __init__(self, bufferSize):
        """
        Args:
            bufferSize (int): max number of stored transitions
        """
        self.bufferSize = bufferSize
        self.buffer = deque(maxlen=bufferSize)

    def store(self, transition):
        """
        Args:
            transition (tuple): (state, action, reward, next_state, done)
        """
        self.buffer.append(transition)

    def sample(self, batchSize):
        """
        Args:
            batchSize (int)

        Returns:
            batch (list): sampled transitions
        """
        batch = random.sample(self.buffer, batchSize)
        return batch

    def splitExperiences(self, experiences):
        states, actions, rewards, sNexts, dones = zip(*experiences)

        states = torch.FloatTensor(np.array(states))
        actions = torch.FloatTensor(np.array(actions))
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        sNexts = torch.FloatTensor(np.array(sNexts))
        dones = torch.FloatTensor(dones).unsqueeze(1)

        # finally returning all the separated numpy arrays
        return states, actions, rewards, sNexts, dones

    def length(self):
        return len(self.buffer)

# %%
# i have added an extra argument in the function defination for reseting the env with the provided seed for reproducibility

class SAC:

    def __init__(self, env, gamma, tau, bufferSize, batchSize, entropyLR,
                 updateFrequency, policyOptimizerFn, valueOptimizerFn_1,
                 valueOptimizerFn_2, policyOptimizerLR, valueOptimizerLR,
                 alphaOptimizerFn, MAX_TRAIN_EPISODES,
                 MAX_EVAL_EPISODE, hDims, minSamples, seed=base_seed):
        """
        Args:
            env: gym environment
            gamma (float): discount factor
            tau (float): target update rate
            bufferSize (int): replay buffer size
            batchSize (int): training batch size
        """
        self.env = env
        self.env.reset(seed=seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        self.env.action_space.seed(seed)
        self.env.observation_space.seed(seed)
        random.seed(seed)

        self.gamma = gamma
        self.tau = tau
        self.bufferSize = bufferSize
        self.batchSize = batchSize
        self.minSamples = minSamples
        self.updateFrequency = updateFrequency
        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODE = MAX_EVAL_EPISODE
        self.MAX_VALUE_GRAD_NORM = MAX_GRAD_NORM_VALUE
        self.MAX_POLICY_GRAD_NORM = MAX_GRAD_NORM_POLICY
        self.entropyLR = entropyLR
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.max_steps = ep_max_steps

        self.stateDim = self.env.observation_space.shape[0]
        self.actionDim = self.env.action_space.shape[0]

        self.actionLowVal = torch.tensor(self.env.action_space.low, dtype=torch.float32).to(self.device)
        self.actionHighVal = torch.tensor(self.env.action_space.high, dtype=torch.float32).to(self.device)
        self.actionRange = (self.actionLowVal,  self.actionHighVal)

        self.targetValueNetwork1 = ValueNetwork(self.stateDim, self.actionDim, hiddenDims=hDims).to(self.device)
        self.targetValueNetwork2 = ValueNetwork(self.stateDim, self.actionDim, hiddenDims=hDims).to(self.device)
        self.onlineValueNetwork1 = ValueNetwork(self.stateDim, self.actionDim, hiddenDims=hDims).to(self.device)
        self.onlineValueNetwork2 = ValueNetwork(self.stateDim, self.actionDim, hiddenDims=hDims).to(self.device)
        self.policyNetwork = PolicyNetwork(self.stateDim, self.actionRange, hiddenDims=hDims).to(self.device)

        self.logAlpha = torch.tensor(0.0, requires_grad=True, device=self.device)
        self.alphaOptimizer = alphaOptimizerFn([self.logAlpha], lr=entropyLR)

        self.valueOptimizerFn_1 = valueOptimizerFn_1(self.onlineValueNetwork1.parameters(), lr=valueOptimizerLR)
        self.valueOptimizerFn_2 = valueOptimizerFn_2(self.onlineValueNetwork2.parameters(), lr=valueOptimizerLR)
        self.policyOptimizerFn = policyOptimizerFn(self.policyNetwork.parameters(), lr=policyOptimizerLR)

        self.updateTargetNetworks(tau=1.0)
        self.initBookKeeping()
        self.startTime = time.time()
        self.rBuffer = ReplayBuffer(bufferSize)

    def initBookKeeping(self):
      self.trainRewardsList = []
      self.evalRewardsList = []
      self.trainTimeList = []
      self.wallClockTimeList = []
      self.totalStepsList = []

      self.startTime = time.time()

    def performBookKeeping(self, train=True):
        if train:
            self.trainTimeList.append(time.time() - self.startTime)
        else:
            self.wallClockTimeList.append(time.time() - self.startTime)


    def selectAction(self, state):
        """
        Args:
            state (array): current state

        Returns:
            action (array): action sampled from policy
        """
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(self.device)
        a_env, _, _ = self.policyNetwork(state)
        return a_env.detach().cpu().numpy().flatten()


    # define this method for turning on-off the require_grad during training
    def _turn_online_grad(self, turn = False):
        for p in self.onlineValueNetwork1.parameters():
            p.requires_grad = turn
        for p in self.onlineValueNetwork2.parameters():
            p.requires_grad = turn


    def trainNetworks(self, batch):
        """
        Args:
            batch: sampled transitions

        Updates:
            critics, policy, entropy coefficient
        """
        ss, actions, rs, sNexts, dones = self.rBuffer.splitExperiences(batch)

        ss = ss.to(self.device)
        actions = actions.to(self.device)
        rs = rs.to(self.device)
        sNexts = sNexts.to(self.device)
        dones = dones.to(self.device)

        with torch.no_grad():
            as_p, _, logp_p = self.policyNetwork(sNexts)
            q_p_1 = self.targetValueNetwork1(sNexts, as_p)
            q_p_2 = self.targetValueNetwork2(sNexts, as_p)
            q_p = torch.min(q_p_1, q_p_2)
            alpha = self.logAlpha.exp()
            target_q = rs + self.gamma * (1 - dones) * (q_p - alpha * logp_p)

        q_1 = self.onlineValueNetwork1(ss, actions)
        q_2 = self.onlineValueNetwork2(ss, actions)
        q_1_loss = (0.5 * (q_1 - target_q)**2).mean()
        q_2_loss = (0.5 * (q_2 - target_q)**2).mean()

        self.valueOptimizerFn_1.zero_grad()
        q_1_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork1.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizerFn_1.step()

        self.valueOptimizerFn_2.zero_grad()
        q_2_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork2.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizerFn_2.step()

        self._turn_online_grad(False)

        as_current, _, logp = self.policyNetwork(ss)
        q_current_1 = self.onlineValueNetwork1(ss, as_current)
        q_current_2 = self.onlineValueNetwork2(ss, as_current)
        q_current = torch.min(q_current_1, q_current_2)

        alpha = self.logAlpha.exp()
        policyLoss = (alpha * logp - q_current).mean()

        self.policyOptimizerFn.zero_grad()
        policyLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.policyNetwork.parameters(), self.MAX_POLICY_GRAD_NORM)
        self.policyOptimizerFn.step()

        self._turn_online_grad(True)

        targetEntropy = -self.actionDim
        alpha_target = (logp + targetEntropy).detach()
        alphaLoss = -(self.logAlpha * alpha_target).mean()
        self.alphaOptimizer.zero_grad()
        alphaLoss.backward()
        self.alphaOptimizer.step()


    def updateTargetNetworks(self, tau=None):
        """
        Performs Polyak update of target networks
        """
        tau = self.tau if tau is None else tau
        for target_param, online_param in zip(self.targetValueNetwork1.parameters(), self.onlineValueNetwork1.parameters()):
            mixedWeights = (1 - tau) * target_param + tau * online_param
            target_param.data.copy_(mixedWeights)

        for target_param, online_param in zip(self.targetValueNetwork2.parameters(), self.onlineValueNetwork2.parameters()):
            mixedWeights = (1 - tau) * target_param + tau * online_param
            target_param.data.copy_(mixedWeights)


    def trainAgent(self):
        """
        Runs training episodes

        Returns:
            trainRewards (list): reward per episode
        """
        for e in range(self.MAX_TRAIN_EPISODES):
            s, _ = self.env.reset()
            train_r = 0.0
            steps = 0
            done = False

            while steps < self.max_steps and not done:
                if self.rBuffer.length() < self.minSamples:
                    action = self.env.action_space.sample()
                else:
                    action = self.selectAction(s)

                sNext, rs, done, truncated, _ = self.env.step(action)
                done = done or truncated
                train_r += rs

                self.rBuffer.store((s, action, rs, sNext, done))

                if self.rBuffer.length() >= self.minSamples:
                    experiences = self.rBuffer.sample(self.batchSize)
                    self.trainNetworks(experiences)

                    if steps % self.updateFrequency == 0:
                        self.updateTargetNetworks()

                steps += 1
                s = sNext

            self.performBookKeeping(train=True)

            # evaluating after every episode
            eval_r = self.evaluateAgent()
            self.performBookKeeping(train=False)

            self.trainRewardsList.append(train_r)
            self.evalRewardsList.append(eval_r)
            self.totalStepsList.append(steps)

            if (e+1) % 5 == 0:
                print(f"[Episode {e+1}/{self.MAX_TRAIN_EPISODES}] Train Reward: {train_r:.3f} | Eval Reward: {eval_r:.3f} | Steps: {steps}")

        # since in runSAC, mentioned to return train time, eval score so depsite not mentioning them in docstring above
        # i am returning them as well
        return self.trainRewardsList, self.evalRewardsList, self.trainTimeList


    def evaluateAgent(self):
        """
        Returns:
            mean_reward (float): evaluation performance
        """
        final_eval_r = 0.0
        for e in range(self.MAX_EVAL_EPISODE):
            s, _ = self.env.reset()
            done = False
            for c in count():
                a = self.selectAction(s)
                s_next, r, done, truncated, _ = self.env.step(a)
                final_eval_r += r
                s = s_next
                if done or truncated:
                    break
        final_eval_r /= self.MAX_EVAL_EPISODE
        return final_eval_r


    def runSAC(self):
        """
        Runs full training pipeline

        Returns:
            train_rewards, eval_score, training_time
        """
        train_r, eval_r, train_t = self.trainAgent()
        return train_r, eval_r, train_t

# %%
# We evaluate the SAC agent on multiple continuous-control

# Environments used in this experiment
sac_env_names = "HalfCheetah-v4"

# Number of independent training runs per environment
num_runs = 5

quantityDictSAC = {}

all_train_rewards = []
all_eval_rewards = []
all_train_times = []

# For each environment:
'''  1. Train the SAC agent for multiple runs
  2. Collect training rewards
  3. Compute mean and standard deviation'''

print(f"\n===== Environment: {sac_env_names} =====")
for run in range(num_runs):
    print(f"Execeuting Run {run+1}   ")

    # Create environment
    env = gym.make(sac_env_names)

    # Initialize SAC agent
    agent = SAC(
        env=env,
        gamma=gamma,
        tau=tau,
        bufferSize=bufferSize,
        entropyLR=entropyLR,
        updateFrequency=updateFrequency,
        policyOptimizerFn=torch.optim.Adam,
        valueOptimizerFn_1=torch.optim.Adam,
        valueOptimizerFn_2=torch.optim.Adam,
        policyOptimizerLR=policyOptimizerLR,
        valueOptimizerLR=valueOptimizerLR,
        alphaOptimizerFn=torch.optim.Adam,
        MAX_TRAIN_EPISODES=MAX_TRAIN_EPISODES,
        MAX_EVAL_EPISODE=MAX_EVAL_EPISODES,
        hDims=[324, 256, 256],
        batchSize=batchSize,
        minSamples=minSamples,
        seed=base_seed+run
    )

    # Run training
    train_r, eval_r, train_t = agent.runSAC()

    all_train_rewards.append(train_r)
    all_eval_rewards.append(eval_r)
    all_train_times.append(train_t)

    print(f"Finished run {run+1}   ")

quantityDictSAC[sac_env_names] = {
    "Mean Train Rewards": {"SAC" : all_train_rewards},
    "Train Times (in sec)": {"SAC" : all_train_times},
    "Mean Eval Rewards": {"SAC": all_eval_rewards}
}

train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"\n(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
print(f"Finished {sac_env_names}")
# Out:
# ===== Environment: HalfCheetah-v4 =====
# Execeuting Run 1
# [Episode 5/150] Train Reward: -227.522 | Eval Reward: -533.688 | Steps: 1000
# [Episode 10/150] Train Reward: -383.397 | Eval Reward: -533.331 | Steps: 1000
# [Episode 15/150] Train Reward: -240.873 | Eval Reward: -247.765 | Steps: 1000
# [Episode 20/150] Train Reward: -271.217 | Eval Reward: -254.856 | Steps: 1000
# [Episode 25/150] Train Reward: -110.169 | Eval Reward: 14.533 | Steps: 1000
# [Episode 30/150] Train Reward: 135.781 | Eval Reward: 222.127 | Steps: 1000
# [Episode 35/150] Train Reward: 548.628 | Eval Reward: 337.058 | Steps: 1000
# [Episode 40/150] Train Reward: -129.477 | Eval Reward: 940.242 | Steps: 1000
# [Episode 45/150] Train Reward: 1387.580 | Eval Reward: 1311.369 | Steps: 1000
# [Episode 50/150] Train Reward: 1697.025 | Eval Reward: 1604.112 | Steps: 1000
# [Episode 55/150] Train Reward: 1481.499 | Eval Reward: 2329.120 | Steps: 1000
# [Episode 60/150] Train Reward: 2730.020 | Eval Reward: 2898.303 | Steps: 1000
# [Episode 65/150] Train Reward: 3430.666 | Eval Reward: 3377.947 | Steps: 1000
# [Episode 70/150] Train Reward: 3367.157 | Eval Reward: 3384.355 | Steps: 1000
# [Episode 75/150] Train Reward: 3543.521 | Eval Reward: 3488.731 | Steps: 1000
# [Episode 80/150] Train Reward: 3863.553 | Eval Reward: 4393.464 | Steps: 1000
# [Episode 85/150] Train Reward: 3988.115 | Eval Reward: 3855.715 | Steps: 1000
# [Episode 90/150] Train Reward: 4399.181 | Eval Reward: 3713.277 | Steps: 1000
# [Episode 95/150] Train Reward: 4521.583 | Eval Reward: 4271.869 | Steps: 1000
# [Episode 100/150] Train Reward: 4774.951 | Eval Reward: 5117.167 | Steps: 1000
# [Episode 105/150] Train Reward: 4793.108 | Eval Reward: 1180.038 | Steps: 1000
# [Episode 110/150] Train Reward: 4978.759 | Eval Reward: 5430.758 | Steps: 1000
# [Episode 115/150] Train Reward: 189.004 | Eval Reward: 5399.830 | Steps: 1000
# [Episode 120/150] Train Reward: 5379.579 | Eval Reward: 5063.840 | Steps: 1000
# [Episode 125/150] Train Reward: 5085.799 | Eval Reward: 4567.721 | Steps: 1000
# [Episode 130/150] Train Reward: 5744.091 | Eval Reward: 4393.686 | Steps: 1000
# [Episode 135/150] Train Reward: 5642.383 | Eval Reward: 5724.179 | Steps: 1000
# [Episode 140/150] Train Reward: 5879.163 | Eval Reward: 5922.887 | Steps: 1000
# [Episode 145/150] Train Reward: 1912.549 | Eval Reward: 6093.916 | Steps: 1000
# [Episode 150/150] Train Reward: 6073.281 | Eval Reward: 6028.940 | Steps: 1000
# Finished run 1
# Execeuting Run 2
# [Episode 5/150] Train Reward: -358.640 | Eval Reward: -334.279 | Steps: 1000
# [Episode 10/150] Train Reward: -402.689 | Eval Reward: -284.608 | Steps: 1000
# [Episode 15/150] Train Reward: -258.905 | Eval Reward: -239.058 | Steps: 1000
# [Episode 20/150] Train Reward: -305.214 | Eval Reward: -110.779 | Steps: 1000
# [Episode 25/150] Train Reward: 245.120 | Eval Reward: 326.902 | Steps: 1000
# [Episode 30/150] Train Reward: 1006.205 | Eval Reward: 657.989 | Steps: 1000
# [Episode 35/150] Train Reward: 1352.226 | Eval Reward: 1734.471 | Steps: 1000
# [Episode 40/150] Train Reward: 2140.939 | Eval Reward: 2460.875 | Steps: 1000
# [Episode 45/150] Train Reward: 2289.121 | Eval Reward: 408.343 | Steps: 1000
# [Episode 50/150] Train Reward: 2755.850 | Eval Reward: 2537.000 | Steps: 1000
# [Episode 55/150] Train Reward: 3026.990 | Eval Reward: 3155.642 | Steps: 1000
# [Episode 60/150] Train Reward: 391.476 | Eval Reward: 3318.351 | Steps: 1000
# [Episode 65/150] Train Reward: 3335.122 | Eval Reward: 3250.473 | Steps: 1000
# [Episode 70/150] Train Reward: 3697.566 | Eval Reward: 3322.066 | Steps: 1000
# [Episode 75/150] Train Reward: 3669.084 | Eval Reward: 3477.083 | Steps: 1000
# [Episode 80/150] Train Reward: 3384.649 | Eval Reward: 3977.089 | Steps: 1000
# [Episode 85/150] Train Reward: 3987.091 | Eval Reward: 4247.910 | Steps: 1000
# [Episode 90/150] Train Reward: 4196.975 | Eval Reward: 1617.289 | Steps: 1000
# [Episode 95/150] Train Reward: 4413.457 | Eval Reward: 3565.164 | Steps: 1000
# [Episode 100/150] Train Reward: 3898.310 | Eval Reward: 4615.388 | Steps: 1000
# [Episode 105/150] Train Reward: 4335.454 | Eval Reward: 4659.309 | Steps: 1000
# [Episode 110/150] Train Reward: 4680.030 | Eval Reward: 4833.339 | Steps: 1000
# [Episode 115/150] Train Reward: 4706.341 | Eval Reward: 4813.220 | Steps: 1000
# [Episode 120/150] Train Reward: 5030.638 | Eval Reward: 4982.696 | Steps: 1000
# [Episode 125/150] Train Reward: 5048.438 | Eval Reward: 4617.945 | Steps: 1000
# [Episode 130/150] Train Reward: 5234.105 | Eval Reward: 2376.516 | Steps: 1000
# [Episode 135/150] Train Reward: 5391.793 | Eval Reward: 5416.877 | Steps: 1000
# [Episode 140/150] Train Reward: 5673.316 | Eval Reward: 5782.981 | Steps: 1000
# [Episode 145/150] Train Reward: 5835.945 | Eval Reward: 5925.166 | Steps: 1000
# [Episode 150/150] Train Reward: 5905.676 | Eval Reward: 1544.818 | Steps: 1000
# Finished run 2
# Execeuting Run 3
# [Episode 5/150] Train Reward: -202.823 | Eval Reward: -320.212 | Steps: 1000
# [Episode 10/150] Train Reward: -401.966 | Eval Reward: -425.350 | Steps: 1000
# [Episode 15/150] Train Reward: -254.139 | Eval Reward: -137.132 | Steps: 1000
# [Episode 20/150] Train Reward: -131.535 | Eval Reward: -232.583 | Steps: 1000
# [Episode 25/150] Train Reward: -229.644 | Eval Reward: -274.682 | Steps: 1000
# [Episode 30/150] Train Reward: -41.370 | Eval Reward: -65.173 | Steps: 1000
# [Episode 35/150] Train Reward: 565.036 | Eval Reward: 441.103 | Steps: 1000
# [Episode 40/150] Train Reward: 1023.805 | Eval Reward: 1071.375 | Steps: 1000
# [Episode 45/150] Train Reward: 1394.596 | Eval Reward: 1466.588 | Steps: 1000
# [Episode 50/150] Train Reward: 1617.534 | Eval Reward: 1655.751 | Steps: 1000
# [Episode 55/150] Train Reward: 174.845 | Eval Reward: 1970.585 | Steps: 1000
# [Episode 60/150] Train Reward: 2060.234 | Eval Reward: 2180.406 | Steps: 1000
# [Episode 65/150] Train Reward: 2189.119 | Eval Reward: 2504.786 | Steps: 1000
# [Episode 70/150] Train Reward: 2324.605 | Eval Reward: 2332.079 | Steps: 1000
# [Episode 75/150] Train Reward: 738.554 | Eval Reward: 2537.777 | Steps: 1000
# [Episode 80/150] Train Reward: 2687.090 | Eval Reward: 2555.184 | Steps: 1000
# [Episode 85/150] Train Reward: 2901.105 | Eval Reward: 2968.357 | Steps: 1000
# [Episode 90/150] Train Reward: 3035.787 | Eval Reward: 2822.757 | Steps: 1000
# [Episode 95/150] Train Reward: 3122.176 | Eval Reward: 3046.982 | Steps: 1000
# [Episode 100/150] Train Reward: 3364.950 | Eval Reward: 3204.975 | Steps: 1000
# [Episode 105/150] Train Reward: 3483.279 | Eval Reward: 3375.994 | Steps: 1000
# [Episode 110/150] Train Reward: 3501.865 | Eval Reward: 3596.825 | Steps: 1000
# [Episode 115/150] Train Reward: 3695.533 | Eval Reward: 3940.539 | Steps: 1000
# [Episode 120/150] Train Reward: 3930.104 | Eval Reward: 3825.365 | Steps: 1000
# [Episode 125/150] Train Reward: 3592.100 | Eval Reward: 3745.948 | Steps: 1000
# [Episode 130/150] Train Reward: 4088.298 | Eval Reward: 1298.229 | Steps: 1000
# [Episode 135/150] Train Reward: 4349.975 | Eval Reward: 3983.996 | Steps: 1000
# [Episode 140/150] Train Reward: 4116.777 | Eval Reward: 4410.341 | Steps: 1000
# [Episode 145/150] Train Reward: 4304.114 | Eval Reward: 4502.384 | Steps: 1000
# [Episode 150/150] Train Reward: 4197.869 | Eval Reward: 4355.229 | Steps: 1000
# Finished run 3
# Execeuting Run 4
# [Episode 5/150] Train Reward: -367.730 | Eval Reward: -126.437 | Steps: 1000
# [Episode 10/150] Train Reward: -290.757 | Eval Reward: -266.262 | Steps: 1000
# [Episode 15/150] Train Reward: -270.003 | Eval Reward: -237.732 | Steps: 1000
# [Episode 20/150] Train Reward: -220.864 | Eval Reward: -202.527 | Steps: 1000
# [Episode 25/150] Train Reward: -141.106 | Eval Reward: -232.588 | Steps: 1000
# [Episode 30/150] Train Reward: 34.830 | Eval Reward: 424.454 | Steps: 1000
# [Episode 35/150] Train Reward: 685.038 | Eval Reward: 789.955 | Steps: 1000
# [Episode 40/150] Train Reward: 742.553 | Eval Reward: 1242.018 | Steps: 1000
# [Episode 45/150] Train Reward: 1803.479 | Eval Reward: 1990.885 | Steps: 1000
# [Episode 50/150] Train Reward: 1251.822 | Eval Reward: 1986.196 | Steps: 1000
# [Episode 55/150] Train Reward: 2593.007 | Eval Reward: 2035.983 | Steps: 1000
# [Episode 60/150] Train Reward: 2206.568 | Eval Reward: 2807.910 | Steps: 1000
# [Episode 65/150] Train Reward: 3082.513 | Eval Reward: 3270.171 | Steps: 1000
# [Episode 70/150] Train Reward: 3235.715 | Eval Reward: 3285.504 | Steps: 1000
# [Episode 75/150] Train Reward: 2391.480 | Eval Reward: 449.388 | Steps: 1000
# [Episode 80/150] Train Reward: 574.239 | Eval Reward: 3311.469 | Steps: 1000
# [Episode 85/150] Train Reward: 3468.926 | Eval Reward: 0.355 | Steps: 1000
# [Episode 90/150] Train Reward: 3898.569 | Eval Reward: 3861.001 | Steps: 1000
# [Episode 95/150] Train Reward: 3790.124 | Eval Reward: 4012.700 | Steps: 1000
# [Episode 100/150] Train Reward: 3975.445 | Eval Reward: 4020.247 | Steps: 1000
# [Episode 105/150] Train Reward: 4201.246 | Eval Reward: 4237.496 | Steps: 1000
# [Episode 110/150] Train Reward: 4116.416 | Eval Reward: 4539.064 | Steps: 1000
# [Episode 115/150] Train Reward: 4672.921 | Eval Reward: 4656.959 | Steps: 1000
# [Episode 120/150] Train Reward: 4589.303 | Eval Reward: 4630.428 | Steps: 1000
# [Episode 125/150] Train Reward: 4579.593 | Eval Reward: 4719.619 | Steps: 1000
# [Episode 130/150] Train Reward: 4574.361 | Eval Reward: 4465.858 | Steps: 1000
# [Episode 135/150] Train Reward: 4760.304 | Eval Reward: 5066.303 | Steps: 1000
# [Episode 140/150] Train Reward: 4869.270 | Eval Reward: 5053.997 | Steps: 1000
# [Episode 145/150] Train Reward: 4960.660 | Eval Reward: 4909.564 | Steps: 1000
# [Episode 150/150] Train Reward: 4959.212 | Eval Reward: 5300.177 | Steps: 1000
# Finished run 4
# Execeuting Run 5
# [Episode 5/150] Train Reward: -346.956 | Eval Reward: -399.090 | Steps: 1000
# [Episode 10/150] Train Reward: -208.350 | Eval Reward: -342.390 | Steps: 1000
# [Episode 15/150] Train Reward: -266.577 | Eval Reward: -201.286 | Steps: 1000
# [Episode 20/150] Train Reward: -461.562 | Eval Reward: -179.047 | Steps: 1000
# [Episode 25/150] Train Reward: 65.739 | Eval Reward: 474.588 | Steps: 1000
# [Episode 30/150] Train Reward: 591.587 | Eval Reward: 334.804 | Steps: 1000
# [Episode 35/150] Train Reward: 800.798 | Eval Reward: 917.063 | Steps: 1000
# [Episode 40/150] Train Reward: 335.436 | Eval Reward: 1202.418 | Steps: 1000
# [Episode 45/150] Train Reward: 1119.779 | Eval Reward: 875.593 | Steps: 1000
# [Episode 50/150] Train Reward: 1872.397 | Eval Reward: 2081.259 | Steps: 1000
# [Episode 55/150] Train Reward: 1970.877 | Eval Reward: 2180.550 | Steps: 1000
# [Episode 60/150] Train Reward: 2128.644 | Eval Reward: 2215.379 | Steps: 1000
# [Episode 65/150] Train Reward: 2338.564 | Eval Reward: 2560.269 | Steps: 1000
# [Episode 70/150] Train Reward: 3115.951 | Eval Reward: 2686.835 | Steps: 1000
# [Episode 75/150] Train Reward: 2807.528 | Eval Reward: 3178.231 | Steps: 1000
# [Episode 80/150] Train Reward: 3267.426 | Eval Reward: 3063.290 | Steps: 1000
# [Episode 85/150] Train Reward: 3435.641 | Eval Reward: 3541.936 | Steps: 1000
# [Episode 90/150] Train Reward: 3836.110 | Eval Reward: 3847.648 | Steps: 1000
# [Episode 95/150] Train Reward: 3876.122 | Eval Reward: 3790.142 | Steps: 1000
# [Episode 100/150] Train Reward: 3941.567 | Eval Reward: 4034.570 | Steps: 1000
# [Episode 105/150] Train Reward: 3973.739 | Eval Reward: 4227.131 | Steps: 1000
# [Episode 110/150] Train Reward: 4076.967 | Eval Reward: 3860.607 | Steps: 1000
# [Episode 115/150] Train Reward: 4166.117 | Eval Reward: 4200.169 | Steps: 1000
# [Episode 120/150] Train Reward: 4192.697 | Eval Reward: 4247.607 | Steps: 1000
# [Episode 125/150] Train Reward: 4419.413 | Eval Reward: 4275.929 | Steps: 1000
# [Episode 130/150] Train Reward: 4371.222 | Eval Reward: 4571.601 | Steps: 1000
# [Episode 135/150] Train Reward: 4541.612 | Eval Reward: 4100.970 | Steps: 1000
# [Episode 140/150] Train Reward: 4492.247 | Eval Reward: 4757.036 | Steps: 1000
# [Episode 145/150] Train Reward: 4470.275 | Eval Reward: 4629.236 | Steps: 1000
# [Episode 150/150] Train Reward: 4664.342 | Eval Reward: 4740.369 | Steps: 1000
# Finished run 5
#
# (Mean over last 50 epiosdes) Mean train rewards: 4529.30 | Mean Eval Score: 4561.08
# Finished HalfCheetah-v4

# %% [markdown]
# ## Plot all the graph across all the 3 environment and write an analysis report.

# %%
plotResults(quantityDictSAC, ["HalfCheetah-v4"], use_moving_avg=False)

# %% [markdown]
# ### SAC Analysis report
#
# 1. Based on **Raw mean Trian Rewards vs Episodes**, it is observed that for the first episodes likely around 20 reward is constant but after then gradually starts increasing and by the end of 150 episodes, reaching around 5000 showing succesful learning.
#
# 2. Also, variance is roughly constant across throughput the epsidoes because of stochasticity in action selction since it learns entropy-coefficient as well in order to masximize entropy.
#
# 3. **Raw mean Eval Rewards vs Episodes** plot is very similar to the **Raw mean Train Rewards vs Episodes** indicating that neual network is learning correctly.
#
# 4. From **Raw train times vs Episodes** (here train times are cummulative as mentioned), it is observed that for earlier episodes training time is less because of warmup episodes since it is collecting sufficient samples in the beggining then training time increases linearly since after getting sufficeint samples in the replay buffer, only batchSize number of samples has to be passed to the neural network each time so training time at each episode is constant but since plots shows cummulative times so increassing linearly.
#
# For SAC, seeds used are [21, 22, 23, 24, 25].

# %% [markdown]
# # PPO [50 marks]
# <a id="PPO"></a>

# %% [markdown]
# PPO have quite a few key implementation details.
# Please Refer:
# "Proximal Policy Optimization Algorithms" [PPO](https://arxiv.org/abs/1707.06347) and
# "Implementation Matters in Deep RL: A Case Study on PPO and TRPO" [Implementation Matters](https://openreview.net/forum?id=r1etN1rtPB)
#
# Lets finish things off with an easy implementation of PPO!
# A easy way to check you implementation details is running your implementation on some easier environment first and make sure it converges.

# %%
#All imports here
## Feel free to add or remove

import os
import random
import time

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
from torch.distributions.normal import Normal

import torch.multiprocessing as mp
from torch.multiprocessing import Barrier, Queue, Process

# %%
# PPO Hyperparameters (multiprocessing version)

ppo_gym_id = "HalfCheetah-v4"
ppo_learning_rate = 3e-4
ppo_seed = 21
ppo_total_timesteps = 1_000_000

ppo_num_workers = 4
ppo_num_steps = 1000

ppo_gamma = 0.99
ppo_gae_lambda = 0.95

ppo_update_epochs = 10
ppo_num_minibatches = 32

ppo_clip_coef = 0.25
ppo_clip_vloss = True

ppo_ent_coef = 0.018
ppo_vf_coef = 0.5
ppo_max_grad_norm = 0.5

ppo_norm_adv = True
ppo_anneal_lr = True
ppo_target_kl = 0.025

ppo_batch_size = ppo_num_workers * ppo_num_steps
ppo_minibatch_size = ppo_batch_size // ppo_num_minibatches

print(f"PPO: batch={ppo_batch_size}, minibatch={ppo_minibatch_size}")
# Out:
# PPO: batch=4000, minibatch=125

# %%
# PPO Agent (takes raw dims, works in any process)
class PPOAgent(nn.Module):
    """
    PPO agent containing separate actor and critic networks.
    Supports both discrete and continuous action spaces.
    """

    def __init__(self, obs_dim, act_dim, is_discrete=False,
                 action_high=None, action_low=None):
        """
        Initialize the PPO agent.

        Args:
            obs_dim (int): Dimension of the observation/state space.
            act_dim (int): Dimension of the action space.
            is_discrete (bool): True if the environment has a discrete
                                action space, otherwise False.
            action_high (array-like, optional): Upper bound of the
                                continuous action space.
            action_low (array-like, optional): Lower bound of the
                                continuous action space.

        Expected Output:
            Initializes actor and critic neural networks along with
            parameters required for action scaling in continuous spaces.
        """

        #Your Code goes here
        super(PPOAgent, self).__init__()
        self.is_discrete = is_discrete

        self.actor = createPolicyNetwork(obs_dim, act_dim, hDim=[512, 324, 256])
        self.critic = createValueNetwork(obs_dim, 1, hDim=[512, 324, 256])

        self.start_time = time.time()

        if not is_discrete:
            self.register_buffer('action_high', torch.FloatTensor(action_high))
            self.register_buffer('action_low', torch.FloatTensor(action_low))
            self.actor_log_std = nn.Parameter(torch.zeros(act_dim))


    def get_value(self, x):
        """
        Compute the value estimate for a given state.

        Args:
            x (Tensor): Input state tensor of shape (batch_size, obs_dim).
        Expected Output:
            Tensor containing the predicted state value V(s)
            from the critic network.
        """
        return self.critic(x)


    def get_action_and_value(self, x, action=None):
        """
        Compute action, log probability, entropy, and state value.

        Args:
            x (Tensor): Input state tensor of shape (batch_size, obs_dim).
            action (Tensor, optional): Specific action for which the
                                       log probability should be computed.
                                       If None, the function samples an action
                                       from the policy distribution.

        Expected Output:
            action (Tensor): Sampled or provided action.
            log_prob (Tensor): Log probability of the selected action.
            entropy (Tensor): Entropy of the action distribution
                              (used for exploration).
            value (Tensor): Predicted state value from the critic.
        """
        value = self.get_value(x)

        if self.is_discrete:
            logits = self.actor(x)
            dist = Categorical(logits=logits)
            if action is None:
                action = dist.sample()
            log_prob = dist.log_prob(action)
            entropy = dist.entropy()

        else:
            mean = self.actor(x)
            log_std = torch.clamp(self.actor_log_std, -20, 2)
            std = torch.exp(log_std).expand_as(mean)
            dist = Normal(mean, std)

            if action is None:
                raw_action = dist.rsample()
                squashed = torch.tanh(raw_action)
                action = self.action_low + (squashed + 1) / 2 * (self.action_high - self.action_low)
            else:
                action = action.to(x.device)
                squashed = 2.0 * (action - self.action_low) / (self.action_high - self.action_low) - 1.0
                squashed = torch.clamp(squashed, -0.9999, 0.9999)
                raw_action = 0.5 * torch.log((1 + squashed) / (1 - squashed))

            log_prob = dist.log_prob(raw_action).sum(dim=-1)
            correction = torch.log((1 - torch.tanh(raw_action).pow(2)) + 1e-6).sum(dim=-1)
            log_prob = log_prob - correction
            entropy = dist.entropy().sum(dim=-1)

        return action, log_prob, entropy, value

# %%
def evaluate_ppo(env_id, agent_state_dict, obs_dim, act_dim, is_discrete,
                 action_high, action_low, max_eval_episodes=1, seed=0):
    env = gym.make(env_id)
    env.reset(seed=seed + 1000)

    local_agent = PPOAgent(obs_dim, act_dim, is_discrete, action_high, action_low)
    local_agent.load_state_dict(agent_state_dict)
    local_agent.eval()

    final_eval_list = []
    for e in range(max_eval_episodes):
        episode_reward = 0.0
        s, _ = env.reset()
        done = False
        truncated = False

        while not (done or truncated):
            s_tensor = torch.tensor(s, dtype=torch.float32).unsqueeze(0)
            with torch.no_grad():
                action, _, _, _ = local_agent.get_action_and_value(s_tensor)

            if is_discrete:
                action_item = action.item()
            else:
                action_item = action.squeeze(0).cpu().numpy()

            s_next, r, done, truncated, _ = env.step(action_item)
            episode_reward += r
            s = s_next

        final_eval_list.append(episode_reward)

    env.close()
    return final_eval_list

# %%
# PPO Worker + Training Loop (Multiprocessing Version)
def ppo_worker(worker_id, global_agent,
               env_id, seed, num_steps, num_updates,
               shared_obs, shared_actions, shared_logprobs,
               shared_rewards, shared_dones, shared_values,
               shared_next_obs, shared_next_done,
               collect_barrier, update_barrier, ep_queue):
    """
    PPO worker process responsible for collecting rollouts.

    Args:
        worker_id        : Unique ID of the worker process.
        global_agent     : Shared PPO policy network.
        env_id           : Gym environment name.
        seed             : Random seed for reproducibility.
        num_steps        : Number of steps collected per rollout.
        num_updates      : Number of PPO updates to perform.

        shared_obs       : Shared buffer storing observations.
        shared_actions   : Shared buffer storing actions.
        shared_logprobs  : Shared buffer storing log probabilities.
        shared_rewards   : Shared buffer storing rewards.
        shared_dones     : Shared buffer storing termination flags.
        shared_values    : Shared buffer storing value predictions.

        shared_next_obs  : Shared buffer storing next observations.
        shared_next_done : Shared buffer storing next done flag.

        collect_barrier  : Synchronization barrier for rollout collection.
        update_barrier   : Synchronization barrier after PPO update.
        ep_queue         : Queue used to send episode rewards to main process.

    Expected Output:
        This function does not return values directly.
        Instead, it stores rollout data in shared buffers and
        sends episode rewards to the main process through ep_queue.
    """
    env = gym.make(env_id)
    env.reset(seed=seed*10 + worker_id)
    env.action_space.seed(seed*10 + worker_id)
    env.observation_space.seed(seed*10 + worker_id)
    np.random.seed(seed=seed*10 + worker_id)
    random.seed(seed*10 + worker_id)
    torch.manual_seed(seed*10 + worker_id)
        
    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]

    state, _ = env.reset()
    done = False
    train_reward = 0.0
    eps_steps = 0
    eps_train_time = 0.0

    local_agent = PPOAgent(
        obs_dim, act_dim, is_discrete,
        env.action_space.high if not is_discrete else None,
        env.action_space.low if not is_discrete else None
    )
    local_agent.eval()
    local_agent.to('cpu')

    for update in range(num_updates):
        local_agent.load_state_dict(global_agent.state_dict())

        local_obs = []
        local_actions = []
        local_logprobs = []
        local_rewards = []
        local_dones = []
        local_values = []

        for step in range(num_steps):
            eps_steps += 1
            state_tensor = torch.FloatTensor(state).unsqueeze(0)

            with torch.no_grad():
                action, log_prob, _, value = local_agent.get_action_and_value(state_tensor)

            if is_discrete:
                action_item = action.item()
            else:
                action_item = action.squeeze(0).cpu().numpy()

            next_state, reward, done, truncated, _ = env.step(action_item)
            done = done or truncated

            local_obs.append(state.copy())
            if is_discrete:
                local_actions.append(action.item())
            else:
                local_actions.append(action_item)

            local_logprobs.append(log_prob.item())
            local_rewards.append(reward)
            local_dones.append(float(done))
            local_values.append(value.item())

            train_reward += reward
            eps_train_time = time.time() - global_agent.start_time

            if done:
                ep_queue.put((worker_id, train_reward, eps_steps, eps_train_time))
                train_reward = 0.0
                eps_steps = 0
                state, _ = env.reset()
                done = False
            else:
                state = next_state
                done = done

        offset = worker_id * num_steps
        for i, (o, a, lp, r, d, v) in enumerate(
            zip(local_obs, local_actions, local_logprobs, local_rewards, local_dones, local_values)
        ):
            idx = offset + i
            shared_obs[idx, :] = torch.from_numpy(o) if isinstance(o, np.ndarray) else o
            shared_actions[idx] = a if isinstance(a, (int, float)) else torch.tensor(a)
            shared_logprobs[idx] = lp
            shared_rewards[idx] = r
            shared_dones[idx] = d
            shared_values[idx] = v

        shared_next_obs[worker_id, :] = torch.from_numpy(state) if isinstance(state, np.ndarray) else state
        shared_next_done[worker_id] = float(done)

        collect_barrier.wait()
        update_barrier.wait()

    env.close()

# %%
def train_ppo(env_id=ppo_gym_id, seed=ppo_seed,
              total_timesteps=ppo_total_timesteps,
              num_workers=ppo_num_workers, num_steps=ppo_num_steps,
              lr=ppo_learning_rate, gamma=ppo_gamma,
              gae_lambda=ppo_gae_lambda, update_epochs=ppo_update_epochs,
              num_minibatches=ppo_num_minibatches,
              clip_coef=ppo_clip_coef, clip_vloss=ppo_clip_vloss,
              ent_coef=ppo_ent_coef, vf_coef=ppo_vf_coef,
              max_grad_norm=ppo_max_grad_norm, norm_adv=ppo_norm_adv,
              anneal_lr=ppo_anneal_lr, target_kl=ppo_target_kl):
    """
    PPO training loop using multiprocessing workers.

    Args:
        env_id           : Gym environment used for training.
        seed             : Random seed.
        total_timesteps  : Total number of environment interactions.
        num_workers      : Number of parallel workers collecting data.
        num_steps        : Number of rollout steps per worker.

        lr               : Learning rate for optimizer.
        gamma            : Discount factor for future rewards.
        gae_lambda       : Lambda parameter for GAE.

        update_epochs    : Number of PPO update passes per batch.
        num_minibatches  : Number of minibatches for SGD.

        clip_coef        : PPO clipping coefficient.
        clip_vloss       : Whether value loss clipping is used.

        ent_coef         : Entropy coefficient for exploration.
        vf_coef          : Value loss coefficient.
        max_grad_norm    : Maximum gradient norm for clipping.

        norm_adv         : Whether to normalize advantages.
        anneal_lr        : Whether learning rate is annealed.
        target_kl        : Optional KL divergence stopping threshold.

    Expected Output:
        results      : List containing tuples (global_step, episode_reward)
                       used to plot the learning curve.
        global_agent : The trained PPO agent.
    """
    dummy_env = gym.make(env_id)
    obs_dim = dummy_env.observation_space.shape[0]
    is_discrete = isinstance(dummy_env.action_space, gym.spaces.Discrete)
    act_dim = dummy_env.action_space.n if is_discrete else dummy_env.action_space.shape[0]
    action_high = dummy_env.action_space.high if not is_discrete else None
    action_low = dummy_env.action_space.low if not is_discrete else None
    dummy_env.close()

    batch_size = num_workers * num_steps
    num_updates = total_timesteps // batch_size
    minibatch_size = batch_size // num_minibatches

    print(f"Starting PPO training: {num_updates} updates, batch size {batch_size}")

    global_agent = PPOAgent(obs_dim, act_dim, is_discrete, action_high, action_low)
    global_agent.share_memory()

    shared_obs = torch.zeros((num_workers * num_steps, obs_dim), dtype=torch.float32).share_memory_()

    if is_discrete:
        shared_actions = torch.zeros((num_workers * num_steps,), dtype=torch.long).share_memory_()
    else:
        shared_actions = torch.zeros((num_workers * num_steps, act_dim), dtype=torch.float32).share_memory_()

    shared_logprobs = torch.zeros((num_workers * num_steps,), dtype=torch.float32).share_memory_()
    shared_rewards = torch.zeros((num_workers * num_steps,), dtype=torch.float32).share_memory_()
    shared_dones = torch.zeros((num_workers * num_steps,), dtype=torch.float32).share_memory_()
    shared_values = torch.zeros((num_workers * num_steps,), dtype=torch.float32).share_memory_()

    shared_next_obs = torch.zeros((num_workers, obs_dim), dtype=torch.float32).share_memory_()
    shared_next_done = torch.zeros((num_workers,), dtype=torch.float32).share_memory_()

    collect_barrier = Barrier(num_workers + 1)
    update_barrier = Barrier(num_workers + 1)

    ep_queue = Queue()
    global_steps = 0
    global_episodes = 0
    start_time = time.time()

    workers = []
    for worker_id in range(num_workers):
        p = Process(target=ppo_worker, args=(
            worker_id, global_agent, env_id, seed, num_steps, num_updates,
            shared_obs, shared_actions, shared_logprobs,
            shared_rewards, shared_dones, shared_values,
            shared_next_obs, shared_next_done,
            collect_barrier, update_barrier, ep_queue
        ))
        p.start()
        workers.append(p)

    optimizer = optim.Adam(global_agent.parameters(), lr=lr, eps=1e-5)

    results = []
    eval_results = []

    for update in range(num_updates):
        if anneal_lr:
            frac = 1.0 - update / num_updates
            lrnow = frac * lr
            optimizer.param_groups[0]["lr"] = lrnow
        collect_barrier.wait()

        while not ep_queue.empty():
            try:
                worker_id, train_reward, eps_steps, train_time = ep_queue.get_nowait()
                global_steps += eps_steps
                global_episodes += 1
                results.append((global_episodes, train_reward, global_steps, train_time, eps_steps))
            except:
                break

        with torch.no_grad():
            next_values = global_agent.get_value(shared_next_obs).squeeze()

            rewards = shared_rewards.view(num_workers, num_steps).t()
            dones = shared_dones.view(num_workers, num_steps).t()
            values = shared_values.view(num_workers, num_steps).t()
            next_values = next_values.view(1, num_workers)
            next_dones = shared_next_done.view(1, num_workers)

            advantages = torch.zeros_like(rewards)
            lastgaelam = 0

            for t in reversed(range(num_steps)):
                if t == num_steps - 1:
                    nextnonterminal = 1.0 - next_dones
                    nextvals = next_values
                else:
                    nextnonterminal = 1.0 - dones[t+1]
                    nextvals = values[t+1]

                delta = rewards[t] + gamma * nextvals * nextnonterminal - values[t]
                advantages[t] = lastgaelam = delta + gamma * gae_lambda * nextnonterminal * lastgaelam

            returns = advantages + values
            advantages = advantages.t().reshape(-1)
            returns = returns.t().reshape(-1)

            if norm_adv:
                advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-6)

        b_obs = shared_obs
        if is_discrete:
            b_actions = shared_actions.long()
        else:
            b_actions = shared_actions
        b_logprobs = shared_logprobs
        b_advantages = advantages
        b_returns = returns
        b_values = shared_values
        b_inds = np.arange(batch_size)
        clipfracs = []

        for epoch in range(update_epochs):
            np.random.shuffle(b_inds)
            for start in range(0, batch_size, minibatch_size):
                end = start + minibatch_size
                mb_inds = b_inds[start:end]

                _, newlogprob, entropy, newvalue = global_agent.get_action_and_value(
                    b_obs[mb_inds],
                    b_actions[mb_inds] if not is_discrete else b_actions[mb_inds]
                )

                logratio = newlogprob - b_logprobs[mb_inds]
                ratio = logratio.exp()

                with torch.no_grad():
                    old_approx_kl = (-logratio).mean()
                    approx_kl = ((ratio - 1) - logratio).mean()
                    clipfracs.append(((ratio - 1.0).abs() > clip_coef).float().mean().item())

                mb_advantages = b_advantages[mb_inds]
                pg_loss1 = -mb_advantages * ratio
                pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - clip_coef, 1 + clip_coef)
                pg_loss = torch.max(pg_loss1, pg_loss2).mean()

                newvalue = newvalue.view(-1)
                if clip_vloss:
                    v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                    v_clipped = b_values[mb_inds] + torch.clamp(
                        newvalue - b_values[mb_inds],
                        -clip_coef,
                        clip_coef,
                    )
                    v_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
                    v_loss_max = torch.max(v_loss_unclipped, v_loss_clipped)
                    v_loss = 0.5 * v_loss_max.mean()
                else:
                    v_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()

                entropy_loss = entropy.mean()
                loss = pg_loss - ent_coef * entropy_loss + vf_coef * v_loss

                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(global_agent.parameters(), max_grad_norm)
                optimizer.step()

            if target_kl is not None:
                if approx_kl > target_kl:
                    break

        update_barrier.wait()

        state_dict = global_agent.state_dict()
        final_eval_rew = evaluate_ppo(env_id, state_dict, obs_dim, act_dim, is_discrete, global_agent.action_high, global_agent.action_low, seed=seed, max_eval_episodes=MAX_EVAL_EPISODES)
        eval_reward = np.mean(final_eval_rew)
        wall_time = time.time() - start_time
        eval_results.append((global_episodes, eval_reward, wall_time))


        if update % 10 == 0:
            print(f"Update {update}/{num_updates}, Episodes collected: {len(results)}")
            if len(results) > 0:
                recent_eval_rewards = [er for _, er, _ in eval_results[-10:]]
                recent_train_rewards = [tr for _, tr, _, _, _ in results[-10:]]
                print(f"[Update {update+1}] Mean train Reward (last 10): {np.mean(recent_train_rewards):.2f} | Mean Eval reward (last 10): {np.mean(recent_eval_rewards):.2f}")

    for p in workers:
        p.join()

    while not ep_queue.empty():
        try:
            worker_id, train_reward, eps_steps, train_time = ep_queue.get_nowait()
            global_steps += eps_steps
            global_episodes += 1
            results.append((global_episodes, train_reward, global_steps, train_time, eps_steps))
        except:
            break
    
    state_dict = global_agent.state_dict()
    final_eval_rew = evaluate_ppo(env_id, state_dict, obs_dim, act_dim, is_discrete, global_agent.action_high, global_agent.action_low, seed=seed, max_eval_episodes=MAX_EVAL_EPISODES)
    eval_reward = np.mean(final_eval_rew)
    wall_time = time.time() - start_time
    eval_results.append((global_episodes, eval_reward, wall_time))

    return results, eval_results, global_agent

# %%
quantityDictPPO = {}
env_names = ["HalfCheetah-v4"]

num_runs = 5
for env_name in env_names:

    print(f"\n===== Environment: {env_name} =====")
    train_r = []
    eval_r = []
    
    all_train_rs = []
    all_eval_rs = []
    all_train_ts = []
    all_wall_ts = []
    all_global_steps = []
    all_e_steps = []

    for run in range(num_runs):
        print(f"Run {run+1}")

        results, eval_results, global_agent = train_ppo(
            env_id=env_name,
            seed=ppo_seed + run,
            total_timesteps=ppo_total_timesteps,
            num_workers=ppo_num_workers,
            num_steps=ppo_num_steps,
            lr=ppo_learning_rate,
            gamma=ppo_gamma,
            gae_lambda=ppo_gae_lambda,
            update_epochs=ppo_update_epochs,
            num_minibatches=ppo_num_minibatches,
            clip_coef=ppo_clip_coef,
            clip_vloss=ppo_clip_vloss,
            ent_coef=ppo_ent_coef,
            vf_coef=ppo_vf_coef,
            max_grad_norm=ppo_max_grad_norm,
            norm_adv=ppo_norm_adv,
            anneal_lr=ppo_anneal_lr,
            target_kl=ppo_target_kl
        )

        _, rewards, global_steps, train_times, e_steps = zip(*results)
        train_r.append(rewards)
        _, eval_results, wall_times = zip(*eval_results)
        eval_r.append(eval_results)

        all_train_rs.append(rewards)
        all_eval_rs.append(eval_results)
        all_train_ts.append(train_times)
        all_wall_ts.append(wall_times)
        all_global_steps.append(global_steps)
        all_e_steps.append(e_steps)

    # Compute Statistics
    if train_r:
        ppo_train_rewards = [np.mean(run[-50:]) for run in train_r]
        ppo_eval_rewards = [np.mean(run[-50:]) for run in eval_r]
        print(f"\nFinished {env_name}")
        print(f"Total episodes collected: {len(train_r[0])}")
        print(f"Mean train rewards: {np.mean(ppo_train_rewards):.2f} | Mean Eval Rewards: {np.mean(ppo_eval_rewards):.2f}")

    quantityDictPPO[env_name] = {
        "Mean Train Rewards": {"PPO": all_train_rs},
        "Mean Eval Rewards": {"PPO": all_eval_rs},
        "Global Steps": {"PPO": all_global_steps},
        "Train Time (in sec)": {"PPO": all_train_ts},
        "WallClock Time (in sec)": {"PPO": all_wall_ts},
        "Total Steps": {"PPO": all_e_steps}
    }
# Out:
# ===== Environment: HalfCheetah-v4 =====
# Run 1
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -525.40 | Mean Eval reward (last 10): -359.98
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): -170.66 | Mean Eval reward (last 10): -241.28
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): -30.22 | Mean Eval reward (last 10): -76.80
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): 137.49 | Mean Eval reward (last 10): 72.88
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): 284.80 | Mean Eval reward (last 10): 293.34
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): 381.00 | Mean Eval reward (last 10): 282.30
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): 452.89 | Mean Eval reward (last 10): 553.12
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): 702.09 | Mean Eval reward (last 10): 693.70
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): 988.78 | Mean Eval reward (last 10): 978.35
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): 1023.09 | Mean Eval reward (last 10): 1092.91
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): 1171.40 | Mean Eval reward (last 10): 1089.36
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 1293.36 | Mean Eval reward (last 10): 1245.17
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 1265.76 | Mean Eval reward (last 10): 1245.78
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 1268.40 | Mean Eval reward (last 10): 1215.30
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 1270.02 | Mean Eval reward (last 10): 1288.12
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 1384.49 | Mean Eval reward (last 10): 1346.67
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 1503.43 | Mean Eval reward (last 10): 1475.02
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 1471.95 | Mean Eval reward (last 10): 1539.56
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 1611.34 | Mean Eval reward (last 10): 1563.05
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 1577.11 | Mean Eval reward (last 10): 1695.24
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 1719.40 | Mean Eval reward (last 10): 1672.94
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 1724.83 | Mean Eval reward (last 10): 1742.59
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 1829.64 | Mean Eval reward (last 10): 1716.35
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 1838.48 | Mean Eval reward (last 10): 1773.87
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 1842.81 | Mean Eval reward (last 10): 1816.64
# Run 2
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -340.57 | Mean Eval reward (last 10): -334.48
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): -234.89 | Mean Eval reward (last 10): -295.68
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): -290.98 | Mean Eval reward (last 10): -264.75
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): -210.18 | Mean Eval reward (last 10): -205.63
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): -133.82 | Mean Eval reward (last 10): -137.73
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): -199.71 | Mean Eval reward (last 10): -50.27
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): -73.56 | Mean Eval reward (last 10): -148.63
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): -11.08 | Mean Eval reward (last 10): -117.70
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): -11.42 | Mean Eval reward (last 10): -5.86
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): -203.90 | Mean Eval reward (last 10): 65.85
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): -35.35 | Mean Eval reward (last 10): -0.94
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 121.54 | Mean Eval reward (last 10): 121.19
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 57.28 | Mean Eval reward (last 10): -51.24
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 28.52 | Mean Eval reward (last 10): 202.25
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 237.01 | Mean Eval reward (last 10): 141.25
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 141.70 | Mean Eval reward (last 10): 210.93
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 320.11 | Mean Eval reward (last 10): 88.32
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 307.14 | Mean Eval reward (last 10): 241.71
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 406.97 | Mean Eval reward (last 10): 282.77
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 554.81 | Mean Eval reward (last 10): 422.89
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 395.23 | Mean Eval reward (last 10): 326.76
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 301.84 | Mean Eval reward (last 10): 414.79
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 313.86 | Mean Eval reward (last 10): 590.53
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 495.71 | Mean Eval reward (last 10): 636.29
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 630.21 | Mean Eval reward (last 10): 315.76
# Run 3
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -404.79 | Mean Eval reward (last 10): -241.19
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): -180.09 | Mean Eval reward (last 10): -216.07
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): -109.55 | Mean Eval reward (last 10): -199.74
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): 105.25 | Mean Eval reward (last 10): 64.39
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): 260.84 | Mean Eval reward (last 10): 327.17
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): 569.01 | Mean Eval reward (last 10): 543.03
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): 737.75 | Mean Eval reward (last 10): 673.48
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): 1110.53 | Mean Eval reward (last 10): 975.26
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): 1145.00 | Mean Eval reward (last 10): 1123.01
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): 1182.86 | Mean Eval reward (last 10): 1136.30
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): 1174.59 | Mean Eval reward (last 10): 1132.08
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 1263.13 | Mean Eval reward (last 10): 1209.98
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 1220.17 | Mean Eval reward (last 10): 1252.40
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 1195.97 | Mean Eval reward (last 10): 1262.33
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 1380.57 | Mean Eval reward (last 10): 1316.63
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 1336.17 | Mean Eval reward (last 10): 1353.57
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 1456.54 | Mean Eval reward (last 10): 1359.77
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 1496.95 | Mean Eval reward (last 10): 1439.70
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 1448.69 | Mean Eval reward (last 10): 1474.98
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 1413.28 | Mean Eval reward (last 10): 1392.94
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 1510.10 | Mean Eval reward (last 10): 1446.69
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 1459.95 | Mean Eval reward (last 10): 1404.23
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 1466.81 | Mean Eval reward (last 10): 1420.93
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 1447.26 | Mean Eval reward (last 10): 1492.18
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 1410.85 | Mean Eval reward (last 10): 1561.11
# Run 4
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -183.66 | Mean Eval reward (last 10): -174.02
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): -138.64 | Mean Eval reward (last 10): -268.70
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): -266.92 | Mean Eval reward (last 10): -281.99
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): -230.26 | Mean Eval reward (last 10): -211.78
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): -234.91 | Mean Eval reward (last 10): -250.22
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): -237.74 | Mean Eval reward (last 10): -246.24
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): -276.98 | Mean Eval reward (last 10): -238.52
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): -207.36 | Mean Eval reward (last 10): -253.64
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): 159.31 | Mean Eval reward (last 10): 33.51
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): 659.48 | Mean Eval reward (last 10): 428.57
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): 858.04 | Mean Eval reward (last 10): 811.09
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 950.38 | Mean Eval reward (last 10): 752.42
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 963.86 | Mean Eval reward (last 10): 919.35
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 1027.39 | Mean Eval reward (last 10): 1108.55
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 1288.88 | Mean Eval reward (last 10): 1269.56
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 1368.29 | Mean Eval reward (last 10): 1356.94
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 1495.56 | Mean Eval reward (last 10): 1380.95
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 1409.72 | Mean Eval reward (last 10): 1414.24
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 1440.20 | Mean Eval reward (last 10): 1371.21
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 1456.66 | Mean Eval reward (last 10): 1380.57
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 1359.42 | Mean Eval reward (last 10): 1513.86
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 1524.18 | Mean Eval reward (last 10): 1499.12
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 1416.14 | Mean Eval reward (last 10): 1490.66
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 1388.97 | Mean Eval reward (last 10): 1475.79
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 1517.74 | Mean Eval reward (last 10): 1515.57
# Run 5
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -227.58 | Mean Eval reward (last 10): -221.81
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): 29.14 | Mean Eval reward (last 10): -83.68
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): 475.01 | Mean Eval reward (last 10): 338.11
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): 187.62 | Mean Eval reward (last 10): 312.47
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): -15.75 | Mean Eval reward (last 10): 228.10
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): 570.68 | Mean Eval reward (last 10): 574.99
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): 961.16 | Mean Eval reward (last 10): 987.61
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): 687.13 | Mean Eval reward (last 10): 769.33
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): 975.12 | Mean Eval reward (last 10): 864.21
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): 1350.06 | Mean Eval reward (last 10): 1553.31
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): 1418.56 | Mean Eval reward (last 10): 1360.97
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 1750.93 | Mean Eval reward (last 10): 1554.03
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 1773.24 | Mean Eval reward (last 10): 2017.73
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 2349.93 | Mean Eval reward (last 10): 2154.07
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 2353.02 | Mean Eval reward (last 10): 2271.32
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 2394.45 | Mean Eval reward (last 10): 2388.61
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 2397.24 | Mean Eval reward (last 10): 2590.85
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 2272.28 | Mean Eval reward (last 10): 2340.92
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 2662.97 | Mean Eval reward (last 10): 2277.84
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 2663.63 | Mean Eval reward (last 10): 2643.06
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 2663.61 | Mean Eval reward (last 10): 2588.39
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 2548.34 | Mean Eval reward (last 10): 2551.68
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 2650.97 | Mean Eval reward (last 10): 2646.40
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 2712.24 | Mean Eval reward (last 10): 2662.96
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 2689.33 | Mean Eval reward (last 10): 2667.62
#
# Finished HalfCheetah-v4
# Total episodes collected: 1000
# Mean train rewards: 1587.77 | Mean Eval Rewards: 1561.88

# %% [markdown]
# For PPO, seeds used are [210, 211, 212, 213; 220, 221, 222, 223; 230, 231, 232, 233; 240, 241, 242, 243; 250, 251, 252, 253]

# %% [markdown]
# # Experiments and Plots [$20 \times 5=100$ marks]
# <a id="experiments"></a>

# %% [markdown]
# Run the VPG, REINFORCE on Pendulum and DDPG, TD3, PPO, on Half Cheetah.
#
# Plot the following for each of the environment separately. Note based on different hyper-parameters and strategies you use, you can have multiple plots for each of the below.
#
# As you are aware from your past experience, single run of the agent over the environment results in plots that have lot of variance and look very noisy. One way to overcome this is to create several different instances of the environment using different seeds and then average out the results across these and plot these. For all the plots below, you this strategy. You need to run 5 different instances of the environment for each agent. As you have seen in the lecture slides, we plot the maximum and minimum values around the mean in the plots, so this gives us the shaded plot with the mean curve in the between. In this assignment, you are required to do the same. Generate plots with envelop between maximum and minimum value
# For each of the quantity of interest, plot each of the agent within the same plot using different colors for the envelop. Choose colors such that that there is clear contrast between the plots corresponding to different agents.
#
# 1. Plot mean train rewards vs episodes
# 2. Plot mean evaluation rewards vs episodes
# 3. Plot total steps vs episode
# 4. Plot train time vs episode
# 5. Plot wall clock time vs episode
# 6. Based on plots what are your observations about DDPG and TD3, compare the two algorithms.
# 7. What is the advatage of PPO over DDPG or TD3?

# %%
env_name = "Pendulum-v1"
config1 = {
    env_name: {
        "Mean Train Rewards": {
            **reinforceQuantityDict[env_name]["Mean Train Rewards"],
            **quantityDictVPG[env_name]["Mean Train Rewards"]
        },
        "Mean Eval Rewards": {
            **reinforceQuantityDict[env_name]["Mean Eval Rewards"],
            **quantityDictVPG[env_name]["Mean Eval Rewards"]
        },
        "Train Time (in sec)": {
            **reinforceQuantityDict[env_name]["Train Time (in sec)"],
            **quantityDictVPG[env_name]["Train Time (in sec)"]
        },
        "Wall Clock Time (in sec)": {
            **reinforceQuantityDict[env_name]["Wall Clock Time (in sec)"],
            **quantityDictVPG[env_name]["Wall Clock Time (in sec)"]
        },
        "Total Steps": {
            **reinforceQuantityDict[env_name]["Total Steps"],
            **quantityDictVPG[env_name]["Total Steps"]
        }
    }
}

plotResults(config1, [env_name], use_moving_avg=False)

# %% [markdown]
# **Comparison of REINFORCE and VPG:**
#
# 1.
#
# 2.
#
# 3.

# %%
env_name = "HalfCheetah-v4"
config2 = {
    env_name: {
        "Mean Train Rewards": {
            **quantityDictDDPG[env_name]["Mean Train Rewards"],
            **quantityDictTD3[env_name]["Mean Train Rewards"],
            **quantityDictPPO[env_name]["Mean Train Rewards"]
        },
        "Mean Eval Rewards": {
            **quantityDictDDPG[env_name]["Mean Eval Rewards"],
            **quantityDictTD3[env_name]["Mean Eval Rewards"],
            **quantityDictPPO[env_name]["Mean Eval Rewards"]
        },
        "Train Time (in sec)": {
            **quantityDictDDPG[env_name]["Train Time (in sec)"],
            **quantityDictTD3[env_name]["Train Time (in sec)"],
            **quantityDictPPO[env_name]["Train Time (in sec)"]
        },
        "Wall Clock Time (in sec)": {
            **quantityDictDDPG[env_name]["Wall Clock Time (in sec)"],
            **quantityDictTD3[env_name]["Wall Clock Time (in sec)"],
            **quantityDictPPO[env_name]["WallClock Time (in sec)"]
        },
        "Total Steps": {
            **quantityDictDDPG[env_name]["Total Steps"],
            **quantityDictTD3[env_name]["Total Steps"],
            **quantityDictPPO[env_name]["Total Steps"]
        }
    }
}

plotResults(config2, [env_name], use_moving_avg=False)

# %% [markdown]
# ### Ques 6: Based on plots what are your observations about DDPG and TD3, compare the two algorithms.
#
# 1. TD3 is giving the better rewards compared to DDPG, since it resolves the issue ofover-estimation bias problem caused by DDPG where actor iplicitly maximizes the noisy Q fcuntion which TD3 solves by using 2 critics and during evaluation, takes the minimum values of thes etwo networks in order to avoid over-estimated values.
#
# 2. TD3 uses 2 critics so it requires more computation compared to DDPG, because of which TD3 is observed to be having higher training time than DDPG.
#
# 3. TD3 has less variance compared to DDPG which can be observed from the above "Mean Train Rewards over Episode" Plots because of using 2 critics, which helps it in avoiding over-estimation bias, therby reduces the variance.
#
#
# ### Ques 7. What is the advatage of PPO over DDPG or TD3?
#
# 1. One of the major advantage of PPO is that PPO changes policy gradaully by restrictinh change in policy during each traning step. Since policy based methods are quite sensotve to change in parameter space. So in order to make it robust, PPO takes gradual steps.
#
# 2. Although PPO might took large number of episodes for convergnce but it is quite stable and robust to outliers compared to DDPG and TD3.
#
# 3. It is faster compared to DDPG and TD3 beacuse of multi processing.
#
# 4. Also it is more sample efficient compared to others since multiple workers explore independent trajecories (similar to A2C) and also it reuses these smaples multiple times for gradient estimation and then updates the global network parameters based on average of all the gradients.
#
# 5. PPO deals with data correlation problem using multiple workers in sync for stable, consistent and gradual updates while TD3 and DDPG handles this issue using replay buffer by sampling expereinces from it for passing them to the policy network.
