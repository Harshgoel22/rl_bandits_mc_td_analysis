# %% [markdown]
# # ASSIGNMENT 5 (Policy Gradient and Actor Critic Methods)
# # Submission Deadline: 30-03-2026, 11:59 PM
# # Submission Link: [https://forms.gle/UYb1Lu6jiSiCiWVs8](https://forms.gle/UYb1Lu6jiSiCiWVs8)

# %% [markdown]
# # Table of Contents
#
# 1. [Provide Information](#Provide-Information)
# 2. [Instructions](#Instructions)
# 3. [Environment](#Environment)
# 4. [Hyperparameters](#Hyperparameters)
# 5. [Helper Functions](#helper)
# 6. [DDPG](#ddpg)
# 7. [TD3](#td3)
# 8. [SAC](#SAC)
# 9. [PPO](#ppo)
# 10. [Experiments to Run](#experiments)

# %% [markdown]
# # Provide Information
# <a id="Provide-Information"></a>

# %% [markdown]
# Name: **HARSH GOEL**
#
# Roll No.: **251110034**
#
# IITK EMail: **harshgoel25@iitk.ac.in**

# %% [markdown]
# # Instructions
# <a id="Instructions"></a>

# %% [markdown]
# **Read all the instructions below carefully before you start working on the assignment.**
# - The purpose of this course is that you learn RL and the best way to do that is by implementation and experimentation.
# - The assignment requires your to implement some algorithms and you are required report your findings after experimenting with those algorithms.
# - **You are required to submit a Jupyter notebook (.ipynb). The notebook would include the code, graphs/plots of the experiments you run and your findings/observations.**
# - In case you use any maths in your explanations, render it using latex in the Jupyter notebook.
# - You are expected to implement algorithms on your own and not copy it from other sources/class mates. Of course, you can refer to lecture slides.
# - If you use any reference or material (including code), please cite the source, else it will be considered plagiarism. But referring to other sources that directly solve the problems given in the assignment is not allowed. There is a limit to which you can refer to outside material.
# - This is an individual assignment.
# - In case your solution is found to have an overlap with solution by someone else (including external sources), all the parties involved will get zero in this and all future assignments plus further more penalties in the overall grade. We will check not just for lexical but also semantic overlap. Same applies for the code as well. Even an iota of cheating would NOT be tolerated. If you cheat one line or cheat one page the penalty would be same.
# - Be a smart agent, think long term, if you cheat we will discover it somehow, the price you would be paying is not worth it.
# - In case you are struggling with the assignment, seek help from TAs. Cheating is not an option! I respect honesty and would be lenient if you are not able to solve some questions due to difficulty in understanding. Remember we are there to help you out, seek help if something is difficult to understand.
# - The deadline for the submission is given above. Submit at least 30 minutes before the deadline, lot can happen at the last moment, your internet can fail, there can be a power failure, you can be abducted by aliens, etc.
# - You have to submit your assignment via the Google Form (link above)
# - The form would close after the deadline and we will not accept any solution. No reason what-so-ever would be accepted for not being able to submit before the deadline.
# - Since the assignment involves experimentation, reporting your results and observations, there is a lot of scope for creativity and innovation and presenting new perspectives. Such efforts would be highly appreciated and accordingly well rewarded. Be an exploratory agent!
# - Your code should be very well documented, there are marks for that.
# - In your plots, have a clear legend and clear lines, etc. Of course you would generating the plots in your code but you must also put these plots in your notebook. Generate high resolution pdf/svg version of the plots so that it doesn't pixilate on zooming.
# - For all experiments, report about the seed used in the code documentation, write about the seed used.
# - In your notebook write about all things that are not obvious from the code e.g., if you have made any assumptions, references/sources, running time, etc.
# -  **DO NOT Forget to write name, roll no and email details above**
# - **In addition to checking your code, we will be conducting one-on-one viva for the evaluation. So please make sure that you do not cheat!**
# - For each of the sub-part in the question create a new cell below the question and put your answer in there. This includes the plots as well

# %% [markdown]
# # LLM Usage Policy
#
# It is **OK** to use LLM or other sources (websites, blogs, books, etc) for:
# * Coding ancillary parts of the algorithm such as plotting graphs, etc.
# * To develop understanding of the algorithm in the case it is not clear to you
#
# It is **NOT OK** to use LLM or other sources (websites, blogs, books, etc) for:
# * Writing the code for the main parts of the algorithm especially given that I have already provided pseudo-code in the lectures. (You can use pseudo code as it is from the lecture slides)
# * For doing hyper-parameter tuning of the algorithm.
# * For doing analysis of the results and drawing conclusions about it
#
# Since RL is specialized domain, it is very straight forward to detect when someone (especially a newbie) is taking code from LLM or other sources. In case you are found to do so (even for a small part of assignment), there will be no questions asked direct zero will be awarded to you along with further penalties which will affect your final grade.
#
# Be a smart agent (remember Honesty is the best Policy), it is ok to loose a few marks than getting a zero + penalties. It is OK if you don't do all questions in the assignment which will cost you a few marks vs getting 0.
#
# **Remember that grading is relative and you are not the only one who is finding it tough!**

# %% [markdown]
# # LLM Usage Declaration
#
# It is permitted to use Large Language Models (LLMs) **only for understanding concepts, ideation, and creating initial code stubs**.
# Using an LLM to **completely solve the assignment is not allowed**.
#
# Even if an LLM is used for the permitted purposes, you **must be able to clearly explain the solution without any LLM assistance during the viva**, if called.
#
# ---
#
# ### Q1. **Which Large Language Model (LLM) did you use to complete this assignment?**
#
# > _Your answer here_
#
# ---
#
# ### Q2. **In which questions did you use the LLM, and how did it help you?**
# (You may extend this table by adding more rows if needed.)
#
# | Question Number / Sub-part | Used LLM? (Yes/No) | Purpose of Using LLM (e.g., ideation, explanation, code stub, grammar) | Brief Description of LLM Contribution |
# |----------------------------|--------------------|------------------------------------------------------------------------|-------------------------------------|
# | Q1                         |                    |                                                                        |                                     |
# | Q2                         |                    |                                                                        |                                     |
# | Q3                         |                    |                                                                        |                                     |
# | Q4                         |                    |                                                                        |                                     |
#
# ---
#
# ### Q3. **Did you refer to any other sources or websites apart from the LLM and lecture slides?**
#
# If yes, please mention the source(s) clearly:
# > _Example: Research papers, blogs, documentation, textbooks, etc._
#
# ---
#
# ### Q4. **Apart from using any LLM, what was your own contribution while solving this assignment?**
#
# Briefly describe:
# - Your understanding of the concepts
# - The reasoning you applied
# - Any implementation or analysis done independently
#
# > _Your answer here_
#
# ---

# %%
SAVE_PATH_REIN = "./plot_configs/rl_results_rein.pkl"
SAVE_PATH_VPG  = "./plot_configs/rl_results_vpg.pkl"
SAVE_PATH_A3C  = "./plot_configs/rl_results_a3c.pkl"
SAVE_PATH_A2C  = "./plot_configs/rl_results_a2c.pkl"
SAVE_PATH_DDPG = "./plot_configs/rl_results_ddpg.pkl"
SAVE_PATH_TD3  = "./plot_configs/rl_results_td3.pkl"
SAVE_PATH_SAC  = "./plot_configs/rl_results_sac.pkl"
SAVE_PATH_SWEEP  = "./plot_configs/rl_results_sweep.pkl"
SAVE_PATH_COMP  = "./plot_configs/rl_results_comp.pkl"

# %% [markdown]
# # OpenAI Gym Environments [10 marks]
# <a id="Environment"></a>

# %%
# all imports go in here
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import time
import random
from itertools import count, cycle
from collections import deque, namedtuple

from matplotlib import animation
from IPython.display import HTML

from scipy import stats
import os
import matplotlib.pyplot as plt
import torch.multiprocessing as mp
from collections import defaultdict

# %%
import pickle

# %% [markdown]
# In this assignment we will be exploring Deep RL algorithms and for this we will be using environmentd provided by OpenAI Gym. In particular we will be exploring "Pendulum-v1" , "Hopper-v4", and "Half-Cheetah" environments (https://gymnasium.farama.org/environments/classic_control/ ). The code to instantiate the environments are given in the cells below. Run these cells and play with the environments to learn more details about the environments.
#
# **We are restricting 1 env per algorithm, so total 9 environments.**
#
# **It will be like this:**
# **REINFORCE, VPG: Pendulum**
#
# **A2C, A3C, GAE: Hopper**
#
# **DDPG, TD3, SAC, PPO: Half Cheetah**

# %%
# Create Inverted Pendulum environment

env = gym.make('Pendulum-v1', render_mode="rgb_array")
s = env.reset(seed = 34)
print("Observation Space = ")
print(env.observation_space)
print("Action Space = ")
print(env.action_space)
done = False
for episode in range(20):
    print("In episode {}".format(episode))
    for i in range(100):
        env.render()
        print(s)
        a = env.action_space.sample()
        s, r, done, truncated, _ = env.step(a)
        if done:
            print("Finished after {} timestep".format(i+1))
env.close()
# Out:
# Observation Space =
# Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# Action Space =
# Box(-2.0, 2.0, (1,), float32)
# In episode 0
# c:\Users\hgoel\anaconda3\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# (array([-0.9996797 , -0.0253075 ,  0.74435383], dtype=float32), {})
# [-0.99729186 -0.07354561  0.9660375 ]
# [-0.9938559  -0.1106818   0.74593925]
# [-0.9884466  -0.15156962  0.82494   ]
# [-0.9806196  -0.19592136  0.9008178 ]
# [-0.9715016  -0.23703308  0.8422766 ]
# [-0.96658355 -0.2563518   0.39870438]
# [-0.960183   -0.2793717   0.47787425]
# [-9.6017396e-01 -2.7940294e-01  6.5053708e-04]
# [-0.9660009  -0.25853866 -0.43326166]
# [-0.9728327  -0.23150924 -0.5576069 ]
# [-0.98034    -0.19731554 -0.70019835]
# [-0.9872269  -0.1593207  -0.77232695]
# [-0.9943769 -0.1058989 -1.0780936]
# [-0.9993525  -0.03598046 -1.4021924 ]
# [-0.9993605   0.03575716 -1.4350601 ]
# [-0.9958214   0.09132183 -1.113689  ]
# [-0.9880408   0.15419275 -1.2672226 ]
# [-0.97915417  0.20311844 -0.99462694]
# [-0.9661026   0.25815848 -1.131477  ]
# [-0.95314425  0.30251622 -0.9243179 ]
# [-0.9389378   0.34408703 -0.8786963 ]
# [-0.92619807  0.3770373  -0.70658255]
# [-0.9171849   0.39846194 -0.46487802]
# [-0.9137356   0.40630925 -0.17143817]
# [-0.9108331  0.4127748 -0.1417437]
# [-0.9151127   0.4031982   0.20978731]
# [-0.92859817  0.37108678  0.69659895]
# [-0.9484951   0.31679183  1.1566778 ]
# [-0.9696117   0.24464907  1.5037493 ]
# [-0.98713547  0.15988608  1.7316498 ]
# [-0.997812   0.0661156  1.8882276]
# [-0.9994247  -0.03391549  2.0017173 ]
# [-0.99071866 -0.13592854  2.048573  ]
# [-0.969309  -0.2458456  2.2408266]
# [-0.9361353  -0.35164005  2.2186098 ]
# [-0.8933577 -0.4493462  2.134218 ]
# [-0.84985316 -0.5270195   1.781126  ]
# [-0.8143302 -0.5804018  1.2826469]
# [-0.7978418 -0.6028669  0.5573512]
# [-0.7860662  -0.6181423   0.38575357]
# [-0.7881229  -0.61551785 -0.06668688]
# [-0.81120247 -0.58476543 -0.76904094]
# [-0.8444592 -0.53562   -1.1869826]
# [-0.8884965 -0.4588834 -1.7700733]
# [-0.93456864 -0.3557828  -2.2597306 ]
# [-0.97116554 -0.23840615 -2.4605439 ]
# [-0.9932739  -0.11578852 -2.4935105 ]
# [-0.9996903   0.02488698 -2.8187675 ]
# [-0.98770154  0.15635125 -2.6421168 ]
# [-0.9632333   0.26866636 -2.3002565 ]
# [-0.9275872   0.37360674 -2.2177212 ]
# [-0.8811099   0.47291154 -2.1939592 ]
# [-0.8381168  0.5454908 -1.6876477]
# [-0.7961833  0.6050555 -1.45722  ]
# [-0.7740453   0.63313025 -0.71509886]
# [-0.75859416  0.6515634  -0.48106006]
# [-0.76436913  0.6447789   0.17819151]
# [-0.78021294  0.62551403  0.49887615]
# [-0.81811976  0.5750479   1.2625496 ]
# [-0.8662618  0.4995904  1.7907363]
# [-0.9091087   0.41655895  1.8693786 ]
# [-0.95163655  0.30722612  2.3476028 ]
# [-0.9831644   0.18272315  2.570426  ]
# [-0.9981566   0.06069124  2.460539  ]
# [-0.99775594 -0.0669561   2.5546958 ]
# [-0.9787831  -0.20489924  2.7870905 ]
# [-0.9464931  -0.32272407  2.444908  ]
# [-0.9020876 -0.4315529  2.3521469]
# [-0.8559557 -0.5170492  1.9437289]
# [-0.8121055  -0.58351064  1.5928987 ]
# [-0.76952535 -0.63861626  1.3930776 ]
# [-0.73380584 -0.67935926  1.0838066 ]
# [-0.72106826 -0.692864    0.37128654]
# [-0.72369653 -0.6901184  -0.0760166 ]
# [-0.7401811 -0.6724076 -0.4839172]
# [-0.77385247 -0.63336587 -1.0312339 ]
# [-0.82768613 -0.5611913  -1.801412  ]
# [-0.87903005 -0.47676638 -1.9770409 ]
# [-0.93088365 -0.36531582 -2.4600065 ]
# [-0.9692911  -0.24591611 -2.5101469 ]
# [-0.99480754 -0.10177418 -2.9302804 ]
# [-0.99934006  0.03632489 -2.7656717 ]
# [-0.9849409   0.17289129 -2.7486308 ]
# [-0.95221835  0.305418   -2.7322593 ]
# [-0.90563506  0.42405793 -2.5508804 ]
# [-0.8575258   0.51444095 -2.0486841 ]
# [-0.81316286  0.5820362  -1.6174978 ]
# [-0.78015506  0.6255862  -1.0930443 ]
# [-0.75957227  0.65042293 -0.6451675 ]
# [-0.76117337  0.6485485   0.04930352]
# [-0.7818492   0.62346756  0.65011775]
# [-0.8099354  0.5865191  0.9283132]
# [-0.84959686  0.5274326   1.4235706 ]
# [-0.8931228   0.44981295  1.7803986 ]
# [-0.9354166   0.35354745  2.1039026 ]
# [-0.9694096  0.2454486  2.2675667]
# [-0.9926997   0.12061221  2.5415173 ]
# [-9.9999923e-01 -1.2269344e-03  2.4426701e+00]
# [-0.9933243  -0.11535545  2.287718  ]
# In episode 1
# [-0.97343165 -0.22897771  2.3082905 ]
# [-0.9480517  -0.31811634  1.8542918 ]
# [-0.91409343 -0.40550366  1.875756  ]
# [-0.8793763  -0.47612742  1.574318  ]
# [-0.84905374 -0.5283065   1.207182  ]
# [-0.8277976  -0.5610269   0.78042054]
# [-0.8104868 -0.5857569  0.6037564]
# [-0.8035019  -0.59530216  0.23656125]
# [-0.8170481  -0.57656956 -0.46235606]
# [-0.84841573 -0.5293305  -1.1342525 ]
# [-0.89186674 -0.45229825 -1.7694138 ]
# [-0.92950124 -0.36881906 -1.8320475 ]
# [-0.9667491 -0.2557269 -2.3827727]
# [-0.9924389  -0.12273962 -2.7109928 ]
# [-0.99970794  0.02416616 -2.9443686 ]
# [-0.98424757  0.17679588 -3.0712316 ]
# [-0.9524116   0.30481502 -2.640282  ]
# [-0.9146506   0.40424532 -2.1281874 ]
# [-0.87700063  0.48048925 -1.7011786 ]
# [-0.8397642   0.54295135 -1.4547023 ]
# [-0.8044794   0.59398055 -1.2410048 ]
# [-0.77711064  0.629364   -0.89473444]
# [-0.7635996   0.6456901  -0.42384222]
# [-0.7620113   0.6475637  -0.04912398]
# [-0.7697902   0.638297    0.24197766]
# [-0.7877823  0.6159538  0.5737579]
# [-0.8245865   0.56573594  1.2454132 ]
# [-0.8640484   0.50340873  1.4757223 ]
# [-0.9048803   0.42566618  1.7568276 ]
# [-0.9431357  0.332408   2.0168467]
# [-0.97187775  0.23548593  2.022742  ]
# [-0.9932261   0.11619759  2.4251568 ]
# [-0.99998516  0.00544802  2.2202525 ]
# [-0.99478763 -0.10196855  2.1518826 ]
# [-0.97812116 -0.20803614  2.148413  ]
# [-0.9481566  -0.31780356  2.2769063 ]
# [-0.91631943 -0.40044808  1.7718748 ]
# [-0.8866185  -0.46250147  1.376174  ]
# [-0.86908567 -0.4946616   0.7326183 ]
# [-0.85792315 -0.51377803  0.44274557]
# [-0.8537709  -0.52064884  0.16056149]
# [-0.8646534  -0.5023688  -0.42549062]
# [-0.88978523 -0.4563795  -1.0482848 ]
# [-0.9147052  -0.40412173 -1.1580706 ]
# [-0.9397308  -0.34191522 -1.3412853 ]
# [-0.96619296 -0.25781995 -1.7637801 ]
# [-0.9880835  -0.15391907 -2.1246357 ]
# [-0.9996059  -0.02807144 -2.5291655 ]
# [-0.99551505  0.09460357 -2.4564075 ]
# [-0.97651714  0.21543984 -2.4479392 ]
# [-0.9478027   0.31885728 -2.1476276 ]
# [-0.9108486   0.41274062 -2.0187454 ]
# [-0.868196    0.49622142 -1.8756049 ]
# [-0.8205263  0.5716088 -1.7844808]
# [-0.7859531   0.61828613 -1.1619003 ]
# [-0.7646091   0.64449435 -0.676032  ]
# [-0.75776213  0.65253085 -0.2111554 ]
# [-0.77330315  0.6340364   0.48315367]
# [-0.8018314   0.59755033  0.92638665]
# [-0.84322935  0.53755397  1.4581783 ]
# [-0.8871506  0.46148    1.7574177]
# [-0.9252021   0.37947485  1.808682  ]
# [-0.9557066   0.29432106  1.809672  ]
# [-0.9806648   0.19569516  2.0355754 ]
# [-0.9971087   0.07598847  2.4180894 ]
# [-0.9984513  -0.05563333  2.6344771 ]
# [-0.98072046 -0.19541587  2.820388  ]
# [-0.9486513  -0.31632367  2.5034037 ]
# [-0.9056371 -0.4240536  2.3212996]
# [-0.8528707 -0.5221222  2.2284145]
# [-0.80415285 -0.5944226   1.744201  ]
# [-0.7549019 -0.6558377  1.5748878]
# [-0.7106733 -0.7035222  1.3009949]
# [-0.6826204  -0.73077315  0.7822464 ]
# [-0.6648335  -0.74699163  0.48143238]
# [-0.6723114  -0.7402684  -0.20111904]
# [-0.70821947 -0.70599234 -0.992923  ]
# [-0.7615297 -0.64813   -1.5739415]
# [-0.8279174 -0.56085   -2.194283 ]
# [-0.8935087  -0.44904596 -2.594297  ]
# [-0.95343626 -0.30159464 -3.1866517 ]
# [-0.98943204 -0.14499755 -3.2170846 ]
# [-0.9993993   0.03465511 -3.603451  ]
# [-0.9786834  0.2053747 -3.44369  ]
# [-0.93058586  0.36607367 -3.3587952 ]
# [-0.85924274  0.51156807 -3.2444491 ]
# [-0.7775296   0.62884635 -2.8611963 ]
# [-0.6966703   0.71739143 -2.3996434 ]
# [-0.6154734  0.7881577 -2.1551828]
# [-0.55440146  0.83224934 -1.5068564 ]
# [-0.5171952   0.85586745 -0.88146055]
# [-0.5068097  0.862058  -0.2418131]
# [-0.514114    0.85772187  0.16988839]
# [-0.5405442  0.8413156  0.6221898]
# [-0.6002495  0.7998128  1.4545845]
# [-0.677321   0.7356876  2.006039 ]
# [-0.76297903  0.6464232   2.4758823 ]
# [-0.8509679  0.5252178  2.9983237]
# [-0.9241062   0.38213584  3.2172914 ]
# [-0.97932553  0.20229061  3.7682025 ]
# In episode 2
# [-0.9999806  0.0062221  3.9494834]
# [-0.9811181  -0.19340959  4.017166  ]
# [-0.9273609  -0.37416813  3.7772682 ]
# [-0.8473373 -0.5310551  3.5269136]
# [-0.7484506  -0.66319054  3.304567  ]
# [-0.6549995 -0.7556293  2.6308153]
# [-0.57899433 -0.8153316   1.9337448 ]
# [-0.51867855 -0.8549693   1.4438015 ]
# [-0.49536958 -0.8686823   0.54088825]
# [-0.49956965 -0.8662737  -0.0968339 ]
# [-0.52073187 -0.85372025 -0.49212208]
# [-0.5778531  -0.81614083 -1.3677522 ]
# [-0.6586651 -0.7524362 -2.0589542]
# [-0.74872446 -0.6628814  -2.5418482 ]
# [-0.845594   -0.53382653 -3.2308238 ]
# [-0.9299983  -0.36756393 -3.734623  ]
# [-0.98228586 -0.18738855 -3.7577064 ]
# [-0.99996614  0.00822545 -3.9345694 ]
# [-0.97996694  0.19916034 -3.8455095 ]
# [-0.9288072  0.3705634 -3.5822897]
# [-0.85041535  0.5261119  -3.488131  ]
# [-0.75102776  0.6602706  -3.343139  ]
# [-0.64636725  0.7630265  -2.936071  ]
# [-0.5619404   0.82717776 -2.121682  ]
# [-0.49665594  0.8679475  -1.5397602 ]
# [-0.47070885  0.8822886  -0.5929526 ]
# [-0.46854973  0.8834371  -0.04891179]
# [-0.4842251  0.8749435  0.3565766]
# [-0.5360324   0.84419745  1.2050579 ]
# [-0.60270184  0.7979665   1.6230514 ]
# [-0.6977905  0.7163019  2.5085096]
# [-0.7959932   0.60530555  2.9667687 ]
# [-0.8807276   0.47362316  3.1349921 ]
# [-0.94821906  0.31761715  3.4036922 ]
# [-0.9898484   0.14212741  3.6121027 ]
# [-0.9988008  -0.04895796  3.831757  ]
# [-0.9709787  -0.23916607  3.8505871 ]
# [-0.90911335 -0.41654882  3.7627778 ]
# [-0.81930953 -0.57335144  3.618896  ]
# [-0.7163209 -0.6977711  3.2338097]
# [-0.6211167 -0.7837181  2.566969 ]
# [-0.5281702 -0.8491385  2.274451 ]
# [-0.44847468 -0.89379555  1.8277239 ]
# [-0.39765412 -0.91753536  1.1219865 ]
# [-0.39098704 -0.9203962   0.145099  ]
# [-0.42731747 -0.90410167 -0.796397  ]
# [-0.4970679  -0.86771166 -1.5738554 ]
# [-0.6023072 -0.7982644 -2.5234373]
# [-0.7146039 -0.6995293 -2.9933894]
# [-0.82972527 -0.558172   -3.651152  ]
# [-0.92036134 -0.39106902 -3.8077636 ]
# [-0.98225427 -0.18755417 -4.2624264 ]
# [-0.999617    0.02767437 -4.3269887 ]
# [-0.97351104  0.22863999 -4.0600505 ]
# [-0.90916026  0.41644642 -3.9770544 ]
# [-0.8246481  0.5656461 -3.433668 ]
# [-0.73746693  0.67538327 -2.8053548 ]
# [-0.65189886  0.7583059  -2.384524  ]
# [-0.588577   0.8084412 -1.6157672]
# [-0.5464845  0.8374693 -1.0227367]
# [-0.53478897  0.84498566 -0.2780534 ]
# [-0.5536942   0.8327201   0.45072168]
# [-0.6065895  0.7950152  1.2993932]
# [-0.68324274  0.7301913   2.0086143 ]
# [-0.76415133  0.645037    2.3506036 ]
# [-0.84948885  0.52760655  2.9058228 ]
# [-0.92071456  0.39023674  3.0978377 ]
# [-0.9763078   0.21638644  3.6555402 ]
# [-0.9998167   0.01914578  3.9792948 ]
# [-0.9812056  -0.19296542  4.266608  ]
# [-0.9231817 -0.3843638  4.0067024]
# [-0.83366024 -0.5522776   3.8115048 ]
# [-0.73353356 -0.6796532   3.2439194 ]
# [-0.6402502 -0.7681665  2.5736527]
# [-0.57109636 -0.82088304  1.7396618 ]
# [-0.5187577  -0.85492134  1.2488725 ]
# [-0.49206775 -0.8705569   0.618676  ]
# [-0.4900608  -0.87168825  0.04607783]
# [-0.50751394 -0.86164355 -0.40275133]
# [-0.556309   -0.83097553 -1.1528057 ]
# [-0.6321628 -0.7748356 -1.88808  ]
# [-0.71981025 -0.6941709  -2.3837514 ]
# [-0.8043461 -0.5941611 -2.620903 ]
# [-0.8880564  -0.45973447 -3.1705217 ]
# [-0.9547879 -0.2972879 -3.516906 ]
# [-0.9939199  -0.11010554 -3.830433  ]
# [-0.9958751   0.09073474 -4.0237784 ]
# [-0.96242493  0.27154794 -3.682827  ]
# [-0.89471763  0.44663227 -3.7599344 ]
# [-0.8142316   0.58054024 -3.1278846 ]
# [-0.72495866  0.6887924  -2.808599  ]
# [-0.6481572   0.76150656 -2.116248  ]
# [-0.596849    0.80235356 -1.3118768 ]
# [-0.5586005   0.82943684 -0.9374118 ]
# [-0.54036313  0.8414319  -0.43657878]
# [-0.5481206   0.8363993   0.18493874]
# [-0.5778105   0.81617093  0.71855927]
# [-0.6297821  0.7767719  1.3045815]
# [-0.69206905  0.72183126  1.661579  ]
# [-0.7724003  0.635136   2.3652039]
# In episode 3
# [-0.8571656  0.515041   2.9425824]
# [-0.9326442   0.36079752  3.4386523 ]
# [-0.98229235  0.18735455  3.6130908 ]
# [-0.99994355  0.01062378  3.5568867 ]
# [-0.9863004  -0.16495897  3.526808  ]
# [-0.94855297 -0.3166185   3.1289208 ]
# [-0.8959134  -0.44422874  2.7630148 ]
# [-0.82892615 -0.55935806  2.6659594 ]
# [-0.7601585 -0.6497377  2.2725635]
# [-0.6997348 -0.7144027  1.7706157]
# [-0.6624666  -0.74909145  1.0183887 ]
# [-0.65236783 -0.7579025   0.26804665]
# [-0.6570281  -0.7538661  -0.12330616]
# [-0.68049914 -0.73274887 -0.6314779 ]
# [-0.727158  -0.6864701 -1.3145837]
# [-0.7910489 -0.6117529 -1.9669764]
# [-0.8538279  -0.52055544 -2.2154672 ]
# [-0.9153578  -0.40264133 -2.6620147 ]
# [-0.96784574 -0.25154445 -3.2024982 ]
# [-0.99599    -0.08946489 -3.2938201 ]
# [-0.9962827   0.08614391 -3.5167096 ]
# [-0.9630223  0.2694218 -3.730835 ]
# [-0.89923596  0.43746397 -3.5996797 ]
# [-0.8095491  0.5870522 -3.4927242]
# [-0.7004201  0.7137308 -3.3479528]
# [-0.59855306  0.80108315 -2.6858459 ]
# [-0.50898534  0.8607752  -2.1537614 ]
# [-0.4549743   0.89050454 -1.2332445 ]
# [-0.4387762   0.89859635 -0.3621407 ]
# [-0.45122412  0.89241064  0.27800483]
# [-0.4869215   0.87344575  0.80850315]
# [-0.5538996  0.8325835  1.5695797]
# [-0.6528821  0.7574595  2.4868495]
# [-0.76507765  0.643938    3.1955745 ]
# [-0.87659365  0.48123133  3.9515116 ]
# [-0.95968604  0.2810743   4.3429103 ]
# [-0.9986598   0.05175508  4.6627026 ]
# [-0.9849281  -0.17296447  4.5123386 ]
# [-0.92596394 -0.37761194  4.2675443 ]
# [-0.84080833 -0.54133296  3.6961143 ]
# [-0.7342946 -0.6788309  3.4829545]
# [-0.63380665 -0.77349156  2.7632453 ]
# [-0.55733466 -0.83028793  1.90585   ]
# [-0.50348645 -0.8640031   1.2708586 ]
# [-0.48933738 -0.8720946   0.32598937]
# [-0.50385976 -0.8637855  -0.33463213]
# [-0.54321635 -0.83959275 -0.9240368 ]
# [-0.6042305  -0.79680955 -1.490732  ]
# [-0.67936665 -0.733799   -1.9619865 ]
# [-0.7580286 -0.6522213 -2.267721 ]
# [-0.8366069 -0.5478037 -2.6154883]
# [-0.90808374 -0.4187886  -2.9525156 ]
# [-0.9661571  -0.25795442 -3.4241312 ]
# [-0.9961889  -0.08722207 -3.4714262 ]
# [-0.9958289   0.09124012 -3.5740047 ]
# [-0.9616875   0.27414793 -3.726728  ]
# [-0.8950116  0.4460428 -3.6927097]
# [-0.8033642  0.595488  -3.5106778]
# [-0.69409937  0.71987915 -3.3151057 ]
# [-0.59565717  0.8032388  -2.581691  ]
# [-0.5123769  0.8587607 -2.0026643]
# [-0.44426823  0.8958938  -1.5518603 ]
# [-0.4094713   0.912323   -0.76965666]
# [-0.40953597  0.912294    0.00141769]
# [-0.4440038   0.8960249   0.76233596]
# [-0.5135384  0.8580666  1.5848261]
# [-0.61421496  0.78913873  2.441747  ]
# [-0.72853464  0.68500894  3.0957904 ]
# [-0.8414453  0.5403423  3.6754444]
# [-0.9327461   0.36053386  4.0400724 ]
# [-0.9901484   0.14002165  4.5671377 ]
# [-0.9941875 -0.1076625  4.9670973]
# [-0.9420132  -0.33557582  4.686897  ]
# [-0.85090756 -0.5253154   4.2173862 ]
# [-0.73494124 -0.6781308   3.8426118 ]
# [-0.60532224 -0.7959805   3.5081873 ]
# [-0.4827647 -0.8757501  2.9272342]
# [-0.37991107 -0.925023    2.2821755 ]
# [-0.30022857 -0.9538673   1.6953577 ]
# [-0.25239453 -0.9676244   0.9955632 ]
# [-0.24438015 -0.96967953  0.16547379]
# [-0.2590658  -0.96585965 -0.30348903]
# [-0.32129088 -0.94698054 -1.3007491 ]
# [-0.40325567 -0.91508734 -1.7595904 ]
# [-0.50547534 -0.86284107 -2.2972188 ]
# [-0.63375825 -0.7735312  -3.129388  ]
# [-0.7643506  -0.64480084 -3.672629  ]
# [-0.8837326  -0.46799216 -4.274906  ]
# [-0.9665714  -0.25639772 -4.5544786 ]
# [-0.9996739  -0.02553552 -4.6751037 ]
# [-0.9774637   0.21110342 -4.7648396 ]
# [-0.9094604   0.41579044 -4.322161  ]
# [-0.8111918  0.5847802 -3.9159465]
# [-0.7056879   0.70852286 -3.2558744 ]
# [-0.59718657  0.8021023  -2.868091  ]
# [-0.5135273  0.8580733 -2.013971 ]
# [-0.44567063  0.895197   -1.5473425 ]
# [-0.41421327  0.91017985 -0.6969004 ]
# [-0.41344014  0.9105313  -0.01698501]
# [-0.43031153  0.90268046  0.37217733]
# In episode 4
# [-0.46505654  0.88528097  0.77721196]
# [-0.53678954  0.84371614  1.6585777 ]
# [-0.639887    0.76846904  2.5544767 ]
# [-0.74819815  0.66347533  3.0198188 ]
# [-0.8501159   0.52659565  3.4172637 ]
# [-0.9304489   0.36642176  3.5886126 ]
# [-0.98353195  0.1807344   3.8685458 ]
# [-0.9997492  -0.02239658  4.082631  ]
# [-0.9728239  -0.23154607  4.225364  ]
# [-0.9041814  -0.42714864  4.153405  ]
# [-0.7974136  -0.60343313  4.129251  ]
# [-0.66648525 -0.7455182   3.8702514 ]
# [-0.526476  -0.85019    3.5006795]
# [-0.39630356 -0.91811955  2.9392617 ]
# [-0.28510672 -0.9584958   2.3673894 ]
# [-0.20510268 -0.97874045  1.650983  ]
# [-0.16090643 -0.98696965  0.89919263]
# [-0.14797394 -0.98899126  0.26179293]
# [-0.18016694 -0.983636   -0.6527364 ]
# [-0.24035208 -0.9706858  -1.2314477 ]
# [-0.33175245 -0.94336647 -1.9086415 ]
# [-0.44951624 -0.89327216 -2.5612612 ]
# [-0.5855261  -0.81065357 -3.186104  ]
# [-0.7261805 -0.6875041 -3.7444196]
# [-0.86079717 -0.5089482  -4.4816804 ]
# [-0.9579419  -0.28696224 -4.858165  ]
# [-0.9996205  -0.02754747 -5.270065  ]
# [-0.9740676   0.22625698 -5.115685  ]
# [-0.8868568   0.46204436 -5.041314  ]
# [-0.75227284  0.6588517  -4.7798457 ]
# [-0.5891198  0.8080457 -4.4307184]
# [-0.42059863  0.9072468  -3.9172816 ]
# [-0.27451935  0.9615816  -3.1203046 ]
# [-0.15881096  0.987309   -2.372072  ]
# [-0.08660778  0.99624246 -1.4553959 ]
# [-0.06286681  0.9980219  -0.47616258]
# [-0.08413775  0.9964541   0.42658088]
# [-0.13396195  0.99098647  1.002571  ]
# [-0.20977868  0.9777489   1.5396543 ]
# [-0.32965675  0.94410086  2.4918277 ]
# [-0.47055885  0.8823686   3.0796807 ]
# [-0.61783314  0.78630924  3.5211985 ]
# [-0.774693   0.6323375  4.4049106]
# [-0.908102    0.41874912  5.0499887 ]
# [-0.98883575  0.14900976  5.6500125 ]
# [-0.9882999  -0.15252316  6.0537515 ]
# [-0.8994699  -0.43698272  5.9824123 ]
# [-0.73965025 -0.67299145  5.720088  ]
# [-0.5352407  -0.84469956  5.355156  ]
# [-0.31817344 -0.9480325   4.819811  ]
# [-0.1040908 -0.9945678  4.3904495]
# [ 0.09226003 -0.99573493  3.9334223 ]
# [ 0.23743652 -0.97140306  2.9466927 ]
# [ 0.33583474 -0.94192094  2.0553052 ]
# [ 0.41076574 -0.9117409   1.6160489 ]
# [ 0.4514265 -0.8923083  0.9013917]
# [ 0.4530041  -0.89150846  0.03537588]
# [ 0.4274974 -0.9040166 -0.5681903]
# [ 0.36552083 -0.9308032  -1.3506066 ]
# [ 0.25958756 -0.9657196  -2.231944  ]
# [ 0.11711978 -0.9931178  -2.9041178 ]
# [-0.06726175 -0.9977354  -3.6940355 ]
# [-0.2847189 -0.9586111 -4.428012 ]
# [-0.5066677  -0.86214143 -4.8520403 ]
# [-0.71543884 -0.69867533 -5.318737  ]
# [-0.8865944  -0.46254766 -5.853554  ]
# [-0.9864035  -0.16434132 -6.315528  ]
# [-0.9882967   0.15254377 -6.3646374 ]
# [-0.8876665   0.46048683 -6.5080385 ]
# [-0.7115553  0.7026301 -6.0108695]
# [-0.49358848  0.8696956  -5.509964  ]
# [-0.27393243  0.96174896 -4.7746315 ]
# [-0.06233728  0.99805516 -4.302036  ]
# [ 0.10241501  0.99474174 -3.2994523 ]
# [ 0.22456871  0.9744583  -2.4781106 ]
# [ 0.3110368   0.95039785 -1.7956665 ]
# [ 0.3589656  0.9333508 -1.0175133]
# [ 0.37099442  0.9286351  -0.2584047 ]
# [0.34494513 0.93862283 0.55798614]
# [0.294768   0.95556885 1.0593519 ]
# [0.19580737 0.9806424  2.042641  ]
# [0.05876024 0.9982721  2.7657316 ]
# [-0.1300019  0.9915137  3.7833004]
# [-0.35122615  0.9362906   4.5701895 ]
# [-0.5784879  0.815691   5.159866 ]
# [-0.7891864   0.61415374  5.852189  ]
# [-0.94212645  0.33525765  6.38869   ]
# [-0.99984324  0.01770481  6.4834595 ]
# [-0.9501347 -0.3118398  6.69669  ]
# [-0.8103111 -0.5859999  6.1796947]
# [-0.6029749 -0.7977601  5.949157 ]
# [-0.3787701 -0.9254908  5.175158 ]
# [-0.16794291 -0.98579675  4.3944893 ]
# [ 0.01392647 -0.999903    3.65339   ]
# [ 0.16389905 -0.98647714  3.0142987 ]
# [ 0.28174463 -0.9594894   2.419401  ]
# [ 0.3654219 -0.930842   1.7694817]
# [ 0.41460824 -0.91        1.068525  ]
# [ 0.42799008 -0.90378344  0.29510915]
# [ 0.40519166 -0.9142318  -0.501585  ]
# In episode 5
# [ 0.3512619 -0.9362772 -1.1653975]
# [ 0.262609   -0.96490234 -1.8638691 ]
# [ 0.12366544 -0.992324   -2.8348455 ]
# [-0.04892229 -0.9988026  -3.4584932 ]
# [-0.26538378 -0.96414286 -4.393203  ]
# [-0.4890253  -0.87226963 -4.8473997 ]
# [-0.717697  -0.6963555 -5.79035  ]
# [-0.89456826 -0.4469314  -6.1394954 ]
# [-0.9889484  -0.14825994 -6.2904716 ]
# [-0.9852598   0.17106488 -6.414378  ]
# [-0.88256156  0.47019684 -6.352068  ]
# [-0.70281976  0.71136796 -6.0385785 ]
# [-0.49558508  0.8685594  -5.2169056 ]
# [-0.30010766  0.95390534 -4.2740564 ]
# [-0.1386917  0.9903356 -3.3133056]
# [-0.02300056  0.9997355  -2.3227527 ]
# [ 0.04395094  0.9990337  -1.3393538 ]
# [ 0.06717259  0.99774134 -0.46516207]
# [0.04475538 0.998998   0.44905734]
# [-0.00769019  0.99997044  1.049212  ]
# [-0.08616813  0.9962806   1.5716972 ]
# [-0.21099621  0.97748685  2.5263777 ]
# [-0.37080675  0.92871004  3.3456707 ]
# [-0.5552849   0.83166015  4.1765594 ]
# [-0.7404271   0.67213666  4.900001  ]
# [-0.8975692  0.4408736  5.6103806]
# [-0.98887455  0.14875172  6.1453176 ]
# [-0.98552567 -0.16952623  6.393095  ]
# [-0.88575387 -0.4641552   6.2466335 ]
# [-0.70930845 -0.70489824  5.9919815 ]
# [-0.488196  -0.872734   5.5699034]
# [-0.27261874 -0.96212214  4.6781526 ]
# [-0.08439916 -0.996432    3.8322833 ]
# [ 0.05489237 -0.9984923   2.788393  ]
# [ 0.14155245 -0.98993075  1.74219   ]
# [ 0.19094919 -0.9815999   1.0019913 ]
# [ 0.20662199 -0.97842085  0.3198428 ]
# [ 0.17725413 -0.98416513 -0.59850955]
# [ 0.11719061 -0.99310946 -1.2147036 ]
# [ 0.02442968 -0.99970156 -1.8605682 ]
# [-0.10009747 -0.99497765 -2.49395   ]
# [-0.26644528 -0.96385    -3.3887541 ]
# [-0.47035334 -0.8824782  -4.3997607 ]
# [-0.66654545 -0.74546444 -4.7974777 ]
# [-0.8377801  -0.54600775 -5.2727966 ]
# [-0.95292115 -0.30321828 -5.3904676 ]
# [-0.9998299  -0.01844404 -5.792461  ]
# [-0.9609908   0.27658048 -5.9735804 ]
# [-0.8411513   0.54079986 -5.823076  ]
# [-0.6699455  0.7424103 -5.3054657]
# [-0.4802855  0.8771122 -4.6631026]
# [-0.29878956  0.954319   -3.951123  ]
# [-0.13157326  0.9913064  -3.4293633 ]
# [ 2.4339803e-03  9.9999702e-01 -2.6877971e+00]
# [ 0.11326621  0.99356467 -2.2215166 ]
# [ 0.1746445   0.98463154 -1.2406979 ]
# [ 0.18688834  0.98238117 -0.24898012]
# [0.17208815 0.98508155 0.30089346]
# [0.12713079 0.99188596 0.90946573]
# [0.04492638 0.9989903  1.6506851 ]
# [-0.06086064  0.9981463   2.1167955 ]
# [-0.20983511  0.9777368   3.0101607 ]
# [-0.3989999   0.91695094  3.9803922 ]
# [-0.6053837  0.7959338  4.796439 ]
# [-0.788288   0.6153065  5.155475 ]
# [-0.9247285  0.3806273  5.4460025]
# [-0.99339104  0.11477892  5.5088425 ]
# [-0.9857539  -0.16819413  5.6805973 ]
# [-0.90223444 -0.43124595  5.5375175 ]
# [-0.76378477 -0.64547104  5.1153307 ]
# [-0.59833074 -0.8012492   4.5548067 ]
# [-0.4211076 -0.9070107  4.135001 ]
# [-0.24994597 -0.9682598   3.640833  ]
# [-0.10762107 -0.994192    2.895891  ]
# [-0.01524152 -0.99988383  1.851756  ]
# [ 0.02834356 -0.99959826  0.8717893 ]
# [ 0.03429935 -0.9994116   0.11917445]
# [ 0.01283597 -0.9999176  -0.42939502]
# [-0.05353118 -0.99856615 -1.3278623 ]
# [-0.1598035 -0.9871488 -2.138696 ]
# [-0.29866344 -0.9543585  -2.8560054 ]
# [-0.46377942 -0.8859507  -3.579291  ]
# [-0.6301821 -0.7764474 -3.9906256]
# [-0.796206   -0.60502565 -4.7842116 ]
# [-0.92454815 -0.3810653  -5.176996  ]
# [-0.9935985  -0.11296894 -5.554753  ]
# [-0.9839356   0.17852384 -5.853932  ]
# [-0.887395   0.4610098 -5.9929357]
# [-0.72183084  0.69206953 -5.704388  ]
# [-0.5201335   0.85408497 -5.1887383 ]
# [-0.30305687  0.9529725  -4.78217   ]
# [-0.1041685   0.99455965 -4.0708184 ]
# [ 0.04785696  0.9988542  -3.0446613 ]
# [ 0.15447325  0.987997   -2.1443806 ]
# [ 0.23030362  0.97311884 -1.5459081 ]
# [ 0.27350068  0.9618718  -0.89281845]
# [ 0.28299084  0.9591226  -0.19760777]
# [0.25137234 0.96789044 0.6562629 ]
# [0.17876539 0.9838917  1.4873272 ]
# [0.07060693 0.99750423 2.181315  ]
# In episode 6
# [-0.06806283  0.997681    2.7756245 ]
# [-0.24366029  0.9698606   3.5604522 ]
# [-0.438649    0.89865845  4.1591334 ]
# [-0.6324598  0.7745932  4.612599 ]
# [-0.8048651  0.5934578  5.014468 ]
# [-0.93347234  0.35864934  5.3705525 ]
# [-0.99532545  0.09657802  5.4018354 ]
# [-0.98208547 -0.1884359   5.725961  ]
# [-0.8864594 -0.4628063  5.8317814]
# [-0.7253314  -0.68839985  5.562446  ]
# [-0.51868826 -0.8549634   5.3239937 ]
# [-0.29841053 -0.9544376   4.8457823 ]
# [-0.08610454 -0.9962861   4.336312  ]
# [ 0.08207362 -0.99662626  3.3675468 ]
# [ 0.22210792 -0.9750221   2.8361962 ]
# [ 0.30980864 -0.9507989   1.8203182 ]
# [ 0.35057658 -0.93653405  0.8638984 ]
# [ 0.36999965 -0.9290319   0.4164394 ]
# [ 0.34586036 -0.938286   -0.5170616 ]
# [ 0.30171448 -0.95339835 -0.93330306]
# [ 0.22246681 -0.97494024 -1.6429291 ]
# [ 0.10653071 -0.9943094  -2.3522143 ]
# [-0.05734371 -0.9983545  -3.2821686 ]
# [-0.2592762 -0.9658032 -4.0979505]
# [-0.47490156 -0.8800389  -4.651589  ]
# [-0.6963088 -0.7177423 -5.5077925]
# [-0.87959903 -0.47571585 -6.095537  ]
# [-0.9867582  -0.16219826 -6.6571937 ]
# [-0.98314047  0.18285185 -6.9360886 ]
# [-0.8641552  0.5032254 -6.868815 ]
# [-0.6633771  0.7482853 -6.3629255]
# [-0.43400517  0.9009104  -5.527783  ]
# [-0.21353957  0.97693443 -4.6747413 ]
# [-0.0072932  0.9999734 -4.158068 ]
# [ 0.16019543  0.98708534 -3.3636377 ]
# [ 0.2787853   0.96035343 -2.4328074 ]
# [ 0.3475058  0.9376778 -1.4476165]
# [ 0.37577724  0.92671    -0.6065103 ]
# [ 0.3819384   0.9241878  -0.13314886]
# [0.34517026 0.9385401  0.7894517 ]
# [0.2777946 0.9606405 1.4184525]
# [0.18249527 0.98320675 1.9594766 ]
# [0.04871085 0.9988129  2.6958723 ]
# [-0.12144024  0.9925988   3.4094174 ]
# [-0.3372733  0.9414068  4.445565 ]
# [-0.5555813  0.8314622  4.9008584]
# [-0.7662656  0.642524   5.678935 ]
# [-0.9241971   0.38191584  6.1183853 ]
# [-0.9983846   0.05681729  6.70041   ]
# [-0.9589155  -0.28369188  6.8897977 ]
# [-0.80863553 -0.58830994  6.826505  ]
# [-0.5930388 -0.8051739  6.140028 ]
# [-0.36384878 -0.93145806  5.2486224 ]
# [-0.13498367 -0.9908478   4.7399917 ]
# [ 0.07855312 -0.9969099   4.280622  ]
# [ 0.2604645 -0.9654834  3.6973827]
# [ 0.40755334 -0.9131814   3.1253986 ]
# [ 0.5253617 -0.850879   2.6673393]
# [ 0.5988273  -0.80087817  1.7779176 ]
# [ 0.6503666 -0.7596205  1.3206178]
# [ 0.67949086 -0.73368394  0.780031  ]
# [ 0.6903981 -0.7234297  0.2994142]
# [ 0.6796111 -0.7335726 -0.2961364]
# [ 0.64345795 -0.7654815  -0.964506  ]
# [ 0.58445007 -0.8114297  -1.4960979 ]
# [ 0.49036282 -0.8715184  -2.2339232 ]
# [ 0.36121944 -0.9324808  -2.8586147 ]
# [ 0.18460202 -0.98281336 -3.6781678 ]
# [-0.04535586 -0.99897087 -4.6207666 ]
# [-0.31195918 -0.95009553 -5.4376597 ]
# [-0.5819154  -0.81324935 -6.0765505 ]
# [-0.8150415  -0.57940257 -6.6343775 ]
# [-0.9686858  -0.24828973 -7.3416243 ]
# [-0.99081755  0.13520575 -7.730708  ]
# [-0.87038475  0.49237216 -7.583839  ]
# [-0.6461167   0.76323867 -7.069957  ]
# [-0.3554962  0.9346777 -6.7808104]
# [-0.07298187  0.9973333  -5.8079615 ]
# [ 0.18131633  0.98342484 -5.1074324 ]
# [ 0.4005186  0.9162886 -4.595159 ]
# [ 0.56096995  0.82783616 -3.6694853 ]
# [ 0.68381745  0.7296531  -3.148495  ]
# [ 0.77231014  0.6352456  -2.5897608 ]
# [ 0.83741504  0.54656756 -2.201333  ]
# [ 0.88831246  0.45923954 -2.0224185 ]
# [ 0.92178476  0.38770202 -1.5800326 ]
# [ 0.94013524  0.34080154 -1.0073593 ]
# [ 0.94910735  0.31495273 -0.5472503 ]
# [ 0.95531934  0.29557553 -0.40697846]
# [ 0.95869374  0.2844404  -0.23270491]
# [0.95681    0.290714   0.13100612]
# [0.9539638  0.29992178 0.19275352]
# [0.9488007  0.3158754  0.33536977]
# [0.9396632  0.34210107 0.5554562 ]
# [0.92004323 0.39181688 1.0690717 ]
# [0.89496714 0.44613203 1.1966645 ]
# [0.85977274 0.51067686 1.4706613 ]
# [0.8154883  0.57877356 1.6250424 ]
# [0.75373393 0.6571797  1.9969385 ]
# [0.6643947  0.74738187 2.5408363 ]
# In episode 7
# [0.5429708 0.8397516 3.054258 ]
# [0.38643727 0.9223157  3.5441017 ]
# [0.19325227 0.9811491  4.045797  ]
# [-0.05242965  0.9986246   4.9385905 ]
# [-0.3361048  0.9418246  5.8064866]
# [-0.62439895  0.7811056   6.631676  ]
# [-0.86434174  0.5029049   7.389563  ]
# [-0.9908752   0.13478273  7.835243  ]
# [-0.9651433  -0.26172185  8.        ]
# [-0.7882583 -0.6153445  7.960343 ]
# [-0.49558696 -0.86855835  7.7892575 ]
# [-0.15487386 -0.98793423  7.2602143 ]
# [ 0.1832409  -0.98306805  6.795639  ]
# [ 0.46086815 -0.88746864  5.8938203 ]
# [ 0.6764594  -0.73647994  5.2794256 ]
# [ 0.83534265 -0.54972965  4.916226  ]
# [ 0.9375769 -0.347778   4.5368085]
# [ 0.9910446  -0.13353121  4.4253774 ]
# [0.996595   0.08245238 4.329547  ]
# [0.95438176 0.2985892  4.4133596 ]
# [0.8575806  0.51434964 4.7407007 ]
# [0.6983019 0.7158033 5.150495 ]
# [0.45677364 0.88958293 5.9731493 ]
# [0.1285506 0.991703  6.9091535]
# [-0.24583744  0.96931106  7.5458174 ]
# [-0.60389876  0.797061    8.        ]
# [-0.8666178   0.49897254  8.        ]
# [-0.99251693  0.12210729  8.        ]
# [-0.96426594 -0.2649362   7.8110113 ]
# [-0.7951195  -0.60645276  7.669078  ]
# [-0.5387953  -0.84243673  7.0039644 ]
# [-0.2617475 -0.9651364  6.0834813]
# [ 0.01413642 -0.9999001   5.5793853 ]
# [ 0.24173552 -0.97034216  4.6003423 ]
# [ 0.4221698 -0.9065168  3.8336706]
# [ 0.55314195 -0.833087    3.0058692 ]
# [ 0.6559489  -0.75480527  2.5861616 ]
# [ 0.7356181 -0.6773965  2.2227926]
# [ 0.7853959  -0.61899376  1.5351347 ]
# [ 0.82577026 -0.5640066   1.364622  ]
# [ 0.8496282  -0.52738214  0.8742675 ]
# [ 0.86124665 -0.5081872   0.44875574]
# [ 0.86149025 -0.5077741   0.00959093]
# [ 0.8574607  -0.5145495  -0.15766232]
# [ 0.83819246 -0.5453746  -0.72707486]
# [ 0.80663955 -0.59104365 -1.1103226 ]
# [ 0.76636344 -0.64240724 -1.305665  ]
# [ 0.71008766 -0.7041133  -1.670767  ]
# [ 0.6265379  -0.77939093 -2.2503889 ]
# [ 0.49970317 -0.8661967  -3.0769436 ]
# [ 0.32753026 -0.94484067 -3.7913518 ]
# [ 0.1003     -0.99495727 -4.6643906 ]
# [-0.18119924 -0.9834464  -5.6534934 ]
# [-0.48840556 -0.87261677 -6.5611176 ]
# [-0.76201355 -0.6475611  -7.1231046 ]
# [-0.9448059  -0.32763046 -7.411699  ]
# [-0.9989301   0.04624613 -7.601143  ]
# [-0.9126126   0.40882546 -7.498081  ]
# [-0.7130919   0.70107055 -7.1146207 ]
# [-0.45824382  0.88882655 -6.3576055 ]
# [-0.20410262  0.9789495  -5.409428  ]
# [ 0.03003266  0.9995489  -4.7116823 ]
# [ 0.2237093  0.9746559 -3.911628 ]
# [ 0.3725849  0.9279981 -3.123487 ]
# [ 0.4915324  0.8708593 -2.6411116]
# [ 0.578385   0.8157639 -2.0579815]
# [ 0.64142823  0.767183   -1.5922184 ]
# [ 0.68995047  0.7238566  -1.3012419 ]
# [ 0.71175474  0.70242804 -0.61145204]
# [ 0.7143382   0.69980067 -0.07369496]
# [0.6881836 0.7255366 0.7339078]
# [0.6418404  0.76683825 1.241734  ]
# [0.5788299  0.81544834 1.5920564 ]
# [0.47478905 0.88009965 2.451374  ]
# [0.3248348 0.9457708 3.2777457]
# [0.12131113 0.9926145  4.184528  ]
# [-0.12824148  0.99174297  5.0041256 ]
# [-0.4057193  0.9139977  5.7834015]
# [-0.67190963  0.74063313  6.3803697 ]
# [-0.88071924  0.47363868  6.8118887 ]
# [-0.99155366  0.129697    7.2670865 ]
# [-0.9746563  -0.22370781  7.113609  ]
# [-0.84481716 -0.5350551   6.779119  ]
# [-0.6390681  -0.76915014  6.2587442 ]
# [-0.41096163 -0.9116526   5.3955493 ]
# [-0.17795163 -0.98403925  4.892083  ]
# [ 0.01974434 -0.99980503  3.973002  ]
# [ 0.18037714 -0.9835975   3.2324848 ]
# [ 0.3087349  -0.95114815  2.649856  ]
# [ 0.38596517 -0.92251337  1.6478237 ]
# [ 0.43918744 -0.8983955   1.1688032 ]
# [ 0.45888925 -0.8884935   0.44101268]
# [ 0.45764163 -0.88913673 -0.02807388]
# [ 0.41519317 -0.9097333  -0.9437161 ]
# [ 0.3403325 -0.9403052 -1.617693 ]
# [ 0.21583915 -0.9764289  -2.5943866 ]
# [ 0.04826444 -0.9988346  -3.3853593 ]
# [-0.17143054 -0.98519623 -4.4112945 ]
# [-0.4096216 -0.9122555 -4.995154 ]
# [-0.6492899 -0.760541  -5.692223 ]
# In episode 8
# [-0.84584105 -0.53343505 -6.0297885 ]
# [-0.97191936 -0.2353142  -6.5022936 ]
# [-0.9964775   0.08386089 -6.4300265 ]
# [-0.92331535  0.38404268 -6.2042255 ]
# [-0.7654344  0.643514  -6.09819  ]
# [-0.55258185  0.83345866 -5.7251453 ]
# [-0.33647156  0.9416936  -4.8458266 ]
# [-0.12248819  0.99246997 -4.4074183 ]
# [ 0.05628282  0.9984149  -3.582183  ]
# [ 0.19087118  0.98161507 -2.7147398 ]
# [ 0.2753357  0.9613482 -1.7377859]
# [ 0.32962692  0.9441113  -1.1393899 ]
# [ 0.36316973  0.931723   -0.7151857 ]
# [0.35842395 0.93355894 0.10177033]
# [0.30901268 0.9510579  1.0484881 ]
# [0.22484115 0.97439545 1.7474943 ]
# [0.11728178 0.9930987  2.1845536 ]
# [-0.02799936  0.9996079   2.9111068 ]
# [-0.22337298  0.97473305  3.94541   ]
# [-0.4509313   0.89255863  4.8506994 ]
# [-0.6837698   0.72969776  5.7021594 ]
# [-0.8695684  0.4938125  6.0282235]
# [-0.9810075   0.19396974  6.425231  ]
# [-0.9892932  -0.14594167  6.8334384 ]
# [-0.8819646  -0.47131562  6.886342  ]
# [-0.6877976 -0.7259025  6.431275 ]
# [-0.4538236 -0.8910915  5.747982 ]
# [-0.22561444 -0.9742167   4.8695583 ]
# [-0.01468665 -0.9998922   4.2577305 ]
# [ 0.15046892 -0.98861474  3.314595  ]
# [ 0.26930854 -0.96305394  2.432648  ]
# [ 0.3429219 -0.9393639  1.5470139]
# [ 0.39374745 -0.91921866  1.0935831 ]
# [ 0.40145093 -0.9158805   0.16791344]
# [ 0.38746515 -0.92188436 -0.3044029 ]
# [ 0.35145393 -0.9362052  -0.7751341 ]
# [ 0.2811414 -0.9596664 -1.4828075]
# [ 0.17416784 -0.984716   -2.198453  ]
# [ 0.03415854 -0.9994164  -2.8179088 ]
# [-0.15388167 -0.98808926 -3.7732146 ]
# [-0.37371367 -0.9275441  -4.5702806 ]
# [-0.59726214 -0.8020461  -5.141472  ]
# [-0.79288614 -0.6093698  -5.508952  ]
# [-0.93847704 -0.3453416  -6.053256  ]
# [-0.99890405 -0.04680455 -6.1156216 ]
# [-0.9659859  0.2585948 -6.1677785]
# [-0.8517054  0.5240209 -5.7999573]
# [-0.67108333  0.74138194 -5.6712427 ]
# [-0.4699782   0.88267803 -4.928059  ]
# [-0.2697451   0.96293175 -4.3227553 ]
# [-0.09525969  0.99545246 -3.5544796 ]
# [ 0.05198042  0.9986481  -2.9481642 ]
# [ 0.16819543  0.98575366 -2.3398974 ]
# [ 0.23285119  0.97251236 -1.3201942 ]
# [ 0.27175504  0.96236646 -0.8041559 ]
# [ 0.27258915  0.96213055 -0.0173366 ]
# [0.23730783 0.9714345  0.7297898 ]
# [0.17417678 0.9847144  1.2904774 ]
# [0.06705921 0.997749   2.1592026 ]
# [-0.07542388  0.99715155  2.852103  ]
# [-0.25367814  0.9672887   3.6197066 ]
# [-0.4596631   0.88809335  4.422698  ]
# [-0.67702496  0.73596007  5.3219376 ]
# [-0.85647357  0.5161908   5.693723  ]
# [-0.96974266  0.2441294   5.915513  ]
# [-0.99801224 -0.06301998  6.1936717 ]
# [-0.92731446 -0.37428316  6.4112377 ]
# [-0.77025884 -0.63773143  6.158516  ]
# [-0.5612818  -0.82762474  5.6662626 ]
# [-0.34981745 -0.9368179   4.77115   ]
# [-0.16190638 -0.9868061   3.8950806 ]
# [ 0.00667993 -0.9999777   3.3860438 ]
# [ 0.13864982 -0.9903415   2.648359  ]
# [ 0.22062428 -0.97535884  1.6671308 ]
# [ 0.27200034 -0.96229714  1.0603331 ]
# [ 0.29891783 -0.9542788   0.5617461 ]
# [ 0.30267212 -0.9530947   0.07873166]
# [ 0.2703809 -0.9627534 -0.674127 ]
# [ 0.19797906 -0.98020625 -1.4898584 ]
# [ 0.07661498 -0.9970608  -2.4521122 ]
# [-0.06949162 -0.99758255 -2.9247563 ]
# [-0.26387307 -0.9645574  -3.9497547 ]
# [-0.4915479 -0.8708505 -4.9366183]
# [-0.7063623 -0.7078505 -5.40959  ]
# [-0.883106  -0.4691735 -5.9619174]
# [-0.9847046 -0.1742321 -6.2645745]
# [-0.9908219   0.13517362 -6.2142916 ]
# [-0.89821464  0.4395571  -6.3903365 ]
# [-0.72880226  0.6847242  -5.982394  ]
# [-0.5260929   0.85042715 -5.251428  ]
# [-0.30436042  0.95255697 -4.894655  ]
# [-0.09982336  0.9950052  -4.1855407 ]
# [ 0.06115889  0.99812806 -3.2237396 ]
# [ 0.18730547  0.9823017  -2.5444252 ]
# [ 0.28074825  0.95978147 -1.9231054 ]
# [ 0.3512242  0.9362914 -1.4860934]
# [ 0.37799847  0.9258062  -0.5751024 ]
# [ 0.38554984  0.922687   -0.16340527]
# [0.3686462  0.9295698  0.36502907]
# [0.30698493 0.9517144  1.3105772 ]
# In episode 9
# [0.20275265 0.97923    2.1571045 ]
# [0.05277825 0.99860626 3.027307  ]
# [-0.12572148  0.99206555  3.5771568 ]
# [-0.33384767  0.942627    4.286549  ]
# [-0.55169845  0.8340437   4.8803353 ]
# [-0.7658601  0.6430073  5.759571 ]
# [-0.92737573  0.3741313   6.299173  ]
# [-0.9979281   0.06433966  6.3815145 ]
# [-0.9636067 -0.267324   6.6999803]
# [-0.8353207 -0.5497629  6.2293105]
# [-0.6462161  -0.76315445  5.7220035 ]
# [-0.43380943 -0.9010047   5.0779853 ]
# [-0.21275637 -0.97710526  4.6864285 ]
# [-0.01245611 -0.9999224   4.0387726 ]
# [ 0.1458454 -0.9893074  3.176478 ]
# [ 0.25684008 -0.9664539   2.2676744 ]
# [ 0.3410747 -0.9400362  1.7661749]
# [ 0.39104456 -0.9203718   1.0741264 ]
# [ 0.4220521  -0.90657157  0.67882884]
# [ 0.42772886 -0.90390706  0.12542057]
# [ 0.40500134 -0.9143161  -0.49996823]
# [ 0.34999257 -0.9367525  -1.1883423 ]
# [ 0.2659994  -0.96397316 -1.7664531 ]
# [ 0.1575085  -0.98751765 -2.2214673 ]
# [ 0.01697282 -0.99985594 -2.8238707 ]
# [-0.15843391 -0.9873696  -3.5215592 ]
# [-0.3557014  -0.93459964 -4.091202  ]
# [-0.574716   -0.81835294 -4.971853  ]
# [-0.7865518 -0.6175243 -5.8589597]
# [-0.93440074 -0.35622355 -6.0273623 ]
# [-0.9986487  -0.05196879 -6.24462   ]
# [-0.9624683   0.27139407 -6.5366673 ]
# [-0.82520384  0.5648351  -6.5078444 ]
# [-0.6168789   0.78705806 -6.1158385 ]
# [-0.3757647   0.92671514 -5.5909843 ]
# [-0.12960912  0.99156517 -5.1049404 ]
# [ 0.08791579  0.9961279  -4.360084  ]
# [ 0.26064485  0.96543473 -3.513213  ]
# [ 0.38807184  0.92162913 -2.696969  ]
# [ 0.48850387  0.87256175 -2.2367153 ]
# [ 0.5632037  0.8263181 -1.7576698]
# [ 0.61051106  0.7920077  -1.168959  ]
# [ 0.6406853  0.7678036 -0.7736948]
# [ 0.6415925  0.7670457 -0.0236423]
# [0.62290025 0.7823013  0.48256087]
# [0.57607013 0.8174003  1.1706362 ]
# [0.5029465  0.86431754 1.7381661 ]
# [0.39772266 0.9175057  2.3594208 ]
# [0.26007795 0.9655876  2.9186094 ]
# [0.0673915 0.9977266 3.913206 ]
# [-0.17213768  0.9850729   4.808839  ]
# [-0.43069285  0.90249854  5.4452205 ]
# [-0.6787606  0.7343596  6.016265 ]
# [-0.8762954  0.4817742  6.440889 ]
# [-0.9890714   0.14743732  7.0940304 ]
# [-0.9786765  -0.20540777  7.097142  ]
# [-0.84923   -0.5280231  6.987813 ]
# [-0.63766825 -0.7703111   6.4611583 ]
# [-0.3787163 -0.9255128  6.0611706]
# [-0.11736016 -0.99308944  5.4155526 ]
# [ 0.1288753  -0.99166083  4.9373198 ]
# [ 0.3268422 -0.9450789  4.0745115]
# [ 0.49350283 -0.8697442   3.6630452 ]
# [ 0.6241356  -0.78131604  3.1582425 ]
# [ 0.7197982  -0.69418335  2.5897384 ]
# [ 0.7932208 -0.6089341  2.2513707]
# [ 0.84269834 -0.538386    1.72391   ]
# [ 0.880563   -0.47392908  1.4954646 ]
# [ 0.9004901  -0.43487644  0.87692773]
# [ 0.9123549 -0.4094002  0.5620906]
# [ 0.91664004 -0.39971367  0.21184157]
# [ 0.91562015 -0.4020445  -0.05088456]
# [ 0.9049503  -0.4255173  -0.51569474]
# [ 0.89281213 -0.4504293  -0.5542537 ]
# [ 0.8758886  -0.48251346 -0.725519  ]
# [ 0.8517467 -0.5239538 -0.9592859]
# [ 0.82138747 -0.5703706  -1.1094123 ]
# [ 0.7816067 -0.6237716 -1.332039 ]
# [ 0.7152675  -0.69885075 -2.0046122 ]
# [ 0.6219187 -0.7830818 -2.5163255]
# [ 0.48451918 -0.87478065 -3.3075414 ]
# [ 0.31650993 -0.9485892  -3.675309  ]
# [ 0.09317181 -0.99565005 -4.574817  ]
# [-0.1603828 -0.9870549 -5.0877123]
# [-0.44663876 -0.89471436 -6.038531  ]
# [-0.72322226 -0.69061536 -6.9090347 ]
# [-0.92157376 -0.3882033  -7.273168  ]
# [-0.9999252  -0.01223283 -7.728961  ]
# [-0.9336566   0.35816953 -7.570795  ]
# [-0.74178964  0.6706326  -7.3750935 ]
# [-0.47185522  0.881676   -6.8868246 ]
# [-0.17586653  0.98441404 -6.292157  ]
# [ 0.08999828  0.99594194 -5.3381233 ]
# [ 0.31349966  0.9495883  -4.575121  ]
# [ 0.49193177  0.8706338  -3.9086185 ]
# [ 0.63051856  0.7761741  -3.3582795 ]
# [ 0.7364616  0.6764794 -2.912071 ]
# [ 0.80700856  0.59053975 -2.2248821 ]
# [ 0.8491931   0.52808243 -1.5077326 ]
# [ 0.8786466   0.47747263 -1.1712968 ]
# In episode 10
# [ 0.89521706  0.4456304  -0.7179541 ]
# [ 0.89728     0.44146192 -0.09302045]
# [0.88826776 0.45932606 0.40018034]
# [0.8714165  0.4905438  0.70954764]
# [0.8488429  0.52864516 0.88579863]
# [0.8135376  0.58151233 1.2716562 ]
# [0.7671602 0.6414556 1.5161538]
# [0.70167863 0.7124936  1.933029  ]
# [0.5976642  0.80174655 2.7433243 ]
# [0.44518495 0.8954386  3.5840743 ]
# [0.2345809 0.9720966 4.491868 ]
# [-0.02103339  0.99977875  5.156447  ]
# [-0.31616604  0.9487039   6.013011  ]
# [-0.61855596  0.78574073  6.9043617 ]
# [-0.86446005  0.5027016   7.543433  ]
# [-0.98966223  0.143418    7.6561365 ]
# [-0.96960664 -0.24466914  7.821854  ]
# [-0.80945706 -0.58717906  7.6078205 ]
# [-0.5529159  -0.83323705  7.147344  ]
# [-0.26785564 -0.9634591   6.29386   ]
# [ 0.01371928 -0.9999059   5.697727  ]
# [ 0.25184524 -0.96776754  4.8173356 ]
# [ 0.44401705 -0.8960183   4.109809  ]
# [ 0.5865614 -0.8099048  3.3345926]
# [ 0.6957869 -0.7182483  2.854167 ]
# [ 0.7818015 -0.6235274  2.5606987]
# [ 0.8428689  -0.53811896  2.1008534 ]
# [ 0.89030874 -0.45535743  1.9086034 ]
# [ 0.92789984 -0.37282956  1.8143415 ]
# [ 0.95690376 -0.2904052   1.7481261 ]
# [ 0.9764136  -0.21590836  1.5405644 ]
# [ 0.9896322  -0.14362511  1.4699702 ]
# [ 0.99812585 -0.06119461  1.6578134 ]
# [0.99959433 0.02848209 1.794376  ]
# [0.9921867  0.12476196 1.9320395 ]
# [0.97200316 0.23496778 2.2419503 ]
# [0.93236285 0.36152387 2.6543272 ]
# [0.8660679 0.4999264 3.0722396]
# [0.77540797 0.6314606  3.1984336 ]
# [0.65353686 0.7568947  3.5022597 ]
# [0.4779858  0.87836754 4.2777543 ]
# [0.26333043 0.9647057  4.6377463 ]
# [-0.00744049  0.99997234  5.478268  ]
# [-0.31967095  0.9475286   6.3588324 ]
# [-0.6353255   0.77224445  7.260956  ]
# [-0.8848429   0.46588954  7.9545336 ]
# [-0.9964202   0.08453865  8.        ]
# [-0.95068467 -0.31015906  8.        ]
# [-0.75485694 -0.65588945  8.        ]
# [-0.44859686 -0.8937342   7.8048253 ]
# [-0.094208   -0.99555254  7.4169364 ]
# [ 0.2389185  -0.97103965  6.711997  ]
# [ 0.517885  -0.8554502  6.062496 ]
# [ 0.72936594 -0.68412375  5.460358  ]
# [ 0.8687857  -0.49518833  4.7070017 ]
# [ 0.9557464 -0.2941918  4.388836 ]
# [ 0.99596727 -0.08971745  4.1754313 ]
# [0.9945785  0.10398842 3.8803    ]
# [0.95175356 0.30686337 4.1543775 ]
# [0.8586247 0.5126047 4.5264006]
# [0.7031072 0.7110839 5.056458 ]
# [0.48004588 0.8772434  5.5810146 ]
# [0.19613868 0.98057616 6.065769  ]
# [-0.143528    0.98964626  6.8288794 ]
# [-0.51087356  0.85965586  7.8435054 ]
# [-0.8053115   0.59285194  8.        ]
# [-0.9726084   0.23244973  8.        ]
# [-0.98635185 -0.16465119  8.        ]
# [-0.8462902 -0.5327222  7.9281907]
# [-0.5981982 -0.8013482  7.354634 ]
# [-0.29234245 -0.95631367  6.8915067 ]
# [ 5.595270e-03 -9.999843e-01  6.045414e+00]
# [ 0.26771092 -0.9634993   5.308423  ]
# [ 0.46834558 -0.8835454   4.328018  ]
# [ 0.6201252 -0.7845029  3.6296973]
# [ 0.7333973 -0.6798003  3.0880766]
# [ 0.80692184 -0.59065825  2.312318  ]
# [ 0.85728747 -0.5148381   1.8211122 ]
# [ 0.8974474  -0.44112152  1.679416  ]
# [ 0.9275831  -0.37361696  1.4788531 ]
# [ 0.94460183 -0.32821846  0.9697674 ]
# [ 0.96003115 -0.27989325  1.0146804 ]
# [ 0.97292686 -0.2311132   1.0092243 ]
# [ 0.98228383 -0.18739925  0.89415747]
# [ 0.99016196 -0.13992599  0.96254313]
# [ 0.99543923 -0.09539759  0.89687574]
# [ 0.9980807  -0.0619269   0.67152673]
# [ 0.9991044  -0.04231393  0.39279962]
# [ 0.99925053 -0.03870903  0.07215732]
# [ 0.9992814  -0.03790365  0.01611941]
# [ 0.99906874 -0.04314739 -0.10496111]
# [ 0.9992109  -0.03971838  0.0686391 ]
# [ 0.9992828  -0.0378678   0.03703939]
# [ 0.99869937 -0.05098605 -0.26262614]
# [ 0.9968688  -0.07907342 -0.5629578 ]
# [ 0.9941848  -0.10768767 -0.5748169 ]
# [ 0.99120337 -0.1323477  -0.49680483]
# [ 0.98737144 -0.15842225 -0.5271074 ]
# [ 0.98024493 -0.19778755 -0.80015725]
# [ 0.967653   -0.25228506 -1.1188118 ]
# In episode 11
# [ 0.9461887 -0.3236154 -1.4901413]
# [ 0.9122906  -0.40954348 -1.8481115 ]
# [ 0.86705923 -0.49820504 -1.9914749 ]
# [ 0.7986811 -0.6017545 -2.483374 ]
# [ 0.7090603 -0.7051478 -2.738711 ]
# [ 0.5757262 -0.8176425 -3.4934528]
# [ 0.40435776 -0.9146009  -3.9443111 ]
# [ 0.19823338 -0.9801549  -4.3344264 ]
# [-0.05406312 -0.99853754 -5.0728936 ]
# [-0.3419736  -0.93970954 -5.8985367 ]
# [-0.6348898  -0.77260274 -6.7769904 ]
# [-0.8675037  -0.49743074 -7.245918  ]
# [-0.99196935 -0.1264785  -7.8763285 ]
# [-0.9629173   0.26979667 -8.        ]
# [-0.7818418   0.62347686 -8.        ]
# [-0.48891395  0.87233204 -7.735403  ]
# [-0.15315036  0.98820287 -7.1417775 ]
# [ 0.17358772  0.9848184  -6.56454   ]
# [ 0.46030274  0.887762   -6.077293  ]
# [ 0.67335945  0.7393153  -5.2081447 ]
# [ 0.8196727  0.5728321 -4.4419208]
# [ 0.9175956   0.39751518 -4.022992  ]
# [ 0.97285074  0.23143335 -3.5051298 ]
# [ 0.99789274  0.06488509 -3.3724012 ]
# [ 0.99606806 -0.08859151 -3.07277   ]
# [ 0.96865225 -0.24842069 -3.2468338 ]
# [ 0.90768164 -0.4196594  -3.6404114 ]
# [ 0.80040586 -0.59945846 -4.195086  ]
# [ 0.6391387 -0.7690915 -4.691882 ]
# [ 0.41993353 -0.90755486 -5.200116  ]
# [ 0.13611388 -0.9906932  -5.936687  ]
# [-0.1844229 -0.982847  -6.440448 ]
# [-0.52487934 -0.8511766  -7.341774  ]
# [-0.8088894  -0.58796084 -7.793747  ]
# [-0.9739992  -0.22655146 -8.        ]
# [-0.98533595  0.17062543 -8.        ]
# [-0.8411099   0.54086435 -8.        ]
# [-0.5877172  0.8090665 -7.4219513]
# [-0.27894083  0.9603083  -6.910868  ]
# [ 0.0234014  0.9997262 -6.12189  ]
# [ 0.28301713  0.95911485 -5.270697  ]
# [ 0.49554974  0.86857957 -4.630585  ]
# [ 0.64635307  0.76303846 -3.686552  ]
# [ 0.76635474  0.64241767 -3.407045  ]
# [ 0.8526719  0.5224468 -2.958617 ]
# [ 0.9160997   0.40095046 -2.743277  ]
# [ 0.95660055  0.2914024  -2.3372316 ]
# [ 0.9809774  0.1941219 -2.006606 ]
# [ 0.9950272   0.09960379 -1.9118603 ]
# [ 0.9999022   0.01398602 -1.715655  ]
# [ 0.996892   -0.07878041 -1.8569722 ]
# [ 0.9866394  -0.16291957 -1.6957381 ]
# [ 0.9654325  -0.26065302 -2.0009902 ]
# [ 0.9357703  -0.35261032 -1.9332113 ]
# [ 0.8958018 -0.4444538 -2.0041063]
# [ 0.8307052  -0.55671257 -2.5971735 ]
# [ 0.73120695 -0.6821557  -3.205673  ]
# [ 0.59863704 -0.8010204  -3.565822  ]
# [ 0.41066164 -0.9117878  -4.3723774 ]
# [ 0.15582381 -0.98778486 -5.3343644 ]
# [-0.15101732 -0.9885311  -6.1611743 ]
# [-0.4822975 -0.8760075 -7.0335646]
# [-0.7701964 -0.6378068 -7.51747  ]
# [-0.9559961 -0.2933795 -7.8777466]
# [-0.99477804  0.10206201 -8.        ]
# [-0.8801052   0.47477868 -7.84945   ]
# [-0.65643114  0.75438595 -7.200113  ]
# [-0.36438656  0.9312478  -6.8620834 ]
# [-0.05469104  0.9985033  -6.365113  ]
# [ 0.22603908  0.97411823 -5.6545587 ]
# [ 0.44347635  0.8962861  -4.62928   ]
# [ 0.6151268  0.7884282 -4.0614634]
# [ 0.7485895  0.6630338 -3.6677077]
# [ 0.8418579  0.5396992 -3.0956879]
# [ 0.9110104   0.41238338 -2.9002213 ]
# [ 0.95891553  0.2836918  -2.748536  ]
# [ 0.98657316  0.16331983 -2.4717436 ]
# [ 0.9985975   0.05294357 -2.2217278 ]
# [ 0.9991222  -0.04189108 -1.8974335 ]
# [ 0.9898059  -0.14242305 -2.0201128 ]
# [ 0.96590054 -0.25891346 -2.379763  ]
# [ 0.92960685 -0.36855277 -2.3110917 ]
# [ 0.87986875 -0.47521675 -2.3551726 ]
# [ 0.8027418 -0.5963267 -2.8741405]
# [ 0.6982572  -0.71584696 -3.178379  ]
# [ 0.55212724 -0.83375984 -3.76093   ]
# [ 0.3626935 -0.9319085 -4.2751384]
# [ 0.12480781 -0.99218094 -4.920449  ]
# [-0.14888482 -0.9888545  -5.4914913 ]
# [-0.4428417 -0.8965998 -6.1865044]
# [-0.71908456 -0.69492257 -6.8743696 ]
# [-0.9209123 -0.3897698 -7.358612 ]
# [-0.99975634 -0.0220753  -7.56609   ]
# [-0.9396709   0.34207967 -7.424126  ]
# [-0.7616301   0.64801204 -7.116843  ]
# [-0.50577873  0.86266327 -6.71081   ]
# [-0.22743611  0.973793   -6.0168095 ]
# [ 0.03077393  0.9995264  -5.2044554 ]
# [ 0.2547349  0.9670109 -4.5358953]
# [ 0.43612185  0.8998876  -3.87422   ]
# In episode 12
# [ 0.58098054  0.81391746 -3.3729665 ]
# [ 0.6910604  0.722797  -2.860446 ]
# [ 0.7622798  0.6472476 -2.0774603]
# [ 0.8065036  0.5912292 -1.427721 ]
# [ 0.84143513  0.5403581  -1.2343888 ]
# [ 0.86047953  0.509485   -0.7255288 ]
# [ 0.873259    0.48725635 -0.51282126]
# [0.87075514 0.4917169  0.10230465]
# [0.86088276 0.50880337 0.39467618]
# [0.8345944  0.55086493 0.99212116]
# [0.78665763 0.6173895  1.6403931 ]
# [0.7164046  0.69768506 2.134823  ]
# [0.6258421 0.7799498 2.448491 ]
# [0.50243735 0.8646136  2.9959047 ]
# [0.33688295 0.94154656 3.656222  ]
# [0.12929426 0.9916063  4.278943  ]
# [-0.11963607  0.9928178   4.9916105 ]
# [-0.3960515  0.9182283  5.745788 ]
# [-0.6735751  0.7391188  6.636449 ]
# [-0.8930986  0.449861   7.30303  ]
# [-0.9961611   0.08753872  7.579176  ]
# [-0.95720315 -0.28941688  7.62537   ]
# [-0.7825847  -0.62254405  7.5674357 ]
# [-0.50569475 -0.8627125   7.3723974 ]
# [-0.18298164 -0.9831163   6.9233727 ]
# [ 0.1362494  -0.99067456  6.4138594 ]
# [ 0.40777197 -0.9130838   5.666762  ]
# [ 0.6130593 -0.7900369  4.79829  ]
# [ 0.76597893 -0.6428657   4.2527113 ]
# [ 0.8669445  -0.49840468  3.5295205 ]
# [ 0.9346247 -0.3556356  3.1632712]
# [ 0.9766345  -0.21490699  2.9399495 ]
# [ 0.9973003  -0.07343081  2.8619926 ]
# [0.9976416  0.06863786 2.8437765 ]
# [0.9783344  0.20703076 2.7969425 ]
# [0.942078  0.3353939 2.669687 ]
# [0.88019633 0.4746098  3.0499463 ]
# [0.7778253  0.62848055 3.701551  ]
# [0.62095255 0.78384817 4.4248166 ]
# [0.4096375 0.9122484 4.958013 ]
# [0.1287013 0.9916834 5.8599477]
# [-0.19533883  0.98073584  6.513244  ]
# [-0.5221041  0.8528818  7.0542636]
# [-0.79543895  0.60603374  7.4083085 ]
# [-0.96783    0.2516051  7.934529 ]
# [-0.9894101  -0.14514711  8.        ]
# [-0.8595655 -0.5110256  7.8143177]
# [-0.6069479  -0.79474163  7.6440845 ]
# [-0.30425856 -0.9525895   6.8610916 ]
# [-0.00615499 -0.99998105  6.060099  ]
# [ 0.25552076 -0.96680355  5.290827  ]
# [ 0.47713748 -0.87882864  4.780166  ]
# [ 0.64764625 -0.76194113  4.1419325 ]
# [ 0.7684299 -0.639934   3.437854 ]
# [ 0.8495093  -0.52757365  2.773411  ]
# [ 0.909491  -0.4157236  2.5400715]
# [ 0.94835895 -0.31719917  2.1192715 ]
# [ 0.97123975 -0.23810375  1.647234  ]
# [ 0.9844673  -0.17556795  1.2786064 ]
# [ 0.9943557  -0.10609808  1.4036901 ]
# [ 0.9990438  -0.04371975  1.2512891 ]
# [0.99960387 0.02814365 1.4376214 ]
# [0.9939195 0.1101094 1.6437149]
# [0.9799157 0.1994124 1.8085026]
# [0.9556217 0.2945965 1.9654998]
# [0.91608936 0.40097424 2.2709367 ]
# [0.8597573 0.5107028 2.4684389]
# [0.7810705  0.62444293 2.7683213 ]
# [0.6650861 0.7467667 3.3753824]
# [0.5115077 0.8592787 3.8134127]
# [0.30125394 0.95354396 4.6186213 ]
# [0.03472601 0.99939686 5.425489  ]
# ...
# [-0.9902963   0.13897222  7.6476026 ]
# [-0.96634734 -0.25724074  7.991785  ]
# [-0.80125576 -0.598322    7.6247888 ]
# [-0.5397219  -0.84184337  7.1856875 ]
# [-0.2392641  -0.97095454  6.5699773 ]
# [ 0.03930118 -0.9992274   5.6183834 ]
# [ 0.2692323 -0.9630753  4.6656904]
# [ 0.44453886 -0.8957596   3.7612715 ]
# [ 0.5749919 -0.8181591  3.0386965]
# [ 0.6606061 -0.7507327  2.1806312]
# [ 0.71422917 -0.6999119   1.4779279 ]
# [ 0.73945725 -0.6732035   0.73483235]
# [ 0.7560369  -0.65452904  0.49946094]
# [ 0.75486666 -0.65587825 -0.03572007]
# [ 0.7339097  -0.679247   -0.62781245]
# [ 0.7033518  -0.7108419  -0.87916714]
# [ 0.6546686 -0.755916  -1.3271537]
# [ 0.57643205 -0.81714505 -1.9877715 ]
# [ 0.46798658 -0.8837356  -2.54689   ]
# [ 0.32566825 -0.9454841  -3.1058533 ]
# [ 0.15474002 -0.9879552  -3.5270822 ]
# [-0.06221367 -0.99806285 -4.3523636 ]
# [-0.3113902  -0.95028216 -5.0880346 ]
# [-0.58043665 -0.8143054  -6.0521836 ]
# [-0.8226819  -0.56850195 -6.9369555 ]
# [-0.9719023  -0.23538454 -7.341391  ]
# [-0.9920467   0.12587021 -7.2763834 ]
# [-0.8879144  0.4600087 -7.0360007]
# In episode 16
# [-0.687506    0.72617865 -6.6948447 ]
# [-0.4484938   0.89378595 -5.859393  ]
# [-0.2087955   0.97795933 -5.0947256 ]
# [ 0.02005906  0.9997988  -4.6080713 ]
# [ 0.20016985  0.9797612  -3.6294174 ]
# [ 0.33690426  0.94153893 -2.8419144 ]
# [ 0.44136086  0.8973297  -2.2697537 ]
# [ 0.50905555  0.8607336  -1.5394503 ]
# [ 0.54529864  0.8382419  -0.85316235]
# [ 0.5656825   0.8246231  -0.49030703]
# [ 0.5669284   0.8237671  -0.03023215]
# [0.5542807 0.8323298 0.3054749]
# [0.50598973 0.86253947 1.1393893 ]
# [0.42328614 0.905996   1.8691941 ]
# [0.297161   0.95482737 2.7070277 ]
# [0.13551462 0.99077535 3.3157024 ]
# [-0.06929331  0.9975963   4.1056347 ]
# [-0.31431103  0.9493201   5.0076385 ]
# [-0.5756263   0.81771284  5.8727818 ]
# [-0.8111266  0.5848706  6.6541185]
# [-0.967492    0.25290173  7.3808436 ]
# [-0.9915401  -0.12980095  7.716931  ]
# [-0.8657633 -0.5004537  7.8790913]
# [-0.62827766 -0.7779892   7.346723  ]
# [-0.33610567 -0.94182426  6.7311687 ]
# [-0.03145179 -0.9995053   6.2264395 ]
# [ 0.2506607 -0.968075   5.696393 ]
# [ 0.48159343 -0.87639475  4.982186  ]
# [ 0.6594    -0.7517923  4.350968 ]
# [ 0.78777176 -0.6159672   3.7432556 ]
# [ 0.8809851  -0.47314405  3.4151404 ]
# [ 0.94078964 -0.338991    2.9402397 ]
# [ 0.97548884 -0.22004896  2.4795904 ]
# [ 0.99360037 -0.11295286  2.1734047 ]
# [0.99998397 0.00566294 2.377148  ]
# [0.9925579 0.1217737 2.3282743]
# [0.9675554  0.25265893 2.6670134 ]
# [0.9229727 0.3848655 2.7926946]
# [0.8502933 0.5263092 3.1838396]
# [0.7345697 0.6785332 3.8301976]
# [0.56341314 0.8261753  4.530422  ]
# [0.34366104 0.93909377 4.9539733 ]
# [0.07239557 0.997376   5.567073  ]
# [-0.23398767  0.97223955  6.1727233 ]
# [-0.5558428   0.83128744  7.0639853 ]
# [-0.82312864  0.5678549   7.5504475 ]
# [-0.9768328   0.21400377  7.7645125 ]
# [-0.98507905 -0.17210259  7.7727113 ]
# [-0.84858036 -0.5290665   7.6907277 ]
# [-0.61348605 -0.7897056   7.0565763 ]
# [-0.32542276 -0.9455686   6.580172  ]
# [-0.0297391 -0.9995577  6.0343065]
# [ 0.24054876 -0.9706371   5.453493  ]
# [ 0.44897547 -0.8935441   4.4537454 ]
# [ 0.5974158 -0.8019317  3.4931262]
# [ 0.7136958 -0.7004558  3.0897133]
# [ 0.7997371 -0.6003504  2.6419353]
# [ 0.8611193  -0.50840294  2.2122004 ]
# [ 0.90139407 -0.43299967  1.7102244 ]
# [ 0.92904633 -0.36996335  1.3769671 ]
# [ 0.94423485 -0.3292727   0.86872745]
# [ 0.9561478  -0.29288468  0.76581526]
# [ 0.96741337 -0.25320223  0.8250704 ]
# [ 0.97508746 -0.22182068  0.64615303]
# [ 0.97851056 -0.2061966   0.31989685]
# [ 0.98178035 -0.1900193   0.33009252]
# [ 0.98529387 -0.17086843  0.38941616]
# [ 0.9872716  -0.1590432   0.23979124]
# [ 0.9886043  -0.15053727  0.17219462]
# [ 0.98942184 -0.14506696  0.11062103]
# [ 0.99017286 -0.13984893  0.1054361 ]
# [ 0.9921274 -0.1252326  0.2949313]
# [ 0.9947881  -0.10196386  0.46841812]
# [ 0.99629027 -0.08605607  0.3195747 ]
# [ 0.9963588  -0.08525936  0.01599295]
# [ 0.99720144 -0.07476152  0.21063319]
# [ 0.9969713  -0.0777699  -0.06034349]
# [ 0.9960654  -0.08862114 -0.21778086]
# [ 0.9959119  -0.0903296  -0.03430684]
# [ 0.99559754 -0.09373123 -0.06832256]
# [ 0.99385315 -0.11070663 -0.34130004]
# [ 0.9915029  -0.13008493 -0.3904122 ]
# [ 0.98576313 -0.16814005 -0.76975846]
# [ 0.9794803  -0.20153973 -0.6797418 ]
# [ 0.9737435  -0.22764789 -0.53463626]
# [ 0.96528655 -0.2611931  -0.69193095]
# [ 0.9547708  -0.29734272 -0.7530057 ]
# [ 0.9362591  -0.35131028 -1.1412388 ]
# [ 0.9066048  -0.42198062 -1.5331724 ]
# [ 0.8695508 -0.4938435 -1.6175096]
# [ 0.80776155 -0.58950937 -2.2789388 ]
# [ 0.73020184 -0.6832315  -2.4345543 ]
# [ 0.6239653  -0.78145206 -2.8962114 ]
# [ 0.4734561 -0.8808174 -3.6119268]
# [ 0.27934936 -0.9601895  -4.20188   ]
# [ 0.04012407 -0.9991947  -4.8596315 ]
# [-0.23311503 -0.9724492  -5.5082917 ]
# [-0.527473  -0.8495718 -6.4068713]
# [-0.7854833 -0.6188829 -6.9570665]
# [-0.9577952  -0.28745154 -7.515094  ]
# In episode 17
# [-0.99669254  0.08126517 -7.4583974 ]
# [-0.89354527  0.4489731  -7.685218  ]
# [-0.6731855   0.73947364 -7.3334465 ]
# [-0.39898762  0.9169563  -6.561914  ]
# [-0.11118191  0.99380004 -5.9800053 ]
# [ 0.16427019  0.9864154  -5.5286074 ]
# [ 0.40253505  0.91540456 -4.9853277 ]
# [ 0.5800508   0.81458026 -4.090132  ]
# [ 0.70488095  0.7093256  -3.2692847 ]
# [ 0.7957975  0.6055628 -2.7613614]
# [ 0.8664234   0.49930993 -2.5534155 ]
# [ 0.9105266   0.41345054 -1.9312344 ]
# [ 0.93889177  0.34421256 -1.496809  ]
# [ 0.9610904   0.27623403 -1.4305305 ]
# [ 0.9741958   0.22570457 -1.044145  ]
# [ 0.9842228   0.17693332 -0.9959293 ]
# [ 0.9892517   0.14622304 -0.622411  ]
# [ 0.9923289   0.12362598 -0.4561224 ]
# [ 0.99578553  0.09171262 -0.64202774]
# [ 0.9981951   0.06005426 -0.63502514]
# [ 0.9998416   0.01779836 -0.84582233]
# [ 0.99972993 -0.02323859 -0.82079965]
# [ 0.9987234  -0.05051317 -0.54588   ]
# [ 0.9960328  -0.08898705 -0.77140474]
# [ 0.9904627  -0.13778117 -0.9823191 ]
# [ 0.9801357  -0.19832803 -1.228618  ]
# [ 0.96479297 -0.2630105  -1.3297896 ]
# [ 0.9375744  -0.34778476 -1.7813213 ]
# [ 0.89902085 -0.43790588 -1.9612137 ]
# [ 0.84723073 -0.53122514 -2.1355588 ]
# [ 0.7702469  -0.63774574 -2.6304424 ]
# [ 0.67040664 -0.7419939  -2.889432  ]
# [ 0.5216512  -0.85315883 -3.7194295 ]
# [ 0.31163284 -0.9502026  -4.6374846 ]
# [ 0.04935633 -0.9987812  -5.3506913 ]
# [-0.24542862 -0.96941465 -5.946764  ]
# [-0.55527455 -0.8316671  -6.8146243 ]
# [-0.8124593  -0.58301795 -7.1932983 ]
# [-0.9727559  -0.23183164 -7.769563  ]
# [-0.9865076   0.16371542 -7.9683185 ]
# [-0.8551215   0.51842767 -7.6111097 ]
# [-0.61346775  0.78971976 -7.3068166 ]
# [-0.3066726   0.95181507 -6.974982  ]
# [ 0.00904938  0.99995905 -6.414894  ]
# [ 0.27485183  0.9614866  -5.387722  ]
# [ 0.47852135  0.8780759  -4.410688  ]
# [ 0.6300205   0.77657855 -3.6521919 ]
# [ 0.75121367  0.6600591  -3.366387  ]
# [ 0.8380034  0.545665  -2.8742983]
# [ 0.89374495  0.44857553 -2.2402325 ]
# [ 0.9271623   0.37465996 -1.6228174 ]
# [ 0.9468188   0.32176718 -1.1286933 ]
# [ 0.9631541   0.26895013 -1.1058496 ]
# [ 0.9719075   0.23536325 -0.694211  ]
# [ 0.97595936  0.21795247 -0.3575256 ]
# [ 0.98010314  0.19848879 -0.39800477]
# [ 0.98222536  0.18770546 -0.2198045 ]
# [ 0.9824253   0.18665628 -0.02136097]
# [0.98198557 0.18895596 0.0468269 ]
# [ 0.9823473   0.18706624 -0.03848082]
# [0.97880316 0.20480324 0.36175743]
# [0.97004807 0.24291292 0.78209805]
# [0.9538753  0.30020303 1.1907581 ]
# [0.9336861 0.3580926 1.2263749]
# [0.91032994 0.41388327 1.2098299 ]
# [0.8814795  0.47222224 1.3018878 ]
# [0.8391941 0.543832  1.6637319]
# [0.77712655 0.62934434 2.1142502 ]
# [0.6825777  0.73081297 2.7760603 ]
# [0.55860007 0.82943714 3.1717412 ]
# [0.3941023  0.91906655 3.7521224 ]
# [0.18785524 0.98219675 4.322257  ]
# [-0.05531411  0.998469    4.8864083 ]
# [-0.34463516  0.93873674  5.930155  ]
# [-0.6412277  0.7673507  6.8849406]
# [-0.87464035  0.48477238  7.371926  ]
# [-0.9926666   0.12088452  7.69844   ]
# [-0.9672511  -0.25382134  7.5561967 ]
# [-0.8194309 -0.573178   7.0749993]
# [-0.5771627 -0.8166292  6.9033484]
# [-0.2973931 -0.9547551  6.2657785]
# [-0.02278906 -0.9997403   5.5834007 ]
# [ 0.2225513 -0.974921   4.944433 ]
# [ 0.4125042 -0.9109557  4.015414 ]
# [ 0.55484504 -0.8319537   3.2595067 ]
# [ 0.6694184  -0.74288565  2.9049778 ]
# [ 0.7564152 -0.6540918  2.4877892]
# [ 0.82370925 -0.56701237  2.2021403 ]
# [ 0.87794113 -0.4787686   2.0724547 ]
# [ 0.9163144  -0.40045956  1.7446648 ]
# [ 0.9453046  -0.32618904  1.5949802 ]
# [ 0.9614801  -0.27487463  1.0761995 ]
# [ 0.97167736 -0.23631151  0.7978245 ]
# [ 0.9785377  -0.20606785  0.62026477]
# [ 0.98188597 -0.18947294  0.3385904 ]
# [ 0.9828462  -0.18442704  0.10272942]
# [ 0.9802235  -0.19789368 -0.2743956 ]
# [ 0.97348076 -0.2287689  -0.63208437]
# [ 0.9672954  -0.2536525  -0.51283056]
# [ 0.95790476 -0.28708625 -0.69458514]
# In episode 18
# [ 0.9449701  -0.32715687 -0.8421931 ]
# [ 0.92344964 -0.3837197  -1.210554  ]
# [ 0.8919421 -0.4521497 -1.5070598]
# [ 0.85370237 -0.5207612  -1.5713673 ]
# [ 0.7945707  -0.60717165 -2.095075  ]
# [ 0.7030867  -0.71110415 -2.771426  ]
# [ 0.57506543 -0.8181074  -3.3408957 ]
# [ 0.4034729 -0.9149916 -3.9474983]
# [ 0.19355153 -0.9810901  -4.4105678 ]
# [-0.07167768 -0.9974278  -5.330401  ]
# [-0.3717674 -0.9283259 -6.183459 ]
# [-0.66035634 -0.7509524  -6.8076205 ]
# [-0.8821172 -0.47103   -7.180902 ]
# [-0.99442786 -0.10541951 -7.696846  ]
# [-0.956981    0.29015064 -8.        ]
# [-0.7766997  0.6298711 -7.7400594]
# [-0.5049229  0.8631644 -7.202328 ]
# [-0.19129439  0.9815327  -6.73624   ]
# [ 0.10758705  0.99419564 -6.005528  ]
# [ 0.36425874  0.9312978  -5.300821  ]
# [ 0.5661578  0.8242969 -4.580009 ]
# [ 0.71402913  0.700116   -3.867984  ]
# [ 0.8232196  0.5677231 -3.4364517]
# [ 0.8948944   0.44627795 -2.8227112 ]
# [ 0.94645655  0.32283118 -2.6776497 ]
# [ 0.97693235  0.21354902 -2.2702591 ]
# [ 0.994024   0.1091618 -2.1165314]
# [ 0.9999429   0.01068699 -1.9738516 ]
# [ 0.9962206  -0.08685916 -1.9531188 ]
# [ 0.98154235 -0.19124496 -2.109232  ]
# [ 0.94924945 -0.31452414 -2.5504994 ]
# [ 0.9021664 -0.4313881 -2.5215104]
# [ 0.828999  -0.5592501 -2.9490027]
# [ 0.72295105 -0.69089925 -3.3850238 ]
# [ 0.57519996 -0.81801283 -3.9043112 ]
# [ 0.37997425 -0.9249971  -4.4616027 ]
# [ 0.1303556 -0.9914673 -5.1808167]
# [-0.16393179 -0.98647165 -5.9080534 ]
# [-0.4897344  -0.87187165 -6.942201  ]
# [-0.77156717 -0.63614786 -7.390319  ]
# [-0.95372087 -0.30069333 -7.6815147 ]
# [-0.99718255  0.07501315 -7.6100645 ]
# [-0.90343964  0.4287153  -7.359732  ]
# [-0.7094733   0.70473236 -6.77951   ]
# [-0.45315123  0.89143366 -6.3690667 ]
# [-0.1953036  0.9807428 -5.4746037]
# [ 0.05216581  0.99863845 -4.97513   ]
# [ 0.2749075   0.96147066 -4.52608   ]
# [ 0.44527727  0.8953927  -3.659808  ]
# [ 0.56743604  0.8234175  -2.8380961 ]
# [ 0.6465236  0.762894  -1.9926007]
# [ 0.6934004  0.7205525 -1.2635764]
# [ 0.72639954  0.68727267 -0.9374206 ]
# [ 0.738849    0.67387104 -0.36584315]
# [0.7333614  0.67983896 0.16214798]
# [0.71793526 0.69610983 0.4484327 ]
# [0.68839604 0.725335   0.8311258 ]
# [0.63336563 0.7738527  1.4676139 ]
# [0.5593239 0.8289492 1.846495 ]
# [0.44917098 0.8934458  2.5546544 ]
# [0.2893868 0.9572122 3.445021 ]
# [0.08861174 0.9960663  4.097162  ]
# [-0.1632747   0.98658067  5.0547423 ]
# [-0.44694048  0.8945637   5.9866657 ]
# [-0.72078276  0.693161    6.831773  ]
# [-0.9243281   0.38159874  7.486802  ]
# [-0.99994934  0.01006633  7.6291757 ]
# [-0.93522996 -0.3540409   7.439097  ]
# [-0.75141543 -0.65982944  7.174068  ]
# [-0.48772448 -0.8729976   6.8144655 ]
# [-0.21097773 -0.97749084  5.938124  ]
# [ 0.03299436 -0.9994555   4.911509  ]
# [ 0.23837416 -0.9711734   4.153821  ]
# [ 0.3954578  -0.91848415  3.3174968 ]
# [ 0.51212746 -0.8589095   2.6218734 ]
# [ 0.5908249 -0.8067998  1.88842  ]
# [ 0.6434878 -0.7654563  1.3393047]
# [ 0.6662389  -0.7457384   0.60215545]
# [ 0.65998155 -0.75128186 -0.1671947 ]
# [ 0.6341953 -0.7731729 -0.6765374]
# [ 0.5738861  -0.81893516 -1.5144802 ]
# [ 0.47061378 -0.8823393  -2.4251404 ]
# [ 0.3365297  -0.94167286 -2.9351413 ]
# [ 0.15316333 -0.9882009  -3.7892122 ]
# [-0.08436809 -0.9964346  -4.764742  ]
# [-0.34786758 -0.9375437  -5.416543  ]
# [-0.60946226 -0.7928151  -6.0017295 ]
# [-0.8329037 -0.5534179 -6.5790377]
# [-0.9746476  -0.22374566 -7.216129  ]
# [-0.9896933   0.14320317 -7.387061  ]
# [-0.8778914  0.4788597 -7.113163 ]
# [-0.676035   0.7368695 -6.5814514]
# [-0.4190963  0.9079418 -6.1983733]
# [-0.16182935  0.98681873 -5.398112  ]
# [ 0.06029446  0.9981806  -4.4575043 ]
# [ 0.23027413  0.9731258  -3.4405663 ]
# [ 0.34590077  0.9382711  -2.416786  ]
# [ 0.43000373  0.9028271  -1.8259652 ]
# [ 0.46930057  0.8830385  -0.8800321 ]
# [0.4665596  0.8844898  0.06202947]
# In episode 19
# [0.44528955 0.89538664 0.47798866]
# [0.3918592  0.92002517 1.1769216 ]
# [0.30673918 0.9517936  1.8177277 ]
# [0.1887841 0.9820186 2.4368265]
# [0.0221213 0.9997553 3.3560147]
# [-0.19352154  0.981096    4.3374677 ]
# [-0.43326205  0.901268    5.067175  ]
# [-0.6600446  0.7512264  5.455382 ]
# [-0.85187376  0.52374715  5.9734898 ]
# [-0.97582287  0.21856283  6.618046  ]
# [-0.991263   -0.13190046  7.0525475 ]
# [-0.891646   -0.45273325  6.750849  ]
# [-0.69548756 -0.71853817  6.637395  ]
# [-0.460563  -0.887627   5.8093767]
# [-0.21461995 -0.9766976   5.2465334 ]
# [ 0.0125206 -0.9999216  4.5764728]
# [ 0.19135064 -0.9815217   3.6003418 ]
# [ 0.31925255 -0.9476697   2.6480525 ]
# [ 0.4156837  -0.90950924  2.0750744 ]
# [ 0.47305897 -0.88103074  1.2813044 ]
# [ 0.51221615 -0.8588566   0.9000708 ]
# [ 0.52932847 -0.848417    0.40091422]
# [ 0.50993395 -0.8602136  -0.45401728]
# [ 0.4703846  -0.88246155 -0.9076286 ]
# [ 0.41253647 -0.91094106 -1.2897956 ]
# [ 0.32613388 -0.9453236  -1.8605168 ]
# [ 0.20522712 -0.97871435 -2.5103033 ]
# [ 0.04130042 -0.99914676 -3.3076718 ]
# [-0.15250218 -0.9883031  -3.8882349 ]
# [-0.36812663 -0.92977566 -4.477875  ]
# [-0.5824958 -0.8128337 -4.8960495]
# [-0.79052174 -0.61243397 -5.797292  ]
# [-0.941732   -0.33636418 -6.321649  ]
# [-0.99978215 -0.02087252 -6.4435883 ]
# [-0.9509464   0.30935568 -6.7077885 ]
# [-0.80190706  0.5974488  -6.5160108 ]
# [-0.59196305  0.8059651  -5.9397616 ]
# [-0.3656522   0.93075156 -5.1831775 ]
# [-0.1471957  0.9891074 -4.532019 ]
# [ 0.03873122  0.99924964 -3.7294679 ]
# [ 0.17224719  0.9850538  -2.6873918 ]
# [ 0.2601399  0.9655709 -1.801132 ]
# [ 0.30902958  0.9510524  -1.0201081 ]
# [ 0.33744955  0.9413436  -0.600674  ]
# [0.33261773 0.94306177 0.10256393]
# [0.29624394 0.95511234 0.76640695]
# [0.22618362 0.9740847  1.4519935 ]
# [0.12216741 0.9925095  2.1136923 ]
# [-0.01903642  0.9998188   2.8302186 ]
# [-0.19324258  0.981151    3.5085676 ]
# [-0.38641772  0.9223239   4.0455694 ]
# [-0.60229903  0.7982706   4.992671  ]
# [-0.79585016  0.60549366  5.480647  ]
# [-0.9424879   0.33424026  6.1917396 ]
# [-0.99955606  0.02979301  6.2200317 ]
# [-0.95876056 -0.28421503  6.3597    ]
# [-0.8347341 -0.5506533  5.899181 ]
# [-0.64914435 -0.76066524  5.623813  ]
# [-0.4301415  -0.90276146  5.236191  ]
# [-0.21448074 -0.9767282   4.569787  ]
# [-0.02132529 -0.9997726   3.896665  ]
# [ 0.14716227 -0.9891124   3.380512  ]
# [ 0.28312352 -0.95908344  2.787013  ]
# [ 0.36827734 -0.929716    1.8021219 ]
# [ 0.4090715  -0.91250235  0.8856176 ]
# [ 0.43152097 -0.9021029   0.49483615]
# [ 0.41166204 -0.9113366  -0.43802154]
# [ 0.3689004  -0.9294689  -0.92902714]
# [ 0.30403468 -0.952661   -1.3780146 ]
# [ 0.20154095 -0.9794801  -2.1198814 ]
# [ 0.07266746 -0.99735624 -2.6039865 ]
# [-0.08154911 -0.99666935 -3.0874267 ]
# [-0.2783192 -0.9604886 -4.0080795]
# [-0.49500647 -0.8688893  -4.7159705 ]
# [-0.6976297 -0.7164585 -5.0848303]
# [-0.8724167 -0.4887629 -5.7608275]
# [-0.97867703 -0.2054052  -6.0758686 ]
# [-0.9952847   0.09699702 -6.0805497 ]
# [-0.9267147   0.37576562 -5.761461  ]
# [-0.7917536  0.6108406 -5.4379816]
# [-0.611862    0.79096454 -5.1052384 ]
# [-0.42417416  0.90558064 -4.4072556 ]
# [-0.25823894  0.9660811  -3.5370173 ]
# [-0.11989227  0.9927869  -2.82035   ]
# [-0.01918704  0.99981594 -2.019863  ]
# [ 0.04037468  0.9991846  -1.1914774 ]
# [ 0.05652533  0.99840117 -0.3233965 ]
# [0.04741555 0.99887526 0.18244275]
# [-0.00359267  0.99999356  1.0205204 ]
# [-0.09246542  0.9957159   1.7801003 ]
# [-0.21144539  0.9773898   2.4091172 ]
# [-0.37382194  0.9275005   3.4014552 ]
# [-0.54690266  0.83719623  3.9106748 ]
# [-0.7165683  0.6975169  4.404197 ]
# [-0.87070674  0.49180257  5.1553526 ]
# [-0.97480804  0.22304554  5.784424  ]
# [-0.99818945 -0.06014803  5.7024393 ]
# [-0.9373077  -0.34850287  5.91578   ]
# [-0.8062555  -0.59156746  5.5405636 ]
# [-0.64004505 -0.76833737  4.8647575 ]

# %%
# %pip install gymnasium
# %pip install swig
# %pip install gymnasium[box2d]
# %pip install gymnasium[mujoco]

# Create Hopper environment
# https://gymnasium.farama.org/environments/mujoco/hopper/


import gymnasium as gym
env = gym.make("Hopper-v4", render_mode = "rgb_array")
s = env.reset(seed = 34)
print("Observation Space = ")
print(env.observation_space)
print("Action Space = ")
print(env.action_space)
done = False
for episode in range(1):
    print("In episode {}".format(episode))
    for i in range(100):

        print(s)
        a = env.action_space.sample()
        s, r, done, truncated, _ = env.step(a)
        if done:
            print("Finished after {} timestep".format(i+1))
env.close()
# Out:
# Requirement already satisfied: gymnasium in c:\users\hgoel\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: swig in c:\users\hgoel\anaconda3\lib\site-packages (4.4.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium[box2d] in c:\users\hgoel\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d==2.3.10 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[box2d]) (4.4.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium[mujoco] in c:\users\hgoel\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[mujoco]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[mujoco]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[mujoco]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[mujoco]) (0.0.4)
# Requirement already satisfied: mujoco>=2.1.5 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[mujoco]) (3.6.0)
# Requirement already satisfied: imageio>=2.14.1 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[mujoco]) (2.37.2)
# Requirement already satisfied: packaging>=23.0 in c:\users\hgoel\anaconda3\lib\site-packages (from gymnasium[mujoco]) (25.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\hgoel\anaconda3\lib\site-packages (from imageio>=2.14.1->gymnasium[mujoco]) (12.0.0)
# Requirement already satisfied: absl-py in c:\users\hgoel\anaconda3\lib\site-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (2.4.0)
# Requirement already satisfied: etils[epath] in c:\users\hgoel\anaconda3\lib\site-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.14.0)
# Requirement already satisfied: glfw in c:\users\hgoel\anaconda3\lib\site-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (2.10.0)
# Requirement already satisfied: pyopengl in c:\users\hgoel\anaconda3\lib\site-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (3.1.10)
# Requirement already satisfied: fsspec in c:\users\hgoel\anaconda3\lib\site-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (2025.10.0)
# Requirement already satisfied: zipp in c:\users\hgoel\anaconda3\lib\site-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.23.0)
# Note: you may need to restart the kernel to use updated packages.
# Observation Space =
# Box(-inf, inf, (11,), float64)
# Action Space =
# Box(-1.0, 1.0, (3,), float32)
# In episode 0
# (array([ 1.25372177e+00, -2.57257612e-03,  1.51061298e-03, -1.59076170e-04,
#         2.88533494e-03,  3.80722565e-03,  3.99721996e-03,  2.09928936e-04,
#         4.64165624e-03,  4.11351193e-03,  1.77765794e-03]), {})
# [ 1.25337027e+00 -2.01587046e-03  1.61689265e-03  7.42412706e-04
#   5.72013728e-03  2.89840592e-02 -9.06368693e-02  8.20422326e-02
#   2.00327517e-02  1.02162041e-01  7.12847388e-01]
# [ 1.25244161 -0.00159765  0.00179281  0.0013795   0.0062758  -0.00235825
#  -0.14158419  0.02312159  0.0229611   0.06005527 -0.57254135]
# [ 1.25094984e+00 -3.87091655e-03 -6.12840912e-04  1.08902912e-03
#   4.66694494e-03 -3.93748684e-02 -2.31461029e-01 -5.90693075e-01
#  -6.23593860e-01 -1.32486955e-01  1.69409841e-01]
# [ 1.24883653e+00 -5.57242217e-03 -1.44965329e-03 -8.53400356e-04
#   3.38496698e-03 -1.75557550e-02 -2.96812706e-01  1.64357391e-01
#   4.13094752e-01 -3.52803905e-01 -4.89114577e-01]
# [ 1.24614458 -0.00232015  0.00309706 -0.00169913 -0.00162397  0.02519203
#  -0.37562058  0.40669392  0.4248167   0.16548795 -0.75935787]
# [ 1.24275748e+00  4.28438770e-04  4.42116151e-03  2.16557831e-03
#  -5.54688525e-03  3.63428637e-02 -4.67537890e-01  1.41739455e-01
#  -6.07986064e-02  4.41440802e-01 -2.02152060e-01]
# [ 1.23873349e+00  4.69032391e-04  3.28538309e-03  4.58298899e-03
#  -7.87506011e-03  1.08828807e-04 -5.38694804e-01 -1.21516853e-01
#  -2.25253563e-01  1.88482626e-01 -3.81089615e-01]
# [ 1.23405239e+00 -7.56288670e-04  1.45771949e-03  5.37057832e-03
#  -7.77252178e-03  1.70494981e-03 -6.31761542e-01 -1.77539402e-01
#  -2.33330629e-01  2.72123649e-02  4.04739043e-01]
# [ 1.22864959e+00 -1.67385250e-03  2.53743328e-04  5.34306904e-03
#  -2.85624115e-03  1.41671690e-02 -7.18966439e-01 -5.72910732e-02
#  -7.80047833e-02 -2.67912712e-02  8.23576458e-01]
# [ 1.22264297e+00 -3.33751727e-03 -1.64437646e-03  5.04191170e-03
#   1.17203560e-03 -1.86311311e-02 -7.82781273e-01 -3.56912378e-01
#  -3.96474279e-01 -4.50798874e-02  1.84064037e-01]
# [ 1.21597032 -0.00486329 -0.00312321  0.00412985  0.00727392  0.01644507
#  -0.88532273 -0.02498093  0.02627881 -0.18261075  1.33999621]
# [ 1.20917765 -0.00920802 -0.0083829   0.00307624  0.01975354  0.03615497
#  -0.74597804 -1.05913939 -1.35313316 -0.09172869  1.65221238]
# [ 1.20397217e+00 -1.48086606e-02 -1.46374357e-02  2.91799183e-05
#   2.85647589e-02  9.47657948e-02 -5.58343633e-01 -3.40030199e-01
#  -2.08727703e-01 -6.53487123e-01  5.88725366e-01]
# [ 1.20039329 -0.02185292 -0.01896199 -0.00949119  0.03695761  0.0050078
#  -0.34735474 -1.42268258 -0.87291041 -1.73214084  1.49272694]
# [ 1.19844025 -0.02957901 -0.0211013  -0.02378479  0.04546022  0.02039281
#  -0.14967993 -0.50475183  0.33768928 -1.8336122   0.65815716]
# [ 1.19775583 -0.03718556 -0.02413447 -0.03556169  0.04981384  0.00493549
#  -0.02913657 -1.39500299 -1.09415922 -1.11132139  0.43273804]
# [ 1.19778285 -0.04922123 -0.03462848 -0.04375865  0.05520522  0.05632531
#   0.0308058  -1.61499274 -1.52996494 -0.94382022  0.90092007]
# [ 1.19819159 -0.06287752 -0.04695667 -0.0532216   0.0649733   0.07153587
#   0.06968024 -1.79958492 -1.55193594 -1.42058971  1.54184627]
# [ 1.19880880e+00 -8.05379571e-02 -6.07964635e-02 -6.91618677e-02
#   8.13040366e-02  1.12878572e-03  8.12595722e-02 -2.61598614e+00
#  -1.90725178e+00 -2.56180675e+00  2.54172829e+00]
# [ 1.19949822 -0.10085345 -0.07285285 -0.0944277   0.10525341 -0.01010398
#   0.08836404 -2.46301445 -1.10784137 -3.75273231  3.44650476]
# [ 1.20021434 -0.12045125 -0.0807215  -0.12641131  0.13548404  0.01354345
#   0.08870867 -2.43570024 -0.8597719  -4.24274491  4.11205821]
# [ 1.20089791 -0.13805186 -0.08715371 -0.15682885  0.16229239  0.08571744
#   0.07815133 -1.96182211 -0.74743044 -3.35776443  2.60388425]
# [ 1.20157106 -0.15070821 -0.09106322 -0.18184628  0.18493526  0.21651143
#   0.09340632 -1.20275719 -0.23156113 -2.90070149  3.05266762]
# [ 1.20219404 -0.16142864 -0.09513928 -0.20327629  0.2065769   0.22863109
#   0.05963571 -1.47648062 -0.78590813 -2.45400273  2.36454531]
# [ 1.20219871 -0.17976904 -0.10649458 -0.2277251   0.23095395  0.09047714
#  -0.06188981 -3.1083308  -2.05094145 -3.65603716  3.72674087]
# Finished after 26 timestep
# [ 1.20180482 -0.20230274 -0.12262748 -0.2535274   0.26275322  0.24478542
#  -0.03130113 -2.52552519 -1.98418974 -2.80199463  4.21620366]
# Finished after 27 timestep
# [ 1.20159456 -0.22406911 -0.14238894 -0.27326462  0.29923449  0.33401749
#  -0.01888586 -2.91679913 -2.95608966 -2.13758088  4.89813984]
# Finished after 28 timestep
# [ 1.20153652e+00 -2.46837897e-01 -1.67046308e-01 -2.87749807e-01
#   3.36444056e-01  4.16772205e-01  3.58145995e-03 -2.77536939e+00
#  -3.20773603e+00 -1.48325648e+00  4.40778571e+00]
# Finished after 29 timestep
# [ 1.20106457 -0.27479058 -0.19712323 -0.30410885  0.37631299  0.30846853
#  -0.12662143 -4.21179929 -4.30910724 -2.60246862  5.55977306]
# Finished after 30 timestep
# [ 1.1999775  -0.3082589  -0.23276888 -0.32193087  0.41553279  0.35102955
#  -0.14830111 -4.15332728 -4.60087997 -1.84934636  4.25458607]
# Finished after 31 timestep
# [ 1.19821844 -0.34498921 -0.2706511  -0.34158346  0.44440632  0.20392097
#  -0.2951032  -5.02666861 -4.86925679 -3.0623912   2.96476699]
# Finished after 32 timestep
# [ 1.19562182 -0.38409999 -0.31088397 -0.36114836  0.46745537  0.300067
#  -0.34989927 -4.74795603 -5.19128765 -1.83856998  2.79097523]
# Finished after 33 timestep
# [ 1.19262159 -0.42043333 -0.35151399 -0.37370037  0.48648179  0.34778059
#  -0.39882314 -4.33566156 -4.96683083 -1.30060725  1.96698076]
# Finished after 34 timestep
# [ 1.18957129 -0.45035642 -0.38766269 -0.38166233  0.50583701  0.52031597
#  -0.3543498  -3.14759843 -4.07618174 -0.70462328  2.85611764]
# Finished after 35 timestep
# [ 1.18680232 -0.47407891 -0.42090006 -0.38296793  0.5241204   0.60742918
#  -0.33672969 -2.78421509 -4.23346637  0.37556468  1.71494483]
# Finished after 36 timestep
# [ 1.18355947 -0.49847912 -0.45574209 -0.38307308  0.54155991  0.56857974
#  -0.47325918 -3.31705407 -4.4771793  -0.40287633  2.64112829]
# Finished after 37 timestep
# [ 1.17994015 -0.52386886 -0.49294029 -0.38297007  0.56668844  0.74011056
#  -0.42607938 -3.03307697 -4.82540433  0.41689608  3.62782018]
# Finished after 38 timestep
# [ 1.17659773 -0.54889423 -0.53476797 -0.37673129  0.59801656  0.87347774
#  -0.40811418 -3.22475038 -5.63180372  1.13741556  4.19784948]
# Finished after 39 timestep
# [ 1.17300466 -0.57795739 -0.58403913 -0.36718025  0.63132813  0.88960005
#  -0.49389207 -4.04022848 -6.68290635  1.25417057  4.13403475]
# Finished after 40 timestep
# [ 1.16896642 -0.60784194 -0.63143332 -0.36331902  0.66659707  0.86862307
#  -0.51544191 -3.43128185 -5.16695016 -0.28244567  4.68848042]
# Finished after 41 timestep
# [ 1.16534192 -0.63139534 -0.67059731 -0.36312237  0.70758343  1.07770045
#  -0.38638714 -2.457641   -4.62790716  0.32302128  5.54902915]
# Finished after 42 timestep
# [ 1.1618756  -0.65276158 -0.70737793 -0.36400097  0.74961909  1.00094507
#  -0.48457741 -2.88089837 -4.56465776 -0.53383387  4.96956488]
# Finished after 43 timestep
# [ 1.15765272 -0.67751852 -0.74586601 -0.36812106  0.78838878  0.99913315
#  -0.5708868  -3.30798849 -5.0550731  -0.48602247  4.57567214]
# Finished after 44 timestep
# [ 1.15302806 -0.70529964 -0.79029774 -0.36622068  0.8128376   1.03467841
#  -0.59396987 -3.63193673 -6.05031056  0.9500816   1.82108577]
# Finished after 45 timestep
# [ 1.14837734 -0.73223764 -0.83740823 -0.35571758  0.82104491  1.08437102
#  -0.57273011 -3.09875814 -5.72735881  1.66952531  0.39301912]
# Finished after 46 timestep
# [ 1.14314054 -0.76030885 -0.88750498 -0.34083729  0.82099667  1.0619284
#  -0.74111042 -3.91534878 -6.79422014  2.0467266  -0.311506  ]
# Finished after 47 timestep
# [ 1.13715134 -0.78919794 -0.93967708 -0.32303696  0.81734225  1.11075937
#  -0.75767853 -3.3017883  -6.24954426  2.40085582 -0.55744505]
# Finished after 48 timestep
# [ 1.13019408 -0.81905602 -0.99147698 -0.30773273  0.81215809  1.01199496
#  -0.98188665 -4.16374803 -6.69984069  1.42551067 -0.73756282]
# Finished after 49 timestep
# [ 1.1219643  -0.85244423 -1.0472575  -0.29222051  0.80482059  1.07841666
#  -1.07671512 -4.18218115 -7.24373308  2.45184143 -1.09651774]
# Finished after 50 timestep
# [ 1.11264784 -0.88759008 -1.10947646 -0.268047    0.79794376  1.14465061
#  -1.25423671 -4.60229398 -8.30810054  3.59180926 -0.65813132]
# Finished after 51 timestep
# [ 1.10187388 -0.92594686 -1.18062633 -0.23362172  0.79378374  1.22835365
#  -1.44254488 -4.98360784 -9.47537791  5.01446771 -0.40211221]
# Finished after 52 timestep
# [  1.08957341  -0.96690003  -1.25990959  -0.18911889   0.79114615
#    1.29252384  -1.63563738  -5.25143362 -10.           6.11101733
#   -0.26657437]
# Finished after 53 timestep
# [ 1.077095   -1.00259479 -1.33827703 -0.13646969  0.78375118  1.47992119
#  -1.46728878 -3.67009815 -9.26636142  7.02005567 -1.61943657]
# Finished after 54 timestep
# [ 1.06546719 -1.03036233 -1.40743462 -0.08610912  0.76817413  1.42154951
#  -1.43900931 -3.28101416 -8.02308733  5.58361696 -2.25855899]
# Finished after 55 timestep
# [ 1.05407182 -1.0538247  -1.47023889 -0.03986271  0.75155285  1.55822611
#  -1.41006448 -2.58244414 -7.67810019  5.97913082 -1.8980058 ]
# Finished after 56 timestep
# [ 1.04306042e+00 -1.07216088e+00 -1.52628611e+00  2.23588122e-03
#   7.39012250e-01  1.54011926e+00 -1.34389179e+00 -2.05324555e+00
#  -6.32802992e+00  4.45270109e+00 -1.22551965e+00]
# Finished after 57 timestep
# [ 1.03136003 -1.09653884 -1.57840465  0.02586762  0.72808706  1.30936858
#  -1.57202967 -3.91667436 -6.72416245  1.73761575 -1.51673274]
# Finished after 58 timestep
# [ 1.01797065 -1.13340913 -1.63442181  0.03375246  0.71394194  1.18920867
#  -1.77317611 -5.22907568 -7.29030204  0.38687402 -2.0259535 ]
# Finished after 59 timestep
# [ 1.00316857 -1.17831646 -1.6938819   0.03348236  0.69568546  1.13008788
#  -1.92956533 -5.9714812  -7.57610214 -0.41581128 -2.5405601 ]
# Finished after 60 timestep
# [ 0.987812   -1.22264941 -1.75028448  0.0293178   0.68011937  1.17447878
#  -1.90756577 -5.0931446  -6.52891217 -0.588536   -1.35337163]
# Finished after 61 timestep
# [ 0.97286085 -1.25997453 -1.79870069  0.02456134  0.66388096  1.1961395
#  -1.82891486 -4.23126843 -5.57792456 -0.585226   -2.70495615]
# Finished after 62 timestep
# [ 0.95724676 -1.29839776 -1.84623102  0.01664724  0.64448145  1.1392425
#  -2.07509748 -5.37664494 -6.30358121 -1.39321911 -2.14592342]
# Finished after 63 timestep
# [ 0.94021955 -1.34210489 -1.89791914  0.00685892  0.62364836  1.16335573
#  -2.18128347 -5.55134914 -6.61816262 -1.05437231 -3.06122074]
# Finished after 64 timestep
# [ 9.22336828e-01 -1.38724525e+00 -1.95214005e+00 -2.19523788e-04
#   5.96073805e-01  1.19154218e+00 -2.28898542e+00 -5.73488842e+00
#  -6.93673991e+00 -7.15746775e-01 -3.83147677e+00]
# Finished after 65 timestep
# [ 9.03562161e-01 -1.43298587e+00 -2.00955892e+00 -1.87580626e-03
#   5.64348090e-01  1.26829378e+00 -2.40449704e+00 -5.69932421e+00
#  -7.41707141e+00  3.00651277e-01 -4.09950487e+00]
# Finished after 66 timestep
# [ 8.84315711e-01 -1.47545561e+00 -2.06648097e+00  2.02090237e-03
#   5.35286027e-01  1.30685019e+00 -2.40179581e+00 -5.05501023e+00
#  -6.80692563e+00  4.09620950e-01 -3.10598157e+00]
# Finished after 67 timestep
# [ 8.65767319e-01 -1.51576831e+00 -2.12041366e+00  4.26095984e-03
#   5.20173891e-01  1.31203419e+00 -2.25095858e+00 -4.98846818e+00
#  -6.66765941e+00  1.73601812e-01 -7.38926881e-01]
# Finished after 68 timestep
# [ 8.47672396e-01 -1.56254590e+00 -2.17857226e+00  2.30789468e-03
#   5.17294509e-01  1.26564447e+00 -2.27975117e+00 -6.70515176e+00
#  -7.86571906e+00 -6.70530130e-01 -1.22526977e-02]
# Finished after 69 timestep
# [ 8.31017040e-01 -1.61077805e+00 -2.23707372e+00 -1.21697436e-03
#   5.17431133e-01  1.30644712e+00 -1.88773559e+00 -5.34475266e+00
#  -6.75874626e+00 -2.02808677e-01  3.30761571e-02]
# Finished after 70 timestep
# [ 8.15685111e-01 -1.65876071e+00 -2.29472828e+00 -5.57595085e-03
#   5.20560762e-01  1.29633780e+00 -1.95175294e+00 -6.65117538e+00
#  -7.64882465e+00 -8.94358102e-01  7.18607702e-01]
# Finished after 71 timestep
# [ 0.80018822 -1.71139911 -2.35437676 -0.0148946   0.53153686  1.30757274
#  -1.93127412 -6.50715769 -7.25741234 -1.44145688  1.98937241]
# Finished after 72 timestep
# [ 0.78594616 -1.7597405  -2.40765142 -0.0278464   0.54510368  1.29243445
#  -1.62759972 -5.58010604 -6.06384092 -1.79296681  1.41190288]
# Finished after 73 timestep
# [ 0.77333224 -1.80362775 -2.45621942 -0.04052662  0.55499974  1.33181429
#  -1.52708683 -5.39026985 -6.07697953 -1.37881519  1.05750189]
# Finished after 74 timestep
# [ 0.76211826 -1.84088783 -2.50168465 -0.04703157  0.56107836  1.37926547
#  -1.27758323 -3.92229644 -5.28961367 -0.24719297  0.4643905 ]
# Finished after 75 timestep
# [ 0.75112205 -1.87869988 -2.54931602 -0.05048064  0.56599893  1.41770743
#  -1.47418819 -5.53032619 -6.61391317 -0.62012391  0.74647789]
# Finished after 76 timestep
# [ 0.74018745 -1.91435044 -2.5971502  -0.05033087  0.57180949  1.44741682
#  -1.2639283  -3.37959573 -5.34400596  0.65724559  0.70107992]
# Finished after 77 timestep
# [ 0.73008329 -1.93967826 -2.63557921 -0.05017793  0.58289337  1.34009302
#  -1.14744459 -2.06317849 -3.40293874 -0.65398162  2.08538957]
# Finished after 78 timestep
# [ 0.72237853 -1.94500807 -2.65288864 -0.05408175  0.59763341  1.2706395
#  -0.80948538  0.48608343 -1.16350485 -0.31047964  1.60270277]
# Finished after 79 timestep
# [ 0.71646313 -1.93537324 -2.65681615 -0.05666302  0.61155104  1.2251754
#  -0.68817731  1.79316894  0.0563245  -0.33156817  1.86567854]
# Finished after 80 timestep
# [ 0.71071104 -1.9193881  -2.65431837 -0.06058506  0.63189703  1.19812363
#  -0.75835687  2.1287597   0.50109218 -0.6449188   3.21728866]
# Finished after 81 timestep
# [ 0.70478962 -1.89964167 -2.64654904 -0.06802135  0.65723703  1.14512852
#  -0.71875787  2.80230197  1.43848707 -1.21052129  3.12870232]
# Finished after 82 timestep
# [ 0.69836871 -1.88251398 -2.63717497 -0.08260123  0.68232383  1.10911318
#  -0.880099    1.51563742  0.93999206 -2.43192862  3.15137679]
# Finished after 83 timestep
# [ 0.69151408 -1.86808823 -2.62940828 -0.0985162   0.70365927  1.14619765
#  -0.82882827  2.09058685  0.99857285 -1.5450231   2.20228077]
# Finished after 84 timestep
# [ 0.68502881 -1.85257429 -2.62091584 -0.11348655  0.71950859  1.12538848
#  -0.78932153  1.78803058  1.1222601  -2.19420285  1.77449625]
# Finished after 85 timestep
# [ 0.6791116  -1.83461453 -2.60952138 -0.12937304  0.73323593  1.13911831
#  -0.68955232  2.702577    1.72530578 -1.77852005  1.65938822]
# Finished after 86 timestep
# [ 0.67389585 -1.81090263 -2.5946928  -0.14205293  0.74524413  1.16822822
#  -0.61320779  3.2250817   1.98071005 -1.39166246  1.34807044]
# Finished after 87 timestep
# [ 0.66973659 -1.78259334 -2.5744828  -0.15661493  0.75549933  1.13705477
#  -0.42462131  3.8504639   3.06923916 -2.24669665  1.22438066]
# Finished after 88 timestep
# [ 0.66545231 -1.75447806 -2.55285434 -0.17462603  0.77065662  1.14561968
#  -0.64728198  3.17548445  2.33949374 -2.2553592   2.55940828]
# Finished after 89 timestep
# [ 0.65975087 -1.73397905 -2.53912502 -0.19203103  0.78694982  1.18345083
#  -0.76989116  1.94373431  1.08904198 -2.08904429  1.49648165]
# Finished after 90 timestep
# [ 0.65415406 -1.71980553 -2.52897881 -0.21311429  0.7949833   1.1549645
#  -0.63032426  1.6030453   1.44753158 -3.18200321  0.6040672 ]
# Finished after 91 timestep
# [ 0.64905273 -1.70952538 -2.52020576 -0.23782799  0.79763546  1.1946458
#  -0.6494556   0.97311204  0.74929341 -3.00131331  0.11458771]
# Finished after 92 timestep
# [ 0.644167   -1.70073616 -2.51528391 -0.25832564  0.79599205  1.28012252
#  -0.5708995   1.22381481  0.48077153 -2.1246413  -0.52032358]
# Finished after 93 timestep
# [ 0.63978585 -1.69052003 -2.51043318 -0.27669994  0.79270285  1.2790153
#  -0.52585074  1.32978208  0.73261549 -2.46929452 -0.31823925]
# Finished after 94 timestep
# [ 0.634814   -1.68239921 -2.5101911  -0.29135972  0.79058397  1.36376497
#  -0.72214988  0.70375236 -0.66702991 -1.20105981 -0.2187144 ]
# Finished after 95 timestep
# [ 0.6291049  -1.67767345 -2.51615228 -0.30137735  0.78687065  1.38417133
#  -0.7033179   0.47506077 -0.8241279  -1.30204119 -0.70158569]
# Finished after 96 timestep
# [ 0.62340635 -1.67208888 -2.52148916 -0.31159921  0.78337572  1.38433354
#  -0.72618555  0.92319279 -0.50726238 -1.25653017 -0.1766004 ]
# Finished after 97 timestep
# [ 0.61702489 -1.66691772 -2.52483347 -0.3272273   0.78708953  1.28044694
#  -0.84932538  0.34519572 -0.34133011 -2.63106526  0.77509023]
# Finished after 98 timestep
# [ 0.61070306 -1.65980535 -2.52407437 -0.34719373  0.79125765  1.31190768
#  -0.73152508  1.43274953  0.53024761 -2.36183333  0.31445853]
# Finished after 99 timestep
# [ 0.60485267 -1.6513728  -2.51957544 -0.37121765  0.79168548  1.25308764
#  -0.72786885  0.67372116  0.5922924  -3.63987017 -0.1911    ]
# Finished after 100 timestep
# c:\Users\hgoel\anaconda3\Lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment Hopper-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(

# %%
# !pip install gymnasium
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install gymnasium[mujoco]

# Create Half-Cheetah environment
# https://gymnasium.farama.org/environments/mujoco/hopper/


import gymnasium as gym
env = gym.make("HalfCheetah-v4", render_mode = "rgb_array")
s = env.reset(seed = 34)
print("Observation Space = ")
print(env.observation_space)
print("Action Space = ")
print(env.action_space)
done = False
for episode in range(1):
    print("In episode {}".format(episode))
    for i in range(100):
        print(s)
        a = env.action_space.sample()
        s, r, done, truncated, _ = env.step(a)
        if done:
            print("Finished after {} timestep".format(i+1))
env.close()
# Out:
# c:\Users\hgoel\anaconda3\Lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Observation Space =
# Box(-inf, inf, (17,), float64)
# Action Space =
# Box(-1.0, 1.0, (6,), float32)
# In episode 0
# (array([ 0.07443538, -0.05145152,  0.03021226, -0.00318152,  0.0577067 ,
#         0.07614451,  0.0799444 ,  0.00419858, -0.06093145,  0.06146804,
#         0.04904031, -0.01182644, -0.07192433, -0.08793664, -0.10080283,
#         0.02766291, -0.03509065]), {})
# [ 5.86081344e-02 -6.01263669e-03 -2.13474105e-01 -2.83600134e-02
#   1.55745076e-01 -2.93888955e-02 -2.32879061e-01  2.54803791e-01
#  -8.32932466e-01 -5.63540943e-01  1.23202005e+00 -6.34715328e+00
#  -1.21622318e+00  2.04000534e+00 -3.42987270e+00 -8.00624987e+00
#   6.63668275e+00]
# [ 0.0371195   0.05472263 -0.04280787 -0.48802642  0.12782595 -0.03262333
#  -0.41172629  0.04691264  0.41034693 -0.58252878  0.66965631  6.62053088
#  -9.45390097 -1.43190037  2.01563336 -0.44399782 -9.32573021]
# [-0.01714287  0.04176873  0.02188292 -0.51035472  0.0225476  -0.13578201
#  -0.106613   -0.2523487  -0.25812532 -1.37711108 -0.52089025 -1.32648258
#   3.5476438  -1.84583672 -3.56271734  7.76471885 -2.95968207]
# [-1.02058668e-01 -2.97533603e-02 -5.70935707e-02  1.59760571e-01
#  -1.90420875e-01 -1.04206089e-02  1.44874076e-01 -6.52913716e-02
#   9.03717896e-01 -1.88442248e+00 -1.71938099e+00  1.47565806e+00
#   1.39483042e+01 -8.75836546e-01  5.48209930e+00  2.96591116e+00
#   6.95892617e+00]
# [-0.14791586 -0.08426646  0.4029301   0.18011957 -0.43800125  0.21620224
#   0.09902123 -0.24577732  1.21678003 -0.6146776  -0.45523041  9.94068948
#  -5.47103482 -1.70227962  2.8998551   0.76956711 -6.37471324]
# [ -0.13476373  -0.04803332   0.25069777   0.17508567  -0.24633221
#   -0.10808959   0.3179508   -0.54409494  -0.98926334   0.49048498
#    1.5067816   -8.30754493   1.2082015    6.34865663 -11.25801969
#    5.32856074  -3.24161539]
# [ -0.13896007   0.01410896  -0.11666296   0.20749162  -0.24859536
#   -0.09163455  -0.07889653  -0.10811727  -0.02945881  -0.33760996
#    0.72760854  -5.68675871  -0.31049649  -3.36362423   5.73871029
#  -12.53876645  12.68189607]
# [-0.16816928 -0.03206259 -0.38798446  0.40381117 -0.43611339  0.04925371
#  -0.21204608  0.0745903  -0.03043292 -0.58464146 -1.84903497 -3.94544513
#   4.38157648 -2.65770706  1.1008265   2.47803887 -1.99908845]
# [-1.25089843e-01 -3.53032492e-03 -2.41914177e-01  1.68163625e-01
#  -2.06448573e-01 -3.92575818e-02  3.64102496e-02 -2.03737212e-01
#   7.93176312e-01  1.70863233e+00  2.22342915e+00  4.26699285e+00
#  -7.47217029e+00  4.74027690e+00 -3.00402924e+00  5.27419908e+00
#  -6.26147041e+00]
# [-0.0698189   0.05577551  0.13869     0.08105989  0.11780931 -0.18330158
#   0.17549573 -0.32661887  1.20518451  0.55820352  0.37966952  8.60882262
#   2.16064274  6.29620021 -2.43064236  0.54200531  0.03576441]
# [-0.05282797  0.14463424  0.16350262  0.01888162  0.17230484 -0.22502234
#  -0.15755351 -0.06948207  0.27445501  0.27611034  2.5801508  -4.28895603
#  -2.58659944 -2.10192502 -0.36931869 -8.46840047  6.81159758]
# [-0.04274123  0.28322902  0.10301184 -0.40918866  0.02869852 -0.24885492
#  -0.33898428 -0.12348983  0.57220887  0.01448494  2.49171167 -0.20402631
#  -9.00952213 -2.5520046  -0.26753727 -0.35773986 -5.24503418]
# [-0.08440709  0.3328764  -0.14037984 -0.16752673 -0.24547081  0.04161743
#  -0.58032685 -0.19376678  0.52692626 -1.16132574  0.28802693 -5.88420272
#   8.72011398 -5.3402878   7.60065275 -6.64858467 -0.16581839]
# [-0.12736455  0.34667632 -0.18082811 -0.17454149 -0.43514564  0.26733155
#  -0.67389581 -0.42589528  0.74588351 -0.62668199  0.08091769  1.40081854
#  -3.9528102   0.3995809   2.52076543  0.5790757  -6.56323181]
# [ -0.13504094   0.29145348  -0.37732403  -0.14966473   0.12547838
#   -0.08596096  -0.50548001  -0.4424393   -0.80400232  -0.10103381
#   -1.61677134  -5.45545959   1.60497552  12.87418943 -11.14472688
#    4.93199852   4.17444531]
# [ -0.12352392   0.23792571  -0.36458902  -0.31066218   0.31456938
#   -0.70340204  -0.03175479  -0.17302736  -0.35104056   0.42404451
#   -0.23841394   2.51993538  -2.6558943   -2.85471262 -11.0353006
#   11.28335326   7.12113429]
# [-0.12413628  0.10553428  0.01833698  0.06409918  0.13964045 -0.47244849
#  -0.20273984  0.29502367  1.56787828 -0.44550287 -3.94175598 11.7895434
#  10.99712976 -0.60508518 11.08704136 -6.8756119  10.33898587]
# [-0.15289439 -0.02610913  0.28555865  0.27509056  0.22926006  0.19166713
#  -0.45546855  0.38884039  0.59374671 -0.51810457 -1.21130375 -1.06357955
#   0.04524436  2.03155848 12.18872998 -2.13564437 -2.88930748]
# [-0.16027048 -0.14841877  0.37944192  0.3454352   0.04714868  0.23635432
#   0.03662054  0.30389251  0.0684479   0.4102585  -3.28692609  4.1029185
#   5.32455852 -4.4271777  -3.80242781 10.29253833 -1.4850439 ]
# [ -0.10946735  -0.16838897   0.16767687   0.38989434   0.13568896
#   -0.22934503   0.60972035   0.0451197   -1.12235501   1.14718605
#    1.50670201  -7.66364898  -1.9728477    3.49797889 -10.69721505
#    8.56510023  -6.91880219]
# [ -0.05304092  -0.03761039   0.07891341  -0.03161952   0.48629754
#   -0.02600305   0.09415841  -0.37064716   0.49590697   0.95838512
#    2.94620417   0.72242292  -9.99250955   6.12432912  10.02769826
#  -15.38486736  -7.7170734 ]
# [-0.04479165  0.02338299  0.13453278  0.01342189  0.30333767  0.48753011
#  -0.18739864 -0.15849782  0.62144984 -0.2033076   0.36665758  1.30705445
#   5.72010103 -6.84086264  8.60113222  1.44102382 10.30096763]
# [ -0.03407866   0.11052105  -0.22407553   0.14297162   0.17903443
#    0.11593425   0.01460557   0.35639903  -1.47320944   0.31547711
#    2.59720679 -10.20618361  -0.79803863  -0.30492827 -14.05032054
#    3.4059266    8.43587953]
# [ 2.33332162e-03  2.14446033e-01 -1.39667651e-01 -4.43627094e-01
#  -2.97085900e-02  1.01079525e-01 -1.87079464e-01  3.91910276e-01
#   8.74072881e-02  5.81781121e-01  1.43237059e+00  5.58518004e+00
#  -1.31013368e+01 -4.68824820e+00  4.95215574e+00 -4.46598645e+00
#  -4.72130952e+00]
# [-1.26047672e-02  2.15836843e-01  6.17880492e-02 -5.26626954e-01
#  -3.10681042e-01  5.52918892e-01 -2.76705918e-01 -8.95999139e-03
#   3.94831357e-01 -7.27251444e-01 -5.74922289e-01  2.86562038e+00
#   4.37752865e+00 -4.23058562e+00  9.42349878e+00  8.05760239e-01
#  -8.17556737e+00]
# [-0.06872081  0.13305234 -0.03359516  0.30376218 -0.39784155  0.70016784
#  -0.18495365 -0.35677283 -0.5287946  -1.16635714 -1.81239068 -1.72004208
#  16.40285269  0.12158374 -1.17018058  1.38804498 -5.2051815 ]
# [ -0.0912745    0.13634788   0.22532287   0.08916688   0.29485886
#    0.32147241  -0.17668081  -0.13634011  -0.22530358  -0.39105729
#    0.83008783   6.88695203 -12.01568755  16.61809294  -9.68252865
#   -1.2059867    8.82687455]
# [ -0.10445835   0.16751992   0.17798871  -0.2430936    0.16853172
#    0.32460003  -0.41310701  -0.11832397  -1.29088339  -0.53125545
#    0.7669988   -5.39109379  -2.8496855  -11.06524479   0.74311176
#   -3.10288685  -3.84629432]
# [-0.15158631  0.17684993 -0.26707481  0.00871966  0.22746334  0.34153076
#  -0.4655345  -0.38869958 -1.26457847 -0.93444041  0.2834758  -8.19781397
#   7.8252053   5.99447768  0.17624718 -0.79638163 -6.16860097]
# [ -0.143911     0.1037687   -0.33183759   0.14850107   0.25178498
#   -0.03421459  -0.13117381  -0.53603109  -1.70079779   0.62791779
#   -2.10462559   2.60706718   0.10625799  -2.16843265 -10.46284872
#   10.38481251   1.64845238]
# [-0.09838999  0.08732001  0.04924272 -0.07190352  0.14845025 -0.58133032
#   0.11135261  0.0702289  -0.87739608  0.61176591 -0.02141541  9.47273157
#  -5.24979568  1.25748276 -9.3010849   0.81878482 16.24088997]
# [-9.71105968e-02  8.13607954e-02  4.77089334e-01 -3.59216955e-01
#  -4.39567645e-03 -8.59119693e-01 -2.71015112e-02  5.42112880e-01
#  -7.83761852e-01 -3.32184135e-01 -3.56580176e-01  6.14947960e+00
#  -3.52429582e+00 -4.00779116e+00 -2.99478436e+00 -4.17990718e+00
#   3.17423477e+00]
# [ -0.1028926    0.04301364   0.2979944   -0.18421124   0.26122889
#   -0.54813255  -0.06933135   0.12502487  -0.87653803   0.19974375
#   -0.26175096  -7.82357496   8.0355022    6.90670709  10.28169447
#    1.65962901 -12.93420735]
# [-1.02891087e-01  6.55873921e-02  1.93941388e-01 -1.84501692e-01
#   5.34364796e-01 -4.52645755e-03  1.63461655e-02 -2.66311905e-01
#  -1.67301517e-02 -1.11965109e-01  1.22804341e+00  5.88594347e-01
#  -3.20704130e+00  3.03423104e+00  9.27422228e+00  2.29825831e+00
#  -3.36341462e+00]
# [-0.10643321  0.09062464  0.3416186  -0.31413553  0.41938425  0.2366287
#  -0.11697641 -0.53020663 -0.26813563 -0.21599108  0.23563178  3.54560344
#  -1.74703121 -3.84010238  2.02415049 -0.43059107  0.99126183]
# [-0.0940054   0.0376016   0.44540797 -0.18709032 -0.07323616 -0.0615561
#   0.23564787 -0.51948724 -1.63811128  0.54654063 -1.63189304  1.07012931
#   3.73258039 -9.64524262 -8.62930935  8.47366569  0.74966026]
# [-0.07695173  0.05616348  0.32395214 -0.33054714 -0.42618985 -0.5143497
#   0.16282807 -0.1536867  -2.10498356  0.0780884   1.22374103 -3.90182545
#  -5.58679208 -4.09925273 -8.39042873 -6.51904051  9.49346958]
# [-1.03033015e-01  3.87082807e-02  1.81822581e-01 -2.16811667e-01
#  -3.38964464e-01 -3.23130661e-01 -4.18931625e-01 -9.34835642e-03
#  -6.96461453e-01 -6.02490840e-01 -9.27723239e-01 -1.91381293e+00
#   5.56618741e+00  4.35858359e-01  9.33865550e+00 -1.06606853e+01
#  -1.49614139e+00]
# [-1.31627165e-01 -3.08864311e-04  4.48453577e-02  2.14320485e-01
#  -1.31836147e-02 -6.56652451e-02 -5.98823121e-01 -4.59132875e-02
#  -7.25233442e-01 -6.58326857e-01 -9.77112521e-01 -7.59444081e-01
#   7.06380786e+00  1.09435307e+01  2.15025786e+00  8.01006800e-01
#  -1.25623825e-01]
# [-0.15700849  0.02997396 -0.11635973  0.27896753  0.05359431 -0.28912216
#  -0.46147909  0.12484313 -1.42178751 -0.37684262  1.77239564 -3.59088654
#  -0.52332673 -3.48828674 -6.82296191  2.82175048  4.7482206 ]
# [ -0.16358048   0.13636149  -0.28759753  -0.03460962  -0.3734485
#   -0.5172062   -0.07120917  -0.18165664  -1.61849497  -0.06930247
#    1.42567674  -3.85059978  -8.60367125  -8.97770456  -3.23648866
#    1.94229255 -15.38791301]
# [-0.18658868  0.09786489 -0.36107623  0.11395338 -0.35772681 -0.46423061
#   0.04933303 -0.56330274 -0.64730172 -0.22800594 -1.39369268 -1.52826383
#   7.50353194 -2.79036059  1.60065077 -0.57004149  1.51638009]
# [-0.15856526  0.13075565 -0.21233214 -0.04800411 -0.26141138 -0.36037106
#  -0.24965947 -0.0606796   0.11882623  0.94144386  1.58720344  4.05491287
#  -6.76101291  3.86441713  1.43157899 -7.44718835 12.39408989]
# [-0.09973352  0.13164799  0.07925906 -0.39794459 -0.17864761 -0.08303945
#  -0.33876318  0.1816887   0.69637411  1.19700179 -1.1608721   5.30884
#  -4.61279669  1.05602802  6.77205797  1.37746397 -0.40034499]
# [-0.06309406  0.05351293 -0.14474334 -0.11426582 -0.20063358 -0.09317304
#   0.03206139  0.20982761 -0.77307344  0.50593404 -1.65535197 -8.05748713
#   7.30480255 -1.20751724 -3.2177484   7.67470633  0.54775204]
# [ -0.0266495    0.03161785   0.03654515  -0.46980084  -0.19121957
#   -0.26249684   0.18880172   0.03972579   0.20604798   0.61710949
#   -0.1622867    8.01993653 -10.44327799   1.09809277  -2.91148764
#   -0.26050769  -5.0638919 ]
# [-0.05649668 -0.08420698  0.25097668  0.05970612 -0.31216329 -0.06810644
#  -0.11411722 -0.30525339  0.64497895 -1.14575265 -3.13955029  4.4575849
#  16.82938435 -2.66938285  5.75678908 -7.16807031 -6.82266848]
# [-0.09991968 -0.19646392  0.32771753  0.45307812  0.17235784 -0.05007458
#  -0.0125928  -0.20991582 -0.13697952 -0.68835389 -1.50410728 -1.09090694
#   1.77958769 12.51135641 -1.99992859  6.15740558  6.56755934]
# [-0.11553559 -0.2039735   0.42662896  0.24091873  0.32353797  0.10224403
#   0.29848768 -0.00667803  1.19376723 -0.02877679  1.18313576  2.57720263
#  -2.53123238 -2.14807388  5.5353512   5.38978342  2.24015391]
# [-0.11871793 -0.10813455  0.1777483   0.36893273  0.0161644   0.10901716
#   0.16890817  0.23496271 -0.52019521  0.30592418  1.47499153 -7.23925892
#   3.1164474  -6.84460032 -1.31015161 -7.39476137  5.45053762]
# [-9.74749032e-02 -2.61223974e-03  1.88062113e-01 -4.65503871e-02
#  -2.16904424e-01  1.70851932e-01 -1.18988882e-01  4.47684450e-01
#   5.88058925e-01  4.48316244e-01  2.38388828e+00  3.92465041e+00
#  -9.22683437e+00 -2.16746696e+00  2.25260571e+00 -3.30722870e+00
#   2.85892279e+00]
# [-0.07756236  0.12686127  0.00937126 -0.34214861 -0.36719803  0.10063015
#  -0.32761799  0.38693578 -0.8929804   0.40131982  2.27932784 -6.94194809
#  -3.33125992 -2.88343144 -2.77530156 -4.0470927  -3.1135066 ]
# [-9.54544679e-02  1.50642889e-01 -2.20366839e-01  2.39836735e-02
#  -4.11007516e-01  2.50722428e-01 -3.77372299e-01  8.35039589e-03
#   2.71653179e-01 -6.60649555e-01 -2.01164120e-01 -1.39588151e+00
#   9.65856411e+00  3.35723110e-01  5.47756691e+00  1.11039028e+00
#  -8.56858045e+00]
# [-1.18057647e-01  1.14762506e-01  2.15239132e-02  1.77615596e-01
#  -4.06899741e-01  4.67677499e-01  7.32199633e-03 -5.10519058e-01
#   8.00631821e-01 -4.56067023e-01 -8.86358228e-01  6.94919746e+00
#  -1.92645944e-01  2.38161147e-01  3.13648394e+00  1.04602996e+01
#  -8.49212469e+00]
# [-0.07270397  0.0512635   0.23307162 -0.22291255  0.15236926  0.23417895
#   0.3984554  -0.37984565 -0.48948198  1.47534477 -1.53357763  1.68933094
#  -9.06308425 13.20115282 -7.39949712  6.89899266  8.00803909]
# [ -0.05505307  -0.04568879  -0.01890182   0.14366609  -0.07823707
#    0.18308781   0.18480863  -0.05893071  -0.9676665   -0.18127189
#   -2.06975427  -6.99078804  11.14946465 -11.83028262   1.8634062
#   -8.45104393   4.19182968]
# [-5.47787097e-02 -1.19616808e-01 -7.21979108e-02  2.60209237e-01
#  -1.77678873e-01 -1.39818638e-01 -8.96765711e-03  3.44316378e-01
#  -8.46405013e-01 -9.43221204e-04 -9.54037016e-01  2.37314542e+00
#  -1.84527002e+00  3.20256238e+00 -1.02616257e+01 -1.59293700e+00
#   8.55352262e+00]
# [-0.04267994 -0.15695821  0.20585776  0.18693035 -0.04932334 -0.43096346
#   0.191657    0.46471433  0.61904723  0.39384535 -0.74102785  6.57636569
#  -0.75800895  2.81346206 -1.8768617   5.30845332 -1.26937085]
# [ -0.05108546  -0.24776193   0.52256257   0.41978496  -0.30516172
#   -0.10590385   0.31720177  -0.04732562   0.99120698  -0.45184189
#   -1.80834475   4.75633476   6.0196001   -6.93271155   9.41225221
#    1.28500081 -13.12695397]
# [ -0.0647142   -0.19834048   0.11063138   0.35088957  -0.26770715
#   -0.18079212   0.45827618  -0.29675267  -0.85157342  -0.32268834
#    2.00338119 -12.17250027  -5.86634472   3.60483726  -6.2761537
#    2.34761627   0.24399796]
# [-0.07507846 -0.07492702 -0.07430351  0.19402807 -0.01048791 -0.21270474
#   0.26141731  0.07863784  0.39293374 -0.21321309  2.51836632  0.2847649
#  -3.29190883  4.43044498  2.11500855 -5.55652247 10.11319498]
# [ -0.10938429   0.09051189  -0.23072994   0.05148112   0.38705832
#   -0.21445943  -0.30981652   0.47559018  -0.19234921  -0.96326119
#    3.54502624  -4.0627274   -2.05921606   7.03233024  -2.19276049
#  -11.7422457    5.01248469]
# [ -0.15872478   0.12806153  -0.18858078   0.27776419   0.52650445
#   -0.1592413   -0.3890672   -0.02499873   0.28877016  -0.9541863
#   -0.74950688   4.07051234   6.71514754   0.45326793   2.52369564
#    3.78217639 -16.96579911]
# [-0.20507352  0.09829324 -0.07036178  0.51780521  0.21937767 -0.22684046
#  -0.19650965 -0.53354384 -0.59843689 -0.83994102 -0.42700131  0.59995712
#   2.6961003  -7.34714845 -3.13744083  1.38190505 -0.98136585]
# [-0.21896405  0.11254647 -0.14622741  0.26826616  0.33067741 -0.27302706
#  -0.34094787 -0.29322936 -0.18769108  0.4121089   1.44105073 -2.60951434
#   0.36929213  4.35337103 -0.41296122 -4.46618228  7.06410775]
# [-0.20651218  0.14527803 -0.13730422  0.38549788  0.11207234 -0.41613276
#  -0.3246368  -0.17383691 -0.25344878  0.1472827   0.26227064  1.75500397
#   2.73505231 -6.97171356 -3.44234287  2.64390949 -0.305416  ]
# [ -0.17861973   0.16150576   0.27542387  -0.12370065  -0.36102975
#   -0.42009842  -0.16508687  -0.43002333   0.39556193   0.48773451
#   -0.18534034   8.6141988  -13.24614681  -7.70008845   1.49734579
#    3.40522853  -6.53652126]
# [-1.95532426e-01  1.48838887e-01 -3.91181488e-03  1.12635666e-01
#   1.96052627e-01 -5.13745228e-01 -2.84338773e-01 -3.06759304e-01
#  -1.13415983e+00 -8.09628548e-01 -3.58342756e-01 -1.05221148e+01
#   1.02911703e+01  1.63763142e+01 -3.16118529e+00 -4.97510190e+00
#   6.76500903e+00]
# [-0.24929284  0.06695532 -0.44373057  0.54270291  0.68439966 -0.55797698
#  -0.03496069 -0.28159721 -0.55163095 -1.10342305 -1.9930401  -5.57138406
#   5.25317771  3.68749069  0.96094069  8.89667312 -2.73539243]
# [-2.74912553e-01 -3.15206024e-03 -4.12448462e-01  8.09155244e-01
#   3.37274912e-02 -5.51543092e-01 -5.20059438e-03 -2.64017692e-01
#  -4.00590070e-01 -1.84555378e-01 -7.12868013e-01  3.27130681e+00
#   2.74884920e+00 -1.75665550e+01 -3.79319715e-01 -5.88178549e-01
#   4.37666239e+00]
# [-2.49303296e-01 -2.85894453e-03 -1.59165684e-01  6.30899260e-01
#  -4.47414614e-01 -3.60089841e-01 -6.88155685e-02 -3.89349179e-01
#   1.79531499e-01  8.62847550e-01  4.26063768e-01  3.30342943e+00
#  -5.55826826e+00 -5.14870700e-01  5.40468225e+00 -8.24587352e-01
#  -5.78978518e+00]
# [ -0.15855361   0.17042189  -0.0508266   -0.07912648  -0.05322181
#   -0.36861277  -0.29620555  -0.13363895   0.12378853   1.99172091
#    4.23250426   1.46943637 -16.52369001  12.0912465   -3.23973101
#   -5.2972763   10.11885933]
# [-1.02272100e-01  2.23362925e-01 -1.20408212e-01 -1.01265538e-01
#   1.10686689e-01  5.18283079e-04 -4.28219486e-01 -1.81189960e-01
#   5.97711063e-01  6.83916968e-01 -3.39707310e-01 -2.75985713e+00
#   6.59720516e+00 -1.89067164e+00  1.20372373e+01  8.46774031e-01
#  -6.21617538e+00]
# [-8.67240036e-02  1.81490001e-01  1.09767307e-01  2.31137536e-01
#  -1.69794987e-03  4.23432397e-01 -2.86443304e-01 -1.44561421e-01
#   1.00263121e+00  1.33445912e-01 -1.11304734e+00  8.68768582e+00
#   5.73871641e+00 -1.11133164e+00  4.95085343e+00  3.49165234e+00
#   4.67167521e+00]
# [ -0.06192589   0.18934098   0.53948014  -0.15378863   0.17407059
#    0.37584623   0.098263    -0.04884898   0.63425662   0.63047402
#    0.62578243   5.81363496 -11.22972712   4.62006429  -2.71902067
#    6.74190059  -0.33539432]
# [-0.02556199  0.24809729  0.38495335 -0.46899892  0.55832777  0.28708059
#   0.22951337  0.03097461 -0.30156556  0.56291647  1.39989206 -7.11206824
#  -2.71625142  6.42664883 -1.18333135  1.23761262  3.24201453]
# [-0.02021914  0.23170912  0.17843301 -0.25553428  0.37098817  0.2016472
#   0.34263605  0.1417524  -0.03689309 -0.08529536 -1.19345296 -1.33519676
#   5.95023214 -7.26442961 -1.16626797  2.29299681  1.64398584]
# [-0.05326218  0.15374092  0.18293041  0.15509565  0.02137416  0.31529798
#   0.18577167  0.24119178  0.20000221 -0.89765644 -1.54784763  1.54616482
#   7.06584219 -4.57146255  3.18202154 -4.77228742  1.71441551]
# [ -0.07556172   0.20135101  -0.07717238  -0.10108751   0.35330138
#    0.43234148  -0.24510072   0.06938754  -0.61404304  -0.26372549
#    1.74108619  -7.36734771 -10.23774475   9.5493007    2.16815004
#   -7.9152317   -5.15537395]
# [-0.08845619  0.20211049 -0.02210943 -0.42342463  0.43190083  0.43439171
#  -0.33534503  0.05563655  0.31608025  0.24936432 -0.17956698  2.83004398
#   0.36138275 -6.06051185 -0.82738675  0.76885072  2.29814173]
# [-0.05237541  0.15720027  0.03829461 -0.29275302 -0.04571496  0.1308543
#  -0.2472844   0.26414923 -0.81953713  0.84899505 -0.89462366  0.04825428
#   2.7782307  -8.36730074 -9.517849    1.95558132  4.2757455 ]
# [ -0.0460172    0.0488039    0.09301533   0.24299958  -0.40536838
#   -0.16506691   0.22863004  -0.08551026  -0.16542333  -0.23650119
#   -2.46495818   3.15098513  11.4401421   -4.17428602  -2.68449904
#   10.32488134 -11.77113118]
# [-5.00805247e-02  7.47788819e-02 -3.26078342e-02  1.31674447e-01
#   1.73009376e-01 -3.69427176e-01 -9.23368099e-03 -4.32296788e-02
#  -9.02181885e-01 -1.25628254e-01  1.85180037e+00 -4.88779858e+00
#  -8.18912594e+00  1.54167127e+01 -4.98181073e+00 -1.12632292e+01
#   7.25818375e+00]
# [-0.0878416   0.09208648 -0.20361074 -0.05505061  0.54533358  0.03250958
#  -0.64383221  0.08680887  0.19103137 -1.10797523 -0.52288924 -2.84102483
#  -0.88051174  1.33179388 14.17247133 -9.00792659 -0.46455295]
# [-1.16942773e-01  7.49791671e-02  2.28191718e-04  5.70278662e-02
#  -8.61554628e-03  1.96821369e-01 -2.40793755e-01 -1.65543770e-01
#   3.75823219e-01 -4.57582983e-01 -4.45357790e-01  7.52224530e+00
#   1.76113918e+00 -1.31338363e+01 -2.95799971e+00  1.48324303e+01
#  -6.25707967e+00]
# [-0.13869345  0.02635186  0.05687485  0.34428922 -0.10037543  0.08253924
#  -0.10443868 -0.43372395 -1.04935089 -0.46907387 -0.7073672  -2.11046601
#   5.82628383  3.83874537 -3.90709788 -1.75935199 -2.5553396 ]
# [-0.15358771  0.02052619  0.10098999  0.14694916 -0.12836345 -0.013789
#  -0.02261593 -0.44019497 -0.57069551 -0.22622146 -0.23262707  1.71407359
#  -7.34808175 -2.4443499  -0.33378741  0.50552269 -0.80195871]
# [-0.14225314 -0.00939024  0.03896658  0.23479711 -0.35338858 -0.24369694
#   0.12646564 -0.22738856 -1.42862249  0.26074881 -1.09619687 -2.81001031
#   2.32510284 -3.57063613 -5.9339333   4.37295113  7.4112768 ]
# [-0.13582355 -0.05905807  0.01965652  0.26722312 -0.38376913 -0.05639615
#   0.04622051 -0.06345441 -0.1830182   0.21048261 -0.54786447  0.42332878
#   0.50464857 -0.61071467  8.05479475 -3.30637594  0.56930065]
# [-0.13422686 -0.02141419  0.06365436  0.13748716 -0.42354358  0.48270861
#  -0.29976797 -0.24475846 -0.11525983 -0.06868013  1.49555471  0.14160757
#  -3.55395426  0.33426202 10.11449557 -5.95386559 -5.28366197]
# [-1.13830719e-01  4.34413621e-02  2.22303596e-01 -1.12591066e-01
#  -2.36505589e-01  4.93400977e-01  5.26882940e-02 -2.96740403e-01
#  -8.36755720e-03  4.37969230e-01  9.10636371e-01  4.32364920e+00
#  -4.30327577e+00  6.23497329e+00 -4.50479536e+00  1.15856514e+01
#   1.82344184e+00]
# [-0.05911418  0.07410108  0.38903697 -0.45561418  0.12861403  0.20956682
#   0.37512477 -0.36616508 -0.81652526  1.3281594   0.44742947  1.66680098
#  -5.68831621  5.8111753  -5.66708709  3.2150225  -1.780872  ]
# [-0.01365547  0.05576805  0.28122758 -0.2528145   0.22062473 -0.07348777
#   0.51814121 -0.04474284 -1.21333194  0.62880259 -0.63703278 -2.99124974
#   6.84324205 -0.54009731 -4.91891554  1.5904423   9.8332135 ]
# [ -0.01834764   0.04591282  -0.065103     0.16421258   0.16504934
#    0.21096977  -0.09359452   0.19907886  -0.93120794  -0.41242948
#    0.12695201  -7.55014612   5.75298769  -1.24111123   9.57200841
#  -14.56524316   1.09594668]
# [-1.04308252e-02  1.12485117e-01 -1.58539672e-02 -2.78806778e-01
#   1.63089309e-01  1.77942204e-01 -4.95402055e-01  1.94593315e-01
#  -9.36826292e-01  2.81634851e-01  1.42093763e+00  4.43446135e+00
#  -1.28038087e+01  5.87575535e-01 -6.66938927e+00 -3.83254571e+00
#  -9.86152919e-01]
# [-0.02899979  0.08482374  0.10429303 -0.35102377  0.2891055  -0.03172068
#  -0.22757009  0.2470862  -0.54897632 -0.7674678  -1.48613472  1.39644849
#   4.40181568  2.7900845  -1.66389327  8.64827474  2.22569498]
# [-0.05133409  0.02098434  0.13472214 -0.19066288  0.26131722 -0.22813348
#   0.30046367  0.02475913 -0.90551719  0.15187251 -1.06853322 -0.34838457
#   2.54287701 -3.44692822 -3.06515244  6.62806237 -7.71871863]
# [-0.06269303 -0.0275912   0.32559895 -0.17481193 -0.08552889  0.08325188
#   0.07334149 -0.33855939  0.16659219 -0.44568151 -0.82035934  4.83342262
#  -0.36026941 -6.55381374  9.44180434 -7.9101319  -5.76176521]
# [-8.82483845e-02 -6.52611379e-03  2.40023779e-01 -7.13924832e-02
#  -3.14109422e-02  5.50796909e-01 -2.21539475e-01 -4.92501761e-01
#  -2.99949231e-01 -4.55465196e-01  1.23288912e+00 -4.62466426e+00
#   2.22630751e+00  4.46418870e+00  7.81595943e+00 -2.66983437e+00
#  -1.05919597e+00]

# %% [markdown]
# # Hyperparameters [10 marks]
# <a id="Hyperparameters"></a>
#
# All your hyperparameters should be stated here. We will change their value here and your code should work  accordingly.

# %%
# mention the values of all the hyperparameters (you can add more hyper-paramters as well) to be used in the entire notebook, put the values that gave the best
# performance and were finally used for the agent

gamma = 0.99                         # FOR REINFORCE, VPG, DDPG, TD3, SAC
beta = 0.08                          # FOR VPG
optimizerFn = torch.optim.Adam       # FOR REINFORCE, VPG
optimizerLR = 0.0003                 # FOR REINFORCE, VPG
MAX_GRAD_NORM_POLICY = 1.0           # FOR REINFORCE, VPG, DDPG, TD3, SAC
MAX_GRAD_NORM_VALUE = 1.0            # FOR REINFORCE, VPG, DDPG, TD3, SAC
MAX_TRAIN_EPISODES = 150             # FOR REINFORCE, VPG, DDPG, TD3, SAC
MAX_EVAL_EPISODES = 1                # FOR REINFORCE, VPG, DDPG, TD3, SAC

updateFrequency = 1                       # FOR DDPG, SAC
policyOptimizerFn = torch.optim.Adam      # FOR DDPG, TD3
valueOptimizerFn = torch.optim.Adam       # FOR DDPG, TD3
policyOptimizerLR = 2e-4                  # FOR DDPG, TD3
valueOptimizerLR = 3e-4                   # FOR DDPG, TD3
minSamples = 10000                          # FOR DDPG, TD3, SAC
noiseScaleRatio = 0.1                     # FOR DDPG, TD3
tau = 5e-3                                # FOR DDPG, TD3, SAC
bufferSize = 1_000_000                    # FOR DDPG, TD3, SAC
batchSize = 256                           # FOR DDPG, TD3, SAC
updateFrequencyValue = 1                  # FOR TD3
updateFrequencyPolicy = 2                 # FOR TD3
trainPolicyFrequency = 2                  # FOR TD3

entropyLR = 2e-4                          # FOR SAC
logSTD_min = -10.0                        # FOR SAC
logSTD_max = 2.0                          # FOR SAC
epsilon = 1e-6                            # FOR SAC
squasherMin = -1                          # FOR SAC
squasherMax = 1                           # FOR SAC
ep_max_steps = 1000
base_seed = 21

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Helper Functions [20 marks]
#
# <a id="helper"></a>
#
# Write all the helper functions that will be used for value-based and policy based algorithms below. In case you want to add more helper functions, please feel free to add.

# %%
#Value Network

'''
Added isTwoStreams boolean in the arguments for reusing the same function for creating
two streams value network in case of TD3.
'''
def createValueNetwork(inDim, outDim, action_size=0, hDim = [32,32], activation = F.relu):
    #this creates a Feed Forward Neural Network class and instantiates it and returns the class
    #the class should be derived from torch nn.Module and it should have init and forward method at the very least
    #the forward function should return q-value for each possible action

    #Your code goes in here
    class ValueNetwork(nn.Module):
        def __init__(self):
            super(ValueNetwork, self).__init__()
            self.activation = activation

            layers = []
            prev_dim = inDim + action_size

            for h in hDim:
                layers.append(nn.Linear(prev_dim, h))
                prev_dim = h

            layers.append(nn.Linear(prev_dim, outDim))
            self.layers = nn.ModuleList(layers)
            self._init_weights()

        def _init_weights(self):
            for m in self.modules():
                if isinstance(m, nn.Linear):
                    nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                    nn.init.constant_(m.bias, 0)

        def forward(self, x, action=None):
            if action is not None:
                x = torch.cat([x, action], dim=-1)

            for layer in self.layers[:-1]:
                x = self.activation(layer(x))

            x = self.layers[-1](x)
            return x

    valueNetwork = ValueNetwork()
    return valueNetwork

# %%
#Policy Network
def createPolicyNetwork(inDim, outDim, hDim = [32,32], activation = F.relu, use_tanh=False):
    #this creates a Feed Forward Neural Network class and instantiates it and returns the class
    #the class should be derived from torch nn.Module and it should have init and forward method at the very least
    #the forward function should return action logit vector
    #Your code goes in here
    class PolicyNetwork(nn.Module):
        def __init__(self):
            super(PolicyNetwork, self).__init__()
            self.activation = activation
            layers = []
            prev_dim = inDim

            # Hidden layers
            for h in hDim:
                layers.append(nn.Linear(prev_dim, h))
                prev_dim = h

            layers.append(nn.Linear(prev_dim, outDim))
            self.layers = nn.ModuleList(layers)
            self._init_weights()

        def _init_weights(self):
            for m in self.modules():
                if isinstance(m, nn.Linear):
                    nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                    nn.init.constant_(m.bias, 0)

        def forward(self, x):
            for layer in self.layers[:-1]:
                x = self.activation(layer(x))
            x = self.layers[-1](x)
            # squeeshing the action-values in the range [-1,+1]
            if use_tanh:
                x = F.tanh(x)
            return x

    policyNetwork = PolicyNetwork()
    return policyNetwork

# %%
def selectGreedyAction(policy_network, s, env):
    state = torch.FloatTensor(s).unsqueeze(0)
    action_low = env.action_space.low
    action_high = env.action_space.high

    action_scale = torch.tensor((action_high - action_low) / 2.0, dtype=torch.float32)
    action_bias = torch.tensor((action_high + action_low) / 2.0, dtype=torch.float32)

    with torch.no_grad():
        mean = torch.tanh(policy_network(state)) * action_scale + action_bias

    return mean.detach().cpu().numpy().flatten()


def selectAction(policy_network, s, env, std_scale=0.5):
    state = torch.FloatTensor(s).unsqueeze(0)
    action_low = env.action_space.low
    action_high = env.action_space.high

    action_scale = torch.tensor((action_high - action_low) / 2.0, dtype=torch.float32)
    action_bias = torch.tensor((action_high + action_low) / 2.0, dtype=torch.float32)

    mean = torch.tanh(policy_network(state)) * action_scale + action_bias

    std = torch.ones_like(mean) * std_scale * action_scale
    dist = torch.distributions.Normal(mean, std)
    action = dist.sample()

    action = torch.clamp(action, action_low[0], action_high[0])

    logp_a = dist.log_prob(action).sum(dim=-1)
    entropy_pa = dist.entropy().sum(dim=-1)

    return action.detach().numpy().flatten(), logp_a.squeeze(), entropy_pa.squeeze()

# %%
def getStepWiseReturnsAndDiscounts(gamma, reward, next_value=0.0):
    rewards = torch.tensor(reward, dtype=torch.float32)
    size = rewards.shape[-1]
    returns = torch.zeros(size, dtype=torch.float32)
    gammas = gamma ** torch.arange(size, dtype=torch.float32)

    G = next_value if isinstance(next_value, float) else next_value.item()
    for t in range(size-1, -1, -1):
        G = rewards[t] + gamma * G
        returns[t] = G

    return returns, gammas

# %%
def moving_average(x, window=50):
    if len(x) < window:
        return np.array(x)
    return np.convolve(x, np.ones(window) / window, mode='valid')


def plotResults(
    quantityDict,
    env_names,
    window=50,
    use_moving_avg=True,
    save_pdf=False,
    save_dir='./plots'
):
    """
    Supports:
    - [y1, y2, y3]
    - (x_list, y_list)
    - [(x, y), (x, y)]
    """

    if save_pdf:
        os.makedirs(save_dir, exist_ok=True)

    for env in env_names:
        for quantityName in quantityDict[env].keys():

            plt.figure(figsize=(8, 5))

            for agent, quantityOverSeeds in quantityDict[env][quantityName].items():

                processed_seeds = []
                x_reference = None

                for quantityList in quantityOverSeeds:
                    # UNWRAP nested structures like [[[(x,y)]]]
                    while isinstance(quantityList, (list, tuple)) and len(quantityList) == 1:
                        quantityList = quantityList[0]
                        
                    # CASE 1: (x_list, y_list)
                    if isinstance(quantityList, tuple) and len(quantityList) == 2:
                        x_vals, y_vals = quantityList
                        x_vals = np.array(x_vals).reshape(-1)
                        y_vals = np.array(y_vals).reshape(-1)

                    # CASE 2: [(x,y), (x,y)]
                    elif (
                        isinstance(quantityList, (list, tuple)) and
                        len(quantityList) > 0 and
                        isinstance(quantityList[0], (list, tuple))
                    ):
                        x_vals = np.array([item[0] for item in quantityList if len(item) >= 2])
                        y_vals = np.array([item[1] for item in quantityList if len(item) >= 2])

                    # CASE 3: [y1, y2, y3]
                    else:
                        y_vals = np.array(quantityList)
                        x_vals = np.arange(len(y_vals))

                    if y_vals.ndim == 0 or len(y_vals) == 0:
                        continue

                    if y_vals.ndim > 1:
                        y_vals = y_vals.reshape(-1)
                        x_vals = x_vals[:len(y_vals)]

                    # Moving Average
                    if use_moving_avg:
                        adaptive_window = min(window, max(3, len(y_vals)//5))
                        y_vals = moving_average(y_vals, adaptive_window)
                        x_vals = x_vals[-len(y_vals):]

                    processed_seeds.append(y_vals)

                    if x_reference is None:
                        x_reference = x_vals

                if len(processed_seeds) == 0:
                    print(f"No valid data for {agent} in {quantityName}")
                    continue

                # Align lengths
                min_len = min(len(s) for s in processed_seeds)
                if min_len == 0:
                    continue

                processed_seeds = np.array([s[:min_len] for s in processed_seeds])

                mean = processed_seeds.mean(axis=0)
                if processed_seeds.shape[0] > 1:
                    std = processed_seeds.std(axis=0)
                    sem = stats.sem(processed_seeds, axis=0)
                else:
                    std = np.zeros_like(mean)
                    sem = np.zeros_like(mean)

                # X-axis
                if x_reference is not None:
                    x = x_reference[:min_len]
                else:
                    x = np.arange(min_len)

                # Plot
                plt.plot(x, mean, label=agent, linewidth=2)

                if processed_seeds.shape[0] > 1:
                    if use_moving_avg:
                        plt.fill_between(x, mean - std, mean + std, alpha=0.2)
                    else:
                        plt.fill_between(x, mean - sem, mean + sem, alpha=0.3)

            # Labels
            title_suffix = "Moving Avg" if use_moving_avg else "Raw"

            plt.title(f"[{env}] {title_suffix} {quantityName} vs Episodes")
            plt.xlabel("Episodes")
            plt.ylabel(quantityName)

            plt.legend()
            plt.grid(True, alpha=0.3)
            plt.tight_layout()

            # Save / Show
            if save_pdf:
                safe_env = env.replace('-', '_').replace(' ', '_')
                safe_quantity = quantityName.replace(' ', '_').replace('/', '_')
                suffix = "MA" if use_moving_avg else "Raw"

                filename = f"{safe_env}_{safe_quantity}_{suffix}.pdf"
                filepath = os.path.join(save_dir, filename)

                plt.savefig(filepath, format='pdf', dpi=300, bbox_inches='tight')
                print(f"Saved: {filepath}")
                plt.close()
            else:
                plt.show()

# %% [markdown]
# ## ReplayBuffer [40 marks]

# %% [markdown]
# In next few cells, you will implement replaybuffer class.
#
# This class creates a buffer for storing and retrieving experiences. This is a generic class and can be used
# for different agents like NFQ, DQN, DDQN, PER_DDQN, etc.
# Following are the methods for this class which are implemented in subsequent cells
#
# ```
# class ReplayBuffer():
#     def __init__(self, bufferSize, batch_size, seed)
#     def store(self, state, action, reward, next_state, done)
#     def sample(self, batchSize)
#     def length(self)
# ```

# %%
class ReplayBuffer():
    def __init__(self, buffer_size, batch_size=32, seed=33):
        # this function creates the relevant data-structures, and intializes all relevant variables
        #Your code goes in here
        self.buffer_size = buffer_size
        self.batch_size = batch_size
        self.seed = seed
        random.seed(self.seed)

        self.buffer = deque(maxlen=self.buffer_size)

# %%
class ReplayBuffer(ReplayBuffer):
    def store(self, state, action, reward, next_state, done):
        #stores the experiences, based on parameters in init
        #
        #this function does not return anything
        #
        #Your code goes in here
        self.buffer.append((state, action, reward, next_state, done))

# %%
class ReplayBuffer(ReplayBuffer):
    def sample(self, batchSize):
        # this method returns batchSize number of experiences
        # this function returns experiences samples
        #
        #Your code goes in here
        experiencesList = random.sample(self.buffer, batchSize)
        return experiencesList

# %%
class ReplayBuffer(ReplayBuffer):
    def splitExperiences(self, experiences):
        #it takes in experiences and gives the following:
        #states, actions, rewards, nextStates, dones
        #
        #Your code goes in here

        states, actions, rewards, sNexts, dones = zip(*experiences)

        states = torch.FloatTensor(np.array(states))
        actions = torch.FloatTensor(np.array(actions))
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        sNexts = torch.FloatTensor(np.array(sNexts))
        dones = torch.FloatTensor(dones).unsqueeze(1)

        # finally returning all the separated numpy arrays
        return states, actions, rewards, sNexts, dones

# %%
class ReplayBuffer(ReplayBuffer):
    def length(self):
        #tells the number of experiences stored in the internal buffer
        #
        #Your code goes in here
        #
        bufferSize = len(self.buffer)
        return bufferSize

# %% [markdown]
# # Deep Policy Based RL agents.
# <a id="deep-policy-based"></a>

# %% [markdown]
# **The purpose of this part is to learn about different Deep Policy Based RL agents.**
#
# In this part of the assignment you will be implementing Deep Policy based RL algorithms we learnt in Lectures. Namely, we will be implementing REINFORCE and VPG.
#
# For all the algorithms below, this time we will not be specifying the hyper-parameters, please play with the hyper-params to come up with the best values. This way you will learn to tune the model. Some of the values were specified in the lecture, that would be a good starting point.

# %% [markdown]
# #REINFORCE [40 marks]

# %% [markdown]
# Implement the REINFORCE algorithm. We have studied about REINFORCE algorithm in the Lecture. Use the function definitions (given below).
#
# This class implements the REINFORCE Agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# ```
# class REINFORCE():
#     def __init__(env, seed, gamma,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runREINFORCE(self)
#     def trainAgent(self)
#     def trainPolicyNetwork(self, experiences)
#     def evaluateAgent(self)
# ```

# %% [markdown]
# ### Implement the methods for the REINFORCE class below

# %%
# def __init__
class Reinforce():
    def __init__(self, env, seed, gamma, optimizerFn, optimizerLR,
                MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                explorationStrategyTrainFn, explorationStrategyEvalFn):

        self.env = env
        self.seed = seed

        self.env.reset(seed=self.seed)
        self.env.action_space.seed(self.seed)
        self.env.observation_space.seed(self.seed)
        np.random.seed(seed=self.seed)
        random.seed(self.seed)
        torch.manual_seed(self.seed)

        self.gamma = gamma
        self.optimizerFn = optimizerFn
        self.optimizerLR = optimizerLR
        self.epsilon = epsilon
        self.render = False

        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES

        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn

        inDim = self.env.observation_space.shape[0]
        outDim = self.env.action_space.shape[0]
        self.policy_network = createPolicyNetwork(inDim, outDim, hDim=[512, 324, 256])

        self.optimizer = self.optimizerFn(self.policy_network.parameters(), lr=self.optimizerLR)
        self.initBookKeeping()

# %%
# def initBookKeeping
class Reinforce(Reinforce):
    def initBookKeeping(self):

        self.trainRewardsList = []
        self.evalRewardsList = []
        self.trainTimeList = []
        self.wallClockTimeList = []
        self.totalStepsList = []

        self.startTime = time.time()

# %%
# def performBookKeeping
class Reinforce(Reinforce):
    def performBookKeeping(self, train = True):

       currentTime = time.time()
       if train:
           trainTime = currentTime - self.startTime
           self.trainTimeList.append(trainTime)
       else :
           wallClock = currentTime - self.startTime
           self.wallClockTimeList.append(wallClock)

# %%
# def runREINFORCE
class Reinforce(Reinforce):
    def runREINFORCE(self):
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
        finalEvalReward = self.evaluateAgent()
        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward

# %%
# def trainAgent
class Reinforce(Reinforce):
    def trainAgent(self):
        for e in range(self.MAX_TRAIN_EPISODES):
            s, done = self.env.reset()
            rewards, logProbs = [], []
            train_steps = 0
            while not done:
                a, logp_a, _ = self.explorationStrategyTrainFn(self.policy_network, s, self.env)
                s, r, done, truncated, _ = self.env.step(a)
                done = done or truncated

                rewards.append(r)
                logProbs.append(logp_a)
                train_steps += 1

            self.totalStepsList.append(train_steps)
            self.trainRewardsList.append(np.sum(rewards))
            self.trainPolicyNetwork(rewards, logProbs)
            self.performBookKeeping(train = True)

            evalRmean, _ = self.evaluateAgent()
            self.evalRewardsList.append(evalRmean)
            self.performBookKeeping(train = False)
            if (e+1) % 10 == 0:
                print(f"[Episode {e+1}] Mean Train Reward = {np.sum(rewards):.2f} | Mean Eval Reward = {evalRmean:.2f}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList, self.wallClockTimeList, self.totalStepsList

# %%
# def trainPolicyNetwork
class Reinforce(Reinforce):
    def trainPolicyNetwork(self, rewards, logProbs):
        returns, gammas = getStepWiseReturnsAndDiscounts(self.gamma, rewards)
        baseline = returns.mean()
        advantages = returns - baseline
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        logProbs = torch.stack(logProbs).squeeze()
        policyLoss = -1.0 * (gammas * advantages * logProbs).mean()

        self.optimizer.zero_grad()
        policyLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_network.parameters(), MAX_GRAD_NORM_POLICY)
        self.optimizer.step()

# %%
# def evaluateAgent
class Reinforce(Reinforce):
    def evaluateAgent(self, greedy = True):
        rewards = []
        for _ in range(self.MAX_EVAL_EPISODES):
            rs, done = 0, 0
            s, _ = self.env.reset()
            for _ in count():
                if greedy:
                    a = self.explorationStrategyEvalFn(self.policy_network, s, self.env)
                else:
                    a, _, _ = self.explorationStrategyTrainFn(self.policy_network, s, self.env)

                s, r, done, truncated, _ = self.env.step(a)
                rs += r
                if done or truncated:
                    rewards.append(rs)
                    break

        rewards = np.array(rewards)
        return rewards.mean(), rewards.std()

# %%
# evaluating the REINFORCE agent on multiple continuous-control

# Environments used in this experiment
rein_env_name = "Pendulum-v1"
reinforceQuantityDict = {}

# Number of independent training runs per environment
num_runs = 5

# For each environment:
print(f"\n===== Environment: {rein_env_name} =====")

all_train_rewards = []
all_eval_rewards = []
all_train_times = []
all_total_steps = []
all_wall_times = []

for run in range(num_runs):
    print(f"Executing Run {run+1}  ")

    # Create environment
    env = gym.make(rein_env_name)

    # Initialize Reinforce agent
    agent = Reinforce(
        env=env, seed=base_seed+run, gamma=gamma,
        optimizerFn=optimizerFn, optimizerLR=optimizerLR,
        MAX_TRAIN_EPISODES=MAX_TRAIN_EPISODES,
        MAX_EVAL_EPISODES=MAX_EVAL_EPISODES,
        explorationStrategyTrainFn=selectAction,
        explorationStrategyEvalFn=selectGreedyAction
    )

    # Run training
    train_rewards, train_times, eval_rewards, wall_clock_times, total_steps, final_eval_reward = agent.runREINFORCE()

    print(f"Finished Run {run+1}  ")

    all_train_rewards.append(train_rewards)
    all_eval_rewards.append(eval_rewards)
    all_train_times.append(train_times)
    all_wall_times.append(wall_clock_times)
    all_total_steps.append(total_steps)


reinforceQuantityDict[rein_env_name] = {
    "Mean Train Rewards": {
        "REINFORCE": all_train_rewards
    },
    "Mean Eval Rewards": {
        "REINFORCE": all_eval_rewards
    },
    "Train Time (in sec)": {
        "REINFORCE": all_train_times
    },
    "Wall Clock Time (in sec)": {
        "REINFORCE": all_wall_times
    },
    "Total Steps": {
        "REINFORCE": all_total_steps
    }
}

# Compute Statistics
train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"\n(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
print(f"Finished {rein_env_name}")
# Out:
# ===== Environment: Pendulum-v1 =====
# Executing Run 1
# [Episode 10] Mean Train Reward = -1807.43 | Mean Eval Reward = -1651.46
# [Episode 20] Mean Train Reward = -1868.24 | Mean Eval Reward = -1771.26
# [Episode 30] Mean Train Reward = -1814.31 | Mean Eval Reward = -1731.12
# [Episode 40] Mean Train Reward = -1780.00 | Mean Eval Reward = -1686.03
# [Episode 50] Mean Train Reward = -1813.54 | Mean Eval Reward = -1704.69
# [Episode 60] Mean Train Reward = -1550.06 | Mean Eval Reward = -1728.12
# [Episode 70] Mean Train Reward = -1784.01 | Mean Eval Reward = -1535.00
# [Episode 80] Mean Train Reward = -1742.29 | Mean Eval Reward = -1585.07
# [Episode 90] Mean Train Reward = -1647.77 | Mean Eval Reward = -1677.09
# [Episode 100] Mean Train Reward = -1535.89 | Mean Eval Reward = -1639.28
# [Episode 110] Mean Train Reward = -1645.62 | Mean Eval Reward = -1609.41
# [Episode 120] Mean Train Reward = -1660.31 | Mean Eval Reward = -1579.34
# [Episode 130] Mean Train Reward = -1398.39 | Mean Eval Reward = -1601.72
# [Episode 140] Mean Train Reward = -1630.05 | Mean Eval Reward = -1576.63
# [Episode 150] Mean Train Reward = -1647.28 | Mean Eval Reward = -1586.92
# Finished Run 1
# Executing Run 2
# [Episode 10] Mean Train Reward = -1433.10 | Mean Eval Reward = -1665.01
# [Episode 20] Mean Train Reward = -1332.83 | Mean Eval Reward = -1662.72
# [Episode 30] Mean Train Reward = -1560.77 | Mean Eval Reward = -1658.92
# [Episode 40] Mean Train Reward = -1182.32 | Mean Eval Reward = -1183.05
# [Episode 50] Mean Train Reward = -1507.97 | Mean Eval Reward = -1628.75
# [Episode 60] Mean Train Reward = -1442.60 | Mean Eval Reward = -1551.69
# [Episode 70] Mean Train Reward = -1565.72 | Mean Eval Reward = -1339.11
# [Episode 80] Mean Train Reward = -1588.74 | Mean Eval Reward = -1358.96
# [Episode 90] Mean Train Reward = -1428.29 | Mean Eval Reward = -1559.36
# [Episode 100] Mean Train Reward = -1206.12 | Mean Eval Reward = -1353.62
# [Episode 110] Mean Train Reward = -1609.39 | Mean Eval Reward = -1525.03
# [Episode 120] Mean Train Reward = -1389.85 | Mean Eval Reward = -1215.16
# [Episode 130] Mean Train Reward = -1383.37 | Mean Eval Reward = -1607.03
# [Episode 140] Mean Train Reward = -1444.32 | Mean Eval Reward = -1503.99
# [Episode 150] Mean Train Reward = -1154.71 | Mean Eval Reward = -1289.42
# Finished Run 2
# Executing Run 3
# [Episode 10] Mean Train Reward = -1488.35 | Mean Eval Reward = -1540.85
# [Episode 20] Mean Train Reward = -1566.49 | Mean Eval Reward = -1594.80
# [Episode 30] Mean Train Reward = -1385.69 | Mean Eval Reward = -1591.41
# [Episode 40] Mean Train Reward = -1561.95 | Mean Eval Reward = -1594.53
# [Episode 50] Mean Train Reward = -1541.74 | Mean Eval Reward = -1595.10
# [Episode 60] Mean Train Reward = -1552.12 | Mean Eval Reward = -1683.20
# [Episode 70] Mean Train Reward = -1510.84 | Mean Eval Reward = -1613.40
# [Episode 80] Mean Train Reward = -1479.41 | Mean Eval Reward = -1572.52
# [Episode 90] Mean Train Reward = -1551.97 | Mean Eval Reward = -1592.66
# [Episode 100] Mean Train Reward = -1504.56 | Mean Eval Reward = -1665.07
# [Episode 110] Mean Train Reward = -1535.24 | Mean Eval Reward = -1562.93
# [Episode 120] Mean Train Reward = -1528.59 | Mean Eval Reward = -1604.55
# [Episode 130] Mean Train Reward = -1554.92 | Mean Eval Reward = -1565.31
# [Episode 140] Mean Train Reward = -1499.13 | Mean Eval Reward = -1627.89
# [Episode 150] Mean Train Reward = -1546.82 | Mean Eval Reward = -1585.76
# Finished Run 3
# Executing Run 4
# [Episode 10] Mean Train Reward = -1360.63 | Mean Eval Reward = -1619.12
# [Episode 20] Mean Train Reward = -1056.37 | Mean Eval Reward = -1275.11
# [Episode 30] Mean Train Reward = -1380.34 | Mean Eval Reward = -1679.06
# [Episode 40] Mean Train Reward = -1389.21 | Mean Eval Reward = -1442.25
# [Episode 50] Mean Train Reward = -1175.11 | Mean Eval Reward = -1381.79
# [Episode 60] Mean Train Reward = -1281.72 | Mean Eval Reward = -1551.90
# [Episode 70] Mean Train Reward = -1612.39 | Mean Eval Reward = -1482.80
# [Episode 80] Mean Train Reward = -1551.07 | Mean Eval Reward = -1512.96
# [Episode 90] Mean Train Reward = -1186.21 | Mean Eval Reward = -1514.23
# [Episode 100] Mean Train Reward = -1357.29 | Mean Eval Reward = -1673.69
# [Episode 110] Mean Train Reward = -1186.54 | Mean Eval Reward = -1606.31
# [Episode 120] Mean Train Reward = -1170.13 | Mean Eval Reward = -1010.78
# [Episode 130] Mean Train Reward = -1358.74 | Mean Eval Reward = -1015.29
# [Episode 140] Mean Train Reward = -1406.41 | Mean Eval Reward = -1605.70
# [Episode 150] Mean Train Reward = -1542.43 | Mean Eval Reward = -1642.01
# Finished Run 4
# Executing Run 5
# [Episode 10] Mean Train Reward = -1333.04 | Mean Eval Reward = -1410.21
# [Episode 20] Mean Train Reward = -1281.89 | Mean Eval Reward = -1771.60
# [Episode 30] Mean Train Reward = -1066.31 | Mean Eval Reward = -1517.03
# [Episode 40] Mean Train Reward = -1548.61 | Mean Eval Reward = -1601.82
# [Episode 50] Mean Train Reward = -1429.63 | Mean Eval Reward = -1667.01
# [Episode 60] Mean Train Reward = -1584.39 | Mean Eval Reward = -1660.61
# [Episode 70] Mean Train Reward = -1660.65 | Mean Eval Reward = -1668.42
# [Episode 80] Mean Train Reward = -1608.08 | Mean Eval Reward = -1623.80
# [Episode 90] Mean Train Reward = -1655.61 | Mean Eval Reward = -1615.78
# [Episode 100] Mean Train Reward = -1563.16 | Mean Eval Reward = -1550.99
# [Episode 110] Mean Train Reward = -1518.10 | Mean Eval Reward = -1531.91
# [Episode 120] Mean Train Reward = -1600.23 | Mean Eval Reward = -1416.86
# [Episode 130] Mean Train Reward = -1534.28 | Mean Eval Reward = -1498.41
# [Episode 140] Mean Train Reward = -1481.26 | Mean Eval Reward = -1392.54
# [Episode 150] Mean Train Reward = -1387.93 | Mean Eval Reward = -1498.80
# Finished Run 5
#
# (Mean over last 50 epiosdes) Mean train rewards: -1495.07 | Mean Eval Score: -1507.52
# Finished Pendulum-v1

# %%
with open(SAVE_PATH_REIN, "wb") as f:
    pickle.dump(reinforceQuantityDict, f)

# %% [markdown]
# # Vanilla Policy Gradient (VPG) [40 marks]

# %% [markdown]
# Implement the VPG algorithm. We have studied about VPG algorithm in the Lecture. Use the function definitions (given below).
#
# This class implements the VPG Agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment.
# Run one environment: 'Pendulum-v1'
#
#
# ```
# class VPG():
#     def __init__(env, seed, gamma, beta,
#                  optimizerFn,
#                  optimizerLR,
#                  MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
#                  explorationStrategyTrainFn,
#                  explorationStrategyEvalFn)
#     def initBookKeeping(self)
#     def performBookKeeping(self, train = True)
#     def runVPG(self)
#     def trainAgent(self)
#     def trainPolicyNetwork(self, experiences)
#     def evaluateAgent(self)
# ```

# %%
# def __init__
class VPG():
    def __init__(self, env, seed, gamma, beta, optimizerFn, optimizerLR,
                MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
                explorationStrategyTrainFn, explorationStrategyEvalFn):

        self.env = env
        self.seed = seed

        self.env.reset(seed=self.seed)
        self.env.action_space.seed(self.seed)
        self.env.observation_space.seed(self.seed)
        np.random.seed(seed=self.seed)
        random.seed(self.seed)
        torch.manual_seed(self.seed)

        self.gamma = gamma
        self.beta = beta
        self.optimizerFn = optimizerFn
        self.optimizerLR = optimizerLR
        self.epsilon = epsilon
        self.render = False

        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODES = MAX_EVAL_EPISODES

        self.explorationStrategyTrainFn = explorationStrategyTrainFn
        self.explorationStrategyEvalFn = explorationStrategyEvalFn

        inDim = self.env.observation_space.shape[0]
        outDim = self.env.action_space.shape[0]

        self.policy_network = createPolicyNetwork(inDim, outDim, hDim=[512, 324, 256])
        self.value_network = createValueNetwork(inDim, 1, hDim=[512, 324, 256])
        self.policyOptimizer = self.optimizerFn(self.policy_network.parameters(), lr=self.optimizerLR)
        self.valueOptimizer = self.optimizerFn(self.value_network.parameters(), lr=self.optimizerLR)

        self.initBookKeeping()

# %%
# def initBookKeeping
class VPG(VPG):
    def initBookKeeping(self):

        self.trainRewardsList = []
        self.evalRewardsList = []
        self.trainTimeList = []
        self.wallClockTimeList = []
        self.totalStepsList = []

        self.startTime = time.time()

# %%
# def performBookKeeping
class VPG(VPG):
    def performBookKeeping(self, train = True):

       currentTime = time.time()
       if train:
           trainTime = currentTime - self.startTime
           self.trainTimeList.append(trainTime)
       else :
           wallClock = currentTime - self.startTime
           self.wallClockTimeList.append(wallClock)

# %%
# def runVPG
class VPG(VPG):
    def runVPG(self):
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
        finalEvalReward = self.evaluateAgent()

        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward

# %%
# def trainAgent
class VPG(VPG):
    def trainAgent(self):
        for e in range(self.MAX_TRAIN_EPISODES):
            s, done = self.env.reset()
            rewards, logProbs = [], []
            entropies, values = [], []
            train_steps = 0
            while not done:
                a, logp_a, entropy_pa = self.explorationStrategyTrainFn(self.policy_network, s, self.env)
                state = torch.FloatTensor(s).unsqueeze(0)
                value = self.value_network(state)
                s, r, done, truncated, _ = self.env.step(a)
                done = done or truncated

                rewards.append(r)
                logProbs.append(logp_a)
                entropies.append(entropy_pa)
                values.append(value.squeeze())
                train_steps += 1

            self.totalStepsList.append(train_steps)
            self.trainRewardsList.append(np.sum(rewards))
            self.trainPolicyAndValueNetwork(rewards, logProbs, entropies, values)
            self.performBookKeeping(train = True)

            evalRmean, _ = self.evaluateAgent()
            self.evalRewardsList.append(evalRmean)
            self.performBookKeeping(train = False)
            if (e+1) % 10 == 0:
                print(f"[worker {self.seed}] [Episode {e+1}] Mean Train Reward = {np.sum(rewards):.2f} | Mean Eval Reward = {evalRmean:.2f}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList, self.wallClockTimeList, self.totalStepsList

# %%
# def trainPolicyNetwork
class VPG(VPG):
    def trainPolicyAndValueNetwork(self, rewards, logProbs, entropies, values):
        returns, gammas = getStepWiseReturnsAndDiscounts(self.gamma, rewards)
        logProbs = torch.stack(logProbs).squeeze()
        entropies = torch.stack(entropies).squeeze()
        values = torch.stack(values).squeeze()

        deltas = returns - values
        deltas = (deltas - deltas.mean()) / (deltas.std() + 1e-6)

        baselineLoss = -1.0 * (gammas * deltas.detach() * logProbs).mean()
        entropyLoss = -1.0 * entropies.mean()
        policyLoss = baselineLoss + self.beta * entropyLoss

        self.policyOptimizer.zero_grad()
        policyLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_network.parameters(), MAX_GRAD_NORM_POLICY)
        self.policyOptimizer.step()

        valueLoss = 0.5 * (deltas ** 2)
        valueLoss = valueLoss.mean()
        self.valueOptimizer.zero_grad()
        valueLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.value_network.parameters(), MAX_GRAD_NORM_VALUE)
        self.valueOptimizer.step()

# %%
# def evaluateAgent
class VPG(VPG):
    def evaluateAgent(self, greedy = True):
        rewards = []
        for _ in range(self.MAX_EVAL_EPISODES):
            rs, done = 0, 0
            s, _ = self.env.reset()
            for _ in count():
                if greedy:
                    a = self.explorationStrategyEvalFn(self.policy_network, s, self.env)
                else:
                    a, _ = self.explorationStrategyTrainFn(self.policy_network, s, self.env)

                s, r, done, truncated, _ = self.env.step(a)
                rs += r
                if done or truncated:
                    rewards.append(rs)
                    break

        rewards = np.array(rewards)
        return rewards.mean(), rewards.std()

# %%
# evaluating the VPG agent on multiple continuous-control

# Environments used in this experiment
vpg_env_name = "Pendulum-v1"

quantityDictVPG = {}

# Number of independent training runs per environment
num_runs = 5

all_train_rewards = []
all_eval_rewards = []
all_train_times = []
all_total_steps = []
all_wall_times = []

# For each environment:
print(f"\n===== Environment: {vpg_env_name} =====")

for run in range(num_runs):
    print(f"Executing Run {run+1}  ")

    # Create environment
    env = gym.make(vpg_env_name)

    # Initialize SAC agent
    agent = VPG(
        env=env, seed=base_seed+run, gamma=gamma, beta=beta,
        optimizerFn=optimizerFn, optimizerLR=optimizerLR,
        MAX_TRAIN_EPISODES=MAX_TRAIN_EPISODES,
        MAX_EVAL_EPISODES=MAX_EVAL_EPISODES,
        explorationStrategyTrainFn=selectAction,
        explorationStrategyEvalFn=selectGreedyAction
    )

    # Run training
    train_rewards, train_times, eval_rewards, wall_clock_times, total_steps, final_eval_reward = agent.runVPG()
    print(f"Finished Run {run+1}")

    all_train_rewards.append(train_rewards)
    all_eval_rewards.append(eval_rewards)
    all_train_times.append(train_times)
    all_wall_times.append(wall_clock_times)
    all_total_steps.append(total_steps)

quantityDictVPG[vpg_env_name] = {
    "Mean Train Rewards": {
        "VPG": all_train_rewards
    },
    "Mean Eval Rewards": {
        "VPG": all_eval_rewards
    },
    "Train Time (in sec)": {
        "VPG": all_train_times
    },
    "Wall Clock Time (in sec)": {
        "VPG": all_wall_times
    },
    "Total Steps": {
        "VPG": all_total_steps
    }
}

# Compute Statistics
train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"\n(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
print(f"Finished {vpg_env_name}")
# Out:
# ===== Environment: Pendulum-v1 =====
# Executing Run 1
# [Episode 10] Mean Train Reward = -1305.58 | Mean Eval Reward = -1417.43
# [Episode 20] Mean Train Reward = -1389.19 | Mean Eval Reward = -1598.64
# [Episode 30] Mean Train Reward = -1390.42 | Mean Eval Reward = -1669.32
# [Episode 40] Mean Train Reward = -1482.30 | Mean Eval Reward = -1658.46
# [Episode 50] Mean Train Reward = -1405.28 | Mean Eval Reward = -1685.33
# [Episode 60] Mean Train Reward = -1257.88 | Mean Eval Reward = -1577.96
# [Episode 70] Mean Train Reward = -1565.42 | Mean Eval Reward = -1578.36
# [Episode 80] Mean Train Reward = -1402.11 | Mean Eval Reward = -1611.57
# [Episode 90] Mean Train Reward = -1549.56 | Mean Eval Reward = -1530.88
# [Episode 100] Mean Train Reward = -1564.92 | Mean Eval Reward = -1596.32
# [Episode 110] Mean Train Reward = -1551.34 | Mean Eval Reward = -1662.36
# [Episode 120] Mean Train Reward = -1561.79 | Mean Eval Reward = -1659.23
# [Episode 130] Mean Train Reward = -1537.19 | Mean Eval Reward = -1674.77
# [Episode 140] Mean Train Reward = -1569.54 | Mean Eval Reward = -1677.05
# [Episode 150] Mean Train Reward = -1421.13 | Mean Eval Reward = -1584.25
# Finished Run 1
# Executing Run 2
# [Episode 10] Mean Train Reward = -1036.92 | Mean Eval Reward = -1393.33
# [Episode 20] Mean Train Reward = -1295.55 | Mean Eval Reward = -1540.84
# [Episode 30] Mean Train Reward = -1537.22 | Mean Eval Reward = -1589.76
# [Episode 40] Mean Train Reward = -1363.43 | Mean Eval Reward = -1541.14
# [Episode 50] Mean Train Reward = -1477.92 | Mean Eval Reward = -1618.41
# [Episode 60] Mean Train Reward = -1283.04 | Mean Eval Reward = -1413.91
# [Episode 70] Mean Train Reward = -1324.53 | Mean Eval Reward = -1538.27
# [Episode 80] Mean Train Reward = -1420.61 | Mean Eval Reward = -1464.18
# [Episode 90] Mean Train Reward = -1422.74 | Mean Eval Reward = -1549.33
# [Episode 100] Mean Train Reward = -1168.54 | Mean Eval Reward = -1286.60
# [Episode 110] Mean Train Reward = -1504.31 | Mean Eval Reward = -1451.33
# [Episode 120] Mean Train Reward = -1411.88 | Mean Eval Reward = -1209.22
# [Episode 130] Mean Train Reward = -1149.22 | Mean Eval Reward = -1606.02
# [Episode 140] Mean Train Reward = -1446.90 | Mean Eval Reward = -1521.43
# [Episode 150] Mean Train Reward = -1170.18 | Mean Eval Reward = -1288.37
# Finished Run 2
# Executing Run 3
# [Episode 10] Mean Train Reward = -1322.83 | Mean Eval Reward = -1365.39
# [Episode 20] Mean Train Reward = -1561.85 | Mean Eval Reward = -1732.72
# [Episode 30] Mean Train Reward = -1555.91 | Mean Eval Reward = -1622.46
# [Episode 40] Mean Train Reward = -1567.23 | Mean Eval Reward = -1230.33
# [Episode 50] Mean Train Reward = -1224.12 | Mean Eval Reward = -1224.00
# [Episode 60] Mean Train Reward = -1557.72 | Mean Eval Reward = -1685.07
# [Episode 70] Mean Train Reward = -1171.74 | Mean Eval Reward = -1331.49
# [Episode 80] Mean Train Reward = -1230.29 | Mean Eval Reward = -1580.01
# [Episode 90] Mean Train Reward = -915.06 | Mean Eval Reward = -1118.11
# [Episode 100] Mean Train Reward = -1543.49 | Mean Eval Reward = -1671.60
# [Episode 110] Mean Train Reward = -1563.90 | Mean Eval Reward = -1493.23
# [Episode 120] Mean Train Reward = -1443.61 | Mean Eval Reward = -1175.86
# [Episode 130] Mean Train Reward = -1157.40 | Mean Eval Reward = -1571.47
# [Episode 140] Mean Train Reward = -1359.79 | Mean Eval Reward = -1642.44
# [Episode 150] Mean Train Reward = -1262.71 | Mean Eval Reward = -1430.45
# Finished Run 3
# Executing Run 4
# [Episode 10] Mean Train Reward = -1624.68 | Mean Eval Reward = -1814.53
# [Episode 20] Mean Train Reward = -1779.29 | Mean Eval Reward = -1879.07
# [Episode 30] Mean Train Reward = -1521.61 | Mean Eval Reward = -1874.60
# [Episode 40] Mean Train Reward = -1445.87 | Mean Eval Reward = -1843.33
# [Episode 50] Mean Train Reward = -1563.52 | Mean Eval Reward = -1669.50
# [Episode 60] Mean Train Reward = -1727.21 | Mean Eval Reward = -1690.18
# [Episode 70] Mean Train Reward = -1705.95 | Mean Eval Reward = -1690.76
# [Episode 80] Mean Train Reward = -1593.39 | Mean Eval Reward = -1646.50
# [Episode 90] Mean Train Reward = -1319.94 | Mean Eval Reward = -1596.75
# [Episode 100] Mean Train Reward = -1330.04 | Mean Eval Reward = -1412.82
# [Episode 110] Mean Train Reward = -1546.21 | Mean Eval Reward = -1587.09
# [Episode 120] Mean Train Reward = -1548.99 | Mean Eval Reward = -1653.74
# [Episode 130] Mean Train Reward = -1534.48 | Mean Eval Reward = -1527.29
# [Episode 140] Mean Train Reward = -1084.12 | Mean Eval Reward = -1604.23
# [Episode 150] Mean Train Reward = -1311.65 | Mean Eval Reward = -842.39
# Finished Run 4
# Executing Run 5
# [Episode 10] Mean Train Reward = -1389.10 | Mean Eval Reward = -1515.35
# [Episode 20] Mean Train Reward = -1435.82 | Mean Eval Reward = -1345.83
# [Episode 30] Mean Train Reward = -1362.17 | Mean Eval Reward = -1655.73
# [Episode 40] Mean Train Reward = -1562.20 | Mean Eval Reward = -1193.02
# [Episode 50] Mean Train Reward = -1379.21 | Mean Eval Reward = -1321.42
# [Episode 60] Mean Train Reward = -1555.89 | Mean Eval Reward = -1639.62
# [Episode 70] Mean Train Reward = -1330.29 | Mean Eval Reward = -1452.24
# [Episode 80] Mean Train Reward = -1558.51 | Mean Eval Reward = -1673.79
# [Episode 90] Mean Train Reward = -1248.72 | Mean Eval Reward = -1172.25
# [Episode 100] Mean Train Reward = -1186.65 | Mean Eval Reward = -1649.83
# [Episode 110] Mean Train Reward = -1539.65 | Mean Eval Reward = -1639.47
# [Episode 120] Mean Train Reward = -1299.37 | Mean Eval Reward = -1558.33
# [Episode 130] Mean Train Reward = -1564.10 | Mean Eval Reward = -1374.33
# [Episode 140] Mean Train Reward = -1057.83 | Mean Eval Reward = -1640.37
# [Episode 150] Mean Train Reward = -1192.18 | Mean Eval Reward = -1329.62
# Finished Run 5
#
# (Mean over last 50 epiosdes) Mean train rewards: -1433.48 | Mean Eval Score: -1477.24
# Finished Pendulum-v1

# %%
with open(SAVE_PATH_VPG, "wb") as f:
    pickle.dump(quantityDictVPG, f)

# %% [markdown]
# # Asynchronous Advantange Actor-Critic (A3C) [50 marks]
# <a id="a3c"></a>
#
# A3C (Mnih et al., 2016) was one of the first successful deep RL algorithms to train on CPU using parallel workers. Each worker maintains its own copy of the environment and policy, collects experience independently, and asynchronously pushes gradient updates to a shared global network.
#
# **Key ideas:**
# - Multiple worker processes each interact with their own environment copy.
# - Each worker computes gradients locally and applies them to a **shared global network** asynchronously (no waiting for other workers).
# - The asynchronous updates provide natural exploration diversity (different workers explore different parts of the state space).
# - Uses n-step returns and advantage estimation similar to A2C.
#
# **Update rule per worker:**
# $$\theta \leftarrow \theta + \alpha \nabla_\theta \log \pi_\theta(a_t|s_t) \cdot A(s_t, a_t)$$
#
# where the gradient is computed by the worker and applied to the shared $\theta$.
#
# **Note:** True A3C requires `multiprocessing` with shared memory. Below we implement it using `torch.multiprocessing` with shared parameters.
#
# ```
# class SharedAdam(optim.Adam)   # Adam optimizer with shared state
# class A3CAgent(nn.Module)      # Same architecture as A2C
# def a3c_worker(...)            # Worker process
# def train_a3c(...)             # Main launcher
# ```

# %%
# ======================================================================
# A3C Implementation
# ======================================================================

import torch.multiprocessing as mp
from queue import Empty

# A3C Hyperparameters
a3c_gym_id = 'Hopper-v4'
a3c_learning_rate = 1e-4
a3c_gamma = 0.99
a3c_num_workers = 10                         # Number of asynchronous worker processes
a3c_num_steps = 15                           # n-step return length per worker
a3c_max_episodes_per_worker = 3000
a3c_ent_coef = 1e-5
a3c_vf_coef = 0.52
a3c_max_grad_norm = 0.5

# %%
# i created this method for checcking the evaluation reward trend in A3C and A2C
# although not mentioned to plot it but for but understanding purpose doing it

def evaluate_policy(agent, env_id, episodes=1):
    env = gym.make(env_id)
    rewards = []

    for _ in range(episodes):
        s, _ = env.reset()
        done = False
        total_reward = 0

        while not done:
            with torch.no_grad():
                s_tensor = torch.FloatTensor(s).unsqueeze(0)
                action, _, _, _ = agent.get_action_and_value(s_tensor)

            if agent.is_discrete:
                action = action.item()
            else:
                action_np = action.squeeze(0).detach().cpu().numpy()
                action_np = np.tanh(action_np)
                action_np = np.clip(action_np, env.action_space.low, env.action_space.high)

            s, r, done, truncated, _ = env.step(action_np)
            done = done or truncated
            total_reward += r

        rewards.append(total_reward)

    return np.mean(rewards)

# %%
# ======================================================================
# SharedAdam: Adam optimizer with shared state across processes
# ======================================================================
# Standard Adam stores its internal state (moment estimates) per-process.
# For A3C, we need the optimizer state to be in shared memory so that
# all worker processes update the same momentum buffers.

class SharedAdam(torch.optim.Adam):
    def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8):
        super().__init__(params, lr=lr, betas=betas, eps=eps)

        for group in self.param_groups:
            for p in group['params']:
                state = self.state[p]
                state['step'] = torch.zeros(1).share_memory_()
                state['exp_avg'] = torch.zeros_like(p.data).share_memory_()
                state['exp_avg_sq'] = torch.zeros_like(p.data).share_memory_()

# %%
# ==============================================================
# A3C Agent
# ==============================================================

class A3CAgent(nn.Module):
    """
    A3C agent with separate actor and critic networks.
    Supports both discrete and continuous action spaces.
    """

    def __init__(self, obs_dim, act_dim, is_discrete=False):
        """
        Initialize actor and critic networks.
        obs_dim     : Dimension of observation space
        act_dim     : Dimension of action space
        is_discrete : Whether the action space is discrete
        """

        # Your code goes here
        super(A3CAgent, self).__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.is_discrete = is_discrete

        self.hDim = [512, 324, 256]
        self.actor_network = createPolicyNetwork(obs_dim, act_dim, hDim=self.hDim)
        self.critic_network = createValueNetwork(obs_dim, 1, hDim=self.hDim)

        if not self.is_discrete:
            self.actor_log_std = nn.Parameter(torch.zeros(act_dim))


    def get_value(self, x):
        """
        Return the value estimate for a given state using the critic.
        """
        return self.critic_network(x)


    def get_action_and_value(self, x, action=None):
        """
        Compute action, log probability, entropy, and value.

        For discrete actions:
            create a categorical distribution from actor logits.

        For continuous actions:
            create a normal distribution using mean and std.

        If action is None, sample from the distribution.
        Return action, log probability, entropy, and value.
        """
        value = self.get_value(x)

        if self.is_discrete:
            logits = self.actor_network(x)
            dist = torch.distributions.Categorical(logits=logits)
            if action is None:
                action = dist.sample()
            else:
                action = action.long().squeeze()
            log_prob = dist.log_prob(action)
            entropy = dist.entropy()

        else:
            mu = self.actor_network(x)

            log_std = torch.clamp(self.actor_log_std, -20, 2)
            std = torch.exp(log_std).unsqueeze(0).expand_as(mu)
            dist = torch.distributions.Normal(mu, std)

            if action is None:
                action = dist.sample()
            else:
                action = action.float()
            log_prob = dist.log_prob(action).sum(dim=-1)
            entropy = dist.entropy().sum(dim=-1)

        return action, log_prob, entropy, value

# %%
# A3C Worker (truly parallel via torch.multiprocessing)

def a3c_worker(worker_id, global_agent, global_optimizer, grad_lock,
               env_id, seed, num_episodes,
               gamma, num_steps, ent_coef, vf_coef, max_grad_norm,
               result_queue):
    """
    A3C worker — runs as a separate OS process.

    Each worker independently:
      1. Syncs local weights from the shared global network.
      2. Collects a rollout of num_steps transitions.
      3. Computes n-step returns and advantage.
      4. Computes gradients on its LOCAL network copy.
      5. Pushes those gradients to the GLOBAL network (under lock).
      6. Sends episode reward to main process via result_queue.

    The grad_lock serialises gradient push + optimizer.step() to prevent
    two workers from corrupting each other's gradients.
    """
    env = gym.make(env_id)
    env.reset(seed=seed*10 + worker_id)
    torch.manual_seed(seed*10 + worker_id)
    np.random.seed(seed*10 + worker_id)
    env.action_space.seed(seed*10 + worker_id)
    env.observation_space.seed(seed*10 + worker_id)
    random.seed(seed*10 + worker_id)

    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
    action_high = env.action_space.high if not is_discrete else None
    action_low = env.action_space.low if not is_discrete else None

    local_agent = A3CAgent(obs_dim, act_dim, is_discrete)

    for episode in range(num_episodes):
        state, _ = env.reset()
        train_er = 0
        step_count = 0

        log_probs = []
        values = []
        rewards = []
        entropies = []

        done = False
        truncated = False

        local_agent.load_state_dict(global_agent.state_dict())
        while not (done or truncated):
            for step in range(num_steps):
                state_tensor = torch.FloatTensor(state).unsqueeze(0)
                action, log_prob, entropy, value = local_agent.get_action_and_value(state_tensor)

                if is_discrete:
                    action_np = action.item()
                else:
                    action_np = action.squeeze(0).detach().cpu().numpy()
                    action_np = np.clip(action_np, env.action_space.low, env.action_space.high)

                next_state, reward, done, truncated, _ = env.step(action_np)

                log_probs.append(log_prob)
                values.append(value)
                rewards.append(reward)
                entropies.append(entropy)

                train_er += reward
                step_count += 1
                state = next_state

                if done or truncated:
                    break

            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            with torch.no_grad():
                next_value = local_agent.get_value(state_tensor)
                if done or truncated:
                    next_value = torch.tensor([[0.0]])

            returns, gammas = getStepWiseReturnsAndDiscounts(gamma, rewards, next_value)
            returns = returns.view(-1, 1)
            gammas = gammas.view(-1, 1)

            values_tensor = torch.cat(values)
            log_probs_tensor = torch.cat(log_probs)
            entropies_tensor = torch.stack(entropies)

            advantages = returns - values_tensor

            policy_loss = -(gammas * log_probs_tensor * advantages.detach()).mean()
            value_loss = 0.5 * advantages.pow(2).mean()
            entropy_loss = entropies_tensor.mean()

            total_loss = policy_loss - ent_coef * entropy_loss + vf_coef * value_loss

            local_agent.zero_grad()
            total_loss.backward()
            nn.utils.clip_grad_norm_(local_agent.parameters(), max_grad_norm)

            with grad_lock:
                global_optimizer.zero_grad()
                for local_p, global_p in zip(local_agent.parameters(), global_agent.parameters()):
                    if global_p.grad is None:
                        global_p.grad = local_p.grad.clone()
                    else:
                        global_p.grad += local_p.grad
                global_optimizer.step()

            log_probs = []
            values = []
            rewards = []
            entropies = []

        result_queue.put((worker_id, float(train_er), int(step_count), float(total_loss)))

    env.close()

# %%
# A3C Launcher — spawns truly parallel worker processes

def train_a3c(env_id=a3c_gym_id, seed=base_seed, num_workers=a3c_num_workers,
              episodes_per_worker=a3c_max_episodes_per_worker,
              gamma=a3c_gamma, num_steps=a3c_num_steps, lr=a3c_learning_rate,
              ent_coef=a3c_ent_coef, vf_coef=a3c_vf_coef,
              max_grad_norm=a3c_max_grad_norm):
    """
    Launches A3C training with truly parallel worker processes.

    1. Creates global_agent in shared memory.
    2. Creates SharedAdam (optimizer state also in shared memory).
    3. Creates mp.Lock for gradient push serialisation.
    4. Spawns num_workers mp.Process instances (all start simultaneously).
    5. Main process collects rewards from Queue while workers train.
    6. p.join() waits for all workers to finish.
    """

    # Your code goes here
    env = gym.make(env_id)
    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]
    env.close()

    global_agent = A3CAgent(obs_dim, act_dim, is_discrete=is_discrete)
    global_agent.share_memory()
    global_optimizer = SharedAdam(global_agent.parameters(), lr=lr)
    eval_agent = A3CAgent(obs_dim, act_dim, is_discrete=is_discrete)

    grad_lock = mp.Lock()
    result_queue = mp.Queue()

    print(f"Training A3C on {env_id}")
    print(f"Workers: {num_workers} | Episodes Per Worker: {episodes_per_worker}")

    processes = []
    for worker_id in range(num_workers):
        p = mp.Process(
            target=a3c_worker,
            args=(
                worker_id, global_agent, global_optimizer,
                grad_lock, env_id, seed, episodes_per_worker,
                gamma, num_steps, ent_coef, vf_coef,
                max_grad_norm, result_queue
            )
        )
        p.start()
        processes.append(p)

    total_episodes = num_workers * episodes_per_worker
    episodes = 0
    global_steps = 0

    train_rewards = []
    global_steps_list = []
    total_steps_list = []
    eval_rewards = []

    trg = []
    erg = []

    while episodes < total_episodes:
        while True:
            try:
                worker_id, train_er, e_step, e_loss = result_queue.get_nowait()
                global_steps += e_step
                episodes += 1
                train_rewards.append((episodes, train_er))
                global_steps_list.append((episodes, global_steps))
                total_steps_list.append((episodes, e_step))
                trg.append((global_steps, train_er))

                if episodes % 10 == 0:
                    eval_agent.load_state_dict(global_agent.state_dict())
                    eval_r = evaluate_policy(eval_agent, env_id)
                    eval_rewards.append((episodes, eval_r))
                    erg.append((global_steps, eval_r))

                    print(f"Worker {worker_id} | Episode {episode+1} | Step Counts: {e_step:.0f} | Train Reward: {train_er:.2f} | "
                          f"Global Steps: {global_steps} | Loss: {e_loss:.2f}")
            except Empty:
                break

    for p in processes:
        p.join()

    while not result_queue.empty():
        worker_id, train_er, e_step, e_loss = result_queue.get_nowait()
        global_steps += e_step
        episodes += 1
        train_rewards.append((episodes, train_er))
        global_steps_list.append((episodes, global_steps))
        total_steps_list.append((episodes, e_step))
        trg.append((global_steps, train_er))

        if episodes % 10 == 0:
            eval_agent.load_state_dict(global_agent.state_dict())
            eval_r = evaluate_policy(eval_agent, env_id)
            eval_rewards.append((episodes, eval_r))
            erg.append((global_steps, eval_r))

            print(f"Worker {worker_id} | Episode {episode+1} | Step Counts: {e_step:.0f} | Train Reward: {train_er:.2f} | "
                          f"Global Steps: {global_steps} | Loss: {e_loss:.2f}")


    _, train_rw = zip(*train_rewards)
    _, eval_rw = zip(*eval_rewards)
    print(f"\nTraining Done!\nMean Train Reward (last 40 episodes): {np.mean(train_rw[-40:]):.2f} | Mean Eval Reward (last 40 episodes): {np.mean(eval_rw[-40:]):.2f}")

    return train_rewards, total_steps_list, eval_rewards, global_steps_list, trg, erg

# %%
# Run A3C on all 3 environments
a3c_all_results = {}

# Plot all the graphs
# Your code goes here

rewards, episode_steps, eval_rewards, global_steps, trg, erg = train_a3c()
a3c_all_results[a3c_gym_id] = {
    "Train Rewards": {"A3C": [rewards]},
    "Total Steps": {"A3C": [episode_steps]},
    "Eval Rewards": {"A3C": [eval_rewards]},
    "Global Steps": {"A3C": [global_steps]},
    "Train Rewards (over global steps)": {"A3C": [trg]},
    "Eval Rewards (over global steps)": {"A3C": [erg]}
}
# Out:
# Training A3C on Hopper-v4
# Workers: 6 | Episodes Per Worker: 500
# Worker 0 | Episode 20 | Step Counts: 48 | Train Reward: 86.77
# Worker 5 | Episode 20 | Step Counts: 73 | Train Reward: 140.15
# Worker 4 | Episode 20 | Step Counts: 75 | Train Reward: 71.53
# Worker 3 | Episode 20 | Step Counts: 39 | Train Reward: 35.17
# Worker 2 | Episode 20 | Step Counts: 53 | Train Reward: 99.23
# Worker 1 | Episode 20 | Step Counts: 31 | Train Reward: 33.93
# Worker 5 | Episode 40 | Step Counts: 105 | Train Reward: 216.29
# Worker 0 | Episode 40 | Step Counts: 92 | Train Reward: 184.04
# Worker 2 | Episode 40 | Step Counts: 98 | Train Reward: 184.49
# Worker 3 | Episode 40 | Step Counts: 94 | Train Reward: 171.65
# Worker 4 | Episode 40 | Step Counts: 166 | Train Reward: 293.59
# Worker 1 | Episode 40 | Step Counts: 102 | Train Reward: 227.18
# Worker 5 | Episode 60 | Step Counts: 93 | Train Reward: 213.62
# Worker 0 | Episode 60 | Step Counts: 88 | Train Reward: 185.17
# Worker 2 | Episode 60 | Step Counts: 99 | Train Reward: 216.51
# Worker 4 | Episode 60 | Step Counts: 93 | Train Reward: 205.34
# Worker 3 | Episode 60 | Step Counts: 98 | Train Reward: 224.02
# Worker 1 | Episode 60 | Step Counts: 103 | Train Reward: 230.66
# Worker 5 | Episode 80 | Step Counts: 99 | Train Reward: 223.58
# Worker 3 | Episode 80 | Step Counts: 100 | Train Reward: 222.36
# Worker 2 | Episode 80 | Step Counts: 97 | Train Reward: 215.09
# Worker 4 | Episode 80 | Step Counts: 108 | Train Reward: 216.74
# Worker 0 | Episode 80 | Step Counts: 91 | Train Reward: 202.21
# Worker 1 | Episode 80 | Step Counts: 88 | Train Reward: 198.59
# Worker 5 | Episode 100 | Step Counts: 47 | Train Reward: 88.33
# Worker 2 | Episode 100 | Step Counts: 20 | Train Reward: 29.61
# Worker 3 | Episode 100 | Step Counts: 38 | Train Reward: 66.74
# Worker 0 | Episode 100 | Step Counts: 25 | Train Reward: 40.09
# Worker 4 | Episode 100 | Step Counts: 76 | Train Reward: 144.47
# Worker 1 | Episode 100 | Step Counts: 89 | Train Reward: 172.39
# Worker 5 | Episode 120 | Step Counts: 15 | Train Reward: 20.66
# Worker 2 | Episode 120 | Step Counts: 15 | Train Reward: 20.96
# Worker 3 | Episode 120 | Step Counts: 55 | Train Reward: 99.01
# Worker 0 | Episode 120 | Step Counts: 86 | Train Reward: 173.13
# Worker 4 | Episode 120 | Step Counts: 83 | Train Reward: 180.49
# Worker 1 | Episode 120 | Step Counts: 84 | Train Reward: 184.83
# Worker 5 | Episode 140 | Step Counts: 92 | Train Reward: 184.21
# Worker 3 | Episode 140 | Step Counts: 85 | Train Reward: 173.53
# Worker 2 | Episode 140 | Step Counts: 104 | Train Reward: 202.66
# Worker 0 | Episode 140 | Step Counts: 108 | Train Reward: 223.46
# Worker 4 | Episode 140 | Step Counts: 50 | Train Reward: 72.61
# Worker 1 | Episode 140 | Step Counts: 105 | Train Reward: 194.26
# Worker 5 | Episode 160 | Step Counts: 66 | Train Reward: 121.06
# Worker 3 | Episode 160 | Step Counts: 77 | Train Reward: 141.33
# Worker 0 | Episode 160 | Step Counts: 155 | Train Reward: 276.10
# Worker 2 | Episode 160 | Step Counts: 63 | Train Reward: 112.10
# Worker 4 | Episode 160 | Step Counts: 89 | Train Reward: 93.91
# Worker 1 | Episode 160 | Step Counts: 126 | Train Reward: 134.73
# Worker 5 | Episode 180 | Step Counts: 111 | Train Reward: 236.53
# Worker 2 | Episode 180 | Step Counts: 132 | Train Reward: 359.39
# Worker 0 | Episode 180 | Step Counts: 22 | Train Reward: 0.80
# Worker 4 | Episode 180 | Step Counts: 20 | Train Reward: 0.61
# Worker 3 | Episode 180 | Step Counts: 18 | Train Reward: -1.16
# Worker 1 | Episode 180 | Step Counts: 21 | Train Reward: 1.10
# Worker 5 | Episode 200 | Step Counts: 27 | Train Reward: 47.65
# Worker 0 | Episode 200 | Step Counts: 18 | Train Reward: -0.62
# Worker 2 | Episode 200 | Step Counts: 45 | Train Reward: 80.36
# Worker 4 | Episode 200 | Step Counts: 43 | Train Reward: 77.09
# Worker 3 | Episode 200 | Step Counts: 59 | Train Reward: 81.45
# Worker 1 | Episode 200 | Step Counts: 37 | Train Reward: 64.71
# Worker 5 | Episode 220 | Step Counts: 20 | Train Reward: -0.91
# Worker 0 | Episode 220 | Step Counts: 19 | Train Reward: -1.73
# Worker 2 | Episode 220 | Step Counts: 18 | Train Reward: -0.56
# Worker 4 | Episode 220 | Step Counts: 49 | Train Reward: 88.76
# Worker 3 | Episode 220 | Step Counts: 49 | Train Reward: 89.67
# Worker 1 | Episode 220 | Step Counts: 46 | Train Reward: 81.98
# Worker 0 | Episode 240 | Step Counts: 117 | Train Reward: 289.90
# Worker 5 | Episode 240 | Step Counts: 34 | Train Reward: 56.31
# Worker 2 | Episode 240 | Step Counts: 47 | Train Reward: 83.90
# Worker 4 | Episode 240 | Step Counts: 50 | Train Reward: 91.02
# Worker 3 | Episode 240 | Step Counts: 55 | Train Reward: 100.94
# Worker 1 | Episode 240 | Step Counts: 83 | Train Reward: 173.48
# Worker 0 | Episode 260 | Step Counts: 50 | Train Reward: 89.35
# Worker 5 | Episode 260 | Step Counts: 29 | Train Reward: 46.33
# Worker 4 | Episode 260 | Step Counts: 49 | Train Reward: 80.94
# Worker 2 | Episode 260 | Step Counts: 57 | Train Reward: 97.72
# Worker 3 | Episode 260 | Step Counts: 57 | Train Reward: 95.99
# Worker 1 | Episode 260 | Step Counts: 52 | Train Reward: 84.14
# Worker 0 | Episode 280 | Step Counts: 55 | Train Reward: 92.07
# Worker 5 | Episode 280 | Step Counts: 81 | Train Reward: 133.82
# Worker 4 | Episode 280 | Step Counts: 83 | Train Reward: 149.45
# Worker 2 | Episode 280 | Step Counts: 69 | Train Reward: 126.09
# Worker 3 | Episode 280 | Step Counts: 16 | Train Reward: 1.99
# Worker 1 | Episode 280 | Step Counts: 119 | Train Reward: 240.28
# Worker 5 | Episode 300 | Step Counts: 19 | Train Reward: -0.95
# Worker 4 | Episode 300 | Step Counts: 146 | Train Reward: 433.55
# Worker 0 | Episode 300 | Step Counts: 133 | Train Reward: 307.49
# Worker 2 | Episode 300 | Step Counts: 55 | Train Reward: 95.72
# Worker 3 | Episode 300 | Step Counts: 84 | Train Reward: 175.36
# Worker 1 | Episode 300 | Step Counts: 59 | Train Reward: 102.22
# Worker 5 | Episode 320 | Step Counts: 97 | Train Reward: 208.87
# Worker 4 | Episode 320 | Step Counts: 96 | Train Reward: 176.02
# Worker 0 | Episode 320 | Step Counts: 72 | Train Reward: 118.98
# Worker 2 | Episode 320 | Step Counts: 56 | Train Reward: 96.18
# Worker 3 | Episode 320 | Step Counts: 86 | Train Reward: 121.92
# Worker 1 | Episode 320 | Step Counts: 95 | Train Reward: 162.65
# Worker 5 | Episode 340 | Step Counts: 105 | Train Reward: 200.08
# Worker 0 | Episode 340 | Step Counts: 37 | Train Reward: 50.52
# Worker 4 | Episode 340 | Step Counts: 133 | Train Reward: 246.33
# Worker 2 | Episode 340 | Step Counts: 85 | Train Reward: 174.32
# Worker 1 | Episode 340 | Step Counts: 66 | Train Reward: 101.32
# Worker 3 | Episode 340 | Step Counts: 99 | Train Reward: 180.81
# Worker 5 | Episode 360 | Step Counts: 13 | Train Reward: 17.36
# Worker 0 | Episode 360 | Step Counts: 15 | Train Reward: 21.48
# Worker 4 | Episode 360 | Step Counts: 65 | Train Reward: 100.77
# Worker 2 | Episode 360 | Step Counts: 60 | Train Reward: 105.51
# Worker 1 | Episode 360 | Step Counts: 73 | Train Reward: 131.69
# Worker 3 | Episode 360 | Step Counts: 67 | Train Reward: 117.33
# Worker 5 | Episode 380 | Step Counts: 105 | Train Reward: 205.06
# Worker 0 | Episode 380 | Step Counts: 90 | Train Reward: 189.66
# Worker 4 | Episode 380 | Step Counts: 89 | Train Reward: 181.67
# Worker 2 | Episode 380 | Step Counts: 89 | Train Reward: 172.85
# Worker 1 | Episode 380 | Step Counts: 95 | Train Reward: 185.00
# Worker 3 | Episode 380 | Step Counts: 88 | Train Reward: 175.89
# Worker 5 | Episode 400 | Step Counts: 79 | Train Reward: 143.97
# Worker 0 | Episode 400 | Step Counts: 87 | Train Reward: 168.20
# Worker 4 | Episode 400 | Step Counts: 86 | Train Reward: 179.29
# Worker 2 | Episode 400 | Step Counts: 88 | Train Reward: 183.18
# Worker 1 | Episode 400 | Step Counts: 87 | Train Reward: 183.85
# Worker 3 | Episode 400 | Step Counts: 91 | Train Reward: 181.69
# Worker 5 | Episode 420 | Step Counts: 89 | Train Reward: 173.65
# Worker 0 | Episode 420 | Step Counts: 82 | Train Reward: 157.95
# Worker 4 | Episode 420 | Step Counts: 96 | Train Reward: 206.46
# Worker 2 | Episode 420 | Step Counts: 96 | Train Reward: 191.24
# Worker 1 | Episode 420 | Step Counts: 93 | Train Reward: 184.30
# Worker 3 | Episode 420 | Step Counts: 91 | Train Reward: 185.47
# Worker 5 | Episode 440 | Step Counts: 65 | Train Reward: 117.64
# Worker 0 | Episode 440 | Step Counts: 89 | Train Reward: 182.50
# Worker 4 | Episode 440 | Step Counts: 95 | Train Reward: 202.68
# Worker 2 | Episode 440 | Step Counts: 99 | Train Reward: 216.83
# Worker 1 | Episode 440 | Step Counts: 82 | Train Reward: 172.23
# Worker 3 | Episode 440 | Step Counts: 99 | Train Reward: 207.87
# Worker 5 | Episode 460 | Step Counts: 91 | Train Reward: 187.80
# Worker 0 | Episode 460 | Step Counts: 97 | Train Reward: 193.14
# Worker 2 | Episode 460 | Step Counts: 112 | Train Reward: 249.13
# Worker 4 | Episode 460 | Step Counts: 93 | Train Reward: 189.02
# Worker 1 | Episode 460 | Step Counts: 101 | Train Reward: 229.78
# Worker 3 | Episode 460 | Step Counts: 74 | Train Reward: 134.69
# Worker 5 | Episode 480 | Step Counts: 100 | Train Reward: 217.65
# Worker 0 | Episode 480 | Step Counts: 90 | Train Reward: 189.34
# Worker 4 | Episode 480 | Step Counts: 85 | Train Reward: 161.23
# Worker 2 | Episode 480 | Step Counts: 87 | Train Reward: 168.76
# Worker 1 | Episode 480 | Step Counts: 86 | Train Reward: 164.05
# Worker 3 | Episode 480 | Step Counts: 85 | Train Reward: 165.76
# Worker 5 | Episode 500 | Step Counts: 83 | Train Reward: 157.84
# Worker 0 | Episode 500 | Step Counts: 86 | Train Reward: 167.71
# Worker 4 | Episode 500 | Step Counts: 84 | Train Reward: 160.32
# Worker 2 | Episode 500 | Step Counts: 87 | Train Reward: 168.55
# Worker 1 | Episode 500 | Step Counts: 86 | Train Reward: 165.08
# Worker 3 | Episode 500 | Step Counts: 86 | Train Reward: 172.68
#
# Training Done!
# Mean Train Reward (last 40 episodes): 167.31 | Mean Eval Reward (last 40 episodes): 166.32

# %%
plotResults(a3c_all_results, env_names=[a3c_gym_id])

# %% [markdown]
# ## A3C Questions [$10 \times 3 = 30$ marks]
#
# ### Q1. Why does A3C use asynchronous updates, and what benefit does this provide over synchronous (A2C) updates?
#
#
# ### Q2. What is the "stale gradient" problem in A3C and how does it affect learning?
#
#
# ### Q3. Compare A3C with DQN in terms of memory requirements and training paradigm.

# %% [markdown]
# # Advantange Actor-Critic (A2C) [50 marks]
# <a id="a2c"></a>
#
# A2C is the synchronous, deterministic variant of A3C. Instead of using asynchronous workers, A2C waits for all parallel workers to finish their rollouts before performing a single gradient update. This makes it simpler to implement and often equally effective.
#
# **Key ideas:**
# - Uses an Actor-Critic architecture: the actor outputs a policy $\pi(a|s)$ and the critic estimates $V(s)$.
# - The advantage $A(s,a) = R_t - V(s_t)$ (or using GAE) is used to reduce variance in the policy gradient.
# - Multiple environments run in parallel (vectorized) and all updates are synchronous.
# - The loss combines: policy gradient loss, value loss, and an entropy bonus for exploration.
#
# **Policy Gradient with Advantage:**
# $$\nabla_\theta J(\theta) = \mathbb{E}\left[\nabla_\theta \log \pi_\theta(a_t|s_t) \cdot A(s_t, a_t)\right]$$
#
# Implement the A2C agent using the class structure below.
#
# ```
# class A2CAgent(nn.Module):
#     def __init__(self, envs)
#     def get_value(self, x)
#     def get_action_and_value(self, x, action=None)
#
# def train_a2c(env_id, seed, ...)
# ```

# %%
# Import all the required libraries
from torch.distributions import Categorical, Normal
import torch.nn.functional as F
from multiprocessing import Process, Queue, Barrier
import time
import copy

# %%
# ======================================================================
# A2C Hyperparameters
# ======================================================================

a2c_gym_id = "Hopper-v4"     # Environment name
a2c_learning_rate = 2.5e-4
a2c_seed = 21

a2c_total_timesteps = 1_000_000
a2c_num_envs = 6
a2c_num_steps = 1000

a2c_gamma = 0.99
a2c_gae_lambda = 0.95
a2c_use_gae = True

a2c_ent_coef = 1e-5
a2c_vf_coef = 0.52
a2c_max_grad_norm = 0.5
a2c_norm_adv = True

# Derived parameter
a2c_batch_size = a2c_num_envs * a2c_num_steps

print(
    f"A2C: {a2c_total_timesteps // a2c_batch_size} gradient updates on {a2c_total_timesteps}"
)
# Out:
# A2C: 250 gradient updates on 1000000

# %%
# ======================================================================
# A2C Agent Network
# ======================================================================
# This class defines the architecture for an Advantage Actor-Critic (A2C) agent.
# A2C has two parts:
# 1. A critic that estimates the value of a state (V(s)).
# 2. An actor that outputs a probability distribution over actions.
# You will create separate networks for the actor and the critic.

class A2CAgent(nn.Module):
    def __init__(self, env):
        # Initialize the A2C agent.
        # Tasks:
        # - Determine the dimensions of the observation space.
        # - Determine the number of possible actions.
        # - Create the critic network (takes state, outputs V(s)).
        # - Create the actor network (takes state, outputs action logits).

        # Your code goes here
        super(A2CAgent, self).__init__()
        self.obs_dim = env.observation_space.shape[0]
        self.is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
        self.act_dim = env.action_space.n if self.is_discrete else env.action_space.shape[0]

        self.hDim = [512, 324, 256]
        self.actor_network = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=self.hDim)
        self.critic_network = createValueNetwork(self.obs_dim, 1, hDim=self.hDim)

        if not self.is_discrete:
            self.actor_log_std = nn.Parameter(torch.zeros(self.act_dim))
            self.register_buffer('action_low', torch.FloatTensor(env.action_space.low))
            self.register_buffer('action_high', torch.FloatTensor(env.action_space.high))


    def get_value(self, x):
        """Return the value of a state from the critic network."""
        # Your code goes here
        return self.critic_network(x)

    def get_action_and_value(self, x, action=None):
        """
        Get an action from the actor and value from the critic.
        Tasks:
        - Use the actor network to produce logits over actions.
        - Convert logits into a probability distribution.
        - Sample an action from the distribution (if action is not provided).
        - Compute the log probability of the chosen action.
        - Compute the entropy of the distribution (helps with exploration).
        - Get the value of the state from the critic.

        Returns: action, log_prob, entropy, value
        """
        # Your code goes here
        value = self.get_value(x)

        if self.is_discrete:
            logits = self.actor_network(x)
            dist = torch.distributions.Categorical(logits=logits)
            if action is None:
                action = dist.sample()
            else:
                action = action.long().view(-1)
            log_prob = dist.log_prob(action)
            entropy = dist.entropy()

        else:
            mu = self.actor_network(x)
            log_std = torch.clamp(self.actor_log_std, -20, 2)
            std = torch.exp(log_std).expand_as(mu)
            dist = torch.distributions.Normal(mu, std)

            if action is None:
                action = dist.rsample()
                action = torch.max(torch.min(action, self.action_high), self.action_low)
            else:
                action = action.float()

            log_prob = dist.log_prob(action).sum(dim=-1)
            entropy = dist.entropy().sum(dim=-1)

        return action, log_prob, entropy, value

# %%
# ======================================================================
# A2C Worker + Training Loop (multiprocessing version)
# ======================================================================
# A2C is the SYNCHRONOUS counterpart to A3C:
#   - Worker processes each run their own environment and collect rollouts.
#   - After each rollout, workers WAIT at a barrier (synchronous).
#   - The main process computes GAE and does a SINGLE gradient update.
#   - A second barrier signals workers that weights have been updated.
# This barrier-based synchronisation is the key difference from A3C.
# ======================================================================

def a2c_worker(worker_id, global_agent,
               env_id, seed, num_steps, num_updates,
               shared_obs, shared_actions, shared_logprobs,
               shared_rewards, shared_dones, shared_values,
               shared_next_obs, shared_next_done,
               collect_barrier, update_barrier, ep_queue):
    """
    A2C worker process.  Collects rollouts into shared memory buffers,
    then waits at a barrier for the main process to do a centralised update.

    Unlike A3C, this worker NEVER computes gradients or calls optimizer.step().
    The main process owns the gradient update exclusively.
    """

    #Your code goes here
    env = gym.make(env_id)
    env.reset(seed=seed * 10 + worker_id)
    torch.manual_seed(seed*10 + worker_id)
    np.random.seed(seed*10 + worker_id)
    env.action_space.seed(seed*10 + worker_id)
    env.observation_space.seed(seed*10 + worker_id)
    random.seed(seed*10 + worker_id)
    
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)

    s, _ = env.reset()
    ep_steps = 0

    for _ in range(num_updates):
        total_reward = 0.0

        for step in range(num_steps):
            ep_steps += 1
            s_tensor = torch.tensor(s, dtype=torch.float32).unsqueeze(0)

            with torch.no_grad():
                action, logprob, _, value = global_agent.get_action_and_value(s_tensor)

            if is_discrete:
                action_np = action.item()
                action_store = action.float()
            else:
                action_np = action.squeeze(0).cpu().numpy()
                action_np = np.clip(action_np, env.action_space.low, env.action_space.high)
                action_store = action.squeeze(0)

            s_next, reward, terminated, truncated, _ = env.step(action_np)
            done = terminated or truncated
            total_reward += reward

            shared_obs[worker_id, step] = s_tensor.squeeze(0)
            shared_actions[worker_id, step] = action_store
            shared_logprobs[worker_id, step] = logprob.item()
            shared_rewards[worker_id, step] = reward
            shared_dones[worker_id, step] = float(done)
            shared_values[worker_id, step] = value.squeeze().detach()

            s = s_next
            if done:
                ep_queue.put((worker_id, total_reward, ep_steps))
                total_reward = 0.0
                ep_steps = 0
                s, _ = env.reset()

        s_tensor = torch.tensor(s, dtype=torch.float32).unsqueeze(0)
        shared_next_obs [worker_id] = s_tensor.squeeze(0)
        shared_next_done[worker_id] = float(done)

        collect_barrier.wait()
        update_barrier.wait()

    env.close()

def train_a2c(env_id=a2c_gym_id, seed=a2c_seed, total_timesteps=a2c_total_timesteps,
              num_envs=a2c_num_envs, num_steps=a2c_num_steps, lr=a2c_learning_rate,
              gamma=a2c_gamma, gae_lambda=a2c_gae_lambda, use_gae=a2c_use_gae,
              ent_coef=a2c_ent_coef, vf_coef=a2c_vf_coef,
              max_grad_norm=a2c_max_grad_norm, norm_adv=a2c_norm_adv):
    """
    A2C training with torch.multiprocessing.

    - num_envs worker processes each run their own environment.
    - Workers collect num_steps of experience into shared memory buffers.
    - A barrier synchronises: all workers must finish before the update.
    - The main process computes GAE advantages and does ONE gradient step.
    - A second barrier signals workers that weights have been updated.
    """

    #Your code goes here
    env = gym.make(env_id)
    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = 1 if is_discrete else env.action_space.shape[0]
    env.close()

    global_agent = A2CAgent(gym.make(env_id))
    global_agent.share_memory()

    eval_agent = A2CAgent(gym.make(env_id))

    optimizer = torch.optim.Adam(global_agent.parameters(), lr=lr)
    num_updates = total_timesteps // (num_envs * num_steps)

    shared_obs = torch.zeros(num_envs, num_steps, obs_dim).share_memory_()
    shared_actions = torch.zeros(num_envs, num_steps, act_dim).share_memory_()
    shared_logprobs = torch.zeros(num_envs, num_steps).share_memory_()
    shared_rewards = torch.zeros(num_envs, num_steps).share_memory_()
    shared_dones = torch.zeros(num_envs, num_steps).share_memory_()
    shared_values = torch.zeros(num_envs, num_steps).share_memory_()
    shared_next_obs = torch.zeros(num_envs, obs_dim).share_memory_()
    shared_next_done = torch.zeros(num_envs).share_memory_()

    collect_barrier = mp.Barrier(num_envs + 1)
    update_barrier = mp.Barrier(num_envs + 1)
    ep_queue = mp.Queue()

    train_rewards = []
    global_steps_list = []
    eval_rewards = []
    total_steps_list = []

    trg = []
    erg = []

    completed_episodes = 0
    global_steps = 0

    processes = []
    for i in range(num_envs):
        p = mp.Process(target=a2c_worker, args=(
            i, global_agent,
            env_id, seed, num_steps, num_updates,
            shared_obs, shared_actions, shared_logprobs,
            shared_rewards, shared_dones, shared_values,
            shared_next_obs, shared_next_done,
            collect_barrier, update_barrier, ep_queue
        ))
        p.start()
        processes.append(p)

    for update in range(num_updates):
        collect_barrier.wait()

        with torch.no_grad():
            next_value = global_agent.get_value(shared_next_obs).squeeze(-1)

        advantages = torch.zeros_like(shared_rewards)
        lastgaelam = torch.zeros(num_envs)

        for t in reversed(range(num_steps)):
            if t == num_steps - 1:
                nextnonterminal = 1.0 - shared_next_done
                nextvalues = next_value
            else:
                nextnonterminal = 1.0 - shared_dones[:, t + 1]
                nextvalues = shared_values[:, t + 1]

            delta = shared_rewards[:, t] + gamma * nextvalues * nextnonterminal - shared_values[:, t]

            if use_gae:
                advantages[:, t] = lastgaelam = delta + gamma * gae_lambda * nextnonterminal * lastgaelam
            else:
                advantages[:, t] = delta

        returns = advantages + shared_values

        b_obs = shared_obs.reshape(-1, obs_dim)
        b_actions = shared_actions.reshape(-1, act_dim)
        b_advantages = advantages.reshape(-1)
        b_returns = returns.reshape(-1)

        if norm_adv:
            b_advantages = (b_advantages - b_advantages.mean()) / (b_advantages.std() + 1e-8)

        _, new_logprob, entropy, value = global_agent.get_action_and_value(
            b_obs,
            b_actions.long().view(-1) if is_discrete else b_actions
        )
        value = value.view(-1)

        policy_loss = -(b_advantages * new_logprob).mean()
        value_loss = ((b_returns - value) ** 2).mean()
        entropy_loss = entropy.mean()
        loss = policy_loss + vf_coef * value_loss - ent_coef * entropy_loss

        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(global_agent.parameters(), max_grad_norm)
        optimizer.step()

        update_barrier.wait()

        while not ep_queue.empty():
            try:
                worker_id, train_r, ep_steps = ep_queue.get_nowait()
                completed_episodes += 1
                global_steps += ep_steps
                train_rewards.append((completed_episodes, train_r))
                global_steps_list.append((completed_episodes, global_steps))
                total_steps_list.append((completed_episodes, ep_steps))
                trg.append((global_steps, train_r))

                if completed_episodes % 20 == 0:
                    eval_agent.load_state_dict(global_agent.state_dict())
                    eval_r = evaluate_policy(eval_agent, env_id)
                    eval_rewards.append((completed_episodes, eval_r))
                    erg.append((global_steps, eval_r))

                    print(f"[worker_id: {worker_id}] Global Steps: {global_steps:.0f} | Completed Episodes: {completed_episodes:.0f} | Train Rewards: {train_r:.2f} | "
                          f"Eval Rewards: {eval_r:.2f} | Steps (this episode): {ep_steps:.0f}")
            except:
                break

    for p in processes:
        p.join()

    if not train_rewards or not eval_rewards:
        print("No episodes or evals recorded.")
        return train_rewards, eval_rewards, total_steps_list

    _, train_r = zip(*train_rewards)
    _, eval_r  = zip(*eval_rewards)

    print(f"\nTraining Done!\nMean Train Reward (last 40): {np.mean(train_r[-40:]):.2f} | Mean Eval Reward (last 40): {np.mean(eval_r[-40:]):.2f}")

    return train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg

# %%
# Run the A2C training on multiple environments and store the results.
# Iterate through the environments: 'Pendulum-v1', 'Hopper-v4', and 'HalfCheetah-v4'.

# For each environment, print a header so that the training progress is clear.

# Call the function train_a2c() with the environment name and a total training
# Store the returned training results in a dictionary.


# Plot the learning curve:
#   - First plot the raw returns with a light transparency.
#   - Then compute a moving-average smoothing using numpy convolution
#     to show a cleaner trend of the learning progress.


# Display the plot for each environment.

a2c_plot_config = {}

print(f"Running {a2c_gym_id}")
train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg = train_a2c()

a2c_plot_config[a2c_gym_id] = {
    "Train Rewards": {"A2C": [train_rewards]},
    "Eval Rewards": {"A2C": [eval_rewards]},
    "Total Steps": {"A2C": [total_steps_list]},
    "Global Steps": {"A2C": [global_steps_list]},
    "Train Rewards (over global steps)": {"A2C": [trg]},
    "Eval Rewards (over global steps)": {"A2C": [erg]}
}
# Out:
# Running Hopper-v4
# [Update 5/250] Global steps: 21888 | Episodes: 854 | Median Steps: 40 | Mean Reward (on update 5): 60.856 | Mean Reward (last 40 episodes): 59.127 | Loss: 227.9811
# [Update 10/250] Global steps: 39827 | Episodes: 1233 | Median Steps: 40 | Mean Reward (on update 10): 74.179 | Mean Reward (last 40 episodes): 69.719 | Loss: 233.0052
# [Update 15/250] Global steps: 59942 | Episodes: 1637 | Median Steps: 64 | Mean Reward (on update 15): 122.144 | Mean Reward (last 40 episodes): 123.149 | Loss: 404.0154
# [Update 20/250] Global steps: 79970 | Episodes: 1974 | Median Steps: 50 | Mean Reward (on update 20): 105.751 | Mean Reward (last 40 episodes): 89.237 | Loss: 348.2122
# [Update 25/250] Global steps: 99820 | Episodes: 2272 | Median Steps: 80 | Mean Reward (on update 25): 134.906 | Mean Reward (last 40 episodes): 142.699 | Loss: 384.0728
# [Update 30/250] Global steps: 119961 | Episodes: 2564 | Median Steps: 83 | Mean Reward (on update 30): 152.017 | Mean Reward (last 40 episodes): 162.230 | Loss: 387.7322
# [Update 35/250] Global steps: 139958 | Episodes: 2854 | Median Steps: 82 | Mean Reward (on update 35): 137.600 | Mean Reward (last 40 episodes): 137.133 | Loss: 343.4828
# [Update 40/250] Global steps: 159897 | Episodes: 3126 | Median Steps: 85 | Mean Reward (on update 40): 146.570 | Mean Reward (last 40 episodes): 149.994 | Loss: 337.2988
# [Update 45/250] Global steps: 179872 | Episodes: 3403 | Median Steps: 85 | Mean Reward (on update 45): 134.288 | Mean Reward (last 40 episodes): 140.885 | Loss: 315.5201
# [Update 50/250] Global steps: 199866 | Episodes: 3661 | Median Steps: 84 | Mean Reward (on update 50): 145.085 | Mean Reward (last 40 episodes): 147.869 | Loss: 309.8977
# [Update 55/250] Global steps: 219885 | Episodes: 3927 | Median Steps: 80 | Mean Reward (on update 55): 142.410 | Mean Reward (last 40 episodes): 141.013 | Loss: 298.7531
# [Update 60/250] Global steps: 239746 | Episodes: 4176 | Median Steps: 84 | Mean Reward (on update 60): 140.104 | Mean Reward (last 40 episodes): 143.520 | Loss: 291.9338
# [Update 65/250] Global steps: 259911 | Episodes: 4441 | Median Steps: 85 | Mean Reward (on update 65): 147.466 | Mean Reward (last 40 episodes): 162.993 | Loss: 275.4541
# [Update 70/250] Global steps: 279786 | Episodes: 4695 | Median Steps: 84 | Mean Reward (on update 70): 148.830 | Mean Reward (last 40 episodes): 153.302 | Loss: 245.2621
# [Update 75/250] Global steps: 299821 | Episodes: 4946 | Median Steps: 85 | Mean Reward (on update 75): 158.201 | Mean Reward (last 40 episodes): 162.688 | Loss: 196.2530
# [Update 80/250] Global steps: 319737 | Episodes: 5198 | Median Steps: 85 | Mean Reward (on update 80): 153.157 | Mean Reward (last 40 episodes): 162.017 | Loss: 106.6055
# [Update 85/250] Global steps: 339939 | Episodes: 5465 | Median Steps: 85 | Mean Reward (on update 85): 125.797 | Mean Reward (last 40 episodes): 158.201 | Loss: -52.7771
# [Update 90/250] Global steps: 359908 | Episodes: 5730 | Median Steps: 85 | Mean Reward (on update 90): 155.168 | Mean Reward (last 40 episodes): 155.071 | Loss: -96.4758
# [Update 95/250] Global steps: 379908 | Episodes: 5998 | Median Steps: 72 | Mean Reward (on update 95): 136.077 | Mean Reward (last 40 episodes): 143.471 | Loss: -185.7121
# [Update 100/250] Global steps: 399885 | Episodes: 6311 | Median Steps: 62 | Mean Reward (on update 100): 111.364 | Mean Reward (last 40 episodes): 113.816 | Loss: -357.4930
# [Update 105/250] Global steps: 419836 | Episodes: 6603 | Median Steps: 68 | Mean Reward (on update 105): 128.812 | Mean Reward (last 40 episodes): 127.625 | Loss: -606.8477
# [Update 110/250] Global steps: 439751 | Episodes: 6862 | Median Steps: 84 | Mean Reward (on update 110): 155.958 | Mean Reward (last 40 episodes): 159.820 | Loss: -1030.2250
# [Update 115/250] Global steps: 459917 | Episodes: 7184 | Median Steps: 85 | Mean Reward (on update 115): 143.421 | Mean Reward (last 40 episodes): 139.756 | Loss: -1561.4998
# [Update 120/250] Global steps: 479813 | Episodes: 7480 | Median Steps: 83 | Mean Reward (on update 120): 156.896 | Mean Reward (last 40 episodes): 158.606 | Loss: -1713.8762
# [Update 125/250] Global steps: 499799 | Episodes: 7738 | Median Steps: 74 | Mean Reward (on update 125): 138.034 | Mean Reward (last 40 episodes): 142.188 | Loss: -1817.5150
# [Update 130/250] Global steps: 519742 | Episodes: 8004 | Median Steps: 82 | Mean Reward (on update 130): 143.596 | Mean Reward (last 40 episodes): 143.050 | Loss: -2690.9431
# [Update 135/250] Global steps: 539944 | Episodes: 8256 | Median Steps: 85 | Mean Reward (on update 135): 153.567 | Mean Reward (last 40 episodes): 162.497 | Loss: -3388.7712
# [Update 140/250] Global steps: 559845 | Episodes: 8512 | Median Steps: 85 | Mean Reward (on update 140): 139.849 | Mean Reward (last 40 episodes): 153.073 | Loss: -3920.1021
# [Update 145/250] Global steps: 579927 | Episodes: 8770 | Median Steps: 86 | Mean Reward (on update 145): 159.549 | Mean Reward (last 40 episodes): 167.377 | Loss: -4684.2490
# [Update 150/250] Global steps: 599793 | Episodes: 9014 | Median Steps: 82 | Mean Reward (on update 150): 155.831 | Mean Reward (last 40 episodes): 162.441 | Loss: -5035.1436
# [Update 155/250] Global steps: 619858 | Episodes: 9278 | Median Steps: 81 | Mean Reward (on update 155): 144.174 | Mean Reward (last 40 episodes): 144.175 | Loss: -5874.0073
# [Update 160/250] Global steps: 639915 | Episodes: 9546 | Median Steps: 71 | Mean Reward (on update 160): 135.027 | Mean Reward (last 40 episodes): 136.944 | Loss: -6647.9492
# [Update 165/250] Global steps: 659724 | Episodes: 9821 | Median Steps: 72 | Mean Reward (on update 165): 139.604 | Mean Reward (last 40 episodes): 145.420 | Loss: -7538.1191
# [Update 170/250] Global steps: 679803 | Episodes: 10085 | Median Steps: 76 | Mean Reward (on update 170): 145.006 | Mean Reward (last 40 episodes): 149.561 | Loss: -9361.7686
# [Update 175/250] Global steps: 699787 | Episodes: 10341 | Median Steps: 86 | Mean Reward (on update 175): 160.043 | Mean Reward (last 40 episodes): 161.622 | Loss: -12501.9600
# [Update 180/250] Global steps: 719912 | Episodes: 10611 | Median Steps: 85 | Mean Reward (on update 180): 161.197 | Mean Reward (last 40 episodes): 160.849 | Loss: -13285.4277
# [Update 185/250] Global steps: 739773 | Episodes: 10868 | Median Steps: 85 | Mean Reward (on update 185): 155.313 | Mean Reward (last 40 episodes): 162.262 | Loss: -14080.4697
# [Update 190/250] Global steps: 759833 | Episodes: 11131 | Median Steps: 72 | Mean Reward (on update 190): 132.620 | Mean Reward (last 40 episodes): 136.216 | Loss: -15207.1787
# [Update 195/250] Global steps: 779932 | Episodes: 11412 | Median Steps: 71 | Mean Reward (on update 195): 132.725 | Mean Reward (last 40 episodes): 139.692 | Loss: -16035.4424
# [Update 200/250] Global steps: 799863 | Episodes: 11709 | Median Steps: 66 | Mean Reward (on update 200): 121.328 | Mean Reward (last 40 episodes): 126.645 | Loss: -17577.0156
# [Update 205/250] Global steps: 819905 | Episodes: 11995 | Median Steps: 74 | Mean Reward (on update 205): 138.137 | Mean Reward (last 40 episodes): 140.999 | Loss: -21709.7676
# [Update 210/250] Global steps: 839738 | Episodes: 12262 | Median Steps: 78 | Mean Reward (on update 210): 135.096 | Mean Reward (last 40 episodes): 137.788 | Loss: -24050.8438
# [Update 215/250] Global steps: 859795 | Episodes: 12536 | Median Steps: 86 | Mean Reward (on update 215): 143.379 | Mean Reward (last 40 episodes): 153.320 | Loss: -27861.0645
# [Update 220/250] Global steps: 879940 | Episodes: 12817 | Median Steps: 78 | Mean Reward (on update 220): 128.021 | Mean Reward (last 40 episodes): 145.033 | Loss: -31489.5371
# [Update 225/250] Global steps: 899822 | Episodes: 13089 | Median Steps: 72 | Mean Reward (on update 225): 133.887 | Mean Reward (last 40 episodes): 137.903 | Loss: -30937.1445
# [Update 230/250] Global steps: 919787 | Episodes: 13381 | Median Steps: 64 | Mean Reward (on update 230): 117.504 | Mean Reward (last 40 episodes): 120.749 | Loss: -32567.6758
# [Update 235/250] Global steps: 939921 | Episodes: 13712 | Median Steps: 58 | Mean Reward (on update 235): 101.755 | Mean Reward (last 40 episodes): 103.846 | Loss: -35487.9102
# [Update 240/250] Global steps: 959911 | Episodes: 14088 | Median Steps: 51 | Mean Reward (on update 240): 91.307 | Mean Reward (last 40 episodes): 93.964 | Loss: -39449.5820
# [Update 245/250] Global steps: 979993 | Episodes: 14536 | Median Steps: 42 | Mean Reward (on update 245): 74.968 | Mean Reward (last 40 episodes): 76.423 | Loss: -46219.9727
# [Update 250/250] Global steps: 999921 | Episodes: 15076 | Median Steps: 33 | Mean Reward (on update 250): 58.995 | Mean Reward (last 40 episodes): 60.313 | Loss: -69124.7344
#
# Training Done!
# Mean Train Reward (last 40): 60.31 | Mean Eval Reward  (last 40): 118.35

# %%
plotResults(a2c_plot_config, env_names=[a2c_gym_id])

# %% [markdown]
# ## A2C Questions [$10 \times 4 = 40$ marks ]
#
# ### Q1. What is the advantage function in A2C and why is it used instead of raw returns?
#
#
#
# ### Q2. How does A2C differ from REINFORCE?
#
#
#
# ### Q3. Why does A2C use RMSprop instead of Adam, and does the choice matter?
#
#
#
# ### Q4. Experiment: Compare A2C with different numbers of parallel environments (num_envs = 1, 4, 8, 16). What do you observe?

# %% [markdown]
# # Generalized Advantage Estimation (GAE) [50 marks]
# <a id="gae"></a>
#
# GAE (Schulman et al., 2016) provides a principled way to balance bias and variance in advantage estimation through a single parameter $\lambda \in [0, 1]$.
#
# **The core idea:**
#
# The 1-step advantage (TD error) is: $\delta_t^V = r_t + \gamma V(s_{t+1}) - V(s_t)$
#
# The GAE advantage is an exponentially-weighted average of multi-step advantages:
# $$\hat{A}_t^{\text{GAE}(\gamma, \lambda)} = \sum_{l=0}^{\infty} (\gamma \lambda)^l \delta_{t+l}^V$$
#
# This can be computed recursively:
# $$\hat{A}_t = \delta_t + \gamma \lambda \hat{A}_{t+1}$$
#
# **Special cases:**
# - $\lambda = 0$: GAE reduces to the 1-step TD advantage $\delta_t^V$ → **low variance, high bias**
# - $\lambda = 1$: GAE reduces to the full Monte Carlo advantage → **high variance, low bias**
# - $0 < \lambda < 1$: Smooth interpolation between the two extremes
#
# Below we implement a standalone GAE module and demonstrate how different values of $\lambda$ affect learning performance.

# %%
# ======================================================================
# GAE Implementation (standalone module)
# ======================================================================

def compute_gae(rewards, values, dones, next_value, gamma, gae_lambda):
    """
    Computes Generalized Advantage Estimation.

    Args:
        rewards    : tensor of shape (T, num_envs) - rewards at each timestep
        values     : tensor of shape (T, num_envs) - V(s_t) predictions
        dones      : tensor of shape (T, num_envs) - done flags
        next_value : tensor of shape (1, num_envs) - V(s_{T}) bootstrap value
        gamma      : discount factor
        gae_lambda : GAE lambda parameter (0=TD, 1=MC)

    Returns:
        advantages : tensor of shape (T, num_envs)
        returns    : tensor of shape (T, num_envs)
    """

    #Your code goes here
    T, N = rewards.shape
    advantages = torch.zeros_like(rewards)
    returns = torch.zeros_like(rewards)

    advantage_next = torch.zeros(N)
    for t in reversed(range(T)):
        if t == T - 1:
            nextnonterminal = 1.0 - dones[t]
            nextvalues = next_value
        else:
            nextnonterminal = 1.0 - dones[t+1]
            nextvalues = values[t+1]

        delta = rewards[t] + gamma * nextvalues * nextnonterminal - values[t]

        advantages[t] = advantage_next = delta + gamma * gae_lambda * nextnonterminal * advantage_next
        returns[t] = advantages[t] + values[t]

    return advantages, returns

# %%
# ==============================================================
# GAE Visualization (Synthetic Example)
# ==============================================================

# Demonstrate how GAE behaves for different λ values using
# a small synthetic reward and value sequence.

# Generate synthetic rewards, values, and a done signal.
# Assume the episode terminates at a specific timestep.

# For multiple λ values (e.g., 0 → 1), compute the advantages
# using the compute_gae() function.

# Plot 1:
# Visualize the advantage estimates across timesteps for
# different λ values to observe how smoothing changes.

# Plot 2:
# Evaluate the bias–variance trade-off:
#   • Compute the variance of advantages for λ ∈ [0,1]
#   • Also compute the mean absolute advantage
# Plot both curves against λ.

# Add labels, legend, grid, and export the figure as
# 'gae_lambda_analysis.pdf'.

def create_synthetic_data(T=50, seed=42):
    np.random.seed(seed)

    rewards = np.zeros(T)
    rewards[10:15] = 1.0
    rewards[25:30] = 1.5
    rewards[40:45] = 2.0
    rewards += np.random.randn(T) * 0.01

    gamma = 0.99
    returns = np.zeros(T)
    G = 0
    for t in reversed(range(T)):
        G = rewards[t] + gamma * G
        returns[t] = G

    values = returns * 0.9 + np.random.randn(T) * 0.02
    dones = np.zeros(T)
    dones[39] = 1.0

    return (
        torch.tensor(rewards, dtype=torch.float32),
        torch.tensor(values, dtype=torch.float32),
        torch.tensor(dones, dtype=torch.float32),
    )

def visualize_gae_bias_variance_and_adv_mean(T=100, num_envs=8):
    gamma = 0.99
    rewards_1d, values_1d, dones_1d = create_synthetic_data(T=T)

    rewards = rewards_1d.unsqueeze(1).repeat(1, num_envs)
    values = values_1d.unsqueeze(1).repeat(1, num_envs)
    dones = dones_1d.unsqueeze(1).repeat(1, num_envs)

    next_value = torch.zeros(num_envs)
    lambda_range1 = np.linspace(0, 1, 50)
    lambda_range2 = [0.0, 0.25, 0.5, 0.75, 0.9, 1.0]

    variances = []
    mean_abs_adv = []
    biases = []

    true_returns = torch.zeros_like(rewards)
    G = torch.zeros(num_envs)
    for t in reversed(range(T)):
        G = rewards[t] + gamma * G * (1.0 - dones[t])
        true_returns[t] = G

    for lam in lambda_range1:
        advantages, returns = compute_gae(rewards, values, dones, next_value, gamma, lam)

        adv_flat = advantages.reshape(-1)
        ret_flat = returns.reshape(-1)
        true_flat = true_returns.reshape(-1)

        variances.append(adv_flat.var().item())
        mean_abs_adv.append(adv_flat.abs().mean().item())
        biases.append((ret_flat - true_flat).abs().mean().item())

    fig = plt.figure(figsize=(16, 10))

    ax_main = plt.subplot(2, 1, 1)

    for lam in lambda_range2:
        advantages, _ = compute_gae(rewards, values, dones, next_value, gamma, lam)

        adv_mean = advantages.mean(dim=1).numpy()
        adv_std = advantages.std(dim=1).numpy()

        timesteps = np.arange(T)

        ax_main.plot(timesteps, adv_mean, label=f"lamda={lam}")
        ax_main.fill_between(timesteps, adv_mean - adv_std, adv_mean + adv_std, alpha=0.15)

    ax_main.set_title("GAE Advantage Estimates over Time", fontsize=14, fontweight='semibold')
    ax_main.set_xlabel("Timestep")
    ax_main.set_ylabel("Advantage")
    ax_main.legend()
    ax_main.grid(True)

    ax1 = plt.subplot(2, 3, 4)
    ax2 = plt.subplot(2, 3, 5)
    ax3 = plt.subplot(2, 3, 6)

    ax1.plot(lambda_range1, variances)
    ax1.set_title("Variance vs lamda", fontweight='semibold')
    ax1.set_xlabel("lamda")
    ax1.set_ylabel("Variance")
    ax1.grid(True)

    ax2.plot(lambda_range1, mean_abs_adv)
    ax2.set_title("Mean Absolute Advantage vs lamda", fontweight='semibold')
    ax2.set_xlabel("lamda")
    ax2.set_ylabel("Magnitude")
    ax2.grid(True)

    ax3.plot(lambda_range1, biases)
    ax3.set_title("Bias vs lamda", fontweight='semibold')
    ax3.set_xlabel("lamda")
    ax3.set_ylabel("Bias")
    ax3.grid(True)

    plt.tight_layout()
    plt.savefig("gae_full_analysis.png", dpi=300)
    plt.show()

visualize_gae_bias_variance_and_adv_mean()

# %%
# GAE Lambda Sweep on all 3 environments
''' - Run A2C with different GAE λ values on multiple environments.
- For each environment (Pendulum, Hopper, HalfCheetah), train the agent
- using several λ values and store the training results for comparison.'''

# Your code goes here
def run_gae_sweep(env_names, lambda_values=[0.0, 0.5, 0.95, 0.99, 1.0]):

    results = {env: {"Train Rewards": {}, "Eval Rewards": {}, "Total Steps": {}, "Global Steps": {}} for env in env_names}

    for env_name in env_names:
        print(f"GAE on {env_name}")

        for lam in lambda_values:
            print(f"\nTrain over lamda={lam}")

            train_rewards, eval_rewards, total_steps_list, global_steps_list, trg, erg = train_a2c(env_id=env_name, gae_lambda=lam)

            agent_name = f"lamda={lam}"
            results[env_name]["Train Rewards"][agent_name] = [[train_rewards]]
            results[env_name]["Eval Rewards"][agent_name] = [[eval_rewards]]
            results[env_name]["Train Rewards (over global steps)"][agent_name] = [[trg]]
            results[env_name]["Eval Rewards (over global steps)"][agent_name] = [[erg]]
            results[env_name]["Total Steps"][agent_name] = [[total_steps_list]]
            results[env_name]["Global Steps"][agent_name] = [[global_steps_list]]

    return results

# %%
# GAE sweep plots for all environments

# Your code goes here
gae_env_names = ["Hopper-v4"]
print("\nGAE sweep plots over Hopper-v4 Environment")
sweep_data = run_gae_sweep(gae_env_names)
# Out:
# GAE sweep plots over Hopper-v4 Environment
# GAE on Hopper-v4
#
# Train over lamda=0.0
# [Update 5/250] Global steps: 19702 | Episodes: 758 | Median Steps: 33 | Mean Reward (on update 5): 40.658 | Mean Reward (last 40 episodes): 36.123 | Loss: 0.8162
# [Update 10/250] Global steps: 39951 | Episodes: 1189 | Median Steps: 43 | Mean Reward (on update 10): 49.388 | Mean Reward (last 40 episodes): 54.577 | Loss: 0.7508
# [Update 15/250] Global steps: 59833 | Episodes: 1638 | Median Steps: 30 | Mean Reward (on update 15): 35.424 | Mean Reward (last 40 episodes): 27.144 | Loss: 0.8128
# [Update 20/250] Global steps: 79827 | Episodes: 2137 | Median Steps: 30 | Mean Reward (on update 20): 37.021 | Mean Reward (last 40 episodes): 32.637 | Loss: 0.6061
# [Update 25/250] Global steps: 99860 | Episodes: 2714 | Median Steps: 25 | Mean Reward (on update 25): 23.365 | Mean Reward (last 40 episodes): 26.809 | Loss: -0.6220
# [Update 30/250] Global steps: 119920 | Episodes: 3375 | Median Steps: 22 | Mean Reward (on update 30): 19.605 | Mean Reward (last 40 episodes): 14.726 | Loss: -3.7879
# [Update 35/250] Global steps: 139965 | Episodes: 4078 | Median Steps: 21 | Mean Reward (on update 35): 15.893 | Mean Reward (last 40 episodes): 8.991 | Loss: -8.0885
# [Update 40/250] Global steps: 159968 | Episodes: 4791 | Median Steps: 20 | Mean Reward (on update 40): 13.989 | Mean Reward (last 40 episodes): 9.815 | Loss: -17.4051
# [Update 45/250] Global steps: 179940 | Episodes: 5593 | Median Steps: 20 | Mean Reward (on update 45): 14.907 | Mean Reward (last 40 episodes): 16.244 | Loss: -29.0889
# [Update 50/250] Global steps: 199984 | Episodes: 6497 | Median Steps: 19 | Mean Reward (on update 50): 6.963 | Mean Reward (last 40 episodes): 3.629 | Loss: -56.7981
# [Update 55/250] Global steps: 219958 | Episodes: 7455 | Median Steps: 18 | Mean Reward (on update 55): 3.390 | Mean Reward (last 40 episodes): 3.112 | Loss: -87.0064
# [Update 60/250] Global steps: 239980 | Episodes: 8477 | Median Steps: 18 | Mean Reward (on update 60): 1.563 | Mean Reward (last 40 episodes): 1.645 | Loss: -135.3942
# [Update 65/250] Global steps: 259990 | Episodes: 9516 | Median Steps: 18 | Mean Reward (on update 65): 0.590 | Mean Reward (last 40 episodes): 5.563 | Loss: -202.5880
# [Update 70/250] Global steps: 279957 | Episodes: 10583 | Median Steps: 18 | Mean Reward (on update 70): -0.652 | Mean Reward (last 40 episodes): -0.391 | Loss: -285.8791
# [Update 75/250] Global steps: 299964 | Episodes: 11681 | Median Steps: 18 | Mean Reward (on update 75): -1.191 | Mean Reward (last 40 episodes): -1.229 | Loss: -384.3700
# [Update 80/250] Global steps: 319954 | Episodes: 12789 | Median Steps: 18 | Mean Reward (on update 80): -1.337 | Mean Reward (last 40 episodes): -1.334 | Loss: -512.0450
# [Update 85/250] Global steps: 339980 | Episodes: 13904 | Median Steps: 18 | Mean Reward (on update 85): -1.404 | Mean Reward (last 40 episodes): -1.308 | Loss: -650.2275
# [Update 90/250] Global steps: 359978 | Episodes: 15022 | Median Steps: 18 | Mean Reward (on update 90): -1.438 | Mean Reward (last 40 episodes): -1.419 | Loss: -821.1186
# [Update 95/250] Global steps: 379983 | Episodes: 16143 | Median Steps: 18 | Mean Reward (on update 95): -1.507 | Mean Reward (last 40 episodes): -1.528 | Loss: -1023.7926
# [Update 100/250] Global steps: 399965 | Episodes: 17262 | Median Steps: 18 | Mean Reward (on update 100): -1.463 | Mean Reward (last 40 episodes): -1.379 | Loss: -1257.4827
# [Update 105/250] Global steps: 419985 | Episodes: 18385 | Median Steps: 18 | Mean Reward (on update 105): -1.412 | Mean Reward (last 40 episodes): -1.367 | Loss: -1530.4855
# [Update 110/250] Global steps: 439987 | Episodes: 19507 | Median Steps: 18 | Mean Reward (on update 110): -1.500 | Mean Reward (last 40 episodes): -1.416 | Loss: -1867.1832
# [Update 115/250] Global steps: 459969 | Episodes: 20627 | Median Steps: 18 | Mean Reward (on update 115): -1.485 | Mean Reward (last 40 episodes): -1.408 | Loss: -2249.4446
# [Update 120/250] Global steps: 479955 | Episodes: 21749 | Median Steps: 18 | Mean Reward (on update 120): -1.472 | Mean Reward (last 40 episodes): -1.391 | Loss: -2683.8062
# [Update 125/250] Global steps: 499960 | Episodes: 22872 | Median Steps: 18 | Mean Reward (on update 125): -1.511 | Mean Reward (last 40 episodes): -1.409 | Loss: -3209.6814
# [Update 130/250] Global steps: 519979 | Episodes: 23995 | Median Steps: 18 | Mean Reward (on update 130): -1.416 | Mean Reward (last 40 episodes): -1.417 | Loss: -3764.8650
# [Update 135/250] Global steps: 539961 | Episodes: 25116 | Median Steps: 18 | Mean Reward (on update 135): -1.481 | Mean Reward (last 40 episodes): -1.387 | Loss: -4430.5933
# [Update 140/250] Global steps: 559975 | Episodes: 26238 | Median Steps: 18 | Mean Reward (on update 140): -1.422 | Mean Reward (last 40 episodes): -1.376 | Loss: -5185.7354
# [Update 145/250] Global steps: 579975 | Episodes: 27359 | Median Steps: 18 | Mean Reward (on update 145): -1.457 | Mean Reward (last 40 episodes): -1.381 | Loss: -6071.6338
# [Update 150/250] Global steps: 599950 | Episodes: 28479 | Median Steps: 18 | Mean Reward (on update 150): -1.452 | Mean Reward (last 40 episodes): -1.447 | Loss: -7023.9375
# [Update 155/250] Global steps: 619987 | Episodes: 29602 | Median Steps: 18 | Mean Reward (on update 155): -1.454 | Mean Reward (last 40 episodes): -1.513 | Loss: -8174.7065
# [Update 160/250] Global steps: 639971 | Episodes: 30723 | Median Steps: 18 | Mean Reward (on update 160): -1.444 | Mean Reward (last 40 episodes): -1.409 | Loss: -9364.6475
# [Update 165/250] Global steps: 659968 | Episodes: 31843 | Median Steps: 18 | Mean Reward (on update 165): -1.443 | Mean Reward (last 40 episodes): -1.364 | Loss: -10682.8721
# [Update 170/250] Global steps: 680001 | Episodes: 32966 | Median Steps: 18 | Mean Reward (on update 170): -1.469 | Mean Reward (last 40 episodes): -1.603 | Loss: -12210.2559
# [Update 175/250] Global steps: 699977 | Episodes: 34086 | Median Steps: 18 | Mean Reward (on update 175): -1.450 | Mean Reward (last 40 episodes): -1.365 | Loss: -13857.3350
# [Update 180/250] Global steps: 719961 | Episodes: 35208 | Median Steps: 18 | Mean Reward (on update 180): -1.449 | Mean Reward (last 40 episodes): -1.424 | Loss: -15693.5850
# [Update 185/250] Global steps: 739968 | Episodes: 36329 | Median Steps: 18 | Mean Reward (on update 185): -1.471 | Mean Reward (last 40 episodes): -1.451 | Loss: -17744.2793
# [Update 190/250] Global steps: 759983 | Episodes: 37451 | Median Steps: 18 | Mean Reward (on update 190): -1.453 | Mean Reward (last 40 episodes): -1.443 | Loss: -20126.9043
# [Update 195/250] Global steps: 779970 | Episodes: 38572 | Median Steps: 18 | Mean Reward (on update 195): -1.519 | Mean Reward (last 40 episodes): -1.398 | Loss: -22683.8262
# [Update 200/250] Global steps: 799972 | Episodes: 39694 | Median Steps: 18 | Mean Reward (on update 200): -1.432 | Mean Reward (last 40 episodes): -1.401 | Loss: -25176.8379
# [Update 205/250] Global steps: 819968 | Episodes: 40816 | Median Steps: 18 | Mean Reward (on update 205): -1.422 | Mean Reward (last 40 episodes): -1.373 | Loss: -28341.4043
# [Update 210/250] Global steps: 839973 | Episodes: 41938 | Median Steps: 18 | Mean Reward (on update 210): -1.473 | Mean Reward (last 40 episodes): -1.507 | Loss: -31638.2539
# [Update 215/250] Global steps: 859980 | Episodes: 43061 | Median Steps: 18 | Mean Reward (on update 215): -1.470 | Mean Reward (last 40 episodes): -1.501 | Loss: -35315.4883
# [Update 220/250] Global steps: 879964 | Episodes: 44182 | Median Steps: 18 | Mean Reward (on update 220): -1.475 | Mean Reward (last 40 episodes): -1.429 | Loss: -39014.1836
# [Update 225/250] Global steps: 899984 | Episodes: 45305 | Median Steps: 18 | Mean Reward (on update 225): -1.474 | Mean Reward (last 40 episodes): -1.499 | Loss: -43192.6172
# [Update 230/250] Global steps: 919974 | Episodes: 46425 | Median Steps: 18 | Mean Reward (on update 230): -1.484 | Mean Reward (last 40 episodes): -1.408 | Loss: -48048.6484
# [Update 235/250] Global steps: 939973 | Episodes: 47547 | Median Steps: 18 | Mean Reward (on update 235): -1.427 | Mean Reward (last 40 episodes): -1.406 | Loss: -52505.0938
# [Update 240/250] Global steps: 959969 | Episodes: 48668 | Median Steps: 18 | Mean Reward (on update 240): -1.449 | Mean Reward (last 40 episodes): -1.360 | Loss: -58026.4844
# [Update 245/250] Global steps: 979979 | Episodes: 49791 | Median Steps: 18 | Mean Reward (on update 245): -1.418 | Mean Reward (last 40 episodes): -1.395 | Loss: -63884.5352
# [Update 250/250] Global steps: 999964 | Episodes: 50911 | Median Steps: 18 | Mean Reward (on update 250): -1.505 | Mean Reward (last 40 episodes): -1.400 | Loss: -70116.1328
#
# Training Done!
# Mean Train Reward (last 40): -1.40 | Mean Eval Reward  (last 40): 0.03
#
# Train over lamda=0.5
# [Update 5/250] Global steps: 19897 | Episodes: 688 | Median Steps: 32 | Mean Reward (on update 5): 13.916 | Mean Reward (last 40 episodes): 14.379 | Loss: 1.0107
# [Update 10/250] Global steps: 39947 | Episodes: 1292 | Median Steps: 29 | Mean Reward (on update 10): 14.976 | Mean Reward (last 40 episodes): 13.199 | Loss: 1.5612
# [Update 15/250] Global steps: 59990 | Episodes: 2012 | Median Steps: 24 | Mean Reward (on update 15): 5.891 | Mean Reward (last 40 episodes): 3.630 | Loss: -0.2174
# [Update 20/250] Global steps: 79976 | Episodes: 2830 | Median Steps: 21 | Mean Reward (on update 20): 5.878 | Mean Reward (last 40 episodes): 4.858 | Loss: -3.6335
# [Update 25/250] Global steps: 99936 | Episodes: 3747 | Median Steps: 20 | Mean Reward (on update 25): 2.407 | Mean Reward (last 40 episodes): 2.625 | Loss: -9.3114
# [Update 30/250] Global steps: 119969 | Episodes: 4700 | Median Steps: 19 | Mean Reward (on update 30): 1.586 | Mean Reward (last 40 episodes): 0.524 | Loss: -15.3736
# [Update 35/250] Global steps: 139958 | Episodes: 5694 | Median Steps: 19 | Mean Reward (on update 35): 1.320 | Mean Reward (last 40 episodes): -0.924 | Loss: -23.3335
# [Update 40/250] Global steps: 159959 | Episodes: 6707 | Median Steps: 18 | Mean Reward (on update 40): 1.265 | Mean Reward (last 40 episodes): 0.624 | Loss: -31.1945
# [Update 45/250] Global steps: 179939 | Episodes: 7741 | Median Steps: 18 | Mean Reward (on update 45): -0.342 | Mean Reward (last 40 episodes): -0.232 | Loss: -42.8123
# [Update 50/250] Global steps: 199970 | Episodes: 8810 | Median Steps: 18 | Mean Reward (on update 50): -0.955 | Mean Reward (last 40 episodes): -0.909 | Loss: -56.0639
# [Update 55/250] Global steps: 219983 | Episodes: 9883 | Median Steps: 18 | Mean Reward (on update 55): -0.833 | Mean Reward (last 40 episodes): -0.836 | Loss: -70.3108
# [Update 60/250] Global steps: 239955 | Episodes: 10965 | Median Steps: 18 | Mean Reward (on update 60): -0.894 | Mean Reward (last 40 episodes): -1.223 | Loss: -84.5197
# [Update 65/250] Global steps: 259974 | Episodes: 12065 | Median Steps: 18 | Mean Reward (on update 65): -1.216 | Mean Reward (last 40 episodes): -1.219 | Loss: -97.0780
# [Update 70/250] Global steps: 279959 | Episodes: 13172 | Median Steps: 18 | Mean Reward (on update 70): -1.360 | Mean Reward (last 40 episodes): -1.371 | Loss: -116.2424
# [Update 75/250] Global steps: 299960 | Episodes: 14284 | Median Steps: 18 | Mean Reward (on update 75): -1.353 | Mean Reward (last 40 episodes): -1.372 | Loss: -138.9951
# [Update 80/250] Global steps: 319987 | Episodes: 15402 | Median Steps: 18 | Mean Reward (on update 80): -1.307 | Mean Reward (last 40 episodes): -1.360 | Loss: -150.6158
# [Update 85/250] Global steps: 339973 | Episodes: 16518 | Median Steps: 18 | Mean Reward (on update 85): -1.515 | Mean Reward (last 40 episodes): -1.507 | Loss: -187.2109
# [Update 90/250] Global steps: 359984 | Episodes: 17638 | Median Steps: 18 | Mean Reward (on update 90): -1.398 | Mean Reward (last 40 episodes): -1.389 | Loss: -211.4023
# [Update 95/250] Global steps: 379992 | Episodes: 18759 | Median Steps: 18 | Mean Reward (on update 95): -1.475 | Mean Reward (last 40 episodes): -1.397 | Loss: -241.6475
# [Update 100/250] Global steps: 399978 | Episodes: 19879 | Median Steps: 18 | Mean Reward (on update 100): -1.455 | Mean Reward (last 40 episodes): -1.403 | Loss: -282.2946
# [Update 105/250] Global steps: 419979 | Episodes: 21000 | Median Steps: 18 | Mean Reward (on update 105): -1.472 | Mean Reward (last 40 episodes): -1.406 | Loss: -293.8243
# [Update 110/250] Global steps: 439998 | Episodes: 22124 | Median Steps: 18 | Mean Reward (on update 110): -1.439 | Mean Reward (last 40 episodes): -1.371 | Loss: -329.9567
# [Update 115/250] Global steps: 459958 | Episodes: 23244 | Median Steps: 18 | Mean Reward (on update 115): -1.501 | Mean Reward (last 40 episodes): -1.402 | Loss: -391.2821
# [Update 120/250] Global steps: 479963 | Episodes: 24366 | Median Steps: 18 | Mean Reward (on update 120): -1.438 | Mean Reward (last 40 episodes): -1.306 | Loss: -452.6747
# [Update 125/250] Global steps: 499958 | Episodes: 25487 | Median Steps: 18 | Mean Reward (on update 125): -1.493 | Mean Reward (last 40 episodes): -1.454 | Loss: -519.6315
# [Update 130/250] Global steps: 519967 | Episodes: 26609 | Median Steps: 18 | Mean Reward (on update 130): -1.474 | Mean Reward (last 40 episodes): -1.425 | Loss: -579.4087
# [Update 135/250] Global steps: 539979 | Episodes: 27731 | Median Steps: 18 | Mean Reward (on update 135): -1.440 | Mean Reward (last 40 episodes): -1.497 | Loss: -633.9309
# [Update 140/250] Global steps: 559961 | Episodes: 28852 | Median Steps: 18 | Mean Reward (on update 140): -1.417 | Mean Reward (last 40 episodes): -1.448 | Loss: -743.9472
# [Update 145/250] Global steps: 579961 | Episodes: 29973 | Median Steps: 18 | Mean Reward (on update 145): -1.449 | Mean Reward (last 40 episodes): -1.426 | Loss: -821.1842
# [Update 150/250] Global steps: 599975 | Episodes: 31094 | Median Steps: 18 | Mean Reward (on update 150): -1.463 | Mean Reward (last 40 episodes): -1.448 | Loss: -1006.8062
# [Update 155/250] Global steps: 619959 | Episodes: 32214 | Median Steps: 18 | Mean Reward (on update 155): -1.455 | Mean Reward (last 40 episodes): -1.424 | Loss: -1105.7521
# [Update 160/250] Global steps: 639991 | Episodes: 33337 | Median Steps: 18 | Mean Reward (on update 160): -1.451 | Mean Reward (last 40 episodes): -1.418 | Loss: -1183.1079
# [Update 165/250] Global steps: 659978 | Episodes: 34458 | Median Steps: 18 | Mean Reward (on update 165): -1.427 | Mean Reward (last 40 episodes): -1.432 | Loss: -1288.3602
# [Update 170/250] Global steps: 679980 | Episodes: 35580 | Median Steps: 18 | Mean Reward (on update 170): -1.446 | Mean Reward (last 40 episodes): -1.434 | Loss: -1611.0371
# [Update 175/250] Global steps: 699954 | Episodes: 36700 | Median Steps: 18 | Mean Reward (on update 175): -1.453 | Mean Reward (last 40 episodes): -1.415 | Loss: -1748.7938
# [Update 180/250] Global steps: 719990 | Episodes: 37823 | Median Steps: 18 | Mean Reward (on update 180): -1.440 | Mean Reward (last 40 episodes): -1.416 | Loss: -1922.5529
# [Update 185/250] Global steps: 739979 | Episodes: 38944 | Median Steps: 18 | Mean Reward (on update 185): -1.472 | Mean Reward (last 40 episodes): -1.433 | Loss: -2084.2698
# [Update 190/250] Global steps: 759972 | Episodes: 40066 | Median Steps: 18 | Mean Reward (on update 190): -1.466 | Mean Reward (last 40 episodes): -1.386 | Loss: -2379.8284
# [Update 195/250] Global steps: 779970 | Episodes: 41188 | Median Steps: 18 | Mean Reward (on update 195): -1.440 | Mean Reward (last 40 episodes): -1.513 | Loss: -2624.2109
# [Update 200/250] Global steps: 799963 | Episodes: 42310 | Median Steps: 18 | Mean Reward (on update 200): -1.442 | Mean Reward (last 40 episodes): -1.346 | Loss: -2848.2104
# [Update 205/250] Global steps: 819971 | Episodes: 43433 | Median Steps: 18 | Mean Reward (on update 205): -1.442 | Mean Reward (last 40 episodes): -1.364 | Loss: -3122.7537
# [Update 210/250] Global steps: 839968 | Episodes: 44554 | Median Steps: 18 | Mean Reward (on update 210): -1.449 | Mean Reward (last 40 episodes): -1.334 | Loss: -3532.8975
# [Update 215/250] Global steps: 859956 | Episodes: 45675 | Median Steps: 18 | Mean Reward (on update 215): -1.463 | Mean Reward (last 40 episodes): -1.345 | Loss: -3978.6003
# [Update 220/250] Global steps: 879981 | Episodes: 46797 | Median Steps: 18 | Mean Reward (on update 220): -1.441 | Mean Reward (last 40 episodes): -1.467 | Loss: -4501.7168
# [Update 225/250] Global steps: 899958 | Episodes: 47918 | Median Steps: 18 | Mean Reward (on update 225): -1.468 | Mean Reward (last 40 episodes): -1.464 | Loss: -4821.4917
# [Update 230/250] Global steps: 919983 | Episodes: 49041 | Median Steps: 18 | Mean Reward (on update 230): -1.423 | Mean Reward (last 40 episodes): -1.453 | Loss: -5233.4277
# [Update 235/250] Global steps: 939952 | Episodes: 50161 | Median Steps: 18 | Mean Reward (on update 235): -1.457 | Mean Reward (last 40 episodes): -1.398 | Loss: -5954.0688
# [Update 240/250] Global steps: 959968 | Episodes: 51283 | Median Steps: 18 | Mean Reward (on update 240): -1.472 | Mean Reward (last 40 episodes): -1.374 | Loss: -6151.0591
# [Update 245/250] Global steps: 979963 | Episodes: 52405 | Median Steps: 18 | Mean Reward (on update 245): -1.446 | Mean Reward (last 40 episodes): -1.479 | Loss: -6997.6934
# [Update 250/250] Global steps: 999965 | Episodes: 53527 | Median Steps: 18 | Mean Reward (on update 250): -1.448 | Mean Reward (last 40 episodes): -1.379 | Loss: -7496.9731
#
# Training Done!
# Mean Train Reward (last 40): -1.38 | Mean Eval Reward  (last 40): 0.07
#
# Train over lamda=0.95
# [Update 5/250] Global steps: 19944 | Episodes: 664 | Median Steps: 37 | Mean Reward (on update 5): 56.107 | Mean Reward (last 40 episodes): 49.563 | Loss: 188.5477
# [Update 10/250] Global steps: 39892 | Episodes: 1104 | Median Steps: 37 | Mean Reward (on update 10): 64.410 | Mean Reward (last 40 episodes): 67.684 | Loss: 186.4882
# [Update 15/250] Global steps: 59913 | Episodes: 1681 | Median Steps: 30 | Mean Reward (on update 15): 53.690 | Mean Reward (last 40 episodes): 60.917 | Loss: 159.2577
# [Update 20/250] Global steps: 79933 | Episodes: 2380 | Median Steps: 26 | Mean Reward (on update 20): 46.030 | Mean Reward (last 40 episodes): 44.481 | Loss: 136.3766
# [Update 25/250] Global steps: 99939 | Episodes: 3082 | Median Steps: 29 | Mean Reward (on update 25): 49.144 | Mean Reward (last 40 episodes): 48.680 | Loss: 127.2078
# [Update 30/250] Global steps: 119916 | Episodes: 3760 | Median Steps: 28 | Mean Reward (on update 30): 49.303 | Mean Reward (last 40 episodes): 49.609 | Loss: 114.9159
# [Update 35/250] Global steps: 139887 | Episodes: 4461 | Median Steps: 27 | Mean Reward (on update 35): 46.512 | Mean Reward (last 40 episodes): 49.436 | Loss: 96.5948
# [Update 40/250] Global steps: 159975 | Episodes: 5232 | Median Steps: 22 | Mean Reward (on update 40): 41.190 | Mean Reward (last 40 episodes): 40.604 | Loss: 71.0579
# [Update 45/250] Global steps: 179949 | Episodes: 6110 | Median Steps: 22 | Mean Reward (on update 45): 38.465 | Mean Reward (last 40 episodes): 38.630 | Loss: 59.6665
# [Update 50/250] Global steps: 199944 | Episodes: 7019 | Median Steps: 22 | Mean Reward (on update 50): 38.456 | Mean Reward (last 40 episodes): 38.568 | Loss: 43.8203
# [Update 55/250] Global steps: 219968 | Episodes: 7928 | Median Steps: 22 | Mean Reward (on update 55): 38.464 | Mean Reward (last 40 episodes): 39.014 | Loss: 20.5703
# [Update 60/250] Global steps: 239979 | Episodes: 8838 | Median Steps: 22 | Mean Reward (on update 60): 38.378 | Mean Reward (last 40 episodes): 38.915 | Loss: -15.5272
# [Update 65/250] Global steps: 259957 | Episodes: 9746 | Median Steps: 22 | Mean Reward (on update 65): 38.354 | Mean Reward (last 40 episodes): 38.610 | Loss: -70.3495
# [Update 70/250] Global steps: 279961 | Episodes: 10657 | Median Steps: 22 | Mean Reward (on update 70): 38.224 | Mean Reward (last 40 episodes): 38.906 | Loss: -143.1538
# [Update 75/250] Global steps: 299956 | Episodes: 11568 | Median Steps: 22 | Mean Reward (on update 75): 38.378 | Mean Reward (last 40 episodes): 38.661 | Loss: -241.1764
# [Update 80/250] Global steps: 319982 | Episodes: 12479 | Median Steps: 22 | Mean Reward (on update 80): 38.173 | Mean Reward (last 40 episodes): 38.481 | Loss: -364.2964
# [Update 85/250] Global steps: 339946 | Episodes: 13386 | Median Steps: 22 | Mean Reward (on update 85): 38.458 | Mean Reward (last 40 episodes): 38.691 | Loss: -514.9399
# [Update 90/250] Global steps: 359962 | Episodes: 14296 | Median Steps: 22 | Mean Reward (on update 90): 38.676 | Mean Reward (last 40 episodes): 38.735 | Loss: -701.1031
# [Update 95/250] Global steps: 379938 | Episodes: 15205 | Median Steps: 22 | Mean Reward (on update 95): 38.400 | Mean Reward (last 40 episodes): 38.880 | Loss: -930.5562
# [Update 100/250] Global steps: 399971 | Episodes: 16117 | Median Steps: 22 | Mean Reward (on update 100): 38.327 | Mean Reward (last 40 episodes): 38.696 | Loss: -1207.4509
# [Update 105/250] Global steps: 419973 | Episodes: 17027 | Median Steps: 22 | Mean Reward (on update 105): 38.120 | Mean Reward (last 40 episodes): 37.803 | Loss: -1529.4498
# [Update 110/250] Global steps: 439956 | Episodes: 17936 | Median Steps: 22 | Mean Reward (on update 110): 38.485 | Mean Reward (last 40 episodes): 38.742 | Loss: -1916.6598
# [Update 115/250] Global steps: 459960 | Episodes: 18847 | Median Steps: 22 | Mean Reward (on update 115): 38.366 | Mean Reward (last 40 episodes): 38.709 | Loss: -2358.6389
# [Update 120/250] Global steps: 479957 | Episodes: 19757 | Median Steps: 22 | Mean Reward (on update 120): 38.113 | Mean Reward (last 40 episodes): 38.801 | Loss: -2901.4041
# [Update 125/250] Global steps: 499953 | Episodes: 20667 | Median Steps: 22 | Mean Reward (on update 125): 38.353 | Mean Reward (last 40 episodes): 38.702 | Loss: -3518.7781
# [Update 130/250] Global steps: 519948 | Episodes: 21577 | Median Steps: 22 | Mean Reward (on update 130): 38.698 | Mean Reward (last 40 episodes): 38.954 | Loss: -4185.4766
# [Update 135/250] Global steps: 539966 | Episodes: 22488 | Median Steps: 22 | Mean Reward (on update 135): 38.277 | Mean Reward (last 40 episodes): 38.434 | Loss: -4979.6958
# [Update 140/250] Global steps: 559963 | Episodes: 23398 | Median Steps: 22 | Mean Reward (on update 140): 38.421 | Mean Reward (last 40 episodes): 38.624 | Loss: -5912.2935
# [Update 145/250] Global steps: 579967 | Episodes: 24308 | Median Steps: 22 | Mean Reward (on update 145): 38.452 | Mean Reward (last 40 episodes): 38.999 | Loss: -6894.1909
# [Update 150/250] Global steps: 599954 | Episodes: 25217 | Median Steps: 22 | Mean Reward (on update 150): 38.114 | Mean Reward (last 40 episodes): 38.621 | Loss: -8097.1675
# [Update 155/250] Global steps: 619971 | Episodes: 26127 | Median Steps: 22 | Mean Reward (on update 155): 38.270 | Mean Reward (last 40 episodes): 38.736 | Loss: -9355.6650
# [Update 160/250] Global steps: 639967 | Episodes: 27037 | Median Steps: 22 | Mean Reward (on update 160): 38.237 | Mean Reward (last 40 episodes): 38.882 | Loss: -10834.2178
# [Update 165/250] Global steps: 659966 | Episodes: 27948 | Median Steps: 22 | Mean Reward (on update 165): 38.433 | Mean Reward (last 40 episodes): 38.528 | Loss: -12538.2246
# [Update 170/250] Global steps: 679958 | Episodes: 28858 | Median Steps: 22 | Mean Reward (on update 170): 38.149 | Mean Reward (last 40 episodes): 38.737 | Loss: -14258.0908
# [Update 175/250] Global steps: 699985 | Episodes: 29770 | Median Steps: 22 | Mean Reward (on update 175): 38.214 | Mean Reward (last 40 episodes): 37.816 | Loss: -16205.6387
# [Update 180/250] Global steps: 719977 | Episodes: 30681 | Median Steps: 22 | Mean Reward (on update 180): 38.352 | Mean Reward (last 40 episodes): 37.993 | Loss: -18526.0566
# [Update 185/250] Global steps: 739960 | Episodes: 31591 | Median Steps: 22 | Mean Reward (on update 185): 38.382 | Mean Reward (last 40 episodes): 38.635 | Loss: -21032.9746
# [Update 190/250] Global steps: 759944 | Episodes: 32500 | Median Steps: 22 | Mean Reward (on update 190): 38.454 | Mean Reward (last 40 episodes): 38.565 | Loss: -23530.6934
# [Update 195/250] Global steps: 779993 | Episodes: 33413 | Median Steps: 22 | Mean Reward (on update 195): 38.333 | Mean Reward (last 40 episodes): 38.624 | Loss: -26556.5801
# [Update 200/250] Global steps: 799958 | Episodes: 34322 | Median Steps: 22 | Mean Reward (on update 200): 38.550 | Mean Reward (last 40 episodes): 38.739 | Loss: -29857.2188
# [Update 205/250] Global steps: 819953 | Episodes: 35232 | Median Steps: 22 | Mean Reward (on update 205): 38.317 | Mean Reward (last 40 episodes): 38.719 | Loss: -33333.1602
# [Update 210/250] Global steps: 839944 | Episodes: 36142 | Median Steps: 22 | Mean Reward (on update 210): 38.439 | Mean Reward (last 40 episodes): 38.868 | Loss: -36963.2461
# [Update 215/250] Global steps: 859955 | Episodes: 37053 | Median Steps: 22 | Mean Reward (on update 215): 38.506 | Mean Reward (last 40 episodes): 38.786 | Loss: -41462.7930
# [Update 220/250] Global steps: 879951 | Episodes: 37964 | Median Steps: 22 | Mean Reward (on update 220): 38.530 | Mean Reward (last 40 episodes): 38.661 | Loss: -46039.8984
# [Update 225/250] Global steps: 899980 | Episodes: 38879 | Median Steps: 22 | Mean Reward (on update 225): 38.397 | Mean Reward (last 40 episodes): 38.831 | Loss: -51041.3594
# [Update 230/250] Global steps: 919990 | Episodes: 39789 | Median Steps: 22 | Mean Reward (on update 230): 38.267 | Mean Reward (last 40 episodes): 38.587 | Loss: -56137.3828
# [Update 235/250] Global steps: 939938 | Episodes: 40696 | Median Steps: 22 | Mean Reward (on update 235): 38.600 | Mean Reward (last 40 episodes): 38.926 | Loss: -62011.9336
# [Update 240/250] Global steps: 959954 | Episodes: 41607 | Median Steps: 22 | Mean Reward (on update 240): 38.356 | Mean Reward (last 40 episodes): 38.696 | Loss: -68101.1875
# [Update 245/250] Global steps: 979971 | Episodes: 42518 | Median Steps: 22 | Mean Reward (on update 245): 38.275 | Mean Reward (last 40 episodes): 38.649 | Loss: -75111.2422
# [Update 250/250] Global steps: 999983 | Episodes: 43428 | Median Steps: 22 | Mean Reward (on update 250): 38.202 | Mean Reward (last 40 episodes): 38.490 | Loss: -82630.0078
#
# Training Done!
# Mean Train Reward (last 40): 38.49 | Mean Eval Reward  (last 40): 41.49
#
# Train over lamda=0.99
# [Update 5/250] Global steps: 19960 | Episodes: 939 | Median Steps: 31 | Mean Reward (on update 5): 48.384 | Mean Reward (last 40 episodes): 48.210 | Loss: 596.8854
# [Update 10/250] Global steps: 39852 | Episodes: 1532 | Median Steps: 29 | Mean Reward (on update 10): 53.027 | Mean Reward (last 40 episodes): 52.991 | Loss: 524.3649
# [Update 15/250] Global steps: 59947 | Episodes: 2135 | Median Steps: 32 | Mean Reward (on update 15): 61.383 | Mean Reward (last 40 episodes): 63.748 | Loss: 554.7394
# [Update 20/250] Global steps: 79876 | Episodes: 2667 | Median Steps: 36 | Mean Reward (on update 20): 65.185 | Mean Reward (last 40 episodes): 67.624 | Loss: 603.4871
# [Update 25/250] Global steps: 99758 | Episodes: 3177 | Median Steps: 28 | Mean Reward (on update 25): 59.077 | Mean Reward (last 40 episodes): 58.556 | Loss: 601.7894
# [Update 30/250] Global steps: 119835 | Episodes: 3631 | Median Steps: 47 | Mean Reward (on update 30): 88.338 | Mean Reward (last 40 episodes): 95.461 | Loss: 860.1574
# [Update 35/250] Global steps: 139983 | Episodes: 4075 | Median Steps: 38 | Mean Reward (on update 35): 81.952 | Mean Reward (last 40 episodes): 79.009 | Loss: 760.3790
# [Update 40/250] Global steps: 159893 | Episodes: 4494 | Median Steps: 44 | Mean Reward (on update 40): 94.137 | Mean Reward (last 40 episodes): 108.747 | Loss: 879.8223
# [Update 45/250] Global steps: 179937 | Episodes: 4900 | Median Steps: 40 | Mean Reward (on update 45): 95.705 | Mean Reward (last 40 episodes): 107.663 | Loss: 905.6903
# [Update 50/250] Global steps: 199874 | Episodes: 5267 | Median Steps: 56 | Mean Reward (on update 50): 104.592 | Mean Reward (last 40 episodes): 107.388 | Loss: 789.9074
# [Update 55/250] Global steps: 219878 | Episodes: 5581 | Median Steps: 62 | Mean Reward (on update 55): 112.359 | Mean Reward (last 40 episodes): 108.331 | Loss: 853.9265
# [Update 60/250] Global steps: 239845 | Episodes: 5905 | Median Steps: 53 | Mean Reward (on update 60): 100.809 | Mean Reward (last 40 episodes): 109.722 | Loss: 706.7548
# [Update 65/250] Global steps: 259816 | Episodes: 6202 | Median Steps: 76 | Mean Reward (on update 65): 135.110 | Mean Reward (last 40 episodes): 139.039 | Loss: 968.8988
# [Update 70/250] Global steps: 279747 | Episodes: 6504 | Median Steps: 68 | Mean Reward (on update 70): 124.581 | Mean Reward (last 40 episodes): 130.681 | Loss: 822.1622
# [Update 75/250] Global steps: 299914 | Episodes: 6803 | Median Steps: 75 | Mean Reward (on update 75): 127.954 | Mean Reward (last 40 episodes): 131.589 | Loss: 778.9867
# [Update 80/250] Global steps: 319844 | Episodes: 7098 | Median Steps: 70 | Mean Reward (on update 80): 125.721 | Mean Reward (last 40 episodes): 122.555 | Loss: 693.0099
# [Update 85/250] Global steps: 339803 | Episodes: 7372 | Median Steps: 81 | Mean Reward (on update 85): 145.045 | Mean Reward (last 40 episodes): 158.716 | Loss: 734.2885
# [Update 90/250] Global steps: 359731 | Episodes: 7647 | Median Steps: 84 | Mean Reward (on update 90): 133.185 | Mean Reward (last 40 episodes): 136.084 | Loss: 558.9084
# [Update 95/250] Global steps: 379954 | Episodes: 7928 | Median Steps: 78 | Mean Reward (on update 95): 138.593 | Mean Reward (last 40 episodes): 144.700 | Loss: 372.8103
# [Update 100/250] Global steps: 399800 | Episodes: 8213 | Median Steps: 84 | Mean Reward (on update 100): 144.993 | Mean Reward (last 40 episodes): 145.233 | Loss: 221.2796
# [Update 105/250] Global steps: 419913 | Episodes: 8520 | Median Steps: 44 | Mean Reward (on update 105): 95.095 | Mean Reward (last 40 episodes): 98.456 | Loss: -97.5825
# [Update 110/250] Global steps: 439764 | Episodes: 8814 | Median Steps: 66 | Mean Reward (on update 110): 110.414 | Mean Reward (last 40 episodes): 122.031 | Loss: -367.9068
# [Update 115/250] Global steps: 459701 | Episodes: 9152 | Median Steps: 57 | Mean Reward (on update 115): 101.137 | Mean Reward (last 40 episodes): 98.983 | Loss: -440.3011
# [Update 120/250] Global steps: 479856 | Episodes: 9467 | Median Steps: 64 | Mean Reward (on update 120): 116.844 | Mean Reward (last 40 episodes): 127.313 | Loss: -1011.2750
# [Update 125/250] Global steps: 499744 | Episodes: 9724 | Median Steps: 86 | Mean Reward (on update 125): 139.029 | Mean Reward (last 40 episodes): 139.620 | Loss: -2065.9326
# [Update 130/250] Global steps: 519954 | Episodes: 9987 | Median Steps: 85 | Mean Reward (on update 130): 144.761 | Mean Reward (last 40 episodes): 140.224 | Loss: -2753.2764
# [Update 135/250] Global steps: 539808 | Episodes: 10256 | Median Steps: 74 | Mean Reward (on update 135): 135.523 | Mean Reward (last 40 episodes): 139.056 | Loss: -3198.6919
# [Update 140/250] Global steps: 559973 | Episodes: 10535 | Median Steps: 73 | Mean Reward (on update 140): 125.709 | Mean Reward (last 40 episodes): 138.874 | Loss: -3933.9832
# [Update 145/250] Global steps: 579794 | Episodes: 10819 | Median Steps: 72 | Mean Reward (on update 145): 131.231 | Mean Reward (last 40 episodes): 138.806 | Loss: -4820.1113
# [Update 150/250] Global steps: 599733 | Episodes: 11079 | Median Steps: 85 | Mean Reward (on update 150): 136.350 | Mean Reward (last 40 episodes): 146.128 | Loss: -6778.6777
# [Update 155/250] Global steps: 619849 | Episodes: 11341 | Median Steps: 81 | Mean Reward (on update 155): 144.104 | Mean Reward (last 40 episodes): 148.085 | Loss: -8587.9482
# [Update 160/250] Global steps: 639804 | Episodes: 11615 | Median Steps: 75 | Mean Reward (on update 160): 132.922 | Mean Reward (last 40 episodes): 136.041 | Loss: -9075.4062
# [Update 165/250] Global steps: 659808 | Episodes: 11890 | Median Steps: 74 | Mean Reward (on update 165): 141.079 | Mean Reward (last 40 episodes): 148.049 | Loss: -12019.9551
# [Update 170/250] Global steps: 679878 | Episodes: 12145 | Median Steps: 85 | Mean Reward (on update 170): 153.121 | Mean Reward (last 40 episodes): 161.812 | Loss: -14494.4688
# [Update 175/250] Global steps: 699910 | Episodes: 12395 | Median Steps: 85 | Mean Reward (on update 175): 151.448 | Mean Reward (last 40 episodes): 155.570 | Loss: -18046.1582
# [Update 180/250] Global steps: 719765 | Episodes: 12646 | Median Steps: 80 | Mean Reward (on update 180): 143.818 | Mean Reward (last 40 episodes): 150.662 | Loss: -18480.3164
# [Update 185/250] Global steps: 739918 | Episodes: 12902 | Median Steps: 81 | Mean Reward (on update 185): 154.459 | Mean Reward (last 40 episodes): 166.527 | Loss: -23190.5664
# [Update 190/250] Global steps: 759946 | Episodes: 13160 | Median Steps: 80 | Mean Reward (on update 190): 140.360 | Mean Reward (last 40 episodes): 145.011 | Loss: -24568.6465
# [Update 195/250] Global steps: 779959 | Episodes: 13428 | Median Steps: 77 | Mean Reward (on update 195): 140.678 | Mean Reward (last 40 episodes): 155.135 | Loss: -29233.2812
# [Update 200/250] Global steps: 799765 | Episodes: 13685 | Median Steps: 74 | Mean Reward (on update 200): 140.421 | Mean Reward (last 40 episodes): 151.693 | Loss: -31222.0273
# [Update 205/250] Global steps: 819695 | Episodes: 13956 | Median Steps: 77 | Mean Reward (on update 205): 146.938 | Mean Reward (last 40 episodes): 149.654 | Loss: -34942.8711
# [Update 210/250] Global steps: 839827 | Episodes: 14229 | Median Steps: 72 | Mean Reward (on update 210): 131.187 | Mean Reward (last 40 episodes): 140.471 | Loss: -38136.1680
# [Update 215/250] Global steps: 859763 | Episodes: 14494 | Median Steps: 82 | Mean Reward (on update 215): 150.297 | Mean Reward (last 40 episodes): 152.174 | Loss: -45203.5000
# [Update 220/250] Global steps: 879932 | Episodes: 14761 | Median Steps: 77 | Mean Reward (on update 220): 143.837 | Mean Reward (last 40 episodes): 148.995 | Loss: -49969.2773
# [Update 225/250] Global steps: 899900 | Episodes: 15028 | Median Steps: 73 | Mean Reward (on update 225): 139.106 | Mean Reward (last 40 episodes): 133.401 | Loss: -50676.0859
# [Update 230/250] Global steps: 919826 | Episodes: 15298 | Median Steps: 78 | Mean Reward (on update 230): 145.234 | Mean Reward (last 40 episodes): 145.312 | Loss: -56885.4492
# [Update 235/250] Global steps: 939829 | Episodes: 15562 | Median Steps: 78 | Mean Reward (on update 235): 145.118 | Mean Reward (last 40 episodes): 146.322 | Loss: -63927.0039
# [Update 240/250] Global steps: 959847 | Episodes: 15827 | Median Steps: 85 | Mean Reward (on update 240): 148.905 | Mean Reward (last 40 episodes): 150.399 | Loss: -78215.6094
# [Update 245/250] Global steps: 979903 | Episodes: 16102 | Median Steps: 73 | Mean Reward (on update 245): 132.474 | Mean Reward (last 40 episodes): 140.275 | Loss: -79249.2031
# [Update 250/250] Global steps: 999830 | Episodes: 16371 | Median Steps: 72 | Mean Reward (on update 250): 138.624 | Mean Reward (last 40 episodes): 138.451 | Loss: -85756.4062
#
# Training Done!
# Mean Train Reward (last 40): 138.45 | Mean Eval Reward  (last 40): 137.57
#
# Train over lamda=1.0
# [Update 5/250] Global steps: 19907 | Episodes: 657 | Median Steps: 50 | Mean Reward (on update 5): 73.892 | Mean Reward (last 40 episodes): 68.499 | Loss: 1031.9985
# [Update 10/250] Global steps: 39952 | Episodes: 1109 | Median Steps: 40 | Mean Reward (on update 10): 68.542 | Mean Reward (last 40 episodes): 67.352 | Loss: 946.0970
# [Update 15/250] Global steps: 59879 | Episodes: 1612 | Median Steps: 40 | Mean Reward (on update 15): 61.900 | Mean Reward (last 40 episodes): 63.398 | Loss: 648.5725
# [Update 20/250] Global steps: 79901 | Episodes: 2118 | Median Steps: 32 | Mean Reward (on update 20): 55.507 | Mean Reward (last 40 episodes): 56.508 | Loss: 525.5587
# [Update 25/250] Global steps: 99889 | Episodes: 2658 | Median Steps: 33 | Mean Reward (on update 25): 56.968 | Mean Reward (last 40 episodes): 57.559 | Loss: 519.4290
# [Update 30/250] Global steps: 119904 | Episodes: 3250 | Median Steps: 28 | Mean Reward (on update 30): 48.404 | Mean Reward (last 40 episodes): 51.617 | Loss: 311.9284
# [Update 35/250] Global steps: 139914 | Episodes: 3899 | Median Steps: 25 | Mean Reward (on update 35): 44.733 | Mean Reward (last 40 episodes): 43.568 | Loss: 224.8212
# [Update 40/250] Global steps: 159956 | Episodes: 4640 | Median Steps: 24 | Mean Reward (on update 40): 43.709 | Mean Reward (last 40 episodes): 44.055 | Loss: 167.8864
# [Update 45/250] Global steps: 179940 | Episodes: 5427 | Median Steps: 23 | Mean Reward (on update 45): 40.881 | Mean Reward (last 40 episodes): 41.846 | Loss: 86.1258
# [Update 50/250] Global steps: 199978 | Episodes: 6272 | Median Steps: 23 | Mean Reward (on update 50): 40.395 | Mean Reward (last 40 episodes): 40.633 | Loss: 37.0066
# [Update 55/250] Global steps: 219940 | Episodes: 7140 | Median Steps: 23 | Mean Reward (on update 55): 39.785 | Mean Reward (last 40 episodes): 39.915 | Loss: -28.8212
# [Update 60/250] Global steps: 239919 | Episodes: 8026 | Median Steps: 22 | Mean Reward (on update 60): 38.951 | Mean Reward (last 40 episodes): 39.212 | Loss: -106.8657
# [Update 65/250] Global steps: 259961 | Episodes: 8929 | Median Steps: 22 | Mean Reward (on update 65): 38.545 | Mean Reward (last 40 episodes): 38.238 | Loss: -187.6818
# [Update 70/250] Global steps: 279964 | Episodes: 9833 | Median Steps: 22 | Mean Reward (on update 70): 38.395 | Mean Reward (last 40 episodes): 38.780 | Loss: -298.3249
# [Update 75/250] Global steps: 299957 | Episodes: 10740 | Median Steps: 22 | Mean Reward (on update 75): 38.378 | Mean Reward (last 40 episodes): 38.582 | Loss: -425.9317
# [Update 80/250] Global steps: 319959 | Episodes: 11650 | Median Steps: 22 | Mean Reward (on update 80): 38.408 | Mean Reward (last 40 episodes): 38.599 | Loss: -588.0301
# [Update 85/250] Global steps: 339969 | Episodes: 12560 | Median Steps: 22 | Mean Reward (on update 85): 38.253 | Mean Reward (last 40 episodes): 38.714 | Loss: -780.5483
# [Update 90/250] Global steps: 359945 | Episodes: 13467 | Median Steps: 22 | Mean Reward (on update 90): 38.209 | Mean Reward (last 40 episodes): 38.739 | Loss: -1003.5069
# [Update 95/250] Global steps: 379955 | Episodes: 14377 | Median Steps: 22 | Mean Reward (on update 95): 38.371 | Mean Reward (last 40 episodes): 38.693 | Loss: -1288.8746
# [Update 100/250] Global steps: 399959 | Episodes: 15287 | Median Steps: 22 | Mean Reward (on update 100): 38.373 | Mean Reward (last 40 episodes): 38.706 | Loss: -1614.5386
# [Update 105/250] Global steps: 419963 | Episodes: 16198 | Median Steps: 22 | Mean Reward (on update 105): 38.468 | Mean Reward (last 40 episodes): 38.688 | Loss: -2026.7532
# [Update 110/250] Global steps: 439969 | Episodes: 17108 | Median Steps: 22 | Mean Reward (on update 110): 38.048 | Mean Reward (last 40 episodes): 38.626 | Loss: -2470.0684
# [Update 115/250] Global steps: 459976 | Episodes: 18018 | Median Steps: 22 | Mean Reward (on update 115): 38.339 | Mean Reward (last 40 episodes): 38.602 | Loss: -3019.9026
# [Update 120/250] Global steps: 479958 | Episodes: 18928 | Median Steps: 22 | Mean Reward (on update 120): 38.399 | Mean Reward (last 40 episodes): 38.711 | Loss: -3648.5728
# [Update 125/250] Global steps: 499953 | Episodes: 19838 | Median Steps: 22 | Mean Reward (on update 125): 38.327 | Mean Reward (last 40 episodes): 38.777 | Loss: -4358.7144
# [Update 130/250] Global steps: 519952 | Episodes: 20748 | Median Steps: 22 | Mean Reward (on update 130): 38.554 | Mean Reward (last 40 episodes): 38.720 | Loss: -5196.0796
# [Update 135/250] Global steps: 539960 | Episodes: 21659 | Median Steps: 22 | Mean Reward (on update 135): 38.179 | Mean Reward (last 40 episodes): 38.533 | Loss: -6128.0352
# [Update 140/250] Global steps: 559942 | Episodes: 22568 | Median Steps: 22 | Mean Reward (on update 140): 38.482 | Mean Reward (last 40 episodes): 38.844 | Loss: -7192.1514
# [Update 145/250] Global steps: 579934 | Episodes: 23478 | Median Steps: 22 | Mean Reward (on update 145): 38.383 | Mean Reward (last 40 episodes): 38.604 | Loss: -8430.5645
# [Update 150/250] Global steps: 599967 | Episodes: 24389 | Median Steps: 22 | Mean Reward (on update 150): 38.462 | Mean Reward (last 40 episodes): 38.816 | Loss: -9699.5215
# [Update 155/250] Global steps: 619973 | Episodes: 25299 | Median Steps: 22 | Mean Reward (on update 155): 38.298 | Mean Reward (last 40 episodes): 38.754 | Loss: -11291.7949
# [Update 160/250] Global steps: 639979 | Episodes: 26208 | Median Steps: 22 | Mean Reward (on update 160): 38.559 | Mean Reward (last 40 episodes): 38.908 | Loss: -12849.1182
# [Update 165/250] Global steps: 659972 | Episodes: 27118 | Median Steps: 22 | Mean Reward (on update 165): 38.654 | Mean Reward (last 40 episodes): 38.913 | Loss: -14742.1387
# [Update 170/250] Global steps: 679964 | Episodes: 28029 | Median Steps: 22 | Mean Reward (on update 170): 37.970 | Mean Reward (last 40 episodes): 38.884 | Loss: -16963.2031
# [Update 175/250] Global steps: 700000 | Episodes: 28941 | Median Steps: 22 | Mean Reward (on update 175): 37.774 | Mean Reward (last 40 episodes): 36.094 | Loss: -19183.4121
# [Update 180/250] Global steps: 719958 | Episodes: 29850 | Median Steps: 22 | Mean Reward (on update 180): 38.579 | Mean Reward (last 40 episodes): 38.586 | Loss: -21637.4199
# [Update 185/250] Global steps: 739979 | Episodes: 30762 | Median Steps: 22 | Mean Reward (on update 185): 37.931 | Mean Reward (last 40 episodes): 37.921 | Loss: -24545.3379
# [Update 190/250] Global steps: 759956 | Episodes: 31672 | Median Steps: 22 | Mean Reward (on update 190): 38.546 | Mean Reward (last 40 episodes): 38.545 | Loss: -27878.1816
# [Update 195/250] Global steps: 779934 | Episodes: 32581 | Median Steps: 22 | Mean Reward (on update 195): 38.435 | Mean Reward (last 40 episodes): 38.759 | Loss: -31262.1211
# [Update 200/250] Global steps: 799964 | Episodes: 33493 | Median Steps: 22 | Mean Reward (on update 200): 38.465 | Mean Reward (last 40 episodes): 38.859 | Loss: -34982.7188
# [Update 205/250] Global steps: 819958 | Episodes: 34403 | Median Steps: 22 | Mean Reward (on update 205): 38.363 | Mean Reward (last 40 episodes): 38.885 | Loss: -38838.4766
# [Update 210/250] Global steps: 839948 | Episodes: 35313 | Median Steps: 22 | Mean Reward (on update 210): 38.482 | Mean Reward (last 40 episodes): 38.671 | Loss: -43286.2695
# [Update 215/250] Global steps: 859977 | Episodes: 36225 | Median Steps: 22 | Mean Reward (on update 215): 38.162 | Mean Reward (last 40 episodes): 38.633 | Loss: -48322.9727
# [Update 220/250] Global steps: 879984 | Episodes: 37136 | Median Steps: 22 | Mean Reward (on update 220): 38.223 | Mean Reward (last 40 episodes): 38.397 | Loss: -53527.4141
# [Update 225/250] Global steps: 899945 | Episodes: 38045 | Median Steps: 22 | Mean Reward (on update 225): 38.288 | Mean Reward (last 40 episodes): 38.691 | Loss: -59558.5117
# [Update 230/250] Global steps: 919954 | Episodes: 38959 | Median Steps: 22 | Mean Reward (on update 230): 38.340 | Mean Reward (last 40 episodes): 38.741 | Loss: -65311.5703
# [Update 235/250] Global steps: 939968 | Episodes: 39869 | Median Steps: 22 | Mean Reward (on update 235): 38.461 | Mean Reward (last 40 episodes): 38.696 | Loss: -72134.6094
# [Update 240/250] Global steps: 959962 | Episodes: 40779 | Median Steps: 22 | Mean Reward (on update 240): 38.177 | Mean Reward (last 40 episodes): 38.536 | Loss: -80110.9844
# [Update 245/250] Global steps: 979929 | Episodes: 41687 | Median Steps: 22 | Mean Reward (on update 245): 38.515 | Mean Reward (last 40 episodes): 38.725 | Loss: -87485.6406
# [Update 250/250] Global steps: 999953 | Episodes: 42598 | Median Steps: 22 | Mean Reward (on update 250): 38.487 | Mean Reward (last 40 episodes): 38.838 | Loss: -94539.8984
#
# Training Done!
# Mean Train Reward (last 40): 38.84 | Mean Eval Reward  (last 40): 41.44

# %%
plotResults(sweep_data, [a2c_gym_id], window=80)

# %%
# A2C vs A3C comparison on all 3 environments

# Your code goes here
def comparison_plot(env_names=["Hopper-v4"]):

    results = {env: {"Train Rewards": {}, "Eval Rewards": {}, "Total Steps": {}, "Global Steps": {}} for env in env_names}

    for env_name in env_names:
        print(f"Comparing A2C vs A3C on {env_name}")

        print("Running A2C")
        a2c_train_r, a2c_eval_r, a2c_total_steps, a2c_global_steps, a2c_trg, a2c_erg = train_a2c(env_id=env_name)

        print("Running A3C")
        a3c_train_r, a3c_total_steps, a3c_eval_r, a3c_global_steps, a3c_trg, a3c_erg = train_a3c(env_id=env_name)

        results[env_name]["Train Rewards"]["A2C"] = [[a2c_train_r]]
        results[env_name]["Train Rewards"]["A3C"] = [[a3c_train_r]]
        results[env_name]["Eval Rewards"]["A2C"] = [[a2c_eval_r]]
        results[env_name]["Eval Rewards"]["A3C"] = [[a3c_eval_r]]
        results[env_name]["Total Steps"]["A2C"] = [[a2c_total_steps]]
        results[env_name]["Total Steps"]["A3C"] = [[a3c_total_steps]]
        results[env_name]["Global Steps"]["A2C"] = [[a2c_global_steps]]
        results[env_name]["Global Steps"]["A3C"] = [[a3c_global_steps]]
        results[env_name]["Train Rewards (over global steps)"]["A2C"] = [[a2c_trg]]
        results[env_name]["Train Rewards (over global steps)"]["A3C"] = [[a3c_trg]]
        results[env_name]["Eval Rewards (over global steps)"]["A2C"] = [[a2c_erg]]
        results[env_name]["Eval Rewards (over global steps)"]["A3C"] = [[a3c_erg]]

    return results

print("\nA2C vs A3C comparison on Hopper-v4 environment")
result = comparison_plot()
# Out:
# A2C vs A3C comparison on Hopper-v4 environment
# Comparing A2C vs A3C on Hopper-v4
# Running A2C
# [Update 5/250] Global steps: 19964 | Episodes: 818 | Median Steps: 30 | Mean Reward (on update 5): 43.952 | Mean Reward (last 40 episodes): 36.959 | Loss: 148.0597
# [Update 10/250] Global steps: 39946 | Episodes: 1330 | Median Steps: 39 | Mean Reward (on update 10): 60.442 | Mean Reward (last 40 episodes): 64.780 | Loss: 177.2565
# [Update 15/250] Global steps: 59928 | Episodes: 1796 | Median Steps: 40 | Mean Reward (on update 15): 65.204 | Mean Reward (last 40 episodes): 69.220 | Loss: 157.8319
# [Update 20/250] Global steps: 79931 | Episodes: 2216 | Median Steps: 44 | Mean Reward (on update 20): 66.510 | Mean Reward (last 40 episodes): 58.653 | Loss: 155.7234
# [Update 25/250] Global steps: 99911 | Episodes: 2605 | Median Steps: 44 | Mean Reward (on update 25): 63.628 | Mean Reward (last 40 episodes): 67.472 | Loss: 147.1519
# [Update 30/250] Global steps: 119915 | Episodes: 2955 | Median Steps: 56 | Mean Reward (on update 30): 71.213 | Mean Reward (last 40 episodes): 70.218 | Loss: 121.7052
# [Update 35/250] Global steps: 139918 | Episodes: 3340 | Median Steps: 41 | Mean Reward (on update 35): 62.099 | Mean Reward (last 40 episodes): 63.489 | Loss: 125.8171
# [Update 40/250] Global steps: 159902 | Episodes: 3759 | Median Steps: 42 | Mean Reward (on update 40): 56.489 | Mean Reward (last 40 episodes): 52.628 | Loss: 103.2532
# [Update 45/250] Global steps: 179889 | Episodes: 4220 | Median Steps: 33 | Mean Reward (on update 45): 34.254 | Mean Reward (last 40 episodes): 35.080 | Loss: 58.4001
# [Update 50/250] Global steps: 199816 | Episodes: 4758 | Median Steps: 31 | Mean Reward (on update 50): 26.178 | Mean Reward (last 40 episodes): 26.781 | Loss: 25.7201
# [Update 55/250] Global steps: 219895 | Episodes: 5389 | Median Steps: 22 | Mean Reward (on update 55): 14.156 | Mean Reward (last 40 episodes): 15.434 | Loss: -56.2400
# [Update 60/250] Global steps: 239934 | Episodes: 6074 | Median Steps: 20 | Mean Reward (on update 60): 8.067 | Mean Reward (last 40 episodes): 6.194 | Loss: -134.2938
# [Update 65/250] Global steps: 259966 | Episodes: 6896 | Median Steps: 19 | Mean Reward (on update 65): 3.105 | Mean Reward (last 40 episodes): 8.455 | Loss: -234.8367
# [Update 70/250] Global steps: 279942 | Episodes: 7795 | Median Steps: 18 | Mean Reward (on update 70): 2.065 | Mean Reward (last 40 episodes): 5.422 | Loss: -340.5095
# [Update 75/250] Global steps: 299975 | Episodes: 8768 | Median Steps: 18 | Mean Reward (on update 75): 0.608 | Mean Reward (last 40 episodes): 1.479 | Loss: -468.1989
# [Update 80/250] Global steps: 319972 | Episodes: 9816 | Median Steps: 18 | Mean Reward (on update 80): -0.429 | Mean Reward (last 40 episodes): -0.470 | Loss: -622.2674
# [Update 85/250] Global steps: 339973 | Episodes: 10886 | Median Steps: 18 | Mean Reward (on update 85): -0.920 | Mean Reward (last 40 episodes): -1.221 | Loss: -804.9409
# [Update 90/250] Global steps: 359973 | Episodes: 11992 | Median Steps: 18 | Mean Reward (on update 90): -1.317 | Mean Reward (last 40 episodes): -1.175 | Loss: -1077.7019
# [Update 95/250] Global steps: 379991 | Episodes: 13109 | Median Steps: 18 | Mean Reward (on update 95): -1.272 | Mean Reward (last 40 episodes): -1.337 | Loss: -1295.1759
# [Update 100/250] Global steps: 399975 | Episodes: 14227 | Median Steps: 18 | Mean Reward (on update 100): -1.430 | Mean Reward (last 40 episodes): -1.389 | Loss: -1585.2766
# [Update 105/250] Global steps: 419974 | Episodes: 15349 | Median Steps: 18 | Mean Reward (on update 105): -1.417 | Mean Reward (last 40 episodes): -1.410 | Loss: -1835.0186
# [Update 110/250] Global steps: 439980 | Episodes: 16470 | Median Steps: 18 | Mean Reward (on update 110): -1.506 | Mean Reward (last 40 episodes): -1.519 | Loss: -2163.5295
# [Update 115/250] Global steps: 459975 | Episodes: 17591 | Median Steps: 18 | Mean Reward (on update 115): -1.449 | Mean Reward (last 40 episodes): -1.366 | Loss: -2500.2693
# [Update 120/250] Global steps: 479956 | Episodes: 18712 | Median Steps: 18 | Mean Reward (on update 120): -1.488 | Mean Reward (last 40 episodes): -1.420 | Loss: -2875.4653
# [Update 125/250] Global steps: 499987 | Episodes: 19836 | Median Steps: 18 | Mean Reward (on update 125): -1.443 | Mean Reward (last 40 episodes): -1.380 | Loss: -3262.7437
# [Update 130/250] Global steps: 519961 | Episodes: 20956 | Median Steps: 18 | Mean Reward (on update 130): -1.484 | Mean Reward (last 40 episodes): -1.457 | Loss: -3704.5085
# [Update 135/250] Global steps: 539943 | Episodes: 22078 | Median Steps: 18 | Mean Reward (on update 135): -1.468 | Mean Reward (last 40 episodes): -1.490 | Loss: -4090.1270
# [Update 140/250] Global steps: 559971 | Episodes: 23202 | Median Steps: 18 | Mean Reward (on update 140): -1.460 | Mean Reward (last 40 episodes): -1.358 | Loss: -4836.1265
# [Update 145/250] Global steps: 579978 | Episodes: 24324 | Median Steps: 18 | Mean Reward (on update 145): -1.464 | Mean Reward (last 40 episodes): -1.370 | Loss: -5405.9707
# [Update 150/250] Global steps: 599988 | Episodes: 25446 | Median Steps: 18 | Mean Reward (on update 150): -1.480 | Mean Reward (last 40 episodes): -1.459 | Loss: -6179.7695
# [Update 155/250] Global steps: 619980 | Episodes: 26567 | Median Steps: 18 | Mean Reward (on update 155): -1.449 | Mean Reward (last 40 episodes): -1.350 | Loss: -6880.8110
# [Update 160/250] Global steps: 639971 | Episodes: 27688 | Median Steps: 18 | Mean Reward (on update 160): -1.442 | Mean Reward (last 40 episodes): -1.451 | Loss: -7503.7402
# [Update 165/250] Global steps: 659956 | Episodes: 28809 | Median Steps: 18 | Mean Reward (on update 165): -1.417 | Mean Reward (last 40 episodes): -1.437 | Loss: -8581.1299
# [Update 170/250] Global steps: 679975 | Episodes: 29931 | Median Steps: 18 | Mean Reward (on update 170): -1.434 | Mean Reward (last 40 episodes): -1.353 | Loss: -9704.8506
# [Update 175/250] Global steps: 699964 | Episodes: 31051 | Median Steps: 18 | Mean Reward (on update 175): -1.522 | Mean Reward (last 40 episodes): -1.482 | Loss: -10910.0557
# [Update 180/250] Global steps: 719969 | Episodes: 32172 | Median Steps: 18 | Mean Reward (on update 180): -1.480 | Mean Reward (last 40 episodes): -1.434 | Loss: -12148.3271
# [Update 185/250] Global steps: 739948 | Episodes: 33292 | Median Steps: 18 | Mean Reward (on update 185): -1.478 | Mean Reward (last 40 episodes): -1.419 | Loss: -13023.9609
# [Update 190/250] Global steps: 759971 | Episodes: 34415 | Median Steps: 18 | Mean Reward (on update 190): -1.418 | Mean Reward (last 40 episodes): -1.437 | Loss: -14560.3193
# [Update 195/250] Global steps: 779970 | Episodes: 35537 | Median Steps: 18 | Mean Reward (on update 195): -1.474 | Mean Reward (last 40 episodes): -1.396 | Loss: -16649.6836
# [Update 200/250] Global steps: 799964 | Episodes: 36658 | Median Steps: 18 | Mean Reward (on update 200): -1.478 | Mean Reward (last 40 episodes): -1.336 | Loss: -18234.3945
# [Update 205/250] Global steps: 819945 | Episodes: 37778 | Median Steps: 18 | Mean Reward (on update 205): -1.467 | Mean Reward (last 40 episodes): -1.469 | Loss: -19253.6484
# [Update 210/250] Global steps: 839955 | Episodes: 38900 | Median Steps: 18 | Mean Reward (on update 210): -1.510 | Mean Reward (last 40 episodes): -1.413 | Loss: -20937.4258
# [Update 215/250] Global steps: 859965 | Episodes: 40023 | Median Steps: 18 | Mean Reward (on update 215): -1.424 | Mean Reward (last 40 episodes): -1.410 | Loss: -23573.9004
# [Update 220/250] Global steps: 879979 | Episodes: 41146 | Median Steps: 18 | Mean Reward (on update 220): -1.462 | Mean Reward (last 40 episodes): -1.464 | Loss: -26309.1504
# [Update 225/250] Global steps: 899976 | Episodes: 42268 | Median Steps: 18 | Mean Reward (on update 225): -1.442 | Mean Reward (last 40 episodes): -1.355 | Loss: -27822.1504
# [Update 230/250] Global steps: 919985 | Episodes: 43391 | Median Steps: 18 | Mean Reward (on update 230): -1.434 | Mean Reward (last 40 episodes): -1.434 | Loss: -30499.0879
# [Update 235/250] Global steps: 939982 | Episodes: 44512 | Median Steps: 18 | Mean Reward (on update 235): -1.485 | Mean Reward (last 40 episodes): -1.439 | Loss: -33270.8984
# [Update 240/250] Global steps: 959967 | Episodes: 45633 | Median Steps: 18 | Mean Reward (on update 240): -1.462 | Mean Reward (last 40 episodes): -1.429 | Loss: -37788.7852
# [Update 245/250] Global steps: 979972 | Episodes: 46754 | Median Steps: 18 | Mean Reward (on update 245): -1.472 | Mean Reward (last 40 episodes): -1.422 | Loss: -41451.7148
# [Update 250/250] Global steps: 999967 | Episodes: 47876 | Median Steps: 18 | Mean Reward (on update 250): -1.451 | Mean Reward (last 40 episodes): -1.406 | Loss: -43060.2852
#
# Training Done!
# Mean Train Reward (last 40): -1.41 | Mean Eval Reward  (last 40): 0.06
# Running A3C
# Training A3C on Hopper-v4
# Workers: 6 | Episodes Per Worker: 500
# Worker 5 | Episode 20 | Step Counts: 69 | Train Reward: 40.24
# Worker 4 | Episode 20 | Step Counts: 192 | Train Reward: 163.70
# Worker 3 | Episode 20 | Step Counts: 55 | Train Reward: 24.96
# Worker 1 | Episode 20 | Step Counts: 233 | Train Reward: 261.00
# Worker 0 | Episode 20 | Step Counts: 73 | Train Reward: 42.84
# Worker 2 | Episode 20 | Step Counts: 68 | Train Reward: 38.80
# Worker 1 | Episode 40 | Step Counts: 41 | Train Reward: 68.08
# Worker 5 | Episode 40 | Step Counts: 45 | Train Reward: 72.54
# Worker 3 | Episode 40 | Step Counts: 64 | Train Reward: 105.26
# Worker 0 | Episode 40 | Step Counts: 44 | Train Reward: 71.73
# Worker 4 | Episode 40 | Step Counts: 44 | Train Reward: 73.40
# Worker 2 | Episode 40 | Step Counts: 46 | Train Reward: 76.65
# Worker 1 | Episode 60 | Step Counts: 63 | Train Reward: 121.89
# Worker 5 | Episode 60 | Step Counts: 44 | Train Reward: 66.66
# Worker 4 | Episode 60 | Step Counts: 32 | Train Reward: 43.33
# Worker 3 | Episode 60 | Step Counts: 77 | Train Reward: 163.07
# Worker 0 | Episode 60 | Step Counts: 52 | Train Reward: 92.14
# Worker 2 | Episode 60 | Step Counts: 80 | Train Reward: 173.68
# Worker 1 | Episode 80 | Step Counts: 50 | Train Reward: 85.77
# Worker 5 | Episode 80 | Step Counts: 48 | Train Reward: 81.00
# Worker 3 | Episode 80 | Step Counts: 98 | Train Reward: 183.44
# Worker 4 | Episode 80 | Step Counts: 65 | Train Reward: 96.32
# Worker 0 | Episode 80 | Step Counts: 161 | Train Reward: 245.96
# Worker 2 | Episode 80 | Step Counts: 97 | Train Reward: 199.62
# Worker 1 | Episode 100 | Step Counts: 26 | Train Reward: 45.11
# Worker 5 | Episode 100 | Step Counts: 48 | Train Reward: 91.39
# Worker 0 | Episode 100 | Step Counts: 88 | Train Reward: 178.42
# Worker 4 | Episode 100 | Step Counts: 79 | Train Reward: 154.72
# Worker 3 | Episode 100 | Step Counts: 71 | Train Reward: 130.84
# Worker 2 | Episode 100 | Step Counts: 61 | Train Reward: 111.39
# Worker 1 | Episode 120 | Step Counts: 28 | Train Reward: 48.87
# Worker 5 | Episode 120 | Step Counts: 87 | Train Reward: 177.17
# Worker 0 | Episode 120 | Step Counts: 38 | Train Reward: 69.84
# Worker 4 | Episode 120 | Step Counts: 24 | Train Reward: 42.46
# Worker 3 | Episode 120 | Step Counts: 37 | Train Reward: 58.88
# Worker 2 | Episode 120 | Step Counts: 97 | Train Reward: 218.15
# Worker 1 | Episode 140 | Step Counts: 53 | Train Reward: 97.53
# Worker 4 | Episode 140 | Step Counts: 89 | Train Reward: 174.66
# Worker 0 | Episode 140 | Step Counts: 88 | Train Reward: 174.87
# Worker 5 | Episode 140 | Step Counts: 41 | Train Reward: 74.10
# Worker 3 | Episode 140 | Step Counts: 72 | Train Reward: 135.83
# Worker 2 | Episode 140 | Step Counts: 44 | Train Reward: 78.08
# Worker 1 | Episode 160 | Step Counts: 49 | Train Reward: 76.55
# Worker 0 | Episode 160 | Step Counts: 64 | Train Reward: 115.17
# Worker 4 | Episode 160 | Step Counts: 71 | Train Reward: 133.24
# Worker 5 | Episode 160 | Step Counts: 134 | Train Reward: 302.22
# Worker 3 | Episode 160 | Step Counts: 123 | Train Reward: 218.80
# Worker 2 | Episode 160 | Step Counts: 111 | Train Reward: 238.08
# Worker 1 | Episode 180 | Step Counts: 291 | Train Reward: 421.67
# Worker 0 | Episode 180 | Step Counts: 71 | Train Reward: 92.56
# Worker 4 | Episode 180 | Step Counts: 62 | Train Reward: 112.65
# Worker 5 | Episode 180 | Step Counts: 103 | Train Reward: 226.27
# Worker 3 | Episode 180 | Step Counts: 104 | Train Reward: 217.35
# Worker 2 | Episode 180 | Step Counts: 96 | Train Reward: 186.91
# Worker 1 | Episode 200 | Step Counts: 23 | Train Reward: 27.09
# Worker 0 | Episode 200 | Step Counts: 17 | Train Reward: 16.77
# Worker 4 | Episode 200 | Step Counts: 12 | Train Reward: 9.04
# Worker 5 | Episode 200 | Step Counts: 13 | Train Reward: 9.64
# Worker 3 | Episode 200 | Step Counts: 12 | Train Reward: 7.69
# Worker 2 | Episode 200 | Step Counts: 14 | Train Reward: 10.57
# Worker 1 | Episode 220 | Step Counts: 10 | Train Reward: 4.75
# Worker 0 | Episode 220 | Step Counts: 17 | Train Reward: 11.67
# Worker 5 | Episode 220 | Step Counts: 10 | Train Reward: 5.89
# Worker 4 | Episode 220 | Step Counts: 11 | Train Reward: 6.98
# Worker 3 | Episode 220 | Step Counts: 10 | Train Reward: 5.01
# Worker 2 | Episode 220 | Step Counts: 11 | Train Reward: 6.61
# Worker 1 | Episode 240 | Step Counts: 10 | Train Reward: 5.81
# Worker 0 | Episode 240 | Step Counts: 10 | Train Reward: 6.05
# Worker 5 | Episode 240 | Step Counts: 10 | Train Reward: 5.03
# Worker 4 | Episode 240 | Step Counts: 10 | Train Reward: 5.27
# Worker 3 | Episode 240 | Step Counts: 10 | Train Reward: 5.39
# Worker 2 | Episode 240 | Step Counts: 11 | Train Reward: 6.24
# Worker 1 | Episode 260 | Step Counts: 12 | Train Reward: 7.81
# Worker 0 | Episode 260 | Step Counts: 10 | Train Reward: 5.49
# Worker 5 | Episode 260 | Step Counts: 12 | Train Reward: 7.42
# Worker 4 | Episode 260 | Step Counts: 11 | Train Reward: 6.31
# Worker 3 | Episode 260 | Step Counts: 10 | Train Reward: 5.57
# Worker 2 | Episode 260 | Step Counts: 11 | Train Reward: 7.75
# Worker 1 | Episode 280 | Step Counts: 11 | Train Reward: 6.36
# Worker 0 | Episode 280 | Step Counts: 10 | Train Reward: 4.89
# Worker 5 | Episode 280 | Step Counts: 10 | Train Reward: 5.30
# Worker 4 | Episode 280 | Step Counts: 10 | Train Reward: 5.18
# Worker 3 | Episode 280 | Step Counts: 10 | Train Reward: 5.31
# Worker 2 | Episode 280 | Step Counts: 11 | Train Reward: 6.99
# Worker 1 | Episode 300 | Step Counts: 11 | Train Reward: 7.16
# Worker 0 | Episode 300 | Step Counts: 10 | Train Reward: 5.42
# Worker 5 | Episode 300 | Step Counts: 11 | Train Reward: 6.56
# Worker 4 | Episode 300 | Step Counts: 10 | Train Reward: 5.90
# Worker 3 | Episode 300 | Step Counts: 10 | Train Reward: 6.18
# Worker 2 | Episode 300 | Step Counts: 10 | Train Reward: 5.62
# Worker 1 | Episode 320 | Step Counts: 10 | Train Reward: 6.14
# Worker 0 | Episode 320 | Step Counts: 10 | Train Reward: 4.84
# Worker 5 | Episode 320 | Step Counts: 10 | Train Reward: 5.46
# Worker 4 | Episode 320 | Step Counts: 10 | Train Reward: 5.00
# Worker 3 | Episode 320 | Step Counts: 10 | Train Reward: 5.26
# Worker 2 | Episode 320 | Step Counts: 10 | Train Reward: 5.13
# Worker 1 | Episode 340 | Step Counts: 10 | Train Reward: 4.79
# Worker 0 | Episode 340 | Step Counts: 11 | Train Reward: 6.06
# Worker 5 | Episode 340 | Step Counts: 10 | Train Reward: 6.33
# Worker 3 | Episode 340 | Step Counts: 11 | Train Reward: 6.65
# Worker 4 | Episode 340 | Step Counts: 10 | Train Reward: 5.00
# Worker 1 | Episode 360 | Step Counts: 10 | Train Reward: 4.67
# Worker 2 | Episode 340 | Step Counts: 10 | Train Reward: 5.25
# Worker 0 | Episode 360 | Step Counts: 10 | Train Reward: 5.49
# Worker 5 | Episode 360 | Step Counts: 10 | Train Reward: 5.20
# Worker 4 | Episode 360 | Step Counts: 10 | Train Reward: 5.02
# Worker 3 | Episode 360 | Step Counts: 11 | Train Reward: 6.64
# Worker 1 | Episode 380 | Step Counts: 10 | Train Reward: 5.11
# Worker 2 | Episode 360 | Step Counts: 10 | Train Reward: 5.14
# Worker 0 | Episode 380 | Step Counts: 11 | Train Reward: 6.61
# Worker 5 | Episode 380 | Step Counts: 10 | Train Reward: 5.27
# Worker 3 | Episode 380 | Step Counts: 10 | Train Reward: 5.34
# Worker 4 | Episode 380 | Step Counts: 10 | Train Reward: 5.41
# Worker 1 | Episode 400 | Step Counts: 10 | Train Reward: 4.87
# Worker 2 | Episode 380 | Step Counts: 10 | Train Reward: 5.03
# Worker 0 | Episode 400 | Step Counts: 10 | Train Reward: 5.12
# Worker 5 | Episode 400 | Step Counts: 10 | Train Reward: 4.90
# Worker 4 | Episode 400 | Step Counts: 12 | Train Reward: 7.03
# Worker 3 | Episode 400 | Step Counts: 10 | Train Reward: 4.88
# Worker 1 | Episode 420 | Step Counts: 10 | Train Reward: 4.48
# Worker 2 | Episode 400 | Step Counts: 13 | Train Reward: 7.93
# Worker 0 | Episode 420 | Step Counts: 10 | Train Reward: 5.49
# Worker 5 | Episode 420 | Step Counts: 12 | Train Reward: 6.97
# Worker 4 | Episode 420 | Step Counts: 10 | Train Reward: 4.35
# Worker 3 | Episode 420 | Step Counts: 10 | Train Reward: 5.06
# Worker 1 | Episode 440 | Step Counts: 12 | Train Reward: 4.85
# Worker 2 | Episode 420 | Step Counts: 10 | Train Reward: 4.08
# Worker 0 | Episode 440 | Step Counts: 10 | Train Reward: 4.10
# Worker 5 | Episode 440 | Step Counts: 10 | Train Reward: 4.73
# Worker 3 | Episode 440 | Step Counts: 11 | Train Reward: 6.59
# Worker 4 | Episode 440 | Step Counts: 10 | Train Reward: 4.91
# Worker 1 | Episode 460 | Step Counts: 10 | Train Reward: 4.30
# Worker 2 | Episode 440 | Step Counts: 10 | Train Reward: 4.98
# Worker 0 | Episode 460 | Step Counts: 10 | Train Reward: 6.00
# Worker 5 | Episode 460 | Step Counts: 11 | Train Reward: 6.98
# Worker 3 | Episode 460 | Step Counts: 10 | Train Reward: 6.28
# Worker 4 | Episode 460 | Step Counts: 11 | Train Reward: 7.19
# Worker 1 | Episode 480 | Step Counts: 10 | Train Reward: 5.53
# Worker 2 | Episode 460 | Step Counts: 10 | Train Reward: 5.39
# Worker 0 | Episode 480 | Step Counts: 11 | Train Reward: 7.59
# Worker 5 | Episode 480 | Step Counts: 10 | Train Reward: 5.45
# Worker 3 | Episode 480 | Step Counts: 11 | Train Reward: 7.69
# Worker 4 | Episode 480 | Step Counts: 10 | Train Reward: 6.08
# Worker 1 | Episode 500 | Step Counts: 10 | Train Reward: 5.77
# Worker 2 | Episode 480 | Step Counts: 14 | Train Reward: 11.36
# Worker 0 | Episode 500 | Step Counts: 11 | Train Reward: 6.95
# Worker 3 | Episode 500 | Step Counts: 11 | Train Reward: 6.42
# Worker 5 | Episode 500 | Step Counts: 12 | Train Reward: 8.82
# Worker 4 | Episode 500 | Step Counts: 11 | Train Reward: 7.26
# Worker 2 | Episode 500 | Step Counts: 12 | Train Reward: 8.58
#
# Training Done!
# Mean Train Reward (last 40 episodes): 6.84 | Mean Eval Reward (last 40 episodes): 7.21

# %%
SAVE_PATH_COMP = "./plot_configs/rl_results_comp.pkl"
# with open(SAVE_PATH_COMP, "wb") as f:
#     pickle.dump(result, f)

# %%
with open(SAVE_PATH_COMP, "rb") as f:
    result = pickle.load(f)

# %%
plotResults(result, [a2c_gym_id])

# %% [markdown]
# ## GAE Questions [$10 \times 4 = 40$ marks]
#
# ### Q1. Derive the GAE formula starting from multi-step advantage estimates.
#
#
#
# ### Q2. What happens at the extreme values of λ, and what is a good practical default?
#
#
#
# ### Q3. From the GAE lambda sweep experiment, which lambda values perform best and why?
#
#
#
# ### Q4. How does GAE relate to TD(λ) from tabular RL?

# %% [markdown]
# # Deep Deterministic Policy Gradient (DDPG) [50 marks]
# <a id="ddpg"></a>

# %% [markdown]
# Implement the Deep Deterministic Policy Gradient (DDPG) agent. We have studied about DDPG agent in the Lecture. Use the function definitions (given below).
#
# This class implements the DDPG agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# ```
# class DDPG():
#     def init(self, env, seed, gamma, tau, bufferSize, batch_size, updateFrequency,
#              policyOptimizerFn, valueOptimizerFn,
#              policyOptimizerLR,valueOptimizerLR,
#              MAX_TRAIN_EPISODES,MAX_EVAL_EPISODE,
#              optimizerFn)
#
#     def runDDPG(self)
#     def trainAgent(self)
#     def gaussianStrategy(self, net , s , envActionRange , noiseScaleRatio,
#         explorationMax = True)
#     def greedyStrategy(self, net , s , envActionRange)
#     def trainNetworks(self, experiences)
#     def updateNetworks(self, onlineNet, targetNet, tau)
#     def evaluateAgent(self)
#
#
#
#
# ```

# %%
class DDPG():
    def __init__(self, env, seed, gamma, tau, bufferSize, batch_size, updateFrequency,
             policyOptimizerFn, valueOptimizerFn,
             policyOptimizerLR,valueOptimizerLR,
             MAX_TRAIN_EPISODES,MAX_EVAL_EPISODE,
             optimizerFn):
        #this DDPG method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates targetValueNetwork , targetPolicyNetwork
        # 4. creates and initializes (with network params) the optimizer function
        # 5. creates onlineValueNetwork, onlinePolicyNetwork
        # 6. Creates the replayBuffer

        #Your code goes in here
        self.env = env
        self.seed = seed
        self.env.reset(seed=seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        self.env.action_space.seed(seed)
        self.env.observation_space.seed(seed)

        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODE = MAX_EVAL_EPISODE
        self.MAX_VALUE_GRAD_NORM = MAX_GRAD_NORM_VALUE
        self.MAX_POLICY_GRAD_NORM = MAX_GRAD_NORM_POLICY

        self.gamma = gamma
        self.tau = tau
        self.bufferSize = bufferSize
        self.batch_size = batch_size
        self.updateFrequency = updateFrequency
        self.minSamples = minSamples
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.obs_dim = self.env.observation_space.shape[0]
        self.act_dim = self.env.action_space.shape[0]
        self.max_steps = ep_max_steps
        self.noiseScaleRatio = noiseScaleRatio

        self.targetValueNetwork = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[256, 256, 256]).to(self.device)
        self.onlineValueNetwork = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[256, 256, 256]).to(self.device)
        self.targetPolicyNetwork = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=[256, 256, 256], use_tanh=True).to(self.device)
        self.onlinePolicyNetwork = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=[256, 256, 256], use_tanh=True).to(self.device)

        self.updateNetworks(self.onlineValueNetwork, self.targetValueNetwork, 1.0)
        self.updateNetworks(self.onlinePolicyNetwork, self.targetPolicyNetwork, 1.0)

        self.policyOptimizer = policyOptimizerFn(self.onlinePolicyNetwork.parameters(), lr=policyOptimizerLR)
        self.valueOptimizer = valueOptimizerFn(self.onlineValueNetwork.parameters(), lr=valueOptimizerLR)

        self.actionLowVal = torch.tensor(self.env.action_space.low, dtype=torch.float32).to(self.device)
        self.actionHighVal = torch.tensor(self.env.action_space.high, dtype=torch.float32).to(self.device)
        self.envActionRange = (self.actionLowVal, self.actionHighVal)

        self.initBookKeeping()
        self.rBuffer = ReplayBuffer(self.bufferSize, self.batch_size, self.seed)

# %%
class DDPG(DDPG):
    def initBookKeeping(self):

      self.trainRewardsList = []
      self.evalRewardsList = []
      self.trainTimeList = []
      self.wallClockTimeList = []
      self.totalStepsList = []

      self.startTime = time.time()

    def performBookKeeping(self, train=True):
        if train:
            self.trainTimeList.append(time.time() - self.startTime)
        else:
            self.wallClockTimeList.append(time.time() - self.startTime)

# %%
class DDPG(DDPG):
    def updateNetworks(self, onlineNet, targetNet, tau):
        #this function updates the onlineNetwork with the target network
        #
        # Your code goes in here
        #
        for targetParam, onlineParam in zip(targetNet.parameters(), onlineNet.parameters()):
            mixedWeights = onlineParam.data * tau + targetParam.data * (1 - tau)
            targetParam.data.copy_(mixedWeights)

# %%
class DDPG(DDPG):
    def gaussianStrategy (self, net , s , envActionRange , noiseScaleRatio , explorationMax = True):
        #this function sets the scale of exploration then add the noise of this scale to the greedy action
        #and clips it within the range

        #Your code here
        if explorationMax:
            return self.env.action_space.sample()

        with torch.no_grad():
            state = torch.FloatTensor(s).unsqueeze(0).to(self.device)
            actionLowVec, actionHighVec = envActionRange
            action = net(state).cpu().numpy()[0]

            if noiseScaleRatio > 0:
                noise = np.random.normal(0, noiseScaleRatio, size=action.shape)
                action = action + noise

            action = np.clip(action, actionLowVec.cpu().numpy(), actionHighVec.cpu().numpy())

            return action

# %%
class DDPG(DDPG):
    def greedyStrategy (self, net , s , envActionRange):
        #this function selects the greedy action
        #and clips it within the range

        #Your code here
        with torch.no_grad():
            state = torch.FloatTensor(s).unsqueeze(0).to(self.device)
            actionLowVec, actionHighVec = envActionRange
            action = net(state).cpu().numpy()[0]

            action = np.clip(action, actionLowVec.cpu().numpy(), actionHighVec.cpu().numpy())

            return action

# %%
class DDPG(DDPG):
    def runDDPG (self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.
        #
        #Your code goes in here
        #
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
        finalEvalReward = self.evaluateAgent()
        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward

# %%
class DDPG(DDPG):
    def trainAgent(self):
        #this method collects experiences and trains the agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES
        #
        #Your code goes in here
        #
        global_steps = 0
        global_max_steps = self.MAX_TRAIN_EPISODES * self.max_steps

        for e in range(self.MAX_TRAIN_EPISODES):
            s, _ = self.env.reset()
            train_r = 0.0
            steps = 0
            done = False

            while steps < self.max_steps and not done:
                # i am decaying noiseScaleRatio linearly wrt the global number of steps taken across episodes
                current_noise = max(0.01, self.noiseScaleRatio * (1 - global_steps / global_max_steps))
                action = self.gaussianStrategy(
                    self.onlinePolicyNetwork, s, self.envActionRange, current_noise,
                    self.rBuffer.length() < self.minSamples
                )

                sNext, rs, done, truncated, _ = self.env.step(action)
                done = done or truncated
                train_r += rs

                self.rBuffer.store(s, action, rs, sNext, done)

                if self.rBuffer.length() >= self.minSamples:
                    experiences = self.rBuffer.sample(self.batch_size)
                    self.trainNetwork(experiences)

                    if steps % self.updateFrequency == 0:
                        self.updateNetworks(self.onlineValueNetwork, self.targetValueNetwork, self.tau)
                        self.updateNetworks(self.onlinePolicyNetwork, self.targetPolicyNetwork, self.tau)

                steps += 1
                global_steps += 1
                s = sNext
            # for reporting episodewise train time, I am bookkeeping traain time after episode ends not after each step
            self.performBookKeeping(train=True)

            # evaluating after every episode
            eval_r = self.evaluateAgent()
            self.performBookKeeping(train=False)

            self.trainRewardsList.append(train_r)
            self.evalRewardsList.append(eval_r)
            self.totalStepsList.append(steps)

            if (e+1) % 5 == 0:
                print(f"[Episode {e+1}/{self.MAX_TRAIN_EPISODES}] Train Reward: {train_r:.3f} | Eval Reward: {eval_r:.3f} | Steps: {steps}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList, self.wallClockTimeList, self.totalStepsList

# %%
class DDPG(DDPG):
    def trainNetwork(self, experiences):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.
        #
        #Your code goes in here

        ss, actions, rs, sNexts, dones = self.rBuffer.splitExperiences(experiences)

        ss = ss.to(self.device)
        actions = actions.to(self.device)
        rs = rs.to(self.device)
        sNexts = sNexts.to(self.device)
        dones = dones.to(self.device)

        with torch.no_grad():
            next_actions = self.targetPolicyNetwork(sNexts)
            next_q = self.targetValueNetwork(sNexts, next_actions)
            targets = rs + self.gamma * (1 - dones) * next_q

        current_q = self.onlineValueNetwork(ss, actions)
        valueLoss = F.mse_loss(current_q, targets)

        self.valueOptimizer.zero_grad()
        valueLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizer.step()

        pred_actions = self.onlinePolicyNetwork(ss)
        actor_loss = -self.onlineValueNetwork(ss, pred_actions).mean()
        self.policyOptimizer.zero_grad()
        actor_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.onlinePolicyNetwork.parameters(), self.MAX_POLICY_GRAD_NORM)
        self.policyOptimizer.step()

# %%
class DDPG(DDPG):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1
        #
        #Your code goes in here

        final_eval_r = 0.0
        for e in range(self.MAX_EVAL_EPISODE):
            s, _ = self.env.reset()
            done = False
            for c in count():
                envActionRange = (self.actionLowVal, self.actionHighVal)
                a = self.greedyStrategy(self.onlinePolicyNetwork, s, envActionRange)
                s_next, r, done, truncated, _ = self.env.step(a)
                final_eval_r += r
                s = s_next
                if done or truncated:
                    break
        final_eval_r /= self.MAX_EVAL_EPISODE
        return final_eval_r

# %%
# evaluating the DDPG agent on multiple continuous-control

# Environments used in this experiment
ddpg_env_name = "HalfCheetah-v4"

quantityDictDDPG = {}

# Number of independent training runs per environment
num_runs = 5

all_train_rewards = []
all_eval_rewards = []
all_total_steps = []
all_train_times = []
all_wall_times = []

# For each environment:
print(f"\n===== Environment: {ddpg_env_name} =====")
for run in range(num_runs):
    print(f"Executing Run {run+1}  ")

    # Create environment
    env = gym.make(ddpg_env_name)

    agent = DDPG(
        env, base_seed + run, gamma, tau, bufferSize, batchSize, updateFrequency,
        policyOptimizerFn, valueOptimizerFn,
        policyOptimizerLR, valueOptimizerLR,
        MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
        optimizerFn
    )

    # Run training
    train_rewards, train_times, eval_rewards, wallclock_times, total_steps, final_eval_reward = agent.runDDPG()

    print(f"Finished Run {run+1}  ")

    all_train_rewards.append(train_rewards)
    all_eval_rewards.append(eval_rewards)
    all_train_times.append(train_times)
    all_wall_times.append(wallclock_times)
    all_total_steps.append(total_steps)

quantityDictDDPG[ddpg_env_name] = {
    "Mean Train Rewards": {
        "DDPG": all_train_rewards
    },
    "Mean Eval Rewards": {
        "DDPG": all_eval_rewards
    },
    "Train Time (in sec)": {
        "DDPG": all_train_times
    },
    "Wall Clock Time (in sec)": {
        "DDPG": all_wall_times
    },
    "Total Steps": {
        "DDPG": all_total_steps
    }
}

train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
print(f"Finished {ddpg_env_name}")
# Out:
# ===== Environment: HalfCheetah-v4 =====
# Executing Run 1
# [Episode 5/150] Train Reward: -491.362 | Eval Reward: -205.801 | Steps: 1000
# [Episode 10/150] Train Reward: -399.436 | Eval Reward: -21.859 | Steps: 1000
# [Episode 15/150] Train Reward: -452.104 | Eval Reward: -528.438 | Steps: 1000
# [Episode 20/150] Train Reward: -45.515 | Eval Reward: -589.780 | Steps: 1000
# [Episode 25/150] Train Reward: 227.902 | Eval Reward: 152.501 | Steps: 1000
# [Episode 30/150] Train Reward: -22.209 | Eval Reward: 183.158 | Steps: 1000
# [Episode 35/150] Train Reward: 272.251 | Eval Reward: 601.987 | Steps: 1000
# [Episode 40/150] Train Reward: 164.325 | Eval Reward: 203.742 | Steps: 1000
# [Episode 45/150] Train Reward: 513.793 | Eval Reward: 550.723 | Steps: 1000
# [Episode 50/150] Train Reward: 641.336 | Eval Reward: 566.175 | Steps: 1000
# [Episode 55/150] Train Reward: 140.734 | Eval Reward: 580.848 | Steps: 1000
# [Episode 60/150] Train Reward: 762.819 | Eval Reward: 216.021 | Steps: 1000
# [Episode 65/150] Train Reward: 1015.197 | Eval Reward: 835.348 | Steps: 1000
# [Episode 70/150] Train Reward: 1339.826 | Eval Reward: 1199.269 | Steps: 1000
# [Episode 75/150] Train Reward: -54.612 | Eval Reward: 50.090 | Steps: 1000
# [Episode 80/150] Train Reward: 1319.950 | Eval Reward: 696.791 | Steps: 1000
# [Episode 85/150] Train Reward: 826.777 | Eval Reward: 1433.282 | Steps: 1000
# [Episode 90/150] Train Reward: 1441.278 | Eval Reward: 1802.122 | Steps: 1000
# [Episode 95/150] Train Reward: 1454.194 | Eval Reward: 1601.285 | Steps: 1000
# [Episode 100/150] Train Reward: 592.667 | Eval Reward: 1899.314 | Steps: 1000
# [Episode 105/150] Train Reward: 1807.891 | Eval Reward: 666.817 | Steps: 1000
# [Episode 110/150] Train Reward: 1710.236 | Eval Reward: -267.538 | Steps: 1000
# [Episode 115/150] Train Reward: 2275.954 | Eval Reward: 2032.918 | Steps: 1000
# [Episode 120/150] Train Reward: 2178.047 | Eval Reward: 2315.061 | Steps: 1000
# [Episode 125/150] Train Reward: 2350.418 | Eval Reward: 2360.560 | Steps: 1000
# [Episode 130/150] Train Reward: 2729.401 | Eval Reward: 2618.579 | Steps: 1000
# [Episode 135/150] Train Reward: 2926.471 | Eval Reward: 2947.211 | Steps: 1000
# [Episode 140/150] Train Reward: 2823.590 | Eval Reward: 2482.987 | Steps: 1000
# [Episode 145/150] Train Reward: 2837.179 | Eval Reward: 3316.373 | Steps: 1000
# [Episode 150/150] Train Reward: 3298.386 | Eval Reward: 3061.711 | Steps: 1000
# Finished Run 1
# Executing Run 2
# [Episode 5/150] Train Reward: -317.332 | Eval Reward: -288.345 | Steps: 1000
# [Episode 10/150] Train Reward: -363.499 | Eval Reward: -280.591 | Steps: 1000
# [Episode 15/150] Train Reward: -667.505 | Eval Reward: -618.122 | Steps: 1000
# [Episode 20/150] Train Reward: -467.644 | Eval Reward: -417.173 | Steps: 1000
# [Episode 25/150] Train Reward: -7.159 | Eval Reward: -29.876 | Steps: 1000
# [Episode 30/150] Train Reward: 73.863 | Eval Reward: -45.369 | Steps: 1000
# [Episode 35/150] Train Reward: -436.755 | Eval Reward: -165.074 | Steps: 1000
# [Episode 40/150] Train Reward: -398.281 | Eval Reward: 161.047 | Steps: 1000
# [Episode 45/150] Train Reward: -330.075 | Eval Reward: -171.242 | Steps: 1000
# [Episode 50/150] Train Reward: -529.366 | Eval Reward: -482.507 | Steps: 1000
# [Episode 55/150] Train Reward: -470.471 | Eval Reward: -392.926 | Steps: 1000
# [Episode 60/150] Train Reward: -378.417 | Eval Reward: -140.027 | Steps: 1000
# [Episode 65/150] Train Reward: -97.939 | Eval Reward: -121.304 | Steps: 1000
# [Episode 70/150] Train Reward: 335.151 | Eval Reward: 309.713 | Steps: 1000
# [Episode 75/150] Train Reward: -61.500 | Eval Reward: -292.769 | Steps: 1000
# [Episode 80/150] Train Reward: 229.557 | Eval Reward: 345.088 | Steps: 1000
# [Episode 85/150] Train Reward: 542.345 | Eval Reward: 629.255 | Steps: 1000
# [Episode 90/150] Train Reward: 622.962 | Eval Reward: 612.484 | Steps: 1000
# [Episode 95/150] Train Reward: 566.034 | Eval Reward: 1017.257 | Steps: 1000
# [Episode 100/150] Train Reward: 988.907 | Eval Reward: 1095.150 | Steps: 1000
# [Episode 105/150] Train Reward: 1486.958 | Eval Reward: 682.872 | Steps: 1000
# [Episode 110/150] Train Reward: 1653.866 | Eval Reward: 1671.554 | Steps: 1000
# [Episode 115/150] Train Reward: 2202.483 | Eval Reward: 1945.465 | Steps: 1000
# [Episode 120/150] Train Reward: 1696.255 | Eval Reward: 1607.217 | Steps: 1000
# [Episode 125/150] Train Reward: 1559.946 | Eval Reward: 2145.494 | Steps: 1000
# [Episode 130/150] Train Reward: 1977.015 | Eval Reward: 1733.671 | Steps: 1000
# [Episode 135/150] Train Reward: 1394.838 | Eval Reward: 2025.667 | Steps: 1000
# [Episode 140/150] Train Reward: 2151.936 | Eval Reward: 2228.654 | Steps: 1000
# [Episode 145/150] Train Reward: 2165.545 | Eval Reward: 2082.572 | Steps: 1000
# [Episode 150/150] Train Reward: 2471.666 | Eval Reward: 2818.905 | Steps: 1000
# Finished Run 2
# Executing Run 3
# [Episode 5/150] Train Reward: -122.539 | Eval Reward: -504.633 | Steps: 1000
# [Episode 10/150] Train Reward: -305.426 | Eval Reward: -261.582 | Steps: 1000
# [Episode 15/150] Train Reward: -487.818 | Eval Reward: -657.322 | Steps: 1000
# [Episode 20/150] Train Reward: -392.999 | Eval Reward: -464.596 | Steps: 1000
# [Episode 25/150] Train Reward: -375.688 | Eval Reward: 234.239 | Steps: 1000
# [Episode 30/150] Train Reward: -223.357 | Eval Reward: -169.636 | Steps: 1000
# [Episode 35/150] Train Reward: 194.465 | Eval Reward: 30.810 | Steps: 1000
# [Episode 40/150] Train Reward: -96.570 | Eval Reward: 69.367 | Steps: 1000
# [Episode 45/150] Train Reward: 138.468 | Eval Reward: 94.805 | Steps: 1000
# [Episode 50/150] Train Reward: -135.436 | Eval Reward: -376.084 | Steps: 1000
# [Episode 55/150] Train Reward: -148.819 | Eval Reward: -221.792 | Steps: 1000
# [Episode 60/150] Train Reward: 83.384 | Eval Reward: 384.933 | Steps: 1000
# [Episode 65/150] Train Reward: 198.492 | Eval Reward: 377.053 | Steps: 1000
# [Episode 70/150] Train Reward: -225.460 | Eval Reward: 214.311 | Steps: 1000
# [Episode 75/150] Train Reward: -78.545 | Eval Reward: -16.546 | Steps: 1000
# [Episode 80/150] Train Reward: -188.487 | Eval Reward: 153.178 | Steps: 1000
# [Episode 85/150] Train Reward: 233.062 | Eval Reward: 682.010 | Steps: 1000
# [Episode 90/150] Train Reward: -17.511 | Eval Reward: 52.239 | Steps: 1000
# [Episode 95/150] Train Reward: 653.567 | Eval Reward: 924.168 | Steps: 1000
# [Episode 100/150] Train Reward: 1042.044 | Eval Reward: 221.794 | Steps: 1000
# [Episode 105/150] Train Reward: 1110.350 | Eval Reward: 1009.497 | Steps: 1000
# [Episode 110/150] Train Reward: 394.634 | Eval Reward: 1199.293 | Steps: 1000
# [Episode 115/150] Train Reward: 1582.092 | Eval Reward: 1241.457 | Steps: 1000
# [Episode 120/150] Train Reward: 1041.259 | Eval Reward: 1247.001 | Steps: 1000
# [Episode 125/150] Train Reward: 1208.972 | Eval Reward: 1746.256 | Steps: 1000
# [Episode 130/150] Train Reward: 1732.083 | Eval Reward: 1896.703 | Steps: 1000
# [Episode 135/150] Train Reward: 1785.217 | Eval Reward: 1292.783 | Steps: 1000
# [Episode 140/150] Train Reward: 1612.899 | Eval Reward: 1745.274 | Steps: 1000
# [Episode 145/150] Train Reward: 1699.793 | Eval Reward: 1362.603 | Steps: 1000
# [Episode 150/150] Train Reward: 1682.793 | Eval Reward: 2349.267 | Steps: 1000
# Finished Run 3
# Executing Run 4
# [Episode 5/150] Train Reward: -280.047 | Eval Reward: -81.221 | Steps: 1000
# [Episode 10/150] Train Reward: -369.911 | Eval Reward: -103.049 | Steps: 1000
# [Episode 15/150] Train Reward: -586.629 | Eval Reward: -513.342 | Steps: 1000
# [Episode 20/150] Train Reward: -572.495 | Eval Reward: -463.542 | Steps: 1000
# [Episode 25/150] Train Reward: -34.947 | Eval Reward: -85.620 | Steps: 1000
# [Episode 30/150] Train Reward: 42.611 | Eval Reward: 87.646 | Steps: 1000
# [Episode 35/150] Train Reward: -283.778 | Eval Reward: 227.599 | Steps: 1000
# [Episode 40/150] Train Reward: -34.016 | Eval Reward: -0.563 | Steps: 1000
# [Episode 45/150] Train Reward: -113.653 | Eval Reward: 39.737 | Steps: 1000
# [Episode 50/150] Train Reward: 36.372 | Eval Reward: 58.222 | Steps: 1000
# [Episode 55/150] Train Reward: -42.550 | Eval Reward: -259.963 | Steps: 1000
# [Episode 60/150] Train Reward: 131.961 | Eval Reward: 263.954 | Steps: 1000
# [Episode 65/150] Train Reward: -80.105 | Eval Reward: -243.620 | Steps: 1000
# [Episode 70/150] Train Reward: 476.938 | Eval Reward: -38.274 | Steps: 1000
# [Episode 75/150] Train Reward: -48.343 | Eval Reward: 407.677 | Steps: 1000
# [Episode 80/150] Train Reward: 400.331 | Eval Reward: 146.428 | Steps: 1000
# [Episode 85/150] Train Reward: 577.136 | Eval Reward: 222.869 | Steps: 1000
# [Episode 90/150] Train Reward: 541.286 | Eval Reward: 341.736 | Steps: 1000
# [Episode 95/150] Train Reward: 1001.720 | Eval Reward: 642.409 | Steps: 1000
# [Episode 100/150] Train Reward: 1303.212 | Eval Reward: 1100.465 | Steps: 1000
# [Episode 105/150] Train Reward: 1141.098 | Eval Reward: 1633.844 | Steps: 1000
# [Episode 110/150] Train Reward: 1690.926 | Eval Reward: 903.460 | Steps: 1000
# [Episode 115/150] Train Reward: 1467.706 | Eval Reward: 1920.325 | Steps: 1000
# [Episode 120/150] Train Reward: 1994.633 | Eval Reward: 1950.698 | Steps: 1000
# [Episode 125/150] Train Reward: 1879.948 | Eval Reward: 2229.745 | Steps: 1000
# [Episode 130/150] Train Reward: 2420.111 | Eval Reward: 2159.581 | Steps: 1000
# [Episode 135/150] Train Reward: 1767.985 | Eval Reward: 2544.177 | Steps: 1000
# [Episode 140/150] Train Reward: 1691.147 | Eval Reward: 2686.970 | Steps: 1000
# [Episode 145/150] Train Reward: 2879.204 | Eval Reward: 2883.764 | Steps: 1000
# [Episode 150/150] Train Reward: 2968.517 | Eval Reward: 2972.904 | Steps: 1000
# Finished Run 4
# Executing Run 5
# [Episode 5/150] Train Reward: -386.020 | Eval Reward: -73.778 | Steps: 1000
# [Episode 10/150] Train Reward: -250.014 | Eval Reward: -82.752 | Steps: 1000
# [Episode 15/150] Train Reward: -466.356 | Eval Reward: -443.212 | Steps: 1000
# [Episode 20/150] Train Reward: -513.469 | Eval Reward: -544.471 | Steps: 1000
# [Episode 25/150] Train Reward: -192.823 | Eval Reward: -371.285 | Steps: 1000
# [Episode 30/150] Train Reward: -224.589 | Eval Reward: -28.743 | Steps: 1000
# [Episode 35/150] Train Reward: -78.491 | Eval Reward: -401.698 | Steps: 1000
# [Episode 40/150] Train Reward: 65.439 | Eval Reward: -214.659 | Steps: 1000
# [Episode 45/150] Train Reward: -238.384 | Eval Reward: -440.051 | Steps: 1000
# [Episode 50/150] Train Reward: 9.637 | Eval Reward: 83.312 | Steps: 1000
# [Episode 55/150] Train Reward: 115.654 | Eval Reward: -25.753 | Steps: 1000
# [Episode 60/150] Train Reward: 197.835 | Eval Reward: 230.536 | Steps: 1000
# [Episode 65/150] Train Reward: 248.937 | Eval Reward: -405.737 | Steps: 1000
# [Episode 70/150] Train Reward: 459.076 | Eval Reward: -484.219 | Steps: 1000
# [Episode 75/150] Train Reward: 340.870 | Eval Reward: 333.422 | Steps: 1000
# [Episode 80/150] Train Reward: 198.470 | Eval Reward: 557.997 | Steps: 1000
# [Episode 85/150] Train Reward: -32.037 | Eval Reward: 321.922 | Steps: 1000
# [Episode 90/150] Train Reward: 796.145 | Eval Reward: 734.241 | Steps: 1000
# [Episode 95/150] Train Reward: 1027.042 | Eval Reward: 349.349 | Steps: 1000
# [Episode 100/150] Train Reward: 620.848 | Eval Reward: 798.984 | Steps: 1000
# [Episode 105/150] Train Reward: 1343.203 | Eval Reward: 1527.788 | Steps: 1000
# [Episode 110/150] Train Reward: 1623.235 | Eval Reward: 760.118 | Steps: 1000
# [Episode 115/150] Train Reward: 1419.302 | Eval Reward: 1829.700 | Steps: 1000
# [Episode 120/150] Train Reward: 266.467 | Eval Reward: 1522.514 | Steps: 1000
# [Episode 125/150] Train Reward: 1920.501 | Eval Reward: 2294.892 | Steps: 1000
# [Episode 130/150] Train Reward: 2312.166 | Eval Reward: 2174.057 | Steps: 1000
# [Episode 135/150] Train Reward: 2146.011 | Eval Reward: 2471.450 | Steps: 1000
# [Episode 140/150] Train Reward: 2638.196 | Eval Reward: 1703.961 | Steps: 1000
# [Episode 145/150] Train Reward: 2880.571 | Eval Reward: 2837.898 | Steps: 1000
# [Episode 150/150] Train Reward: 2836.450 | Eval Reward: 2956.607 | Steps: 1000
# Finished Run 5
# (Mean over last 50 epiosdes) Mean train rewards: 1910.82 | Mean Eval Score: 1934.30
# Finished HalfCheetah-v4

# %%
with open(SAVE_PATH_DDPG, "wb") as f:
    pickle.dump(quantityDictDDPG, f)

# %% [markdown]
# # Twin-Delayed Deep Deterministic Policy Gradient (TD3) [50 marks]
# <a id="td3"></a>

# %% [markdown]
# Implement the Twin-delayed deep deterministic policy gradient (TD3) agent. We have studied about TD3 agent in the Lecture. Use the function definitions (given below).
#
# This class implements the TD3 agent, you are required to implement the various methods of this class
# as outlined below. Note this class is generic and should work with any permissible Gym environment
#
# ```
# class DDPG():
#     def init(env, gamma, tau,
#     bufferSize ,
#     updateFrequencyPolicy ,
#     updateFrequencyValue ,
#     trainPolicyFrequency ,
#     policyOptimizerFn ,
#     valueOptimizerFn ,
#     policyOptimizerLR ,
#     valueOptimizerLR ,
#     MAX TRAIN EPISODES,
#     MAX EVAL EPISODE,
#     optimizerFn )
#
#     def runTD3 (self)
#     def trainAgent (self)
#     def gaussianStrategy (self, net , s , envActionRange , noiseScaleRatio ,
#         explorationMax = True)
#     def greedyStrategy (self, net , s , envActionRange)
#     def trainNetworks (self,experiences , envActionRange)
#     def updateValueNetwork(self, onlineNet, targetNet, tau)
#     def updatePolicyNetwork(self, onlineNet, targetNet, tau)
#     def evaluateAgent (self)
#
#
#
# ```

# %%
class TD3():
    def __init__(self, seed, env, gamma, tau,
    bufferSize ,
    updateFrequencyPolicy ,
    updateFrequencyValue ,
    trainPolicyFrequency ,
    policyOptimizerFn ,
    valueOptimizerFn ,
    policyOptimizerLR ,
    valueOptimizerLR ,
    MAX_TRAIN_EPISODES,
    MAX_EVAL_EPISODE,
    optimizerFn):
        #this TD3 method
        # 1. creates and initializes (with seed) the environment, train/eval episodes, gamma, etc.
        # 2. creates and intializes all the variables required for book-keeping values via the initBookKeeping method
        # 3. creates targetValueNetwork , targetPolicyNetwork
        # 4. creates and initializes (with network params) the optimizer function
        # 5. creates onlineValueNetwork, onlinePolicyNetwork
        # 6. Creates the replayBuffer

        #Your code goes in here
        self.env = env
        self.seed = seed
        self.env.reset(seed=seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        self.env.action_space.seed(seed)
        self.env.observation_space.seed(seed)

        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODE = MAX_EVAL_EPISODE
        self.MAX_VALUE_GRAD_NORM = MAX_GRAD_NORM_VALUE
        self.MAX_POLICY_GRAD_NORM = MAX_GRAD_NORM_POLICY

        self.gamma = gamma
        self.tau = tau
        self.bufferSize = bufferSize
        self.batch_size = batchSize
        self.updateFrequencyValue = updateFrequencyValue
        self.updateFrequencyPolicy = updateFrequencyPolicy
        self.trainPolicyFrequency = trainPolicyFrequency
        self.minSamples = minSamples
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.obs_dim = self.env.observation_space.shape[0]
        self.act_dim = self.env.action_space.shape[0]
        self.max_steps = ep_max_steps
        self.noiseScaleRatio = noiseScaleRatio

        self.targetValueNetwork1 = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.onlineValueNetwork1 = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.targetValueNetwork2 = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.onlineValueNetwork2 = createValueNetwork(self.obs_dim, 1, self.act_dim, hDim=[324, 256, 256]).to(self.device)
        self.targetPolicyNetwork = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=[324, 256, 256], use_tanh=True).to(self.device)
        self.onlinePolicyNetwork = createPolicyNetwork(self.obs_dim, self.act_dim, hDim=[324, 256, 256], use_tanh=True).to(self.device)

        self.updateValueNetwork(self.onlineValueNetwork1, self.targetValueNetwork1, 1.0)
        self.updateValueNetwork(self.onlineValueNetwork2, self.targetValueNetwork2, 1.0)
        self.updatePolicyNetwork(self.onlinePolicyNetwork, self.targetPolicyNetwork, 1.0)

        self.policyOptimizer = policyOptimizerFn(self.onlinePolicyNetwork.parameters(), lr=policyOptimizerLR)
        self.valueOptimizer1 = valueOptimizerFn(self.onlineValueNetwork1.parameters(), lr=valueOptimizerLR)
        self.valueOptimizer2 = valueOptimizerFn(self.onlineValueNetwork2.parameters(), lr=valueOptimizerLR)

        self.actionLowVal = torch.tensor(self.env.action_space.low, dtype=torch.float32).to(self.device)
        self.actionHighVal = torch.tensor(self.env.action_space.high, dtype=torch.float32).to(self.device)
        self.envActionRange = (self.actionLowVal, self.actionHighVal)
        self.action_scale = torch.tensor((self.env.action_space.high - self.env.action_space.low) / 2.0, dtype=torch.float32).to(self.device)

        self.initBookKeeping()
        self.rBuffer = ReplayBuffer(self.bufferSize, self.batch_size, self.seed)

# %%
class TD3(TD3):
    def initBookKeeping(self):
      self.trainRewardsList = []
      self.evalRewardsList = []
      self.trainTimeList = []
      self.wallClockTimeList = []
      self.totalStepsList = []

      self.startTime = time.time()

    def performBookKeeping(self, train=True):
        if train:
            self.trainTimeList.append(time.time() - self.startTime)
        else:
            self.wallClockTimeList.append(time.time() - self.startTime)

# %%
class TD3(TD3):
    def updateValueNetwork(self, onlineNet, targetNet, tau):
        #this function updates the onlineValueNetwork with the targetValuenetwork
        #
        # Your code goes in here
        #
        for targetParam, onlineParam in zip(targetNet.parameters(), onlineNet.parameters()):
            mixedWeights = onlineParam.data * tau + targetParam.data * (1 - tau)
            targetParam.data.copy_(mixedWeights)

# %%
class TD3(TD3):
    def updatePolicyNetwork(self, onlineNet, targetNet, tau):
        #this function updates the onlinePolicuNetwork with the targetPolicynetwork
        #
        # Your code goes in here
        #
        for targetParam, onlineParam in zip(targetNet.parameters(), onlineNet.parameters()):
            mixedWeights = onlineParam.data * tau + targetParam.data * (1 - tau)
            targetParam.data.copy_(mixedWeights)

# %%
class TD3(TD3):
    def gaussianStrategy (self, net , s , envActionRange , noiseScaleRatio ,
        explorationMax = True ):
        #this function sets the scale of exploration then add the noise of this scale to the greedy action
        #and clips it within the range

        #Your code here
        if explorationMax:
            return self.env.action_space.sample()

        with torch.no_grad():
            state = torch.FloatTensor(s).unsqueeze(0).to(self.device)
            actionLowVec, actionHighVec = envActionRange
            action = net(state).cpu().numpy()[0]

            if noiseScaleRatio > 0:
                noise = np.random.normal(0, noiseScaleRatio, size=action.shape)
                action = action + noise

            action = np.clip(action, actionLowVec.cpu().numpy(), actionHighVec.cpu().numpy())

            return action

# %%
class TD3(TD3):
    def greedyStrategy (self, net , s , envActionRange ):
        #this function selects the greedy action
        #and clips it within the range

        #Your code here
        with torch.no_grad():
            state = torch.FloatTensor(s).unsqueeze(0).to(self.device)
            actionLowVec, actionHighVec = envActionRange
            action = net(state).cpu().numpy()[0]

            action = np.clip(action, actionLowVec.cpu().numpy(), actionHighVec.cpu().numpy())

            return action

# %%
class TD3(TD3):
    def runTD3 (self):
        #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
        #the agent and returns the following quantities:
        #1. episode wise mean train rewards
        #2. epsiode wise mean eval rewards
        #2. episode wise trainTime (in seconds): time elapsed during training since the start of the first episode
        #3. episode wise wallClockTime (in seconds): actual time elapsed since the start of training,
        #                               note this will include time for BookKeeping and evaluation
        # Note both trainTime and wallClockTime get accumulated as episodes proceed.
        #
        #Your code goes in here
        #
        trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
        finalEvalReward = self.evaluateAgent()
        return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward

# %%
class TD3(TD3):
    def trainAgent(self):
        #this method collects experiences and trains the agent and does BookKeeping while training.
        #this calls the trainNetwork() method internally, it also evaluates the agent per episode
        #it trains the agent for MAX_TRAIN_EPISODES
        #
        #Your code goes in here
        #
        self.global_steps = 0
        global_max_steps = self.MAX_TRAIN_EPISODES * self.max_steps

        for e in range(self.MAX_TRAIN_EPISODES):
            s, _ = self.env.reset()
            train_r = 0.0
            steps = 0
            done = False

            while steps < self.max_steps and not done:
                # i am decaying noiseScaleRatio linearly wrt the global number of steps taken across episodes
                current_noise = max(0.01, self.noiseScaleRatio * (1 - self.global_steps / global_max_steps))
                action = self.gaussianStrategy(
                    self.onlinePolicyNetwork, s, self.envActionRange, current_noise,
                    self.rBuffer.length() < self.minSamples
                )

                sNext, rs, done, truncated, _ = self.env.step(action)
                done = done or truncated
                train_r += rs

                self.rBuffer.store(s, action, rs, sNext, done)

                if self.rBuffer.length() >= self.minSamples:
                    experiences = self.rBuffer.sample(self.batch_size)
                    self.trainNetwork(experiences, self.envActionRange)

                    if steps % self.updateFrequencyValue == 0:
                        self.updateValueNetwork(self.onlineValueNetwork1, self.targetValueNetwork1, self.tau)
                        self.updateValueNetwork(self.onlineValueNetwork2, self.targetValueNetwork2, self.tau)

                    if steps % self.updateFrequencyPolicy == 0:
                        self.updatePolicyNetwork(self.onlinePolicyNetwork, self.targetPolicyNetwork, self.tau)

                steps += 1
                self.global_steps += 1
                s = sNext
            
            self.performBookKeeping(train=True)
            
            # evaluating after every episode
            eval_r = self.evaluateAgent()
            self.performBookKeeping(train=False)

            self.trainRewardsList.append(train_r)
            self.evalRewardsList.append(eval_r)
            self.totalStepsList.append(steps)

            if (e+1) % 5 == 0:
                print(f"[Episode {e+1}/{self.MAX_TRAIN_EPISODES}] Train Reward: {train_r:.3f} | Eval Reward: {eval_r:.3f} | Steps: {steps}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList, self.wallClockTimeList, self.totalStepsList

# %%
class TD3(TD3):
    def trainNetwork(self, experiences , envActionRange):
        # this method trains the value network epoch number of times and is called by the trainAgent function
        # it essentially uses the experiences to calculate target, using the targets it calculates the error, which
        # is further used for calulating the loss. It then uses the optimizer over the loss
        # to update the params of the network by backpropagating through the network
        # this function does not return anything
        # you can try out other loss functions other than MSE like Huber loss, MAE, etc.
        #
        #Your code goes in here
        #

        ss, actions, rs, sNexts, dones = self.rBuffer.splitExperiences(experiences)

        ss = ss.to(self.device)
        actions = actions.to(self.device)
        rs = rs.to(self.device)
        sNexts = sNexts.to(self.device)
        dones = dones.to(self.device)

        policy_noise = 0.2 * self.action_scale
        noise_clip = 0.5 * self.action_scale
        as_noise = torch.randn_like(actions) * policy_noise
        as_noise = torch.clamp(as_noise, -noise_clip, noise_clip)

        argmax_a_qs_v = self.targetPolicyNetwork(sNexts)
        noisy_argmax_a_qs_v = argmax_a_qs_v + as_noise
        noisy_argmax_a_qs_v = torch.max(torch.min(noisy_argmax_a_qs_v, self.actionHighVal), self.actionLowVal)

        max_1_a_qs_v = self.targetValueNetwork1(sNexts, noisy_argmax_a_qs_v)
        max_2_a_qs_v = self.targetValueNetwork2(sNexts, noisy_argmax_a_qs_v)
        max_a_qs_v = torch.min(max_1_a_qs_v, max_2_a_qs_v)
        target_qs = rs + self.gamma * (1 - dones) * max_a_qs_v

        qs_1 = self.onlineValueNetwork1(ss, actions)
        qs_2 = self.onlineValueNetwork2(ss, actions)
        tdErrors_1 = target_qs.detach() - qs_1
        tdErrors_2 = target_qs.detach() - qs_2

        valueLoss1 = torch.mean(0.5 * (tdErrors_1 ** 2))
        valueLoss2 = torch.mean(0.5 * (tdErrors_2 ** 2))

        self.valueOptimizer1.zero_grad()
        valueLoss1.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork1.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizer1.step()

        self.valueOptimizer2.zero_grad()
        valueLoss2.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork2.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizer2.step()

        if self.global_steps % self.trainPolicyFrequency == 0:
            argmax_a_qs_p = self.onlinePolicyNetwork(ss)
            max_a_qs_p1 = self.onlineValueNetwork1(ss, argmax_a_qs_p)
            max_a_qs_p2 = self.onlineValueNetwork2(ss, argmax_a_qs_p)
            min_max_a_qs_p = torch.min(max_a_qs_p1, max_a_qs_p2)
            policyLoss = -min_max_a_qs_p.mean()
            self.policyOptimizer.zero_grad()
            policyLoss.backward()
            torch.nn.utils.clip_grad_norm_(self.onlinePolicyNetwork.parameters(), self.MAX_POLICY_GRAD_NORM)
            self.policyOptimizer.step()

# %%
class TD3(TD3):
    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #typcially MAX_EVAL_EPISODES = 1
        #
        #Your code goes in here
        #
        final_eval_r = 0.0
        for e in range(self.MAX_EVAL_EPISODE):
            s, _ = self.env.reset()
            done = False
            for c in count():
                envActionRange = (self.actionLowVal, self.actionHighVal)
                a = self.greedyStrategy(self.onlinePolicyNetwork, s, envActionRange)
                s_next, r, done, truncated, _ = self.env.step(a)
                final_eval_r += r
                s = s_next
                if done or truncated:
                    break
        final_eval_r /= self.MAX_EVAL_EPISODE
        return final_eval_r

# %%
# evaluating the TD3 agent on multiple continuous-control

# Environments used in this experiment
td3_env_name = "HalfCheetah-v4"

quantityDictTD3 = {}

# Number of independent training runs per environment
num_runs = 5

all_train_rewards = []
all_eval_rewards = []
all_train_times = []
all_wall_clock_times = []
all_total_steps = []

# For each environment:
print(f"\n===== Environment: {td3_env_name} =====")
for run in range(num_runs):
    print(f"Executing Run {run+1}   ")

    # Create environment
    env = gym.make(td3_env_name)

    agent = TD3(
        base_seed + run, env, gamma, tau, bufferSize, updateFrequencyPolicy,
        updateFrequencyValue, trainPolicyFrequency,
        policyOptimizerFn, valueOptimizerFn,
        policyOptimizerLR, valueOptimizerLR,
        MAX_TRAIN_EPISODES, MAX_EVAL_EPISODES,
        optimizerFn
    )

    # Run training
    train_rewards, train_times, eval_rewards, wall_clock_times, total_steps, final_eval_reward = agent.runTD3()

    all_train_rewards.append(train_rewards)
    all_eval_rewards.append(eval_rewards)
    all_train_times.append(train_times)
    all_wall_clock_times.append(wall_clock_times)
    all_total_steps.append(total_steps)

    print(f"Finished Run {run+1}  ")


print(f'Mean train rewards: {np.mean(all_train_rewards):.2f} | Train std: {np.std(all_train_rewards):.2f}')
print(f'Mean eval rewards: {np.mean(all_eval_rewards):.2f} | Eval std: {np.std(all_eval_rewards):.2f}')
print(f"Finished {td3_env_name}")

quantityDictTD3[td3_env_name] = {
    "Mean Train Rewards": {
        "TD3": all_train_rewards
    },
    "Mean Eval Rewards": {
        "TD3": all_eval_rewards
    },
    "Train Time (in sec)": {
        "TD3": all_train_times
    },
    "Wall Clock Time (in sec)": {
        "TD3": all_wall_clock_times
    },
    "Total Steps": {
        "TD3": all_total_steps
    }
}

train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"\n(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
# Out:
# ===== Environment: HalfCheetah-v4 =====
# Executing Run 1
# [Episode 5/150] Train Reward: -227.522 | Eval Reward: -372.793 | Steps: 1000
# [Episode 10/150] Train Reward: -383.397 | Eval Reward: -341.703 | Steps: 1000

# %%
with open(SAVE_PATH_TD3, "wb") as f:
    pickle.dump(quantityDictTD3, f)

# %% [markdown]
# # Soft Actor-Critic (SAC) [ 50 marks ]
#
# SAC is an off-policy maximum entropy deep RL algorithm for continuous action spaces. It maintains two online Q-networks and two target Q-networks to mitigate overestimation bias, and uses a squashed Gaussian policy with automatic entropy tuning.
#
# ### Key Ideas
#
# **1. Stochastic Policy (Squashed Gaussian)**
# The network learns $\mu$ and $\sigma$; samples $u \sim \mathcal{N}(\mu, \sigma)$, applies $a = \tanh(u)$, then rescales to the environment action range.
#
# **2. Log-probability correction for tanh squashing:**
#
# $$\log \pi(a \mid s) = \log p(u \mid s) - \sum_{i=0}^{D} \log(1 - \tanh^2(u_i))$$
#
# **3. Policy Loss (maximize Q, maximize entropy):**
#
# $$J_\pi(\phi) = -\, \mathbb{E}_{s \sim \mathcal{U}(D),\, \hat{a} \sim \pi} \left[ \min_k Q(s, \hat{a};\, \theta^k) - \alpha \log \pi(\hat{a} \mid s;\, \phi) \right]$$
#
# **4. Automatic Entropy Tuning (learn $\alpha$):**
#
# $$J(\alpha) = -\, \mathbb{E}_{s \sim \mathcal{U}(D),\, \hat{a} \sim \pi} \left[ \alpha \left( \mathcal{H} + \log \pi(\hat{a} \mid s;\, \phi) \right) \right]$$
#
# where $\mathcal{H} = -|\mathcal{A}| = -\prod \text{shape}(a_\text{env})$
#
# **5. Soft Bellman Backup (critic target):**
#
# $$\text{target\_q} = r + \gamma \cdot \left( \min_k Q_{\text{target},k}(s', a') - \alpha \log \pi(a' \mid s') \right) \cdot (1 - \text{done})$$
#
# **6. Soft (Polyak) Target Update:**
#
# $$\theta_{\text{target}} \leftarrow (1 - \tau)\, \theta_{\text{target}} + \tau\, \theta_{\text{online}}$$
#
#
#
# ### Task
#
# Implement the SAC agent using the class structure below.

# %%
class ValueNetwork(nn.Module):

    def __init__(self, stateDim, actionDim, hiddenDims):
        """
        Args:
            stateDim (int): dimension of state space
            actionDim (int): dimension of action space
            hiddenDims (list): hidden layer sizes

        Output:
            Initializes Q-network Q(s,a)
        """
        super(ValueNetwork, self).__init__()
        prevdim = stateDim + actionDim
        self.layers = nn.ModuleList()
        for dim in hiddenDims:
            self.layers.append(nn.Linear(prevdim, dim))
            prevdim = dim
        self.layers.append(nn.Linear(prevdim, 1))
        self.activation = nn.ReLU()

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                nn.init.constant_(m.bias, 0)

    def forward(self, state, action):
        """
        Args:
            state (tensor): shape (batch_size, stateDim)
            action (tensor): shape (batch_size, actionDim)

        Returns:
            q_value (tensor): predicted Q(s,a), shape (batch_size,1)
        """
        x = torch.cat([state, action], dim=-1)
        for layer in self.layers[:-1]:
            x = self.activation(layer(x))
        x = self.layers[-1](x)
        return x

# %%
class PolicyNetwork(nn.Module):

    def __init__(self, stateDim, actionRange, hiddenDims):
        """
        Args:
            stateDim (int): state dimension
            actionRange (tuple): (action_low, action_high)
            hiddenDims (list): hidden layer sizes

        Output:
            Initializes stochastic policy network
        """
        super(PolicyNetwork, self).__init__()

        self.logSTD_min = logSTD_min
        self.logSTD_max = logSTD_max
        self.epsilon = epsilon

        self.actionRange = actionRange
        self.actDim = len(self.actionRange[0])
        self.register_buffer('actionLowVal', torch.as_tensor(actionRange[0], dtype=torch.float32))
        self.register_buffer('actionHighVal', torch.as_tensor(actionRange[1], dtype=torch.float32))

        hLayers = []
        prevDim = stateDim
        for nextDim in hiddenDims:
            hLayers.append(nn.Linear(prevDim, nextDim))
            hLayers.append(nn.ReLU())
            prevDim = nextDim
        self.features = nn.Sequential(*hLayers)
        self.mean = nn.Linear(prevDim, self.actDim)
        self.logStd = nn.Linear(prevDim, self.actDim)

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight, gain=np.sqrt(2))
                nn.init.constant_(m.bias, 0)

    def forward(self, state):
        """
        Args:
            state (tensor): input states

        Returns:
            action_env (tensor): sampled action in env range
            action_greedy (tensor): deterministic action
            log_prob (tensor): log probability of action
        """
        l = self.features(state)
        mean, logSTD = self.mean(l), self.logStd(l)
        logSTD = torch.clamp(logSTD, self.logSTD_min, self.logSTD_max)
        std = torch.exp(logSTD)

        pi_s = torch.distributions.Normal(mean, std)
        u = pi_s.rsample()
        a = torch.tanh(u)
        a_env = self.rescale(a)
        a_greedy = self.rescale(torch.tanh(mean))
        log_prob = pi_s.log_prob(u) - torch.log(1 - a**2 + self.epsilon)
        log_prob = log_prob.sum(dim=1, keepdim=True)
        return a_env, a_greedy, log_prob

    def rescale(self, action):
        """
        Args:
            action (tensor): tanh output in [-1,1]

        Returns:
            scaled_action (tensor): action in environment range
        """
        action_scale = (self.actionHighVal - self.actionLowVal) / (squasherMax - squasherMin)
        action_bias = (self.actionHighVal + self.actionLowVal) / (squasherMax - squasherMin)
        action_r = action * action_scale + action_bias
        return action_r

# %%
class ReplayBuffer:

    def __init__(self, bufferSize):
        """
        Args:
            bufferSize (int): max number of stored transitions
        """
        self.bufferSize = bufferSize
        self.buffer = deque(maxlen=bufferSize)

    def store(self, transition):
        """
        Args:
            transition (tuple): (state, action, reward, next_state, done)
        """
        self.buffer.append(transition)

    def sample(self, batchSize):
        """
        Args:
            batchSize (int)

        Returns:
            batch (list): sampled transitions
        """
        batch = random.sample(self.buffer, batchSize)
        return batch

    def splitExperiences(self, experiences):
        states, actions, rewards, sNexts, dones = zip(*experiences)

        states = torch.FloatTensor(np.array(states))
        actions = torch.FloatTensor(np.array(actions))
        rewards = torch.FloatTensor(rewards).unsqueeze(1)
        sNexts = torch.FloatTensor(np.array(sNexts))
        dones = torch.FloatTensor(dones).unsqueeze(1)

        # finally returning all the separated numpy arrays
        return states, actions, rewards, sNexts, dones

    def length(self):
        return len(self.buffer)

# %%
# i have added an extra argument in the function defination for reseting the env with the provided seed for reproducibility

class SAC:

    def __init__(self, env, gamma, tau, bufferSize, batchSize, entropyLR,
                 updateFrequency, policyOptimizerFn, valueOptimizerFn_1,
                 valueOptimizerFn_2, policyOptimizerLR, valueOptimizerLR,
                 alphaOptimizerFn, MAX_TRAIN_EPISODES,
                 MAX_EVAL_EPISODE, hDims, minSamples, seed=base_seed):
        """
        Args:
            env: gym environment
            gamma (float): discount factor
            tau (float): target update rate
            bufferSize (int): replay buffer size
            batchSize (int): training batch size
        """
        self.env = env
        self.env.reset(seed=seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        self.env.action_space.seed(seed)
        self.env.observation_space.seed(seed)
        random.seed(seed)

        self.gamma = gamma
        self.tau = tau
        self.bufferSize = bufferSize
        self.batchSize = batchSize
        self.minSamples = minSamples
        self.updateFrequency = updateFrequency
        self.MAX_TRAIN_EPISODES = MAX_TRAIN_EPISODES
        self.MAX_EVAL_EPISODE = MAX_EVAL_EPISODE
        self.MAX_VALUE_GRAD_NORM = MAX_GRAD_NORM_VALUE
        self.MAX_POLICY_GRAD_NORM = MAX_GRAD_NORM_POLICY
        self.entropyLR = entropyLR
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.max_steps = ep_max_steps

        self.stateDim = self.env.observation_space.shape[0]
        self.actionDim = self.env.action_space.shape[0]

        self.actionLowVal = torch.tensor(self.env.action_space.low, dtype=torch.float32).to(self.device)
        self.actionHighVal = torch.tensor(self.env.action_space.high, dtype=torch.float32).to(self.device)
        self.actionRange = (self.actionLowVal,  self.actionHighVal)

        self.targetValueNetwork1 = ValueNetwork(self.stateDim, self.actionDim, hiddenDims=hDims).to(self.device)
        self.targetValueNetwork2 = ValueNetwork(self.stateDim, self.actionDim, hiddenDims=hDims).to(self.device)
        self.onlineValueNetwork1 = ValueNetwork(self.stateDim, self.actionDim, hiddenDims=hDims).to(self.device)
        self.onlineValueNetwork2 = ValueNetwork(self.stateDim, self.actionDim, hiddenDims=hDims).to(self.device)
        self.policyNetwork = PolicyNetwork(self.stateDim, self.actionRange, hiddenDims=hDims).to(self.device)

        self.logAlpha = torch.tensor(0.0, requires_grad=True, device=self.device)
        self.alphaOptimizer = alphaOptimizerFn([self.logAlpha], lr=entropyLR)

        self.valueOptimizerFn_1 = valueOptimizerFn_1(self.onlineValueNetwork1.parameters(), lr=valueOptimizerLR)
        self.valueOptimizerFn_2 = valueOptimizerFn_2(self.onlineValueNetwork2.parameters(), lr=valueOptimizerLR)
        self.policyOptimizerFn = policyOptimizerFn(self.policyNetwork.parameters(), lr=policyOptimizerLR)

        self.updateTargetNetworks(tau=1.0)
        self.initBookKeeping()
        self.startTime = time.time()
        self.rBuffer = ReplayBuffer(bufferSize)

    def initBookKeeping(self):
      self.trainRewardsList = []
      self.evalRewardsList = []
      self.trainTimeList = []
      self.wallClockTimeList = []
      self.totalStepsList = []

      self.startTime = time.time()

    def performBookKeeping(self, train=True):
        if train:
            self.trainTimeList.append(time.time() - self.startTime)
        else:
            self.wallClockTimeList.append(time.time() - self.startTime)


    def selectAction(self, state):
        """
        Args:
            state (array): current state

        Returns:
            action (array): action sampled from policy
        """
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(self.device)
        a_env, _, _ = self.policyNetwork(state)
        return a_env.detach().cpu().numpy().flatten()


    def _turn_online_grad(self, turn = False):
        for p in self.onlineValueNetwork1.parameters():
            p.requires_grad = turn
        for p in self.onlineValueNetwork2.parameters():
            p.requires_grad = turn


    def trainNetworks(self, batch):
        """
        Args:
            batch: sampled transitions

        Updates:
            critics, policy, entropy coefficient
        """
        ss, actions, rs, sNexts, dones = self.rBuffer.splitExperiences(batch)

        ss = ss.to(self.device)
        actions = actions.to(self.device)
        rs = rs.to(self.device)
        sNexts = sNexts.to(self.device)
        dones = dones.to(self.device)

        with torch.no_grad():
            as_p, _, logp_p = self.policyNetwork(sNexts)
            q_p_1 = self.targetValueNetwork1(sNexts, as_p)
            q_p_2 = self.targetValueNetwork2(sNexts, as_p)
            q_p = torch.min(q_p_1, q_p_2)
            alpha = self.logAlpha.exp()
            target_q = rs + self.gamma * (1 - dones) * (q_p - alpha * logp_p)

        q_1 = self.onlineValueNetwork1(ss, actions)
        q_2 = self.onlineValueNetwork2(ss, actions)
        q_1_loss = (0.5 * (q_1 - target_q)**2).mean()
        q_2_loss = (0.5 * (q_2 - target_q)**2).mean()

        self.valueOptimizerFn_1.zero_grad()
        q_1_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork1.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizerFn_1.step()

        self.valueOptimizerFn_2.zero_grad()
        q_2_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.onlineValueNetwork2.parameters(), self.MAX_VALUE_GRAD_NORM)
        self.valueOptimizerFn_2.step()

        self._turn_online_grad(False)

        as_current, _, logp = self.policyNetwork(ss)
        q_current_1 = self.onlineValueNetwork1(ss, as_current)
        q_current_2 = self.onlineValueNetwork2(ss, as_current)
        q_current = torch.min(q_current_1, q_current_2)

        alpha = self.logAlpha.exp()
        policyLoss = (alpha * logp - q_current).mean()

        self.policyOptimizerFn.zero_grad()
        policyLoss.backward()
        torch.nn.utils.clip_grad_norm_(self.policyNetwork.parameters(), self.MAX_POLICY_GRAD_NORM)
        self.policyOptimizerFn.step()

        self._turn_online_grad(True)

        targetEntropy = -self.actionDim
        alpha_target = (logp + targetEntropy).detach()
        alphaLoss = -(self.logAlpha * alpha_target).mean()
        self.alphaOptimizer.zero_grad()
        alphaLoss.backward()
        self.alphaOptimizer.step()


    def updateTargetNetworks(self, tau=None):
        """
        Performs Polyak update of target networks
        """
        tau = self.tau if tau is None else tau
        for target_param, online_param in zip(self.targetValueNetwork1.parameters(), self.onlineValueNetwork1.parameters()):
            mixedWeights = (1 - tau) * target_param + tau * online_param
            target_param.data.copy_(mixedWeights)

        for target_param, online_param in zip(self.targetValueNetwork2.parameters(), self.onlineValueNetwork2.parameters()):
            mixedWeights = (1 - tau) * target_param + tau * online_param
            target_param.data.copy_(mixedWeights)


    def trainAgent(self):
        """
        Runs training episodes

        Returns:
            trainRewards (list): reward per episode
        """
        for e in range(self.MAX_TRAIN_EPISODES):
            s, _ = self.env.reset()
            train_r = 0.0
            steps = 0
            done = False

            while steps < self.max_steps and not done:
                if self.rBuffer.length() < self.minSamples:
                    action = self.env.action_space.sample()
                else:
                    action = self.selectAction(s)

                sNext, rs, done, truncated, _ = self.env.step(action)
                done = done or truncated
                train_r += rs

                self.rBuffer.store((s, action, rs, sNext, done))

                if self.rBuffer.length() >= self.minSamples:
                    experiences = self.rBuffer.sample(self.batchSize)
                    self.trainNetworks(experiences)

                    if steps % self.updateFrequency == 0:
                        self.updateTargetNetworks()

                steps += 1
                s = sNext

            self.performBookKeeping(train=True)

            # evaluating after every episode
            eval_r = self.evaluateAgent()
            self.performBookKeeping(train=False)

            self.trainRewardsList.append(train_r)
            self.evalRewardsList.append(eval_r)
            self.totalStepsList.append(steps)

            if (e+1) % 5 == 0:
                print(f"[Episode {e+1}/{self.MAX_TRAIN_EPISODES}] Train Reward: {train_r:.3f} | Eval Reward: {eval_r:.3f} | Steps: {steps}")

        return self.trainRewardsList, self.evalRewardsList, self.trainTimeList


    def evaluateAgent(self):
        """
        Returns:
            mean_reward (float): evaluation performance
        """
        final_eval_r = 0.0
        for e in range(self.MAX_EVAL_EPISODE):
            s, _ = self.env.reset()
            done = False
            for c in count():
                a = self.selectAction(s)
                s_next, r, done, truncated, _ = self.env.step(a)
                final_eval_r += r
                s = s_next
                if done or truncated:
                    break
        final_eval_r /= self.MAX_EVAL_EPISODE
        return final_eval_r


    def runSAC(self):
        """
        Runs full training pipeline

        Returns:
            train_rewards, eval_score, training_time
        """
        train_r, eval_r, train_t = self.trainAgent()
        return train_r, eval_r, train_t

# %%
# We evaluate the SAC agent on multiple continuous-control

# Environments used in this experiment
sac_env_names = "HalfCheetah-v4"

# Number of independent training runs per environment
num_runs = 5

quantityDictSAC = {}

all_train_rewards = []
all_eval_rewards = []
all_train_times = []

# For each environment:
'''  1. Train the SAC agent for multiple runs
  2. Collect training rewards
  3. Compute mean and standard deviation'''

print(f"\n===== Environment: {sac_env_names} =====")
for run in range(num_runs):
    print(f"Execeuting Run {run+1}   ")

    # Create environment
    env = gym.make(sac_env_names)

    # Initialize SAC agent
    agent = SAC(
        env=env,
        gamma=gamma,
        tau=tau,
        bufferSize=bufferSize,
        entropyLR=entropyLR,
        updateFrequency=updateFrequency,
        policyOptimizerFn=torch.optim.Adam,
        valueOptimizerFn_1=torch.optim.Adam,
        valueOptimizerFn_2=torch.optim.Adam,
        policyOptimizerLR=policyOptimizerLR,
        valueOptimizerLR=valueOptimizerLR,
        alphaOptimizerFn=torch.optim.Adam,
        MAX_TRAIN_EPISODES=MAX_TRAIN_EPISODES,
        MAX_EVAL_EPISODE=MAX_EVAL_EPISODES,
        hDims=[324, 256, 256],
        batchSize=batchSize,
        minSamples=minSamples,
        seed=base_seed+run
    )

    # Run training
    train_r, eval_r, train_t = agent.runSAC()

    all_train_rewards.append(train_r)
    all_eval_rewards.append(eval_r)
    all_train_times.append(train_t)

    print(f"Finished run {run+1}   ")

quantityDictSAC[sac_env_names] = {
    "Mean Train Rewards": {"SAC" : all_train_rewards},
    "Train Times (in sec)": {"SAC" : all_train_times},
    "Mean Eval Rewards": {"SAC": all_eval_rewards}
}

train_means = [np.mean(run[-50:]) for run in all_train_rewards]
eval_means = [np.mean(run[-50:]) for run in all_eval_rewards]

print(f"\n(Mean over last 50 epiosdes) Mean train rewards: {np.mean(train_means):.2f} | Mean Eval Score: {np.mean(eval_means):.2f}")
print(f"Finished {sac_env_names}")
# Out:
# ===== Environment: HalfCheetah-v4 =====
# Execeuting Run 1
# c:\Users\hgoel\anaconda3\Lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# [Episode 5/150] Train Reward: -227.522 | Eval Reward: -533.688 | Steps: 1000
# [Episode 10/150] Train Reward: -383.397 | Eval Reward: -533.331 | Steps: 1000
# [Episode 15/150] Train Reward: -240.873 | Eval Reward: -247.765 | Steps: 1000
# [Episode 20/150] Train Reward: -271.217 | Eval Reward: -254.856 | Steps: 1000
# [Episode 25/150] Train Reward: -110.169 | Eval Reward: 14.533 | Steps: 1000
# [Episode 30/150] Train Reward: 135.781 | Eval Reward: 222.127 | Steps: 1000
# [Episode 35/150] Train Reward: 548.628 | Eval Reward: 337.058 | Steps: 1000
# [Episode 40/150] Train Reward: -129.477 | Eval Reward: 940.242 | Steps: 1000
# [Episode 45/150] Train Reward: 1387.580 | Eval Reward: 1311.369 | Steps: 1000
# [Episode 50/150] Train Reward: 1697.025 | Eval Reward: 1604.112 | Steps: 1000
# [Episode 55/150] Train Reward: 1481.499 | Eval Reward: 2329.120 | Steps: 1000
# [Episode 60/150] Train Reward: 2730.020 | Eval Reward: 2898.303 | Steps: 1000
# [Episode 65/150] Train Reward: 3430.666 | Eval Reward: 3377.947 | Steps: 1000
# [Episode 70/150] Train Reward: 3367.157 | Eval Reward: 3384.355 | Steps: 1000
# [Episode 75/150] Train Reward: 3543.521 | Eval Reward: 3488.731 | Steps: 1000
# [Episode 80/150] Train Reward: 3863.553 | Eval Reward: 4393.464 | Steps: 1000
# [Episode 85/150] Train Reward: 3988.115 | Eval Reward: 3855.715 | Steps: 1000
# [Episode 90/150] Train Reward: 4399.181 | Eval Reward: 3713.277 | Steps: 1000
# [Episode 95/150] Train Reward: 4521.583 | Eval Reward: 4271.869 | Steps: 1000
# [Episode 100/150] Train Reward: 4774.951 | Eval Reward: 5117.167 | Steps: 1000
# [Episode 105/150] Train Reward: 4793.108 | Eval Reward: 1180.038 | Steps: 1000
# [Episode 110/150] Train Reward: 4978.759 | Eval Reward: 5430.758 | Steps: 1000
# [Episode 115/150] Train Reward: 189.004 | Eval Reward: 5399.830 | Steps: 1000
# [Episode 120/150] Train Reward: 5379.579 | Eval Reward: 5063.840 | Steps: 1000
# [Episode 125/150] Train Reward: 5085.799 | Eval Reward: 4567.721 | Steps: 1000
# [Episode 130/150] Train Reward: 5744.091 | Eval Reward: 4393.686 | Steps: 1000
# [Episode 135/150] Train Reward: 5642.383 | Eval Reward: 5724.179 | Steps: 1000
# [Episode 140/150] Train Reward: 5879.163 | Eval Reward: 5922.887 | Steps: 1000
# [Episode 145/150] Train Reward: 1912.549 | Eval Reward: 6093.916 | Steps: 1000
# [Episode 150/150] Train Reward: 6073.281 | Eval Reward: 6028.940 | Steps: 1000
# Finished run 1
# Execeuting Run 2
# [Episode 5/150] Train Reward: -358.640 | Eval Reward: -334.279 | Steps: 1000
# [Episode 10/150] Train Reward: -402.689 | Eval Reward: -284.608 | Steps: 1000
# [Episode 15/150] Train Reward: -258.905 | Eval Reward: -239.058 | Steps: 1000
# [Episode 20/150] Train Reward: -305.214 | Eval Reward: -110.779 | Steps: 1000
# [Episode 25/150] Train Reward: 245.120 | Eval Reward: 326.902 | Steps: 1000
# [Episode 30/150] Train Reward: 1006.205 | Eval Reward: 657.989 | Steps: 1000
# [Episode 35/150] Train Reward: 1352.226 | Eval Reward: 1734.471 | Steps: 1000
# [Episode 40/150] Train Reward: 2140.939 | Eval Reward: 2460.875 | Steps: 1000
# [Episode 45/150] Train Reward: 2289.121 | Eval Reward: 408.343 | Steps: 1000
# [Episode 50/150] Train Reward: 2755.850 | Eval Reward: 2537.000 | Steps: 1000
# [Episode 55/150] Train Reward: 3026.990 | Eval Reward: 3155.642 | Steps: 1000
# [Episode 60/150] Train Reward: 391.476 | Eval Reward: 3318.351 | Steps: 1000
# [Episode 65/150] Train Reward: 3335.122 | Eval Reward: 3250.473 | Steps: 1000
# [Episode 70/150] Train Reward: 3697.566 | Eval Reward: 3322.066 | Steps: 1000
# [Episode 75/150] Train Reward: 3669.084 | Eval Reward: 3477.083 | Steps: 1000
# [Episode 80/150] Train Reward: 3384.649 | Eval Reward: 3977.089 | Steps: 1000
# [Episode 85/150] Train Reward: 3987.091 | Eval Reward: 4247.910 | Steps: 1000
# [Episode 90/150] Train Reward: 4196.975 | Eval Reward: 1617.289 | Steps: 1000
# [Episode 95/150] Train Reward: 4413.457 | Eval Reward: 3565.164 | Steps: 1000
# [Episode 100/150] Train Reward: 3898.310 | Eval Reward: 4615.388 | Steps: 1000
# [Episode 105/150] Train Reward: 4335.454 | Eval Reward: 4659.309 | Steps: 1000
# [Episode 110/150] Train Reward: 4680.030 | Eval Reward: 4833.339 | Steps: 1000
# [Episode 115/150] Train Reward: 4706.341 | Eval Reward: 4813.220 | Steps: 1000
# [Episode 120/150] Train Reward: 5030.638 | Eval Reward: 4982.696 | Steps: 1000
# [Episode 125/150] Train Reward: 5048.438 | Eval Reward: 4617.945 | Steps: 1000
# [Episode 130/150] Train Reward: 5234.105 | Eval Reward: 2376.516 | Steps: 1000
# [Episode 135/150] Train Reward: 5391.793 | Eval Reward: 5416.877 | Steps: 1000
# [Episode 140/150] Train Reward: 5673.316 | Eval Reward: 5782.981 | Steps: 1000
# [Episode 145/150] Train Reward: 5835.945 | Eval Reward: 5925.166 | Steps: 1000
# [Episode 150/150] Train Reward: 5905.676 | Eval Reward: 1544.818 | Steps: 1000
# Finished run 2
# Execeuting Run 3
# [Episode 5/150] Train Reward: -202.823 | Eval Reward: -320.212 | Steps: 1000
# [Episode 10/150] Train Reward: -401.966 | Eval Reward: -425.350 | Steps: 1000
# [Episode 15/150] Train Reward: -254.139 | Eval Reward: -137.132 | Steps: 1000
# [Episode 20/150] Train Reward: -131.535 | Eval Reward: -232.583 | Steps: 1000
# [Episode 25/150] Train Reward: -229.644 | Eval Reward: -274.682 | Steps: 1000
# [Episode 30/150] Train Reward: -41.370 | Eval Reward: -65.173 | Steps: 1000
# [Episode 35/150] Train Reward: 565.036 | Eval Reward: 441.103 | Steps: 1000
# [Episode 40/150] Train Reward: 1023.805 | Eval Reward: 1071.375 | Steps: 1000
# [Episode 45/150] Train Reward: 1394.596 | Eval Reward: 1466.588 | Steps: 1000
# [Episode 50/150] Train Reward: 1617.534 | Eval Reward: 1655.751 | Steps: 1000
# [Episode 55/150] Train Reward: 174.845 | Eval Reward: 1970.585 | Steps: 1000
# [Episode 60/150] Train Reward: 2060.234 | Eval Reward: 2180.406 | Steps: 1000
# [Episode 65/150] Train Reward: 2189.119 | Eval Reward: 2504.786 | Steps: 1000
# [Episode 70/150] Train Reward: 2324.605 | Eval Reward: 2332.079 | Steps: 1000
# [Episode 75/150] Train Reward: 738.554 | Eval Reward: 2537.777 | Steps: 1000
# [Episode 80/150] Train Reward: 2687.090 | Eval Reward: 2555.184 | Steps: 1000
# [Episode 85/150] Train Reward: 2901.105 | Eval Reward: 2968.357 | Steps: 1000
# [Episode 90/150] Train Reward: 3035.787 | Eval Reward: 2822.757 | Steps: 1000
# [Episode 95/150] Train Reward: 3122.176 | Eval Reward: 3046.982 | Steps: 1000
# [Episode 100/150] Train Reward: 3364.950 | Eval Reward: 3204.975 | Steps: 1000
# [Episode 105/150] Train Reward: 3483.279 | Eval Reward: 3375.994 | Steps: 1000
# [Episode 110/150] Train Reward: 3501.865 | Eval Reward: 3596.825 | Steps: 1000
# [Episode 115/150] Train Reward: 3695.533 | Eval Reward: 3940.539 | Steps: 1000
# [Episode 120/150] Train Reward: 3930.104 | Eval Reward: 3825.365 | Steps: 1000
# [Episode 125/150] Train Reward: 3592.100 | Eval Reward: 3745.948 | Steps: 1000
# [Episode 130/150] Train Reward: 4088.298 | Eval Reward: 1298.229 | Steps: 1000
# [Episode 135/150] Train Reward: 4349.975 | Eval Reward: 3983.996 | Steps: 1000
# [Episode 140/150] Train Reward: 4116.777 | Eval Reward: 4410.341 | Steps: 1000
# [Episode 145/150] Train Reward: 4304.114 | Eval Reward: 4502.384 | Steps: 1000
# [Episode 150/150] Train Reward: 4197.869 | Eval Reward: 4355.229 | Steps: 1000
# Finished run 3
# Execeuting Run 4
# [Episode 5/150] Train Reward: -367.730 | Eval Reward: -126.437 | Steps: 1000
# [Episode 10/150] Train Reward: -290.757 | Eval Reward: -266.262 | Steps: 1000
# [Episode 15/150] Train Reward: -270.003 | Eval Reward: -237.732 | Steps: 1000
# [Episode 20/150] Train Reward: -220.864 | Eval Reward: -202.527 | Steps: 1000
# [Episode 25/150] Train Reward: -141.106 | Eval Reward: -232.588 | Steps: 1000
# [Episode 30/150] Train Reward: 34.830 | Eval Reward: 424.454 | Steps: 1000
# [Episode 35/150] Train Reward: 685.038 | Eval Reward: 789.955 | Steps: 1000
# [Episode 40/150] Train Reward: 742.553 | Eval Reward: 1242.018 | Steps: 1000
# [Episode 45/150] Train Reward: 1803.479 | Eval Reward: 1990.885 | Steps: 1000
# [Episode 50/150] Train Reward: 1251.822 | Eval Reward: 1986.196 | Steps: 1000
# [Episode 55/150] Train Reward: 2593.007 | Eval Reward: 2035.983 | Steps: 1000
# [Episode 60/150] Train Reward: 2206.568 | Eval Reward: 2807.910 | Steps: 1000
# [Episode 65/150] Train Reward: 3082.513 | Eval Reward: 3270.171 | Steps: 1000
# [Episode 70/150] Train Reward: 3235.715 | Eval Reward: 3285.504 | Steps: 1000
# [Episode 75/150] Train Reward: 2391.480 | Eval Reward: 449.388 | Steps: 1000
# [Episode 80/150] Train Reward: 574.239 | Eval Reward: 3311.469 | Steps: 1000
# [Episode 85/150] Train Reward: 3468.926 | Eval Reward: 0.355 | Steps: 1000
# [Episode 90/150] Train Reward: 3898.569 | Eval Reward: 3861.001 | Steps: 1000
# [Episode 95/150] Train Reward: 3790.124 | Eval Reward: 4012.700 | Steps: 1000
# [Episode 100/150] Train Reward: 3975.445 | Eval Reward: 4020.247 | Steps: 1000
# [Episode 105/150] Train Reward: 4201.246 | Eval Reward: 4237.496 | Steps: 1000
# [Episode 110/150] Train Reward: 4116.416 | Eval Reward: 4539.064 | Steps: 1000
# [Episode 115/150] Train Reward: 4672.921 | Eval Reward: 4656.959 | Steps: 1000
# [Episode 120/150] Train Reward: 4589.303 | Eval Reward: 4630.428 | Steps: 1000
# [Episode 125/150] Train Reward: 4579.593 | Eval Reward: 4719.619 | Steps: 1000
# [Episode 130/150] Train Reward: 4574.361 | Eval Reward: 4465.858 | Steps: 1000
# [Episode 135/150] Train Reward: 4760.304 | Eval Reward: 5066.303 | Steps: 1000
# [Episode 140/150] Train Reward: 4869.270 | Eval Reward: 5053.997 | Steps: 1000
# [Episode 145/150] Train Reward: 4960.660 | Eval Reward: 4909.564 | Steps: 1000
# [Episode 150/150] Train Reward: 4959.212 | Eval Reward: 5300.177 | Steps: 1000
# Finished run 4
# Execeuting Run 5
# [Episode 5/150] Train Reward: -346.956 | Eval Reward: -399.090 | Steps: 1000
# [Episode 10/150] Train Reward: -208.350 | Eval Reward: -342.390 | Steps: 1000
# [Episode 15/150] Train Reward: -266.577 | Eval Reward: -201.286 | Steps: 1000
# [Episode 20/150] Train Reward: -461.562 | Eval Reward: -179.047 | Steps: 1000
# [Episode 25/150] Train Reward: 65.739 | Eval Reward: 474.588 | Steps: 1000
# [Episode 30/150] Train Reward: 591.587 | Eval Reward: 334.804 | Steps: 1000
# [Episode 35/150] Train Reward: 800.798 | Eval Reward: 917.063 | Steps: 1000
# [Episode 40/150] Train Reward: 335.436 | Eval Reward: 1202.418 | Steps: 1000
# [Episode 45/150] Train Reward: 1119.779 | Eval Reward: 875.593 | Steps: 1000
# [Episode 50/150] Train Reward: 1872.397 | Eval Reward: 2081.259 | Steps: 1000
# [Episode 55/150] Train Reward: 1970.877 | Eval Reward: 2180.550 | Steps: 1000
# [Episode 60/150] Train Reward: 2128.644 | Eval Reward: 2215.379 | Steps: 1000
# [Episode 65/150] Train Reward: 2338.564 | Eval Reward: 2560.269 | Steps: 1000
# [Episode 70/150] Train Reward: 3115.951 | Eval Reward: 2686.835 | Steps: 1000
# [Episode 75/150] Train Reward: 2807.528 | Eval Reward: 3178.231 | Steps: 1000
# [Episode 80/150] Train Reward: 3267.426 | Eval Reward: 3063.290 | Steps: 1000
# [Episode 85/150] Train Reward: 3435.641 | Eval Reward: 3541.936 | Steps: 1000
# [Episode 90/150] Train Reward: 3836.110 | Eval Reward: 3847.648 | Steps: 1000
# [Episode 95/150] Train Reward: 3876.122 | Eval Reward: 3790.142 | Steps: 1000
# [Episode 100/150] Train Reward: 3941.567 | Eval Reward: 4034.570 | Steps: 1000
# [Episode 105/150] Train Reward: 3973.739 | Eval Reward: 4227.131 | Steps: 1000
# [Episode 110/150] Train Reward: 4076.967 | Eval Reward: 3860.607 | Steps: 1000
# [Episode 115/150] Train Reward: 4166.117 | Eval Reward: 4200.169 | Steps: 1000
# [Episode 120/150] Train Reward: 4192.697 | Eval Reward: 4247.607 | Steps: 1000
# [Episode 125/150] Train Reward: 4419.413 | Eval Reward: 4275.929 | Steps: 1000
# [Episode 130/150] Train Reward: 4371.222 | Eval Reward: 4571.601 | Steps: 1000
# [Episode 135/150] Train Reward: 4541.612 | Eval Reward: 4100.970 | Steps: 1000
# [Episode 140/150] Train Reward: 4492.247 | Eval Reward: 4757.036 | Steps: 1000
# [Episode 145/150] Train Reward: 4470.275 | Eval Reward: 4629.236 | Steps: 1000
# [Episode 150/150] Train Reward: 4664.342 | Eval Reward: 4740.369 | Steps: 1000
# Finished run 5
#
# (Mean over last 50 epiosdes) Mean train rewards: 4529.30 | Mean Eval Score: 4561.08
# Finished HalfCheetah-v4

# %%
with open(SAVE_PATH_SAC, "wb") as f:
    pickle.dump(quantityDictSAC, f)

# %% [markdown]
# ## Plot all the graph across all the 3 environment and write an analysis report.

# %%
plotResults(quantityDictSAC, ["HalfCheetah-v4"], use_moving_avg=False)

# %% [markdown]
# # PPO [50 marks]
# <a id="PPO"></a>

# %% [markdown]
# PPO have quite a few key implementation details.
# Please Refer:
# "Proximal Policy Optimization Algorithms" [PPO](https://arxiv.org/abs/1707.06347) and
# "Implementation Matters in Deep RL: A Case Study on PPO and TRPO" [Implementation Matters](https://openreview.net/forum?id=r1etN1rtPB)
#
# Lets finish things off with an easy implementation of PPO!
# A easy way to check you implementation details is running your implementation on some easier environment first and make sure it converges.

# %%
#All imports here
## Feel free to add or remove

import os
import random
import time

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
from torch.distributions.normal import Normal

import torch.multiprocessing as mp
from torch.multiprocessing import Barrier, Queue, Process

# %%
# PPO Hyperparameters (multiprocessing version)

ppo_gym_id = "HalfCheetah-v4"
ppo_learning_rate = 3e-4
ppo_seed = 21
ppo_total_timesteps = 1_000_000

ppo_num_workers = 4
ppo_num_steps = 1000

ppo_gamma = 0.99
ppo_gae_lambda = 0.95

ppo_update_epochs = 10
ppo_num_minibatches = 32

ppo_clip_coef = 0.25
ppo_clip_vloss = True

ppo_ent_coef = 0.018
ppo_vf_coef = 0.5
ppo_max_grad_norm = 0.5

ppo_norm_adv = True
ppo_anneal_lr = True
ppo_target_kl = 0.025

ppo_batch_size = ppo_num_workers * ppo_num_steps
ppo_minibatch_size = ppo_batch_size // ppo_num_minibatches

print(f"PPO: batch={ppo_batch_size}, minibatch={ppo_minibatch_size}")
# Out:
# PPO: batch=4000, minibatch=125

# %%
# PPO Agent (takes raw dims, works in any process)
class PPOAgent(nn.Module):
    """
    PPO agent containing separate actor and critic networks.
    Supports both discrete and continuous action spaces.
    """

    def __init__(self, obs_dim, act_dim, is_discrete=False,
                 action_high=None, action_low=None):
        """
        Initialize the PPO agent.

        Args:
            obs_dim (int): Dimension of the observation/state space.
            act_dim (int): Dimension of the action space.
            is_discrete (bool): True if the environment has a discrete
                                action space, otherwise False.
            action_high (array-like, optional): Upper bound of the
                                continuous action space.
            action_low (array-like, optional): Lower bound of the
                                continuous action space.

        Expected Output:
            Initializes actor and critic neural networks along with
            parameters required for action scaling in continuous spaces.
        """

        #Your Code goes here
        super(PPOAgent, self).__init__()
        self.is_discrete = is_discrete

        self.actor = createPolicyNetwork(obs_dim, act_dim, hDim=[512, 324, 256])
        self.critic = createValueNetwork(obs_dim, 1, hDim=[512, 324, 256])

        self.start_time = time.time()

        if not is_discrete:
            self.register_buffer('action_high', torch.FloatTensor(action_high))
            self.register_buffer('action_low', torch.FloatTensor(action_low))
            self.actor_log_std = nn.Parameter(torch.zeros(act_dim))


    def get_value(self, x):
        """
        Compute the value estimate for a given state.

        Args:
            x (Tensor): Input state tensor of shape (batch_size, obs_dim).
        Expected Output:
            Tensor containing the predicted state value V(s)
            from the critic network.
        """
        return self.critic(x)


    def get_action_and_value(self, x, action=None):
        """
        Compute action, log probability, entropy, and state value.

        Args:
            x (Tensor): Input state tensor of shape (batch_size, obs_dim).
            action (Tensor, optional): Specific action for which the
                                       log probability should be computed.
                                       If None, the function samples an action
                                       from the policy distribution.

        Expected Output:
            action (Tensor): Sampled or provided action.
            log_prob (Tensor): Log probability of the selected action.
            entropy (Tensor): Entropy of the action distribution
                              (used for exploration).
            value (Tensor): Predicted state value from the critic.
        """
        value = self.get_value(x)

        if self.is_discrete:
            logits = self.actor(x)
            dist = Categorical(logits=logits)
            if action is None:
                action = dist.sample()
            log_prob = dist.log_prob(action)
            entropy = dist.entropy()

        else:
            mean = self.actor(x)
            log_std = torch.clamp(self.actor_log_std, -20, 2)
            std = torch.exp(log_std).expand_as(mean)
            dist = Normal(mean, std)

            if action is None:
                raw_action = dist.rsample()
                squashed = torch.tanh(raw_action)
                action = self.action_low + (squashed + 1) / 2 * (self.action_high - self.action_low)
            else:
                action = action.to(x.device)
                squashed = 2.0 * (action - self.action_low) / (self.action_high - self.action_low) - 1.0
                squashed = torch.clamp(squashed, -0.9999, 0.9999)
                raw_action = 0.5 * torch.log((1 + squashed) / (1 - squashed))

            log_prob = dist.log_prob(raw_action).sum(dim=-1)
            correction = torch.log((1 - torch.tanh(raw_action).pow(2)) + 1e-6).sum(dim=-1)
            log_prob = log_prob - correction
            entropy = dist.entropy().sum(dim=-1)

        return action, log_prob, entropy, value

# %%
def evaluate_ppo(env_id, agent_state_dict, obs_dim, act_dim, is_discrete,
                 action_high, action_low, max_eval_episodes=1, seed=0):
    env = gym.make(env_id)
    env.reset(seed=seed + 1000)

    local_agent = PPOAgent(obs_dim, act_dim, is_discrete, action_high, action_low)
    local_agent.load_state_dict(agent_state_dict)
    local_agent.eval()

    final_eval_list = []
    for e in range(max_eval_episodes):
        episode_reward = 0.0
        s, _ = env.reset()
        done = False
        truncated = False

        while not (done or truncated):
            s_tensor = torch.tensor(s, dtype=torch.float32).unsqueeze(0)
            with torch.no_grad():
                action, _, _, _ = local_agent.get_action_and_value(s_tensor)

            if is_discrete:
                action_item = action.item()
            else:
                action_item = action.squeeze(0).cpu().numpy()

            s_next, r, done, truncated, _ = env.step(action_item)
            episode_reward += r
            s = s_next

        final_eval_list.append(episode_reward)

    env.close()
    return final_eval_list

# %%
# PPO Worker + Training Loop (Multiprocessing Version)
def ppo_worker(worker_id, global_agent,
               env_id, seed, num_steps, num_updates,
               shared_obs, shared_actions, shared_logprobs,
               shared_rewards, shared_dones, shared_values,
               shared_next_obs, shared_next_done,
               collect_barrier, update_barrier, ep_queue):
    """
    PPO worker process responsible for collecting rollouts.

    Args:
        worker_id        : Unique ID of the worker process.
        global_agent     : Shared PPO policy network.
        env_id           : Gym environment name.
        seed             : Random seed for reproducibility.
        num_steps        : Number of steps collected per rollout.
        num_updates      : Number of PPO updates to perform.

        shared_obs       : Shared buffer storing observations.
        shared_actions   : Shared buffer storing actions.
        shared_logprobs  : Shared buffer storing log probabilities.
        shared_rewards   : Shared buffer storing rewards.
        shared_dones     : Shared buffer storing termination flags.
        shared_values    : Shared buffer storing value predictions.

        shared_next_obs  : Shared buffer storing next observations.
        shared_next_done : Shared buffer storing next done flag.

        collect_barrier  : Synchronization barrier for rollout collection.
        update_barrier   : Synchronization barrier after PPO update.
        ep_queue         : Queue used to send episode rewards to main process.

    Expected Output:
        This function does not return values directly.
        Instead, it stores rollout data in shared buffers and
        sends episode rewards to the main process through ep_queue.
    """
    env = gym.make(env_id)
    env.reset(seed=seed*10 + worker_id)
    env.action_space.seed(seed*10 + worker_id)
    env.observation_space.seed(seed*10 + worker_id)
    np.random.seed(seed=seed*10 + worker_id)
    random.seed(seed*10 + worker_id)
    torch.manual_seed(seed*10 + worker_id)
        
    obs_dim = env.observation_space.shape[0]
    is_discrete = isinstance(env.action_space, gym.spaces.Discrete)
    act_dim = env.action_space.n if is_discrete else env.action_space.shape[0]

    state, _ = env.reset()
    done = False
    train_reward = 0.0
    eps_steps = 0
    eps_train_time = 0.0

    local_agent = PPOAgent(
        obs_dim, act_dim, is_discrete,
        env.action_space.high if not is_discrete else None,
        env.action_space.low if not is_discrete else None
    )
    local_agent.eval()
    local_agent.to('cpu')

    for update in range(num_updates):
        local_agent.load_state_dict(global_agent.state_dict())

        local_obs = []
        local_actions = []
        local_logprobs = []
        local_rewards = []
        local_dones = []
        local_values = []

        for step in range(num_steps):
            eps_steps += 1
            state_tensor = torch.FloatTensor(state).unsqueeze(0)

            with torch.no_grad():
                action, log_prob, _, value = local_agent.get_action_and_value(state_tensor)

            if is_discrete:
                action_item = action.item()
            else:
                action_item = action.squeeze(0).cpu().numpy()

            next_state, reward, done, truncated, _ = env.step(action_item)
            done = done or truncated

            local_obs.append(state.copy())
            if is_discrete:
                local_actions.append(action.item())
            else:
                local_actions.append(action_item)

            local_logprobs.append(log_prob.item())
            local_rewards.append(reward)
            local_dones.append(float(done))
            local_values.append(value.item())

            train_reward += reward
            eps_train_time = time.time() - global_agent.start_time

            if done:
                ep_queue.put((worker_id, train_reward, eps_steps, eps_train_time))
                train_reward = 0.0
                eps_steps = 0
                state, _ = env.reset()
                done = False
            else:
                state = next_state
                done = done

        offset = worker_id * num_steps
        for i, (o, a, lp, r, d, v) in enumerate(
            zip(local_obs, local_actions, local_logprobs, local_rewards, local_dones, local_values)
        ):
            idx = offset + i
            shared_obs[idx, :] = torch.from_numpy(o) if isinstance(o, np.ndarray) else o
            shared_actions[idx] = a if isinstance(a, (int, float)) else torch.tensor(a)
            shared_logprobs[idx] = lp
            shared_rewards[idx] = r
            shared_dones[idx] = d
            shared_values[idx] = v

        shared_next_obs[worker_id, :] = torch.from_numpy(state) if isinstance(state, np.ndarray) else state
        shared_next_done[worker_id] = float(done)

        collect_barrier.wait()
        update_barrier.wait()

    env.close()

# %%
def train_ppo(env_id=ppo_gym_id, seed=ppo_seed,
              total_timesteps=ppo_total_timesteps,
              num_workers=ppo_num_workers, num_steps=ppo_num_steps,
              lr=ppo_learning_rate, gamma=ppo_gamma,
              gae_lambda=ppo_gae_lambda, update_epochs=ppo_update_epochs,
              num_minibatches=ppo_num_minibatches,
              clip_coef=ppo_clip_coef, clip_vloss=ppo_clip_vloss,
              ent_coef=ppo_ent_coef, vf_coef=ppo_vf_coef,
              max_grad_norm=ppo_max_grad_norm, norm_adv=ppo_norm_adv,
              anneal_lr=ppo_anneal_lr, target_kl=ppo_target_kl):
    """
    PPO training loop using multiprocessing workers.

    Args:
        env_id           : Gym environment used for training.
        seed             : Random seed.
        total_timesteps  : Total number of environment interactions.
        num_workers      : Number of parallel workers collecting data.
        num_steps        : Number of rollout steps per worker.

        lr               : Learning rate for optimizer.
        gamma            : Discount factor for future rewards.
        gae_lambda       : Lambda parameter for GAE.

        update_epochs    : Number of PPO update passes per batch.
        num_minibatches  : Number of minibatches for SGD.

        clip_coef        : PPO clipping coefficient.
        clip_vloss       : Whether value loss clipping is used.

        ent_coef         : Entropy coefficient for exploration.
        vf_coef          : Value loss coefficient.
        max_grad_norm    : Maximum gradient norm for clipping.

        norm_adv         : Whether to normalize advantages.
        anneal_lr        : Whether learning rate is annealed.
        target_kl        : Optional KL divergence stopping threshold.

    Expected Output:
        results      : List containing tuples (global_step, episode_reward)
                       used to plot the learning curve.
        global_agent : The trained PPO agent.
    """
    dummy_env = gym.make(env_id)
    obs_dim = dummy_env.observation_space.shape[0]
    is_discrete = isinstance(dummy_env.action_space, gym.spaces.Discrete)
    act_dim = dummy_env.action_space.n if is_discrete else dummy_env.action_space.shape[0]
    action_high = dummy_env.action_space.high if not is_discrete else None
    action_low = dummy_env.action_space.low if not is_discrete else None
    dummy_env.close()

    batch_size = num_workers * num_steps
    num_updates = total_timesteps // batch_size
    minibatch_size = batch_size // num_minibatches

    print(f"Starting PPO training: {num_updates} updates, batch size {batch_size}")

    global_agent = PPOAgent(obs_dim, act_dim, is_discrete, action_high, action_low)
    global_agent.share_memory()

    shared_obs = torch.zeros((num_workers * num_steps, obs_dim), dtype=torch.float32).share_memory_()

    if is_discrete:
        shared_actions = torch.zeros((num_workers * num_steps,), dtype=torch.long).share_memory_()
    else:
        shared_actions = torch.zeros((num_workers * num_steps, act_dim), dtype=torch.float32).share_memory_()

    shared_logprobs = torch.zeros((num_workers * num_steps,), dtype=torch.float32).share_memory_()
    shared_rewards = torch.zeros((num_workers * num_steps,), dtype=torch.float32).share_memory_()
    shared_dones = torch.zeros((num_workers * num_steps,), dtype=torch.float32).share_memory_()
    shared_values = torch.zeros((num_workers * num_steps,), dtype=torch.float32).share_memory_()

    shared_next_obs = torch.zeros((num_workers, obs_dim), dtype=torch.float32).share_memory_()
    shared_next_done = torch.zeros((num_workers,), dtype=torch.float32).share_memory_()

    collect_barrier = Barrier(num_workers + 1)
    update_barrier = Barrier(num_workers + 1)

    ep_queue = Queue()
    global_steps = 0
    global_episodes = 0
    start_time = time.time()

    workers = []
    for worker_id in range(num_workers):
        p = Process(target=ppo_worker, args=(
            worker_id, global_agent, env_id, seed, num_steps, num_updates,
            shared_obs, shared_actions, shared_logprobs,
            shared_rewards, shared_dones, shared_values,
            shared_next_obs, shared_next_done,
            collect_barrier, update_barrier, ep_queue
        ))
        p.start()
        workers.append(p)

    optimizer = optim.Adam(global_agent.parameters(), lr=lr, eps=1e-5)

    results = []
    eval_results = []

    for update in range(num_updates):
        if anneal_lr:
            frac = 1.0 - update / num_updates
            lrnow = frac * lr
            optimizer.param_groups[0]["lr"] = lrnow
        collect_barrier.wait()

        while not ep_queue.empty():
            try:
                worker_id, train_reward, eps_steps, train_time = ep_queue.get_nowait()
                global_steps += eps_steps
                global_episodes += 1
                results.append((global_episodes, train_reward, global_steps, train_time, eps_steps))
            except:
                break

        with torch.no_grad():
            next_values = global_agent.get_value(shared_next_obs).squeeze()

            rewards = shared_rewards.view(num_workers, num_steps).t()
            dones = shared_dones.view(num_workers, num_steps).t()
            values = shared_values.view(num_workers, num_steps).t()
            next_values = next_values.view(1, num_workers)
            next_dones = shared_next_done.view(1, num_workers)

            advantages = torch.zeros_like(rewards)
            lastgaelam = 0

            for t in reversed(range(num_steps)):
                if t == num_steps - 1:
                    nextnonterminal = 1.0 - next_dones
                    nextvals = next_values
                else:
                    nextnonterminal = 1.0 - dones[t+1]
                    nextvals = values[t+1]

                delta = rewards[t] + gamma * nextvals * nextnonterminal - values[t]
                advantages[t] = lastgaelam = delta + gamma * gae_lambda * nextnonterminal * lastgaelam

            returns = advantages + values
            advantages = advantages.t().reshape(-1)
            returns = returns.t().reshape(-1)

            if norm_adv:
                advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-6)

        b_obs = shared_obs
        if is_discrete:
            b_actions = shared_actions.long()
        else:
            b_actions = shared_actions
        b_logprobs = shared_logprobs
        b_advantages = advantages
        b_returns = returns
        b_values = shared_values
        b_inds = np.arange(batch_size)
        clipfracs = []

        for epoch in range(update_epochs):
            np.random.shuffle(b_inds)
            for start in range(0, batch_size, minibatch_size):
                end = start + minibatch_size
                mb_inds = b_inds[start:end]

                _, newlogprob, entropy, newvalue = global_agent.get_action_and_value(
                    b_obs[mb_inds],
                    b_actions[mb_inds] if not is_discrete else b_actions[mb_inds]
                )

                logratio = newlogprob - b_logprobs[mb_inds]
                ratio = logratio.exp()

                with torch.no_grad():
                    old_approx_kl = (-logratio).mean()
                    approx_kl = ((ratio - 1) - logratio).mean()
                    clipfracs.append(((ratio - 1.0).abs() > clip_coef).float().mean().item())

                mb_advantages = b_advantages[mb_inds]
                pg_loss1 = -mb_advantages * ratio
                pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - clip_coef, 1 + clip_coef)
                pg_loss = torch.max(pg_loss1, pg_loss2).mean()

                newvalue = newvalue.view(-1)
                if clip_vloss:
                    v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                    v_clipped = b_values[mb_inds] + torch.clamp(
                        newvalue - b_values[mb_inds],
                        -clip_coef,
                        clip_coef,
                    )
                    v_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
                    v_loss_max = torch.max(v_loss_unclipped, v_loss_clipped)
                    v_loss = 0.5 * v_loss_max.mean()
                else:
                    v_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()

                entropy_loss = entropy.mean()
                loss = pg_loss - ent_coef * entropy_loss + vf_coef * v_loss

                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(global_agent.parameters(), max_grad_norm)
                optimizer.step()

            if target_kl is not None:
                if approx_kl > target_kl:
                    break

        update_barrier.wait()

        state_dict = global_agent.state_dict()
        final_eval_rew = evaluate_ppo(env_id, state_dict, obs_dim, act_dim, is_discrete, global_agent.action_high, global_agent.action_low, seed=seed, max_eval_episodes=MAX_EVAL_EPISODES)
        eval_reward = np.mean(final_eval_rew)
        wall_time = time.time() - start_time
        eval_results.append((global_episodes, eval_reward, wall_time))


        if update % 10 == 0:
            print(f"Update {update}/{num_updates}, Episodes collected: {len(results)}")
            if len(results) > 0:
                recent_eval_rewards = [er for _, er, _ in eval_results[-10:]]
                recent_train_rewards = [tr for _, tr, _, _, _ in results[-10:]]
                print(f"[Update {update+1}] Mean train Reward (last 10): {np.mean(recent_train_rewards):.2f} | Mean Eval reward (last 10): {np.mean(recent_eval_rewards):.2f}")

    for p in workers:
        p.join()

    while not ep_queue.empty():
        try:
            worker_id, train_reward, eps_steps, train_time = ep_queue.get_nowait()
            global_steps += eps_steps
            global_episodes += 1
            results.append((global_episodes, train_reward, global_steps, train_time, eps_steps))
        except:
            break
    
    state_dict = global_agent.state_dict()
    final_eval_rew = evaluate_ppo(env_id, state_dict, obs_dim, act_dim, is_discrete, global_agent.action_high, global_agent.action_low, seed=seed, max_eval_episodes=MAX_EVAL_EPISODES)
    eval_reward = np.mean(final_eval_rew)
    wall_time = time.time() - start_time
    eval_results.append((global_episodes, eval_reward, wall_time))

    return results, eval_results, global_agent

# %%
quantityDictPPO = {}
env_names = ["HalfCheetah-v4"]

num_runs = 5
for env_name in env_names:

    print(f"\n===== Environment: {env_name} =====")
    train_r = []
    eval_r = []
    
    all_train_rs = []
    all_eval_rs = []
    all_train_ts = []
    all_wall_ts = []
    all_global_steps = []
    all_e_steps = []

    for run in range(num_runs):
        print(f"Run {run+1}")

        results, eval_results, global_agent = train_ppo(
            env_id=env_name,
            seed=ppo_seed + run,
            total_timesteps=ppo_total_timesteps,
            num_workers=ppo_num_workers,
            num_steps=ppo_num_steps,
            lr=ppo_learning_rate,
            gamma=ppo_gamma,
            gae_lambda=ppo_gae_lambda,
            update_epochs=ppo_update_epochs,
            num_minibatches=ppo_num_minibatches,
            clip_coef=ppo_clip_coef,
            clip_vloss=ppo_clip_vloss,
            ent_coef=ppo_ent_coef,
            vf_coef=ppo_vf_coef,
            max_grad_norm=ppo_max_grad_norm,
            norm_adv=ppo_norm_adv,
            anneal_lr=ppo_anneal_lr,
            target_kl=ppo_target_kl
        )

        _, rewards, global_steps, train_times, e_steps = zip(*results)
        train_r.append(rewards)
        _, eval_results, wall_times = zip(*eval_results)
        eval_r.append(eval_results)

        all_train_rs.append(rewards)
        all_eval_rs.append(eval_results)
        all_train_ts.append(train_times)
        all_wall_ts.append(wall_times)
        all_global_steps.append(global_steps)
        all_e_steps.append(e_steps)

    # Compute Statistics
    if train_r:
        ppo_train_rewards = [np.mean(run[-50:]) for run in train_r]
        ppo_eval_rewards = [np.mean(run[-50:]) for run in eval_r]
        print(f"\nFinished {env_name}")
        print(f"Total episodes collected: {len(train_r[0])}")
        print(f"Mean train rewards: {np.mean(ppo_train_rewards):.2f} | Mean Eval Rewards: {np.mean(ppo_eval_rewards):.2f}")

    quantityDictPPO[env_name] = {
        "Mean Train Rewards": {"PPO": all_train_rs},
        "Mean Eval Rewards": {"PPO": all_eval_rs},
        "Global Steps": {"PPO": all_global_steps},
        "Train Time (in sec)": {"PPO": all_train_ts},
        "WallClock Time (in sec)": {"PPO": all_wall_ts},
        "Total Steps": {"PPO": all_e_steps}
    }
# Out:
# ===== Environment: HalfCheetah-v4 =====
# Run 1
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -525.40 | Mean Eval reward (last 10): -359.98
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): -170.66 | Mean Eval reward (last 10): -241.28
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): -30.22 | Mean Eval reward (last 10): -76.80
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): 137.49 | Mean Eval reward (last 10): 72.88
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): 284.80 | Mean Eval reward (last 10): 293.34
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): 381.00 | Mean Eval reward (last 10): 282.30
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): 452.89 | Mean Eval reward (last 10): 553.12
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): 702.09 | Mean Eval reward (last 10): 693.70
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): 988.78 | Mean Eval reward (last 10): 978.35
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): 1023.09 | Mean Eval reward (last 10): 1092.91
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): 1171.40 | Mean Eval reward (last 10): 1089.36
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 1293.36 | Mean Eval reward (last 10): 1245.17
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 1265.76 | Mean Eval reward (last 10): 1245.78
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 1268.40 | Mean Eval reward (last 10): 1215.30
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 1270.02 | Mean Eval reward (last 10): 1288.12
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 1384.49 | Mean Eval reward (last 10): 1346.67
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 1503.43 | Mean Eval reward (last 10): 1475.02
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 1471.95 | Mean Eval reward (last 10): 1539.56
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 1611.34 | Mean Eval reward (last 10): 1563.05
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 1577.11 | Mean Eval reward (last 10): 1695.24
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 1719.40 | Mean Eval reward (last 10): 1672.94
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 1724.83 | Mean Eval reward (last 10): 1742.59
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 1829.64 | Mean Eval reward (last 10): 1716.35
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 1838.48 | Mean Eval reward (last 10): 1773.87
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 1842.81 | Mean Eval reward (last 10): 1816.64
# Run 2
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -340.57 | Mean Eval reward (last 10): -334.48
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): -234.89 | Mean Eval reward (last 10): -295.68
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): -290.98 | Mean Eval reward (last 10): -264.75
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): -210.18 | Mean Eval reward (last 10): -205.63
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): -133.82 | Mean Eval reward (last 10): -137.73
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): -199.71 | Mean Eval reward (last 10): -50.27
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): -73.56 | Mean Eval reward (last 10): -148.63
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): -11.08 | Mean Eval reward (last 10): -117.70
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): -11.42 | Mean Eval reward (last 10): -5.86
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): -203.90 | Mean Eval reward (last 10): 65.85
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): -35.35 | Mean Eval reward (last 10): -0.94
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 121.54 | Mean Eval reward (last 10): 121.19
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 57.28 | Mean Eval reward (last 10): -51.24
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 28.52 | Mean Eval reward (last 10): 202.25
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 237.01 | Mean Eval reward (last 10): 141.25
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 141.70 | Mean Eval reward (last 10): 210.93
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 320.11 | Mean Eval reward (last 10): 88.32
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 307.14 | Mean Eval reward (last 10): 241.71
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 406.97 | Mean Eval reward (last 10): 282.77
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 554.81 | Mean Eval reward (last 10): 422.89
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 395.23 | Mean Eval reward (last 10): 326.76
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 301.84 | Mean Eval reward (last 10): 414.79
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 313.86 | Mean Eval reward (last 10): 590.53
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 495.71 | Mean Eval reward (last 10): 636.29
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 630.21 | Mean Eval reward (last 10): 315.76
# Run 3
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -404.79 | Mean Eval reward (last 10): -241.19
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): -180.09 | Mean Eval reward (last 10): -216.07
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): -109.55 | Mean Eval reward (last 10): -199.74
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): 105.25 | Mean Eval reward (last 10): 64.39
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): 260.84 | Mean Eval reward (last 10): 327.17
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): 569.01 | Mean Eval reward (last 10): 543.03
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): 737.75 | Mean Eval reward (last 10): 673.48
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): 1110.53 | Mean Eval reward (last 10): 975.26
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): 1145.00 | Mean Eval reward (last 10): 1123.01
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): 1182.86 | Mean Eval reward (last 10): 1136.30
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): 1174.59 | Mean Eval reward (last 10): 1132.08
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 1263.13 | Mean Eval reward (last 10): 1209.98
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 1220.17 | Mean Eval reward (last 10): 1252.40
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 1195.97 | Mean Eval reward (last 10): 1262.33
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 1380.57 | Mean Eval reward (last 10): 1316.63
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 1336.17 | Mean Eval reward (last 10): 1353.57
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 1456.54 | Mean Eval reward (last 10): 1359.77
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 1496.95 | Mean Eval reward (last 10): 1439.70
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 1448.69 | Mean Eval reward (last 10): 1474.98
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 1413.28 | Mean Eval reward (last 10): 1392.94
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 1510.10 | Mean Eval reward (last 10): 1446.69
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 1459.95 | Mean Eval reward (last 10): 1404.23
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 1466.81 | Mean Eval reward (last 10): 1420.93
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 1447.26 | Mean Eval reward (last 10): 1492.18
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 1410.85 | Mean Eval reward (last 10): 1561.11
# Run 4
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -183.66 | Mean Eval reward (last 10): -174.02
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): -138.64 | Mean Eval reward (last 10): -268.70
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): -266.92 | Mean Eval reward (last 10): -281.99
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): -230.26 | Mean Eval reward (last 10): -211.78
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): -234.91 | Mean Eval reward (last 10): -250.22
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): -237.74 | Mean Eval reward (last 10): -246.24
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): -276.98 | Mean Eval reward (last 10): -238.52
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): -207.36 | Mean Eval reward (last 10): -253.64
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): 159.31 | Mean Eval reward (last 10): 33.51
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): 659.48 | Mean Eval reward (last 10): 428.57
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): 858.04 | Mean Eval reward (last 10): 811.09
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 950.38 | Mean Eval reward (last 10): 752.42
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 963.86 | Mean Eval reward (last 10): 919.35
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 1027.39 | Mean Eval reward (last 10): 1108.55
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 1288.88 | Mean Eval reward (last 10): 1269.56
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 1368.29 | Mean Eval reward (last 10): 1356.94
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 1495.56 | Mean Eval reward (last 10): 1380.95
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 1409.72 | Mean Eval reward (last 10): 1414.24
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 1440.20 | Mean Eval reward (last 10): 1371.21
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 1456.66 | Mean Eval reward (last 10): 1380.57
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 1359.42 | Mean Eval reward (last 10): 1513.86
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 1524.18 | Mean Eval reward (last 10): 1499.12
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 1416.14 | Mean Eval reward (last 10): 1490.66
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 1388.97 | Mean Eval reward (last 10): 1475.79
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 1517.74 | Mean Eval reward (last 10): 1515.57
# Run 5
# Starting PPO training: 250 updates, batch size 4000
# Update 0/250, Episodes collected: 4
# [Update 1] Mean train Reward (last 10): -227.58 | Mean Eval reward (last 10): -221.81
# Update 10/250, Episodes collected: 44
# [Update 11] Mean train Reward (last 10): 29.14 | Mean Eval reward (last 10): -83.68
# Update 20/250, Episodes collected: 84
# [Update 21] Mean train Reward (last 10): 475.01 | Mean Eval reward (last 10): 338.11
# Update 30/250, Episodes collected: 124
# [Update 31] Mean train Reward (last 10): 187.62 | Mean Eval reward (last 10): 312.47
# Update 40/250, Episodes collected: 164
# [Update 41] Mean train Reward (last 10): -15.75 | Mean Eval reward (last 10): 228.10
# Update 50/250, Episodes collected: 204
# [Update 51] Mean train Reward (last 10): 570.68 | Mean Eval reward (last 10): 574.99
# Update 60/250, Episodes collected: 244
# [Update 61] Mean train Reward (last 10): 961.16 | Mean Eval reward (last 10): 987.61
# Update 70/250, Episodes collected: 284
# [Update 71] Mean train Reward (last 10): 687.13 | Mean Eval reward (last 10): 769.33
# Update 80/250, Episodes collected: 324
# [Update 81] Mean train Reward (last 10): 975.12 | Mean Eval reward (last 10): 864.21
# Update 90/250, Episodes collected: 364
# [Update 91] Mean train Reward (last 10): 1350.06 | Mean Eval reward (last 10): 1553.31
# Update 100/250, Episodes collected: 404
# [Update 101] Mean train Reward (last 10): 1418.56 | Mean Eval reward (last 10): 1360.97
# Update 110/250, Episodes collected: 444
# [Update 111] Mean train Reward (last 10): 1750.93 | Mean Eval reward (last 10): 1554.03
# Update 120/250, Episodes collected: 484
# [Update 121] Mean train Reward (last 10): 1773.24 | Mean Eval reward (last 10): 2017.73
# Update 130/250, Episodes collected: 524
# [Update 131] Mean train Reward (last 10): 2349.93 | Mean Eval reward (last 10): 2154.07
# Update 140/250, Episodes collected: 564
# [Update 141] Mean train Reward (last 10): 2353.02 | Mean Eval reward (last 10): 2271.32
# Update 150/250, Episodes collected: 604
# [Update 151] Mean train Reward (last 10): 2394.45 | Mean Eval reward (last 10): 2388.61
# Update 160/250, Episodes collected: 644
# [Update 161] Mean train Reward (last 10): 2397.24 | Mean Eval reward (last 10): 2590.85
# Update 170/250, Episodes collected: 684
# [Update 171] Mean train Reward (last 10): 2272.28 | Mean Eval reward (last 10): 2340.92
# Update 180/250, Episodes collected: 724
# [Update 181] Mean train Reward (last 10): 2662.97 | Mean Eval reward (last 10): 2277.84
# Update 190/250, Episodes collected: 764
# [Update 191] Mean train Reward (last 10): 2663.63 | Mean Eval reward (last 10): 2643.06
# Update 200/250, Episodes collected: 804
# [Update 201] Mean train Reward (last 10): 2663.61 | Mean Eval reward (last 10): 2588.39
# Update 210/250, Episodes collected: 844
# [Update 211] Mean train Reward (last 10): 2548.34 | Mean Eval reward (last 10): 2551.68
# Update 220/250, Episodes collected: 884
# [Update 221] Mean train Reward (last 10): 2650.97 | Mean Eval reward (last 10): 2646.40
# Update 230/250, Episodes collected: 924
# [Update 231] Mean train Reward (last 10): 2712.24 | Mean Eval reward (last 10): 2662.96
# Update 240/250, Episodes collected: 964
# [Update 241] Mean train Reward (last 10): 2689.33 | Mean Eval reward (last 10): 2667.62
#
# Finished HalfCheetah-v4
# Total episodes collected: 1000
# Mean train rewards: 1587.77 | Mean Eval Rewards: 1561.88

# %% [markdown]
# # Experiments and Plots [$20 \times 5=100$ marks]
# <a id="experiments"></a>

# %% [markdown]
# Run the VPG, REINFORCE on Pendulum and DDPG, TD3, PPO, on Half Cheetah.
#
# Plot the following for each of the environment separately. Note based on different hyper-parameters and strategies you use, you can have multiple plots for each of the below.
#
# As you are aware from your past experience, single run of the agent over the environment results in plots that have lot of variance and look very noisy. One way to overcome this is to create several different instances of the environment using different seeds and then average out the results across these and plot these. For all the plots below, you this strategy. You need to run 5 different instances of the environment for each agent. As you have seen in the lecture slides, we plot the maximum and minimum values around the mean in the plots, so this gives us the shaded plot with the mean curve in the between. In this assignment, you are required to do the same. Generate plots with envelop between maximum and minimum value
# For each of the quantity of interest, plot each of the agent within the same plot using different colors for the envelop. Choose colors such that that there is clear contrast between the plots corresponding to different agents.
#
# 1. Plot mean train rewards vs episodes
# 2. Plot mean evaluation rewards vs episodes
# 3. Plot total steps vs episode
# 4. Plot train time vs episode
# 5. Plot wall clock time vs episode
# 6. Based on plots what are your observations about DDPG and TD3, compare the two algorithms.
# 7. What is the advatage of PPO over DDPG or TD3?

# %%
with open(SAVE_PATH_REIN, "rb") as f:
    reinforceQuantityDict = pickle.load(f)

with open(SAVE_PATH_VPG, "rb") as f:
    quantityDictVPG = pickle.load(f)

# %%
env_name = "Pendulum-v1"
config1 = {
    env_name: {
        "Mean Train Rewards": {
            **reinforceQuantityDict[env_name]["Mean Train Rewards"],
            **quantityDictVPG[env_name]["Mean Train Rewards"]
        },
        "Mean Eval Rewards": {
            **reinforceQuantityDict[env_name]["Mean Eval Rewards"],
            **quantityDictVPG[env_name]["Mean Eval Rewards"]
        },
        "Train Time (in sec)": {
            **reinforceQuantityDict[env_name]["Train Time (in sec)"],
            **quantityDictVPG[env_name]["Train Time (in sec)"]
        },
        "Wall Clock Time (in sec)": {
            **reinforceQuantityDict[env_name]["Wall Clock Time (in sec)"],
            **quantityDictVPG[env_name]["Wall Clock Time (in sec)"]
        },
        "Total Steps": {
            **reinforceQuantityDict[env_name]["Total Steps"],
            **quantityDictVPG[env_name]["Total Steps"]
        }
    }
}

plotResults(config1, [env_name], use_moving_avg=False)

# %%
SAVE_PATH_TD3 = "./plot_configs/rl_results_td3.pkl"
SAVE_PATH_DDPG = "./plot_configs/rl_results_ddpg.pkl"
SAVE_PATH_PPO = "./plot_configs/rl_results_ppo.pkl"

# %%
with open(SAVE_PATH_DDPG, "rb") as f:
    quantityDictDDPG = pickle.load(f)

with open(SAVE_PATH_TD3, "rb") as f:
    quantityDictTD3 = pickle.load(f)

with open(SAVE_PATH_PPO, "rb") as f:
    quantityDictPPO = pickle.load(f)

# %%
env_name = "HalfCheetah-v4"
config2 = {
    env_name: {
        "Mean Train Rewards": {
            **quantityDictDDPG[env_name]["Mean Train Rewards"],
            **quantityDictTD3[env_name]["Mean Train Rewards"],
            **quantityDictPPO[env_name]["Mean Train Rewards"]
        },
        "Mean Eval Rewards": {
            **quantityDictDDPG[env_name]["Mean Eval Rewards"],
            **quantityDictTD3[env_name]["Mean Eval Rewards"],
            **quantityDictPPO[env_name]["Mean Eval Rewards"]
        },
        "Train Time (in sec)": {
            **quantityDictDDPG[env_name]["Train Time (in sec)"],
            **quantityDictTD3[env_name]["Train Time (in sec)"],
            **quantityDictPPO[env_name]["Train Time (in sec)"]
        },
        "Wall Clock Time (in sec)": {
            **quantityDictDDPG[env_name]["Wall Clock Time (in sec)"],
            **quantityDictTD3[env_name]["Wall Clock Time (in sec)"],
            **quantityDictPPO[env_name]["WallClock Time (in sec)"]
        },
        "Total Steps": {
            **quantityDictDDPG[env_name]["Total Steps"],
            **quantityDictTD3[env_name]["Total Steps"],
            **quantityDictPPO[env_name]["Total Steps"]
        }
    }
}

plotResults(config2, [env_name], use_moving_avg=False)
